# %%
# !python3 -m spacy download pt_core_news_lg
from tensorflow.keras import optimizers
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.probability import FreqDist
from scipy.sparse import csr_matrix
from nltk.corpus import stopwords
from transformers import pipeline
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
# %matplotlib inline
import torch
import string
import nltk
import re
# Out:
# Collecting pt-core-news-lg==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/pt_core_news_lg-3.7.0/pt_core_news_lg-3.7.0-py3-none-any.whl (568.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 568.2/568.2 MB 998.6 kB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from pt-core-news-lg==3.7.0) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (4.66.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.7.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (24.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (1.25.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.18.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.1.5)
# Installing collected packages: pt-core-news-lg
# Successfully installed pt-core-news-lg-3.7.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
classificador = pipeline("zero-shot-classification")
rotulos = ["testador", "aplicativo", "desempenho", "teste"]
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli and revision c626438 (https://huggingface.co/facebook/bart-large-mnli).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
roberta = pipeline("ner", grouped_entities=True, model="joelniklaus/legal-portuguese-roberta-base")
# Out:
# config.json:   0%|          | 0.00/699 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/443M [00:00<?, ?B/s]
# Some weights of RobertaForTokenClassification were not initialized from the model checkpoint at joelniklaus/legal-portuguese-roberta-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# tokenizer_config.json:   0%|          | 0.00/403 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.41M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/167 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/token_classification.py:168: UserWarning: `grouped_entities` is deprecated and will be removed in version v5.0.0, defaulted to `aggregation_strategy="simple"` instead.
#   warnings.warn(

# %%
historias_usuario = [
    "Como Testador eu quero um jeito mais fácil de incluir os requisitos do aplicativo na ferramenta DRL-Mobtest para criar casos de teste que cubram tudo que o aplicativo precisa fazer, sem ter que gastar muito tempo escrevendo manualmente.",
    "Como Testador eu quero uma maneira de ensinar a ferramenta DRL-Mobtest a entender os requisitos do aplicativo usando NLP para fazer com que a ferramenta gere testes automaticamente.",
    "Como Testador eu quero que a ferramenta gere casos de teste abrangentes que cubram integralmente todos os requisitos do aplicativo, assegurando que o software seja completo e funcional, sem depender exclusivamente da criação manual de casos de teste.",
    "Como Testador eu quero que a ferramenta seja integrada com outras ferramentas de gerenciamento, permitindo sincronização automática dos requisitos e facilitando o processo de criação de casos de testes.",
    "Como testador, eu quero que a ferramenta gere casos de teste completos e funcionais que cubram todos os requisitos do aplicativo, para garantir uma cobertura abrangente durante os testes.",
    "Como testador, eu quero integração com outras ferramentas de gerenciamento para sincronizar automaticamente requisitos e facilitar a criação de casos de teste, visando melhorar a eficiência e precisão do processo de teste.",
    "Como testador, eu quero relatórios detalhados sobre a cobertura dos testes para análise precisa durante a execução, a fim de avaliar a qualidade e a extensão dos testes realizados.",
    "Como testador, eu desejo que a ferramenta identifique automaticamente os casos de teste mais críticos para priorizar a análise, visando direcionar os esforços de teste para áreas de maior risco.",
    "Como testador, eu preciso que a ferramenta sugira casos de teste com base em padrões de uso real do aplicativo, para garantir que os testes reflitam cenários típicos de uso.",
    "Como testador, eu quero sugestões com base em padrões de falha históricos para evitar problemas recorrentes no software, visando melhorar a qualidade e a robustez do produto.",
    "Como testador, eu desejo suporte à execução de testes automatizados em diferentes dispositivos e ambientes, para garantir a consistência e a confiabilidade dos testes em diferentes cenários.",
    "Como testador, eu preciso que a ferramenta detecte automaticamente mudanças nos requisitos e ajuste os casos de teste correspondentes, para manter os testes alinhados com a evolução do aplicativo.",
    "Como testador, eu quero integração com sistemas de controle de versão para rastrear mudanças nos requisitos e no código-fonte, visando uma gestão eficaz de mudanças durante o ciclo de desenvolvimento.",
    "Como testador, eu desejo métricas detalhadas sobre a eficácia dos testes, incluindo taxa de cobertura e taxa de falha, para avaliar a qualidade do processo de teste.",
    "Como testador, eu preciso de suporte à execução de testes de desempenho e escalabilidade, para garantir que o aplicativo atenda aos requisitos de desempenho sob carga.",
    "Como testador, eu quero análise automática dos resultados dos testes para relatórios detalhados sobre problemas encontrados, a fim de facilitar a identificação e correção de defeitos.",
    "Como testador, eu desejo simular cenários de teste complexos e realistas para garantir testes próximos à realidade, visando uma validação mais precisa do software.",
    "Como testador, eu preciso de suporte à execução de testes de regressão automatizados, para garantir que as alterações no código não introduzam regressões.",
    "Como testador, eu quero identificação automática de casos de teste redundantes ou desnecessários, para otimizar os esforços de teste.",
    "Como testador, eu desejo integração fácil com ferramentas de gerenciamento de projetos, para uma colaboração eficiente com outros membros da equipe de desenvolvimento.",
    "Como testador, eu preciso de suporte à execução de testes de usabilidade, para garantir que o aplicativo seja fácil e intuitivo de usar.",
    "Como testador, eu quero que a ferramenta crie automaticamente conjuntos de dados de teste realistas, para simular condições reais de uso.",
    "Como testador, eu desejo integração com ferramentas de monitoramento de desempenho em tempo real, para avaliar o desempenho do aplicativo durante os testes.",
    "Como testador, eu preciso de suporte à execução de testes de localização e internacionalização, para garantir que o aplicativo seja compatível com diferentes idiomas e regiões.",
    "Como testador, eu quero geração automática de dados de teste sintéticos, para complementar os casos de teste manuais.",
    "Como testador, eu desejo suporte à execução de testes de acessibilidade, para garantir que o aplicativo seja acessível a todos os usuários.",
    "Como testador, eu preciso de suporte à execução de testes de integração contínua, para garantir que as alterações no código não quebrem a integração com outras partes do sistema.",
    "Como testador, eu quero identificação automática de casos de teste incompletos ou mal definidos, para garantir a qualidade dos testes.",
    "Como testador, eu desejo identificação automática de dependências entre casos de teste, para garantir uma sequência lógica na execução dos testes.",
    "Como testador, eu preciso de suporte à execução de testes de recuperação de desastres, para avaliar a capacidade do sistema de se recuperar de falhas.",
    "Como testador, eu quero que a ferramenta identifique automaticamente casos de teste paralelizáveis, para otimizar a execução dos testes.",
    "Como testador, eu desejo simulação de cenários de teste de carga extremamente alta, para avaliar a capacidade de escalabilidade do sistema.",
    "Como testador, eu preciso de suporte à execução de testes de compatibilidade com diferentes navegadores e dispositivos, para garantir uma experiência consistente para todos os usuários.",
    "Como testador, eu quero geração automática de relatórios de teste personalizados, para comunicar eficazmente os resultados dos testes.",
    "Como testador, eu desejo rastreamento automático de resultados de teste ao longo do tempo, para identificar tendências e padrões de qualidade.",
    "Como testador, eu preciso de suporte à execução de testes de regressão progressiva, para garantir que as novas alterações não quebrem funcionalidades existentes.",
    "Como testador, eu quero sugestões automáticas para aprimorar os casos de teste existentes, para aumentar a eficiência e a eficácia dos testes.",
    "Como testador, eu desejo que a ferramenta aprenda com os resultados dos testes e melhore suas sugestões futuras, para uma otimização contínua do processo de teste.",
    "Como testador, eu preciso de suporte à execução de testes de segurança automatizados, para identificar vulnerabilidades no aplicativo.",
    "Como testador, eu quero integração com ferramentas de análise de código estático para identificar áreas de risco, para uma avaliação abrangente da qualidade do código.",
    "Como testador, eu desejo suporte à execução de testes de integração de sistema e teste de aceitação do usuário, para validar a integração entre diferentes partes do sistema e a conformidade com os requisitos do usuário.",
    "Como testador, eu preciso de suporte à execução de testes de confiabilidade e disponibilidade, para garantir que o aplicativo esteja sempre disponível e funcione corretamente.",
    "Como testador, eu quero que a ferramenta sugira casos de teste com base em modelos de qualidade de software reconhecidos, para garantir uma abordagem abrangente e padronizada para os testes.",
    "Como testador, eu desejo integração com ferramentas de automação de teste de interface do usuário, para automatizar testes de interação com o usuário.",
    "Como testador, eu preciso de suporte à execução de testes de estresse e robustez, para avaliar a estabilidade e a confiabilidade do aplicativo sob condições adversas.",
    "Como testador, eu quero que a ferramenta sugira casos de teste para áreas de alto risco e complexidade, para priorizar os esforços de teste.",
    "Como testador, eu desejo integração com ferramentas de gerenciamento de defeitos para rastreamento de correções, para uma gestão eficaz de problemas encontrados durante os testes.",
    "Como testador, eu preciso de suporte à execução de testes de usabilidade remota e teste de usuário beta, para coletar feedback de usuários reais.",
    "Como testador, eu quero que a ferramenta forneça feedback em tempo real durante a execução dos testes, para facilitar a identificação imediata de problemas.",
    "Como testador, eu desejo integração com ferramentas de automação de infraestrutura para provisionamento e configuração automatizados, para facilitar a preparação do ambiente de teste.",
    "Como testador, eu preciso de suporte à execução de testes de comparação de desempenho para versões anteriores e atuais do aplicativo, para avaliar o impacto de mudanças no desempenho."
]

# %%
#sem_pontuacao = re.findall(r'\b(^[^A-Za-z])\b', historias_usuario, re.IGNORECASE)

# %%
class ProcessadorHistoriasUsuario:
    def __init__(self):
        nltk.download('punkt')
        nltk.download('stopwords')
        nltk.download('wordnet')
        self.lemmatizer = WordNetLemmatizer()
        self.stop_words = set(stopwords.words('portuguese'))

    def processar_historias_usuario(self, historias_usuario):
        freq_dists = []
        for historia_usuario in historias_usuario:
            tokens = word_tokenize(historia_usuario)
            tokens = [token.lower() for token in tokens if token not in string.punctuation]
            tokens = [token for token in tokens if token not in self.stop_words]
            tokens = [self.lemmatizer.lemmatize(token) for token in tokens]
            freq_dist = FreqDist(tokens)
            freq_dists.append(freq_dist)
        return freq_dists

# %%
processador = ProcessadorHistoriasUsuario()
freq_dists = processador.processar_historias_usuario(historias_usuario)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
unicas = set()
for freq_dist in freq_dists:
    unicas.update(freq_dist.keys())

print("Total de palavras únicas:", len(unicas))
print("Diversidade Lexica:", len(unicas) / len(freq_dists))
# Out:
# Total de palavras únicas: 262
# Diversidade Lexica: 5.137254901960785

# %%
historia_index = 0
print("História de usuário original:")
print(historias_usuario[historia_index])
print()
print("Tokens processados e limpos:")
print(freq_dists[historia_index].keys())
# Out:
# História de usuário original:
# Como Testador eu quero um jeito mais fácil de incluir os requisitos do aplicativo na ferramenta DRL-Mobtest para criar casos de teste que cubram tudo que o aplicativo precisa fazer, sem ter que gastar muito tempo escrevendo manualmente.
#
# Tokens processados e limpos:
# dict_keys(['testador', 'quero', 'jeito', 'fácil', 'incluir', 'requisitos', 'aplicativo', 'ferramenta', 'drl-mobtest', 'criar', 'casos', 'teste', 'cubram', 'tudo', 'precisa', 'fazer', 'ter', 'gastar', 'tempo', 'escrevendo', 'manualmente'])

# %%
for i, freq_dist in enumerate(freq_dists):
    print(f"História de Usuário {i+1}:")
    for palavra, frequencia in freq_dist.most_common():
        print(f"- {palavra}:  - QTDE: ({frequencia})")
        print(f"tipo: {type(palavra)},\n Tamanho: {len(palavra)},\n Binário: {palavra.isalpha()},\n Null:{palavra == ''},\n")
# Out:
# História de Usuário 1:
# - aplicativo:  - QTDE: (2)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - quero:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - jeito:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - fácil:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - incluir:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - requisitos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - ferramenta:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - drl-mobtest:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: False,
#  Null:False,
#
# - criar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - casos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - teste:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - cubram:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - tudo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 4,
#  Binário: True,
#  Null:False,
#
# - precisa:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - fazer:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - ter:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 3,
#  Binário: True,
#  Null:False,
#
# - gastar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - tempo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - escrevendo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - manualmente:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# História de Usuário 2:
# - ferramenta:  - QTDE: (2)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - quero:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - maneira:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - ensinar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - drl-mobtest:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: False,
#  Null:False,
#
# - entender:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - requisitos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - aplicativo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - usando:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - nlp:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 3,
#  Binário: True,
#  Null:False,
#
# - fazer:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - gere:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 4,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - automaticamente:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 15,
#  Binário: True,
#  Null:False,
#
# História de Usuário 3:
# - casos:  - QTDE: (2)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - teste:  - QTDE: (2)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - quero:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - ferramenta:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - gere:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 4,
#  Binário: True,
#  Null:False,
#
# - abrangentes:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - cubram:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - integralmente:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 13,
#  Binário: True,
#  Null:False,
#
# - todos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - requisitos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - aplicativo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - assegurando:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - software:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - completo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - funcional:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - depender:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - exclusivamente:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 14,
#  Binário: True,
#  Null:False,
#
# - criação:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - manual:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# História de Usuário 4:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - quero:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - ferramenta:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - integrada:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - outras:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - ferramentas:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - gerenciamento:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 13,
#  Binário: True,
#  Null:False,
#
# - permitindo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - sincronização:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 13,
#  Binário: True,
#  Null:False,
#
# - automática:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - requisitos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - facilitando:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - processo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - criação:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - casos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# História de Usuário 5:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - quero:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - ferramenta:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - gere:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 4,
#  Binário: True,
#  Null:False,
#
# - casos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - teste:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - completos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - funcionais:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - cubram:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - todos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - requisitos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - aplicativo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - garantir:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - cobertura:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - abrangente:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - durante:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# História de Usuário 6:
# - teste:  - QTDE: (2)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - quero:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - integração:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - outras:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - ferramentas:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - gerenciamento:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 13,
#  Binário: True,
#  Null:False,
#
# - sincronizar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - automaticamente:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 15,
#  Binário: True,
#  Null:False,
#
# - requisitos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - facilitar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - criação:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - casos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - visando:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - melhorar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - eficiência:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - precisão:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - processo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# História de Usuário 7:
# - testis:  - QTDE: (2)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - quero:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - relatórios:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - detalhados:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - sobre:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - cobertura:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - análise:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - precisa:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - durante:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - execução:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - fim:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 3,
#  Binário: True,
#  Null:False,
#
# - avaliar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - qualidade:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - extensão:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - realizados:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# História de Usuário 8:
# - teste:  - QTDE: (2)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - desejo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - ferramenta:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - identifique:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - automaticamente:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 15,
#  Binário: True,
#  Null:False,
#
# - casos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - críticos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - priorizar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - análise:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - visando:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - direcionar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - esforços:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - áreas:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - maior:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - risco:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# História de Usuário 9:
# - uso:  - QTDE: (2)
# tipo: <class 'str'>,
#  Tamanho: 3,
#  Binário: True,
#  Null:False,
#
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - preciso:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - ferramenta:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - sugira:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - casos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - teste:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - base:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 4,
#  Binário: True,
#  Null:False,
#
# - padrões:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - real:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 4,
#  Binário: True,
#  Null:False,
#
# - aplicativo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - garantir:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - reflitam:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - cenários:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - típicos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# História de Usuário 10:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - quero:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - sugestões:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - base:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 4,
#  Binário: True,
#  Null:False,
#
# - padrões:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - falha:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - históricos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - evitar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - problemas:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - recorrentes:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - software:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - visando:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - melhorar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - qualidade:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - robustez:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - produto:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# História de Usuário 11:
# - testis:  - QTDE: (2)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - diferentes:  - QTDE: (2)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - desejo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - suporte:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - execução:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - automatizados:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 13,
#  Binário: True,
#  Null:False,
#
# - dispositivos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 12,
#  Binário: True,
#  Null:False,
#
# - ambientes:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - garantir:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - consistência:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 12,
#  Binário: True,
#  Null:False,
#
# - confiabilidade:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 14,
#  Binário: True,
#  Null:False,
#
# - cenários:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# História de Usuário 12:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - preciso:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - ferramenta:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - detecte:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - automaticamente:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 15,
#  Binário: True,
#  Null:False,
#
# - mudanças:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - requisitos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - ajuste:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - casos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - teste:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - correspondentes:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 15,
#  Binário: True,
#  Null:False,
#
# - manter:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - alinhados:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - evolução:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - aplicativo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# História de Usuário 13:
# - mudanças:  - QTDE: (2)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - quero:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - integração:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - sistemas:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - controle:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - versão:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - rastrear:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - requisitos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - código-fonte:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 12,
#  Binário: False,
#  Null:False,
#
# - visando:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - gestão:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - eficaz:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - durante:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - ciclo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - desenvolvimento:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 15,
#  Binário: True,
#  Null:False,
#
# História de Usuário 14:
# - taxon:  - QTDE: (2)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - desejo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - métricas:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - detalhadas:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - sobre:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - eficácia:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - incluindo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - cobertura:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - falha:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - avaliar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - qualidade:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - processo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - teste:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# História de Usuário 15:
# - desempenho:  - QTDE: (2)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - preciso:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - suporte:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - execução:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - escalabilidade:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 14,
#  Binário: True,
#  Null:False,
#
# - garantir:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - aplicativo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - atenda:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - requisitos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - sob:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 3,
#  Binário: True,
#  Null:False,
#
# - carga:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# História de Usuário 16:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - quero:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - análise:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - automática:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - resultados:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - relatórios:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - detalhados:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - sobre:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - problemas:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - encontrados:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - fim:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 3,
#  Binário: True,
#  Null:False,
#
# - facilitar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - identificação:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 13,
#  Binário: True,
#  Null:False,
#
# - correção:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - defeitos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# História de Usuário 17:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - desejo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - simular:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - cenários:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - teste:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - complexos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - realistas:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - garantir:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - próximos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - realidade:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - visando:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - validação:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - precisa:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - software:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# História de Usuário 18:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - preciso:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - suporte:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - execução:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - regressão:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - automatizados:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 13,
#  Binário: True,
#  Null:False,
#
# - garantir:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - alterações:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - código:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - introduzam:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - regressões:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# História de Usuário 19:
# - teste:  - QTDE: (2)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - quero:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - identificação:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 13,
#  Binário: True,
#  Null:False,
#
# - automática:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - casos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - redundantes:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - desnecessários:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 14,
#  Binário: True,
#  Null:False,
#
# - otimizar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - esforços:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# História de Usuário 20:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - desejo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - integração:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - fácil:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - ferramentas:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - gerenciamento:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 13,
#  Binário: True,
#  Null:False,
#
# - projetos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - colaboração:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - eficiente:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - outros:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - membros:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - equipe:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - desenvolvimento:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 15,
#  Binário: True,
#  Null:False,
#
# História de Usuário 21:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - preciso:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - suporte:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - execução:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - usabilidade:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - garantir:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - aplicativo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - fácil:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - intuitivo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - usar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 4,
#  Binário: True,
#  Null:False,
#
# História de Usuário 22:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - quero:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - ferramenta:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - crie:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 4,
#  Binário: True,
#  Null:False,
#
# - automaticamente:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 15,
#  Binário: True,
#  Null:False,
#
# - conjuntos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - dado:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 4,
#  Binário: True,
#  Null:False,
#
# - teste:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - realistas:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - simular:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - condições:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - reais:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - uso:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 3,
#  Binário: True,
#  Null:False,
#
# História de Usuário 23:
# - desempenho:  - QTDE: (2)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - desejo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - integração:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - ferramentas:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - monitoramento:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 13,
#  Binário: True,
#  Null:False,
#
# - tempo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - real:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 4,
#  Binário: True,
#  Null:False,
#
# - avaliar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - aplicativo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - durante:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# História de Usuário 24:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - preciso:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - suporte:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - execução:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - localização:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - internacionalização:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 19,
#  Binário: True,
#  Null:False,
#
# - garantir:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - aplicativo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - compatível:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - diferentes:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - idiomas:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - regiões:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# História de Usuário 25:
# - teste:  - QTDE: (2)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - quero:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - geração:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - automática:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - dado:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 4,
#  Binário: True,
#  Null:False,
#
# - sintéticos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - complementar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 12,
#  Binário: True,
#  Null:False,
#
# - casos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - manuais:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# História de Usuário 26:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - desejo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - suporte:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - execução:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - acessibilidade:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 14,
#  Binário: True,
#  Null:False,
#
# - garantir:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - aplicativo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - acessível:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - todos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - usuários:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# História de Usuário 27:
# - integração:  - QTDE: (2)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - preciso:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - suporte:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - execução:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - contínua:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - garantir:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - alterações:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - código:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - quebrem:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - outras:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - partes:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - sistema:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# História de Usuário 28:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - quero:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - identificação:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 13,
#  Binário: True,
#  Null:False,
#
# - automática:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - casos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - teste:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - incompletos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - mal:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 3,
#  Binário: True,
#  Null:False,
#
# - definidos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - garantir:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - qualidade:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# História de Usuário 29:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - desejo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - identificação:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 13,
#  Binário: True,
#  Null:False,
#
# - automática:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - dependências:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 12,
#  Binário: True,
#  Null:False,
#
# - casos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - teste:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - garantir:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - sequência:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - lógica:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - execução:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# História de Usuário 30:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - preciso:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - suporte:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - execução:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - recuperação:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - desastres:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - avaliar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - capacidade:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - sistema:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - recuperar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - falhas:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# História de Usuário 31:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - quero:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - ferramenta:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - identifique:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - automaticamente:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 15,
#  Binário: True,
#  Null:False,
#
# - casos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - teste:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - paralelizáveis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 14,
#  Binário: True,
#  Null:False,
#
# - otimizar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - execução:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# História de Usuário 32:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - desejo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - simulação:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - cenários:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - teste:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - carga:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - extremamente:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 12,
#  Binário: True,
#  Null:False,
#
# - alta:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 4,
#  Binário: True,
#  Null:False,
#
# - avaliar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - capacidade:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - escalabilidade:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 14,
#  Binário: True,
#  Null:False,
#
# - sistema:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# História de Usuário 33:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - preciso:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - suporte:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - execução:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - compatibilidade:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 15,
#  Binário: True,
#  Null:False,
#
# - diferentes:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - navegadores:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - dispositivos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 12,
#  Binário: True,
#  Null:False,
#
# - garantir:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - experiência:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - consistente:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - todos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - usuários:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# História de Usuário 34:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - quero:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - geração:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - automática:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - relatórios:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - teste:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - personalizados:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 14,
#  Binário: True,
#  Null:False,
#
# - comunicar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - eficazmente:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - resultados:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# História de Usuário 35:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - desejo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - rastreamento:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 12,
#  Binário: True,
#  Null:False,
#
# - automático:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - resultados:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - teste:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - longo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - tempo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - identificar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - tendências:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - padrões:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - qualidade:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# História de Usuário 36:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - preciso:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - suporte:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - execução:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - regressão:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - progressiva:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - garantir:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - nova:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 4,
#  Binário: True,
#  Null:False,
#
# - alterações:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - quebrem:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - funcionalidades:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 15,
#  Binário: True,
#  Null:False,
#
# - existentes:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# História de Usuário 37:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - quero:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - sugestões:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - automáticas:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - aprimorar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - casos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - teste:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - existentes:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - aumentar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - eficiência:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - eficácia:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# História de Usuário 38:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - desejo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - ferramenta:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - aprenda:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - resultados:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - melhore:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - sugestões:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - futuras:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - otimização:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - contínua:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - processo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - teste:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# História de Usuário 39:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - preciso:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - suporte:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - execução:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - segurança:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - automatizados:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 13,
#  Binário: True,
#  Null:False,
#
# - identificar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - vulnerabilidades:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 16,
#  Binário: True,
#  Null:False,
#
# - aplicativo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# História de Usuário 40:
# - código:  - QTDE: (2)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - quero:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - integração:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - ferramentas:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - análise:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - estático:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - identificar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - áreas:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - risco:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - avaliação:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - abrangente:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - qualidade:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# História de Usuário 41:
# - integração:  - QTDE: (2)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - sistema:  - QTDE: (2)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - usuário:  - QTDE: (2)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - desejo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - suporte:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - execução:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - teste:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - aceitação:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - validar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - diferentes:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - partes:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - conformidade:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 12,
#  Binário: True,
#  Null:False,
#
# - requisitos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# História de Usuário 42:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - preciso:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - suporte:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - execução:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - confiabilidade:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 14,
#  Binário: True,
#  Null:False,
#
# - disponibilidade:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 15,
#  Binário: True,
#  Null:False,
#
# - garantir:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - aplicativo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - sempre:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - disponível:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - funcione:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - corretamente:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 12,
#  Binário: True,
#  Null:False,
#
# História de Usuário 43:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - quero:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - ferramenta:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - sugira:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - casos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - teste:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - base:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 4,
#  Binário: True,
#  Null:False,
#
# - modelos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - qualidade:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - software:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - reconhecidos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 12,
#  Binário: True,
#  Null:False,
#
# - garantir:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - abordagem:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - abrangente:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - padronizada:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# História de Usuário 44:
# - usuário:  - QTDE: (2)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - desejo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - integração:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - ferramentas:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - automação:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - teste:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - interface:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - automatizar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - interação:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# História de Usuário 45:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - preciso:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - suporte:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - execução:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - estresse:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - robustez:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - avaliar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - estabilidade:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 12,
#  Binário: True,
#  Null:False,
#
# - confiabilidade:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 14,
#  Binário: True,
#  Null:False,
#
# - aplicativo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - sob:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 3,
#  Binário: True,
#  Null:False,
#
# - condições:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - adversas:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# História de Usuário 46:
# - teste:  - QTDE: (2)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - quero:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - ferramenta:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - sugira:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - casos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - áreas:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - alto:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 4,
#  Binário: True,
#  Null:False,
#
# - risco:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - complexidade:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 12,
#  Binário: True,
#  Null:False,
#
# - priorizar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - esforços:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# História de Usuário 47:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - desejo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - integração:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - ferramentas:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - gerenciamento:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 13,
#  Binário: True,
#  Null:False,
#
# - defeitos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - rastreamento:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 12,
#  Binário: True,
#  Null:False,
#
# - correções:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - gestão:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - eficaz:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - problemas:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - encontrados:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - durante:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# História de Usuário 48:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - preciso:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - suporte:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - execução:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - usabilidade:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - remota:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - teste:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - usuário:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - beta:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 4,
#  Binário: True,
#  Null:False,
#
# - coletar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - feedback:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - usuários:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - reais:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# História de Usuário 49:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - quero:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - ferramenta:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - forneça:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - feedback:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - tempo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - real:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 4,
#  Binário: True,
#  Null:False,
#
# - durante:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - execução:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - facilitar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - identificação:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 13,
#  Binário: True,
#  Null:False,
#
# - imediata:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - problemas:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# História de Usuário 50:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - desejo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - integração:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - ferramentas:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - automação:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - infraestrutura:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 14,
#  Binário: True,
#  Null:False,
#
# - provisionamento:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 15,
#  Binário: True,
#  Null:False,
#
# - configuração:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 12,
#  Binário: True,
#  Null:False,
#
# - automatizados:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 13,
#  Binário: True,
#  Null:False,
#
# - facilitar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - preparação:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - ambiente:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - teste:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# História de Usuário 51:
# - desempenho:  - QTDE: (2)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - preciso:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - suporte:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - execução:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - comparação:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - versões:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - anteriores:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - atuais:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - aplicativo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - avaliar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - impacto:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - mudanças:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,

# %%
nome, valor = zip(*freq_dists[0].most_common(5))
fig, ax = plt.subplots(figsize=(6,5))
sns.barplot(x=np.array(nome), y=np.array(valor), ax=ax)
plt.show()

# %%
nome,valor = zip(*freq_dists[i].most_common(5))
fig, ax = plt.subplots(figsize=(6,5))
sns.barplot(x=np.array(nome), y=np.array(valor), ax=ax)
# Out:
# <Axes: >

# %%
for i, freq_dist in enumerate(freq_dists):
    historia_usuario = " ".join(freq_dist.keys())
    resultado = classificador(historia_usuario, candidate_labels=rotulos)
    top_label = resultado['labels'][0]
    confianca = resultado['scores'][0]
    print(f"História de Usuário {i+1}: Rótulo Previsto: {top_label}, Confiança: {confianca:.2f}")
# Out:
# História de Usuário 1: Rótulo Previsto: testador, Confiança: 0.56
# História de Usuário 2: Rótulo Previsto: testador, Confiança: 0.69
# História de Usuário 3: Rótulo Previsto: testador, Confiança: 0.60
# História de Usuário 4: Rótulo Previsto: testador, Confiança: 0.70
# História de Usuário 5: Rótulo Previsto: testador, Confiança: 0.63
# História de Usuário 6: Rótulo Previsto: testador, Confiança: 0.73
# História de Usuário 7: Rótulo Previsto: testador, Confiança: 0.68
# História de Usuário 8: Rótulo Previsto: testador, Confiança: 0.53
# História de Usuário 9: Rótulo Previsto: testador, Confiança: 0.44
# História de Usuário 10: Rótulo Previsto: testador, Confiança: 0.79
# História de Usuário 11: Rótulo Previsto: testador, Confiança: 0.56
# História de Usuário 12: Rótulo Previsto: testador, Confiança: 0.64
# História de Usuário 13: Rótulo Previsto: testador, Confiança: 0.78
# História de Usuário 14: Rótulo Previsto: testador, Confiança: 0.72
# História de Usuário 15: Rótulo Previsto: testador, Confiança: 0.58
# História de Usuário 16: Rótulo Previsto: testador, Confiança: 0.64
# História de Usuário 17: Rótulo Previsto: testador, Confiança: 0.70
# História de Usuário 18: Rótulo Previsto: testador, Confiança: 0.66
# História de Usuário 19: Rótulo Previsto: testador, Confiança: 0.43
# História de Usuário 20: Rótulo Previsto: testador, Confiança: 0.78
# História de Usuário 21: Rótulo Previsto: testador, Confiança: 0.68
# História de Usuário 22: Rótulo Previsto: testador, Confiança: 0.55
# História de Usuário 23: Rótulo Previsto: testador, Confiança: 0.47
# História de Usuário 24: Rótulo Previsto: testador, Confiança: 0.63
# História de Usuário 25: Rótulo Previsto: testador, Confiança: 0.49
# História de Usuário 26: Rótulo Previsto: testador, Confiança: 0.52
# História de Usuário 27: Rótulo Previsto: testador, Confiança: 0.66
# História de Usuário 28: Rótulo Previsto: testador, Confiança: 0.53
# História de Usuário 29: Rótulo Previsto: testador, Confiança: 0.55
# História de Usuário 30: Rótulo Previsto: testador, Confiança: 0.66
# História de Usuário 31: Rótulo Previsto: testador, Confiança: 0.48
# História de Usuário 32: Rótulo Previsto: testador, Confiança: 0.63
# História de Usuário 33: Rótulo Previsto: testador, Confiança: 0.60
# História de Usuário 34: Rótulo Previsto: testador, Confiança: 0.56
# História de Usuário 35: Rótulo Previsto: testador, Confiança: 0.60
# História de Usuário 36: Rótulo Previsto: testador, Confiança: 0.74
# História de Usuário 37: Rótulo Previsto: testador, Confiança: 0.49
# História de Usuário 38: Rótulo Previsto: testador, Confiança: 0.63
# História de Usuário 39: Rótulo Previsto: testador, Confiança: 0.63
# História de Usuário 40: Rótulo Previsto: testador, Confiança: 0.69
# História de Usuário 41: Rótulo Previsto: testador, Confiança: 0.58
# História de Usuário 42: Rótulo Previsto: testador, Confiança: 0.66
# História de Usuário 43: Rótulo Previsto: testador, Confiança: 0.65
# História de Usuário 44: Rótulo Previsto: testador, Confiança: 0.71
# História de Usuário 45: Rótulo Previsto: testador, Confiança: 0.66
# História de Usuário 46: Rótulo Previsto: testador, Confiança: 0.61
# História de Usuário 47: Rótulo Previsto: testador, Confiança: 0.77
# História de Usuário 48: Rótulo Previsto: testador, Confiança: 0.56
# História de Usuário 49: Rótulo Previsto: testador, Confiança: 0.72
# História de Usuário 50: Rótulo Previsto: testador, Confiança: 0.63
# História de Usuário 51: Rótulo Previsto: testador, Confiança: 0.33

# %%
for i, freq_dist in enumerate(freq_dists):
    historia_usuario = " ".join(freq_dist.keys())
    resultado = roberta(f"História de Usuário {i+1}: {historia_usuario}")
    print(f"Resultado para História de Usuário {i+1}:")
    for item in resultado:
        print(item)
    print()
# Out:
# Resultado para História de Usuário 1:
# {'entity_group': 'LABEL_1', 'score': 0.6588907, 'word': ' historia de usuario 1', 'start': 0, 'end': 21}
# {'entity_group': 'LABEL_0', 'score': 0.5806519, 'word': ' :', 'start': 22, 'end': 22}
# {'entity_group': 'LABEL_1', 'score': 0.60015804, 'word': ' testador quero jeito facil incluir requisitos aplica', 'start': 24, 'end': 75}
# {'entity_group': 'LABEL_0', 'score': 0.5251617, 'word': 'tivo', 'start': 75, 'end': 79}
# {'entity_group': 'LABEL_1', 'score': 0.56739473, 'word': ' ferramenta dr', 'start': 81, 'end': 93}
# {'entity_group': 'LABEL_0', 'score': 0.5901193, 'word': 'l - mobtest', 'start': 93, 'end': 102}
# {'entity_group': 'LABEL_1', 'score': 0.5067717, 'word': ' criar', 'start': 104, 'end': 108}
# {'entity_group': 'LABEL_0', 'score': 0.5175034, 'word': ' casos', 'start': 110, 'end': 114}
# {'entity_group': 'LABEL_1', 'score': 0.5419715, 'word': ' teste', 'start': 116, 'end': 120}
# {'entity_group': 'LABEL_0', 'score': 0.5393573, 'word': ' cubram', 'start': 122, 'end': 127}
# {'entity_group': 'LABEL_1', 'score': 0.62037206, 'word': ' tudo precisa fazer ter gastar tempo escreve', 'start': 129, 'end': 171}
# {'entity_group': 'LABEL_0', 'score': 0.52065134, 'word': 'ndo', 'start': 171, 'end': 174}
# {'entity_group': 'LABEL_1', 'score': 0.63044035, 'word': ' manualmente', 'start': 176, 'end': 186}
#
# Resultado para História de Usuário 2:
# {'entity_group': 'LABEL_1', 'score': 0.649286, 'word': ' historia de usuario 2', 'start': 0, 'end': 21}
# {'entity_group': 'LABEL_0', 'score': 0.57495785, 'word': ' :', 'start': 22, 'end': 22}
# {'entity_group': 'LABEL_1', 'score': 0.6526778, 'word': ' testador quero maneira ensinar ferramenta dr', 'start': 24, 'end': 67}
# {'entity_group': 'LABEL_0', 'score': 0.5837527, 'word': 'l - mobtest', 'start': 67, 'end': 76}
# {'entity_group': 'LABEL_1', 'score': 0.63376856, 'word': ' entender requisitos aplicativo', 'start': 78, 'end': 107}
# {'entity_group': 'LABEL_0', 'score': 0.5093634, 'word': ' usando', 'start': 109, 'end': 114}
# {'entity_group': 'LABEL_1', 'score': 0.56932294, 'word': ' nlp', 'start': 116, 'end': 118}
# {'entity_group': 'LABEL_0', 'score': 0.52605534, 'word': ' fazer', 'start': 120, 'end': 124}
# {'entity_group': 'LABEL_1', 'score': 0.63911945, 'word': ' gere tes', 'start': 126, 'end': 133}
# {'entity_group': 'LABEL_0', 'score': 0.53230727, 'word': 'tis', 'start': 133, 'end': 136}
# {'entity_group': 'LABEL_1', 'score': 0.65059185, 'word': ' automaticamente', 'start': 138, 'end': 152}
#
# Resultado para História de Usuário 3:
# {'entity_group': 'LABEL_1', 'score': 0.659372, 'word': ' historia de usuario 3', 'start': 0, 'end': 21}
# {'entity_group': 'LABEL_0', 'score': 0.5460801, 'word': ' : tes', 'start': 22, 'end': 26}
# {'entity_group': 'LABEL_1', 'score': 0.5699835, 'word': 'tador quero ferramenta gere casos teste', 'start': 26, 'end': 65}
# {'entity_group': 'LABEL_0', 'score': 0.51498693, 'word': ' abrangentes', 'start': 67, 'end': 77}
# {'entity_group': 'LABEL_1', 'score': 0.6066882, 'word': ' cubram integralmente todos requisitos aplicativo assegurando software completo funcional depender exclusivamente criacao manual', 'start': 79, 'end': 205}
#
# Resultado para História de Usuário 4:
# {'entity_group': 'LABEL_1', 'score': 0.6235727, 'word': ' historia de usuario 4', 'start': 0, 'end': 21}
# {'entity_group': 'LABEL_0', 'score': 0.5948716, 'word': ' :', 'start': 22, 'end': 22}
# {'entity_group': 'LABEL_1', 'score': 0.6104648, 'word': ' testador quero ferramenta integrada outras ferramentas gerencia', 'start': 24, 'end': 86}
# {'entity_group': 'LABEL_0', 'score': 0.55263096, 'word': 'mento', 'start': 86, 'end': 91}
# {'entity_group': 'LABEL_1', 'score': 0.61386824, 'word': ' permitindo', 'start': 93, 'end': 102}
# {'entity_group': 'LABEL_0', 'score': 0.57107663, 'word': ' sincronizacao', 'start': 104, 'end': 116}
# {'entity_group': 'LABEL_1', 'score': 0.6182127, 'word': ' automatica requisitos facilitando processo criacao', 'start': 118, 'end': 167}
# {'entity_group': 'LABEL_0', 'score': 0.5493704, 'word': ' casos', 'start': 169, 'end': 173}
# {'entity_group': 'LABEL_1', 'score': 0.542671, 'word': ' tes', 'start': 175, 'end': 177}
# {'entity_group': 'LABEL_0', 'score': 0.61961526, 'word': 'tis', 'start': 177, 'end': 180}
#
# Resultado para História de Usuário 5:
# {'entity_group': 'LABEL_1', 'score': 0.6431911, 'word': ' historia de usuario 5', 'start': 0, 'end': 21}
# {'entity_group': 'LABEL_0', 'score': 0.54596937, 'word': ' : tes', 'start': 22, 'end': 26}
# {'entity_group': 'LABEL_1', 'score': 0.5698367, 'word': 'tador quero ferramenta gere casos teste completos funcionais', 'start': 26, 'end': 86}
# {'entity_group': 'LABEL_0', 'score': 0.52256864, 'word': ' cub', 'start': 88, 'end': 90}
# {'entity_group': 'LABEL_1', 'score': 0.54513526, 'word': 'ram todos requisitos aplica', 'start': 90, 'end': 117}
# {'entity_group': 'LABEL_0', 'score': 0.5090284, 'word': 'tivo', 'start': 117, 'end': 121}
# {'entity_group': 'LABEL_1', 'score': 0.53398067, 'word': ' garantir', 'start': 123, 'end': 130}
# {'entity_group': 'LABEL_0', 'score': 0.5000248, 'word': ' cobertura', 'start': 132, 'end': 140}
# {'entity_group': 'LABEL_1', 'score': 0.50572693, 'word': ' abrangente', 'start': 142, 'end': 151}
# {'entity_group': 'LABEL_0', 'score': 0.5616732, 'word': ' durante testis', 'start': 153, 'end': 166}
#
# Resultado para História de Usuário 6:
# {'entity_group': 'LABEL_1', 'score': 0.6394782, 'word': ' historia de usuario 6', 'start': 0, 'end': 21}
# {'entity_group': 'LABEL_0', 'score': 0.554065, 'word': ' :', 'start': 22, 'end': 22}
# {'entity_group': 'LABEL_1', 'score': 0.65164816, 'word': ' testador quero integracao outras ferramentas gerencia', 'start': 24, 'end': 76}
# {'entity_group': 'LABEL_0', 'score': 0.5236926, 'word': 'mento sincronizar', 'start': 76, 'end': 93}
# {'entity_group': 'LABEL_1', 'score': 0.6051412, 'word': ' automaticamente requisitos facilitar criacao', 'start': 95, 'end': 138}
# {'entity_group': 'LABEL_0', 'score': 0.50663435, 'word': ' casos', 'start': 140, 'end': 144}
# {'entity_group': 'LABEL_1', 'score': 0.61362284, 'word': ' teste visando melhorar eficiencia precisao processo', 'start': 146, 'end': 196}
#
# Resultado para História de Usuário 7:
# {'entity_group': 'LABEL_1', 'score': 0.60957557, 'word': ' historia de usuario 7', 'start': 0, 'end': 21}
# {'entity_group': 'LABEL_0', 'score': 0.5510736, 'word': ' : testador', 'start': 22, 'end': 31}
# {'entity_group': 'LABEL_1', 'score': 0.61299133, 'word': ' quero', 'start': 33, 'end': 37}
# {'entity_group': 'LABEL_0', 'score': 0.6202844, 'word': ' relatorios', 'start': 39, 'end': 48}
# {'entity_group': 'LABEL_1', 'score': 0.5034252, 'word': ' detalhados', 'start': 50, 'end': 59}
# {'entity_group': 'LABEL_0', 'score': 0.508993, 'word': ' sobre', 'start': 61, 'end': 65}
# {'entity_group': 'LABEL_1', 'score': 0.5154982, 'word': ' cobertura', 'start': 67, 'end': 75}
# {'entity_group': 'LABEL_0', 'score': 0.65485424, 'word': ' testis analise precisa durante', 'start': 77, 'end': 106}
# {'entity_group': 'LABEL_1', 'score': 0.50643, 'word': ' execucao', 'start': 108, 'end': 115}
# {'entity_group': 'LABEL_0', 'score': 0.5855644, 'word': ' fim avaliar qualidade extensao realizados', 'start': 117, 'end': 157}
#
# Resultado para História de Usuário 8:
# {'entity_group': 'LABEL_1', 'score': 0.59072685, 'word': ' historia de usuario 8', 'start': 0, 'end': 21}
# {'entity_group': 'LABEL_0', 'score': 0.5461103, 'word': ' : tes', 'start': 22, 'end': 26}
# {'entity_group': 'LABEL_1', 'score': 0.54787445, 'word': 'tador desejo ferramenta identifique automaticamente', 'start': 26, 'end': 77}
# {'entity_group': 'LABEL_0', 'score': 0.5638295, 'word': ' casos teste criticos', 'start': 79, 'end': 98}
# {'entity_group': 'LABEL_1', 'score': 0.5115305, 'word': ' priori', 'start': 100, 'end': 105}
# {'entity_group': 'LABEL_0', 'score': 0.5740862, 'word': 'zar', 'start': 105, 'end': 108}
# {'entity_group': 'LABEL_1', 'score': 0.5864705, 'word': ' analise visando direcionar esforcos areas', 'start': 110, 'end': 150}
# {'entity_group': 'LABEL_0', 'score': 0.5552796, 'word': ' maior', 'start': 152, 'end': 156}
# {'entity_group': 'LABEL_1', 'score': 0.6494364, 'word': ' risco', 'start': 158, 'end': 162}
#
# Resultado para História de Usuário 9:
# {'entity_group': 'LABEL_1', 'score': 0.66033393, 'word': ' historia de usuario 9', 'start': 0, 'end': 21}
# {'entity_group': 'LABEL_0', 'score': 0.52482265, 'word': ' :', 'start': 22, 'end': 22}
# {'entity_group': 'LABEL_1', 'score': 0.57123995, 'word': ' testador preciso ferramenta', 'start': 24, 'end': 50}
# {'entity_group': 'LABEL_0', 'score': 0.58551997, 'word': ' su', 'start': 52, 'end': 53}
# {'entity_group': 'LABEL_1', 'score': 0.62732846, 'word': 'gira casos teste', 'start': 53, 'end': 69}
# {'entity_group': 'LABEL_0', 'score': 0.50604326, 'word': ' base', 'start': 71, 'end': 74}
# {'entity_group': 'LABEL_1', 'score': 0.5390566, 'word': ' padroes uso real aplicativo garantir tes', 'start': 76, 'end': 115}
# {'entity_group': 'LABEL_0', 'score': 0.5449026, 'word': 'tis refli', 'start': 115, 'end': 124}
# {'entity_group': 'LABEL_1', 'score': 0.61497855, 'word': 'tam cenarios', 'start': 124, 'end': 136}
# {'entity_group': 'LABEL_0', 'score': 0.6260134, 'word': ' ti', 'start': 138, 'end': 139}
# {'entity_group': 'LABEL_1', 'score': 0.5259788, 'word': 'picos', 'start': 139, 'end': 144}
#
# Resultado para História de Usuário 10:
# {'entity_group': 'LABEL_1', 'score': 0.6861671, 'word': ' historia de usuario 10', 'start': 0, 'end': 22}
# {'entity_group': 'LABEL_0', 'score': 0.5259974, 'word': ' :', 'start': 23, 'end': 23}
# {'entity_group': 'LABEL_1', 'score': 0.6265873, 'word': ' testador quero sugestoes base padroes falha historicos evitar problemas recorrentes software visando melhorar qualidade robustez produto', 'start': 25, 'end': 160}
#
# Resultado para História de Usuário 11:
# {'entity_group': 'LABEL_1', 'score': 0.6439066, 'word': ' historia de usuario 11 :', 'start': 0, 'end': 23}
# {'entity_group': 'LABEL_0', 'score': 0.5020441, 'word': ' tes', 'start': 25, 'end': 27}
# {'entity_group': 'LABEL_1', 'score': 0.6031442, 'word': 'tador desejo suporte execucao tes', 'start': 27, 'end': 60}
# {'entity_group': 'LABEL_0', 'score': 0.5199673, 'word': 'tis', 'start': 60, 'end': 63}
# {'entity_group': 'LABEL_1', 'score': 0.6249982, 'word': ' automatizados diferentes dispositivos ambientes garantir consistencia confiabilidade cenarios', 'start': 65, 'end': 157}
#
# Resultado para História de Usuário 12:
# {'entity_group': 'LABEL_1', 'score': 0.63734907, 'word': ' historia de usuario 12', 'start': 0, 'end': 22}
# {'entity_group': 'LABEL_0', 'score': 0.54036564, 'word': ' :', 'start': 23, 'end': 23}
# {'entity_group': 'LABEL_1', 'score': 0.5592755, 'word': ' testador', 'start': 25, 'end': 32}
# {'entity_group': 'LABEL_0', 'score': 0.55522615, 'word': ' preciso', 'start': 34, 'end': 40}
# {'entity_group': 'LABEL_1', 'score': 0.59325534, 'word': ' ferramenta detecte automaticamente mudancas requisitos', 'start': 42, 'end': 95}
# {'entity_group': 'LABEL_0', 'score': 0.5516633, 'word': ' ajuste casos', 'start': 97, 'end': 108}
# {'entity_group': 'LABEL_1', 'score': 0.5427729, 'word': ' teste', 'start': 110, 'end': 114}
# {'entity_group': 'LABEL_0', 'score': 0.5813444, 'word': ' correspondentes', 'start': 116, 'end': 130}
# {'entity_group': 'LABEL_1', 'score': 0.58800805, 'word': ' manter tes', 'start': 132, 'end': 141}
# {'entity_group': 'LABEL_0', 'score': 0.59820575, 'word': 'tis', 'start': 141, 'end': 144}
# {'entity_group': 'LABEL_1', 'score': 0.5494727, 'word': ' alinhados evolucao aplicativo', 'start': 146, 'end': 174}
#
# Resultado para História de Usuário 13:
# {'entity_group': 'LABEL_1', 'score': 0.6450704, 'word': ' historia de usuario 13', 'start': 0, 'end': 22}
# {'entity_group': 'LABEL_0', 'score': 0.5976087, 'word': ' :', 'start': 23, 'end': 23}
# {'entity_group': 'LABEL_1', 'score': 0.63437724, 'word': ' testador quero integracao sistemas controle versao rastrear mudancas requisitos codigo', 'start': 25, 'end': 110}
# {'entity_group': 'LABEL_0', 'score': 0.52827567, 'word': ' -', 'start': 111, 'end': 111}
# {'entity_group': 'LABEL_1', 'score': 0.74597144, 'word': ' fonte visando gestao eficaz', 'start': 112, 'end': 138}
# {'entity_group': 'LABEL_0', 'score': 0.5242317, 'word': ' durante', 'start': 140, 'end': 146}
# {'entity_group': 'LABEL_1', 'score': 0.74600005, 'word': ' ciclo desenvolvimento', 'start': 148, 'end': 168}
#
# Resultado para História de Usuário 14:
# {'entity_group': 'LABEL_1', 'score': 0.6203102, 'word': ' historia de usuario 14', 'start': 0, 'end': 22}
# {'entity_group': 'LABEL_0', 'score': 0.5644053, 'word': ' :', 'start': 23, 'end': 23}
# {'entity_group': 'LABEL_1', 'score': 0.53191054, 'word': ' testador', 'start': 25, 'end': 32}
# {'entity_group': 'LABEL_0', 'score': 0.55660886, 'word': ' desejo metricas', 'start': 34, 'end': 48}
# {'entity_group': 'LABEL_1', 'score': 0.57336986, 'word': ' detalhadas sobre eficacia', 'start': 50, 'end': 74}
# {'entity_group': 'LABEL_0', 'score': 0.5522636, 'word': ' testis incluindo taxon cobertura', 'start': 76, 'end': 107}
# {'entity_group': 'LABEL_1', 'score': 0.57289946, 'word': ' falha avaliar qualidade processo teste', 'start': 109, 'end': 146}
#
# Resultado para História de Usuário 15:
# {'entity_group': 'LABEL_1', 'score': 0.6257387, 'word': ' historia de usuario', 'start': 0, 'end': 19}
# {'entity_group': 'LABEL_0', 'score': 0.52835417, 'word': ' 15 :', 'start': 21, 'end': 23}
# {'entity_group': 'LABEL_1', 'score': 0.536317, 'word': ' testador', 'start': 25, 'end': 32}
# {'entity_group': 'LABEL_0', 'score': 0.5281771, 'word': ' preciso', 'start': 34, 'end': 40}
# {'entity_group': 'LABEL_1', 'score': 0.6297373, 'word': ' suporte execucao tes', 'start': 42, 'end': 61}
# {'entity_group': 'LABEL_0', 'score': 0.6364714, 'word': 'tis', 'start': 61, 'end': 64}
# {'entity_group': 'LABEL_1', 'score': 0.5687892, 'word': ' desempenho', 'start': 66, 'end': 75}
# {'entity_group': 'LABEL_0', 'score': 0.53210545, 'word': ' escala', 'start': 77, 'end': 82}
# {'entity_group': 'LABEL_1', 'score': 0.63248056, 'word': 'bilidade garantir aplicativo atenda requisitos sob carga', 'start': 82, 'end': 138}
#
# Resultado para História de Usuário 16:
# {'entity_group': 'LABEL_1', 'score': 0.59919995, 'word': ' historia de usuario 16', 'start': 0, 'end': 22}
# {'entity_group': 'LABEL_0', 'score': 0.58387595, 'word': ' :', 'start': 23, 'end': 23}
# {'entity_group': 'LABEL_1', 'score': 0.59874153, 'word': ' testador quero analise automatica', 'start': 25, 'end': 57}
# {'entity_group': 'LABEL_0', 'score': 0.58543336, 'word': ' resultados testis relatorios detalhados', 'start': 59, 'end': 97}
# {'entity_group': 'LABEL_1', 'score': 0.5256142, 'word': ' sobre', 'start': 99, 'end': 103}
# {'entity_group': 'LABEL_0', 'score': 0.5732582, 'word': ' problemas encontrados fim', 'start': 105, 'end': 129}
# {'entity_group': 'LABEL_1', 'score': 0.53858423, 'word': ' facilitar identificacao correcao', 'start': 131, 'end': 162}
# {'entity_group': 'LABEL_0', 'score': 0.5903634, 'word': ' defeitos', 'start': 164, 'end': 171}
#
# Resultado para História de Usuário 17:
# {'entity_group': 'LABEL_1', 'score': 0.6656884, 'word': ' historia de usuario 17 : testador desejo simular cenarios teste complexos realistas garantir', 'start': 0, 'end': 91}
# {'entity_group': 'LABEL_0', 'score': 0.550979, 'word': ' testis', 'start': 93, 'end': 98}
# {'entity_group': 'LABEL_1', 'score': 0.66160023, 'word': ' proximos realidade visando validacao precisa software', 'start': 100, 'end': 152}
#
# Resultado para História de Usuário 18:
# {'entity_group': 'LABEL_1', 'score': 0.61206615, 'word': ' historia de usuario 18', 'start': 0, 'end': 22}
# {'entity_group': 'LABEL_0', 'score': 0.55612063, 'word': ' :', 'start': 23, 'end': 23}
# {'entity_group': 'LABEL_1', 'score': 0.5404402, 'word': ' testador', 'start': 25, 'end': 32}
# {'entity_group': 'LABEL_0', 'score': 0.5707793, 'word': ' preciso', 'start': 34, 'end': 40}
# {'entity_group': 'LABEL_1', 'score': 0.5712134, 'word': ' suporte execucao tes', 'start': 42, 'end': 61}
# {'entity_group': 'LABEL_0', 'score': 0.61329126, 'word': 'tis regressao', 'start': 61, 'end': 74}
# {'entity_group': 'LABEL_1', 'score': 0.5505747, 'word': ' automatizados', 'start': 76, 'end': 88}
# {'entity_group': 'LABEL_0', 'score': 0.5379937, 'word': ' garantir alteracoes', 'start': 90, 'end': 108}
# {'entity_group': 'LABEL_1', 'score': 0.51705664, 'word': ' codigo', 'start': 110, 'end': 115}
# {'entity_group': 'LABEL_0', 'score': 0.56247616, 'word': ' introduzam', 'start': 117, 'end': 126}
# {'entity_group': 'LABEL_1', 'score': 0.53050053, 'word': ' regres', 'start': 128, 'end': 133}
# {'entity_group': 'LABEL_0', 'score': 0.5464495, 'word': 'soes', 'start': 133, 'end': 137}
#
# Resultado para História de Usuário 19:
# {'entity_group': 'LABEL_1', 'score': 0.69350654, 'word': ' historia de usuario 19', 'start': 0, 'end': 22}
# {'entity_group': 'LABEL_0', 'score': 0.56069297, 'word': ' :', 'start': 23, 'end': 23}
# {'entity_group': 'LABEL_1', 'score': 0.62654334, 'word': ' testador quero identificacao automatica casos teste redundantes desnecessarios otimizar esforcos', 'start': 25, 'end': 120}
#
# Resultado para História de Usuário 20:
# {'entity_group': 'LABEL_1', 'score': 0.62809896, 'word': ' historia de usuario 20 : testador desejo integracao facil ferramentas gerenciamento projetos colaboracao eficiente outros membros equipe desenvolvimento', 'start': 0, 'end': 151}
#
# Resultado para História de Usuário 21:
# {'entity_group': 'LABEL_1', 'score': 0.6578866, 'word': ' historia de usuario 21', 'start': 0, 'end': 22}
# {'entity_group': 'LABEL_0', 'score': 0.5146963, 'word': ' :', 'start': 23, 'end': 23}
# {'entity_group': 'LABEL_1', 'score': 0.58855975, 'word': ' testador', 'start': 25, 'end': 32}
# {'entity_group': 'LABEL_0', 'score': 0.51904464, 'word': ' preciso', 'start': 34, 'end': 40}
# {'entity_group': 'LABEL_1', 'score': 0.6497479, 'word': ' suporte execucao tes', 'start': 42, 'end': 61}
# {'entity_group': 'LABEL_0', 'score': 0.5577509, 'word': 'tis', 'start': 61, 'end': 64}
# {'entity_group': 'LABEL_1', 'score': 0.63345987, 'word': ' usabilidade garantir aplicativo facil intu', 'start': 66, 'end': 107}
# {'entity_group': 'LABEL_0', 'score': 0.5016395, 'word': 'i', 'start': 107, 'end': 108}
# {'entity_group': 'LABEL_1', 'score': 0.5868412, 'word': 'tivo usar', 'start': 108, 'end': 117}
#
# Resultado para História de Usuário 22:
# {'entity_group': 'LABEL_1', 'score': 0.67792267, 'word': ' historia de usuario 22', 'start': 0, 'end': 22}
# {'entity_group': 'LABEL_0', 'score': 0.58993345, 'word': ' :', 'start': 23, 'end': 23}
# {'entity_group': 'LABEL_1', 'score': 0.66060615, 'word': ' testador quero ferramenta crie automaticamente conjuntos dado teste realistas simular condicoes reais uso', 'start': 25, 'end': 129}
#
# Resultado para História de Usuário 23:
# {'entity_group': 'LABEL_1', 'score': 0.6040993, 'word': ' historia de usuario 23', 'start': 0, 'end': 22}
# {'entity_group': 'LABEL_0', 'score': 0.5244184, 'word': ' :', 'start': 23, 'end': 23}
# {'entity_group': 'LABEL_1', 'score': 0.57360154, 'word': ' testador desejo integracao ferramentas', 'start': 25, 'end': 62}
# {'entity_group': 'LABEL_0', 'score': 0.5298065, 'word': ' monitoramento', 'start': 64, 'end': 76}
# {'entity_group': 'LABEL_1', 'score': 0.5248485, 'word': ' desempenho tempo real avaliar aplicativo', 'start': 78, 'end': 117}
# {'entity_group': 'LABEL_0', 'score': 0.57882583, 'word': ' durante', 'start': 119, 'end': 125}
# {'entity_group': 'LABEL_1', 'score': 0.53575176, 'word': ' tes', 'start': 127, 'end': 129}
# {'entity_group': 'LABEL_0', 'score': 0.63694, 'word': 'tis', 'start': 129, 'end': 132}
#
# Resultado para História de Usuário 24:
# {'entity_group': 'LABEL_1', 'score': 0.64578176, 'word': ' historia de usuario', 'start': 0, 'end': 19}
# {'entity_group': 'LABEL_0', 'score': 0.52499926, 'word': ' 24 :', 'start': 21, 'end': 23}
# {'entity_group': 'LABEL_1', 'score': 0.59268755, 'word': ' testador preciso suporte execucao tes', 'start': 25, 'end': 61}
# {'entity_group': 'LABEL_0', 'score': 0.628354, 'word': 'tis', 'start': 61, 'end': 64}
# {'entity_group': 'LABEL_1', 'score': 0.6237576, 'word': ' localizacao internacionalizacao garantir aplicativo compativel diferentes idiomas regioes', 'start': 66, 'end': 154}
#
# Resultado para História de Usuário 25:
# {'entity_group': 'LABEL_1', 'score': 0.6572038, 'word': ' historia de usuario 25', 'start': 0, 'end': 22}
# {'entity_group': 'LABEL_0', 'score': 0.5351511, 'word': ' : tes', 'start': 23, 'end': 27}
# {'entity_group': 'LABEL_1', 'score': 0.5906575, 'word': 'tador quero geracao automatica dado teste sinteticos complementar', 'start': 27, 'end': 92}
# {'entity_group': 'LABEL_0', 'score': 0.5014517, 'word': ' casos', 'start': 94, 'end': 98}
# {'entity_group': 'LABEL_1', 'score': 0.5436993, 'word': ' manuais', 'start': 100, 'end': 106}
#
# Resultado para História de Usuário 26:
# {'entity_group': 'LABEL_1', 'score': 0.6023903, 'word': ' historia de usuario', 'start': 0, 'end': 19}
# {'entity_group': 'LABEL_0', 'score': 0.540816, 'word': ' 26 : tes', 'start': 21, 'end': 27}
# {'entity_group': 'LABEL_1', 'score': 0.5639039, 'word': 'tador desejo suporte execucao tes', 'start': 27, 'end': 60}
# {'entity_group': 'LABEL_0', 'score': 0.6267894, 'word': 'tis', 'start': 60, 'end': 63}
# {'entity_group': 'LABEL_1', 'score': 0.5506984, 'word': ' acessibilidade garantir', 'start': 65, 'end': 87}
# {'entity_group': 'LABEL_0', 'score': 0.534279, 'word': ' aplicativo', 'start': 89, 'end': 98}
# {'entity_group': 'LABEL_1', 'score': 0.62694705, 'word': ' acessivel', 'start': 100, 'end': 108}
# {'entity_group': 'LABEL_0', 'score': 0.51134545, 'word': ' todos usuarios', 'start': 110, 'end': 123}
#
# Resultado para História de Usuário 27:
# {'entity_group': 'LABEL_1', 'score': 0.6414493, 'word': ' historia', 'start': 0, 'end': 8}
# {'entity_group': 'LABEL_0', 'score': 0.50696015, 'word': ' de', 'start': 10, 'end': 11}
# {'entity_group': 'LABEL_1', 'score': 0.5397192, 'word': ' usuario 27', 'start': 13, 'end': 22}
# {'entity_group': 'LABEL_0', 'score': 0.53315973, 'word': ' : tes', 'start': 23, 'end': 27}
# {'entity_group': 'LABEL_1', 'score': 0.55846035, 'word': 'tador', 'start': 27, 'end': 32}
# {'entity_group': 'LABEL_0', 'score': 0.5499738, 'word': ' preciso', 'start': 34, 'end': 40}
# {'entity_group': 'LABEL_1', 'score': 0.58083624, 'word': ' suporte execucao tes', 'start': 42, 'end': 61}
# {'entity_group': 'LABEL_0', 'score': 0.5759454, 'word': 'tis integracao continua', 'start': 61, 'end': 84}
# {'entity_group': 'LABEL_1', 'score': 0.5071359, 'word': ' garantir', 'start': 86, 'end': 93}
# {'entity_group': 'LABEL_0', 'score': 0.5752556, 'word': ' alteracoes', 'start': 95, 'end': 104}
# {'entity_group': 'LABEL_1', 'score': 0.5173586, 'word': ' codigo', 'start': 106, 'end': 111}
# {'entity_group': 'LABEL_0', 'score': 0.52768487, 'word': ' que', 'start': 113, 'end': 115}
# {'entity_group': 'LABEL_1', 'score': 0.6956373, 'word': 'bre', 'start': 115, 'end': 118}
# {'entity_group': 'LABEL_0', 'score': 0.6060783, 'word': 'm outras partes', 'start': 118, 'end': 133}
# {'entity_group': 'LABEL_1', 'score': 0.5301474, 'word': ' sistema', 'start': 135, 'end': 141}
#
# Resultado para História de Usuário 28:
# {'entity_group': 'LABEL_1', 'score': 0.65464455, 'word': ' historia de usuario', 'start': 0, 'end': 19}
# {'entity_group': 'LABEL_0', 'score': 0.5358288, 'word': ' 28 :', 'start': 21, 'end': 23}
# {'entity_group': 'LABEL_1', 'score': 0.57203484, 'word': ' testador quero identificacao automatica', 'start': 25, 'end': 63}
# {'entity_group': 'LABEL_0', 'score': 0.5756042, 'word': ' casos', 'start': 65, 'end': 69}
# {'entity_group': 'LABEL_1', 'score': 0.5332894, 'word': ' teste incompletos', 'start': 71, 'end': 87}
# {'entity_group': 'LABEL_0', 'score': 0.52079695, 'word': ' mal definidos', 'start': 89, 'end': 101}
# {'entity_group': 'LABEL_1', 'score': 0.54144025, 'word': ' garantir qualidade tes', 'start': 103, 'end': 124}
# {'entity_group': 'LABEL_0', 'score': 0.65879726, 'word': 'tis', 'start': 124, 'end': 127}
#
# Resultado para História de Usuário 29:
# {'entity_group': 'LABEL_1', 'score': 0.6039151, 'word': ' historia de usuario 29', 'start': 0, 'end': 22}
# {'entity_group': 'LABEL_0', 'score': 0.53420365, 'word': ' : tes', 'start': 23, 'end': 27}
# {'entity_group': 'LABEL_1', 'score': 0.5158175, 'word': 'tador', 'start': 27, 'end': 32}
# {'entity_group': 'LABEL_0', 'score': 0.5045525, 'word': ' desejo', 'start': 34, 'end': 39}
# {'entity_group': 'LABEL_1', 'score': 0.5419023, 'word': ' identificacao automatica', 'start': 41, 'end': 64}
# {'entity_group': 'LABEL_0', 'score': 0.5311184, 'word': ' dependencias casos', 'start': 66, 'end': 83}
# {'entity_group': 'LABEL_1', 'score': 0.54232687, 'word': ' teste garantir sequencia logica execucao tes', 'start': 85, 'end': 128}
# {'entity_group': 'LABEL_0', 'score': 0.62387455, 'word': 'tis', 'start': 128, 'end': 131}
#
# Resultado para História de Usuário 30:
# {'entity_group': 'LABEL_1', 'score': 0.59623766, 'word': ' historia de usuario 30', 'start': 0, 'end': 22}
# {'entity_group': 'LABEL_0', 'score': 0.5300665, 'word': ' :', 'start': 23, 'end': 23}
# {'entity_group': 'LABEL_1', 'score': 0.56166685, 'word': ' testador', 'start': 25, 'end': 32}
# {'entity_group': 'LABEL_0', 'score': 0.5102566, 'word': ' preciso', 'start': 34, 'end': 40}
# {'entity_group': 'LABEL_1', 'score': 0.64244133, 'word': ' suporte execucao tes', 'start': 42, 'end': 61}
# {'entity_group': 'LABEL_0', 'score': 0.5893044, 'word': 'tis', 'start': 61, 'end': 64}
# {'entity_group': 'LABEL_1', 'score': 0.5497026, 'word': ' recuperacao', 'start': 66, 'end': 76}
# {'entity_group': 'LABEL_0', 'score': 0.62869763, 'word': ' desastres', 'start': 78, 'end': 86}
# {'entity_group': 'LABEL_1', 'score': 0.59360677, 'word': ' avaliar capacidade sistema recuperar falhas', 'start': 88, 'end': 130}
#
# Resultado para História de Usuário 31:
# {'entity_group': 'LABEL_1', 'score': 0.59412736, 'word': ' historia de usuario 31', 'start': 0, 'end': 22}
# {'entity_group': 'LABEL_0', 'score': 0.54707175, 'word': ' : testador', 'start': 23, 'end': 32}
# {'entity_group': 'LABEL_1', 'score': 0.60364944, 'word': ' quero ferramenta identifique automaticamente', 'start': 34, 'end': 77}
# {'entity_group': 'LABEL_0', 'score': 0.5418335, 'word': ' casos', 'start': 79, 'end': 83}
# {'entity_group': 'LABEL_1', 'score': 0.5348042, 'word': ' teste parale', 'start': 85, 'end': 96}
# {'entity_group': 'LABEL_0', 'score': 0.5639503, 'word': 'lizaveis', 'start': 96, 'end': 104}
# {'entity_group': 'LABEL_1', 'score': 0.5410057, 'word': ' otimizar execucao tes', 'start': 106, 'end': 126}
# {'entity_group': 'LABEL_0', 'score': 0.6326347, 'word': 'tis', 'start': 126, 'end': 129}
#
# Resultado para História de Usuário 32:
# {'entity_group': 'LABEL_1', 'score': 0.72852004, 'word': ' historia de usuario 32', 'start': 0, 'end': 22}
# {'entity_group': 'LABEL_0', 'score': 0.51155794, 'word': ' :', 'start': 23, 'end': 23}
# {'entity_group': 'LABEL_1', 'score': 0.68618196, 'word': ' testador desejo simulacao cenarios teste carga extremamente alta avaliar capacidade', 'start': 25, 'end': 107}
# {'entity_group': 'LABEL_0', 'score': 0.502736, 'word': ' escala', 'start': 109, 'end': 114}
# {'entity_group': 'LABEL_1', 'score': 0.7428341, 'word': 'bilidade sistema', 'start': 114, 'end': 130}
#
# Resultado para História de Usuário 33:
# {'entity_group': 'LABEL_1', 'score': 0.62916386, 'word': ' historia de usuario 33 : testador preciso suporte execucao tes', 'start': 0, 'end': 61}
# {'entity_group': 'LABEL_0', 'score': 0.6005856, 'word': 'tis', 'start': 61, 'end': 64}
# {'entity_group': 'LABEL_1', 'score': 0.6821799, 'word': ' compatibilidade', 'start': 66, 'end': 80}
# {'entity_group': 'LABEL_0', 'score': 0.5002075, 'word': ' diferentes', 'start': 82, 'end': 91}
# {'entity_group': 'LABEL_1', 'score': 0.606035, 'word': ' navegadores dispositivos garantir experiencia consistente todos usuarios', 'start': 93, 'end': 164}
#
# Resultado para História de Usuário 34:
# {'entity_group': 'LABEL_1', 'score': 0.6365956, 'word': ' historia de usuario 34', 'start': 0, 'end': 22}
# {'entity_group': 'LABEL_0', 'score': 0.5243865, 'word': ' : tes', 'start': 23, 'end': 27}
# {'entity_group': 'LABEL_1', 'score': 0.6199678, 'word': 'tador quero geracao automatica', 'start': 27, 'end': 57}
# {'entity_group': 'LABEL_0', 'score': 0.5682402, 'word': ' relatorios', 'start': 59, 'end': 68}
# {'entity_group': 'LABEL_1', 'score': 0.5299565, 'word': ' teste personalizados', 'start': 70, 'end': 89}
# {'entity_group': 'LABEL_0', 'score': 0.53872687, 'word': ' comunicar', 'start': 91, 'end': 99}
# {'entity_group': 'LABEL_1', 'score': 0.5318215, 'word': ' eficazmente', 'start': 101, 'end': 111}
# {'entity_group': 'LABEL_0', 'score': 0.5717353, 'word': ' resultados', 'start': 113, 'end': 122}
# {'entity_group': 'LABEL_1', 'score': 0.5018112, 'word': ' tes', 'start': 124, 'end': 126}
# {'entity_group': 'LABEL_0', 'score': 0.6472394, 'word': 'tis', 'start': 126, 'end': 129}
#
# Resultado para História de Usuário 35:
# {'entity_group': 'LABEL_1', 'score': 0.6322336, 'word': ' historia de usuario 35', 'start': 0, 'end': 22}
# {'entity_group': 'LABEL_0', 'score': 0.5331624, 'word': ' :', 'start': 23, 'end': 23}
# {'entity_group': 'LABEL_1', 'score': 0.5775829, 'word': ' testador desejo rastreamento automatico resultados teste', 'start': 25, 'end': 80}
# {'entity_group': 'LABEL_0', 'score': 0.5140239, 'word': ' longo', 'start': 82, 'end': 86}
# {'entity_group': 'LABEL_1', 'score': 0.56918293, 'word': ' tempo', 'start': 88, 'end': 92}
# {'entity_group': 'LABEL_0', 'score': 0.5766225, 'word': ' identificar', 'start': 94, 'end': 104}
# {'entity_group': 'LABEL_1', 'score': 0.58191633, 'word': ' tendencias padroes qualidade', 'start': 106, 'end': 133}
#
# Resultado para História de Usuário 36:
# {'entity_group': 'LABEL_1', 'score': 0.6189806, 'word': ' historia de usuario 36', 'start': 0, 'end': 22}
# {'entity_group': 'LABEL_0', 'score': 0.56012416, 'word': ' :', 'start': 23, 'end': 23}
# {'entity_group': 'LABEL_1', 'score': 0.54314834, 'word': ' testador', 'start': 25, 'end': 32}
# {'entity_group': 'LABEL_0', 'score': 0.54995644, 'word': ' preciso', 'start': 34, 'end': 40}
# {'entity_group': 'LABEL_1', 'score': 0.5951936, 'word': ' suporte execucao tes', 'start': 42, 'end': 61}
# {'entity_group': 'LABEL_0', 'score': 0.5678354, 'word': 'tis regressao progressiva', 'start': 61, 'end': 86}
# {'entity_group': 'LABEL_1', 'score': 0.52101636, 'word': ' garantir', 'start': 88, 'end': 95}
# {'entity_group': 'LABEL_0', 'score': 0.507531, 'word': ' nova', 'start': 97, 'end': 100}
# {'entity_group': 'LABEL_1', 'score': 0.51749843, 'word': ' alteracoes', 'start': 102, 'end': 111}
# {'entity_group': 'LABEL_0', 'score': 0.5251372, 'word': ' que', 'start': 113, 'end': 115}
# {'entity_group': 'LABEL_1', 'score': 0.6163043, 'word': 'bre', 'start': 115, 'end': 118}
# {'entity_group': 'LABEL_0', 'score': 0.57396996, 'word': 'm', 'start': 118, 'end': 119}
# {'entity_group': 'LABEL_1', 'score': 0.57646847, 'word': ' funcionalidades existentes', 'start': 121, 'end': 146}
#
# Resultado para História de Usuário 37:
# {'entity_group': 'LABEL_1', 'score': 0.6510221, 'word': ' historia de usuario 37', 'start': 0, 'end': 22}
# {'entity_group': 'LABEL_0', 'score': 0.57008624, 'word': ' :', 'start': 23, 'end': 23}
# {'entity_group': 'LABEL_1', 'score': 0.6207098, 'word': ' testador quero sugestoes automaticas apri', 'start': 25, 'end': 65}
# {'entity_group': 'LABEL_0', 'score': 0.53840894, 'word': 'morar casos', 'start': 65, 'end': 76}
# {'entity_group': 'LABEL_1', 'score': 0.5726138, 'word': ' teste existentes aumentar eficiencia eficacia tes', 'start': 78, 'end': 126}
# {'entity_group': 'LABEL_0', 'score': 0.6025279, 'word': 'tis', 'start': 126, 'end': 129}
#
# Resultado para História de Usuário 38:
# {'entity_group': 'LABEL_1', 'score': 0.6505362, 'word': ' historia de usuario 38', 'start': 0, 'end': 22}
# {'entity_group': 'LABEL_0', 'score': 0.50568867, 'word': ' :', 'start': 23, 'end': 23}
# {'entity_group': 'LABEL_1', 'score': 0.61891603, 'word': ' testador desejo ferramenta aprenda resultados tes', 'start': 25, 'end': 73}
# {'entity_group': 'LABEL_0', 'score': 0.64554054, 'word': 'tis', 'start': 73, 'end': 76}
# {'entity_group': 'LABEL_1', 'score': 0.6163516, 'word': ' melhore sugestoes futuras otimizacao continua processo teste', 'start': 78, 'end': 137}
#
# Resultado para História de Usuário 39:
# {'entity_group': 'LABEL_1', 'score': 0.58603436, 'word': ' historia de usuario 39', 'start': 0, 'end': 22}
# {'entity_group': 'LABEL_0', 'score': 0.57474035, 'word': ' :', 'start': 23, 'end': 23}
# {'entity_group': 'LABEL_1', 'score': 0.54788035, 'word': ' testador', 'start': 25, 'end': 32}
# {'entity_group': 'LABEL_0', 'score': 0.5853276, 'word': ' preciso', 'start': 34, 'end': 40}
# {'entity_group': 'LABEL_1', 'score': 0.58680516, 'word': ' suporte execucao tes', 'start': 42, 'end': 61}
# {'entity_group': 'LABEL_0', 'score': 0.6237, 'word': 'tis', 'start': 61, 'end': 64}
# {'entity_group': 'LABEL_1', 'score': 0.527058, 'word': ' seguranca automatizados', 'start': 66, 'end': 88}
# {'entity_group': 'LABEL_0', 'score': 0.5834139, 'word': ' identificar vulnerabilidades', 'start': 90, 'end': 117}
# {'entity_group': 'LABEL_1', 'score': 0.5052816, 'word': ' aplica', 'start': 119, 'end': 124}
# {'entity_group': 'LABEL_0', 'score': 0.50697225, 'word': 'tivo', 'start': 124, 'end': 128}
#
# Resultado para História de Usuário 40:
# {'entity_group': 'LABEL_1', 'score': 0.640493, 'word': ' historia de usuario 40', 'start': 0, 'end': 22}
# {'entity_group': 'LABEL_0', 'score': 0.54937494, 'word': ' :', 'start': 23, 'end': 23}
# {'entity_group': 'LABEL_1', 'score': 0.6295424, 'word': ' testador quero integracao ferramentas analise codigo', 'start': 25, 'end': 76}
# {'entity_group': 'LABEL_0', 'score': 0.5780738, 'word': ' esta', 'start': 78, 'end': 81}
# {'entity_group': 'LABEL_1', 'score': 0.6062746, 'word': 'tico', 'start': 81, 'end': 85}
# {'entity_group': 'LABEL_0', 'score': 0.5738346, 'word': ' identificar', 'start': 87, 'end': 97}
# {'entity_group': 'LABEL_1', 'score': 0.5923108, 'word': ' areas risco avaliacao abrangente qualidade', 'start': 99, 'end': 140}
#
# Resultado para História de Usuário 41:
# {'entity_group': 'LABEL_1', 'score': 0.6296804, 'word': ' historia de usuario 41 : testador desejo suporte execucao tes', 'start': 0, 'end': 60}
# {'entity_group': 'LABEL_0', 'score': 0.6605777, 'word': 'tis', 'start': 60, 'end': 63}
# {'entity_group': 'LABEL_1', 'score': 0.6314579, 'word': ' integracao sistema teste aceitacao usuario validar diferentes partes conformidade requisitos', 'start': 65, 'end': 156}
#
# Resultado para História de Usuário 42:
# {'entity_group': 'LABEL_1', 'score': 0.6285033, 'word': ' historia de usuario 42', 'start': 0, 'end': 22}
# {'entity_group': 'LABEL_0', 'score': 0.50379586, 'word': ' :', 'start': 23, 'end': 23}
# {'entity_group': 'LABEL_1', 'score': 0.56355435, 'word': ' testador', 'start': 25, 'end': 32}
# {'entity_group': 'LABEL_0', 'score': 0.54322445, 'word': ' preciso', 'start': 34, 'end': 40}
# {'entity_group': 'LABEL_1', 'score': 0.621835, 'word': ' suporte execucao tes', 'start': 42, 'end': 61}
# {'entity_group': 'LABEL_0', 'score': 0.54974836, 'word': 'tis confiabilidade', 'start': 61, 'end': 79}
# {'entity_group': 'LABEL_1', 'score': 0.5758374, 'word': ' disponibilidade garantir aplicativo', 'start': 81, 'end': 115}
# {'entity_group': 'LABEL_0', 'score': 0.501772, 'word': ' sempre', 'start': 117, 'end': 122}
# {'entity_group': 'LABEL_1', 'score': 0.6305266, 'word': ' disponivel funcione corretamente', 'start': 124, 'end': 155}
#
# Resultado para História de Usuário 43:
# {'entity_group': 'LABEL_1', 'score': 0.6592463, 'word': ' historia de usuario 43', 'start': 0, 'end': 22}
# {'entity_group': 'LABEL_0', 'score': 0.54543483, 'word': ' :', 'start': 23, 'end': 23}
# {'entity_group': 'LABEL_1', 'score': 0.6083353, 'word': ' testador quero ferramenta', 'start': 25, 'end': 49}
# {'entity_group': 'LABEL_0', 'score': 0.5961137, 'word': ' su', 'start': 51, 'end': 52}
# {'entity_group': 'LABEL_1', 'score': 0.7055425, 'word': 'gira', 'start': 52, 'end': 56}
# {'entity_group': 'LABEL_0', 'score': 0.5126098, 'word': ' casos', 'start': 58, 'end': 62}
# {'entity_group': 'LABEL_1', 'score': 0.61331105, 'word': ' teste base modelos qualidade software', 'start': 64, 'end': 100}
# {'entity_group': 'LABEL_0', 'score': 0.5294609, 'word': ' reconhecidos', 'start': 102, 'end': 113}
# {'entity_group': 'LABEL_1', 'score': 0.61539143, 'word': ' garantir abordagem abrangente', 'start': 115, 'end': 143}
# {'entity_group': 'LABEL_0', 'score': 0.5394296, 'word': ' padro', 'start': 145, 'end': 149}
# {'entity_group': 'LABEL_1', 'score': 0.5133054, 'word': 'nizada tes', 'start': 149, 'end': 159}
# {'entity_group': 'LABEL_0', 'score': 0.5974844, 'word': 'tis', 'start': 159, 'end': 162}
#
# Resultado para História de Usuário 44:
# {'entity_group': 'LABEL_1', 'score': 0.64976305, 'word': ' historia de usuario 44 : testador desejo integracao ferramentas automacao teste interface usuario automatizar tes', 'start': 0, 'end': 112}
# {'entity_group': 'LABEL_0', 'score': 0.65116346, 'word': 'tis', 'start': 112, 'end': 115}
# {'entity_group': 'LABEL_1', 'score': 0.72235614, 'word': ' interacao', 'start': 117, 'end': 125}
#
# Resultado para História de Usuário 45:
# {'entity_group': 'LABEL_1', 'score': 0.617369, 'word': ' historia de usuario 45 : testador', 'start': 0, 'end': 32}
# {'entity_group': 'LABEL_0', 'score': 0.5603194, 'word': ' preciso', 'start': 34, 'end': 40}
# {'entity_group': 'LABEL_1', 'score': 0.6375578, 'word': ' suporte execucao tes', 'start': 42, 'end': 61}
# {'entity_group': 'LABEL_0', 'score': 0.55440813, 'word': 'tis est', 'start': 61, 'end': 68}
# {'entity_group': 'LABEL_1', 'score': 0.55505955, 'word': 'resse robus', 'start': 68, 'end': 79}
# {'entity_group': 'LABEL_0', 'score': 0.53769314, 'word': 'te', 'start': 79, 'end': 81}
# {'entity_group': 'LABEL_1', 'score': 0.58429736, 'word': 'z avaliar estabilidade confi', 'start': 81, 'end': 109}
# {'entity_group': 'LABEL_0', 'score': 0.50665265, 'word': 'abilidade', 'start': 109, 'end': 118}
# {'entity_group': 'LABEL_1', 'score': 0.62170756, 'word': ' aplicativo sob condicoes adversas', 'start': 120, 'end': 152}
#
# Resultado para História de Usuário 46:
# {'entity_group': 'LABEL_1', 'score': 0.6365998, 'word': ' historia de usuario 46', 'start': 0, 'end': 22}
# {'entity_group': 'LABEL_0', 'score': 0.59185666, 'word': ' :', 'start': 23, 'end': 23}
# {'entity_group': 'LABEL_1', 'score': 0.58774745, 'word': ' testador quero ferramenta', 'start': 25, 'end': 49}
# {'entity_group': 'LABEL_0', 'score': 0.5929959, 'word': ' su', 'start': 51, 'end': 52}
# {'entity_group': 'LABEL_1', 'score': 0.68682724, 'word': 'gira', 'start': 52, 'end': 56}
# {'entity_group': 'LABEL_0', 'score': 0.51149124, 'word': ' casos', 'start': 58, 'end': 62}
# {'entity_group': 'LABEL_1', 'score': 0.53644955, 'word': ' teste', 'start': 64, 'end': 68}
# {'entity_group': 'LABEL_0', 'score': 0.5072619, 'word': ' areas', 'start': 70, 'end': 74}
# {'entity_group': 'LABEL_1', 'score': 0.61590004, 'word': ' alto risco complexidade priorizar esforcos', 'start': 76, 'end': 117}
#
# Resultado para História de Usuário 47:
# {'entity_group': 'LABEL_1', 'score': 0.62648934, 'word': ' historia de usuario 47', 'start': 0, 'end': 22}
# {'entity_group': 'LABEL_0', 'score': 0.5118265, 'word': ' : tes', 'start': 23, 'end': 27}
# {'entity_group': 'LABEL_1', 'score': 0.6134869, 'word': 'tador desejo integracao ferramentas gerenciamento defeitos rastreamento correcoes gestao eficaz', 'start': 27, 'end': 122}
# {'entity_group': 'LABEL_0', 'score': 0.58563447, 'word': ' problemas encontrados durante', 'start': 124, 'end': 152}
# {'entity_group': 'LABEL_1', 'score': 0.54238474, 'word': ' tes', 'start': 154, 'end': 156}
# {'entity_group': 'LABEL_0', 'score': 0.6081065, 'word': 'tis', 'start': 156, 'end': 159}
#
# Resultado para História de Usuário 48:
# {'entity_group': 'LABEL_1', 'score': 0.61825025, 'word': ' historia de usuario 48 :', 'start': 0, 'end': 23}
# {'entity_group': 'LABEL_0', 'score': 0.51089084, 'word': ' tes', 'start': 25, 'end': 27}
# {'entity_group': 'LABEL_1', 'score': 0.54204, 'word': 'tador', 'start': 27, 'end': 32}
# {'entity_group': 'LABEL_0', 'score': 0.5411976, 'word': ' preciso', 'start': 34, 'end': 40}
# {'entity_group': 'LABEL_1', 'score': 0.6352708, 'word': ' suporte execucao tes', 'start': 42, 'end': 61}
# {'entity_group': 'LABEL_0', 'score': 0.6772816, 'word': 'tis', 'start': 61, 'end': 64}
# {'entity_group': 'LABEL_1', 'score': 0.57500196, 'word': ' usabilidade', 'start': 66, 'end': 76}
# {'entity_group': 'LABEL_0', 'score': 0.51051396, 'word': ' remo', 'start': 78, 'end': 81}
# {'entity_group': 'LABEL_1', 'score': 0.5420908, 'word': 'ta teste usuario beta cole', 'start': 81, 'end': 107}
# {'entity_group': 'LABEL_0', 'score': 0.51350486, 'word': 'tar', 'start': 107, 'end': 110}
# {'entity_group': 'LABEL_1', 'score': 0.5067957, 'word': ' fe', 'start': 112, 'end': 113}
# {'entity_group': 'LABEL_0', 'score': 0.6666815, 'word': 'ed', 'start': 113, 'end': 115}
# {'entity_group': 'LABEL_1', 'score': 0.5435466, 'word': 'back', 'start': 115, 'end': 119}
# {'entity_group': 'LABEL_0', 'score': 0.53676945, 'word': ' usuarios', 'start': 121, 'end': 128}
# {'entity_group': 'LABEL_1', 'score': 0.58266836, 'word': ' reais', 'start': 130, 'end': 134}
#
# Resultado para História de Usuário 49:
# {'entity_group': 'LABEL_1', 'score': 0.6325921, 'word': ' historia de usuario 49', 'start': 0, 'end': 22}
# {'entity_group': 'LABEL_0', 'score': 0.5750819, 'word': ' :', 'start': 23, 'end': 23}
# {'entity_group': 'LABEL_1', 'score': 0.5958496, 'word': ' testador quero ferramenta forneca fe', 'start': 25, 'end': 60}
# {'entity_group': 'LABEL_0', 'score': 0.54013354, 'word': 'ed', 'start': 60, 'end': 62}
# {'entity_group': 'LABEL_1', 'score': 0.5314048, 'word': 'back', 'start': 62, 'end': 66}
# {'entity_group': 'LABEL_0', 'score': 0.50952417, 'word': ' tempo', 'start': 68, 'end': 72}
# {'entity_group': 'LABEL_1', 'score': 0.51819414, 'word': ' real', 'start': 74, 'end': 77}
# {'entity_group': 'LABEL_0', 'score': 0.5942719, 'word': ' durante', 'start': 79, 'end': 85}
# {'entity_group': 'LABEL_1', 'score': 0.5958562, 'word': ' execucao tes', 'start': 87, 'end': 98}
# {'entity_group': 'LABEL_0', 'score': 0.5798518, 'word': 'tis', 'start': 98, 'end': 101}
# {'entity_group': 'LABEL_1', 'score': 0.56578314, 'word': ' facilitar identificacao', 'start': 103, 'end': 125}
# {'entity_group': 'LABEL_0', 'score': 0.5349161, 'word': ' imediata problemas', 'start': 127, 'end': 144}
#
# Resultado para História de Usuário 50:
# {'entity_group': 'LABEL_1', 'score': 0.649078, 'word': ' historia de usuario 50', 'start': 0, 'end': 22}
# {'entity_group': 'LABEL_0', 'score': 0.5206789, 'word': ' :', 'start': 23, 'end': 23}
# {'entity_group': 'LABEL_1', 'score': 0.67150307, 'word': ' testador desejo integracao ferramentas automacao infraestrutura provisionamento configuracao automatizados facilitar preparacao ambiente teste', 'start': 25, 'end': 166}
#
# Resultado para História de Usuário 51:
# {'entity_group': 'LABEL_1', 'score': 0.67053723, 'word': ' historia de usuario 51', 'start': 0, 'end': 22}
# {'entity_group': 'LABEL_0', 'score': 0.5065319, 'word': ' :', 'start': 23, 'end': 23}
# {'entity_group': 'LABEL_1', 'score': 0.5931428, 'word': ' testador preciso suporte execucao tes', 'start': 25, 'end': 61}
# {'entity_group': 'LABEL_0', 'score': 0.60516906, 'word': 'tis', 'start': 61, 'end': 64}
# {'entity_group': 'LABEL_1', 'score': 0.5239157, 'word': ' comparacao desempenho versoes anteriores', 'start': 66, 'end': 105}
# {'entity_group': 'LABEL_0', 'score': 0.53540105, 'word': ' atuais', 'start': 107, 'end': 112}
# {'entity_group': 'LABEL_1', 'score': 0.53918225, 'word': ' aplicativo avaliar impacto mudancas', 'start': 114, 'end': 148}

# %%
def extracao(freq_dist):
    frequencia = " ".join(freq_dist.keys()).lower()

    autor = None
    if "testador" in frequencia:
        autor = "Testador"

    finalidade = None
    for word in ["quero", "preciso", "desejo"]:
        if word in frequencia:
            pos_inicial = frequencia.find(word) + len(word)
            finalidade = frequencia[pos_inicial:].strip().split(",")[0]
            break
    if "para" in frequencia:
        pos_inicial_para = frequencia.find("para") + len("para")
        finalidade = "para " + frequencia[pos_inicial_para:].strip().split(",")[0]


    return autor, finalidade


for i, freq_dist in enumerate(freq_dists):
    autor, finalidade = extracao(freq_dist)
    print("História do Usuário:", historias_usuario[i])
    print("Autor:", autor)
    print("Finalidade:", finalidade)
    print()
# Out:
# História do Usuário: Como Testador eu quero um jeito mais fácil de incluir os requisitos do aplicativo na ferramenta DRL-Mobtest para criar casos de teste que cubram tudo que o aplicativo precisa fazer, sem ter que gastar muito tempo escrevendo manualmente.
# Autor: Testador
# Finalidade: jeito fácil incluir requisitos aplicativo ferramenta drl-mobtest criar casos teste cubram tudo precisa fazer ter gastar tempo escrevendo manualmente
#
# História do Usuário: Como Testador eu quero uma maneira de ensinar a ferramenta DRL-Mobtest a entender os requisitos do aplicativo usando NLP para fazer com que a ferramenta gere testes automaticamente.
# Autor: Testador
# Finalidade: maneira ensinar ferramenta drl-mobtest entender requisitos aplicativo usando nlp fazer gere testis automaticamente
#
# História do Usuário: Como Testador eu quero que a ferramenta gere casos de teste abrangentes que cubram integralmente todos os requisitos do aplicativo, assegurando que o software seja completo e funcional, sem depender exclusivamente da criação manual de casos de teste.
# Autor: Testador
# Finalidade: ferramenta gere casos teste abrangentes cubram integralmente todos requisitos aplicativo assegurando software completo funcional depender exclusivamente criação manual
#
# História do Usuário: Como Testador eu quero que a ferramenta seja integrada com outras ferramentas de gerenciamento, permitindo sincronização automática dos requisitos e facilitando o processo de criação de casos de testes.
# Autor: Testador
# Finalidade: ferramenta integrada outras ferramentas gerenciamento permitindo sincronização automática requisitos facilitando processo criação casos testis
#
# História do Usuário: Como testador, eu quero que a ferramenta gere casos de teste completos e funcionais que cubram todos os requisitos do aplicativo, para garantir uma cobertura abrangente durante os testes.
# Autor: Testador
# Finalidade: ferramenta gere casos teste completos funcionais cubram todos requisitos aplicativo garantir cobertura abrangente durante testis
#
# História do Usuário: Como testador, eu quero integração com outras ferramentas de gerenciamento para sincronizar automaticamente requisitos e facilitar a criação de casos de teste, visando melhorar a eficiência e precisão do processo de teste.
# Autor: Testador
# Finalidade: integração outras ferramentas gerenciamento sincronizar automaticamente requisitos facilitar criação casos teste visando melhorar eficiência precisão processo
#
# História do Usuário: Como testador, eu quero relatórios detalhados sobre a cobertura dos testes para análise precisa durante a execução, a fim de avaliar a qualidade e a extensão dos testes realizados.
# Autor: Testador
# Finalidade: relatórios detalhados sobre cobertura testis análise precisa durante execução fim avaliar qualidade extensão realizados
#
# História do Usuário: Como testador, eu desejo que a ferramenta identifique automaticamente os casos de teste mais críticos para priorizar a análise, visando direcionar os esforços de teste para áreas de maior risco.
# Autor: Testador
# Finalidade: ferramenta identifique automaticamente casos teste críticos priorizar análise visando direcionar esforços áreas maior risco
#
# História do Usuário: Como testador, eu preciso que a ferramenta sugira casos de teste com base em padrões de uso real do aplicativo, para garantir que os testes reflitam cenários típicos de uso.
# Autor: Testador
# Finalidade: ferramenta sugira casos teste base padrões uso real aplicativo garantir testis reflitam cenários típicos
#
# História do Usuário: Como testador, eu quero sugestões com base em padrões de falha históricos para evitar problemas recorrentes no software, visando melhorar a qualidade e a robustez do produto.
# Autor: Testador
# Finalidade: sugestões base padrões falha históricos evitar problemas recorrentes software visando melhorar qualidade robustez produto
#
# História do Usuário: Como testador, eu desejo suporte à execução de testes automatizados em diferentes dispositivos e ambientes, para garantir a consistência e a confiabilidade dos testes em diferentes cenários.
# Autor: Testador
# Finalidade: suporte execução testis automatizados diferentes dispositivos ambientes garantir consistência confiabilidade cenários
#
# História do Usuário: Como testador, eu preciso que a ferramenta detecte automaticamente mudanças nos requisitos e ajuste os casos de teste correspondentes, para manter os testes alinhados com a evolução do aplicativo.
# Autor: Testador
# Finalidade: ferramenta detecte automaticamente mudanças requisitos ajuste casos teste correspondentes manter testis alinhados evolução aplicativo
#
# História do Usuário: Como testador, eu quero integração com sistemas de controle de versão para rastrear mudanças nos requisitos e no código-fonte, visando uma gestão eficaz de mudanças durante o ciclo de desenvolvimento.
# Autor: Testador
# Finalidade: integração sistemas controle versão rastrear mudanças requisitos código-fonte visando gestão eficaz durante ciclo desenvolvimento
#
# História do Usuário: Como testador, eu desejo métricas detalhadas sobre a eficácia dos testes, incluindo taxa de cobertura e taxa de falha, para avaliar a qualidade do processo de teste.
# Autor: Testador
# Finalidade: métricas detalhadas sobre eficácia testis incluindo taxon cobertura falha avaliar qualidade processo teste
#
# História do Usuário: Como testador, eu preciso de suporte à execução de testes de desempenho e escalabilidade, para garantir que o aplicativo atenda aos requisitos de desempenho sob carga.
# Autor: Testador
# Finalidade: suporte execução testis desempenho escalabilidade garantir aplicativo atenda requisitos sob carga
#
# História do Usuário: Como testador, eu quero análise automática dos resultados dos testes para relatórios detalhados sobre problemas encontrados, a fim de facilitar a identificação e correção de defeitos.
# Autor: Testador
# Finalidade: análise automática resultados testis relatórios detalhados sobre problemas encontrados fim facilitar identificação correção defeitos
#
# História do Usuário: Como testador, eu desejo simular cenários de teste complexos e realistas para garantir testes próximos à realidade, visando uma validação mais precisa do software.
# Autor: Testador
# Finalidade: simular cenários teste complexos realistas garantir testis próximos realidade visando validação precisa software
#
# História do Usuário: Como testador, eu preciso de suporte à execução de testes de regressão automatizados, para garantir que as alterações no código não introduzam regressões.
# Autor: Testador
# Finalidade: suporte execução testis regressão automatizados garantir alterações código introduzam regressões
#
# História do Usuário: Como testador, eu quero identificação automática de casos de teste redundantes ou desnecessários, para otimizar os esforços de teste.
# Autor: Testador
# Finalidade: identificação automática casos teste redundantes desnecessários otimizar esforços
#
# História do Usuário: Como testador, eu desejo integração fácil com ferramentas de gerenciamento de projetos, para uma colaboração eficiente com outros membros da equipe de desenvolvimento.
# Autor: Testador
# Finalidade: integração fácil ferramentas gerenciamento projetos colaboração eficiente outros membros equipe desenvolvimento
#
# História do Usuário: Como testador, eu preciso de suporte à execução de testes de usabilidade, para garantir que o aplicativo seja fácil e intuitivo de usar.
# Autor: Testador
# Finalidade: suporte execução testis usabilidade garantir aplicativo fácil intuitivo usar
#
# História do Usuário: Como testador, eu quero que a ferramenta crie automaticamente conjuntos de dados de teste realistas, para simular condições reais de uso.
# Autor: Testador
# Finalidade: ferramenta crie automaticamente conjuntos dado teste realistas simular condições reais uso
#
# História do Usuário: Como testador, eu desejo integração com ferramentas de monitoramento de desempenho em tempo real, para avaliar o desempenho do aplicativo durante os testes.
# Autor: Testador
# Finalidade: integração ferramentas monitoramento desempenho tempo real avaliar aplicativo durante testis
#
# História do Usuário: Como testador, eu preciso de suporte à execução de testes de localização e internacionalização, para garantir que o aplicativo seja compatível com diferentes idiomas e regiões.
# Autor: Testador
# Finalidade: suporte execução testis localização internacionalização garantir aplicativo compatível diferentes idiomas regiões
#
# História do Usuário: Como testador, eu quero geração automática de dados de teste sintéticos, para complementar os casos de teste manuais.
# Autor: Testador
# Finalidade: geração automática dado teste sintéticos complementar casos manuais
#
# História do Usuário: Como testador, eu desejo suporte à execução de testes de acessibilidade, para garantir que o aplicativo seja acessível a todos os usuários.
# Autor: Testador
# Finalidade: suporte execução testis acessibilidade garantir aplicativo acessível todos usuários
#
# História do Usuário: Como testador, eu preciso de suporte à execução de testes de integração contínua, para garantir que as alterações no código não quebrem a integração com outras partes do sistema.
# Autor: Testador
# Finalidade: suporte execução testis integração contínua garantir alterações código quebrem outras partes sistema
#
# História do Usuário: Como testador, eu quero identificação automática de casos de teste incompletos ou mal definidos, para garantir a qualidade dos testes.
# Autor: Testador
# Finalidade: identificação automática casos teste incompletos mal definidos garantir qualidade testis
#
# História do Usuário: Como testador, eu desejo identificação automática de dependências entre casos de teste, para garantir uma sequência lógica na execução dos testes.
# Autor: Testador
# Finalidade: identificação automática dependências casos teste garantir sequência lógica execução testis
#
# História do Usuário: Como testador, eu preciso de suporte à execução de testes de recuperação de desastres, para avaliar a capacidade do sistema de se recuperar de falhas.
# Autor: Testador
# Finalidade: suporte execução testis recuperação desastres avaliar capacidade sistema recuperar falhas
#
# História do Usuário: Como testador, eu quero que a ferramenta identifique automaticamente casos de teste paralelizáveis, para otimizar a execução dos testes.
# Autor: Testador
# Finalidade: para lelizáveis otimizar execução testis
#
# História do Usuário: Como testador, eu desejo simulação de cenários de teste de carga extremamente alta, para avaliar a capacidade de escalabilidade do sistema.
# Autor: Testador
# Finalidade: simulação cenários teste carga extremamente alta avaliar capacidade escalabilidade sistema
#
# História do Usuário: Como testador, eu preciso de suporte à execução de testes de compatibilidade com diferentes navegadores e dispositivos, para garantir uma experiência consistente para todos os usuários.
# Autor: Testador
# Finalidade: suporte execução testis compatibilidade diferentes navegadores dispositivos garantir experiência consistente todos usuários
#
# História do Usuário: Como testador, eu quero geração automática de relatórios de teste personalizados, para comunicar eficazmente os resultados dos testes.
# Autor: Testador
# Finalidade: geração automática relatórios teste personalizados comunicar eficazmente resultados testis
#
# História do Usuário: Como testador, eu desejo rastreamento automático de resultados de teste ao longo do tempo, para identificar tendências e padrões de qualidade.
# Autor: Testador
# Finalidade: rastreamento automático resultados teste longo tempo identificar tendências padrões qualidade
#
# História do Usuário: Como testador, eu preciso de suporte à execução de testes de regressão progressiva, para garantir que as novas alterações não quebrem funcionalidades existentes.
# Autor: Testador
# Finalidade: suporte execução testis regressão progressiva garantir nova alterações quebrem funcionalidades existentes
#
# História do Usuário: Como testador, eu quero sugestões automáticas para aprimorar os casos de teste existentes, para aumentar a eficiência e a eficácia dos testes.
# Autor: Testador
# Finalidade: sugestões automáticas aprimorar casos teste existentes aumentar eficiência eficácia testis
#
# História do Usuário: Como testador, eu desejo que a ferramenta aprenda com os resultados dos testes e melhore suas sugestões futuras, para uma otimização contínua do processo de teste.
# Autor: Testador
# Finalidade: ferramenta aprenda resultados testis melhore sugestões futuras otimização contínua processo teste
#
# História do Usuário: Como testador, eu preciso de suporte à execução de testes de segurança automatizados, para identificar vulnerabilidades no aplicativo.
# Autor: Testador
# Finalidade: suporte execução testis segurança automatizados identificar vulnerabilidades aplicativo
#
# História do Usuário: Como testador, eu quero integração com ferramentas de análise de código estático para identificar áreas de risco, para uma avaliação abrangente da qualidade do código.
# Autor: Testador
# Finalidade: integração ferramentas análise código estático identificar áreas risco avaliação abrangente qualidade
#
# História do Usuário: Como testador, eu desejo suporte à execução de testes de integração de sistema e teste de aceitação do usuário, para validar a integração entre diferentes partes do sistema e a conformidade com os requisitos do usuário.
# Autor: Testador
# Finalidade: suporte execução testis integração sistema teste aceitação usuário validar diferentes partes conformidade requisitos
#
# História do Usuário: Como testador, eu preciso de suporte à execução de testes de confiabilidade e disponibilidade, para garantir que o aplicativo esteja sempre disponível e funcione corretamente.
# Autor: Testador
# Finalidade: suporte execução testis confiabilidade disponibilidade garantir aplicativo sempre disponível funcione corretamente
#
# História do Usuário: Como testador, eu quero que a ferramenta sugira casos de teste com base em modelos de qualidade de software reconhecidos, para garantir uma abordagem abrangente e padronizada para os testes.
# Autor: Testador
# Finalidade: ferramenta sugira casos teste base modelos qualidade software reconhecidos garantir abordagem abrangente padronizada testis
#
# História do Usuário: Como testador, eu desejo integração com ferramentas de automação de teste de interface do usuário, para automatizar testes de interação com o usuário.
# Autor: Testador
# Finalidade: integração ferramentas automação teste interface usuário automatizar testis interação
#
# História do Usuário: Como testador, eu preciso de suporte à execução de testes de estresse e robustez, para avaliar a estabilidade e a confiabilidade do aplicativo sob condições adversas.
# Autor: Testador
# Finalidade: suporte execução testis estresse robustez avaliar estabilidade confiabilidade aplicativo sob condições adversas
#
# História do Usuário: Como testador, eu quero que a ferramenta sugira casos de teste para áreas de alto risco e complexidade, para priorizar os esforços de teste.
# Autor: Testador
# Finalidade: ferramenta sugira casos teste áreas alto risco complexidade priorizar esforços
#
# História do Usuário: Como testador, eu desejo integração com ferramentas de gerenciamento de defeitos para rastreamento de correções, para uma gestão eficaz de problemas encontrados durante os testes.
# Autor: Testador
# Finalidade: integração ferramentas gerenciamento defeitos rastreamento correções gestão eficaz problemas encontrados durante testis
#
# História do Usuário: Como testador, eu preciso de suporte à execução de testes de usabilidade remota e teste de usuário beta, para coletar feedback de usuários reais.
# Autor: Testador
# Finalidade: suporte execução testis usabilidade remota teste usuário beta coletar feedback usuários reais
#
# História do Usuário: Como testador, eu quero que a ferramenta forneça feedback em tempo real durante a execução dos testes, para facilitar a identificação imediata de problemas.
# Autor: Testador
# Finalidade: ferramenta forneça feedback tempo real durante execução testis facilitar identificação imediata problemas
#
# História do Usuário: Como testador, eu desejo integração com ferramentas de automação de infraestrutura para provisionamento e configuração automatizados, para facilitar a preparação do ambiente de teste.
# Autor: Testador
# Finalidade: para ção ambiente teste
#
# História do Usuário: Como testador, eu preciso de suporte à execução de testes de comparação de desempenho para versões anteriores e atuais do aplicativo, para avaliar o impacto de mudanças no desempenho.
# Autor: Testador
# Finalidade: para ção desempenho versões anteriores atuais aplicativo avaliar impacto mudanças

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import recall_score, f1_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
# !pip install scikit-learn
from random import choice
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.25.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.4.0)

# %%
X = freq_dists
rotulos_possiveis = ["testador", "aplicativo", "desempenho", "teste"]
y = [choice(rotulos_possiveis) for _ in range(len(freq_dists))]
vetorizacao = TfidfVectorizer()
X = vetorizacao.fit_transform([" ".join(freq_dist.keys()) for freq_dist in X])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.4, random_state=42,stratify=y)

# %%
from sklearn.linear_model import LogisticRegression
modelo_regressao = LogisticRegression()
modelo_regressao.fit(X_train, y_train)
y_predicted = modelo_regressao.predict(X_test)
acuracia = accuracy_score(y_test, y_predicted)
print("Acurácia:", acuracia)
# Out:
# Acurácia: 0.38095238095238093

# %%
clf_tf = DecisionTreeClassifier(criterion='gini',max_depth=15)
clf_tf.fit(X_train, y_train)
pred_arvore_entropy_tf = clf_tf.predict(X_test)
accuracy_decision = accuracy_score(y_test,pred_arvore_entropy_tf)
recall = recall_score(y_test, pred_arvore_entropy_tf, average='weighted')
f1 = f1_score(y_test, pred_arvore_entropy_tf, average='weighted')
print(f"Resultado: ",accuracy_decision)
print(f"Resultado: ",recall)
print(f"Resultado: ",f1)
# Out:
# Resultado:  0.2857142857142857
# Resultado:  0.2857142857142857
# Resultado:  0.2585034013605442

# %%
clf = DecisionTreeClassifier(criterion='entropy',max_depth=7)
clf.fit(X_train, y_train)
pred_arvore_entropy = clf.predict(X_test)
accuracy_decision = accuracy_score(y_test,pred_arvore_entropy)
recall_entropy = recall_score(y_test, pred_arvore_entropy, average='weighted')
f1_entropy = f1_score(y_test, pred_arvore_entropy, average='weighted')
print(f"Resultado: ",accuracy_decision)
print(f"Resultado: ",recall_entropy)
print(f"Resultado: ",f1_entropy)
# Out:
# Resultado:  0.19047619047619047
# Resultado:  0.19047619047619047
# Resultado:  0.17055711173358232

# %%
clf_tf3 = KNeighborsClassifier(metric='manhattan',n_neighbors=3)
clf_tf3.fit(X_train, y_train)
pred_knn_tf = clf_tf3.predict(X_test)
acuracy_KNN = accuracy_score(y_test,pred_knn_tf)
recall_knn = recall_score(y_test, pred_knn_tf, average='weighted')
f1_knn = f1_score(y_test, pred_knn_tf, average='weighted')
print(f"Resultado: ",acuracy_KNN)
print(f"Resultado: ",recall_knn)
print(f"Resultado: ",f1_knn)
# Out:
# Resultado:  0.23809523809523808
# Resultado:  0.23809523809523808
# Resultado:  0.15014005602240899

# %%
clf_tf4 = KNeighborsClassifier(n_neighbors=5,weights='distance', algorithm='brute')
clf_tf4.fit(X_train, y_train)
pred_knn_tf2 = clf_tf4.predict(X_test)
acuracy_KNN2 = accuracy_score(y_test,pred_knn_tf2)
recall_knn2 = recall_score(y_test, pred_knn_tf2, average='weighted')
f1_knn2 = f1_score(y_test, pred_knn_tf2, average='weighted')
print(f"Resultado: ",acuracy_KNN)
print(f"Resultado: ",recall_knn2)
print(f"Resultado: ",f1_knn2)
# Out:
# Resultado:  0.23809523809523808
# Resultado:  0.3333333333333333
# Resultado:  0.3047619047619048

# %%
svc = SVC(kernel='linear', C=0.05)
svc.fit(X_train, y_train)
pred_svc = svc.predict(X_test)
accuracy_svc = accuracy_score(y_test, pred_svc)
recall_svc = recall_score(y_test, pred_svc, average='weighted')
f1_svc = f1_score(y_test, pred_svc, average='weighted')
print(f"Resultado: ",accuracy_svc)
print(f"Resultado: ",recall_svc)
print(f"Resultado: ",f1_svc)
# Out:
# Resultado:  0.3333333333333333
# Resultado:  0.3333333333333333
# Resultado:  0.16666666666666666

# %%
from tensorflow.keras import layers
import tensorflow_datasets as tfds
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt
from tensorflow import keras
import tensorflow_hub as hub
import tensorflow as tf

# %%
le_rn = LabelEncoder()
ytrain = le_rn.fit_transform(y_train)
ytest = le_rn.transform(y_test)

# %%
Xtrain = np.expand_dims(X_train.toarray(), axis=1)
Xtest = np.expand_dims(X_test.toarray(), axis=1)

# %%
num_classes = 4
model = tf.keras.Sequential([
    layers.LSTM(128, input_shape=(Xtrain.shape[1], Xtrain.shape[2])),
    layers.Dense(64, activation='relu'),
    layers.Dense(num_classes, activation='softmax')
])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
EPOCHS = 20
history = model.fit(Xtrain, ytrain, epochs=EPOCHS, batch_size=32, validation_data=(Xtest, ytest))
# Out:
# Epoch 1/20
# 1/1 [==============================] - 3s 3s/step - loss: 1.3847 - accuracy: 0.3333 - val_loss: 1.3893 - val_accuracy: 0.0952
# Epoch 2/20
# 1/1 [==============================] - 0s 45ms/step - loss: 1.3771 - accuracy: 0.4000 - val_loss: 1.3892 - val_accuracy: 0.0952
# Epoch 3/20
# 1/1 [==============================] - 0s 67ms/step - loss: 1.3699 - accuracy: 0.6000 - val_loss: 1.3890 - val_accuracy: 0.1429
# Epoch 4/20
# 1/1 [==============================] - 0s 66ms/step - loss: 1.3627 - accuracy: 0.7000 - val_loss: 1.3889 - val_accuracy: 0.1429
# Epoch 5/20
# 1/1 [==============================] - 0s 71ms/step - loss: 1.3555 - accuracy: 0.7333 - val_loss: 1.3888 - val_accuracy: 0.1429
# Epoch 6/20
# 1/1 [==============================] - 0s 43ms/step - loss: 1.3482 - accuracy: 0.7000 - val_loss: 1.3886 - val_accuracy: 0.1429
# Epoch 7/20
# 1/1 [==============================] - 0s 61ms/step - loss: 1.3406 - accuracy: 0.7000 - val_loss: 1.3884 - val_accuracy: 0.2381
# Epoch 8/20
# 1/1 [==============================] - 0s 85ms/step - loss: 1.3328 - accuracy: 0.7000 - val_loss: 1.3881 - val_accuracy: 0.2857
# Epoch 9/20
# 1/1 [==============================] - 0s 81ms/step - loss: 1.3245 - accuracy: 0.7667 - val_loss: 1.3879 - val_accuracy: 0.2857
# Epoch 10/20
# 1/1 [==============================] - 0s 73ms/step - loss: 1.3159 - accuracy: 0.7667 - val_loss: 1.3877 - val_accuracy: 0.2857
# Epoch 11/20
# 1/1 [==============================] - 0s 95ms/step - loss: 1.3068 - accuracy: 0.7667 - val_loss: 1.3875 - val_accuracy: 0.2857
# Epoch 12/20
# 1/1 [==============================] - 0s 86ms/step - loss: 1.2972 - accuracy: 0.7667 - val_loss: 1.3871 - val_accuracy: 0.2857
# Epoch 13/20
# 1/1 [==============================] - 0s 96ms/step - loss: 1.2870 - accuracy: 0.7667 - val_loss: 1.3868 - val_accuracy: 0.2857
# Epoch 14/20
# 1/1 [==============================] - 0s 83ms/step - loss: 1.2763 - accuracy: 0.7667 - val_loss: 1.3865 - val_accuracy: 0.3333
# Epoch 15/20
# 1/1 [==============================] - 0s 94ms/step - loss: 1.2649 - accuracy: 0.8333 - val_loss: 1.3863 - val_accuracy: 0.3333
# Epoch 16/20
# 1/1 [==============================] - 0s 83ms/step - loss: 1.2528 - accuracy: 0.8333 - val_loss: 1.3861 - val_accuracy: 0.3333
# Epoch 17/20
# 1/1 [==============================] - 0s 93ms/step - loss: 1.2401 - accuracy: 0.8333 - val_loss: 1.3860 - val_accuracy: 0.3333
# Epoch 18/20
# 1/1 [==============================] - 0s 114ms/step - loss: 1.2265 - accuracy: 0.8333 - val_loss: 1.3859 - val_accuracy: 0.3810
# Epoch 19/20
# 1/1 [==============================] - 0s 90ms/step - loss: 1.2122 - accuracy: 0.8333 - val_loss: 1.3858 - val_accuracy: 0.3810
# Epoch 20/20
# 1/1 [==============================] - 0s 199ms/step - loss: 1.1971 - accuracy: 0.8333 - val_loss: 1.3858 - val_accuracy: 0.3810

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(len(acc))

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Acuracia no treino')
plt.plot(epochs_range, val_acc, label='Acuracia na validacao')
plt.legend(loc='lower right')
plt.title('Acuracia no treino na validacao')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Perda no treino')
plt.plot(epochs_range, val_loss, label='Perda na validacao')
plt.legend(loc='upper right')
plt.title('Perda no treino e na validacao')
plt.show()

# %%
model_drop = tf.keras.Sequential([
    layers.LSTM(128, input_shape=(Xtrain.shape[1], Xtrain.shape[2])),
    layers.Dense(64, activation='relu'),
    keras.layers.Dropout(rate=0.5),
    layers.Dense(num_classes, activation='softmax')
])

# %%
model_drop.compile(optimizer='adam',
                   loss='sparse_categorical_crossentropy',
                   metrics=['accuracy'])

# %%
EPOCHS = 20
history_drop = model_drop.fit(Xtrain, ytrain, epochs=EPOCHS, batch_size=32, validation_data=(Xtest, ytest))
# Out:
# Epoch 1/20
# 1/1 [==============================] - 4s 4s/step - loss: 1.3931 - accuracy: 0.1000 - val_loss: 1.3871 - val_accuracy: 0.3333
# Epoch 2/20
# 1/1 [==============================] - 0s 143ms/step - loss: 1.3814 - accuracy: 0.4000 - val_loss: 1.3869 - val_accuracy: 0.2857
# Epoch 3/20
# 1/1 [==============================] - 0s 125ms/step - loss: 1.3772 - accuracy: 0.4333 - val_loss: 1.3867 - val_accuracy: 0.2857
# Epoch 4/20
# 1/1 [==============================] - 0s 124ms/step - loss: 1.3733 - accuracy: 0.5000 - val_loss: 1.3865 - val_accuracy: 0.2857
# Epoch 5/20
# 1/1 [==============================] - 0s 79ms/step - loss: 1.3717 - accuracy: 0.4667 - val_loss: 1.3863 - val_accuracy: 0.2857
# Epoch 6/20
# 1/1 [==============================] - 0s 89ms/step - loss: 1.3617 - accuracy: 0.7333 - val_loss: 1.3860 - val_accuracy: 0.2857
# Epoch 7/20
# 1/1 [==============================] - 0s 73ms/step - loss: 1.3666 - accuracy: 0.5333 - val_loss: 1.3857 - val_accuracy: 0.3333
# Epoch 8/20
# 1/1 [==============================] - 0s 77ms/step - loss: 1.3569 - accuracy: 0.6000 - val_loss: 1.3855 - val_accuracy: 0.3333
# Epoch 9/20
# 1/1 [==============================] - 0s 90ms/step - loss: 1.3550 - accuracy: 0.7333 - val_loss: 1.3852 - val_accuracy: 0.3333
# Epoch 10/20
# 1/1 [==============================] - 0s 138ms/step - loss: 1.3462 - accuracy: 0.6667 - val_loss: 1.3851 - val_accuracy: 0.3333
# Epoch 11/20
# 1/1 [==============================] - 0s 82ms/step - loss: 1.3444 - accuracy: 0.7000 - val_loss: 1.3850 - val_accuracy: 0.3333
# Epoch 12/20
# 1/1 [==============================] - 0s 89ms/step - loss: 1.3409 - accuracy: 0.7333 - val_loss: 1.3848 - val_accuracy: 0.3333
# Epoch 13/20
# 1/1 [==============================] - 0s 213ms/step - loss: 1.3280 - accuracy: 0.8000 - val_loss: 1.3845 - val_accuracy: 0.3333
# Epoch 14/20
# 1/1 [==============================] - 0s 87ms/step - loss: 1.3227 - accuracy: 0.8000 - val_loss: 1.3843 - val_accuracy: 0.3333
# Epoch 15/20
# 1/1 [==============================] - 0s 93ms/step - loss: 1.3229 - accuracy: 0.9000 - val_loss: 1.3842 - val_accuracy: 0.3810
# Epoch 16/20
# 1/1 [==============================] - 0s 80ms/step - loss: 1.3149 - accuracy: 0.8333 - val_loss: 1.3841 - val_accuracy: 0.3810
# Epoch 17/20
# 1/1 [==============================] - 0s 69ms/step - loss: 1.3067 - accuracy: 0.8667 - val_loss: 1.3840 - val_accuracy: 0.3810
# Epoch 18/20
# 1/1 [==============================] - 0s 91ms/step - loss: 1.3013 - accuracy: 0.8667 - val_loss: 1.3838 - val_accuracy: 0.3810
# Epoch 19/20
# 1/1 [==============================] - 0s 88ms/step - loss: 1.2940 - accuracy: 0.8333 - val_loss: 1.3837 - val_accuracy: 0.3810
# Epoch 20/20
# 1/1 [==============================] - 0s 75ms/step - loss: 1.2933 - accuracy: 0.7333 - val_loss: 1.3836 - val_accuracy: 0.3810

# %%
acc2 = history_drop.history['accuracy']
val_acc2 = history_drop.history['val_accuracy']
loss2 = history_drop.history['loss']
val_loss2 = history_drop.history['val_loss']

epochs_range = range(len(acc2))

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc2, label='Acuracia no treino')
plt.plot(epochs_range, val_acc2, label='Acuracia na validacao')
plt.legend(loc='lower right')
plt.title('Acuracia no treino na validacao')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss2, label='Perda no treino')
plt.plot(epochs_range, val_loss2, label='Perda na validacao')
plt.legend(loc='upper right')
plt.title('Perda no treino e na validacao')
plt.show()

# %%
model_early = tf.keras.Sequential([
    layers.LSTM(128, input_shape=(Xtrain.shape[1], Xtrain.shape[2])),
    layers.Dense(64, activation='relu'),
    layers.Dense(num_classes, activation='softmax')
])

# %%
model_early.compile(optimizer='adam',
                   loss='sparse_categorical_crossentropy',
                   metrics=['accuracy'])

# %%
callbacks = [
    keras.callbacks.EarlyStopping(
        monitor="val_loss",
        min_delta=1e-2,
        patience=5,
        restore_best_weights=True,
        verbose=1,
    )
]

# %%
EPOCHS = 100
history_early = model_early.fit(Xtrain, ytrain,callbacks = callbacks, epochs=EPOCHS, batch_size=32, validation_data=(Xtest, ytest))
# Out:
# Epoch 1/100
# 1/1 [==============================] - 5s 5s/step - loss: 1.3865 - accuracy: 0.2667 - val_loss: 1.3845 - val_accuracy: 0.1905
# Epoch 2/100
# 1/1 [==============================] - 0s 119ms/step - loss: 1.3784 - accuracy: 0.4000 - val_loss: 1.3838 - val_accuracy: 0.2857
# Epoch 3/100
# 1/1 [==============================] - 0s 208ms/step - loss: 1.3710 - accuracy: 0.4667 - val_loss: 1.3832 - val_accuracy: 0.3333
# Epoch 4/100
# 1/1 [==============================] - 0s 127ms/step - loss: 1.3639 - accuracy: 0.4667 - val_loss: 1.3826 - val_accuracy: 0.3333
# Epoch 5/100
# 1/1 [==============================] - 0s 68ms/step - loss: 1.3568 - accuracy: 0.6000 - val_loss: 1.3823 - val_accuracy: 0.3333
# Epoch 6/100
# 1/1 [==============================] - ETA: 0s - loss: 1.3495 - accuracy: 0.6333Restoring model weights from the end of the best epoch: 1.
# 1/1 [==============================] - 0s 105ms/step - loss: 1.3495 - accuracy: 0.6333 - val_loss: 1.3819 - val_accuracy: 0.3333
# Epoch 6: early stopping

# %%
acc3 = history_early.history['accuracy']
val_acc3 = history_early.history['val_accuracy']
loss3 = history_early.history['loss']
val_loss3 = history_early.history['val_loss']

epochs_range = range(len(acc3))

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc3, label='Acuracia no treino')
plt.plot(epochs_range, val_acc3, label='Acuracia na validacao')
plt.legend(loc='lower right')
plt.title('Acuracia no treino na validacao')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss3, label='Perda no treino')
plt.plot(epochs_range, val_loss3, label='Perda na validacao')
plt.legend(loc='upper right')
plt.title('Perda no treino e na validacao')
plt.show()
