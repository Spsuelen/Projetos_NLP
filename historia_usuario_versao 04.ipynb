# %%
# Importando as Bibliotecas necessárias ao Projeto

import nltk
from sklearn.feature_extraction.text import TfidfVectorizer
# !python3 -m spacy download pt_core_news_lg
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.probability import FreqDist
from transformers import pipeline
from nltk.corpus import stopwords
import matplotlib.pyplot as plt
from random import choice
import seaborn as sns
import numpy as np
import pandas as pd
# %matplotlib inline
import torch
import string
import re
# Out:
# Collecting pt-core-news-lg==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/pt_core_news_lg-3.7.0/pt_core_news_lg-3.7.0-py3-none-any.whl (568.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 568.2/568.2 MB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from pt-core-news-lg==3.7.0) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (4.66.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.6.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (24.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (1.25.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.16.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.1.5)
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
# !pip install scikit-learn

from sklearn.tree import plot_tree
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow import keras
import tensorflow_hub as hub
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import shutil
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.25.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.4.0)

# %%
# Classificando o texto das Histórias de Usuário em uma categoria especifica utilizando o modelo de treinamento zero shot

classifier = pipeline("zero-shot-classification")
candidate_labels = ["testador", "suporte", "ferramenta"]
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli and revision c626438 (https://huggingface.co/facebook/bart-large-mnli).
# Using a pipeline without specifying a model name and revision in production is not recommended.

# %%
# Utilizando o modelo de Treino roberta para Identificar as entidades nomeadas

roberta = pipeline("ner", grouped_entities=True, model="joelniklaus/legal-portuguese-roberta-base")
# Out:
# Some weights of RobertaForTokenClassification were not initialized from the model checkpoint at joelniklaus/legal-portuguese-roberta-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/token_classification.py:168: UserWarning: `grouped_entities` is deprecated and will be removed in version v5.0.0, defaulted to `aggregation_strategy="simple"` instead.
#   warnings.warn(

# %%
# Criando as Histórias de Usuários (exemplos de teste para treino) e as guardando em uma lista para ser manipulada de acordo com a necessidade

historias_usuario = [
    "Como Testador eu quero um jeito mais fácil de incluir os requisitos do aplicativo na ferramenta DRL-Mobtest para criar casos de teste que cubram tudo que o aplicativo precisa fazer, sem ter que gastar muito tempo escrevendo manualmente.",
    "Como Testador eu quero uma maneira de ensinar a ferramenta DRL-Mobtest a entender os requisitos do aplicativo usando NLP para fazer com que a ferramenta gere testes automaticamente.",
    "Como Testador eu quero que a ferramenta gere casos de teste abrangentes que cubram integralmente todos os requisitos do aplicativo, assegurando que o software seja completo e funcional, sem depender exclusivamente da criação manual de casos de teste.",
    "Como Testador eu quero que a ferramenta seja integrada com outras ferramentas de gerenciamento, permitindo sincronização automática dos requisitos e facilitando o processo de criação de casos de testes.",
    "Como Testador eu quero que a ferramenta  forneça o recurso de criação de relatórios detalhados sobre a cobertura dos testes, permitindo uma análise precisa sobre sua progressão e identificação das lacunas durante sua execução.",
    "Como testador, quero uma maneira mais fácil de incluir requisitos do aplicativo para criar casos de teste abrangentes, economizando tempo na escrita manual.",
    "Como testador, desejo ensinar a ferramenta a entender os requisitos do aplicativo usando NLP para gerar testes automaticamente.",
    "Como testador, preciso que a ferramenta gere casos de teste completos e funcionais que cubram todos os requisitos do aplicativo.",
    "Como testador, quero integração com outras ferramentas de gerenciamento para sincronizar automaticamente requisitos e facilitar a criação de casos de teste.",
    "Como testador, quero relatórios detalhados sobre a cobertura dos testes para análise precisa durante a execução.",
    "Como testador, desejo que a ferramenta identifique automaticamente os casos de teste mais críticos para priorizar a análise.",
    "Como testador, preciso que a ferramenta sugira casos de teste com base em padrões de uso real do aplicativo.",
    "Como testador, quero sugestões com base em padrões de falha históricos para evitar problemas recorrentes no software.",
    "Como testador, desejo suporte à execução de testes automatizados em diferentes dispositivos e ambientes.",
    "Como testador, preciso que a ferramenta detecte automaticamente mudanças nos requisitos e ajuste os casos de teste correspondentes.",
    "Como testador, quero integração com sistemas de controle de versão para rastrear mudanças nos requisitos e no código-fonte.",
    "Como testador, desejo métricas detalhadas sobre a eficácia dos testes, incluindo taxa de cobertura e taxa de falha.",
    "Como testador, preciso de suporte à execução de testes de desempenho e escalabilidade.",
    "Como testador, quero análise automática dos resultados dos testes para relatórios detalhados sobre problemas encontrados.",
    "Como testador, desejo simular cenários de teste complexos e realistas para garantir testes próximos à realidade.",
    "Como testador, preciso de suporte à execução de testes de regressão automatizados.",
    "Como testador, quero identificação automática de casos de teste redundantes ou desnecessários.",
    "Como testador, desejo integração fácil com ferramentas de gerenciamento de projetos.",
    "Como testador, preciso de suporte à execução de testes de usabilidade.",
    "Como testador, quero que a ferramenta crie automaticamente conjuntos de dados de teste realistas.",
    "Como testador, desejo integração com ferramentas de monitoramento de desempenho em tempo real.",
    "Como testador, preciso de suporte à execução de testes de localização e internacionalização.",
    "Como testador, quero geração automática de dados de teste sintéticos.",
    "Como testador, desejo suporte à execução de testes de acessibilidade.",
    "Como testador, preciso de suporte à execução de testes de integração contínua.",
    "Como testador, quero identificação automática de casos de teste incompletos ou mal definidos.",
    "Como testador, desejo identificação automática de dependências entre casos de teste.",
    "Como testador, preciso de suporte à execução de testes de recuperação de desastres.",
    "Como testador, quero que a ferramenta identifique automaticamente casos de teste paralelizáveis.",
    "Como testador, desejo simulação de cenários de teste de carga extremamente alta.",
    "Como testador, preciso de suporte à execução de testes de compatibilidade com diferentes navegadores e dispositivos.",
    "Como testador, quero geração automática de relatórios de teste personalizados.",
    "Como testador, desejo rastreamento automático de resultados de teste ao longo do tempo.",
    "Como testador, preciso de suporte à execução de testes de regressão progressiva.",
    "Como testador, quero sugestões automáticas para aprimorar os casos de teste existentes.",
    "Como testador, desejo que a ferramenta aprenda com os resultados dos testes e melhore suas sugestões futuras.",
    "Como testador, preciso de suporte à execução de testes de segurança automatizados.",
    "Como testador, quero integração com ferramentas de análise de código estático para identificar áreas de risco.",
    "Como testador, desejo suporte à execução de testes de integração de sistema e teste de aceitação do usuário.",
    "Como testador, preciso de suporte à execução de testes de confiabilidade e disponibilidade.",
    "Como testador, quero que a ferramenta sugira casos de teste com base em modelos de qualidade de software reconhecidos.",
    "Como testador, desejo integração com ferramentas de automação de teste de interface do usuário.",
    "Como testador, preciso de suporte à execução de testes de estresse e robustez.",
    "Como testador, quero que a ferramenta sugira casos de teste para áreas de alto risco e complexidade.",
    "Como testador, desejo integração com ferramentas de gerenciamento de defeitos para rastreamento de correções.",
    "Como testador, preciso de suporte à execução de testes de usabilidade remota e teste de usuário beta.",
    "Como testador, quero que a ferramenta forneça feedback em tempo real durante a execução dos testes.",
    "Como testador, desejo integração com ferramentas de automação de infraestrutura para provisionamento e configuração automatizados.",
    "Como testador, preciso de suporte à execução de testes de comparação de desempenho para versões anteriores e atuais do aplicativo."
  ]

# %%
# Verificando as palavras que são unicas na lista de Histórias de Usuários e a diversidade Léxica encontrada

unicas = set(historias_usuario)

print("Total de palavras unicas:",len(unicas))

print("Diversidade Lexica:",len(unicas)/len(historias_usuario))
# Out:
# Total de palavras unicas: 54
# Diversidade Lexica: 1.0

# %%
#sem_pontuacao = re.findall(r'\b(^[^A-Za-z])\b', historias_usuario, re.IGNORECASE)

# %%
# Crianndo uma classe e função para o processamento de texto

class ProcessadorHistoriasUsuario:
    def __init__(self):
        nltk.download('punkt')
        nltk.download('stopwords')
        nltk.download('wordnet')
        self.lemmatizer = WordNetLemmatizer()
        self.stop_words = set(stopwords.words('portuguese'))

    def processar_historias_usuario(self, historias_usuario):
        freq_dists = []
        for historia_usuario in historias_usuario:
            tokens = word_tokenize(historia_usuario)
            tokens = [token.lower() for token in tokens if token not in string.punctuation]
            tokens = [token for token in tokens if token not in self.stop_words]
            tokens = [self.lemmatizer.lemmatize(token) for token in tokens]
            freq_dist = FreqDist(tokens)
            freq_dists.append(freq_dist)
        return freq_dists

# %%
# Criando um objeto para processar as Histórias de Usuário.

processador = ProcessadorHistoriasUsuario()
freq_dists = processador.processar_historias_usuario(historias_usuario)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# Imprime as cinco palavras comuns em cada História de Usuário

for i, freq_dist in enumerate(freq_dists):
    print(f"História de Usuário {i+1}: {freq_dist.most_common(5)}")
# Out:
# História de Usuário 1: [('aplicativo', 2), ('testador', 1), ('quero', 1), ('jeito', 1), ('fácil', 1)]
# História de Usuário 2: [('ferramenta', 2), ('testador', 1), ('quero', 1), ('maneira', 1), ('ensinar', 1)]
# História de Usuário 3: [('casos', 2), ('teste', 2), ('testador', 1), ('quero', 1), ('ferramenta', 1)]
# História de Usuário 4: [('testador', 1), ('quero', 1), ('ferramenta', 1), ('integrada', 1), ('outras', 1)]
# História de Usuário 5: [('sobre', 2), ('testador', 1), ('quero', 1), ('ferramenta', 1), ('forneça', 1)]
# História de Usuário 6: [('testador', 1), ('quero', 1), ('maneira', 1), ('fácil', 1), ('incluir', 1)]
# História de Usuário 7: [('testador', 1), ('desejo', 1), ('ensinar', 1), ('ferramenta', 1), ('entender', 1)]
# História de Usuário 8: [('testador', 1), ('preciso', 1), ('ferramenta', 1), ('gere', 1), ('casos', 1)]
# História de Usuário 9: [('testador', 1), ('quero', 1), ('integração', 1), ('outras', 1), ('ferramentas', 1)]
# História de Usuário 10: [('testador', 1), ('quero', 1), ('relatórios', 1), ('detalhados', 1), ('sobre', 1)]
# História de Usuário 11: [('testador', 1), ('desejo', 1), ('ferramenta', 1), ('identifique', 1), ('automaticamente', 1)]
# História de Usuário 12: [('testador', 1), ('preciso', 1), ('ferramenta', 1), ('sugira', 1), ('casos', 1)]
# História de Usuário 13: [('testador', 1), ('quero', 1), ('sugestões', 1), ('base', 1), ('padrões', 1)]
# História de Usuário 14: [('testador', 1), ('desejo', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 15: [('testador', 1), ('preciso', 1), ('ferramenta', 1), ('detecte', 1), ('automaticamente', 1)]
# História de Usuário 16: [('testador', 1), ('quero', 1), ('integração', 1), ('sistemas', 1), ('controle', 1)]
# História de Usuário 17: [('taxon', 2), ('testador', 1), ('desejo', 1), ('métricas', 1), ('detalhadas', 1)]
# História de Usuário 18: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 19: [('testador', 1), ('quero', 1), ('análise', 1), ('automática', 1), ('resultados', 1)]
# História de Usuário 20: [('testador', 1), ('desejo', 1), ('simular', 1), ('cenários', 1), ('teste', 1)]
# História de Usuário 21: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 22: [('testador', 1), ('quero', 1), ('identificação', 1), ('automática', 1), ('casos', 1)]
# História de Usuário 23: [('testador', 1), ('desejo', 1), ('integração', 1), ('fácil', 1), ('ferramentas', 1)]
# História de Usuário 24: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 25: [('testador', 1), ('quero', 1), ('ferramenta', 1), ('crie', 1), ('automaticamente', 1)]
# História de Usuário 26: [('testador', 1), ('desejo', 1), ('integração', 1), ('ferramentas', 1), ('monitoramento', 1)]
# História de Usuário 27: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 28: [('testador', 1), ('quero', 1), ('geração', 1), ('automática', 1), ('dado', 1)]
# História de Usuário 29: [('testador', 1), ('desejo', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 30: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 31: [('testador', 1), ('quero', 1), ('identificação', 1), ('automática', 1), ('casos', 1)]
# História de Usuário 32: [('testador', 1), ('desejo', 1), ('identificação', 1), ('automática', 1), ('dependências', 1)]
# História de Usuário 33: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 34: [('testador', 1), ('quero', 1), ('ferramenta', 1), ('identifique', 1), ('automaticamente', 1)]
# História de Usuário 35: [('testador', 1), ('desejo', 1), ('simulação', 1), ('cenários', 1), ('teste', 1)]
# História de Usuário 36: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 37: [('testador', 1), ('quero', 1), ('geração', 1), ('automática', 1), ('relatórios', 1)]
# História de Usuário 38: [('testador', 1), ('desejo', 1), ('rastreamento', 1), ('automático', 1), ('resultados', 1)]
# História de Usuário 39: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 40: [('testador', 1), ('quero', 1), ('sugestões', 1), ('automáticas', 1), ('aprimorar', 1)]
# História de Usuário 41: [('testador', 1), ('desejo', 1), ('ferramenta', 1), ('aprenda', 1), ('resultados', 1)]
# História de Usuário 42: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 43: [('testador', 1), ('quero', 1), ('integração', 1), ('ferramentas', 1), ('análise', 1)]
# História de Usuário 44: [('testador', 1), ('desejo', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 45: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 46: [('testador', 1), ('quero', 1), ('ferramenta', 1), ('sugira', 1), ('casos', 1)]
# História de Usuário 47: [('testador', 1), ('desejo', 1), ('integração', 1), ('ferramentas', 1), ('automação', 1)]
# História de Usuário 48: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 49: [('testador', 1), ('quero', 1), ('ferramenta', 1), ('sugira', 1), ('casos', 1)]
# História de Usuário 50: [('testador', 1), ('desejo', 1), ('integração', 1), ('ferramentas', 1), ('gerenciamento', 1)]
# História de Usuário 51: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 52: [('testador', 1), ('quero', 1), ('ferramenta', 1), ('forneça', 1), ('feedback', 1)]
# História de Usuário 53: [('testador', 1), ('desejo', 1), ('integração', 1), ('ferramentas', 1), ('automação', 1)]
# História de Usuário 54: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]

# %%
nome, valor = zip(*freq_dists[0].most_common(5))
fig, ax = plt.subplots(figsize=(6,5))
sns.barplot(x=np.array(nome), y=np.array(valor), ax=ax)
plt.show()

# %%
nome,valor = zip(*freq_dist.most_common(5))
fig, ax = plt.subplots(figsize=(6,5))
sns.barplot(x=np.array(nome), y=np.array(valor), ax=ax)
# Out:
# <Axes: >

# %%
for i, historia_usuario in enumerate(historias_usuario):
    result = classifier(historia_usuario, candidate_labels=candidate_labels)
    top_label = result['labels'][0]
    confidence = result['scores'][0]
    print(f"História de Usuário {i+1}: Rótulo Previsto: {top_label}, Confiança: {confidence:.2f}")
# Out:
# História de Usuário 1: Rótulo Previsto: ferramenta, Confiança: 0.70
# História de Usuário 2: Rótulo Previsto: testador, Confiança: 0.64
# História de Usuário 3: Rótulo Previsto: testador, Confiança: 0.64
# História de Usuário 4: Rótulo Previsto: testador, Confiança: 0.73
# História de Usuário 5: Rótulo Previsto: testador, Confiança: 0.70
# História de Usuário 6: Rótulo Previsto: testador, Confiança: 0.95
# História de Usuário 7: Rótulo Previsto: testador, Confiança: 0.68
# História de Usuário 8: Rótulo Previsto: testador, Confiança: 0.69
# História de Usuário 9: Rótulo Previsto: testador, Confiança: 0.87
# História de Usuário 10: Rótulo Previsto: testador, Confiança: 0.95
# História de Usuário 11: Rótulo Previsto: testador, Confiança: 0.66
# História de Usuário 12: Rótulo Previsto: testador, Confiança: 0.68
# História de Usuário 13: Rótulo Previsto: testador, Confiança: 0.94
# História de Usuário 14: Rótulo Previsto: testador, Confiança: 0.76
# História de Usuário 15: Rótulo Previsto: testador, Confiança: 0.72
# História de Usuário 16: Rótulo Previsto: testador, Confiança: 0.91
# História de Usuário 17: Rótulo Previsto: testador, Confiança: 0.95
# História de Usuário 18: Rótulo Previsto: testador, Confiança: 0.72
# História de Usuário 19: Rótulo Previsto: testador, Confiança: 0.92
# História de Usuário 20: Rótulo Previsto: testador, Confiança: 0.91
# História de Usuário 21: Rótulo Previsto: testador, Confiança: 0.82
# História de Usuário 22: Rótulo Previsto: testador, Confiança: 0.98
# História de Usuário 23: Rótulo Previsto: testador, Confiança: 0.80
# História de Usuário 24: Rótulo Previsto: testador, Confiança: 0.81
# História de Usuário 25: Rótulo Previsto: ferramenta, Confiança: 0.53
# História de Usuário 26: Rótulo Previsto: testador, Confiança: 0.80
# História de Usuário 27: Rótulo Previsto: testador, Confiança: 0.75
# História de Usuário 28: Rótulo Previsto: testador, Confiança: 0.95
# História de Usuário 29: Rótulo Previsto: testador, Confiança: 0.82
# História de Usuário 30: Rótulo Previsto: testador, Confiança: 0.80
# História de Usuário 31: Rótulo Previsto: testador, Confiança: 0.95
# História de Usuário 32: Rótulo Previsto: testador, Confiança: 0.92
# História de Usuário 33: Rótulo Previsto: testador, Confiança: 0.77
# História de Usuário 34: Rótulo Previsto: testador, Confiança: 0.61
# História de Usuário 35: Rótulo Previsto: testador, Confiança: 0.90
# História de Usuário 36: Rótulo Previsto: testador, Confiança: 0.75
# História de Usuário 37: Rótulo Previsto: testador, Confiança: 0.95
# História de Usuário 38: Rótulo Previsto: testador, Confiança: 0.94
# História de Usuário 39: Rótulo Previsto: testador, Confiança: 0.78
# História de Usuário 40: Rótulo Previsto: testador, Confiança: 0.94
# História de Usuário 41: Rótulo Previsto: testador, Confiança: 0.61
# História de Usuário 42: Rótulo Previsto: testador, Confiança: 0.82
# História de Usuário 43: Rótulo Previsto: testador, Confiança: 0.76
# História de Usuário 44: Rótulo Previsto: testador, Confiança: 0.73
# História de Usuário 45: Rótulo Previsto: testador, Confiança: 0.75
# História de Usuário 46: Rótulo Previsto: testador, Confiança: 0.80
# História de Usuário 47: Rótulo Previsto: testador, Confiança: 0.74
# História de Usuário 48: Rótulo Previsto: testador, Confiança: 0.77
# História de Usuário 49: Rótulo Previsto: testador, Confiança: 0.66
# História de Usuário 50: Rótulo Previsto: testador, Confiança: 0.77
# História de Usuário 51: Rótulo Previsto: testador, Confiança: 0.77
# História de Usuário 52: Rótulo Previsto: testador, Confiança: 0.54
# História de Usuário 53: Rótulo Previsto: testador, Confiança: 0.87
# História de Usuário 54: Rótulo Previsto: testador, Confiança: 0.70

# %%
roberta(f"Resultado: {historias_usuario}")
# Out:
# [{'entity_group': 'LABEL_0',
#   'score': 0.5693124,
#   'word': ' resultado : [',
#   'start': 0,
#   'end': 12},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5886749,
#   'word': " '",
#   'start': 13,
#   'end': 13},
#  {'entity_group': 'LABEL_0',
#   'score': 0.65764403,
#   'word': ' como testador eu quero um jeito mais facil de',
#   'start': 14,
#   'end': 58},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5374738,
#   'word': ' incluir',
#   'start': 60,
#   'end': 66},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6081387,
#   'word': ' os requisitos do aplicativo na ferramenta drl - mob',
#   'start': 68,
#   'end': 116},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5595997,
#   'word': 'test',
#   'start': 116,
#   'end': 120},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6939447,
#   'word': ' para',
#   'start': 122,
#   'end': 125},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6129328,
#   'word': ' criar casos',
#   'start': 127,
#   'end': 137},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5997368,
#   'word': ' de teste que cubram tudo que o aplicativo precisa fazer , sem ter que',
#   'start': 139,
#   'end': 206},
#  {'entity_group': 'LABEL_1',
#   'score': 0.62386686,
#   'word': ' gastar muito tempo escrevendo manualmente',
#   'start': 208,
#   'end': 248},
#  {'entity_group': 'LABEL_0',
#   'score': 0.63143903,
#   'word': ' .',
#   'start': 249,
#   'end': 249},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5329122,
#   'word': " '",
#   'start': 250,
#   'end': 250},
#  {'entity_group': 'LABEL_0',
#   'score': 0.63347626,
#   'word': ' ,',
#   'start': 251,
#   'end': 251},
#  {'entity_group': 'LABEL_1',
#   'score': 0.62385255,
#   'word': " '",
#   'start': 253,
#   'end': 253},
#  {'entity_group': 'LABEL_0',
#   'score': 0.61584044,
#   'word': ' como testador eu quero uma maneira de ensinar a ferramenta drl - mob',
#   'start': 254,
#   'end': 319},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5425053,
#   'word': 'test',
#   'start': 319,
#   'end': 323},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6432427,
#   'word': ' a entender os requisitos do aplicativo',
#   'start': 325,
#   'end': 362},
#  {'entity_group': 'LABEL_1',
#   'score': 0.61944455,
#   'word': ' usando',
#   'start': 364,
#   'end': 369},
#  {'entity_group': 'LABEL_0',
#   'score': 0.62653077,
#   'word': ' nlp para fazer com que a ferramenta',
#   'start': 371,
#   'end': 405},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5074456,
#   'word': ' gere',
#   'start': 407,
#   'end': 410},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6140736,
#   'word': ' testes automaticamente .',
#   'start': 412,
#   'end': 434},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5280715,
#   'word': " '",
#   'start': 435,
#   'end': 435},
#  {'entity_group': 'LABEL_0',
#   'score': 0.60726875,
#   'word': ' ,',
#   'start': 436,
#   'end': 436},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6578629,
#   'word': " '",
#   'start': 438,
#   'end': 438},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6018548,
#   'word': ' como testador eu quero que a ferramenta',
#   'start': 439,
#   'end': 477},
#  {'entity_group': 'LABEL_1',
#   'score': 0.53777456,
#   'word': ' gere casos',
#   'start': 479,
#   'end': 488},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6371221,
#   'word': ' de teste abrangentes que cubram integralmente todos os requisitos do aplicativo ,',
#   'start': 490,
#   'end': 569},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5087688,
#   'word': ' assegurando',
#   'start': 571,
#   'end': 581},
#  {'entity_group': 'LABEL_0',
#   'score': 0.61379886,
#   'word': ' que o',
#   'start': 583,
#   'end': 587},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5798047,
#   'word': ' software seja completo',
#   'start': 589,
#   'end': 610},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5573208,
#   'word': ' e funcional , sem',
#   'start': 612,
#   'end': 627},
#  {'entity_group': 'LABEL_1',
#   'score': 0.53392404,
#   'word': ' depender exclusivamente',
#   'start': 629,
#   'end': 651},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5484279,
#   'word': ' da',
#   'start': 653,
#   'end': 654},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6909432,
#   'word': ' criacao manual de casos',
#   'start': 656,
#   'end': 678},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5875372,
#   'word': ' de teste .',
#   'start': 680,
#   'end': 688},
#  {'entity_group': 'LABEL_1',
#   'score': 0.546372,
#   'word': " '",
#   'start': 689,
#   'end': 689},
#  {'entity_group': 'LABEL_0',
#   'score': 0.58802855,
#   'word': ' ,',
#   'start': 690,
#   'end': 690},
#  {'entity_group': 'LABEL_1',
#   'score': 0.67409056,
#   'word': " '",
#   'start': 692,
#   'end': 692},
#  {'entity_group': 'LABEL_0',
#   'score': 0.59661394,
#   'word': ' como tes',
#   'start': 693,
#   'end': 700},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5007072,
#   'word': 'tador',
#   'start': 700,
#   'end': 705},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5636304,
#   'word': ' eu quero que a ferramenta',
#   'start': 707,
#   'end': 731},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5131197,
#   'word': ' seja',
#   'start': 733,
#   'end': 736},
#  {'entity_group': 'LABEL_0',
#   'score': 0.57924175,
#   'word': ' integrada com outras',
#   'start': 738,
#   'end': 757},
#  {'entity_group': 'LABEL_1',
#   'score': 0.63522816,
#   'word': ' ferramentas',
#   'start': 759,
#   'end': 769},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6000371,
#   'word': ' de',
#   'start': 771,
#   'end': 772},
#  {'entity_group': 'LABEL_1',
#   'score': 0.65224123,
#   'word': ' gerenciamento',
#   'start': 774,
#   'end': 786},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5629147,
#   'word': ' ,',
#   'start': 787,
#   'end': 787},
#  {'entity_group': 'LABEL_1',
#   'score': 0.664452,
#   'word': ' permitindo sincronizacao automatica',
#   'start': 789,
#   'end': 823},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6021327,
#   'word': ' dos requisitos e facilitando o processo de',
#   'start': 825,
#   'end': 866},
#  {'entity_group': 'LABEL_1',
#   'score': 0.733015,
#   'word': ' criacao',
#   'start': 868,
#   'end': 874},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5462534,
#   'word': ' de',
#   'start': 876,
#   'end': 877},
#  {'entity_group': 'LABEL_1',
#   'score': 0.57891166,
#   'word': ' casos',
#   'start': 879,
#   'end': 883},
#  {'entity_group': 'LABEL_0',
#   'score': 0.63830787,
#   'word': ' de testes .',
#   'start': 885,
#   'end': 894},
#  {'entity_group': 'LABEL_1',
#   'score': 0.52589905,
#   'word': " '",
#   'start': 895,
#   'end': 895},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5822244,
#   'word': ' ,',
#   'start': 896,
#   'end': 896},
#  {'entity_group': 'LABEL_1',
#   'score': 0.67964196,
#   'word': " '",
#   'start': 898,
#   'end': 898},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5629399,
#   'word': ' como testador eu',
#   'start': 899,
#   'end': 914},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5215498,
#   'word': ' que',
#   'start': 916,
#   'end': 918},
#  {'entity_group': 'LABEL_0',
#   'score': 0.56491566,
#   'word': 'ro que a ferramenta',
#   'start': 918,
#   'end': 937},
#  {'entity_group': 'LABEL_1',
#   'score': 0.59063244,
#   'word': ' forneca',
#   'start': 940,
#   'end': 946},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5350502,
#   'word': ' o',
#   'start': 948,
#   'end': 948},
#  {'entity_group': 'LABEL_1',
#   'score': 0.59197503,
#   'word': ' recurso',
#   'start': 950,
#   'end': 956},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5580104,
#   'word': ' de',
#   'start': 958,
#   'end': 959},
#  {'entity_group': 'LABEL_1',
#   'score': 0.67615443,
#   'word': ' criacao de relatorios',
#   'start': 961,
#   'end': 981},
#  {'entity_group': 'LABEL_0',
#   'score': 0.50417453,
#   'word': ' detalhados',
#   'start': 983,
#   'end': 992},
#  {'entity_group': 'LABEL_1',
#   'score': 0.559225,
#   'word': ' sobre',
#   'start': 994,
#   'end': 998},
#  {'entity_group': 'LABEL_0',
#   'score': 0.55403197,
#   'word': ' a',
#   'start': 1000,
#   'end': 1000},
#  {'entity_group': 'LABEL_1',
#   'score': 0.59234774,
#   'word': ' cobertura',
#   'start': 1002,
#   'end': 1010},
#  {'entity_group': 'LABEL_0',
#   'score': 0.552397,
#   'word': ' dos testes ,',
#   'start': 1012,
#   'end': 1022},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5474736,
#   'word': ' permitindo uma analise',
#   'start': 1024,
#   'end': 1045},
#  {'entity_group': 'LABEL_0',
#   'score': 0.51508754,
#   'word': ' precisa',
#   'start': 1047,
#   'end': 1053},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5890673,
#   'word': ' sobre sua progressao e identificacao das lacunas durante sua execucao',
#   'start': 1055,
#   'end': 1123},
#  {'entity_group': 'LABEL_0',
#   'score': 0.59239405,
#   'word': ' .',
#   'start': 1124,
#   'end': 1124},
#  {'entity_group': 'LABEL_1',
#   'score': 0.56393945,
#   'word': " '",
#   'start': 1125,
#   'end': 1125},
#  {'entity_group': 'LABEL_0',
#   'score': 0.55079293,
#   'word': ' ,',
#   'start': 1126,
#   'end': 1126},
#  {'entity_group': 'LABEL_1',
#   'score': 0.673817,
#   'word': " '",
#   'start': 1128,
#   'end': 1128},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5890672,
#   'word': ' como tes',
#   'start': 1129,
#   'end': 1136},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5048821,
#   'word': 'tador',
#   'start': 1136,
#   'end': 1141},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6904217,
#   'word': ' ,',
#   'start': 1142,
#   'end': 1142},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5237839,
#   'word': ' que',
#   'start': 1144,
#   'end': 1146},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6386181,
#   'word': 'ro uma maneira mais facil de',
#   'start': 1146,
#   'end': 1174},
#  {'entity_group': 'LABEL_1',
#   'score': 0.53778195,
#   'word': ' incluir',
#   'start': 1176,
#   'end': 1182},
#  {'entity_group': 'LABEL_0',
#   'score': 0.58482397,
#   'word': ' requisitos do aplicativo para',
#   'start': 1184,
#   'end': 1212},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6359638,
#   'word': ' criar casos',
#   'start': 1214,
#   'end': 1224},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6500077,
#   'word': ' de teste abrangentes',
#   'start': 1226,
#   'end': 1245},
#  {'entity_group': 'LABEL_1',
#   'score': 0.59361523,
#   'word': ' , economizando',
#   'start': 1246,
#   'end': 1259},
#  {'entity_group': 'LABEL_0',
#   'score': 0.53543675,
#   'word': ' tempo na',
#   'start': 1261,
#   'end': 1268},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6982201,
#   'word': ' escrita manual',
#   'start': 1270,
#   'end': 1283},
#  {'entity_group': 'LABEL_0',
#   'score': 0.56597525,
#   'word': ' .',
#   'start': 1284,
#   'end': 1284},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5521938,
#   'word': " '",
#   'start': 1285,
#   'end': 1285},
#  {'entity_group': 'LABEL_0',
#   'score': 0.56164193,
#   'word': ' ,',
#   'start': 1286,
#   'end': 1286},
#  {'entity_group': 'LABEL_1',
#   'score': 0.67363507,
#   'word': " '",
#   'start': 1288,
#   'end': 1288},
#  {'entity_group': 'LABEL_0',
#   'score': 0.56296206,
#   'word': ' como tes',
#   'start': 1289,
#   'end': 1296},
#  {'entity_group': 'LABEL_1',
#   'score': 0.54437506,
#   'word': 'tador',
#   'start': 1296,
#   'end': 1301},
#  {'entity_group': 'LABEL_0',
#   'score': 0.60441726,
#   'word': ' , desejo ensinar a ferramenta a entender os requisitos do aplicativo',
#   'start': 1302,
#   'end': 1369},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5983664,
#   'word': ' usando',
#   'start': 1371,
#   'end': 1376},
#  {'entity_group': 'LABEL_0',
#   'score': 0.59692574,
#   'word': ' nlp para',
#   'start': 1378,
#   'end': 1385},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6843531,
#   'word': ' gerar',
#   'start': 1387,
#   'end': 1391},
#  {'entity_group': 'LABEL_0',
#   'score': 0.59371054,
#   'word': ' testes',
#   'start': 1393,
#   'end': 1398},
#  {'entity_group': 'LABEL_1',
#   'score': 0.50190717,
#   'word': ' automaticamente',
#   'start': 1400,
#   'end': 1414},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5520361,
#   'word': ' .',
#   'start': 1415,
#   'end': 1415},
#  {'entity_group': 'LABEL_1',
#   'score': 0.55741996,
#   'word': " '",
#   'start': 1416,
#   'end': 1416},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5701178,
#   'word': ' ,',
#   'start': 1417,
#   'end': 1417},
#  {'entity_group': 'LABEL_1',
#   'score': 0.64577776,
#   'word': " '",
#   'start': 1419,
#   'end': 1419},
#  {'entity_group': 'LABEL_0',
#   'score': 0.58056915,
#   'word': ' como tes',
#   'start': 1420,
#   'end': 1427},
#  {'entity_group': 'LABEL_1',
#   'score': 0.51445884,
#   'word': 'tador',
#   'start': 1427,
#   'end': 1432},
#  {'entity_group': 'LABEL_0',
#   'score': 0.59810823,
#   'word': ' ,',
#   'start': 1433,
#   'end': 1433},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5037029,
#   'word': ' preciso',
#   'start': 1435,
#   'end': 1441},
#  {'entity_group': 'LABEL_0',
#   'score': 0.635651,
#   'word': ' que a ferramenta',
#   'start': 1443,
#   'end': 1458},
#  {'entity_group': 'LABEL_1',
#   'score': 0.56046116,
#   'word': ' gere casos',
#   'start': 1460,
#   'end': 1469},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6808883,
#   'word': ' de teste',
#   'start': 1471,
#   'end': 1478},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5002677,
#   'word': ' completos',
#   'start': 1480,
#   'end': 1488},
#  {'entity_group': 'LABEL_0',
#   'score': 0.62838125,
#   'word': ' e funcionais que cubram todos os requisitos do aplicativo .',
#   'start': 1490,
#   'end': 1547},
#  {'entity_group': 'LABEL_1',
#   'score': 0.53911877,
#   'word': " '",
#   'start': 1548,
#   'end': 1548},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5708026,
#   'word': ' ,',
#   'start': 1549,
#   'end': 1549},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6329172,
#   'word': " '",
#   'start': 1551,
#   'end': 1551},
#  {'entity_group': 'LABEL_0',
#   'score': 0.59196436,
#   'word': ' como testador ,',
#   'start': 1552,
#   'end': 1565},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5434584,
#   'word': ' que',
#   'start': 1567,
#   'end': 1569},
#  {'entity_group': 'LABEL_0',
#   'score': 0.58756346,
#   'word': 'ro integracao com outras',
#   'start': 1569,
#   'end': 1593},
#  {'entity_group': 'LABEL_1',
#   'score': 0.628423,
#   'word': ' ferramentas',
#   'start': 1595,
#   'end': 1605},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5855067,
#   'word': ' de',
#   'start': 1607,
#   'end': 1608},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6728829,
#   'word': ' gerenciamento',
#   'start': 1610,
#   'end': 1622},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5447077,
#   'word': ' para',
#   'start': 1624,
#   'end': 1627},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6016169,
#   'word': ' sincronizar automaticamente',
#   'start': 1629,
#   'end': 1655},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5586478,
#   'word': ' requisitos e',
#   'start': 1657,
#   'end': 1668},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5404523,
#   'word': ' facilitar',
#   'start': 1670,
#   'end': 1678},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6541826,
#   'word': ' a',
#   'start': 1680,
#   'end': 1680},
#  {'entity_group': 'LABEL_1',
#   'score': 0.624749,
#   'word': ' criacao de casos',
#   'start': 1682,
#   'end': 1697},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6039236,
#   'word': ' de teste .',
#   'start': 1699,
#   'end': 1707},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5389593,
#   'word': " '",
#   'start': 1708,
#   'end': 1708},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5662134,
#   'word': ' ,',
#   'start': 1709,
#   'end': 1709},
#  {'entity_group': 'LABEL_1',
#   'score': 0.64775944,
#   'word': " '",
#   'start': 1711,
#   'end': 1711},
#  {'entity_group': 'LABEL_0',
#   'score': 0.58562315,
#   'word': ' como testador ,',
#   'start': 1712,
#   'end': 1725},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5710695,
#   'word': ' que',
#   'start': 1727,
#   'end': 1729},
#  {'entity_group': 'LABEL_0',
#   'score': 0.50798315,
#   'word': 'ro',
#   'start': 1729,
#   'end': 1731},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5918959,
#   'word': ' relatorios',
#   'start': 1733,
#   'end': 1742},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5165479,
#   'word': ' detalhados',
#   'start': 1744,
#   'end': 1753},
#  {'entity_group': 'LABEL_1',
#   'score': 0.50147414,
#   'word': ' sobre',
#   'start': 1755,
#   'end': 1759},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5833299,
#   'word': ' a',
#   'start': 1761,
#   'end': 1761},
#  {'entity_group': 'LABEL_1',
#   'score': 0.56630945,
#   'word': ' cobertura',
#   'start': 1763,
#   'end': 1771},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6093358,
#   'word': ' dos testes para analise precisa durante a',
#   'start': 1773,
#   'end': 1813},
#  {'entity_group': 'LABEL_1',
#   'score': 0.56828153,
#   'word': ' execucao',
#   'start': 1815,
#   'end': 1822},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5762476,
#   'word': ' .',
#   'start': 1823,
#   'end': 1823},
#  {'entity_group': 'LABEL_1',
#   'score': 0.53988093,
#   'word': " '",
#   'start': 1824,
#   'end': 1824},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5686964,
#   'word': ' ,',
#   'start': 1825,
#   'end': 1825},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6331965,
#   'word': " '",
#   'start': 1827,
#   'end': 1827},
#  {'entity_group': 'LABEL_0',
#   'score': 0.62024146,
#   'word': ' como testador , desejo que a ferramenta identifique',
#   'start': 1828,
#   'end': 1877},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5136213,
#   'word': ' automaticamente',
#   'start': 1879,
#   'end': 1893},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5835683,
#   'word': ' os',
#   'start': 1895,
#   'end': 1896},
#  {'entity_group': 'LABEL_1',
#   'score': 0.56079763,
#   'word': ' casos',
#   'start': 1898,
#   'end': 1902},
#  {'entity_group': 'LABEL_0',
#   'score': 0.59768885,
#   'word': ' de teste mais criticos para priori',
#   'start': 1904,
#   'end': 1937},
#  {'entity_group': 'LABEL_1',
#   'score': 0.60844314,
#   'word': 'zar',
#   'start': 1937,
#   'end': 1940},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6139691,
#   'word': ' a analise .',
#   'start': 1942,
#   'end': 1951},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5227183,
#   'word': " '",
#   'start': 1952,
#   'end': 1952},
#  {'entity_group': 'LABEL_0',
#   'score': 0.56198615,
#   'word': ' ,',
#   'start': 1953,
#   'end': 1953},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6519575,
#   'word': " '",
#   'start': 1955,
#   'end': 1955},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5648886,
#   'word': ' como tes',
#   'start': 1956,
#   'end': 1963},
#  {'entity_group': 'LABEL_1',
#   'score': 0.50624645,
#   'word': 'tador',
#   'start': 1963,
#   'end': 1968},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6192808,
#   'word': ' ,',
#   'start': 1969,
#   'end': 1969},
#  {'entity_group': 'LABEL_1',
#   'score': 0.50168073,
#   'word': ' preciso',
#   'start': 1971,
#   'end': 1977},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5843176,
#   'word': ' que a ferramenta su',
#   'start': 1979,
#   'end': 1997},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5665674,
#   'word': 'gira casos',
#   'start': 1997,
#   'end': 2007},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6493993,
#   'word': ' de teste com',
#   'start': 2009,
#   'end': 2020},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5125141,
#   'word': ' base',
#   'start': 2022,
#   'end': 2025},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6282289,
#   'word': ' em padroes de',
#   'start': 2027,
#   'end': 2039},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5477555,
#   'word': ' uso real',
#   'start': 2041,
#   'end': 2048},
#  {'entity_group': 'LABEL_0',
#   'score': 0.55818355,
#   'word': ' do aplicativo .',
#   'start': 2050,
#   'end': 2063},
#  {'entity_group': 'LABEL_1',
#   'score': 0.526452,
#   'word': " '",
#   'start': 2064,
#   'end': 2064},
#  {'entity_group': 'LABEL_0',
#   'score': 0.57241553,
#   'word': ' ,',
#   'start': 2065,
#   'end': 2065},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6286147,
#   'word': " '",
#   'start': 2067,
#   'end': 2067},
#  {'entity_group': 'LABEL_0',
#   'score': 0.60471916,
#   'word': ' como testador ,',
#   'start': 2068,
#   'end': 2081},
#  {'entity_group': 'LABEL_1',
#   'score': 0.52543235,
#   'word': ' que',
#   'start': 2083,
#   'end': 2085},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5336226,
#   'word': 'ro',
#   'start': 2085,
#   'end': 2087},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5823297,
#   'word': ' sugestoes',
#   'start': 2089,
#   'end': 2097},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6271436,
#   'word': ' com base em padroes de falha historicos para',
#   'start': 2099,
#   'end': 2142},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5017776,
#   'word': ' evitar',
#   'start': 2144,
#   'end': 2149},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5625418,
#   'word': ' problemas',
#   'start': 2151,
#   'end': 2159},
#  {'entity_group': 'LABEL_1',
#   'score': 0.59766954,
#   'word': ' recorrentes',
#   'start': 2161,
#   'end': 2171},
#  {'entity_group': 'LABEL_0',
#   'score': 0.57168216,
#   'word': ' no',
#   'start': 2173,
#   'end': 2174},
#  {'entity_group': 'LABEL_1',
#   'score': 0.61623544,
#   'word': ' software',
#   'start': 2176,
#   'end': 2183},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5719753,
#   'word': ' .',
#   'start': 2184,
#   'end': 2184},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5316058,
#   'word': " '",
#   'start': 2185,
#   'end': 2185},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5729002,
#   'word': ' ,',
#   'start': 2186,
#   'end': 2186},
#  {'entity_group': 'LABEL_1',
#   'score': 0.64902925,
#   'word': " '",
#   'start': 2188,
#   'end': 2188},
#  {'entity_group': 'LABEL_0',
#   'score': 0.56853557,
#   'word': ' como tes',
#   'start': 2189,
#   'end': 2196},
#  {'entity_group': 'LABEL_1',
#   'score': 0.51530975,
#   'word': 'tador',
#   'start': 2196,
#   'end': 2201},
#  {'entity_group': 'LABEL_0',
#   'score': 0.57186115,
#   'word': ' , desejo',
#   'start': 2202,
#   'end': 2209},
#  {'entity_group': 'LABEL_1',
#   'score': 0.53991157,
#   'word': ' suporte',
#   'start': 2211,
#   'end': 2217},
#  {'entity_group': 'LABEL_0',
#   'score': 0.51209503,
#   'word': ' a',
#   'start': 2219,
#   'end': 2219},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6959657,
#   'word': ' execucao',
#   'start': 2221,
#   'end': 2228},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5749006,
#   'word': ' de testes',
#   'start': 2230,
#   'end': 2238},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5337406,
#   'word': ' automatizados',
#   'start': 2240,
#   'end': 2252},
#  {'entity_group': 'LABEL_0',
#   'score': 0.58805054,
#   'word': ' em',
#   'start': 2254,
#   'end': 2255},
#  {'entity_group': 'LABEL_1',
#   'score': 0.55214846,
#   'word': ' diferentes dispositivos',
#   'start': 2257,
#   'end': 2279},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5653381,
#   'word': ' e ambientes .',
#   'start': 2281,
#   'end': 2292},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5446922,
#   'word': " '",
#   'start': 2293,
#   'end': 2293},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5735723,
#   'word': ' ,',
#   'start': 2294,
#   'end': 2294},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6686086,
#   'word': " '",
#   'start': 2296,
#   'end': 2296},
#  {'entity_group': 'LABEL_0',
#   'score': 0.58635044,
#   'word': ' como',
#   'start': 2297,
#   'end': 2300},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5218643,
#   'word': ' testador',
#   'start': 2302,
#   'end': 2309},
#  {'entity_group': 'LABEL_0',
#   'score': 0.58742577,
#   'word': ' ,',
#   'start': 2310,
#   'end': 2310},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5351826,
#   'word': ' preciso',
#   'start': 2312,
#   'end': 2318},
#  {'entity_group': 'LABEL_0',
#   'score': 0.56542295,
#   'word': ' que a ferramenta dete',
#   'start': 2320,
#   'end': 2340},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5906144,
#   'word': 'cte automaticamente mudancas',
#   'start': 2340,
#   'end': 2368},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5725864,
#   'word': ' nos requisitos',
#   'start': 2370,
#   'end': 2383},
#  {'entity_group': 'LABEL_1',
#   'score': 0.61011606,
#   'word': ' e ajuste os casos',
#   'start': 2385,
#   'end': 2401},
#  {'entity_group': 'LABEL_0',
#   'score': 0.58366424,
#   'word': ' de teste',
#   'start': 2403,
#   'end': 2410},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6278249,
#   'word': ' correspondentes',
#   'start': 2412,
#   'end': 2426},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5516163,
#   'word': ' .',
#   'start': 2427,
#   'end': 2427},
#  {'entity_group': 'LABEL_1',
#   'score': 0.549263,
#   'word': " '",
#   'start': 2428,
#   'end': 2428},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5829492,
#   'word': ' ,',
#   'start': 2429,
#   'end': 2429},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6032353,
#   'word': " '",
#   'start': 2431,
#   'end': 2431},
#  {'entity_group': 'LABEL_0',
#   'score': 0.60484624,
#   'word': ' como testador ,',
#   'start': 2432,
#   'end': 2445},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5192799,
#   'word': ' que',
#   'start': 2447,
#   'end': 2449},
#  {'entity_group': 'LABEL_0',
#   'score': 0.62088174,
#   'word': 'ro integracao com',
#   'start': 2449,
#   'end': 2466},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5436365,
#   'word': ' sistemas',
#   'start': 2468,
#   'end': 2475},
#  {'entity_group': 'LABEL_0',
#   'score': 0.63169134,
#   'word': ' de',
#   'start': 2477,
#   'end': 2478},
#  {'entity_group': 'LABEL_1',
#   'score': 0.66728616,
#   'word': ' controle',
#   'start': 2480,
#   'end': 2487},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5243442,
#   'word': ' de versao para',
#   'start': 2489,
#   'end': 2502},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6079256,
#   'word': ' rastrear mudancas',
#   'start': 2504,
#   'end': 2520},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5883752,
#   'word': ' nos requisitos',
#   'start': 2522,
#   'end': 2535},
#  {'entity_group': 'LABEL_1',
#   'score': 0.506816,
#   'word': ' e',
#   'start': 2537,
#   'end': 2537},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5218239,
#   'word': ' no',
#   'start': 2539,
#   'end': 2540}]

# %%
for i, historia_usuario in enumerate(historias_usuario):
    result = roberta(f"História de Usuário {i+1}: {historia_usuario}")
    print(f"Resultado para História de Usuário {i+1}: {result}")
# Out:
# Resultado para História de Usuário 1: [{'entity_group': 'LABEL_1', 'score': 0.51378, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.72277004, 'word': ' de', 'start': 10, 'end': 11}, {'entity_group': 'LABEL_1', 'score': 0.5156764, 'word': ' usuario 1', 'start': 13, 'end': 21}, {'entity_group': 'LABEL_0', 'score': 0.67364395, 'word': ' : como testador eu quero um jeito mais facil de incluir os requisitos do aplicativo na ferramenta drl - mobtest para criar casos de teste que cubram tudo que o aplicativo precisa fazer , sem ter que', 'start': 22, 'end': 216}, {'entity_group': 'LABEL_1', 'score': 0.59217024, 'word': ' gas', 'start': 218, 'end': 220}, {'entity_group': 'LABEL_0', 'score': 0.5482206, 'word': 'tar muito tempo', 'start': 220, 'end': 235}, {'entity_group': 'LABEL_1', 'score': 0.5939686, 'word': ' escrevendo manualmente', 'start': 237, 'end': 258}, {'entity_group': 'LABEL_0', 'score': 0.5649023, 'word': ' .', 'start': 259, 'end': 259}]
# Resultado para História de Usuário 2: [{'entity_group': 'LABEL_1', 'score': 0.5188577, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.6763385, 'word': ' de usuario 2 : como testador eu quero uma maneira de ensinar a ferramenta drl - mobtest a entender os requisitos do aplicativo usando nlp para fazer com que a ferramenta gere testes automaticamente', 'start': 10, 'end': 203}, {'entity_group': 'LABEL_1', 'score': 0.56202585, 'word': ' .', 'start': 204, 'end': 204}]
# Resultado para História de Usuário 3: [{'entity_group': 'LABEL_1', 'score': 0.58715105, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.6695148, 'word': ' de usuario 3 : como testador eu quero que a ferramenta gere casos de teste abrangentes que cubram integralmente todos os requisitos do aplica', 'start': 10, 'end': 149}, {'entity_group': 'LABEL_1', 'score': 0.5185412, 'word': 'tivo', 'start': 149, 'end': 153}, {'entity_group': 'LABEL_0', 'score': 0.62681484, 'word': ' , assegurando que o', 'start': 154, 'end': 172}, {'entity_group': 'LABEL_1', 'score': 0.5269059, 'word': ' software', 'start': 174, 'end': 181}, {'entity_group': 'LABEL_0', 'score': 0.6192237, 'word': ' seja completo e funcional , sem depender exclusivamente da', 'start': 183, 'end': 239}, {'entity_group': 'LABEL_1', 'score': 0.6028353, 'word': ' criacao manual', 'start': 241, 'end': 254}, {'entity_group': 'LABEL_0', 'score': 0.60417885, 'word': ' de casos de teste .', 'start': 256, 'end': 273}]
# Resultado para História de Usuário 4: [{'entity_group': 'LABEL_1', 'score': 0.5198256, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.61544377, 'word': ' de usuario', 'start': 10, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.5708305, 'word': ' 4', 'start': 21, 'end': 21}, {'entity_group': 'LABEL_0', 'score': 0.6683989, 'word': ' : como testador eu quero que a ferramenta seja integrada com outras ferramentas de', 'start': 22, 'end': 103}, {'entity_group': 'LABEL_1', 'score': 0.59522194, 'word': ' gerenciamento', 'start': 105, 'end': 117}, {'entity_group': 'LABEL_0', 'score': 0.6359463, 'word': ' , permitindo', 'start': 118, 'end': 129}, {'entity_group': 'LABEL_1', 'score': 0.5366156, 'word': ' sincronizacao automatica', 'start': 131, 'end': 154}, {'entity_group': 'LABEL_0', 'score': 0.6767076, 'word': ' dos requisitos e facilitando o processo de', 'start': 156, 'end': 197}, {'entity_group': 'LABEL_1', 'score': 0.50135916, 'word': ' criacao', 'start': 199, 'end': 205}, {'entity_group': 'LABEL_0', 'score': 0.6441058, 'word': ' de casos de testes .', 'start': 207, 'end': 225}]
# Resultado para História de Usuário 5: [{'entity_group': 'LABEL_0', 'score': 0.65259755, 'word': ' historia de usuario 5 : como testador eu quero que a ferramenta forneca o recurso de', 'start': 0, 'end': 84}, {'entity_group': 'LABEL_1', 'score': 0.6442601, 'word': ' criacao', 'start': 86, 'end': 92}, {'entity_group': 'LABEL_0', 'score': 0.6272166, 'word': ' de relatorios detalhados sobre a cobertura dos testes , permitindo uma analise precisa sobre sua progressao e identificacao das lacunas durante sua execucao .', 'start': 94, 'end': 249}]
# Resultado para História de Usuário 6: [{'entity_group': 'LABEL_1', 'score': 0.55376524, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.65778726, 'word': ' de usuario 6 : como tes', 'start': 10, 'end': 31}, {'entity_group': 'LABEL_1', 'score': 0.5071694, 'word': 'tador', 'start': 31, 'end': 36}, {'entity_group': 'LABEL_0', 'score': 0.7044758, 'word': ' , quero uma maneira mais facil de incluir requisitos do aplica', 'start': 37, 'end': 98}, {'entity_group': 'LABEL_1', 'score': 0.5184895, 'word': 'tivo', 'start': 98, 'end': 102}, {'entity_group': 'LABEL_0', 'score': 0.64139396, 'word': ' para criar casos de teste abrangentes , economizando tempo na', 'start': 104, 'end': 163}, {'entity_group': 'LABEL_1', 'score': 0.51820856, 'word': ' escrita', 'start': 165, 'end': 171}, {'entity_group': 'LABEL_0', 'score': 0.56102794, 'word': ' manual .', 'start': 173, 'end': 179}]
# Resultado para História de Usuário 7: [{'entity_group': 'LABEL_1', 'score': 0.5442408, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.61949545, 'word': ' de usuario', 'start': 10, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.52564293, 'word': ' 7', 'start': 21, 'end': 21}, {'entity_group': 'LABEL_0', 'score': 0.67439616, 'word': ' : como testador , desejo ensinar a ferramenta a entender os requisitos do aplicativo usando nlp para', 'start': 22, 'end': 120}, {'entity_group': 'LABEL_1', 'score': 0.54279554, 'word': ' gerar', 'start': 122, 'end': 126}, {'entity_group': 'LABEL_0', 'score': 0.59642404, 'word': ' testes automaticamente .', 'start': 128, 'end': 150}]
# Resultado para História de Usuário 8: [{'entity_group': 'LABEL_1', 'score': 0.5745348, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.6139895, 'word': ' de usuario', 'start': 10, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.5521969, 'word': ' 8', 'start': 21, 'end': 21}, {'entity_group': 'LABEL_0', 'score': 0.7066047, 'word': ' : como tes', 'start': 22, 'end': 31}, {'entity_group': 'LABEL_1', 'score': 0.5096525, 'word': 'tador', 'start': 31, 'end': 36}, {'entity_group': 'LABEL_0', 'score': 0.68898976, 'word': ' , preciso que a ferramenta gere casos de teste completos e funcionais que cubram todos os requisitos do aplica', 'start': 37, 'end': 146}, {'entity_group': 'LABEL_1', 'score': 0.51711094, 'word': 'tivo', 'start': 146, 'end': 150}, {'entity_group': 'LABEL_0', 'score': 0.6006548, 'word': ' .', 'start': 151, 'end': 151}]
# Resultado para História de Usuário 9: [{'entity_group': 'LABEL_1', 'score': 0.5369588, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.5961311, 'word': ' de usuario', 'start': 10, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.52077466, 'word': ' 9', 'start': 21, 'end': 21}, {'entity_group': 'LABEL_0', 'score': 0.6757047, 'word': ' : como tes', 'start': 22, 'end': 31}, {'entity_group': 'LABEL_1', 'score': 0.5006164, 'word': 'tador', 'start': 31, 'end': 36}, {'entity_group': 'LABEL_0', 'score': 0.67063314, 'word': ' , quero integracao com outras ferramentas de', 'start': 37, 'end': 80}, {'entity_group': 'LABEL_1', 'score': 0.60867393, 'word': ' gerenciamento', 'start': 82, 'end': 94}, {'entity_group': 'LABEL_0', 'score': 0.5855236, 'word': ' para sincronizar automaticamente requisitos e facilitar a', 'start': 96, 'end': 152}, {'entity_group': 'LABEL_1', 'score': 0.5781838, 'word': ' criacao', 'start': 154, 'end': 160}, {'entity_group': 'LABEL_0', 'score': 0.64732325, 'word': ' de casos de teste .', 'start': 162, 'end': 179}]
# Resultado para História de Usuário 10: [{'entity_group': 'LABEL_1', 'score': 0.51493394, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.63041246, 'word': ' de usuario 10 : como testador , quero relatorios detalhados sobre a', 'start': 10, 'end': 74}, {'entity_group': 'LABEL_1', 'score': 0.5028598, 'word': ' cobertura', 'start': 76, 'end': 84}, {'entity_group': 'LABEL_0', 'score': 0.68622005, 'word': ' dos testes para analise precisa durante a execucao .', 'start': 86, 'end': 136}]
# Resultado para História de Usuário 11: [{'entity_group': 'LABEL_1', 'score': 0.53883266, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.63722795, 'word': ' de usuario 11 : como testador , desejo que a ferramenta identifique automaticamente os casos de teste mais criticos para priorizar a analise .', 'start': 10, 'end': 148}]
# Resultado para História de Usuário 12: [{'entity_group': 'LABEL_1', 'score': 0.5013467, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.59879416, 'word': ' de usuario', 'start': 10, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.5255698, 'word': ' 12', 'start': 21, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.70343876, 'word': ' : como tes', 'start': 23, 'end': 32}, {'entity_group': 'LABEL_1', 'score': 0.52286357, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_0', 'score': 0.68803, 'word': ' , preciso que a ferramenta sugira casos de teste com base em padroes de uso real do aplica', 'start': 38, 'end': 127}, {'entity_group': 'LABEL_1', 'score': 0.56593066, 'word': 'tivo', 'start': 127, 'end': 131}, {'entity_group': 'LABEL_0', 'score': 0.6273457, 'word': ' .', 'start': 132, 'end': 132}]
# Resultado para História de Usuário 13: [{'entity_group': 'LABEL_1', 'score': 0.58756024, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.67443836, 'word': ' de', 'start': 10, 'end': 11}, {'entity_group': 'LABEL_1', 'score': 0.51589364, 'word': ' usuario 13', 'start': 13, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.67856616, 'word': ' : como tes', 'start': 23, 'end': 32}, {'entity_group': 'LABEL_1', 'score': 0.5173312, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_0', 'score': 0.6614672, 'word': ' , quero sugestoes com base em padroes de falha historicos para evitar problemas recorrentes no', 'start': 38, 'end': 131}, {'entity_group': 'LABEL_1', 'score': 0.5853311, 'word': ' software', 'start': 133, 'end': 140}, {'entity_group': 'LABEL_0', 'score': 0.701184, 'word': ' .', 'start': 141, 'end': 141}]
# Resultado para História de Usuário 14: [{'entity_group': 'LABEL_1', 'score': 0.53141725, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.61171466, 'word': ' de usuario', 'start': 10, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.63853645, 'word': ' 14', 'start': 21, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.6436559, 'word': ' : como testador , desejo suporte a', 'start': 23, 'end': 55}, {'entity_group': 'LABEL_1', 'score': 0.5119495, 'word': ' execucao', 'start': 57, 'end': 64}, {'entity_group': 'LABEL_0', 'score': 0.70230854, 'word': ' de testes automatizados em diferentes', 'start': 66, 'end': 102}, {'entity_group': 'LABEL_1', 'score': 0.5089816, 'word': ' dispositivos', 'start': 104, 'end': 115}, {'entity_group': 'LABEL_0', 'score': 0.6487729, 'word': ' e ambientes .', 'start': 117, 'end': 128}]
# Resultado para História de Usuário 15: [{'entity_group': 'LABEL_1', 'score': 0.5409753, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.61111605, 'word': ' de usuario', 'start': 10, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.5984275, 'word': ' 15', 'start': 21, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.68298244, 'word': ' : como tes', 'start': 23, 'end': 32}, {'entity_group': 'LABEL_1', 'score': 0.5064329, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_0', 'score': 0.6320828, 'word': ' , preciso que a ferramenta detecte automaticamente mudancas nos requisitos e', 'start': 38, 'end': 113}, {'entity_group': 'LABEL_1', 'score': 0.604248, 'word': ' ajuste', 'start': 115, 'end': 120}, {'entity_group': 'LABEL_0', 'score': 0.66283613, 'word': ' os casos de teste', 'start': 122, 'end': 138}, {'entity_group': 'LABEL_1', 'score': 0.5147659, 'word': ' correspondentes', 'start': 140, 'end': 154}, {'entity_group': 'LABEL_0', 'score': 0.61816555, 'word': ' .', 'start': 155, 'end': 155}]
# Resultado para História de Usuário 16: [{'entity_group': 'LABEL_1', 'score': 0.58713895, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.6093141, 'word': ' de usuario', 'start': 10, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.5470925, 'word': ' 16', 'start': 21, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.67447263, 'word': ' : como tes', 'start': 23, 'end': 32}, {'entity_group': 'LABEL_1', 'score': 0.51690984, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_0', 'score': 0.68711317, 'word': ' , quero integracao com sistemas de', 'start': 38, 'end': 71}, {'entity_group': 'LABEL_1', 'score': 0.5366782, 'word': ' controle', 'start': 73, 'end': 80}, {'entity_group': 'LABEL_0', 'score': 0.67651844, 'word': ' de versao para', 'start': 82, 'end': 95}, {'entity_group': 'LABEL_1', 'score': 0.58124024, 'word': ' rastre', 'start': 97, 'end': 102}, {'entity_group': 'LABEL_0', 'score': 0.60643923, 'word': 'ar mudancas nos requisitos e no codigo -', 'start': 102, 'end': 141}, {'entity_group': 'LABEL_1', 'score': 0.50867885, 'word': ' fonte', 'start': 142, 'end': 146}, {'entity_group': 'LABEL_0', 'score': 0.58814704, 'word': ' .', 'start': 147, 'end': 147}]
# Resultado para História de Usuário 17: [{'entity_group': 'LABEL_1', 'score': 0.5782673, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.5921752, 'word': ' de usuario', 'start': 10, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.6387501, 'word': ' 17', 'start': 21, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.6707906, 'word': ' : como tes', 'start': 23, 'end': 32}, {'entity_group': 'LABEL_1', 'score': 0.5167326, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_0', 'score': 0.5812473, 'word': ' , desejo', 'start': 38, 'end': 45}, {'entity_group': 'LABEL_1', 'score': 0.51067936, 'word': ' metricas', 'start': 47, 'end': 54}, {'entity_group': 'LABEL_0', 'score': 0.648404, 'word': ' detalhadas sobre a eficacia dos testes ,', 'start': 56, 'end': 94}, {'entity_group': 'LABEL_1', 'score': 0.5480069, 'word': ' incluindo taxa', 'start': 96, 'end': 109}, {'entity_group': 'LABEL_0', 'score': 0.71453476, 'word': ' de', 'start': 111, 'end': 112}, {'entity_group': 'LABEL_1', 'score': 0.52097183, 'word': ' cobertura', 'start': 114, 'end': 122}, {'entity_group': 'LABEL_0', 'score': 0.6498822, 'word': ' e', 'start': 124, 'end': 124}, {'entity_group': 'LABEL_1', 'score': 0.538566, 'word': ' taxa', 'start': 126, 'end': 129}, {'entity_group': 'LABEL_0', 'score': 0.60392165, 'word': ' de falha .', 'start': 131, 'end': 139}]
# Resultado para História de Usuário 18: [{'entity_group': 'LABEL_1', 'score': 0.55043924, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.6260277, 'word': ' de usuario', 'start': 10, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.5452016, 'word': ' 18', 'start': 21, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.64845365, 'word': ' : como testador , preciso de suporte a execucao de testes de desempenho e escalabilidade .', 'start': 23, 'end': 110}]
# Resultado para História de Usuário 19: [{'entity_group': 'LABEL_1', 'score': 0.54783815, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.608426, 'word': ' de usuario', 'start': 10, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.62113684, 'word': ' 19', 'start': 21, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.6945984, 'word': ' : como testador , quero analise automatica dos resultados dos testes para relatorios detalhados sobre problemas encontrados .', 'start': 23, 'end': 145}]
# Resultado para História de Usuário 20: [{'entity_group': 'LABEL_0', 'score': 0.65420294, 'word': ' historia de usuario 20 : como testador , desejo simular cenarios de teste complexos e realistas para garantir testes proximos a realidade .', 'start': 0, 'end': 136}]
# Resultado para História de Usuário 21: [{'entity_group': 'LABEL_1', 'score': 0.51051366, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.64034235, 'word': ' de usuario', 'start': 10, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.5545089, 'word': ' 21', 'start': 21, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.6619256, 'word': ' : como testador , preciso de suporte a execucao de testes de regressao automatizados .', 'start': 23, 'end': 106}]
# Resultado para História de Usuário 22: [{'entity_group': 'LABEL_1', 'score': 0.60330576, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.5780233, 'word': ' de usuario', 'start': 10, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.50811255, 'word': ' 22', 'start': 21, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.61106277, 'word': ' : como testador , quero identificacao automatica de casos de teste', 'start': 23, 'end': 87}, {'entity_group': 'LABEL_1', 'score': 0.53553045, 'word': ' redundantes', 'start': 89, 'end': 99}, {'entity_group': 'LABEL_0', 'score': 0.60486466, 'word': ' ou desnecessarios .', 'start': 101, 'end': 118}]
# Resultado para História de Usuário 23: [{'entity_group': 'LABEL_1', 'score': 0.5592978, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.60772234, 'word': ' de usuario 23 : como tes', 'start': 10, 'end': 32}, {'entity_group': 'LABEL_1', 'score': 0.5198508, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_0', 'score': 0.6753645, 'word': ' , desejo integracao facil com ferramentas de', 'start': 38, 'end': 81}, {'entity_group': 'LABEL_1', 'score': 0.6193427, 'word': ' gerenciamento', 'start': 83, 'end': 95}, {'entity_group': 'LABEL_0', 'score': 0.6345801, 'word': ' de projetos .', 'start': 97, 'end': 108}]
# Resultado para História de Usuário 24: [{'entity_group': 'LABEL_1', 'score': 0.5009348, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.604401, 'word': ' de usuario', 'start': 10, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.54242516, 'word': ' 24', 'start': 21, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.6974109, 'word': ' : como tes', 'start': 23, 'end': 32}, {'entity_group': 'LABEL_1', 'score': 0.5251534, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_0', 'score': 0.65483934, 'word': ' , preciso de suporte a execucao de testes de usabilidade .', 'start': 38, 'end': 94}]
# Resultado para História de Usuário 25: [{'entity_group': 'LABEL_1', 'score': 0.5389723, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.5823641, 'word': ' de usuario', 'start': 10, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.505967, 'word': ' 25', 'start': 21, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.66879565, 'word': ' : como testador , quero que a ferramenta crie automaticamente conjuntos de dados de teste realistas .', 'start': 23, 'end': 121}]
# Resultado para História de Usuário 26: [{'entity_group': 'LABEL_0', 'score': 0.6495358, 'word': ' historia de usuario 26 : como testador , desejo integracao com ferramentas de monitoramento de desempenho em tempo real .', 'start': 0, 'end': 118}]
# Resultado para História de Usuário 27: [{'entity_group': 'LABEL_0', 'score': 0.57429713, 'word': ' historia de usuario', 'start': 0, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.50746816, 'word': ' 27', 'start': 21, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.6692241, 'word': ' : como testador , preciso de suporte a execucao de testes de localizacao e internacionalizacao .', 'start': 23, 'end': 116}]
# Resultado para História de Usuário 28: [{'entity_group': 'LABEL_1', 'score': 0.59078056, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.5926938, 'word': ' de usuario', 'start': 10, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.61365217, 'word': ' 28', 'start': 21, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.65550816, 'word': ' : como testador , quero', 'start': 23, 'end': 44}, {'entity_group': 'LABEL_1', 'score': 0.5894335, 'word': ' geracao', 'start': 46, 'end': 52}, {'entity_group': 'LABEL_0', 'score': 0.6889456, 'word': ' automatica de dados de teste sinteticos .', 'start': 54, 'end': 93}]
# Resultado para História de Usuário 29: [{'entity_group': 'LABEL_1', 'score': 0.50394946, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.6422436, 'word': ' de usuario 29 : como testador , desejo suporte a execucao de testes de', 'start': 10, 'end': 77}, {'entity_group': 'LABEL_1', 'score': 0.5223489, 'word': ' acessibilidade', 'start': 79, 'end': 92}, {'entity_group': 'LABEL_0', 'score': 0.60510164, 'word': ' .', 'start': 93, 'end': 93}]
# Resultado para História de Usuário 30: [{'entity_group': 'LABEL_1', 'score': 0.5053003, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.65761477, 'word': ' de usuario 30 : como testador , preciso de suporte a execucao de testes de integracao continua .', 'start': 10, 'end': 102}]
# Resultado para História de Usuário 31: [{'entity_group': 'LABEL_1', 'score': 0.5837227, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.5613079, 'word': ' de usuario', 'start': 10, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.51567197, 'word': ' 31', 'start': 21, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.625654, 'word': ' : como testador , quero identificacao automatica de casos de teste incompletos ou mal definidos .', 'start': 23, 'end': 117}]
# Resultado para História de Usuário 32: [{'entity_group': 'LABEL_1', 'score': 0.5229864, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.6347602, 'word': ' de usuario 32 : como tes', 'start': 10, 'end': 32}, {'entity_group': 'LABEL_1', 'score': 0.51812375, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_0', 'score': 0.6416333, 'word': ' , desejo identificacao automatica de dependencias entre casos de teste .', 'start': 38, 'end': 108}]
# Resultado para História de Usuário 33: [{'entity_group': 'LABEL_1', 'score': 0.5288479, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.599516, 'word': ' de usuario', 'start': 10, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.59141546, 'word': ' 33', 'start': 21, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.67346454, 'word': ' : como testador , preciso de suporte a execucao de testes de recuperacao de desastres .', 'start': 23, 'end': 107}]
# Resultado para História de Usuário 34: [{'entity_group': 'LABEL_1', 'score': 0.5206096, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.5653217, 'word': ' de usuario', 'start': 10, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.5551352, 'word': ' 34', 'start': 21, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.66513216, 'word': ' : como testador , quero que a ferramenta identifique automaticamente casos de teste paralelizaveis .', 'start': 23, 'end': 120}]
# Resultado para História de Usuário 35: [{'entity_group': 'LABEL_1', 'score': 0.5918589, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.63277775, 'word': ' de', 'start': 10, 'end': 11}, {'entity_group': 'LABEL_1', 'score': 0.5420208, 'word': ' usuario 35', 'start': 13, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.6591778, 'word': ' : como testador , desejo simulacao de cenarios de teste de carga extremamente', 'start': 23, 'end': 98}, {'entity_group': 'LABEL_1', 'score': 0.5603042, 'word': ' alta', 'start': 100, 'end': 103}, {'entity_group': 'LABEL_0', 'score': 0.6306817, 'word': ' .', 'start': 104, 'end': 104}]
# Resultado para História de Usuário 36: [{'entity_group': 'LABEL_1', 'score': 0.57998616, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.6600479, 'word': ' de', 'start': 10, 'end': 11}, {'entity_group': 'LABEL_1', 'score': 0.6014712, 'word': ' usuario 36', 'start': 13, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.67320126, 'word': ' : como tes', 'start': 23, 'end': 32}, {'entity_group': 'LABEL_1', 'score': 0.5206131, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_0', 'score': 0.664944, 'word': ' , preciso de suporte a execucao de testes de compatibilidade com diferentes navega', 'start': 38, 'end': 119}, {'entity_group': 'LABEL_1', 'score': 0.55400026, 'word': 'dores', 'start': 119, 'end': 124}, {'entity_group': 'LABEL_0', 'score': 0.69690293, 'word': ' e', 'start': 126, 'end': 126}, {'entity_group': 'LABEL_1', 'score': 0.5263896, 'word': ' dispositivos', 'start': 128, 'end': 139}, {'entity_group': 'LABEL_0', 'score': 0.60082835, 'word': ' .', 'start': 140, 'end': 140}]
# Resultado para História de Usuário 37: [{'entity_group': 'LABEL_1', 'score': 0.6176887, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.58040607, 'word': ' de usuario', 'start': 10, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.6166431, 'word': ' 37', 'start': 21, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.65477335, 'word': ' : como testador , quero', 'start': 23, 'end': 44}, {'entity_group': 'LABEL_1', 'score': 0.60393053, 'word': ' geracao', 'start': 46, 'end': 52}, {'entity_group': 'LABEL_0', 'score': 0.653534, 'word': ' automatica de relatorios de teste personalizados .', 'start': 54, 'end': 102}]
# Resultado para História de Usuário 38: [{'entity_group': 'LABEL_1', 'score': 0.613123, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.6049713, 'word': ' de usuario', 'start': 10, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.6506978, 'word': ' 38', 'start': 21, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.61547476, 'word': ' : como testador , desejo', 'start': 23, 'end': 45}, {'entity_group': 'LABEL_1', 'score': 0.51642907, 'word': ' rastre', 'start': 47, 'end': 52}, {'entity_group': 'LABEL_0', 'score': 0.6977263, 'word': 'amento automatico de resultados de teste ao longo do tempo .', 'start': 52, 'end': 111}]
# Resultado para História de Usuário 39: [{'entity_group': 'LABEL_0', 'score': 0.6078872, 'word': ' historia de usuario', 'start': 0, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.57515746, 'word': ' 39', 'start': 21, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.6791411, 'word': ' : como testador , preciso de suporte a execucao de testes de regressao progressiva .', 'start': 23, 'end': 104}]
# Resultado para História de Usuário 40: [{'entity_group': 'LABEL_1', 'score': 0.53348416, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.60862404, 'word': ' de usuario', 'start': 10, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.51644105, 'word': ' 40', 'start': 21, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.70384514, 'word': ' : como testador , quero sugestoes automaticas para aprimorar os casos de teste existentes .', 'start': 23, 'end': 111}]
# Resultado para História de Usuário 41: [{'entity_group': 'LABEL_1', 'score': 0.52954036, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.59624577, 'word': ' de usuario', 'start': 10, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.54072076, 'word': ' 41', 'start': 21, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.67449594, 'word': ' : como tes', 'start': 23, 'end': 32}, {'entity_group': 'LABEL_1', 'score': 0.51962066, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_0', 'score': 0.6881455, 'word': ' , desejo que a ferramenta aprenda com os resultados dos testes e melhore suas sugestoes futuras .', 'start': 38, 'end': 133}]
# Resultado para História de Usuário 42: [{'entity_group': 'LABEL_1', 'score': 0.5473209, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.5929005, 'word': ' de usuario', 'start': 10, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.6009144, 'word': ' 42', 'start': 21, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.6600444, 'word': ' : como tes', 'start': 23, 'end': 32}, {'entity_group': 'LABEL_1', 'score': 0.52500933, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_0', 'score': 0.6678411, 'word': ' , preciso de suporte a', 'start': 38, 'end': 59}, {'entity_group': 'LABEL_1', 'score': 0.5161109, 'word': ' execucao', 'start': 61, 'end': 68}, {'entity_group': 'LABEL_0', 'score': 0.67369866, 'word': ' de testes de seguranca automatizados .', 'start': 70, 'end': 106}]
# Resultado para História de Usuário 43: [{'entity_group': 'LABEL_1', 'score': 0.5566375, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.63524073, 'word': ' de', 'start': 10, 'end': 11}, {'entity_group': 'LABEL_1', 'score': 0.608356, 'word': ' usuario 43', 'start': 13, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.65116674, 'word': ' : como tes', 'start': 23, 'end': 32}, {'entity_group': 'LABEL_1', 'score': 0.5052909, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_0', 'score': 0.66898483, 'word': ' , quero integracao com ferramentas de analise de codigo estatico para identificar areas de risco .', 'start': 38, 'end': 134}]
# Resultado para História de Usuário 44: [{'entity_group': 'LABEL_1', 'score': 0.5121143, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.62968194, 'word': ' de usuario', 'start': 10, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.73936707, 'word': ' 44', 'start': 21, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.673163, 'word': ' : como testador , desejo suporte a execucao de testes de integracao de sistema e teste de aceitacao do usuario .', 'start': 23, 'end': 132}]
# Resultado para História de Usuário 45: [{'entity_group': 'LABEL_1', 'score': 0.56723535, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.5815436, 'word': ' de usuario', 'start': 10, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.7177029, 'word': ' 45', 'start': 21, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.67296547, 'word': ' : como tes', 'start': 23, 'end': 32}, {'entity_group': 'LABEL_1', 'score': 0.51478046, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_0', 'score': 0.626538, 'word': ' , preciso de suporte a execucao de testes de confiabilidade e disponibilidade .', 'start': 38, 'end': 115}]
# Resultado para História de Usuário 46: [{'entity_group': 'LABEL_1', 'score': 0.5916922, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.6604446, 'word': ' de', 'start': 10, 'end': 11}, {'entity_group': 'LABEL_1', 'score': 0.5648067, 'word': ' usuario 46', 'start': 13, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.7021113, 'word': ' : como testador , quero que a ferramenta sugira casos de teste com base em modelos de qualidade de', 'start': 23, 'end': 119}, {'entity_group': 'LABEL_1', 'score': 0.50067496, 'word': ' software', 'start': 121, 'end': 128}, {'entity_group': 'LABEL_0', 'score': 0.6395706, 'word': ' reconhecidos .', 'start': 130, 'end': 142}]
# Resultado para História de Usuário 47: [{'entity_group': 'LABEL_1', 'score': 0.5967368, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.60635734, 'word': ' de usuario', 'start': 10, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.70190334, 'word': ' 47', 'start': 21, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.69094205, 'word': ' : como tes', 'start': 23, 'end': 32}, {'entity_group': 'LABEL_1', 'score': 0.5039986, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_0', 'score': 0.6596283, 'word': ' , desejo integracao com ferramentas de auto', 'start': 38, 'end': 80}, {'entity_group': 'LABEL_1', 'score': 0.5475883, 'word': 'macao', 'start': 80, 'end': 85}, {'entity_group': 'LABEL_0', 'score': 0.6737236, 'word': ' de teste de interface do usuario .', 'start': 87, 'end': 119}]
# Resultado para História de Usuário 48: [{'entity_group': 'LABEL_1', 'score': 0.5989327, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.66772556, 'word': ' de', 'start': 10, 'end': 11}, {'entity_group': 'LABEL_1', 'score': 0.61228585, 'word': ' usuario 48', 'start': 13, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.6595237, 'word': ' : como tes', 'start': 23, 'end': 32}, {'entity_group': 'LABEL_1', 'score': 0.5177017, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_0', 'score': 0.6378477, 'word': ' , preciso de suporte a', 'start': 38, 'end': 59}, {'entity_group': 'LABEL_1', 'score': 0.54649824, 'word': ' execucao', 'start': 61, 'end': 68}, {'entity_group': 'LABEL_0', 'score': 0.6648974, 'word': ' de testes de', 'start': 70, 'end': 81}, {'entity_group': 'LABEL_1', 'score': 0.60512197, 'word': ' estresse', 'start': 83, 'end': 90}, {'entity_group': 'LABEL_0', 'score': 0.670263, 'word': ' e', 'start': 92, 'end': 92}, {'entity_group': 'LABEL_1', 'score': 0.6429265, 'word': ' robuste', 'start': 94, 'end': 100}, {'entity_group': 'LABEL_0', 'score': 0.5550668, 'word': 'z', 'start': 100, 'end': 101}, {'entity_group': 'LABEL_1', 'score': 0.5203378, 'word': ' .', 'start': 102, 'end': 102}]
# Resultado para História de Usuário 49: [{'entity_group': 'LABEL_1', 'score': 0.55232257, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.6463244, 'word': ' de', 'start': 10, 'end': 11}, {'entity_group': 'LABEL_1', 'score': 0.530316, 'word': ' usuario 49', 'start': 13, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.6584911, 'word': ' : como testador , quero que a ferramenta sugira casos de teste para areas de alto risco e complexidade .', 'start': 23, 'end': 124}]
# Resultado para História de Usuário 50: [{'entity_group': 'LABEL_1', 'score': 0.5758753, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.64836913, 'word': ' de usuario 50 : como tes', 'start': 10, 'end': 32}, {'entity_group': 'LABEL_1', 'score': 0.5112645, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_0', 'score': 0.6951225, 'word': ' , desejo integracao com ferramentas de', 'start': 38, 'end': 75}, {'entity_group': 'LABEL_1', 'score': 0.588491, 'word': ' gerenciamento', 'start': 77, 'end': 89}, {'entity_group': 'LABEL_0', 'score': 0.6680673, 'word': ' de defeitos para', 'start': 91, 'end': 106}, {'entity_group': 'LABEL_1', 'score': 0.57093596, 'word': ' rastre', 'start': 108, 'end': 113}, {'entity_group': 'LABEL_0', 'score': 0.61124825, 'word': 'amento de', 'start': 113, 'end': 122}, {'entity_group': 'LABEL_1', 'score': 0.52043796, 'word': ' correcoes', 'start': 124, 'end': 132}, {'entity_group': 'LABEL_0', 'score': 0.6225599, 'word': ' .', 'start': 133, 'end': 133}]
# Resultado para História de Usuário 51: [{'entity_group': 'LABEL_0', 'score': 0.6315116, 'word': ' historia de usuario', 'start': 0, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.5280958, 'word': ' 51', 'start': 21, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.6772048, 'word': ' : como testador , preciso de suporte a execucao de testes de usabilidade remota e teste de usuario beta .', 'start': 23, 'end': 125}]
# Resultado para História de Usuário 52: [{'entity_group': 'LABEL_1', 'score': 0.532271, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.5917333, 'word': ' de usuario', 'start': 10, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.5273379, 'word': ' 52', 'start': 21, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.6381418, 'word': ' : como testador , quero que a ferramenta forneca feedback em tempo real durante a', 'start': 23, 'end': 102}, {'entity_group': 'LABEL_1', 'score': 0.50044847, 'word': ' execucao', 'start': 104, 'end': 111}, {'entity_group': 'LABEL_0', 'score': 0.7113983, 'word': ' dos testes .', 'start': 113, 'end': 123}]
# Resultado para História de Usuário 53: [{'entity_group': 'LABEL_1', 'score': 0.60524946, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.59233916, 'word': ' de usuario', 'start': 10, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.6733079, 'word': ' 53', 'start': 21, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.65987116, 'word': ' : como tes', 'start': 23, 'end': 32}, {'entity_group': 'LABEL_1', 'score': 0.5324395, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_0', 'score': 0.6409897, 'word': ' , desejo integracao com ferramentas de auto', 'start': 38, 'end': 80}, {'entity_group': 'LABEL_1', 'score': 0.57733035, 'word': 'macao', 'start': 80, 'end': 85}, {'entity_group': 'LABEL_0', 'score': 0.65459937, 'word': ' de infraestrutura para', 'start': 87, 'end': 108}, {'entity_group': 'LABEL_1', 'score': 0.52524096, 'word': ' provisionamento', 'start': 110, 'end': 124}, {'entity_group': 'LABEL_0', 'score': 0.6075133, 'word': ' e configuracao automatizados .', 'start': 126, 'end': 154}]
# Resultado para História de Usuário 54: [{'entity_group': 'LABEL_1', 'score': 0.50224555, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.72094023, 'word': ' de', 'start': 10, 'end': 11}, {'entity_group': 'LABEL_1', 'score': 0.55828047, 'word': ' usuario 54', 'start': 13, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.69765466, 'word': ' : como tes', 'start': 23, 'end': 32}, {'entity_group': 'LABEL_1', 'score': 0.5029045, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_0', 'score': 0.6697772, 'word': ' , preciso de suporte a execucao de testes de comparacao de desempenho para versoes anteriores e atuais do aplica', 'start': 38, 'end': 149}, {'entity_group': 'LABEL_1', 'score': 0.55713034, 'word': 'tivo', 'start': 149, 'end': 153}, {'entity_group': 'LABEL_0', 'score': 0.60610497, 'word': ' .', 'start': 154, 'end': 154}]

# %%
X = historias_usuario
rotulos_possiveis = ["testador", "desenvolvedor", "aplicativo", "ferramenta", "suporte"]
y = [choice(rotulos_possiveis) for _ in range(len(historias_usuario))]
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=42)

# %%
clf_tf = DecisionTreeClassifier(criterion='gini',max_depth=3)
clf_tf.fit(X_train, y_train)
pred_arvore_entropy_tf = clf_tf.predict(X_test)
accuracy_decision = accuracy_score(y_test,pred_arvore_entropy_tf)
print(pred_arvore_entropy_tf)
print(accuracy_decision)
# Out:
# ['aplicativo' 'suporte' 'aplicativo' 'aplicativo' 'aplicativo'
#  'aplicativo' 'aplicativo' 'aplicativo' 'aplicativo']
# 0.1111111111111111

# %%
clf_tf = DecisionTreeClassifier(criterion='entropy',max_depth=7)
clf_tf.fit(X_train, y_train)
pred_arvore_entropy_tf = clf_tf.predict(X_test)
accuracy_decision = accuracy_score(y_test,pred_arvore_entropy_tf)
print(pred_arvore_entropy_tf)
print(accuracy_decision)
# Out:
# ['ferramenta' 'suporte' 'suporte' 'ferramenta' 'aplicativo' 'ferramenta'
#  'ferramenta' 'suporte' 'aplicativo']
# 0.3333333333333333

# %%
clf_tf3 = KNeighborsClassifier(metric='manhattan')
clf_tf3.fit(X_train, y_train)
pred_knn_tf = clf_tf3.predict(X_test)
acuracy_KNN = accuracy_score(y_test,pred_knn_tf)
print(pred_knn_tf)
print(acuracy_KNN)
# Out:
# ['aplicativo' 'testador' 'aplicativo' 'suporte' 'aplicativo' 'aplicativo'
#  'aplicativo' 'aplicativo' 'aplicativo']
# 0.0

# %%
clf_tf3 = KNeighborsClassifier(metric='euclidean')
clf_tf3.fit(X_train, y_train)
pred_knn_tf = clf_tf3.predict(X_test)
acuracy_KNN = accuracy_score(y_test,pred_knn_tf)
print(pred_knn_tf)
print(acuracy_KNN)
# Out:
# ['suporte' 'suporte' 'aplicativo' 'aplicativo' 'aplicativo' 'suporte'
#  'aplicativo' 'suporte' 'aplicativo']
# 0.2222222222222222
