# %%
# !python3 -m spacy download pt_core_news_lg
from tensorflow.keras import optimizers
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.probability import FreqDist
from scipy.sparse import csr_matrix
from nltk.corpus import stopwords
from transformers import pipeline
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
# %matplotlib inline
import torch
import string
import nltk
import re
# Out:
# Collecting pt-core-news-lg==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/pt_core_news_lg-3.7.0/pt_core_news_lg-3.7.0-py3-none-any.whl (568.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 568.2/568.2 MB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from pt-core-news-lg==3.7.0) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (4.66.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.7.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (24.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (1.25.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.18.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.1.5)
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
classificador = pipeline("zero-shot-classification")
rotulos = ["testador", "aplicativo", "desempenho", "teste"]
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli and revision c626438 (https://huggingface.co/facebook/bart-large-mnli).
# Using a pipeline without specifying a model name and revision in production is not recommended.

# %%
roberta = pipeline("ner", grouped_entities=True, model="joelniklaus/legal-portuguese-roberta-base")
# Out:
# Some weights of RobertaForTokenClassification were not initialized from the model checkpoint at joelniklaus/legal-portuguese-roberta-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/token_classification.py:168: UserWarning: `grouped_entities` is deprecated and will be removed in version v5.0.0, defaulted to `aggregation_strategy="simple"` instead.
#   warnings.warn(

# %%
historias_usuario = [
    "Como Testador eu quero um jeito mais fácil de incluir os requisitos do aplicativo na ferramenta DRL-Mobtest para criar casos de teste que cubram tudo que o aplicativo precisa fazer, sem ter que gastar muito tempo escrevendo manualmente.",
    "Como Testador eu quero uma maneira de ensinar a ferramenta DRL-Mobtest a entender os requisitos do aplicativo usando NLP para fazer com que a ferramenta gere testes automaticamente.",
    "Como Testador eu quero que a ferramenta gere casos de teste abrangentes que cubram integralmente todos os requisitos do aplicativo, assegurando que o software seja completo e funcional, sem depender exclusivamente da criação manual de casos de teste.",
    "Como Testador eu quero que a ferramenta seja integrada com outras ferramentas de gerenciamento, permitindo sincronização automática dos requisitos e facilitando o processo de criação de casos de testes.",
    "Como testador, eu quero que a ferramenta gere casos de teste completos e funcionais que cubram todos os requisitos do aplicativo, para garantir uma cobertura abrangente durante os testes.",
    "Como testador, eu quero integração com outras ferramentas de gerenciamento para sincronizar automaticamente requisitos e facilitar a criação de casos de teste, visando melhorar a eficiência e precisão do processo de teste.",
    "Como testador, eu quero relatórios detalhados sobre a cobertura dos testes para análise precisa durante a execução, a fim de avaliar a qualidade e a extensão dos testes realizados.",
    "Como testador, eu desejo que a ferramenta identifique automaticamente os casos de teste mais críticos para priorizar a análise, visando direcionar os esforços de teste para áreas de maior risco.",
    "Como testador, eu preciso que a ferramenta sugira casos de teste com base em padrões de uso real do aplicativo, para garantir que os testes reflitam cenários típicos de uso.",
    "Como testador, eu quero sugestões com base em padrões de falha históricos para evitar problemas recorrentes no software, visando melhorar a qualidade e a robustez do produto.",
    "Como testador, eu desejo suporte à execução de testes automatizados em diferentes dispositivos e ambientes, para garantir a consistência e a confiabilidade dos testes em diferentes cenários.",
    "Como testador, eu preciso que a ferramenta detecte automaticamente mudanças nos requisitos e ajuste os casos de teste correspondentes, para manter os testes alinhados com a evolução do aplicativo.",
    "Como testador, eu quero integração com sistemas de controle de versão para rastrear mudanças nos requisitos e no código-fonte, visando uma gestão eficaz de mudanças durante o ciclo de desenvolvimento.",
    "Como testador, eu desejo métricas detalhadas sobre a eficácia dos testes, incluindo taxa de cobertura e taxa de falha, para avaliar a qualidade do processo de teste.",
    "Como testador, eu preciso de suporte à execução de testes de desempenho e escalabilidade, para garantir que o aplicativo atenda aos requisitos de desempenho sob carga.",
    "Como testador, eu quero análise automática dos resultados dos testes para relatórios detalhados sobre problemas encontrados, a fim de facilitar a identificação e correção de defeitos.",
    "Como testador, eu desejo simular cenários de teste complexos e realistas para garantir testes próximos à realidade, visando uma validação mais precisa do software.",
    "Como testador, eu preciso de suporte à execução de testes de regressão automatizados, para garantir que as alterações no código não introduzam regressões.",
    "Como testador, eu quero identificação automática de casos de teste redundantes ou desnecessários, para otimizar os esforços de teste.",
    "Como testador, eu desejo integração fácil com ferramentas de gerenciamento de projetos, para uma colaboração eficiente com outros membros da equipe de desenvolvimento.",
    "Como testador, eu preciso de suporte à execução de testes de usabilidade, para garantir que o aplicativo seja fácil e intuitivo de usar.",
    "Como testador, eu quero que a ferramenta crie automaticamente conjuntos de dados de teste realistas, para simular condições reais de uso.",
    "Como testador, eu desejo integração com ferramentas de monitoramento de desempenho em tempo real, para avaliar o desempenho do aplicativo durante os testes.",
    "Como testador, eu preciso de suporte à execução de testes de localização e internacionalização, para garantir que o aplicativo seja compatível com diferentes idiomas e regiões.",
    "Como testador, eu quero geração automática de dados de teste sintéticos, para complementar os casos de teste manuais.",
    "Como testador, eu desejo suporte à execução de testes de acessibilidade, para garantir que o aplicativo seja acessível a todos os usuários.",
    "Como testador, eu preciso de suporte à execução de testes de integração contínua, para garantir que as alterações no código não quebrem a integração com outras partes do sistema.",
    "Como testador, eu quero identificação automática de casos de teste incompletos ou mal definidos, para garantir a qualidade dos testes.",
    "Como testador, eu desejo identificação automática de dependências entre casos de teste, para garantir uma sequência lógica na execução dos testes.",
    "Como testador, eu preciso de suporte à execução de testes de recuperação de desastres, para avaliar a capacidade do sistema de se recuperar de falhas.",
    "Como testador, eu quero que a ferramenta identifique automaticamente casos de teste paralelizáveis, para otimizar a execução dos testes.",
    "Como testador, eu desejo simulação de cenários de teste de carga extremamente alta, para avaliar a capacidade de escalabilidade do sistema.",
    "Como testador, eu preciso de suporte à execução de testes de compatibilidade com diferentes navegadores e dispositivos, para garantir uma experiência consistente para todos os usuários.",
    "Como testador, eu quero geração automática de relatórios de teste personalizados, para comunicar eficazmente os resultados dos testes.",
    "Como testador, eu desejo rastreamento automático de resultados de teste ao longo do tempo, para identificar tendências e padrões de qualidade.",
    "Como testador, eu preciso de suporte à execução de testes de regressão progressiva, para garantir que as novas alterações não quebrem funcionalidades existentes.",
    "Como testador, eu quero sugestões automáticas para aprimorar os casos de teste existentes, para aumentar a eficiência e a eficácia dos testes.",
    "Como testador, eu desejo que a ferramenta aprenda com os resultados dos testes e melhore suas sugestões futuras, para uma otimização contínua do processo de teste.",
    "Como testador, eu preciso de suporte à execução de testes de segurança automatizados, para identificar vulnerabilidades no aplicativo.",
    "Como testador, eu quero integração com ferramentas de análise de código estático para identificar áreas de risco, para uma avaliação abrangente da qualidade do código.",
    "Como testador, eu desejo suporte à execução de testes de integração de sistema e teste de aceitação do usuário, para validar a integração entre diferentes partes do sistema e a conformidade com os requisitos do usuário.",
    "Como testador, eu preciso de suporte à execução de testes de confiabilidade e disponibilidade, para garantir que o aplicativo esteja sempre disponível e funcione corretamente.",
    "Como testador, eu quero que a ferramenta sugira casos de teste com base em modelos de qualidade de software reconhecidos, para garantir uma abordagem abrangente e padronizada para os testes.",
    "Como testador, eu desejo integração com ferramentas de automação de teste de interface do usuário, para automatizar testes de interação com o usuário.",
    "Como testador, eu preciso de suporte à execução de testes de estresse e robustez, para avaliar a estabilidade e a confiabilidade do aplicativo sob condições adversas.",
    "Como testador, eu quero que a ferramenta sugira casos de teste para áreas de alto risco e complexidade, para priorizar os esforços de teste.",
    "Como testador, eu desejo integração com ferramentas de gerenciamento de defeitos para rastreamento de correções, para uma gestão eficaz de problemas encontrados durante os testes.",
    "Como testador, eu preciso de suporte à execução de testes de usabilidade remota e teste de usuário beta, para coletar feedback de usuários reais.",
    "Como testador, eu quero que a ferramenta forneça feedback em tempo real durante a execução dos testes, para facilitar a identificação imediata de problemas.",
    "Como testador, eu desejo integração com ferramentas de automação de infraestrutura para provisionamento e configuração automatizados, para facilitar a preparação do ambiente de teste.",
    "Como testador, eu preciso de suporte à execução de testes de comparação de desempenho para versões anteriores e atuais do aplicativo, para avaliar o impacto de mudanças no desempenho."
]

# %%
#sem_pontuacao = re.findall(r'\b(^[^A-Za-z])\b', historias_usuario, re.IGNORECASE)

# %%
class ProcessadorHistoriasUsuario:
    def __init__(self):
        nltk.download('punkt')
        nltk.download('stopwords')
        nltk.download('wordnet')
        self.lemmatizer = WordNetLemmatizer()
        self.stop_words = set(stopwords.words('portuguese'))

    def processar_historias_usuario(self, historias_usuario):
        freq_dists = []
        for historia_usuario in historias_usuario:
            tokens = word_tokenize(historia_usuario)
            tokens = [token.lower() for token in tokens if token not in string.punctuation]
            tokens = [token for token in tokens if token not in self.stop_words]
            tokens = [self.lemmatizer.lemmatize(token) for token in tokens]
            freq_dist = FreqDist(tokens)
            freq_dists.append(freq_dist)
        return freq_dists

# %%
processador = ProcessadorHistoriasUsuario()
freq_dists = processador.processar_historias_usuario(historias_usuario)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
unicas = set()
for freq_dist in freq_dists:
    unicas.update(freq_dist.keys())

print("Total de palavras únicas:", len(unicas))
print("Diversidade Lexica:", len(unicas) / len(freq_dists))
# Out:
# Total de palavras únicas: 262
# Diversidade Lexica: 5.137254901960785

# %%
for palavra, freq_dist in enumerate(freq_dists):
    print(f"História de Usuário {palavra+1}: {freq_dist.most_common(5)}")
# Out:
# História de Usuário 1: [('aplicativo', 2), ('testador', 1), ('quero', 1), ('jeito', 1), ('fácil', 1)]
# História de Usuário 2: [('ferramenta', 2), ('testador', 1), ('quero', 1), ('maneira', 1), ('ensinar', 1)]
# História de Usuário 3: [('casos', 2), ('teste', 2), ('testador', 1), ('quero', 1), ('ferramenta', 1)]
# História de Usuário 4: [('testador', 1), ('quero', 1), ('ferramenta', 1), ('integrada', 1), ('outras', 1)]
# História de Usuário 5: [('testador', 1), ('quero', 1), ('ferramenta', 1), ('gere', 1), ('casos', 1)]
# História de Usuário 6: [('teste', 2), ('testador', 1), ('quero', 1), ('integração', 1), ('outras', 1)]
# História de Usuário 7: [('testis', 2), ('testador', 1), ('quero', 1), ('relatórios', 1), ('detalhados', 1)]
# História de Usuário 8: [('teste', 2), ('testador', 1), ('desejo', 1), ('ferramenta', 1), ('identifique', 1)]
# História de Usuário 9: [('uso', 2), ('testador', 1), ('preciso', 1), ('ferramenta', 1), ('sugira', 1)]
# História de Usuário 10: [('testador', 1), ('quero', 1), ('sugestões', 1), ('base', 1), ('padrões', 1)]
# História de Usuário 11: [('testis', 2), ('diferentes', 2), ('testador', 1), ('desejo', 1), ('suporte', 1)]
# História de Usuário 12: [('testador', 1), ('preciso', 1), ('ferramenta', 1), ('detecte', 1), ('automaticamente', 1)]
# História de Usuário 13: [('mudanças', 2), ('testador', 1), ('quero', 1), ('integração', 1), ('sistemas', 1)]
# História de Usuário 14: [('taxon', 2), ('testador', 1), ('desejo', 1), ('métricas', 1), ('detalhadas', 1)]
# História de Usuário 15: [('desempenho', 2), ('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1)]
# História de Usuário 16: [('testador', 1), ('quero', 1), ('análise', 1), ('automática', 1), ('resultados', 1)]
# História de Usuário 17: [('testador', 1), ('desejo', 1), ('simular', 1), ('cenários', 1), ('teste', 1)]
# História de Usuário 18: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 19: [('teste', 2), ('testador', 1), ('quero', 1), ('identificação', 1), ('automática', 1)]
# História de Usuário 20: [('testador', 1), ('desejo', 1), ('integração', 1), ('fácil', 1), ('ferramentas', 1)]
# História de Usuário 21: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 22: [('testador', 1), ('quero', 1), ('ferramenta', 1), ('crie', 1), ('automaticamente', 1)]
# História de Usuário 23: [('desempenho', 2), ('testador', 1), ('desejo', 1), ('integração', 1), ('ferramentas', 1)]
# História de Usuário 24: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 25: [('teste', 2), ('testador', 1), ('quero', 1), ('geração', 1), ('automática', 1)]
# História de Usuário 26: [('testador', 1), ('desejo', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 27: [('integração', 2), ('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1)]
# História de Usuário 28: [('testador', 1), ('quero', 1), ('identificação', 1), ('automática', 1), ('casos', 1)]
# História de Usuário 29: [('testador', 1), ('desejo', 1), ('identificação', 1), ('automática', 1), ('dependências', 1)]
# História de Usuário 30: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 31: [('testador', 1), ('quero', 1), ('ferramenta', 1), ('identifique', 1), ('automaticamente', 1)]
# História de Usuário 32: [('testador', 1), ('desejo', 1), ('simulação', 1), ('cenários', 1), ('teste', 1)]
# História de Usuário 33: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 34: [('testador', 1), ('quero', 1), ('geração', 1), ('automática', 1), ('relatórios', 1)]
# História de Usuário 35: [('testador', 1), ('desejo', 1), ('rastreamento', 1), ('automático', 1), ('resultados', 1)]
# História de Usuário 36: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 37: [('testador', 1), ('quero', 1), ('sugestões', 1), ('automáticas', 1), ('aprimorar', 1)]
# História de Usuário 38: [('testador', 1), ('desejo', 1), ('ferramenta', 1), ('aprenda', 1), ('resultados', 1)]
# História de Usuário 39: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 40: [('código', 2), ('testador', 1), ('quero', 1), ('integração', 1), ('ferramentas', 1)]
# História de Usuário 41: [('integração', 2), ('sistema', 2), ('usuário', 2), ('testador', 1), ('desejo', 1)]
# História de Usuário 42: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 43: [('testador', 1), ('quero', 1), ('ferramenta', 1), ('sugira', 1), ('casos', 1)]
# História de Usuário 44: [('usuário', 2), ('testador', 1), ('desejo', 1), ('integração', 1), ('ferramentas', 1)]
# História de Usuário 45: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 46: [('teste', 2), ('testador', 1), ('quero', 1), ('ferramenta', 1), ('sugira', 1)]
# História de Usuário 47: [('testador', 1), ('desejo', 1), ('integração', 1), ('ferramentas', 1), ('gerenciamento', 1)]
# História de Usuário 48: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 49: [('testador', 1), ('quero', 1), ('ferramenta', 1), ('forneça', 1), ('feedback', 1)]
# História de Usuário 50: [('testador', 1), ('desejo', 1), ('integração', 1), ('ferramentas', 1), ('automação', 1)]
# História de Usuário 51: [('desempenho', 2), ('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1)]

# %%
nome, valor = zip(*freq_dists[0].most_common(5))
fig, ax = plt.subplots(figsize=(6,5))
sns.barplot(x=np.array(nome), y=np.array(valor), ax=ax)
plt.show()

# %%
nome,valor = zip(*freq_dists[palavra].most_common(5))
fig, ax = plt.subplots(figsize=(6,5))
sns.barplot(x=np.array(nome), y=np.array(valor), ax=ax)
# Out:
# <Axes: >

# %%
for i, freq_dist in enumerate(freq_dists):
    historia_usuario = " ".join(freq_dist.keys())
    resultado = classificador(historia_usuario, candidate_labels=rotulos)
    top_label = resultado['labels'][0]
    confianca = resultado['scores'][0]
    print(f"História de Usuário {i+1}: Rótulo Previsto: {top_label}, Confiança: {confianca:.2f}")
# Out:
# História de Usuário 1: Rótulo Previsto: testador, Confiança: 0.56
# História de Usuário 2: Rótulo Previsto: testador, Confiança: 0.69
# História de Usuário 3: Rótulo Previsto: testador, Confiança: 0.60
# História de Usuário 4: Rótulo Previsto: testador, Confiança: 0.70
# História de Usuário 5: Rótulo Previsto: testador, Confiança: 0.63
# História de Usuário 6: Rótulo Previsto: testador, Confiança: 0.73
# História de Usuário 7: Rótulo Previsto: testador, Confiança: 0.68
# História de Usuário 8: Rótulo Previsto: testador, Confiança: 0.53
# História de Usuário 9: Rótulo Previsto: testador, Confiança: 0.44
# História de Usuário 10: Rótulo Previsto: testador, Confiança: 0.79
# História de Usuário 11: Rótulo Previsto: testador, Confiança: 0.56
# História de Usuário 12: Rótulo Previsto: testador, Confiança: 0.64
# História de Usuário 13: Rótulo Previsto: testador, Confiança: 0.78
# História de Usuário 14: Rótulo Previsto: testador, Confiança: 0.72
# História de Usuário 15: Rótulo Previsto: testador, Confiança: 0.58
# História de Usuário 16: Rótulo Previsto: testador, Confiança: 0.64
# História de Usuário 17: Rótulo Previsto: testador, Confiança: 0.70
# História de Usuário 18: Rótulo Previsto: testador, Confiança: 0.66
# História de Usuário 19: Rótulo Previsto: testador, Confiança: 0.43
# História de Usuário 20: Rótulo Previsto: testador, Confiança: 0.78
# História de Usuário 21: Rótulo Previsto: testador, Confiança: 0.68
# História de Usuário 22: Rótulo Previsto: testador, Confiança: 0.55
# História de Usuário 23: Rótulo Previsto: testador, Confiança: 0.47
# História de Usuário 24: Rótulo Previsto: testador, Confiança: 0.63
# História de Usuário 25: Rótulo Previsto: testador, Confiança: 0.49
# História de Usuário 26: Rótulo Previsto: testador, Confiança: 0.52
# História de Usuário 27: Rótulo Previsto: testador, Confiança: 0.66
# História de Usuário 28: Rótulo Previsto: testador, Confiança: 0.53
# História de Usuário 29: Rótulo Previsto: testador, Confiança: 0.55
# História de Usuário 30: Rótulo Previsto: testador, Confiança: 0.66
# História de Usuário 31: Rótulo Previsto: testador, Confiança: 0.48
# História de Usuário 32: Rótulo Previsto: testador, Confiança: 0.63
# História de Usuário 33: Rótulo Previsto: testador, Confiança: 0.60
# História de Usuário 34: Rótulo Previsto: testador, Confiança: 0.56
# História de Usuário 35: Rótulo Previsto: testador, Confiança: 0.60
# História de Usuário 36: Rótulo Previsto: testador, Confiança: 0.74
# História de Usuário 37: Rótulo Previsto: testador, Confiança: 0.49
# História de Usuário 38: Rótulo Previsto: testador, Confiança: 0.63
# História de Usuário 39: Rótulo Previsto: testador, Confiança: 0.63
# História de Usuário 40: Rótulo Previsto: testador, Confiança: 0.69
# História de Usuário 41: Rótulo Previsto: testador, Confiança: 0.58
# História de Usuário 42: Rótulo Previsto: testador, Confiança: 0.66
# História de Usuário 43: Rótulo Previsto: testador, Confiança: 0.65
# História de Usuário 44: Rótulo Previsto: testador, Confiança: 0.71
# História de Usuário 45: Rótulo Previsto: testador, Confiança: 0.66
# História de Usuário 46: Rótulo Previsto: testador, Confiança: 0.61
# História de Usuário 47: Rótulo Previsto: testador, Confiança: 0.77
# História de Usuário 48: Rótulo Previsto: testador, Confiança: 0.56
# História de Usuário 49: Rótulo Previsto: testador, Confiança: 0.72
# História de Usuário 50: Rótulo Previsto: testador, Confiança: 0.63
# História de Usuário 51: Rótulo Previsto: testador, Confiança: 0.33

# %%
for i, freq_dist in enumerate(freq_dists):
    historia_usuario = " ".join(freq_dist.keys())
    resultado = roberta(f"História de Usuário {i+1}: {historia_usuario}")
    print(f"Resultado para História de Usuário {i+1}: {resultado}")
# Out:
# Resultado para História de Usuário 1: [{'entity_group': 'LABEL_1', 'score': 0.53793055, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.61254245, 'word': ' de usuario 1 : testador quero jeito facil incluir requisitos aplicativo ferramenta drl - mobtest criar casos teste cubram tudo precisa fazer ter', 'start': 10, 'end': 150}, {'entity_group': 'LABEL_1', 'score': 0.5148471, 'word': ' gas', 'start': 152, 'end': 154}, {'entity_group': 'LABEL_0', 'score': 0.57311, 'word': 'tar tempo escrevendo manualmente', 'start': 154, 'end': 186}]
# Resultado para História de Usuário 2: [{'entity_group': 'LABEL_1', 'score': 0.53439534, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.6108768, 'word': ' de usuario', 'start': 10, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.5315218, 'word': ' 2', 'start': 21, 'end': 21}, {'entity_group': 'LABEL_0', 'score': 0.66252095, 'word': ' : testador quero maneira', 'start': 22, 'end': 45}, {'entity_group': 'LABEL_1', 'score': 0.53120226, 'word': ' ens', 'start': 47, 'end': 49}, {'entity_group': 'LABEL_0', 'score': 0.6339705, 'word': 'inar ferramenta drl - mobtest entender requisitos aplicativo usando nlp fazer gere', 'start': 49, 'end': 129}, {'entity_group': 'LABEL_1', 'score': 0.51878244, 'word': ' tes', 'start': 131, 'end': 133}, {'entity_group': 'LABEL_0', 'score': 0.6819902, 'word': 'tis automaticamente', 'start': 133, 'end': 152}]
# Resultado para História de Usuário 3: [{'entity_group': 'LABEL_1', 'score': 0.5424329, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.6224681, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.5201032, 'word': ' 3', 'start': 21, 'end': 21}, {'entity_group': 'LABEL_0', 'score': 0.71319467, 'word': ' :', 'start': 22, 'end': 22}, {'entity_group': 'LABEL_1', 'score': 0.5198009, 'word': ' tes', 'start': 24, 'end': 26}, {'entity_group': 'LABEL_0', 'score': 0.63986903, 'word': 'tador quero ferramenta gere casos', 'start': 26, 'end': 59}, {'entity_group': 'LABEL_1', 'score': 0.5587435, 'word': ' teste', 'start': 61, 'end': 65}, {'entity_group': 'LABEL_0', 'score': 0.5190815, 'word': ' abrangentes', 'start': 67, 'end': 77}, {'entity_group': 'LABEL_1', 'score': 0.50859123, 'word': ' cub', 'start': 79, 'end': 81}, {'entity_group': 'LABEL_0', 'score': 0.5754321, 'word': 'ram integralmente todos', 'start': 81, 'end': 104}, {'entity_group': 'LABEL_1', 'score': 0.5000557, 'word': ' requisitos', 'start': 106, 'end': 115}, {'entity_group': 'LABEL_0', 'score': 0.5981758, 'word': ' aplicativo assegurando software completo funcional', 'start': 117, 'end': 166}, {'entity_group': 'LABEL_1', 'score': 0.5066529, 'word': ' depender', 'start': 168, 'end': 175}, {'entity_group': 'LABEL_0', 'score': 0.6527757, 'word': ' exclusivamente criacao manual', 'start': 177, 'end': 205}]
# Resultado para História de Usuário 4: [{'entity_group': 'LABEL_1', 'score': 0.50802076, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.6801572, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.50204504, 'word': ' 4', 'start': 21, 'end': 21}, {'entity_group': 'LABEL_0', 'score': 0.6650213, 'word': ' : testador quero ferramenta integrada outras ferramentas gerenciamento permitindo', 'start': 22, 'end': 102}, {'entity_group': 'LABEL_1', 'score': 0.52267855, 'word': ' sincro', 'start': 104, 'end': 109}, {'entity_group': 'LABEL_0', 'score': 0.6223006, 'word': 'nizacao automatica requisitos facilitando processo criacao casos testis', 'start': 109, 'end': 180}]
# Resultado para História de Usuário 5: [{'entity_group': 'LABEL_1', 'score': 0.5680494, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.5727776, 'word': ' de usuario', 'start': 10, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.5198184, 'word': ' 5', 'start': 21, 'end': 21}, {'entity_group': 'LABEL_0', 'score': 0.6370485, 'word': ' : testador quero ferramenta gere casos teste completos funcionais cubram todos requisitos aplicativo garantir cobertura abrangente durante', 'start': 22, 'end': 159}, {'entity_group': 'LABEL_1', 'score': 0.53009844, 'word': ' tes', 'start': 161, 'end': 163}, {'entity_group': 'LABEL_0', 'score': 0.6089301, 'word': 'tis', 'start': 163, 'end': 166}]
# Resultado para História de Usuário 6: [{'entity_group': 'LABEL_1', 'score': 0.5224029, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.6423431, 'word': ' de usuario 6 : testador quero integracao outras ferramentas', 'start': 10, 'end': 67}, {'entity_group': 'LABEL_1', 'score': 0.542679, 'word': ' gerencia', 'start': 69, 'end': 76}, {'entity_group': 'LABEL_0', 'score': 0.60866046, 'word': 'mento', 'start': 76, 'end': 81}, {'entity_group': 'LABEL_1', 'score': 0.55552197, 'word': ' sincro', 'start': 83, 'end': 88}, {'entity_group': 'LABEL_0', 'score': 0.63369584, 'word': 'nizar automaticamente requisitos facilitar criacao casos teste visando melhorar eficiencia precisao processo', 'start': 88, 'end': 196}]
# Resultado para História de Usuário 7: [{'entity_group': 'LABEL_1', 'score': 0.51349103, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.63813776, 'word': ' de usuario 7 : testador quero relatorios detalhados sobre cobertura testis analise precisa durante execucao fim avaliar qualidade extensao realizados', 'start': 10, 'end': 157}]
# Resultado para História de Usuário 8: [{'entity_group': 'LABEL_1', 'score': 0.5449936, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.6146751, 'word': ' de usuario 8 :', 'start': 10, 'end': 22}, {'entity_group': 'LABEL_1', 'score': 0.5169787, 'word': ' tes', 'start': 24, 'end': 26}, {'entity_group': 'LABEL_0', 'score': 0.5940171, 'word': 'tador desejo ferramenta identifique automaticamente casos', 'start': 26, 'end': 83}, {'entity_group': 'LABEL_1', 'score': 0.5564035, 'word': ' teste criticos priori', 'start': 85, 'end': 105}, {'entity_group': 'LABEL_0', 'score': 0.6440781, 'word': 'zar analise visando', 'start': 105, 'end': 124}, {'entity_group': 'LABEL_1', 'score': 0.55417734, 'word': ' dire', 'start': 126, 'end': 129}, {'entity_group': 'LABEL_0', 'score': 0.6772972, 'word': 'cionar', 'start': 129, 'end': 135}, {'entity_group': 'LABEL_1', 'score': 0.583921, 'word': ' esforcos', 'start': 137, 'end': 144}, {'entity_group': 'LABEL_0', 'score': 0.67153996, 'word': ' areas', 'start': 146, 'end': 150}, {'entity_group': 'LABEL_1', 'score': 0.60168105, 'word': ' maior', 'start': 152, 'end': 156}, {'entity_group': 'LABEL_0', 'score': 0.5085276, 'word': ' risco', 'start': 158, 'end': 162}]
# Resultado para História de Usuário 9: [{'entity_group': 'LABEL_1', 'score': 0.5555723, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.61883134, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.5112526, 'word': ' 9', 'start': 21, 'end': 21}, {'entity_group': 'LABEL_0', 'score': 0.721022, 'word': ' :', 'start': 22, 'end': 22}, {'entity_group': 'LABEL_1', 'score': 0.5520629, 'word': ' tes', 'start': 24, 'end': 26}, {'entity_group': 'LABEL_0', 'score': 0.6436566, 'word': 'tador', 'start': 26, 'end': 31}, {'entity_group': 'LABEL_1', 'score': 0.6097573, 'word': ' preciso', 'start': 33, 'end': 39}, {'entity_group': 'LABEL_0', 'score': 0.6027101, 'word': ' ferramenta', 'start': 41, 'end': 50}, {'entity_group': 'LABEL_1', 'score': 0.6470918, 'word': ' su', 'start': 52, 'end': 53}, {'entity_group': 'LABEL_0', 'score': 0.51919043, 'word': 'gira casos', 'start': 53, 'end': 63}, {'entity_group': 'LABEL_1', 'score': 0.6279947, 'word': ' teste base padroes uso', 'start': 65, 'end': 86}, {'entity_group': 'LABEL_0', 'score': 0.5471739, 'word': ' real aplicativo', 'start': 88, 'end': 102}, {'entity_group': 'LABEL_1', 'score': 0.5455209, 'word': ' garantir tes', 'start': 104, 'end': 115}, {'entity_group': 'LABEL_0', 'score': 0.5817915, 'word': 'tis', 'start': 115, 'end': 118}, {'entity_group': 'LABEL_1', 'score': 0.51351017, 'word': ' refli', 'start': 120, 'end': 124}, {'entity_group': 'LABEL_0', 'score': 0.54168993, 'word': 'tam', 'start': 124, 'end': 127}, {'entity_group': 'LABEL_1', 'score': 0.59696674, 'word': ' cenarios ti', 'start': 129, 'end': 139}, {'entity_group': 'LABEL_0', 'score': 0.5400559, 'word': 'picos', 'start': 139, 'end': 144}]
# Resultado para História de Usuário 10: [{'entity_group': 'LABEL_1', 'score': 0.60661376, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.60576487, 'word': ' de usuario', 'start': 10, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.6357552, 'word': ' 10', 'start': 21, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.60627604, 'word': ' : testador quero sugestoes', 'start': 23, 'end': 48}, {'entity_group': 'LABEL_1', 'score': 0.5927566, 'word': ' base padroes', 'start': 50, 'end': 61}, {'entity_group': 'LABEL_0', 'score': 0.52135456, 'word': ' falha historicos', 'start': 63, 'end': 78}, {'entity_group': 'LABEL_1', 'score': 0.5386364, 'word': ' evitar problemas', 'start': 80, 'end': 95}, {'entity_group': 'LABEL_0', 'score': 0.608792, 'word': ' recorrentes software visando melhorar qualidade robustez produto', 'start': 97, 'end': 160}]
# Resultado para História de Usuário 11: [{'entity_group': 'LABEL_0', 'score': 0.61780125, 'word': ' historia de usuario 11 : testador desejo suporte execucao testis automatizados diferentes dispositivos ambientes garantir consistencia confiabilidade cenarios', 'start': 0, 'end': 157}]
# Resultado para História de Usuário 12: [{'entity_group': 'LABEL_1', 'score': 0.535648, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.6187139, 'word': ' usuario 12 :', 'start': 13, 'end': 23}, {'entity_group': 'LABEL_1', 'score': 0.5320521, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_0', 'score': 0.6876684, 'word': 'tador', 'start': 27, 'end': 32}, {'entity_group': 'LABEL_1', 'score': 0.5340746, 'word': ' preciso', 'start': 34, 'end': 40}, {'entity_group': 'LABEL_0', 'score': 0.70811486, 'word': ' ferramenta', 'start': 42, 'end': 51}, {'entity_group': 'LABEL_1', 'score': 0.5144203, 'word': ' dete', 'start': 53, 'end': 56}, {'entity_group': 'LABEL_0', 'score': 0.54739845, 'word': 'cte automaticamente mudancas requisitos', 'start': 56, 'end': 95}, {'entity_group': 'LABEL_1', 'score': 0.5069794, 'word': ' ajuste', 'start': 97, 'end': 102}, {'entity_group': 'LABEL_0', 'score': 0.57316965, 'word': ' casos', 'start': 104, 'end': 108}, {'entity_group': 'LABEL_1', 'score': 0.548342, 'word': ' teste', 'start': 110, 'end': 114}, {'entity_group': 'LABEL_0', 'score': 0.5210508, 'word': ' correspondentes manter', 'start': 116, 'end': 137}, {'entity_group': 'LABEL_1', 'score': 0.5660248, 'word': ' tes', 'start': 139, 'end': 141}, {'entity_group': 'LABEL_0', 'score': 0.58889925, 'word': 'tis alinhados evolucao aplicativo', 'start': 141, 'end': 174}]
# Resultado para História de Usuário 13: [{'entity_group': 'LABEL_1', 'score': 0.5162306, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.64031285, 'word': ' de usuario 13 : testador quero integracao sistemas controle versao rastrear mudancas requisitos codigo', 'start': 10, 'end': 110}, {'entity_group': 'LABEL_1', 'score': 0.5124119, 'word': ' -', 'start': 111, 'end': 111}, {'entity_group': 'LABEL_0', 'score': 0.68305975, 'word': ' fonte visando gestao eficaz durante ciclo desenvolvimento', 'start': 112, 'end': 168}]
# Resultado para História de Usuário 14: [{'entity_group': 'LABEL_0', 'score': 0.643895, 'word': ' historia de usuario 14 : testador desejo', 'start': 0, 'end': 39}, {'entity_group': 'LABEL_1', 'score': 0.52029765, 'word': ' metricas', 'start': 41, 'end': 48}, {'entity_group': 'LABEL_0', 'score': 0.57113236, 'word': ' detalhadas sobre eficacia', 'start': 50, 'end': 74}, {'entity_group': 'LABEL_1', 'score': 0.5625924, 'word': ' tes', 'start': 76, 'end': 78}, {'entity_group': 'LABEL_0', 'score': 0.6350244, 'word': 'tis incluindo', 'start': 78, 'end': 91}, {'entity_group': 'LABEL_1', 'score': 0.6125843, 'word': ' tax', 'start': 93, 'end': 95}, {'entity_group': 'LABEL_0', 'score': 0.5659167, 'word': 'on cobertura falha avaliar qualidade processo teste', 'start': 95, 'end': 146}]
# Resultado para História de Usuário 15: [{'entity_group': 'LABEL_1', 'score': 0.5290259, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.63191617, 'word': ' usuario 15 : testador preciso suporte execucao', 'start': 13, 'end': 57}, {'entity_group': 'LABEL_1', 'score': 0.5184741, 'word': ' tes', 'start': 59, 'end': 61}, {'entity_group': 'LABEL_0', 'score': 0.5914716, 'word': 'tis desempenho escalabilidade garantir aplicativo', 'start': 61, 'end': 110}, {'entity_group': 'LABEL_1', 'score': 0.5486089, 'word': ' ate', 'start': 112, 'end': 114}, {'entity_group': 'LABEL_0', 'score': 0.6519456, 'word': 'nda', 'start': 114, 'end': 117}, {'entity_group': 'LABEL_1', 'score': 0.5327117, 'word': ' requisitos', 'start': 119, 'end': 128}, {'entity_group': 'LABEL_0', 'score': 0.54918313, 'word': ' sob carga', 'start': 130, 'end': 138}]
# Resultado para História de Usuário 16: [{'entity_group': 'LABEL_0', 'score': 0.6221904, 'word': ' historia de usuario 16 : testador quero analise automatica resultados testis relatorios detalhados sobre problemas encontrados fim facilitar identificacao correcao defeitos', 'start': 0, 'end': 171}]
# Resultado para História de Usuário 17: [{'entity_group': 'LABEL_1', 'score': 0.595359, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.6327857, 'word': ' de usuario 17 : testador desejo', 'start': 10, 'end': 39}, {'entity_group': 'LABEL_1', 'score': 0.553661, 'word': ' si', 'start': 41, 'end': 42}, {'entity_group': 'LABEL_0', 'score': 0.61656296, 'word': 'mular', 'start': 42, 'end': 47}, {'entity_group': 'LABEL_1', 'score': 0.55590445, 'word': ' cenarios', 'start': 49, 'end': 56}, {'entity_group': 'LABEL_0', 'score': 0.5380291, 'word': ' teste complexos', 'start': 58, 'end': 72}, {'entity_group': 'LABEL_1', 'score': 0.5765561, 'word': ' realistas garantir testis', 'start': 74, 'end': 98}, {'entity_group': 'LABEL_0', 'score': 0.5756321, 'word': ' proximos realidade visando validacao', 'start': 100, 'end': 135}, {'entity_group': 'LABEL_1', 'score': 0.52328974, 'word': ' precisa', 'start': 137, 'end': 143}, {'entity_group': 'LABEL_0', 'score': 0.59469825, 'word': ' software', 'start': 145, 'end': 152}]
# Resultado para História de Usuário 18: [{'entity_group': 'LABEL_1', 'score': 0.5039833, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.61595553, 'word': ' de usuario 18 : testador preciso suporte execucao testis regressao automatizados garantir alteracoes codigo introduzam', 'start': 10, 'end': 126}, {'entity_group': 'LABEL_1', 'score': 0.5369338, 'word': ' regres', 'start': 128, 'end': 133}, {'entity_group': 'LABEL_0', 'score': 0.6359953, 'word': 'soes', 'start': 133, 'end': 137}]
# Resultado para História de Usuário 19: [{'entity_group': 'LABEL_1', 'score': 0.5529028, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.6727498, 'word': ' usuario 19 :', 'start': 13, 'end': 23}, {'entity_group': 'LABEL_1', 'score': 0.50486165, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_0', 'score': 0.63211316, 'word': 'tador quero identificacao automatica casos', 'start': 27, 'end': 69}, {'entity_group': 'LABEL_1', 'score': 0.5713222, 'word': ' teste redunda', 'start': 71, 'end': 83}, {'entity_group': 'LABEL_0', 'score': 0.5348592, 'word': 'ntes desnecessarios', 'start': 83, 'end': 102}, {'entity_group': 'LABEL_1', 'score': 0.58489764, 'word': ' otimizar esforcos', 'start': 104, 'end': 120}]
# Resultado para História de Usuário 20: [{'entity_group': 'LABEL_0', 'score': 0.6244744, 'word': ' historia de usuario', 'start': 0, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.5036636, 'word': ' 20', 'start': 21, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.6636776, 'word': ' : testador desejo integracao facil ferramentas gerenciamento projetos colaboracao eficiente outros membros equipe desenvolvimento', 'start': 23, 'end': 151}]
# Resultado para História de Usuário 21: [{'entity_group': 'LABEL_1', 'score': 0.5338909, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.63795644, 'word': ' de usuario 21 : testador', 'start': 10, 'end': 32}, {'entity_group': 'LABEL_1', 'score': 0.51028156, 'word': ' preciso', 'start': 34, 'end': 40}, {'entity_group': 'LABEL_0', 'score': 0.5944388, 'word': ' suporte execucao testis usabilidade garantir aplicativo', 'start': 42, 'end': 96}, {'entity_group': 'LABEL_1', 'score': 0.5598991, 'word': ' facil', 'start': 98, 'end': 102}, {'entity_group': 'LABEL_0', 'score': 0.5969578, 'word': ' intuitivo usar', 'start': 104, 'end': 117}]
# Resultado para História de Usuário 22: [{'entity_group': 'LABEL_1', 'score': 0.5686258, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.66485316, 'word': ' usuario 22 :', 'start': 13, 'end': 23}, {'entity_group': 'LABEL_1', 'score': 0.5111461, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_0', 'score': 0.6063771, 'word': 'tador quero ferramenta crie automaticamente conjuntos dado', 'start': 27, 'end': 85}, {'entity_group': 'LABEL_1', 'score': 0.6166052, 'word': ' teste realistas simular condicoes reais', 'start': 87, 'end': 125}, {'entity_group': 'LABEL_0', 'score': 0.5164479, 'word': ' uso', 'start': 127, 'end': 129}]
# Resultado para História de Usuário 23: [{'entity_group': 'LABEL_0', 'score': 0.63324356, 'word': ' historia de usuario 23 : testador desejo integracao ferramentas', 'start': 0, 'end': 62}, {'entity_group': 'LABEL_1', 'score': 0.65690786, 'word': ' monito', 'start': 64, 'end': 69}, {'entity_group': 'LABEL_0', 'score': 0.5271806, 'word': 'ramento', 'start': 69, 'end': 76}, {'entity_group': 'LABEL_1', 'score': 0.50374174, 'word': ' desempenho tempo', 'start': 78, 'end': 93}, {'entity_group': 'LABEL_0', 'score': 0.61600626, 'word': ' real avaliar aplicativo durante', 'start': 95, 'end': 125}, {'entity_group': 'LABEL_1', 'score': 0.534329, 'word': ' tes', 'start': 127, 'end': 129}, {'entity_group': 'LABEL_0', 'score': 0.6604835, 'word': 'tis', 'start': 129, 'end': 132}]
# Resultado para História de Usuário 24: [{'entity_group': 'LABEL_0', 'score': 0.63435185, 'word': ' historia de usuario 24 : testador preciso suporte execucao testis localizacao internacionalizacao garantir aplicativo compativel diferentes', 'start': 0, 'end': 138}, {'entity_group': 'LABEL_1', 'score': 0.56315565, 'word': ' idio', 'start': 140, 'end': 143}, {'entity_group': 'LABEL_0', 'score': 0.65995395, 'word': 'mas regioes', 'start': 143, 'end': 154}]
# Resultado para História de Usuário 25: [{'entity_group': 'LABEL_1', 'score': 0.5910607, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.62044823, 'word': ' de usuario 25 :', 'start': 10, 'end': 23}, {'entity_group': 'LABEL_1', 'score': 0.50164557, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_0', 'score': 0.6448599, 'word': 'tador quero geracao automatica dado', 'start': 27, 'end': 62}, {'entity_group': 'LABEL_1', 'score': 0.5766907, 'word': ' teste sinteticos', 'start': 64, 'end': 79}, {'entity_group': 'LABEL_0', 'score': 0.5246064, 'word': ' complementar casos manuais', 'start': 81, 'end': 106}]
# Resultado para História de Usuário 26: [{'entity_group': 'LABEL_0', 'score': 0.6152377, 'word': ' historia de usuario 26 : testador desejo suporte execucao testis acessibilidade garantir aplicativo acessivel todos usuarios', 'start': 0, 'end': 123}]
# Resultado para História de Usuário 27: [{'entity_group': 'LABEL_0', 'score': 0.6724794, 'word': ' historia de usuario 27 : testador preciso suporte execucao testis integracao continua garantir alteracoes codigo quebrem outras partes sistema', 'start': 0, 'end': 141}]
# Resultado para História de Usuário 28: [{'entity_group': 'LABEL_1', 'score': 0.5615553, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.6726864, 'word': ' usuario 28 :', 'start': 13, 'end': 23}, {'entity_group': 'LABEL_1', 'score': 0.50788003, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_0', 'score': 0.6177229, 'word': 'tador quero identificacao automatica casos', 'start': 27, 'end': 69}, {'entity_group': 'LABEL_1', 'score': 0.56478727, 'word': ' teste incompletos mal definidos garantir qualidade tes', 'start': 71, 'end': 124}, {'entity_group': 'LABEL_0', 'score': 0.5874024, 'word': 'tis', 'start': 124, 'end': 127}]
# Resultado para História de Usuário 29: [{'entity_group': 'LABEL_1', 'score': 0.529092, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.61238664, 'word': ' usuario 29 : testador desejo identificacao automatica dependencias casos', 'start': 13, 'end': 83}, {'entity_group': 'LABEL_1', 'score': 0.54626465, 'word': ' teste garantir', 'start': 85, 'end': 98}, {'entity_group': 'LABEL_0', 'score': 0.542205, 'word': ' sequencia logica execucao', 'start': 100, 'end': 124}, {'entity_group': 'LABEL_1', 'score': 0.50200063, 'word': ' tes', 'start': 126, 'end': 128}, {'entity_group': 'LABEL_0', 'score': 0.62178683, 'word': 'tis', 'start': 128, 'end': 131}]
# Resultado para História de Usuário 30: [{'entity_group': 'LABEL_1', 'score': 0.5230409, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.62598544, 'word': ' usuario 30 : testador preciso suporte execucao testis recuperacao desastres avaliar capacidade sistema recuperar falhas', 'start': 13, 'end': 130}]
# Resultado para História de Usuário 31: [{'entity_group': 'LABEL_1', 'score': 0.5500519, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.6433136, 'word': ' usuario 31 :', 'start': 13, 'end': 23}, {'entity_group': 'LABEL_1', 'score': 0.5171433, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_0', 'score': 0.64251274, 'word': 'tador quero ferramenta identifique automaticamente casos', 'start': 27, 'end': 83}, {'entity_group': 'LABEL_1', 'score': 0.50352204, 'word': ' teste', 'start': 85, 'end': 89}, {'entity_group': 'LABEL_0', 'score': 0.69425243, 'word': ' paralelizaveis', 'start': 91, 'end': 104}, {'entity_group': 'LABEL_1', 'score': 0.5600496, 'word': ' otimizar', 'start': 106, 'end': 113}, {'entity_group': 'LABEL_0', 'score': 0.5907596, 'word': ' execucao testis', 'start': 115, 'end': 129}]
# Resultado para História de Usuário 32: [{'entity_group': 'LABEL_1', 'score': 0.5303483, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.64960027, 'word': ' usuario 32 :', 'start': 13, 'end': 23}, {'entity_group': 'LABEL_1', 'score': 0.57348824, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_0', 'score': 0.68711907, 'word': 'tador', 'start': 27, 'end': 32}, {'entity_group': 'LABEL_1', 'score': 0.52601534, 'word': ' desejo', 'start': 34, 'end': 39}, {'entity_group': 'LABEL_0', 'score': 0.55146676, 'word': ' simulacao', 'start': 41, 'end': 49}, {'entity_group': 'LABEL_1', 'score': 0.5706549, 'word': ' cenarios teste carga', 'start': 51, 'end': 70}, {'entity_group': 'LABEL_0', 'score': 0.516051, 'word': ' extremamente alta avaliar', 'start': 72, 'end': 96}, {'entity_group': 'LABEL_1', 'score': 0.52135277, 'word': ' capacidade', 'start': 98, 'end': 107}, {'entity_group': 'LABEL_0', 'score': 0.58800143, 'word': ' escalabilidade sistema', 'start': 109, 'end': 130}]
# Resultado para História de Usuário 33: [{'entity_group': 'LABEL_0', 'score': 0.64735234, 'word': ' historia de usuario 33 : testador preciso suporte execucao testis compatibilidade diferentes navegadores dispositivos garantir experiencia consistente todos usuarios', 'start': 0, 'end': 164}]
# Resultado para História de Usuário 34: [{'entity_group': 'LABEL_1', 'score': 0.5266712, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.6393618, 'word': ' de usuario 34 :', 'start': 10, 'end': 23}, {'entity_group': 'LABEL_1', 'score': 0.5177641, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_0', 'score': 0.6515872, 'word': 'tador quero geracao automatica relatorios', 'start': 27, 'end': 68}, {'entity_group': 'LABEL_1', 'score': 0.53160006, 'word': ' teste personalizados', 'start': 70, 'end': 89}, {'entity_group': 'LABEL_0', 'score': 0.5715177, 'word': ' comunicar eficazmente resultados', 'start': 91, 'end': 122}, {'entity_group': 'LABEL_1', 'score': 0.5227831, 'word': ' tes', 'start': 124, 'end': 126}, {'entity_group': 'LABEL_0', 'score': 0.62162113, 'word': 'tis', 'start': 126, 'end': 129}]
# Resultado para História de Usuário 35: [{'entity_group': 'LABEL_1', 'score': 0.5303477, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.637985, 'word': ' usuario 35 :', 'start': 13, 'end': 23}, {'entity_group': 'LABEL_1', 'score': 0.5684023, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_0', 'score': 0.6277113, 'word': 'tador', 'start': 27, 'end': 32}, {'entity_group': 'LABEL_1', 'score': 0.5384709, 'word': ' desejo rastreamento', 'start': 34, 'end': 52}, {'entity_group': 'LABEL_0', 'score': 0.5250069, 'word': ' automatico resultados', 'start': 54, 'end': 74}, {'entity_group': 'LABEL_1', 'score': 0.6357768, 'word': ' teste longo tempo identificar tendencias padroes qualidade', 'start': 76, 'end': 133}]
# Resultado para História de Usuário 36: [{'entity_group': 'LABEL_0', 'score': 0.6221969, 'word': ' historia de usuario 36 : testador preciso suporte execucao testis', 'start': 0, 'end': 64}, {'entity_group': 'LABEL_1', 'score': 0.5495502, 'word': ' regressao progressiva', 'start': 66, 'end': 86}, {'entity_group': 'LABEL_0', 'score': 0.55581355, 'word': ' garantir nova alteracoes que', 'start': 88, 'end': 115}, {'entity_group': 'LABEL_1', 'score': 0.50374043, 'word': 'bre', 'start': 115, 'end': 118}, {'entity_group': 'LABEL_0', 'score': 0.67792565, 'word': 'm funcionalidades existentes', 'start': 118, 'end': 146}]
# Resultado para História de Usuário 37: [{'entity_group': 'LABEL_1', 'score': 0.53906703, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.60391843, 'word': ' de usuario 37 : testador quero sugestoes automaticas aprimorar casos teste existentes aumentar eficiencia eficacia testis', 'start': 10, 'end': 129}]
# Resultado para História de Usuário 38: [{'entity_group': 'LABEL_1', 'score': 0.52449894, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.6338096, 'word': ' de usuario 38 :', 'start': 10, 'end': 23}, {'entity_group': 'LABEL_1', 'score': 0.532119, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_0', 'score': 0.74381024, 'word': 'tador', 'start': 27, 'end': 32}, {'entity_group': 'LABEL_1', 'score': 0.51285857, 'word': ' desejo', 'start': 34, 'end': 39}, {'entity_group': 'LABEL_0', 'score': 0.7153831, 'word': ' ferramenta', 'start': 41, 'end': 50}, {'entity_group': 'LABEL_1', 'score': 0.5982995, 'word': ' apre', 'start': 52, 'end': 55}, {'entity_group': 'LABEL_0', 'score': 0.6183443, 'word': 'nda resultados', 'start': 55, 'end': 69}, {'entity_group': 'LABEL_1', 'score': 0.57603496, 'word': ' tes', 'start': 71, 'end': 73}, {'entity_group': 'LABEL_0', 'score': 0.6002201, 'word': 'tis melhore sugestoes futuras otimizacao continua processo teste', 'start': 73, 'end': 137}]
# Resultado para História de Usuário 39: [{'entity_group': 'LABEL_1', 'score': 0.53463435, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.62460047, 'word': ' usuario 39 : testador preciso suporte execucao testis seguranca automatizados identificar vulnerabilidades aplicativo', 'start': 13, 'end': 128}]
# Resultado para História de Usuário 40: [{'entity_group': 'LABEL_1', 'score': 0.556981, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.6078651, 'word': ' de usuario', 'start': 10, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.54300076, 'word': ' 40', 'start': 21, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.6142507, 'word': ' : testador quero integracao ferramentas analise codigo estatico identificar areas risco', 'start': 23, 'end': 109}, {'entity_group': 'LABEL_1', 'score': 0.54477376, 'word': ' avaliacao', 'start': 111, 'end': 119}, {'entity_group': 'LABEL_0', 'score': 0.5138992, 'word': ' abrangente', 'start': 121, 'end': 130}, {'entity_group': 'LABEL_1', 'score': 0.5040196, 'word': ' qualidade', 'start': 132, 'end': 140}]
# Resultado para História de Usuário 41: [{'entity_group': 'LABEL_0', 'score': 0.5960777, 'word': ' historia de usuario', 'start': 0, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.52459204, 'word': ' 41', 'start': 21, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.7670207, 'word': ' :', 'start': 23, 'end': 23}, {'entity_group': 'LABEL_1', 'score': 0.50407684, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_0', 'score': 0.6361209, 'word': 'tador desejo suporte execucao', 'start': 27, 'end': 56}, {'entity_group': 'LABEL_1', 'score': 0.59645665, 'word': ' tes', 'start': 58, 'end': 60}, {'entity_group': 'LABEL_0', 'score': 0.66576797, 'word': 'tis integracao sistema', 'start': 60, 'end': 82}, {'entity_group': 'LABEL_1', 'score': 0.5412257, 'word': ' teste', 'start': 84, 'end': 88}, {'entity_group': 'LABEL_0', 'score': 0.6093689, 'word': ' aceitacao usuario', 'start': 90, 'end': 106}, {'entity_group': 'LABEL_1', 'score': 0.50147814, 'word': ' validar', 'start': 108, 'end': 114}, {'entity_group': 'LABEL_0', 'score': 0.6504362, 'word': ' diferentes partes conformidade', 'start': 116, 'end': 145}, {'entity_group': 'LABEL_1', 'score': 0.5695271, 'word': ' requisitos', 'start': 147, 'end': 156}]
# Resultado para História de Usuário 42: [{'entity_group': 'LABEL_1', 'score': 0.511878, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.6607982, 'word': ' usuario 42 : testador preciso suporte execucao testis confiabilidade disponibilidade garantir aplicativo sempre disponivel funcione', 'start': 13, 'end': 142}, {'entity_group': 'LABEL_1', 'score': 0.5072322, 'word': ' corretamente', 'start': 144, 'end': 155}]
# Resultado para História de Usuário 43: [{'entity_group': 'LABEL_1', 'score': 0.5612026, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.64752924, 'word': ' de usuario 43 :', 'start': 10, 'end': 23}, {'entity_group': 'LABEL_1', 'score': 0.5242291, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_0', 'score': 0.66024584, 'word': 'tador quero ferramenta', 'start': 27, 'end': 49}, {'entity_group': 'LABEL_1', 'score': 0.58570206, 'word': ' su', 'start': 51, 'end': 52}, {'entity_group': 'LABEL_0', 'score': 0.5783391, 'word': 'gira casos', 'start': 52, 'end': 62}, {'entity_group': 'LABEL_1', 'score': 0.5867317, 'word': ' teste base modelos qualidade', 'start': 64, 'end': 91}, {'entity_group': 'LABEL_0', 'score': 0.59140944, 'word': ' software reconhecidos garantir abordagem abrangente padronizada testis', 'start': 93, 'end': 162}]
# Resultado para História de Usuário 44: [{'entity_group': 'LABEL_1', 'score': 0.51977146, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.6328639, 'word': ' usuario 44 : testador desejo integracao ferramentas', 'start': 13, 'end': 62}, {'entity_group': 'LABEL_1', 'score': 0.6385477, 'word': ' auto', 'start': 64, 'end': 67}, {'entity_group': 'LABEL_0', 'score': 0.56285113, 'word': 'macao teste interface usuario', 'start': 67, 'end': 96}, {'entity_group': 'LABEL_1', 'score': 0.562441, 'word': ' automa', 'start': 98, 'end': 103}, {'entity_group': 'LABEL_0', 'score': 0.6789393, 'word': 'tizar', 'start': 103, 'end': 108}, {'entity_group': 'LABEL_1', 'score': 0.55439925, 'word': ' tes', 'start': 110, 'end': 112}, {'entity_group': 'LABEL_0', 'score': 0.6263545, 'word': 'tis interacao', 'start': 112, 'end': 125}]
# Resultado para História de Usuário 45: [{'entity_group': 'LABEL_1', 'score': 0.5328429, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.65505224, 'word': ' de usuario 45 : testador preciso suporte execucao testis estresse robustez avaliar estabilidade confiabilidade aplicativo sob condicoes adversas', 'start': 10, 'end': 152}]
# Resultado para História de Usuário 46: [{'entity_group': 'LABEL_1', 'score': 0.54606426, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.7012582, 'word': ' usuario 46 :', 'start': 13, 'end': 23}, {'entity_group': 'LABEL_1', 'score': 0.56829953, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_0', 'score': 0.63965124, 'word': 'tador quero ferramenta', 'start': 27, 'end': 49}, {'entity_group': 'LABEL_1', 'score': 0.57437915, 'word': ' su', 'start': 51, 'end': 52}, {'entity_group': 'LABEL_0', 'score': 0.5692124, 'word': 'gira casos', 'start': 52, 'end': 62}, {'entity_group': 'LABEL_1', 'score': 0.55662173, 'word': ' teste', 'start': 64, 'end': 68}, {'entity_group': 'LABEL_0', 'score': 0.63604397, 'word': ' areas', 'start': 70, 'end': 74}, {'entity_group': 'LABEL_1', 'score': 0.55122256, 'word': ' alto risco', 'start': 76, 'end': 85}, {'entity_group': 'LABEL_0', 'score': 0.559109, 'word': ' complexidade', 'start': 87, 'end': 98}, {'entity_group': 'LABEL_1', 'score': 0.53826207, 'word': ' priori', 'start': 100, 'end': 105}, {'entity_group': 'LABEL_0', 'score': 0.67425895, 'word': 'zar', 'start': 105, 'end': 108}, {'entity_group': 'LABEL_1', 'score': 0.53411126, 'word': ' esforcos', 'start': 110, 'end': 117}]
# Resultado para História de Usuário 47: [{'entity_group': 'LABEL_0', 'score': 0.6411494, 'word': ' historia de usuario 47 : testador desejo integracao ferramentas gerenciamento defeitos rastreamento correcoes gestao eficaz problemas encontrados durante testis', 'start': 0, 'end': 159}]
# Resultado para História de Usuário 48: [{'entity_group': 'LABEL_1', 'score': 0.54211295, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.684439, 'word': ' usuario 48 :', 'start': 13, 'end': 23}, {'entity_group': 'LABEL_1', 'score': 0.5399462, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_0', 'score': 0.69857156, 'word': 'tador', 'start': 27, 'end': 32}, {'entity_group': 'LABEL_1', 'score': 0.52192724, 'word': ' preciso', 'start': 34, 'end': 40}, {'entity_group': 'LABEL_0', 'score': 0.549647, 'word': ' suporte execucao', 'start': 42, 'end': 57}, {'entity_group': 'LABEL_1', 'score': 0.6263779, 'word': ' tes', 'start': 59, 'end': 61}, {'entity_group': 'LABEL_0', 'score': 0.59983134, 'word': 'tis usabilidade', 'start': 61, 'end': 76}, {'entity_group': 'LABEL_1', 'score': 0.5084209, 'word': ' remo', 'start': 78, 'end': 81}, {'entity_group': 'LABEL_0', 'score': 0.707177, 'word': 'ta', 'start': 81, 'end': 83}, {'entity_group': 'LABEL_1', 'score': 0.53538984, 'word': ' teste usuario beta cole', 'start': 85, 'end': 107}, {'entity_group': 'LABEL_0', 'score': 0.56309634, 'word': 'tar feedback usuarios reais', 'start': 107, 'end': 134}]
# Resultado para História de Usuário 49: [{'entity_group': 'LABEL_1', 'score': 0.5053776, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_0', 'score': 0.64416486, 'word': ' de usuario 49 : testador quero ferramenta forneca feedback tempo real durante execucao testis facilitar identificacao imediata problemas', 'start': 10, 'end': 144}]
# Resultado para História de Usuário 50: [{'entity_group': 'LABEL_1', 'score': 0.5390824, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.6042229, 'word': ' usuario 50 :', 'start': 13, 'end': 23}, {'entity_group': 'LABEL_1', 'score': 0.5842025, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_0', 'score': 0.6008987, 'word': 'tador desejo integracao ferramentas', 'start': 27, 'end': 62}, {'entity_group': 'LABEL_1', 'score': 0.67260724, 'word': ' auto', 'start': 64, 'end': 67}, {'entity_group': 'LABEL_0', 'score': 0.55602956, 'word': 'macao infraestrutura', 'start': 67, 'end': 87}, {'entity_group': 'LABEL_1', 'score': 0.5599096, 'word': ' provisionamento configuracao automatizados', 'start': 89, 'end': 130}, {'entity_group': 'LABEL_0', 'score': 0.5851706, 'word': ' facilitar', 'start': 132, 'end': 140}, {'entity_group': 'LABEL_1', 'score': 0.5404331, 'word': ' preparacao', 'start': 142, 'end': 151}, {'entity_group': 'LABEL_0', 'score': 0.5220668, 'word': ' ambiente', 'start': 153, 'end': 160}, {'entity_group': 'LABEL_1', 'score': 0.54015625, 'word': ' teste', 'start': 162, 'end': 166}]
# Resultado para História de Usuário 51: [{'entity_group': 'LABEL_1', 'score': 0.52260196, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.6439496, 'word': ' usuario 51 : testador', 'start': 13, 'end': 32}, {'entity_group': 'LABEL_1', 'score': 0.5112531, 'word': ' preciso', 'start': 34, 'end': 40}, {'entity_group': 'LABEL_0', 'score': 0.59907305, 'word': ' suporte execucao testis', 'start': 42, 'end': 64}, {'entity_group': 'LABEL_1', 'score': 0.5187273, 'word': ' comparacao desempenho', 'start': 66, 'end': 86}, {'entity_group': 'LABEL_0', 'score': 0.5874276, 'word': ' versoes anteriores atuais aplicativo avaliar impacto mudancas', 'start': 88, 'end': 148}]

# %%
def extracao(freq_dist):
    frequencia = " ".join(freq_dist.keys()).lower()

    autor = None
    if "testador" in frequencia:
        autor = "Testador"

    finalidade = None
    for word in ["quero", "preciso", "desejo"]:
        if word in frequencia:
            pos_inicial = frequencia.find(word) + len(word)
            finalidade = frequencia[pos_inicial:].strip().split(",")[0]
            break
    if "para" in frequencia:
        pos_inicial_para = frequencia.find("para") + len("para")
        finalidade = "para " + frequencia[pos_inicial_para:].strip().split(",")[0]


    return autor, finalidade


for i, freq_dist in enumerate(freq_dist):
    autor, finalidade = extracao(freq_dist)
    print("História do Usuário:", historias_usuario[i])
    print("Autor:", autor)
    print("Finalidade:", finalidade)
    print()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-117-e62efb354a58> in <cell line: 22>()
#      21
#      22 for i, freq_dist in enumerate(freq_dist):
# ---> 23     autor, finalidade = extracao(freq_dist)
#      24     print("História do Usuário:", historias_usuario[i])
#      25     print("Autor:", autor)
#
# <ipython-input-117-e62efb354a58> in extracao(freq_dist)
#       1 def extracao(freq_dist):
# ----> 2     frequencia = " ".join(freq_dist.keys()).lower()
#       3
#       4     autor = None
#       5     if "testador" in frequencia:
#
# AttributeError: 'str' object has no attribute 'keys'

# %%
detalhes_palavras_chave = []

for palavra, freq_dist in zip(["testador", "quero", "integração", "ferramentas", "análise", "código", "estático", "identificar", "áreas", "risco", "avaliação", "abrangente", "qualidade", "suporte", "execução", "testis", "sistema", "teste", "aceitação", "usuário", "validar", "diferentes", "partes", "conformidade", "requisitos"], freq_dists):
    detalhe = {
        "palavra": palavra,
        "tamanho": len(palavra.encode('utf-8')),
        "tipo": type(palavra).__name__, 
        "lematizacao": None, 
        "tokens": None,  
        "binario": "Sim" if palavra.lower() in freq_dist else "Não", 
        "null": "Não",  
        "score": freq_dist[palavra],  
        "finalidade": None,  
        "finalidade_palavra": None, 
        "finalidade_posicao": None 
    }
    detalhes_palavras_chave.append(detalhe)


for detalhe in detalhes_palavras_chave:
    print(detalhe)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-114-e5d5260dc7f8> in <cell line: 4>()
#      11         "binario": "Sim" if palavra.lower() in freq_dist else "Não",  # Se é ou não uma palavra-chave relevante
#      12         "null": "Não",  # Não há valores nulos nas palavras
# ---> 13         "score": freq_dist[palavra],  # Frequência da palavra
#      14         "finalidade": None,  # Inicialmente nenhum propósito definido
#      15         "finalidade_palavra": None,  # Palavra-chave da finalidade
#
# TypeError: string indices must be integers

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import recall_score, f1_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
# !pip install scikit-learn
from random import choice
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.25.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.4.0)

# %%
X = freq_dists
rotulos_possiveis = ["testador", "aplicativo", "desempenho", "teste"]
y = [choice(rotulos_possiveis) for _ in range(len(freq_dists))]
vetorizacao = TfidfVectorizer()
X = vetorizacao.fit_transform([" ".join(freq_dist.keys()) for freq_dist in X])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.4, random_state=42,stratify=y)

# %%
from sklearn.linear_model import LogisticRegression
modelo_regressao = LogisticRegression()
modelo_regressao.fit(X_train, y_train)
y_predicted = modelo_regressao.predict(X_test)
acuracia = accuracy_score(y_test, y_predicted)
print("Acurácia:", acuracia)
# Out:
# Acurácia: 0.2857142857142857

# %%
clf_tf = DecisionTreeClassifier(criterion='gini',max_depth=15)
clf_tf.fit(X_train, y_train)
pred_arvore_entropy_tf = clf_tf.predict(X_test)
accuracy_decision = accuracy_score(y_test,pred_arvore_entropy_tf)
recall = recall_score(y_test, pred_arvore_entropy_tf, average='weighted')
f1 = f1_score(y_test, pred_arvore_entropy_tf, average='weighted')
print(f"Resultado: ",accuracy_decision)
print(f"Resultado: ",recall)
print(f"Resultado: ",f1)
# Out:
# Resultado:  0.23809523809523808
# Resultado:  0.23809523809523808
# Resultado:  0.22222222222222218

# %%
clf = DecisionTreeClassifier(criterion='entropy',max_depth=7)
clf.fit(X_train, y_train)
pred_arvore_entropy = clf.predict(X_test)
accuracy_decision = accuracy_score(y_test,pred_arvore_entropy)
recall_entropy = recall_score(y_test, pred_arvore_entropy, average='weighted')
f1_entropy = f1_score(y_test, pred_arvore_entropy, average='weighted')
print(f"Resultado: ",accuracy_decision)
print(f"Resultado: ",recall_entropy)
print(f"Resultado: ",f1_entropy)
# Out:
# Resultado:  0.23809523809523808
# Resultado:  0.23809523809523808
# Resultado:  0.21630591630591628

# %%
clf_tf3 = KNeighborsClassifier(metric='manhattan',n_neighbors=3)
clf_tf3.fit(X_train, y_train)
pred_knn_tf = clf_tf3.predict(X_test)
acuracy_KNN = accuracy_score(y_test,pred_knn_tf)
recall_knn = recall_score(y_test, pred_knn_tf, average='weighted')
f1_knn = f1_score(y_test, pred_knn_tf, average='weighted')
print(f"Resultado: ",acuracy_KNN)
print(f"Resultado: ",recall_knn)
print(f"Resultado: ",f1_knn)
# Out:
# Resultado:  0.19047619047619047
# Resultado:  0.19047619047619047
# Resultado:  0.10385692738633914

# %%
clf_tf4 = KNeighborsClassifier(n_neighbors=5,weights='distance', algorithm='brute')
clf_tf4.fit(X_train, y_train)
pred_knn_tf2 = clf_tf4.predict(X_test)
acuracy_KNN2 = accuracy_score(y_test,pred_knn_tf2)
recall_knn2 = recall_score(y_test, pred_knn_tf2, average='weighted')
f1_knn2 = f1_score(y_test, pred_knn_tf2, average='weighted')
print(f"Resultado: ",acuracy_KNN)
print(f"Resultado: ",recall_knn2)
print(f"Resultado: ",f1_knn2)
# Out:
# Resultado:  0.19047619047619047
# Resultado:  0.3333333333333333
# Resultado:  0.3235294117647059

# %%
svc = SVC(kernel='linear', C=0.05)
svc.fit(X_train, y_train)
pred_svc = svc.predict(X_test)
accuracy_svc = accuracy_score(y_test, pred_svc)
recall_svc = recall_score(y_test, pred_svc, average='weighted')
f1_svc = f1_score(y_test, pred_svc, average='weighted')
print(f"Resultado: ",accuracy_svc)
print(f"Resultado: ",recall_svc)
print(f"Resultado: ",f1_svc)
# Out:
# Resultado:  0.3333333333333333
# Resultado:  0.3333333333333333
# Resultado:  0.16666666666666666

# %%
from tensorflow.keras import layers
import tensorflow_datasets as tfds
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt
from tensorflow import keras
import tensorflow_hub as hub
import tensorflow as tf

# %%
le_rn = LabelEncoder()
ytrain = le_rn.fit_transform(y_train)
ytest = le_rn.transform(y_test)

# %%
Xtrain = np.expand_dims(X_train.toarray(), axis=1)
Xtest = np.expand_dims(X_test.toarray(), axis=1)

# %%
num_classes = 4
model = tf.keras.Sequential([
    layers.LSTM(128, input_shape=(Xtrain.shape[1], Xtrain.shape[2])),
    layers.Dense(64, activation='relu'),
    layers.Dense(num_classes, activation='softmax')
])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
EPOCHS = 20
history = model.fit(Xtrain, ytrain, epochs=EPOCHS, batch_size=32, validation_data=(Xtest, ytest))
# Out:
# Epoch 1/20
# 1/1 [==============================] - 3s 3s/step - loss: 1.3862 - accuracy: 0.2000 - val_loss: 1.3874 - val_accuracy: 0.2381
# Epoch 2/20
# 1/1 [==============================] - 0s 73ms/step - loss: 1.3779 - accuracy: 0.4333 - val_loss: 1.3865 - val_accuracy: 0.2857
# Epoch 3/20
# 1/1 [==============================] - 0s 71ms/step - loss: 1.3702 - accuracy: 0.6000 - val_loss: 1.3856 - val_accuracy: 0.3333
# Epoch 4/20
# 1/1 [==============================] - 0s 60ms/step - loss: 1.3627 - accuracy: 0.7000 - val_loss: 1.3847 - val_accuracy: 0.3333
# Epoch 5/20
# 1/1 [==============================] - 0s 86ms/step - loss: 1.3553 - accuracy: 0.7000 - val_loss: 1.3837 - val_accuracy: 0.3810
# Epoch 6/20
# 1/1 [==============================] - 0s 79ms/step - loss: 1.3479 - accuracy: 0.6667 - val_loss: 1.3829 - val_accuracy: 0.3810
# Epoch 7/20
# 1/1 [==============================] - 0s 77ms/step - loss: 1.3403 - accuracy: 0.6667 - val_loss: 1.3820 - val_accuracy: 0.4286
# Epoch 8/20
# 1/1 [==============================] - 0s 71ms/step - loss: 1.3325 - accuracy: 0.6667 - val_loss: 1.3812 - val_accuracy: 0.4286
# Epoch 9/20
# 1/1 [==============================] - 0s 76ms/step - loss: 1.3244 - accuracy: 0.6667 - val_loss: 1.3804 - val_accuracy: 0.3810
# Epoch 10/20
# 1/1 [==============================] - 0s 66ms/step - loss: 1.3160 - accuracy: 0.7000 - val_loss: 1.3797 - val_accuracy: 0.4286
# Epoch 11/20
# 1/1 [==============================] - 0s 81ms/step - loss: 1.3073 - accuracy: 0.7000 - val_loss: 1.3790 - val_accuracy: 0.4286
# Epoch 12/20
# 1/1 [==============================] - 0s 69ms/step - loss: 1.2980 - accuracy: 0.6667 - val_loss: 1.3784 - val_accuracy: 0.4286
# Epoch 13/20
# 1/1 [==============================] - 0s 60ms/step - loss: 1.2883 - accuracy: 0.6667 - val_loss: 1.3778 - val_accuracy: 0.4286
# Epoch 14/20
# 1/1 [==============================] - 0s 54ms/step - loss: 1.2780 - accuracy: 0.6667 - val_loss: 1.3772 - val_accuracy: 0.4286
# Epoch 15/20
# 1/1 [==============================] - 0s 46ms/step - loss: 1.2673 - accuracy: 0.6667 - val_loss: 1.3766 - val_accuracy: 0.4286
# Epoch 16/20
# 1/1 [==============================] - 0s 44ms/step - loss: 1.2562 - accuracy: 0.6667 - val_loss: 1.3761 - val_accuracy: 0.4286
# Epoch 17/20
# 1/1 [==============================] - 0s 61ms/step - loss: 1.2444 - accuracy: 0.6667 - val_loss: 1.3757 - val_accuracy: 0.4286
# Epoch 18/20
# 1/1 [==============================] - 0s 45ms/step - loss: 1.2321 - accuracy: 0.6667 - val_loss: 1.3754 - val_accuracy: 0.4286
# Epoch 19/20
# 1/1 [==============================] - 0s 46ms/step - loss: 1.2190 - accuracy: 0.7000 - val_loss: 1.3752 - val_accuracy: 0.3810
# Epoch 20/20
# 1/1 [==============================] - 0s 44ms/step - loss: 1.2054 - accuracy: 0.7000 - val_loss: 1.3750 - val_accuracy: 0.3810

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(len(acc))

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Acuracia no treino')
plt.plot(epochs_range, val_acc, label='Acuracia na validacao')
plt.legend(loc='lower right')
plt.title('Acuracia no treino na validacao')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Perda no treino')
plt.plot(epochs_range, val_loss, label='Perda na validacao')
plt.legend(loc='upper right')
plt.title('Perda no treino e na validacao')
plt.show()

# %%
model_drop = tf.keras.Sequential([
    layers.LSTM(128, input_shape=(Xtrain.shape[1], Xtrain.shape[2])),
    layers.Dense(64, activation='relu'),
    keras.layers.Dropout(rate=0.5),
    layers.Dense(num_classes, activation='softmax')
])

# %%
model_drop.compile(optimizer='adam',
                   loss='sparse_categorical_crossentropy',
                   metrics=['accuracy'])

# %%
EPOCHS = 20
history_drop = model_drop.fit(Xtrain, ytrain, epochs=EPOCHS, batch_size=32, validation_data=(Xtest, ytest))
# Out:
# Epoch 1/20
# 1/1 [==============================] - 2s 2s/step - loss: 1.3861 - accuracy: 0.3000 - val_loss: 1.3868 - val_accuracy: 0.1429
# Epoch 2/20
# 1/1 [==============================] - 0s 61ms/step - loss: 1.3839 - accuracy: 0.3000 - val_loss: 1.3857 - val_accuracy: 0.2857
# Epoch 3/20
# 1/1 [==============================] - 0s 66ms/step - loss: 1.3758 - accuracy: 0.4667 - val_loss: 1.3845 - val_accuracy: 0.4286
# Epoch 4/20
# 1/1 [==============================] - 0s 42ms/step - loss: 1.3700 - accuracy: 0.4667 - val_loss: 1.3837 - val_accuracy: 0.4286
# Epoch 5/20
# 1/1 [==============================] - 0s 42ms/step - loss: 1.3582 - accuracy: 0.6000 - val_loss: 1.3830 - val_accuracy: 0.3810
# Epoch 6/20
# 1/1 [==============================] - 0s 43ms/step - loss: 1.3635 - accuracy: 0.4667 - val_loss: 1.3823 - val_accuracy: 0.3810
# Epoch 7/20
# 1/1 [==============================] - 0s 41ms/step - loss: 1.3521 - accuracy: 0.5667 - val_loss: 1.3818 - val_accuracy: 0.3333
# Epoch 8/20
# 1/1 [==============================] - 0s 44ms/step - loss: 1.3490 - accuracy: 0.6000 - val_loss: 1.3813 - val_accuracy: 0.3333
# Epoch 9/20
# 1/1 [==============================] - 0s 43ms/step - loss: 1.3473 - accuracy: 0.6333 - val_loss: 1.3808 - val_accuracy: 0.3333
# Epoch 10/20
# 1/1 [==============================] - 0s 58ms/step - loss: 1.3368 - accuracy: 0.5000 - val_loss: 1.3803 - val_accuracy: 0.3333
# Epoch 11/20
# 1/1 [==============================] - 0s 58ms/step - loss: 1.3332 - accuracy: 0.6000 - val_loss: 1.3797 - val_accuracy: 0.3333
# Epoch 12/20
# 1/1 [==============================] - 0s 61ms/step - loss: 1.3184 - accuracy: 0.7000 - val_loss: 1.3792 - val_accuracy: 0.3333
# Epoch 13/20
# 1/1 [==============================] - 0s 70ms/step - loss: 1.3217 - accuracy: 0.5333 - val_loss: 1.3787 - val_accuracy: 0.3333
# Epoch 14/20
# 1/1 [==============================] - 0s 76ms/step - loss: 1.3138 - accuracy: 0.5333 - val_loss: 1.3782 - val_accuracy: 0.3333
# Epoch 15/20
# 1/1 [==============================] - 0s 59ms/step - loss: 1.3104 - accuracy: 0.6667 - val_loss: 1.3778 - val_accuracy: 0.3333
# Epoch 16/20
# 1/1 [==============================] - 0s 59ms/step - loss: 1.2997 - accuracy: 0.6333 - val_loss: 1.3773 - val_accuracy: 0.3333
# Epoch 17/20
# 1/1 [==============================] - 0s 42ms/step - loss: 1.2968 - accuracy: 0.6333 - val_loss: 1.3768 - val_accuracy: 0.3333
# Epoch 18/20
# 1/1 [==============================] - 0s 42ms/step - loss: 1.2914 - accuracy: 0.5667 - val_loss: 1.3763 - val_accuracy: 0.3333
# Epoch 19/20
# 1/1 [==============================] - 0s 45ms/step - loss: 1.2810 - accuracy: 0.6000 - val_loss: 1.3759 - val_accuracy: 0.3333
# Epoch 20/20
# 1/1 [==============================] - 0s 61ms/step - loss: 1.2700 - accuracy: 0.6000 - val_loss: 1.3756 - val_accuracy: 0.3333

# %%
 #Criar um dicionário para contar o número de ocorrências de cada rótulo para a segunda LSTM
contagem_rotulos_drop = {}

# Preencher o dicionário com os dados para a segunda LSTM
for (_, (_, rotulo_original)) in dados_primitivos.items():
    if rotulo_original not in contagem_rotulos_drop:
        contagem_rotulos_drop[rotulo_original] = 0
    contagem_rotulos_drop[rotulo_original] += 1

# Imprimir as estatísticas sobre os rótulos processados para a segunda LSTM
print("\nEstatísticas sobre os rótulos processados para a segunda LSTM:")
for rotulo, contagem in contagem_rotulos_drop.items():
    print(f"Rótulo: {rotulo}, Total: {contagem}")
# Out:
# Estatísticas sobre os rótulos processados para a segunda LSTM:
# Rótulo: aplicativo, Total: 13
# Rótulo: desempenho, Total: 13
# Rótulo: testador, Total: 13
# Rótulo: teste, Total: 12

# %%
acc2 = history_drop.history['accuracy']
val_acc2 = history_drop.history['val_accuracy']
loss2 = history_drop.history['loss']
val_loss2 = history_drop.history['val_loss']

epochs_range = range(len(acc2))

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc2, label='Acuracia no treino')
plt.plot(epochs_range, val_acc2, label='Acuracia na validacao')
plt.legend(loc='lower right')
plt.title('Acuracia no treino na validacao')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss2, label='Perda no treino')
plt.plot(epochs_range, val_loss2, label='Perda na validacao')
plt.legend(loc='upper right')
plt.title('Perda no treino e na validacao')
plt.show()

# %%
model_early = tf.keras.Sequential([
    layers.LSTM(128, input_shape=(Xtrain.shape[1], Xtrain.shape[2])),
    layers.Dense(64, activation='relu'),
    layers.Dense(num_classes, activation='softmax')
])

# %%
model_early.compile(optimizer='adam',
                   loss='sparse_categorical_crossentropy',
                   metrics=['accuracy'])

# %%
callbacks = [
    keras.callbacks.EarlyStopping(
        monitor="val_loss",
        min_delta=1e-2,
        patience=5,
        restore_best_weights=True,
        verbose=1,
    )
]

# %%
EPOCHS = 100
history_early = model_early.fit(Xtrain, ytrain,callbacks = callbacks, epochs=EPOCHS, batch_size=32, validation_data=(Xtest, ytest))
# Out:
# Epoch 1/100
# 1/1 [==============================] - 5s 5s/step - loss: 1.3870 - accuracy: 0.2333 - val_loss: 1.3847 - val_accuracy: 0.2857
# Epoch 2/100
# 1/1 [==============================] - 0s 93ms/step - loss: 1.3793 - accuracy: 0.5333 - val_loss: 1.3842 - val_accuracy: 0.2857
# Epoch 3/100
# 1/1 [==============================] - 0s 80ms/step - loss: 1.3720 - accuracy: 0.6000 - val_loss: 1.3837 - val_accuracy: 0.2857
# Epoch 4/100
# 1/1 [==============================] - 0s 111ms/step - loss: 1.3650 - accuracy: 0.5667 - val_loss: 1.3831 - val_accuracy: 0.3333
# Epoch 5/100
# 1/1 [==============================] - 0s 118ms/step - loss: 1.3582 - accuracy: 0.5333 - val_loss: 1.3825 - val_accuracy: 0.3333
# Epoch 6/100
# 1/1 [==============================] - ETA: 0s - loss: 1.3513 - accuracy: 0.5667Restoring model weights from the end of the best epoch: 1.
# 1/1 [==============================] - 0s 112ms/step - loss: 1.3513 - accuracy: 0.5667 - val_loss: 1.3819 - val_accuracy: 0.3333
# Epoch 6: early stopping

# %%
acc3 = history_early.history['accuracy']
val_acc3 = history_early.history['val_accuracy']
loss3 = history_early.history['loss']
val_loss3 = history_early.history['val_loss']

epochs_range = range(len(acc3))

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc3, label='Acuracia no treino')
plt.plot(epochs_range, val_acc3, label='Acuracia na validacao')
plt.legend(loc='lower right')
plt.title('Acuracia no treino na validacao')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss3, label='Perda no treino')
plt.plot(epochs_range, val_loss3, label='Perda na validacao')
plt.legend(loc='upper right')
plt.title('Perda no treino e na validacao')
plt.show()

# %%
# Criar um dicionário para contar o número de ocorrências de cada rótulo
contagem_rotulos = {}

# Preencher o dicionário com os dados
for (_, (_, rotulo_original)) in dados_primitivos.items():
    if rotulo_original not in contagem_rotulos:
        contagem_rotulos[rotulo_original] = 0
    contagem_rotulos[rotulo_original] += 1

# Imprimir as estatísticas sobre os rótulos processados
print("Estatísticas sobre os rótulos processados:")
for rotulo, contagem in contagem_rotulos.items():
    print(f"Rótulo: {rotulo}, Total: {contagem}")
# Out:
# Estatísticas sobre os rótulos processados:
# Rótulo: aplicativo, Total: 13
# Rótulo: desempenho, Total: 13
# Rótulo: testador, Total: 13
# Rótulo: teste, Total: 12
