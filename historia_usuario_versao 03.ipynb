# %%
# Importando as Bibliotecas necessárias ao Projeto

import nltk
from sklearn.feature_extraction.text import TfidfVectorizer
# !python3 -m spacy download pt_core_news_lg
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.probability import FreqDist
from transformers import pipeline
from nltk.corpus import stopwords
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
# %matplotlib inline
import torch
import string
import re
# Out:
# Collecting pt-core-news-lg==3.7.0
#   Using cached https://github.com/explosion/spacy-models/releases/download/pt_core_news_lg-3.7.0/pt_core_news_lg-3.7.0-py3-none-any.whl (568.2 MB)
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from pt-core-news-lg==3.7.0) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (4.66.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.6.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (24.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (1.25.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.16.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.1.5)
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
# !pip install scikit-learn

from sklearn.tree import plot_tree
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow import keras
import tensorflow_hub as hub
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import shutil
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.25.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.4.0)

# %%
# Classificando o texto das Histórias de Usuário em uma categoria especifica utilizando o modelo de treinamento zero shot

classifier = pipeline("zero-shot-classification")
candidate_labels = ["testador", "suporte", "ferramenta"]
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli and revision c626438 (https://huggingface.co/facebook/bart-large-mnli).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
# Utilizando o modelo de Treino roberta para Identificar as entidades nomeadas

roberta = pipeline("ner", grouped_entities=True, model="joelniklaus/legal-portuguese-roberta-base")
# Out:
# config.json:   0%|          | 0.00/699 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/443M [00:00<?, ?B/s]
# Some weights of RobertaForTokenClassification were not initialized from the model checkpoint at joelniklaus/legal-portuguese-roberta-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# tokenizer_config.json:   0%|          | 0.00/403 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.41M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/167 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/token_classification.py:168: UserWarning: `grouped_entities` is deprecated and will be removed in version v5.0.0, defaulted to `aggregation_strategy="simple"` instead.
#   warnings.warn(

# %%
# Criando as Histórias de Usuários (exemplos de teste para treino) e as guardando em uma lista para ser manipulada de acordo com a necessidade

historias_usuario = [
    "Como Testador eu quero um jeito mais fácil de incluir os requisitos do aplicativo na ferramenta DRL-Mobtest para criar casos de teste que cubram tudo que o aplicativo precisa fazer, sem ter que gastar muito tempo escrevendo manualmente.",
    "Como Testador eu quero uma maneira de ensinar a ferramenta DRL-Mobtest a entender os requisitos do aplicativo usando NLP para fazer com que a ferramenta gere testes automaticamente.",
    "Como Testador eu quero que a ferramenta gere casos de teste abrangentes que cubram integralmente todos os requisitos do aplicativo, assegurando que o software seja completo e funcional, sem depender exclusivamente da criação manual de casos de teste.",
    "Como Testador eu quero que a ferramenta seja integrada com outras ferramentas de gerenciamento, permitindo sincronização automática dos requisitos e facilitando o processo de criação de casos de testes.",
    "Como Testador eu quero que a ferramenta  forneça o recurso de criação de relatórios detalhados sobre a cobertura dos testes, permitindo uma análise precisa sobre sua progressão e identificação das lacunas durante sua execução.",
    "Como testador, quero uma maneira mais fácil de incluir requisitos do aplicativo para criar casos de teste abrangentes, economizando tempo na escrita manual.",
    "Como testador, desejo ensinar a ferramenta a entender os requisitos do aplicativo usando NLP para gerar testes automaticamente.",
    "Como testador, preciso que a ferramenta gere casos de teste completos e funcionais que cubram todos os requisitos do aplicativo.",
    "Como testador, quero integração com outras ferramentas de gerenciamento para sincronizar automaticamente requisitos e facilitar a criação de casos de teste.",
    "Como testador, quero relatórios detalhados sobre a cobertura dos testes para análise precisa durante a execução.",
    "Como testador, desejo que a ferramenta identifique automaticamente os casos de teste mais críticos para priorizar a análise.",
    "Como testador, preciso que a ferramenta sugira casos de teste com base em padrões de uso real do aplicativo.",
    "Como testador, quero sugestões com base em padrões de falha históricos para evitar problemas recorrentes no software.",
    "Como testador, desejo suporte à execução de testes automatizados em diferentes dispositivos e ambientes.",
    "Como testador, preciso que a ferramenta detecte automaticamente mudanças nos requisitos e ajuste os casos de teste correspondentes.",
    "Como testador, quero integração com sistemas de controle de versão para rastrear mudanças nos requisitos e no código-fonte.",
    "Como testador, desejo métricas detalhadas sobre a eficácia dos testes, incluindo taxa de cobertura e taxa de falha.",
    "Como testador, preciso de suporte à execução de testes de desempenho e escalabilidade.",
    "Como testador, quero análise automática dos resultados dos testes para relatórios detalhados sobre problemas encontrados.",
    "Como testador, desejo simular cenários de teste complexos e realistas para garantir testes próximos à realidade.",
    "Como testador, preciso de suporte à execução de testes de regressão automatizados.",
    "Como testador, quero identificação automática de casos de teste redundantes ou desnecessários.",
    "Como testador, desejo integração fácil com ferramentas de gerenciamento de projetos.",
    "Como testador, preciso de suporte à execução de testes de usabilidade.",
    "Como testador, quero que a ferramenta crie automaticamente conjuntos de dados de teste realistas.",
    "Como testador, desejo integração com ferramentas de monitoramento de desempenho em tempo real.",
    "Como testador, preciso de suporte à execução de testes de localização e internacionalização.",
    "Como testador, quero geração automática de dados de teste sintéticos.",
    "Como testador, desejo suporte à execução de testes de acessibilidade.",
    "Como testador, preciso de suporte à execução de testes de integração contínua.",
    "Como testador, quero identificação automática de casos de teste incompletos ou mal definidos.",
    "Como testador, desejo identificação automática de dependências entre casos de teste.",
    "Como testador, preciso de suporte à execução de testes de recuperação de desastres.",
    "Como testador, quero que a ferramenta identifique automaticamente casos de teste paralelizáveis.",
    "Como testador, desejo simulação de cenários de teste de carga extremamente alta.",
    "Como testador, preciso de suporte à execução de testes de compatibilidade com diferentes navegadores e dispositivos.",
    "Como testador, quero geração automática de relatórios de teste personalizados.",
    "Como testador, desejo rastreamento automático de resultados de teste ao longo do tempo.",
    "Como testador, preciso de suporte à execução de testes de regressão progressiva.",
    "Como testador, quero sugestões automáticas para aprimorar os casos de teste existentes.",
    "Como testador, desejo que a ferramenta aprenda com os resultados dos testes e melhore suas sugestões futuras.",
    "Como testador, preciso de suporte à execução de testes de segurança automatizados.",
    "Como testador, quero integração com ferramentas de análise de código estático para identificar áreas de risco.",
    "Como testador, desejo suporte à execução de testes de integração de sistema e teste de aceitação do usuário.",
    "Como testador, preciso de suporte à execução de testes de confiabilidade e disponibilidade.",
    "Como testador, quero que a ferramenta sugira casos de teste com base em modelos de qualidade de software reconhecidos.",
    "Como testador, desejo integração com ferramentas de automação de teste de interface do usuário.",
    "Como testador, preciso de suporte à execução de testes de estresse e robustez.",
    "Como testador, quero que a ferramenta sugira casos de teste para áreas de alto risco e complexidade.",
    "Como testador, desejo integração com ferramentas de gerenciamento de defeitos para rastreamento de correções.",
    "Como testador, preciso de suporte à execução de testes de usabilidade remota e teste de usuário beta.",
    "Como testador, quero que a ferramenta forneça feedback em tempo real durante a execução dos testes.",
    "Como testador, desejo integração com ferramentas de automação de infraestrutura para provisionamento e configuração automatizados.",
    "Como testador, preciso de suporte à execução de testes de comparação de desempenho para versões anteriores e atuais do aplicativo."
  ]

# %%
# Verificando as palavras que são unicas na lista de Histórias de Usuários e a diversidade Léxica encontrada

unicas = set(historias_usuario)

print("Total de palavras unicas:",len(unicas))

print("Diversidade Lexica:",len(unicas)/len(historias_usuario))
# Out:
# Total de palavras unicas: 54
# Diversidade Lexica: 1.0

# %%
#sem_pontuacao = re.findall(r'\b(^[^A-Za-z])\b', historias_usuario, re.IGNORECASE)

# %%
# Crianndo uma classe e função para o processamento de texto

class ProcessadorHistoriasUsuario:
    def __init__(self):
        nltk.download('punkt')
        nltk.download('stopwords')
        nltk.download('wordnet')
        self.lemmatizer = WordNetLemmatizer()
        self.stop_words = set(stopwords.words('portuguese'))

    def processar_historias_usuario(self, historias_usuario):
        freq_dists = []
        for historia_usuario in historias_usuario:
            tokens = word_tokenize(historia_usuario)
            tokens = [token.lower() for token in tokens if token not in string.punctuation]
            tokens = [token for token in tokens if token not in self.stop_words]
            tokens = [self.lemmatizer.lemmatize(token) for token in tokens]
            freq_dist = FreqDist(tokens)
            freq_dists.append(freq_dist)
        return freq_dists

# %%
# Criando um objeto para processar as Histórias de Usuário.

processador = ProcessadorHistoriasUsuario()
freq_dists = processador.processar_historias_usuario(historias_usuario)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
# Imprime as cinco palavras comuns em cada História de Usuário

for i, freq_dist in enumerate(freq_dists):
    print(f"História de Usuário {i+1}: {freq_dist.most_common(5)}")
# Out:
# História de Usuário 1: [('aplicativo', 2), ('testador', 1), ('quero', 1), ('jeito', 1), ('fácil', 1)]
# História de Usuário 2: [('ferramenta', 2), ('testador', 1), ('quero', 1), ('maneira', 1), ('ensinar', 1)]
# História de Usuário 3: [('casos', 2), ('teste', 2), ('testador', 1), ('quero', 1), ('ferramenta', 1)]
# História de Usuário 4: [('testador', 1), ('quero', 1), ('ferramenta', 1), ('integrada', 1), ('outras', 1)]
# História de Usuário 5: [('sobre', 2), ('testador', 1), ('quero', 1), ('ferramenta', 1), ('forneça', 1)]
# História de Usuário 6: [('testador', 1), ('quero', 1), ('maneira', 1), ('fácil', 1), ('incluir', 1)]
# História de Usuário 7: [('testador', 1), ('desejo', 1), ('ensinar', 1), ('ferramenta', 1), ('entender', 1)]
# História de Usuário 8: [('testador', 1), ('preciso', 1), ('ferramenta', 1), ('gere', 1), ('casos', 1)]
# História de Usuário 9: [('testador', 1), ('quero', 1), ('integração', 1), ('outras', 1), ('ferramentas', 1)]
# História de Usuário 10: [('testador', 1), ('quero', 1), ('relatórios', 1), ('detalhados', 1), ('sobre', 1)]
# História de Usuário 11: [('testador', 1), ('desejo', 1), ('ferramenta', 1), ('identifique', 1), ('automaticamente', 1)]
# História de Usuário 12: [('testador', 1), ('preciso', 1), ('ferramenta', 1), ('sugira', 1), ('casos', 1)]
# História de Usuário 13: [('testador', 1), ('quero', 1), ('sugestões', 1), ('base', 1), ('padrões', 1)]
# História de Usuário 14: [('testador', 1), ('desejo', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 15: [('testador', 1), ('preciso', 1), ('ferramenta', 1), ('detecte', 1), ('automaticamente', 1)]
# História de Usuário 16: [('testador', 1), ('quero', 1), ('integração', 1), ('sistemas', 1), ('controle', 1)]
# História de Usuário 17: [('taxon', 2), ('testador', 1), ('desejo', 1), ('métricas', 1), ('detalhadas', 1)]
# História de Usuário 18: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 19: [('testador', 1), ('quero', 1), ('análise', 1), ('automática', 1), ('resultados', 1)]
# História de Usuário 20: [('testador', 1), ('desejo', 1), ('simular', 1), ('cenários', 1), ('teste', 1)]
# História de Usuário 21: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 22: [('testador', 1), ('quero', 1), ('identificação', 1), ('automática', 1), ('casos', 1)]
# História de Usuário 23: [('testador', 1), ('desejo', 1), ('integração', 1), ('fácil', 1), ('ferramentas', 1)]
# História de Usuário 24: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 25: [('testador', 1), ('quero', 1), ('ferramenta', 1), ('crie', 1), ('automaticamente', 1)]
# História de Usuário 26: [('testador', 1), ('desejo', 1), ('integração', 1), ('ferramentas', 1), ('monitoramento', 1)]
# História de Usuário 27: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 28: [('testador', 1), ('quero', 1), ('geração', 1), ('automática', 1), ('dado', 1)]
# História de Usuário 29: [('testador', 1), ('desejo', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 30: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 31: [('testador', 1), ('quero', 1), ('identificação', 1), ('automática', 1), ('casos', 1)]
# História de Usuário 32: [('testador', 1), ('desejo', 1), ('identificação', 1), ('automática', 1), ('dependências', 1)]
# História de Usuário 33: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 34: [('testador', 1), ('quero', 1), ('ferramenta', 1), ('identifique', 1), ('automaticamente', 1)]
# História de Usuário 35: [('testador', 1), ('desejo', 1), ('simulação', 1), ('cenários', 1), ('teste', 1)]
# História de Usuário 36: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 37: [('testador', 1), ('quero', 1), ('geração', 1), ('automática', 1), ('relatórios', 1)]
# História de Usuário 38: [('testador', 1), ('desejo', 1), ('rastreamento', 1), ('automático', 1), ('resultados', 1)]
# História de Usuário 39: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 40: [('testador', 1), ('quero', 1), ('sugestões', 1), ('automáticas', 1), ('aprimorar', 1)]
# História de Usuário 41: [('testador', 1), ('desejo', 1), ('ferramenta', 1), ('aprenda', 1), ('resultados', 1)]
# História de Usuário 42: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 43: [('testador', 1), ('quero', 1), ('integração', 1), ('ferramentas', 1), ('análise', 1)]
# História de Usuário 44: [('testador', 1), ('desejo', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 45: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 46: [('testador', 1), ('quero', 1), ('ferramenta', 1), ('sugira', 1), ('casos', 1)]
# História de Usuário 47: [('testador', 1), ('desejo', 1), ('integração', 1), ('ferramentas', 1), ('automação', 1)]
# História de Usuário 48: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 49: [('testador', 1), ('quero', 1), ('ferramenta', 1), ('sugira', 1), ('casos', 1)]
# História de Usuário 50: [('testador', 1), ('desejo', 1), ('integração', 1), ('ferramentas', 1), ('gerenciamento', 1)]
# História de Usuário 51: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 52: [('testador', 1), ('quero', 1), ('ferramenta', 1), ('forneça', 1), ('feedback', 1)]
# História de Usuário 53: [('testador', 1), ('desejo', 1), ('integração', 1), ('ferramentas', 1), ('automação', 1)]
# História de Usuário 54: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]

# %%
nome, valor = zip(*freq_dists[0].most_common(5))
fig, ax = plt.subplots(figsize=(6,5))
sns.barplot(x=np.array(nome), y=np.array(valor), ax=ax)
plt.show()

# %%
nome,valor = zip(*freq_dist.most_common(5))
fig, ax = plt.subplots(figsize=(6,5))
sns.barplot(x=np.array(nome), y=np.array(valor), ax=ax)
# Out:
# <Axes: >

# %%
for i, historia_usuario in enumerate(historias_usuario):
    result = classifier(historia_usuario, candidate_labels=candidate_labels)
    top_label = result['labels'][0]
    confidence = result['scores'][0]
    print(f"História de Usuário {i+1}: Rótulo Previsto: {top_label}, Confiança: {confidence:.2f}")
# Out:
# História de Usuário 1: Rótulo Previsto: ferramenta, Confiança: 0.70
# História de Usuário 2: Rótulo Previsto: testador, Confiança: 0.64
# História de Usuário 3: Rótulo Previsto: testador, Confiança: 0.64
# História de Usuário 4: Rótulo Previsto: testador, Confiança: 0.73
# História de Usuário 5: Rótulo Previsto: testador, Confiança: 0.70
# História de Usuário 6: Rótulo Previsto: testador, Confiança: 0.95
# História de Usuário 7: Rótulo Previsto: testador, Confiança: 0.68
# História de Usuário 8: Rótulo Previsto: testador, Confiança: 0.69
# História de Usuário 9: Rótulo Previsto: testador, Confiança: 0.87
# História de Usuário 10: Rótulo Previsto: testador, Confiança: 0.95
# História de Usuário 11: Rótulo Previsto: testador, Confiança: 0.66
# História de Usuário 12: Rótulo Previsto: testador, Confiança: 0.68
# História de Usuário 13: Rótulo Previsto: testador, Confiança: 0.94
# História de Usuário 14: Rótulo Previsto: testador, Confiança: 0.76
# História de Usuário 15: Rótulo Previsto: testador, Confiança: 0.72
# História de Usuário 16: Rótulo Previsto: testador, Confiança: 0.91
# História de Usuário 17: Rótulo Previsto: testador, Confiança: 0.95
# História de Usuário 18: Rótulo Previsto: testador, Confiança: 0.72
# História de Usuário 19: Rótulo Previsto: testador, Confiança: 0.92
# História de Usuário 20: Rótulo Previsto: testador, Confiança: 0.91
# História de Usuário 21: Rótulo Previsto: testador, Confiança: 0.82
# História de Usuário 22: Rótulo Previsto: testador, Confiança: 0.98
# História de Usuário 23: Rótulo Previsto: testador, Confiança: 0.80
# História de Usuário 24: Rótulo Previsto: testador, Confiança: 0.81
# História de Usuário 25: Rótulo Previsto: ferramenta, Confiança: 0.53
# História de Usuário 26: Rótulo Previsto: testador, Confiança: 0.80
# História de Usuário 27: Rótulo Previsto: testador, Confiança: 0.75
# História de Usuário 28: Rótulo Previsto: testador, Confiança: 0.95
# História de Usuário 29: Rótulo Previsto: testador, Confiança: 0.82
# História de Usuário 30: Rótulo Previsto: testador, Confiança: 0.80
# História de Usuário 31: Rótulo Previsto: testador, Confiança: 0.95
# História de Usuário 32: Rótulo Previsto: testador, Confiança: 0.92
# História de Usuário 33: Rótulo Previsto: testador, Confiança: 0.77
# História de Usuário 34: Rótulo Previsto: testador, Confiança: 0.61
# História de Usuário 35: Rótulo Previsto: testador, Confiança: 0.90
# História de Usuário 36: Rótulo Previsto: testador, Confiança: 0.75
# História de Usuário 37: Rótulo Previsto: testador, Confiança: 0.95
# História de Usuário 38: Rótulo Previsto: testador, Confiança: 0.94
# História de Usuário 39: Rótulo Previsto: testador, Confiança: 0.78
# História de Usuário 40: Rótulo Previsto: testador, Confiança: 0.94
# História de Usuário 41: Rótulo Previsto: testador, Confiança: 0.61
# História de Usuário 42: Rótulo Previsto: testador, Confiança: 0.82
# História de Usuário 43: Rótulo Previsto: testador, Confiança: 0.76
# História de Usuário 44: Rótulo Previsto: testador, Confiança: 0.73
# História de Usuário 45: Rótulo Previsto: testador, Confiança: 0.75
# História de Usuário 46: Rótulo Previsto: testador, Confiança: 0.80
# História de Usuário 47: Rótulo Previsto: testador, Confiança: 0.74
# História de Usuário 48: Rótulo Previsto: testador, Confiança: 0.77
# História de Usuário 49: Rótulo Previsto: testador, Confiança: 0.66
# História de Usuário 50: Rótulo Previsto: testador, Confiança: 0.77
# História de Usuário 51: Rótulo Previsto: testador, Confiança: 0.77
# História de Usuário 52: Rótulo Previsto: testador, Confiança: 0.54
# História de Usuário 53: Rótulo Previsto: testador, Confiança: 0.87
# História de Usuário 54: Rótulo Previsto: testador, Confiança: 0.70

# %%
roberta(f"Resultado: {historias_usuario}")
# Out:
# [{'entity_group': 'LABEL_0',
#   'score': 0.6801563,
#   'word': " resultado : [ ' como testador",
#   'start': 0,
#   'end': 26},
#  {'entity_group': 'LABEL_1',
#   'score': 0.54031545,
#   'word': ' eu que',
#   'start': 28,
#   'end': 33},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6180153,
#   'word': 'ro um',
#   'start': 33,
#   'end': 38},
#  {'entity_group': 'LABEL_1',
#   'score': 0.640453,
#   'word': ' je',
#   'start': 40,
#   'end': 41},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6702968,
#   'word': 'ito mais facil de incluir os requisitos do',
#   'start': 41,
#   'end': 83},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5988051,
#   'word': ' aplica',
#   'start': 85,
#   'end': 90},
#  {'entity_group': 'LABEL_0',
#   'score': 0.67389226,
#   'word': 'tivo na ferramenta drl - mobtest para criar casos de teste que cubram tudo que o',
#   'start': 90,
#   'end': 168},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5303443,
#   'word': ' aplica',
#   'start': 170,
#   'end': 175},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6399699,
#   'word': 'tivo precisa fazer , sem ter que gastar',
#   'start': 175,
#   'end': 213},
#  {'entity_group': 'LABEL_1',
#   'score': 0.52009934,
#   'word': ' muito',
#   'start': 215,
#   'end': 219},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6733452,
#   'word': " tempo escrevendo manualmente . ' , ' como testador",
#   'start': 221,
#   'end': 266},
#  {'entity_group': 'LABEL_1',
#   'score': 0.57197756,
#   'word': ' eu que',
#   'start': 268,
#   'end': 273},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6332715,
#   'word': 'ro',
#   'start': 273,
#   'end': 275},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5420767,
#   'word': ' uma maneira',
#   'start': 277,
#   'end': 287},
#  {'entity_group': 'LABEL_0',
#   'score': 0.70252186,
#   'word': ' de',
#   'start': 289,
#   'end': 290},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5760706,
#   'word': ' ens',
#   'start': 292,
#   'end': 294},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6463269,
#   'word': 'inar a ferramenta drl - mobtest a entender os requisitos do',
#   'start': 294,
#   'end': 351},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6256918,
#   'word': ' aplica',
#   'start': 353,
#   'end': 358},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6001837,
#   'word': 'tivo usando nlp para',
#   'start': 358,
#   'end': 378},
#  {'entity_group': 'LABEL_1',
#   'score': 0.53038716,
#   'word': ' fazer com',
#   'start': 380,
#   'end': 388},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6315994,
#   'word': ' que a',
#   'start': 390,
#   'end': 394},
#  {'entity_group': 'LABEL_1',
#   'score': 0.57523054,
#   'word': ' ferramenta gere testes automaticamente',
#   'start': 396,
#   'end': 433},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6763319,
#   'word': " . ' , ' como testador",
#   'start': 434,
#   'end': 451},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5336041,
#   'word': ' eu que',
#   'start': 453,
#   'end': 458},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6149092,
#   'word': 'ro que a ferramenta',
#   'start': 458,
#   'end': 477},
#  {'entity_group': 'LABEL_1',
#   'score': 0.57701343,
#   'word': ' gere casos',
#   'start': 479,
#   'end': 488},
#  {'entity_group': 'LABEL_0',
#   'score': 0.67368865,
#   'word': ' de teste',
#   'start': 490,
#   'end': 497},
#  {'entity_group': 'LABEL_1',
#   'score': 0.672591,
#   'word': ' abrangentes',
#   'start': 499,
#   'end': 509},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5466744,
#   'word': ' que cubram',
#   'start': 511,
#   'end': 520},
#  {'entity_group': 'LABEL_1',
#   'score': 0.56751347,
#   'word': ' integralmente',
#   'start': 522,
#   'end': 534},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6819885,
#   'word': ' todos os requisitos do',
#   'start': 536,
#   'end': 557},
#  {'entity_group': 'LABEL_1',
#   'score': 0.56930375,
#   'word': ' aplica',
#   'start': 559,
#   'end': 564},
#  {'entity_group': 'LABEL_0',
#   'score': 0.65913564,
#   'word': 'tivo ,',
#   'start': 564,
#   'end': 569},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6802177,
#   'word': ' assegurando',
#   'start': 571,
#   'end': 581},
#  {'entity_group': 'LABEL_0',
#   'score': 0.64332765,
#   'word': ' que o software seja completo e',
#   'start': 583,
#   'end': 612},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5245861,
#   'word': ' funcional',
#   'start': 614,
#   'end': 622},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6828551,
#   'word': ' , sem depender exclusivamente da criacao manual de',
#   'start': 623,
#   'end': 672},
#  {'entity_group': 'LABEL_1',
#   'score': 0.56836635,
#   'word': ' casos',
#   'start': 674,
#   'end': 678},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6614919,
#   'word': " de teste . ' , ' como",
#   'start': 680,
#   'end': 696},
#  {'entity_group': 'LABEL_1',
#   'score': 0.51052284,
#   'word': ' tes',
#   'start': 698,
#   'end': 700},
#  {'entity_group': 'LABEL_0',
#   'score': 0.8200173,
#   'word': 'tador',
#   'start': 700,
#   'end': 705},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5892923,
#   'word': ' eu que',
#   'start': 707,
#   'end': 712},
#  {'entity_group': 'LABEL_0',
#   'score': 0.59128886,
#   'word': 'ro',
#   'start': 712,
#   'end': 714},
#  {'entity_group': 'LABEL_1',
#   'score': 0.54908395,
#   'word': ' que',
#   'start': 716,
#   'end': 718},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5376868,
#   'word': ' a',
#   'start': 720,
#   'end': 720},
#  {'entity_group': 'LABEL_1',
#   'score': 0.60157764,
#   'word': ' ferramenta seja integrada com',
#   'start': 722,
#   'end': 750},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5146267,
#   'word': ' outras',
#   'start': 752,
#   'end': 757},
#  {'entity_group': 'LABEL_1',
#   'score': 0.637922,
#   'word': ' ferramentas',
#   'start': 759,
#   'end': 769},
#  {'entity_group': 'LABEL_0',
#   'score': 0.60416806,
#   'word': ' de gerenciamento ,',
#   'start': 771,
#   'end': 787},
#  {'entity_group': 'LABEL_1',
#   'score': 0.62135446,
#   'word': ' permitindo sincro',
#   'start': 789,
#   'end': 805},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6362267,
#   'word': 'nizacao automatica dos requisitos e',
#   'start': 805,
#   'end': 840},
#  {'entity_group': 'LABEL_1',
#   'score': 0.61949813,
#   'word': ' facilitando',
#   'start': 842,
#   'end': 852},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6722096,
#   'word': ' o processo de criacao de',
#   'start': 854,
#   'end': 877},
#  {'entity_group': 'LABEL_1',
#   'score': 0.57566595,
#   'word': ' casos',
#   'start': 879,
#   'end': 883},
#  {'entity_group': 'LABEL_0',
#   'score': 0.69293624,
#   'word': ' de',
#   'start': 885,
#   'end': 886},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5011727,
#   'word': ' testes',
#   'start': 888,
#   'end': 893},
#  {'entity_group': 'LABEL_0',
#   'score': 0.66804105,
#   'word': " . ' , ' como testador eu",
#   'start': 894,
#   'end': 914},
#  {'entity_group': 'LABEL_1',
#   'score': 0.549369,
#   'word': ' que',
#   'start': 916,
#   'end': 918},
#  {'entity_group': 'LABEL_0',
#   'score': 0.623668,
#   'word': 'ro que a ferramenta',
#   'start': 918,
#   'end': 937},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5516179,
#   'word': ' forneca',
#   'start': 940,
#   'end': 946},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6452788,
#   'word': ' o recurso de',
#   'start': 948,
#   'end': 959},
#  {'entity_group': 'LABEL_1',
#   'score': 0.55710787,
#   'word': ' criacao',
#   'start': 961,
#   'end': 967},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6665303,
#   'word': ' de',
#   'start': 969,
#   'end': 970},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6141255,
#   'word': ' relatorios detalhados',
#   'start': 972,
#   'end': 992},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6033403,
#   'word': ' sobre a cobertura dos testes ,',
#   'start': 994,
#   'end': 1022},
#  {'entity_group': 'LABEL_1',
#   'score': 0.59828806,
#   'word': ' permitindo uma',
#   'start': 1024,
#   'end': 1037},
#  {'entity_group': 'LABEL_0',
#   'score': 0.50523084,
#   'word': ' analise',
#   'start': 1039,
#   'end': 1045},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6948153,
#   'word': ' precisa',
#   'start': 1047,
#   'end': 1053},
#  {'entity_group': 'LABEL_0',
#   'score': 0.66456205,
#   'word': ' sobre sua',
#   'start': 1055,
#   'end': 1063},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5282759,
#   'word': ' progressao',
#   'start': 1065,
#   'end': 1074},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6836344,
#   'word': " e identificacao das lacunas durante sua execucao . ' , ' como testador",
#   'start': 1076,
#   'end': 1141},
#  {'entity_group': 'LABEL_1',
#   'score': 0.55178046,
#   'word': ' , que',
#   'start': 1142,
#   'end': 1146},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6492748,
#   'word': 'ro uma maneira mais facil de incluir requisitos do',
#   'start': 1146,
#   'end': 1196},
#  {'entity_group': 'LABEL_1',
#   'score': 0.55196136,
#   'word': ' aplica',
#   'start': 1198,
#   'end': 1203},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6875749,
#   'word': 'tivo para criar',
#   'start': 1203,
#   'end': 1218},
#  {'entity_group': 'LABEL_1',
#   'score': 0.51883215,
#   'word': ' casos',
#   'start': 1220,
#   'end': 1224},
#  {'entity_group': 'LABEL_0',
#   'score': 0.7316128,
#   'word': ' de teste',
#   'start': 1226,
#   'end': 1233},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5935753,
#   'word': ' abrangentes',
#   'start': 1235,
#   'end': 1245},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6928366,
#   'word': ' ,',
#   'start': 1246,
#   'end': 1246},
#  {'entity_group': 'LABEL_1',
#   'score': 0.50034535,
#   'word': ' economi',
#   'start': 1248,
#   'end': 1254},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6859147,
#   'word': "zando tempo na escrita manual . ' , ' como testador",
#   'start': 1254,
#   'end': 1301},
#  {'entity_group': 'LABEL_1',
#   'score': 0.55765796,
#   'word': ' , desejo',
#   'start': 1302,
#   'end': 1309},
#  {'entity_group': 'LABEL_0',
#   'score': 0.68438274,
#   'word': ' ensinar a ferramenta a entender os requisitos do',
#   'start': 1311,
#   'end': 1358},
#  {'entity_group': 'LABEL_1',
#   'score': 0.56393784,
#   'word': ' aplica',
#   'start': 1360,
#   'end': 1365},
#  {'entity_group': 'LABEL_0',
#   'score': 0.667659,
#   'word': 'tivo usando nlp para',
#   'start': 1365,
#   'end': 1385},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5423318,
#   'word': ' gerar testes automaticamente',
#   'start': 1387,
#   'end': 1414},
#  {'entity_group': 'LABEL_0',
#   'score': 0.70348895,
#   'word': " . ' , ' como testador",
#   'start': 1415,
#   'end': 1432},
#  {'entity_group': 'LABEL_1',
#   'score': 0.64838964,
#   'word': ' , preciso',
#   'start': 1433,
#   'end': 1441},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6203012,
#   'word': ' que a ferramenta',
#   'start': 1443,
#   'end': 1458},
#  {'entity_group': 'LABEL_1',
#   'score': 0.53365064,
#   'word': ' gere casos',
#   'start': 1460,
#   'end': 1469},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6862176,
#   'word': ' de teste',
#   'start': 1471,
#   'end': 1478},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6138051,
#   'word': ' completos',
#   'start': 1480,
#   'end': 1488},
#  {'entity_group': 'LABEL_0',
#   'score': 0.66952676,
#   'word': ' e',
#   'start': 1490,
#   'end': 1490},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5679142,
#   'word': ' funcionais',
#   'start': 1492,
#   'end': 1501},
#  {'entity_group': 'LABEL_0',
#   'score': 0.63309467,
#   'word': ' que cubram todos os requisitos do',
#   'start': 1503,
#   'end': 1535},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5705258,
#   'word': ' aplica',
#   'start': 1537,
#   'end': 1542},
#  {'entity_group': 'LABEL_0',
#   'score': 0.70820355,
#   'word': "tivo . ' , ' como testador ,",
#   'start': 1542,
#   'end': 1565},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5755376,
#   'word': ' que',
#   'start': 1567,
#   'end': 1569},
#  {'entity_group': 'LABEL_0',
#   'score': 0.7031075,
#   'word': 'ro',
#   'start': 1569,
#   'end': 1571},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5736858,
#   'word': ' integracao',
#   'start': 1573,
#   'end': 1582},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6608497,
#   'word': ' com outras',
#   'start': 1584,
#   'end': 1593},
#  {'entity_group': 'LABEL_1',
#   'score': 0.50497407,
#   'word': ' ferramentas',
#   'start': 1595,
#   'end': 1605},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6982936,
#   'word': ' de gerenciamento para',
#   'start': 1607,
#   'end': 1627},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5897706,
#   'word': ' sincro',
#   'start': 1629,
#   'end': 1634},
#  {'entity_group': 'LABEL_0',
#   'score': 0.66136277,
#   'word': 'nizar automaticamente requisitos e facilitar a criacao de',
#   'start': 1634,
#   'end': 1691},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5039833,
#   'word': ' casos',
#   'start': 1693,
#   'end': 1697},
#  {'entity_group': 'LABEL_0',
#   'score': 0.7111958,
#   'word': " de teste . ' , ' como",
#   'start': 1699,
#   'end': 1715},
#  {'entity_group': 'LABEL_1',
#   'score': 0.50515187,
#   'word': ' tes',
#   'start': 1717,
#   'end': 1719},
#  {'entity_group': 'LABEL_0',
#   'score': 0.84071535,
#   'word': 'tador',
#   'start': 1719,
#   'end': 1724},
#  {'entity_group': 'LABEL_1',
#   'score': 0.60277456,
#   'word': ' , que',
#   'start': 1725,
#   'end': 1729},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6295236,
#   'word': 'ro',
#   'start': 1729,
#   'end': 1731},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6245487,
#   'word': ' relatorios detalhados sobre',
#   'start': 1733,
#   'end': 1759},
#  {'entity_group': 'LABEL_0',
#   'score': 0.59854597,
#   'word': ' a cobertura dos testes para',
#   'start': 1761,
#   'end': 1787},
#  {'entity_group': 'LABEL_1',
#   'score': 0.56161654,
#   'word': ' analise precisa',
#   'start': 1789,
#   'end': 1803},
#  {'entity_group': 'LABEL_0',
#   'score': 0.69982773,
#   'word': " durante a execucao . ' , ' como testador ,",
#   'start': 1805,
#   'end': 1841},
#  {'entity_group': 'LABEL_1',
#   'score': 0.56716394,
#   'word': ' desejo',
#   'start': 1843,
#   'end': 1848},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6661322,
#   'word': ' que a ferramenta identifique automaticamente os casos de teste mais',
#   'start': 1850,
#   'end': 1916},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5688185,
#   'word': ' criticos',
#   'start': 1918,
#   'end': 1925},
#  {'entity_group': 'LABEL_0',
#   'score': 0.7106244,
#   'word': " para priorizar a analise . ' , ' como testador",
#   'start': 1927,
#   'end': 1968},
#  {'entity_group': 'LABEL_1',
#   'score': 0.62813103,
#   'word': ' , preciso',
#   'start': 1969,
#   'end': 1977},
#  {'entity_group': 'LABEL_0',
#   'score': 0.61499214,
#   'word': ' que a ferramenta sugira casos de teste com',
#   'start': 1979,
#   'end': 2020},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5265456,
#   'word': ' base',
#   'start': 2022,
#   'end': 2025},
#  {'entity_group': 'LABEL_0',
#   'score': 0.7001156,
#   'word': ' em padroes de uso real do',
#   'start': 2027,
#   'end': 2051},
#  {'entity_group': 'LABEL_1',
#   'score': 0.61398685,
#   'word': ' aplica',
#   'start': 2053,
#   'end': 2058},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6888957,
#   'word': "tivo . ' , ' como testador",
#   'start': 2058,
#   'end': 2080},
#  {'entity_group': 'LABEL_1',
#   'score': 0.54817843,
#   'word': ' , que',
#   'start': 2081,
#   'end': 2085},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6768122,
#   'word': 'ro',
#   'start': 2085,
#   'end': 2087},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6054326,
#   'word': ' sugestoes',
#   'start': 2089,
#   'end': 2097},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6785445,
#   'word': " com base em padroes de falha historicos para evitar problemas recorrentes no software . ' , ' como testador",
#   'start': 2099,
#   'end': 2201},
#  {'entity_group': 'LABEL_1',
#   'score': 0.57338166,
#   'word': ' , desejo',
#   'start': 2202,
#   'end': 2209},
#  {'entity_group': 'LABEL_0',
#   'score': 0.69069153,
#   'word': " suporte a execucao de testes automatizados em diferentes dispositivos e ambientes . ' , ' como",
#   'start': 2211,
#   'end': 2300},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5027882,
#   'word': ' tes',
#   'start': 2302,
#   'end': 2304},
#  {'entity_group': 'LABEL_0',
#   'score': 0.8223168,
#   'word': 'tador',
#   'start': 2304,
#   'end': 2309},
#  {'entity_group': 'LABEL_1',
#   'score': 0.64698017,
#   'word': ' , preciso',
#   'start': 2310,
#   'end': 2318},
#  {'entity_group': 'LABEL_0',
#   'score': 0.68907166,
#   'word': ' que a',
#   'start': 2320,
#   'end': 2324},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5051044,
#   'word': ' ferramenta',
#   'start': 2326,
#   'end': 2335},
#  {'entity_group': 'LABEL_0',
#   'score': 0.61304134,
#   'word': ' detecte',
#   'start': 2337,
#   'end': 2343},
#  {'entity_group': 'LABEL_1',
#   'score': 0.50390005,
#   'word': ' automaticamente',
#   'start': 2345,
#   'end': 2359},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6347971,
#   'word': ' mudancas nos requisitos e',
#   'start': 2361,
#   'end': 2385},
#  {'entity_group': 'LABEL_1',
#   'score': 0.56179804,
#   'word': ' ajuste',
#   'start': 2387,
#   'end': 2392},
#  {'entity_group': 'LABEL_0',
#   'score': 0.67765635,
#   'word': ' os',
#   'start': 2394,
#   'end': 2395},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5207831,
#   'word': ' casos',
#   'start': 2397,
#   'end': 2401},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6911182,
#   'word': " de teste correspondentes . ' , ' como testador ,",
#   'start': 2403,
#   'end': 2445},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5929188,
#   'word': ' que',
#   'start': 2447,
#   'end': 2449},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6828536,
#   'word': 'ro',
#   'start': 2449,
#   'end': 2451},
#  {'entity_group': 'LABEL_1',
#   'score': 0.50715965,
#   'word': ' integracao',
#   'start': 2453,
#   'end': 2462},
#  {'entity_group': 'LABEL_0',
#   'score': 0.7519161,
#   'word': ' com sistemas de controle de versao para rastrear mudancas nos requisitos e no',
#   'start': 2464,
#   'end': 2540}]

# %%
for i, historia_usuario in enumerate(historias_usuario):
    result = roberta(f"História de Usuário {i+1}: {historia_usuario}")
    print(f"Resultado para História de Usuário {i+1}: {result}")
# Out:
# Resultado para História de Usuário 1: [{'entity_group': 'LABEL_0', 'score': 0.72897553, 'word': ' historia de usuario 1 : como', 'start': 0, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.5274084, 'word': ' tes', 'start': 29, 'end': 31}, {'entity_group': 'LABEL_0', 'score': 0.6274613, 'word': 'tador eu quero um', 'start': 31, 'end': 48}, {'entity_group': 'LABEL_1', 'score': 0.53015727, 'word': ' je', 'start': 50, 'end': 51}, {'entity_group': 'LABEL_0', 'score': 0.6760417, 'word': 'ito mais facil de incluir os requisitos do aplicativo na ferramenta drl - mobtest para criar casos de teste que cubram tudo que o aplicativo precisa fazer , sem ter que gastar muito tempo escrevendo manualmente .', 'start': 51, 'end': 259}]
# Resultado para História de Usuário 2: [{'entity_group': 'LABEL_0', 'score': 0.71725637, 'word': ' historia de usuario 2 : como', 'start': 0, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.5400601, 'word': ' tes', 'start': 29, 'end': 31}, {'entity_group': 'LABEL_0', 'score': 0.6732623, 'word': 'tador eu quero uma maneira de ensinar a ferramenta drl - mobtest a entender os requisitos do aplicativo usando nlp para fazer com que a ferramenta gere testes automaticamente .', 'start': 31, 'end': 204}]
# Resultado para História de Usuário 3: [{'entity_group': 'LABEL_0', 'score': 0.6748951, 'word': ' historia de usuario 3 : como', 'start': 0, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.556894, 'word': ' tes', 'start': 29, 'end': 31}, {'entity_group': 'LABEL_0', 'score': 0.6028448, 'word': 'tador eu quero que a ferramenta', 'start': 31, 'end': 62}, {'entity_group': 'LABEL_1', 'score': 0.5620209, 'word': ' gere casos', 'start': 64, 'end': 73}, {'entity_group': 'LABEL_0', 'score': 0.64032763, 'word': ' de teste', 'start': 75, 'end': 82}, {'entity_group': 'LABEL_1', 'score': 0.6981145, 'word': ' abrangentes', 'start': 84, 'end': 94}, {'entity_group': 'LABEL_0', 'score': 0.58278877, 'word': ' que cubram', 'start': 96, 'end': 105}, {'entity_group': 'LABEL_1', 'score': 0.523181, 'word': ' integralmente', 'start': 107, 'end': 119}, {'entity_group': 'LABEL_0', 'score': 0.69766194, 'word': ' todos os requisitos do', 'start': 121, 'end': 142}, {'entity_group': 'LABEL_1', 'score': 0.56048787, 'word': ' aplica', 'start': 144, 'end': 149}, {'entity_group': 'LABEL_0', 'score': 0.70590717, 'word': 'tivo ,', 'start': 149, 'end': 154}, {'entity_group': 'LABEL_1', 'score': 0.5076916, 'word': ' assegurando', 'start': 156, 'end': 166}, {'entity_group': 'LABEL_0', 'score': 0.72036153, 'word': ' que o software seja completo e funcional , sem depender exclusivamente da criacao manual de casos de teste .', 'start': 168, 'end': 273}]
# Resultado para História de Usuário 4: [{'entity_group': 'LABEL_0', 'score': 0.6943255, 'word': ' historia de usuario 4 : como', 'start': 0, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.52360153, 'word': ' tes', 'start': 29, 'end': 31}, {'entity_group': 'LABEL_0', 'score': 0.70202225, 'word': 'tador eu', 'start': 31, 'end': 39}, {'entity_group': 'LABEL_1', 'score': 0.5182839, 'word': ' que', 'start': 41, 'end': 43}, {'entity_group': 'LABEL_0', 'score': 0.5360655, 'word': 'ro', 'start': 43, 'end': 45}, {'entity_group': 'LABEL_1', 'score': 0.5417647, 'word': ' que', 'start': 47, 'end': 49}, {'entity_group': 'LABEL_0', 'score': 0.5662039, 'word': ' a ferramenta seja', 'start': 51, 'end': 67}, {'entity_group': 'LABEL_1', 'score': 0.54186976, 'word': ' integrada', 'start': 69, 'end': 77}, {'entity_group': 'LABEL_0', 'score': 0.541038, 'word': ' com', 'start': 79, 'end': 81}, {'entity_group': 'LABEL_1', 'score': 0.5167555, 'word': ' outras ferramentas', 'start': 83, 'end': 100}, {'entity_group': 'LABEL_0', 'score': 0.681751, 'word': ' de gerenciamento , permitindo sincronizacao automatica dos requisitos e facilitando o processo de criacao de casos de', 'start': 102, 'end': 217}, {'entity_group': 'LABEL_1', 'score': 0.50336576, 'word': ' testes', 'start': 219, 'end': 224}, {'entity_group': 'LABEL_0', 'score': 0.59743077, 'word': ' .', 'start': 225, 'end': 225}]
# Resultado para História de Usuário 5: [{'entity_group': 'LABEL_0', 'score': 0.66763145, 'word': ' historia de usuario 5 : como testador eu', 'start': 0, 'end': 39}, {'entity_group': 'LABEL_1', 'score': 0.51989245, 'word': ' que', 'start': 41, 'end': 43}, {'entity_group': 'LABEL_0', 'score': 0.57342, 'word': 'ro que a ferramenta', 'start': 43, 'end': 62}, {'entity_group': 'LABEL_1', 'score': 0.5377599, 'word': ' forneca', 'start': 65, 'end': 71}, {'entity_group': 'LABEL_0', 'score': 0.6746727, 'word': ' o', 'start': 73, 'end': 73}, {'entity_group': 'LABEL_1', 'score': 0.5126831, 'word': ' recurso', 'start': 75, 'end': 81}, {'entity_group': 'LABEL_0', 'score': 0.7017387, 'word': ' de', 'start': 83, 'end': 84}, {'entity_group': 'LABEL_1', 'score': 0.5313274, 'word': ' criacao', 'start': 86, 'end': 92}, {'entity_group': 'LABEL_0', 'score': 0.64457893, 'word': ' de', 'start': 94, 'end': 95}, {'entity_group': 'LABEL_1', 'score': 0.5934218, 'word': ' relatorios detalhados', 'start': 97, 'end': 117}, {'entity_group': 'LABEL_0', 'score': 0.633357, 'word': ' sobre a cobertura dos testes , permitindo uma analise', 'start': 119, 'end': 170}, {'entity_group': 'LABEL_1', 'score': 0.5539222, 'word': ' precisa', 'start': 172, 'end': 178}, {'entity_group': 'LABEL_0', 'score': 0.72431296, 'word': ' sobre sua progressao e identificacao das lacunas durante sua execucao .', 'start': 180, 'end': 249}]
# Resultado para História de Usuário 6: [{'entity_group': 'LABEL_0', 'score': 0.70905465, 'word': ' historia de usuario 6 : como', 'start': 0, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.5354391, 'word': ' tes', 'start': 29, 'end': 31}, {'entity_group': 'LABEL_0', 'score': 0.63403374, 'word': 'tador , quero uma maneira mais facil de incluir requisitos do', 'start': 31, 'end': 91}, {'entity_group': 'LABEL_1', 'score': 0.5472574, 'word': ' aplica', 'start': 93, 'end': 98}, {'entity_group': 'LABEL_0', 'score': 0.70464414, 'word': 'tivo para criar casos de teste', 'start': 98, 'end': 128}, {'entity_group': 'LABEL_1', 'score': 0.599199, 'word': ' abrangentes', 'start': 130, 'end': 140}, {'entity_group': 'LABEL_0', 'score': 0.68725264, 'word': ' , economizando tempo na escrita manual .', 'start': 141, 'end': 179}]
# Resultado para História de Usuário 7: [{'entity_group': 'LABEL_0', 'score': 0.68779606, 'word': ' historia de usuario 7 : como testador', 'start': 0, 'end': 36}, {'entity_group': 'LABEL_1', 'score': 0.52670676, 'word': ' ,', 'start': 37, 'end': 37}, {'entity_group': 'LABEL_0', 'score': 0.5168076, 'word': ' desejo', 'start': 39, 'end': 44}, {'entity_group': 'LABEL_1', 'score': 0.5257326, 'word': ' ens', 'start': 46, 'end': 48}, {'entity_group': 'LABEL_0', 'score': 0.6406516, 'word': 'inar a ferramenta a entender os', 'start': 48, 'end': 79}, {'entity_group': 'LABEL_1', 'score': 0.5039966, 'word': ' requisitos', 'start': 81, 'end': 90}, {'entity_group': 'LABEL_0', 'score': 0.7337072, 'word': ' do', 'start': 92, 'end': 93}, {'entity_group': 'LABEL_1', 'score': 0.54820746, 'word': ' aplica', 'start': 95, 'end': 100}, {'entity_group': 'LABEL_0', 'score': 0.6547553, 'word': 'tivo usando nlp para gerar testes automaticamente .', 'start': 100, 'end': 150}]
# Resultado para História de Usuário 8: [{'entity_group': 'LABEL_0', 'score': 0.6881682, 'word': ' historia de usuario 8 : como', 'start': 0, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.5292202, 'word': ' tes', 'start': 29, 'end': 31}, {'entity_group': 'LABEL_0', 'score': 0.81439114, 'word': 'tador', 'start': 31, 'end': 36}, {'entity_group': 'LABEL_1', 'score': 0.60020435, 'word': ' , preciso', 'start': 37, 'end': 45}, {'entity_group': 'LABEL_0', 'score': 0.55223715, 'word': ' que a ferramenta', 'start': 47, 'end': 62}, {'entity_group': 'LABEL_1', 'score': 0.5529181, 'word': ' gere', 'start': 64, 'end': 67}, {'entity_group': 'LABEL_0', 'score': 0.5892389, 'word': ' casos de teste', 'start': 69, 'end': 82}, {'entity_group': 'LABEL_1', 'score': 0.60698605, 'word': ' completos', 'start': 84, 'end': 92}, {'entity_group': 'LABEL_0', 'score': 0.72359776, 'word': ' e', 'start': 94, 'end': 94}, {'entity_group': 'LABEL_1', 'score': 0.56655526, 'word': ' funcionais', 'start': 96, 'end': 105}, {'entity_group': 'LABEL_0', 'score': 0.6427847, 'word': ' que cubram todos os requisitos do', 'start': 107, 'end': 139}, {'entity_group': 'LABEL_1', 'score': 0.5446348, 'word': ' aplica', 'start': 141, 'end': 146}, {'entity_group': 'LABEL_0', 'score': 0.6599183, 'word': 'tivo .', 'start': 146, 'end': 151}]
# Resultado para História de Usuário 9: [{'entity_group': 'LABEL_0', 'score': 0.716553, 'word': ' historia de usuario 9 : como', 'start': 0, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.5340188, 'word': ' tes', 'start': 29, 'end': 31}, {'entity_group': 'LABEL_0', 'score': 0.82485163, 'word': 'tador', 'start': 31, 'end': 36}, {'entity_group': 'LABEL_1', 'score': 0.5876223, 'word': ' , que', 'start': 37, 'end': 41}, {'entity_group': 'LABEL_0', 'score': 0.5793086, 'word': 'ro', 'start': 41, 'end': 43}, {'entity_group': 'LABEL_1', 'score': 0.5576757, 'word': ' integracao', 'start': 45, 'end': 54}, {'entity_group': 'LABEL_0', 'score': 0.5322827, 'word': ' com outras', 'start': 56, 'end': 65}, {'entity_group': 'LABEL_1', 'score': 0.5485241, 'word': ' ferramentas', 'start': 67, 'end': 77}, {'entity_group': 'LABEL_0', 'score': 0.6607198, 'word': ' de gerenciamento para', 'start': 79, 'end': 99}, {'entity_group': 'LABEL_1', 'score': 0.53556, 'word': ' sincro', 'start': 101, 'end': 106}, {'entity_group': 'LABEL_0', 'score': 0.68234783, 'word': 'nizar automaticamente requisitos e facilitar a criacao de casos de teste .', 'start': 106, 'end': 179}]
# Resultado para História de Usuário 10: [{'entity_group': 'LABEL_0', 'score': 0.65885407, 'word': ' historia de usuario 10 : como testador ,', 'start': 0, 'end': 38}, {'entity_group': 'LABEL_1', 'score': 0.5977122, 'word': ' que', 'start': 40, 'end': 42}, {'entity_group': 'LABEL_0', 'score': 0.56321985, 'word': 'ro', 'start': 42, 'end': 44}, {'entity_group': 'LABEL_1', 'score': 0.61890614, 'word': ' relatorios detalhados', 'start': 46, 'end': 66}, {'entity_group': 'LABEL_0', 'score': 0.62162787, 'word': ' sobre a cobertura dos testes para analise', 'start': 68, 'end': 108}, {'entity_group': 'LABEL_1', 'score': 0.567887, 'word': ' precisa', 'start': 110, 'end': 116}, {'entity_group': 'LABEL_0', 'score': 0.71291614, 'word': ' durante a execucao .', 'start': 118, 'end': 136}]
# Resultado para História de Usuário 11: [{'entity_group': 'LABEL_0', 'score': 0.66788965, 'word': ' historia de usuario 11 : como testador', 'start': 0, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.5560814, 'word': ' , desejo', 'start': 38, 'end': 45}, {'entity_group': 'LABEL_0', 'score': 0.59548527, 'word': ' que a', 'start': 47, 'end': 51}, {'entity_group': 'LABEL_1', 'score': 0.51242274, 'word': ' ferramenta', 'start': 53, 'end': 62}, {'entity_group': 'LABEL_0', 'score': 0.5659608, 'word': ' identifique automaticamente os casos de teste mais', 'start': 64, 'end': 113}, {'entity_group': 'LABEL_1', 'score': 0.6113459, 'word': ' criticos', 'start': 115, 'end': 122}, {'entity_group': 'LABEL_0', 'score': 0.62946796, 'word': ' para priorizar a analise .', 'start': 124, 'end': 148}]
# Resultado para História de Usuário 12: [{'entity_group': 'LABEL_0', 'score': 0.6937003, 'word': ' historia de usuario 12 : como', 'start': 0, 'end': 28}, {'entity_group': 'LABEL_1', 'score': 0.52983004, 'word': ' tes', 'start': 30, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.82470083, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.56985617, 'word': ' , preciso', 'start': 38, 'end': 46}, {'entity_group': 'LABEL_0', 'score': 0.6304912, 'word': ' que a', 'start': 48, 'end': 52}, {'entity_group': 'LABEL_1', 'score': 0.5041932, 'word': ' ferramenta', 'start': 54, 'end': 63}, {'entity_group': 'LABEL_0', 'score': 0.65908426, 'word': ' sugira casos de teste com base em padroes de uso real do', 'start': 65, 'end': 120}, {'entity_group': 'LABEL_1', 'score': 0.54001856, 'word': ' aplica', 'start': 122, 'end': 127}, {'entity_group': 'LABEL_0', 'score': 0.66125035, 'word': 'tivo .', 'start': 127, 'end': 132}]
# Resultado para História de Usuário 13: [{'entity_group': 'LABEL_0', 'score': 0.6841437, 'word': ' historia de usuario 13 : como', 'start': 0, 'end': 28}, {'entity_group': 'LABEL_1', 'score': 0.5256502, 'word': ' tes', 'start': 30, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.8050704, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.54258275, 'word': ' , que', 'start': 38, 'end': 42}, {'entity_group': 'LABEL_0', 'score': 0.58850014, 'word': 'ro', 'start': 42, 'end': 44}, {'entity_group': 'LABEL_1', 'score': 0.5869225, 'word': ' sugestoes', 'start': 46, 'end': 54}, {'entity_group': 'LABEL_0', 'score': 0.55255973, 'word': ' com', 'start': 56, 'end': 58}, {'entity_group': 'LABEL_1', 'score': 0.52615243, 'word': ' base', 'start': 60, 'end': 63}, {'entity_group': 'LABEL_0', 'score': 0.65049034, 'word': ' em', 'start': 65, 'end': 66}, {'entity_group': 'LABEL_1', 'score': 0.5105686, 'word': ' padroes', 'start': 68, 'end': 74}, {'entity_group': 'LABEL_0', 'score': 0.72136825, 'word': ' de', 'start': 76, 'end': 77}, {'entity_group': 'LABEL_1', 'score': 0.5587844, 'word': ' falha', 'start': 79, 'end': 83}, {'entity_group': 'LABEL_0', 'score': 0.6429367, 'word': ' historicos para evitar problemas recorrentes no software .', 'start': 85, 'end': 141}]
# Resultado para História de Usuário 14: [{'entity_group': 'LABEL_0', 'score': 0.6927912, 'word': ' historia de usuario 14 : como', 'start': 0, 'end': 28}, {'entity_group': 'LABEL_1', 'score': 0.5110998, 'word': ' tes', 'start': 30, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.84033936, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.5620295, 'word': ' , desejo', 'start': 38, 'end': 45}, {'entity_group': 'LABEL_0', 'score': 0.67692435, 'word': ' suporte a execucao de', 'start': 47, 'end': 67}, {'entity_group': 'LABEL_1', 'score': 0.5073265, 'word': ' testes', 'start': 69, 'end': 74}, {'entity_group': 'LABEL_0', 'score': 0.6449843, 'word': ' automatizados em diferentes', 'start': 76, 'end': 102}, {'entity_group': 'LABEL_1', 'score': 0.5651923, 'word': ' dispositivos', 'start': 104, 'end': 115}, {'entity_group': 'LABEL_0', 'score': 0.68946815, 'word': ' e ambientes .', 'start': 117, 'end': 128}]
# Resultado para História de Usuário 15: [{'entity_group': 'LABEL_0', 'score': 0.6924302, 'word': ' historia de usuario', 'start': 0, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.55465794, 'word': ' 15', 'start': 21, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.6544701, 'word': ' : como testador', 'start': 23, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.6438875, 'word': ' , preciso', 'start': 38, 'end': 46}, {'entity_group': 'LABEL_0', 'score': 0.59478754, 'word': ' que a', 'start': 48, 'end': 52}, {'entity_group': 'LABEL_1', 'score': 0.50944364, 'word': ' ferramenta', 'start': 54, 'end': 63}, {'entity_group': 'LABEL_0', 'score': 0.6045448, 'word': ' detecte automaticamente mudancas nos', 'start': 65, 'end': 100}, {'entity_group': 'LABEL_1', 'score': 0.5395592, 'word': ' requisitos', 'start': 102, 'end': 111}, {'entity_group': 'LABEL_0', 'score': 0.754532, 'word': ' e', 'start': 113, 'end': 113}, {'entity_group': 'LABEL_1', 'score': 0.5324819, 'word': ' ajuste', 'start': 115, 'end': 120}, {'entity_group': 'LABEL_0', 'score': 0.6661076, 'word': ' os casos de teste correspondentes .', 'start': 122, 'end': 155}]
# Resultado para História de Usuário 16: [{'entity_group': 'LABEL_0', 'score': 0.722001, 'word': ' historia de usuario 16 : como', 'start': 0, 'end': 28}, {'entity_group': 'LABEL_1', 'score': 0.51960903, 'word': ' tes', 'start': 30, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.81802243, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.55043805, 'word': ' , que', 'start': 38, 'end': 42}, {'entity_group': 'LABEL_0', 'score': 0.7115774, 'word': 'ro integracao com sistemas de controle de versao para rastrear mudancas nos requisitos e no codigo - fonte .', 'start': 42, 'end': 147}]
# Resultado para História de Usuário 17: [{'entity_group': 'LABEL_0', 'score': 0.71057266, 'word': ' historia de usuario 17 : como', 'start': 0, 'end': 28}, {'entity_group': 'LABEL_1', 'score': 0.5415919, 'word': ' tes', 'start': 30, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.8025057, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.59952044, 'word': ' , desejo metricas detalhadas', 'start': 38, 'end': 65}, {'entity_group': 'LABEL_0', 'score': 0.64856863, 'word': ' sobre a', 'start': 67, 'end': 73}, {'entity_group': 'LABEL_1', 'score': 0.5230373, 'word': ' eficacia', 'start': 75, 'end': 82}, {'entity_group': 'LABEL_0', 'score': 0.6314491, 'word': ' dos', 'start': 84, 'end': 86}, {'entity_group': 'LABEL_1', 'score': 0.5653108, 'word': ' testes', 'start': 88, 'end': 93}, {'entity_group': 'LABEL_0', 'score': 0.7114286, 'word': ' , incluindo taxa de cobertura e taxa de falha .', 'start': 94, 'end': 139}]
# Resultado para História de Usuário 18: [{'entity_group': 'LABEL_0', 'score': 0.70393056, 'word': ' historia de usuario', 'start': 0, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.52608126, 'word': ' 18', 'start': 21, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.6341995, 'word': ' : como testador ,', 'start': 23, 'end': 38}, {'entity_group': 'LABEL_1', 'score': 0.7221429, 'word': ' preciso', 'start': 40, 'end': 46}, {'entity_group': 'LABEL_0', 'score': 0.6207838, 'word': ' de suporte a', 'start': 48, 'end': 59}, {'entity_group': 'LABEL_1', 'score': 0.5577184, 'word': ' execucao', 'start': 61, 'end': 68}, {'entity_group': 'LABEL_0', 'score': 0.6497793, 'word': ' de', 'start': 70, 'end': 71}, {'entity_group': 'LABEL_1', 'score': 0.5734121, 'word': ' testes', 'start': 73, 'end': 78}, {'entity_group': 'LABEL_0', 'score': 0.6795763, 'word': ' de', 'start': 80, 'end': 81}, {'entity_group': 'LABEL_1', 'score': 0.5184531, 'word': ' desempenho', 'start': 83, 'end': 92}, {'entity_group': 'LABEL_0', 'score': 0.6503702, 'word': ' e escalabilidade .', 'start': 94, 'end': 110}]
# Resultado para História de Usuário 19: [{'entity_group': 'LABEL_0', 'score': 0.6834459, 'word': ' historia de usuario 19 : como testador ,', 'start': 0, 'end': 38}, {'entity_group': 'LABEL_1', 'score': 0.5062937, 'word': ' que', 'start': 40, 'end': 42}, {'entity_group': 'LABEL_0', 'score': 0.67056245, 'word': 'ro analise automatica dos resultados dos', 'start': 42, 'end': 82}, {'entity_group': 'LABEL_1', 'score': 0.5208358, 'word': ' testes', 'start': 84, 'end': 89}, {'entity_group': 'LABEL_0', 'score': 0.64816624, 'word': ' para relatorios detalhados sobre problemas encontrados .', 'start': 91, 'end': 145}]
# Resultado para História de Usuário 20: [{'entity_group': 'LABEL_0', 'score': 0.67760944, 'word': ' historia de usuario 20 : como testador', 'start': 0, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.5365875, 'word': ' , desejo si', 'start': 38, 'end': 48}, {'entity_group': 'LABEL_0', 'score': 0.6107694, 'word': 'mular cenarios de teste', 'start': 48, 'end': 71}, {'entity_group': 'LABEL_1', 'score': 0.53877705, 'word': ' complexos', 'start': 73, 'end': 81}, {'entity_group': 'LABEL_0', 'score': 0.71124727, 'word': ' e', 'start': 83, 'end': 83}, {'entity_group': 'LABEL_1', 'score': 0.63947016, 'word': ' realistas', 'start': 85, 'end': 93}, {'entity_group': 'LABEL_0', 'score': 0.5349505, 'word': ' para', 'start': 95, 'end': 98}, {'entity_group': 'LABEL_1', 'score': 0.68517566, 'word': ' garantir', 'start': 100, 'end': 107}, {'entity_group': 'LABEL_0', 'score': 0.5539925, 'word': ' testes', 'start': 109, 'end': 114}, {'entity_group': 'LABEL_1', 'score': 0.52370244, 'word': ' proximos', 'start': 116, 'end': 123}, {'entity_group': 'LABEL_0', 'score': 0.70066136, 'word': ' a realidade .', 'start': 125, 'end': 136}]
# Resultado para História de Usuário 21: [{'entity_group': 'LABEL_0', 'score': 0.6773837, 'word': ' historia de usuario 21 : como testador ,', 'start': 0, 'end': 38}, {'entity_group': 'LABEL_1', 'score': 0.7074422, 'word': ' preciso', 'start': 40, 'end': 46}, {'entity_group': 'LABEL_0', 'score': 0.6233867, 'word': ' de suporte a execucao de testes de regressao automatizados .', 'start': 48, 'end': 106}]
# Resultado para História de Usuário 22: [{'entity_group': 'LABEL_0', 'score': 0.6827166, 'word': ' historia de usuario 22 : como', 'start': 0, 'end': 28}, {'entity_group': 'LABEL_1', 'score': 0.5737594, 'word': ' tes', 'start': 30, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.80769837, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.5461408, 'word': ' , que', 'start': 38, 'end': 42}, {'entity_group': 'LABEL_0', 'score': 0.6518045, 'word': 'ro identificacao automatica de casos de teste redundantes ou desnecessarios .', 'start': 42, 'end': 118}]
# Resultado para História de Usuário 23: [{'entity_group': 'LABEL_0', 'score': 0.6752142, 'word': ' historia de usuario 23 : como testador', 'start': 0, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.54401517, 'word': ' , desejo', 'start': 38, 'end': 45}, {'entity_group': 'LABEL_0', 'score': 0.61362267, 'word': ' integracao facil com ferramentas de gerenciamento de', 'start': 47, 'end': 98}, {'entity_group': 'LABEL_1', 'score': 0.53331727, 'word': ' projetos', 'start': 100, 'end': 107}, {'entity_group': 'LABEL_0', 'score': 0.59205455, 'word': ' .', 'start': 108, 'end': 108}]
# Resultado para História de Usuário 24: [{'entity_group': 'LABEL_0', 'score': 0.67577446, 'word': ' historia de usuario 24 : como testador ,', 'start': 0, 'end': 38}, {'entity_group': 'LABEL_1', 'score': 0.7259061, 'word': ' preciso', 'start': 40, 'end': 46}, {'entity_group': 'LABEL_0', 'score': 0.62846464, 'word': ' de suporte a', 'start': 48, 'end': 59}, {'entity_group': 'LABEL_1', 'score': 0.53502506, 'word': ' execucao', 'start': 61, 'end': 68}, {'entity_group': 'LABEL_0', 'score': 0.6652959, 'word': ' de', 'start': 70, 'end': 71}, {'entity_group': 'LABEL_1', 'score': 0.5530529, 'word': ' testes', 'start': 73, 'end': 78}, {'entity_group': 'LABEL_0', 'score': 0.6650731, 'word': ' de usabilidade .', 'start': 80, 'end': 94}]
# Resultado para História de Usuário 25: [{'entity_group': 'LABEL_0', 'score': 0.70095426, 'word': ' historia de usuario 25 : como', 'start': 0, 'end': 28}, {'entity_group': 'LABEL_1', 'score': 0.5048013, 'word': ' tes', 'start': 30, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.83054703, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.51055217, 'word': ' ,', 'start': 38, 'end': 38}, {'entity_group': 'LABEL_0', 'score': 0.60664445, 'word': ' quero que a ferramenta', 'start': 40, 'end': 61}, {'entity_group': 'LABEL_1', 'score': 0.5201511, 'word': ' crie automaticamente', 'start': 63, 'end': 82}, {'entity_group': 'LABEL_0', 'score': 0.6028577, 'word': ' conjuntos de dados de teste', 'start': 84, 'end': 110}, {'entity_group': 'LABEL_1', 'score': 0.5958475, 'word': ' realistas', 'start': 112, 'end': 120}, {'entity_group': 'LABEL_0', 'score': 0.6704848, 'word': ' .', 'start': 121, 'end': 121}]
# Resultado para História de Usuário 26: [{'entity_group': 'LABEL_0', 'score': 0.68641424, 'word': ' historia de usuario 26 : como testador ,', 'start': 0, 'end': 38}, {'entity_group': 'LABEL_1', 'score': 0.50740135, 'word': ' desejo', 'start': 40, 'end': 45}, {'entity_group': 'LABEL_0', 'score': 0.6557099, 'word': ' integracao com ferramentas de monitoramento de desempenho em tempo real .', 'start': 47, 'end': 118}]
# Resultado para História de Usuário 27: [{'entity_group': 'LABEL_0', 'score': 0.6897153, 'word': ' historia de usuario 27 : como testador', 'start': 0, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.627645, 'word': ' , preciso', 'start': 38, 'end': 46}, {'entity_group': 'LABEL_0', 'score': 0.62208617, 'word': ' de suporte a', 'start': 48, 'end': 59}, {'entity_group': 'LABEL_1', 'score': 0.54248804, 'word': ' execucao', 'start': 61, 'end': 68}, {'entity_group': 'LABEL_0', 'score': 0.67221415, 'word': ' de', 'start': 70, 'end': 71}, {'entity_group': 'LABEL_1', 'score': 0.55947214, 'word': ' testes', 'start': 73, 'end': 78}, {'entity_group': 'LABEL_0', 'score': 0.63816464, 'word': ' de localizacao e internacionalizacao .', 'start': 80, 'end': 116}]
# Resultado para História de Usuário 28: [{'entity_group': 'LABEL_0', 'score': 0.70506316, 'word': ' historia de usuario 28 : como', 'start': 0, 'end': 28}, {'entity_group': 'LABEL_1', 'score': 0.5388851, 'word': ' tes', 'start': 30, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.8260735, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.533676, 'word': ' , que', 'start': 38, 'end': 42}, {'entity_group': 'LABEL_0', 'score': 0.58908224, 'word': 'ro', 'start': 42, 'end': 44}, {'entity_group': 'LABEL_1', 'score': 0.60412765, 'word': ' geracao', 'start': 46, 'end': 52}, {'entity_group': 'LABEL_0', 'score': 0.6427733, 'word': ' automatica de dados de teste', 'start': 54, 'end': 81}, {'entity_group': 'LABEL_1', 'score': 0.594384, 'word': ' sinteticos', 'start': 83, 'end': 92}, {'entity_group': 'LABEL_0', 'score': 0.6917038, 'word': ' .', 'start': 93, 'end': 93}]
# Resultado para História de Usuário 29: [{'entity_group': 'LABEL_0', 'score': 0.7326554, 'word': ' historia de usuario 29 : como testador', 'start': 0, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.5463727, 'word': ' , desejo', 'start': 38, 'end': 45}, {'entity_group': 'LABEL_0', 'score': 0.6641978, 'word': ' suporte a', 'start': 47, 'end': 55}, {'entity_group': 'LABEL_1', 'score': 0.510476, 'word': ' execucao', 'start': 57, 'end': 64}, {'entity_group': 'LABEL_0', 'score': 0.66268384, 'word': ' de testes de acessibilidade .', 'start': 66, 'end': 93}]
# Resultado para História de Usuário 30: [{'entity_group': 'LABEL_0', 'score': 0.7289149, 'word': ' historia de usuario', 'start': 0, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.5543969, 'word': ' 30', 'start': 21, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.66595644, 'word': ' : como testador', 'start': 23, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.6287757, 'word': ' , preciso', 'start': 38, 'end': 46}, {'entity_group': 'LABEL_0', 'score': 0.61414105, 'word': ' de suporte a', 'start': 48, 'end': 59}, {'entity_group': 'LABEL_1', 'score': 0.5661239, 'word': ' execucao', 'start': 61, 'end': 68}, {'entity_group': 'LABEL_0', 'score': 0.6596138, 'word': ' de', 'start': 70, 'end': 71}, {'entity_group': 'LABEL_1', 'score': 0.59560966, 'word': ' testes', 'start': 73, 'end': 78}, {'entity_group': 'LABEL_0', 'score': 0.6029751, 'word': ' de integracao', 'start': 80, 'end': 92}, {'entity_group': 'LABEL_1', 'score': 0.55805635, 'word': ' continua', 'start': 94, 'end': 101}, {'entity_group': 'LABEL_0', 'score': 0.63207716, 'word': ' .', 'start': 102, 'end': 102}]
# Resultado para História de Usuário 31: [{'entity_group': 'LABEL_0', 'score': 0.67554134, 'word': ' historia de usuario 31 : como', 'start': 0, 'end': 28}, {'entity_group': 'LABEL_1', 'score': 0.53405094, 'word': ' tes', 'start': 30, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.8124257, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.53274155, 'word': ' , que', 'start': 38, 'end': 42}, {'entity_group': 'LABEL_0', 'score': 0.6619559, 'word': 'ro identificacao automatica de casos de teste', 'start': 42, 'end': 87}, {'entity_group': 'LABEL_1', 'score': 0.569596, 'word': ' incompletos', 'start': 89, 'end': 99}, {'entity_group': 'LABEL_0', 'score': 0.7644921, 'word': ' ou', 'start': 101, 'end': 102}, {'entity_group': 'LABEL_1', 'score': 0.5967293, 'word': ' mal', 'start': 104, 'end': 106}, {'entity_group': 'LABEL_0', 'score': 0.6173934, 'word': ' definidos .', 'start': 108, 'end': 117}]
# Resultado para História de Usuário 32: [{'entity_group': 'LABEL_0', 'score': 0.72027713, 'word': ' historia de usuario 32 : como', 'start': 0, 'end': 28}, {'entity_group': 'LABEL_1', 'score': 0.50155073, 'word': ' tes', 'start': 30, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.68661904, 'word': 'tador , desejo identificacao automatica de dependencias entre casos de teste .', 'start': 32, 'end': 108}]
# Resultado para História de Usuário 33: [{'entity_group': 'LABEL_0', 'score': 0.6931983, 'word': ' historia de usuario 33 : como testador', 'start': 0, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.60900235, 'word': ' , preciso', 'start': 38, 'end': 46}, {'entity_group': 'LABEL_0', 'score': 0.628105, 'word': ' de suporte a', 'start': 48, 'end': 59}, {'entity_group': 'LABEL_1', 'score': 0.50261617, 'word': ' execucao', 'start': 61, 'end': 68}, {'entity_group': 'LABEL_0', 'score': 0.67783237, 'word': ' de', 'start': 70, 'end': 71}, {'entity_group': 'LABEL_1', 'score': 0.5339916, 'word': ' testes', 'start': 73, 'end': 78}, {'entity_group': 'LABEL_0', 'score': 0.6426898, 'word': ' de recuperacao de desastres .', 'start': 80, 'end': 107}]
# Resultado para História de Usuário 34: [{'entity_group': 'LABEL_0', 'score': 0.7131241, 'word': ' historia de usuario 34 : como', 'start': 0, 'end': 28}, {'entity_group': 'LABEL_1', 'score': 0.5495645, 'word': ' tes', 'start': 30, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.6320224, 'word': 'tador , quero que a ferramenta identifique automaticamente casos de teste paralelizaveis .', 'start': 32, 'end': 120}]
# Resultado para História de Usuário 35: [{'entity_group': 'LABEL_0', 'score': 0.67581666, 'word': ' historia de usuario 35 : como testador , desejo simulacao de cenarios de teste de carga extremamente alta .', 'start': 0, 'end': 104}]
# Resultado para História de Usuário 36: [{'entity_group': 'LABEL_0', 'score': 0.66301703, 'word': ' historia de usuario 36 : como', 'start': 0, 'end': 28}, {'entity_group': 'LABEL_1', 'score': 0.5228689, 'word': ' tes', 'start': 30, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.7994853, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.6343811, 'word': ' , preciso', 'start': 38, 'end': 46}, {'entity_group': 'LABEL_0', 'score': 0.6239591, 'word': ' de suporte a', 'start': 48, 'end': 59}, {'entity_group': 'LABEL_1', 'score': 0.54056823, 'word': ' execucao', 'start': 61, 'end': 68}, {'entity_group': 'LABEL_0', 'score': 0.68104047, 'word': ' de', 'start': 70, 'end': 71}, {'entity_group': 'LABEL_1', 'score': 0.526076, 'word': ' testes', 'start': 73, 'end': 78}, {'entity_group': 'LABEL_0', 'score': 0.6271219, 'word': ' de compatibilidade com diferentes navegadores e dispositivos .', 'start': 80, 'end': 140}]
# Resultado para História de Usuário 37: [{'entity_group': 'LABEL_0', 'score': 0.68697804, 'word': ' historia de usuario 37 : como', 'start': 0, 'end': 28}, {'entity_group': 'LABEL_1', 'score': 0.56519717, 'word': ' tes', 'start': 30, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.81525856, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.5244608, 'word': ' , que', 'start': 38, 'end': 42}, {'entity_group': 'LABEL_0', 'score': 0.57327324, 'word': 'ro', 'start': 42, 'end': 44}, {'entity_group': 'LABEL_1', 'score': 0.6045803, 'word': ' geracao', 'start': 46, 'end': 52}, {'entity_group': 'LABEL_0', 'score': 0.65688527, 'word': ' automatica de', 'start': 54, 'end': 66}, {'entity_group': 'LABEL_1', 'score': 0.5395347, 'word': ' relatorios', 'start': 68, 'end': 77}, {'entity_group': 'LABEL_0', 'score': 0.6719719, 'word': ' de teste', 'start': 79, 'end': 86}, {'entity_group': 'LABEL_1', 'score': 0.5409209, 'word': ' personalizados', 'start': 88, 'end': 101}, {'entity_group': 'LABEL_0', 'score': 0.67505884, 'word': ' .', 'start': 102, 'end': 102}]
# Resultado para História de Usuário 38: [{'entity_group': 'LABEL_0', 'score': 0.64400434, 'word': ' historia de usuario 38 : como', 'start': 0, 'end': 28}, {'entity_group': 'LABEL_1', 'score': 0.5349674, 'word': ' tes', 'start': 30, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.6854595, 'word': 'tador ,', 'start': 32, 'end': 38}, {'entity_group': 'LABEL_1', 'score': 0.5394201, 'word': ' desejo', 'start': 40, 'end': 45}, {'entity_group': 'LABEL_0', 'score': 0.6701306, 'word': ' rastreamento automatico de resultados de teste ao', 'start': 47, 'end': 95}, {'entity_group': 'LABEL_1', 'score': 0.5477064, 'word': ' longo', 'start': 97, 'end': 101}, {'entity_group': 'LABEL_0', 'score': 0.62130076, 'word': ' do tempo .', 'start': 103, 'end': 111}]
# Resultado para História de Usuário 39: [{'entity_group': 'LABEL_0', 'score': 0.6867023, 'word': ' historia de usuario 39 : como testador ,', 'start': 0, 'end': 38}, {'entity_group': 'LABEL_1', 'score': 0.70453507, 'word': ' preciso', 'start': 40, 'end': 46}, {'entity_group': 'LABEL_0', 'score': 0.61526424, 'word': ' de suporte a', 'start': 48, 'end': 59}, {'entity_group': 'LABEL_1', 'score': 0.55672866, 'word': ' execucao', 'start': 61, 'end': 68}, {'entity_group': 'LABEL_0', 'score': 0.60105026, 'word': ' de testes de regressao progressiva .', 'start': 70, 'end': 104}]
# Resultado para História de Usuário 40: [{'entity_group': 'LABEL_0', 'score': 0.7085338, 'word': ' historia de usuario', 'start': 0, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.5925229, 'word': ' 40', 'start': 21, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.65010494, 'word': ' : como', 'start': 23, 'end': 28}, {'entity_group': 'LABEL_1', 'score': 0.5382655, 'word': ' tes', 'start': 30, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.8095633, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.5447545, 'word': ' , que', 'start': 38, 'end': 42}, {'entity_group': 'LABEL_0', 'score': 0.60581356, 'word': 'ro', 'start': 42, 'end': 44}, {'entity_group': 'LABEL_1', 'score': 0.6032719, 'word': ' sugestoes automaticas', 'start': 46, 'end': 66}, {'entity_group': 'LABEL_0', 'score': 0.60056275, 'word': ' para', 'start': 68, 'end': 71}, {'entity_group': 'LABEL_1', 'score': 0.66786635, 'word': ' aprimo', 'start': 73, 'end': 78}, {'entity_group': 'LABEL_0', 'score': 0.5782132, 'word': 'rar os casos de teste existentes .', 'start': 78, 'end': 111}]
# Resultado para História de Usuário 41: [{'entity_group': 'LABEL_0', 'score': 0.6679862, 'word': ' historia de usuario 41 : como', 'start': 0, 'end': 28}, {'entity_group': 'LABEL_1', 'score': 0.51591736, 'word': ' tes', 'start': 30, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.8064315, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.5332429, 'word': ' , desejo', 'start': 38, 'end': 45}, {'entity_group': 'LABEL_0', 'score': 0.56979007, 'word': ' que a ferramenta', 'start': 47, 'end': 62}, {'entity_group': 'LABEL_1', 'score': 0.5877873, 'word': ' aprenda', 'start': 64, 'end': 70}, {'entity_group': 'LABEL_0', 'score': 0.6004756, 'word': ' com os resultados dos', 'start': 72, 'end': 92}, {'entity_group': 'LABEL_1', 'score': 0.5893326, 'word': ' testes', 'start': 94, 'end': 99}, {'entity_group': 'LABEL_0', 'score': 0.6401055, 'word': ' e', 'start': 101, 'end': 101}, {'entity_group': 'LABEL_1', 'score': 0.66201603, 'word': ' melhore', 'start': 103, 'end': 109}, {'entity_group': 'LABEL_0', 'score': 0.68429255, 'word': ' suas', 'start': 111, 'end': 114}, {'entity_group': 'LABEL_1', 'score': 0.52310485, 'word': ' sugestoes', 'start': 116, 'end': 124}, {'entity_group': 'LABEL_0', 'score': 0.6763836, 'word': ' futuras .', 'start': 126, 'end': 133}]
# Resultado para História de Usuário 42: [{'entity_group': 'LABEL_0', 'score': 0.6841023, 'word': ' historia de usuario 42 : como', 'start': 0, 'end': 28}, {'entity_group': 'LABEL_1', 'score': 0.512748, 'word': ' tes', 'start': 30, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.83034766, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.613354, 'word': ' , preciso', 'start': 38, 'end': 46}, {'entity_group': 'LABEL_0', 'score': 0.6400173, 'word': ' de suporte a', 'start': 48, 'end': 59}, {'entity_group': 'LABEL_1', 'score': 0.5059406, 'word': ' execucao', 'start': 61, 'end': 68}, {'entity_group': 'LABEL_0', 'score': 0.6823274, 'word': ' de', 'start': 70, 'end': 71}, {'entity_group': 'LABEL_1', 'score': 0.56465274, 'word': ' testes', 'start': 73, 'end': 78}, {'entity_group': 'LABEL_0', 'score': 0.6245736, 'word': ' de seguranca automatizados .', 'start': 80, 'end': 106}]
# Resultado para História de Usuário 43: [{'entity_group': 'LABEL_0', 'score': 0.69674224, 'word': ' historia de usuario 43 : como testador', 'start': 0, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.55982196, 'word': ' , que', 'start': 38, 'end': 42}, {'entity_group': 'LABEL_0', 'score': 0.67748594, 'word': 'ro integracao com ferramentas de analise de codigo estatico para identificar areas de risco .', 'start': 42, 'end': 134}]
# Resultado para História de Usuário 44: [{'entity_group': 'LABEL_0', 'score': 0.6767655, 'word': ' historia de usuario 44 : como', 'start': 0, 'end': 28}, {'entity_group': 'LABEL_1', 'score': 0.5596937, 'word': ' tes', 'start': 30, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.79227203, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.5787226, 'word': ' , desejo', 'start': 38, 'end': 45}, {'entity_group': 'LABEL_0', 'score': 0.65592235, 'word': ' suporte a', 'start': 47, 'end': 55}, {'entity_group': 'LABEL_1', 'score': 0.5832316, 'word': ' execucao', 'start': 57, 'end': 64}, {'entity_group': 'LABEL_0', 'score': 0.6967032, 'word': ' de', 'start': 66, 'end': 67}, {'entity_group': 'LABEL_1', 'score': 0.56681484, 'word': ' testes', 'start': 69, 'end': 74}, {'entity_group': 'LABEL_0', 'score': 0.6883507, 'word': ' de integracao de sistema e teste de aceitacao do usuario .', 'start': 76, 'end': 132}]
# Resultado para História de Usuário 45: [{'entity_group': 'LABEL_0', 'score': 0.67106634, 'word': ' historia de usuario', 'start': 0, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.50481546, 'word': ' 45', 'start': 21, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.643854, 'word': ' : como testador', 'start': 23, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.63001513, 'word': ' , preciso', 'start': 38, 'end': 46}, {'entity_group': 'LABEL_0', 'score': 0.6150077, 'word': ' de suporte a', 'start': 48, 'end': 59}, {'entity_group': 'LABEL_1', 'score': 0.5535178, 'word': ' execucao', 'start': 61, 'end': 68}, {'entity_group': 'LABEL_0', 'score': 0.6129824, 'word': ' de', 'start': 70, 'end': 71}, {'entity_group': 'LABEL_1', 'score': 0.5994563, 'word': ' testes', 'start': 73, 'end': 78}, {'entity_group': 'LABEL_0', 'score': 0.59056884, 'word': ' de confiabilidade e disponibilidade .', 'start': 80, 'end': 115}]
# Resultado para História de Usuário 46: [{'entity_group': 'LABEL_0', 'score': 0.7161148, 'word': ' historia de usuario 46 : como', 'start': 0, 'end': 28}, {'entity_group': 'LABEL_1', 'score': 0.5753393, 'word': ' tes', 'start': 30, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.6035007, 'word': 'tador , quero que a ferramenta sugira casos de teste com base em', 'start': 32, 'end': 95}, {'entity_group': 'LABEL_1', 'score': 0.5111398, 'word': ' modelos', 'start': 97, 'end': 103}, {'entity_group': 'LABEL_0', 'score': 0.6511112, 'word': ' de qualidade de software reconhecidos .', 'start': 105, 'end': 142}]
# Resultado para História de Usuário 47: [{'entity_group': 'LABEL_0', 'score': 0.74437666, 'word': ' historia de usuario 47 : como', 'start': 0, 'end': 28}, {'entity_group': 'LABEL_1', 'score': 0.52293456, 'word': ' tes', 'start': 30, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.696414, 'word': 'tador ,', 'start': 32, 'end': 38}, {'entity_group': 'LABEL_1', 'score': 0.5081783, 'word': ' desejo', 'start': 40, 'end': 45}, {'entity_group': 'LABEL_0', 'score': 0.69155735, 'word': ' integracao com ferramentas de automacao de teste de interface do usuario .', 'start': 47, 'end': 119}]
# Resultado para História de Usuário 48: [{'entity_group': 'LABEL_0', 'score': 0.69179845, 'word': ' historia de usuario 48 : como testador', 'start': 0, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.60982245, 'word': ' , preciso', 'start': 38, 'end': 46}, {'entity_group': 'LABEL_0', 'score': 0.62801623, 'word': ' de suporte a', 'start': 48, 'end': 59}, {'entity_group': 'LABEL_1', 'score': 0.514979, 'word': ' execucao', 'start': 61, 'end': 68}, {'entity_group': 'LABEL_0', 'score': 0.6628948, 'word': ' de', 'start': 70, 'end': 71}, {'entity_group': 'LABEL_1', 'score': 0.5061251, 'word': ' testes', 'start': 73, 'end': 78}, {'entity_group': 'LABEL_0', 'score': 0.7046359, 'word': ' de estresse e', 'start': 80, 'end': 92}, {'entity_group': 'LABEL_1', 'score': 0.5617785, 'word': ' robuste', 'start': 94, 'end': 100}, {'entity_group': 'LABEL_0', 'score': 0.68563014, 'word': 'z .', 'start': 100, 'end': 102}]
# Resultado para História de Usuário 49: [{'entity_group': 'LABEL_0', 'score': 0.7530009, 'word': ' historia de usuario 49 : como', 'start': 0, 'end': 28}, {'entity_group': 'LABEL_1', 'score': 0.541102, 'word': ' tes', 'start': 30, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.6553864, 'word': 'tador , quero que a ferramenta sugira casos de teste para areas de alto risco e complexidade .', 'start': 32, 'end': 124}]
# Resultado para História de Usuário 50: [{'entity_group': 'LABEL_0', 'score': 0.6832774, 'word': ' historia de usuario 50 : como testador', 'start': 0, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.53728986, 'word': ' , desejo', 'start': 38, 'end': 45}, {'entity_group': 'LABEL_0', 'score': 0.64826816, 'word': ' integracao com ferramentas de gerenciamento de', 'start': 47, 'end': 92}, {'entity_group': 'LABEL_1', 'score': 0.5235082, 'word': ' defeitos', 'start': 94, 'end': 101}, {'entity_group': 'LABEL_0', 'score': 0.664838, 'word': ' para rastreamento de', 'start': 103, 'end': 122}, {'entity_group': 'LABEL_1', 'score': 0.54042006, 'word': ' correcoes', 'start': 124, 'end': 132}, {'entity_group': 'LABEL_0', 'score': 0.67528504, 'word': ' .', 'start': 133, 'end': 133}]
# Resultado para História de Usuário 51: [{'entity_group': 'LABEL_0', 'score': 0.68734026, 'word': ' historia de usuario 51 : como testador', 'start': 0, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.6167669, 'word': ' , preciso', 'start': 38, 'end': 46}, {'entity_group': 'LABEL_0', 'score': 0.64622545, 'word': ' de suporte a', 'start': 48, 'end': 59}, {'entity_group': 'LABEL_1', 'score': 0.5009564, 'word': ' execucao', 'start': 61, 'end': 68}, {'entity_group': 'LABEL_0', 'score': 0.63923967, 'word': ' de testes de usabilidade', 'start': 70, 'end': 93}, {'entity_group': 'LABEL_1', 'score': 0.5166468, 'word': ' remo', 'start': 95, 'end': 98}, {'entity_group': 'LABEL_0', 'score': 0.7521272, 'word': 'ta e teste de usuario beta .', 'start': 98, 'end': 125}]
# Resultado para História de Usuário 52: [{'entity_group': 'LABEL_0', 'score': 0.7017751, 'word': ' historia de usuario 52 : como testador', 'start': 0, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.5020242, 'word': ' ,', 'start': 38, 'end': 38}, {'entity_group': 'LABEL_0', 'score': 0.6478078, 'word': ' quero que a ferramenta forneca feedback em tempo real durante a execucao dos', 'start': 40, 'end': 115}, {'entity_group': 'LABEL_1', 'score': 0.513276, 'word': ' testes', 'start': 117, 'end': 122}, {'entity_group': 'LABEL_0', 'score': 0.7067828, 'word': ' .', 'start': 123, 'end': 123}]
# Resultado para História de Usuário 53: [{'entity_group': 'LABEL_0', 'score': 0.6803277, 'word': ' historia de usuario 53 : como testador , desejo integracao com ferramentas de automacao de infraestrutura para provisionamento e configuracao automatizados .', 'start': 0, 'end': 154}]
# Resultado para História de Usuário 54: [{'entity_group': 'LABEL_0', 'score': 0.6462081, 'word': ' historia de usuario 54 : como testador', 'start': 0, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.63892984, 'word': ' , preciso', 'start': 38, 'end': 46}, {'entity_group': 'LABEL_0', 'score': 0.60381675, 'word': ' de suporte a', 'start': 48, 'end': 59}, {'entity_group': 'LABEL_1', 'score': 0.5735921, 'word': ' execucao', 'start': 61, 'end': 68}, {'entity_group': 'LABEL_0', 'score': 0.6647796, 'word': ' de', 'start': 70, 'end': 71}, {'entity_group': 'LABEL_1', 'score': 0.5818544, 'word': ' testes', 'start': 73, 'end': 78}, {'entity_group': 'LABEL_0', 'score': 0.6324091, 'word': ' de comparacao de desempenho para versoes anteriores e', 'start': 80, 'end': 132}, {'entity_group': 'LABEL_1', 'score': 0.5868953, 'word': ' atuais', 'start': 134, 'end': 139}, {'entity_group': 'LABEL_0', 'score': 0.7608076, 'word': ' do', 'start': 141, 'end': 142}, {'entity_group': 'LABEL_1', 'score': 0.52148664, 'word': ' aplica', 'start': 144, 'end': 149}, {'entity_group': 'LABEL_0', 'score': 0.67328906, 'word': 'tivo .', 'start': 149, 'end': 154}]

# %%
tfidf_vectorizer = TfidfVectorizer()
X = tfidf_vectorizer.fit_transform(historias_usuario)
y = [
    'categoria_1', 'categoria_2', 'categoria_3', 'categoria_4', 'categoria_5',
    'categoria_6', 'categoria_7', 'categoria_8', 'categoria_9', 'categoria_10',
    'categoria_11', 'categoria_12', 'categoria_13', 'categoria_14', 'categoria_15',
    'categoria_16', 'categoria_17', 'categoria_18', 'categoria_19', 'categoria_20',
    'categoria_21', 'categoria_22', 'categoria_23', 'categoria_24', 'categoria_25',
    'categoria_26', 'categoria_27', 'categoria_28', 'categoria_29', 'categoria_30',
    'categoria_31', 'categoria_32', 'categoria_33', 'categoria_34', 'categoria_35',
    'categoria_36', 'categoria_37', 'categoria_38', 'categoria_39', 'categoria_40',
    'categoria_41', 'categoria_42', 'categoria_43', 'categoria_44', 'categoria_45',
    'categoria_46', 'categoria_47', 'categoria_48', 'categoria_49', 'categoria_50',
    'categoria_51', 'categoria_52', 'categoria_53', 'categoria_54'
]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=42)

# %%
clf_tf = DecisionTreeClassifier(criterion='entropy',max_depth=7)
clf_tf.fit(X_train, y_train)
pred_arvore_entropy_tf = clf_tf.predict(X_test)
accuracy_decision = accuracy_score(y_test,pred_arvore_entropy_tf)
print(pred_arvore_entropy_tf)
print(accuracy_decision)
# Out:
# ['categoria_19' 'categoria_54' 'categoria_25' 'categoria_15'
#  'categoria_27' 'categoria_40' 'categoria_42' 'categoria_38'
#  'categoria_46']
# 0.0

# %%
clf = GaussianNB()
clf.fit(X_train, y_train)
pred_naive = clf.predict(X_test)
accuracy_GuassianNB = accuracy_score(y_test,pred_naive)
print(pred_naive)
print(accuracy_GuassianNB)

# %%
clf_tf3 = KNeighborsClassifier(metric='euclidean')
clf_tf3.fit(X_train, y_train)
pred_knn_tf = clf_tf3.predict(X_test)
acuracy_KNN = accuracy_score(y_test,pred_knn_tf)
print(pred_knn_tf)
print(acuracy_KNN)

# %%
print("Tamanho do conjunto de treinamento:", len(X_train))
print("Tamanho do conjunto de teste:", len(X_test))
print("Rótulos únicos no conjunto de treinamento:", np.unique(y_train))
print("Rótulos únicos no conjunto de teste:", np.unique(y_test))

# %%
print(X_train[:5])
print(y_train[:5])

# %%
contagem_classes = df['categoria'].value_counts()
print("Contagem de instâncias por classe:")
print(contagem_classes)
