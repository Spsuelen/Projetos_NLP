# %%
from sklearn.feature_extraction.text import TfidfVectorizer
# !python3 -m spacy download pt_core_news_lg
from tensorflow.keras import optimizers
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.probability import FreqDist
from scipy.sparse import csr_matrix
from nltk.corpus import stopwords
from transformers import pipeline
import matplotlib.pyplot as plt
from random import choice
import seaborn as sns
import pandas as pd
import numpy as np
# %matplotlib inline
import torch
import string
import nltk
import re
# Out:
# Collecting pt-core-news-lg==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/pt_core_news_lg-3.7.0/pt_core_news_lg-3.7.0-py3-none-any.whl (568.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 568.2/568.2 MB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from pt-core-news-lg==3.7.0) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (4.66.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.7.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (24.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (1.25.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.18.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.1.5)
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
classifier = pipeline("zero-shot-classification")
candidate_labels = ["testador", "suporte", "ferramenta"]
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli and revision c626438 (https://huggingface.co/facebook/bart-large-mnli).
# Using a pipeline without specifying a model name and revision in production is not recommended.

# %%
roberta = pipeline("ner", grouped_entities=True, model="joelniklaus/legal-portuguese-roberta-base")
# Out:
# Some weights of RobertaForTokenClassification were not initialized from the model checkpoint at joelniklaus/legal-portuguese-roberta-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/token_classification.py:168: UserWarning: `grouped_entities` is deprecated and will be removed in version v5.0.0, defaulted to `aggregation_strategy="simple"` instead.
#   warnings.warn(

# %%
historias_usuario = [
    "Como Testador eu quero um jeito mais fácil de incluir os requisitos do aplicativo na ferramenta DRL-Mobtest para criar casos de teste que cubram tudo que o aplicativo precisa fazer, sem ter que gastar muito tempo escrevendo manualmente.",
    "Como Testador eu quero uma maneira de ensinar a ferramenta DRL-Mobtest a entender os requisitos do aplicativo usando NLP para fazer com que a ferramenta gere testes automaticamente.",
    "Como Testador eu quero que a ferramenta gere casos de teste abrangentes que cubram integralmente todos os requisitos do aplicativo, assegurando que o software seja completo e funcional, sem depender exclusivamente da criação manual de casos de teste.",
    "Como Testador eu quero que a ferramenta seja integrada com outras ferramentas de gerenciamento, permitindo sincronização automática dos requisitos e facilitando o processo de criação de casos de testes.",
    "Como Testador eu quero que a ferramenta  forneça o recurso de criação de relatórios detalhados sobre a cobertura dos testes, permitindo uma análise precisa sobre sua progressão e identificação das lacunas durante sua execução.",
    "Como testador, quero uma maneira mais fácil de incluir requisitos do aplicativo para criar casos de teste abrangentes, economizando tempo na escrita manual.",
    "Como testador, desejo ensinar a ferramenta a entender os requisitos do aplicativo usando NLP para gerar testes automaticamente.",
    "Como testador, preciso que a ferramenta gere casos de teste completos e funcionais que cubram todos os requisitos do aplicativo.",
    "Como testador, quero integração com outras ferramentas de gerenciamento para sincronizar automaticamente requisitos e facilitar a criação de casos de teste.",
    "Como testador, quero relatórios detalhados sobre a cobertura dos testes para análise precisa durante a execução.",
    "Como testador, desejo que a ferramenta identifique automaticamente os casos de teste mais críticos para priorizar a análise.",
    "Como testador, preciso que a ferramenta sugira casos de teste com base em padrões de uso real do aplicativo.",
    "Como testador, quero sugestões com base em padrões de falha históricos para evitar problemas recorrentes no software.",
    "Como testador, desejo suporte à execução de testes automatizados em diferentes dispositivos e ambientes.",
    "Como testador, preciso que a ferramenta detecte automaticamente mudanças nos requisitos e ajuste os casos de teste correspondentes.",
    "Como testador, quero integração com sistemas de controle de versão para rastrear mudanças nos requisitos e no código-fonte.",
    "Como testador, desejo métricas detalhadas sobre a eficácia dos testes, incluindo taxa de cobertura e taxa de falha.",
    "Como testador, preciso de suporte à execução de testes de desempenho e escalabilidade.",
    "Como testador, quero análise automática dos resultados dos testes para relatórios detalhados sobre problemas encontrados.",
    "Como testador, desejo simular cenários de teste complexos e realistas para garantir testes próximos à realidade.",
    "Como testador, preciso de suporte à execução de testes de regressão automatizados.",
    "Como testador, quero identificação automática de casos de teste redundantes ou desnecessários.",
    "Como testador, desejo integração fácil com ferramentas de gerenciamento de projetos.",
    "Como testador, preciso de suporte à execução de testes de usabilidade.",
    "Como testador, quero que a ferramenta crie automaticamente conjuntos de dados de teste realistas.",
    "Como testador, desejo integração com ferramentas de monitoramento de desempenho em tempo real.",
    "Como testador, preciso de suporte à execução de testes de localização e internacionalização.",
    "Como testador, quero geração automática de dados de teste sintéticos.",
    "Como testador, desejo suporte à execução de testes de acessibilidade.",
    "Como testador, preciso de suporte à execução de testes de integração contínua.",
    "Como testador, quero identificação automática de casos de teste incompletos ou mal definidos.",
    "Como testador, desejo identificação automática de dependências entre casos de teste.",
    "Como testador, preciso de suporte à execução de testes de recuperação de desastres.",
    "Como testador, quero que a ferramenta identifique automaticamente casos de teste paralelizáveis.",
    "Como testador, desejo simulação de cenários de teste de carga extremamente alta.",
    "Como testador, preciso de suporte à execução de testes de compatibilidade com diferentes navegadores e dispositivos.",
    "Como testador, quero geração automática de relatórios de teste personalizados.",
    "Como testador, desejo rastreamento automático de resultados de teste ao longo do tempo.",
    "Como testador, preciso de suporte à execução de testes de regressão progressiva.",
    "Como testador, quero sugestões automáticas para aprimorar os casos de teste existentes.",
    "Como testador, desejo que a ferramenta aprenda com os resultados dos testes e melhore suas sugestões futuras.",
    "Como testador, preciso de suporte à execução de testes de segurança automatizados.",
    "Como testador, quero integração com ferramentas de análise de código estático para identificar áreas de risco.",
    "Como testador, desejo suporte à execução de testes de integração de sistema e teste de aceitação do usuário.",
    "Como testador, preciso de suporte à execução de testes de confiabilidade e disponibilidade.",
    "Como testador, quero que a ferramenta sugira casos de teste com base em modelos de qualidade de software reconhecidos.",
    "Como testador, desejo integração com ferramentas de automação de teste de interface do usuário.",
    "Como testador, preciso de suporte à execução de testes de estresse e robustez.",
    "Como testador, quero que a ferramenta sugira casos de teste para áreas de alto risco e complexidade.",
    "Como testador, desejo integração com ferramentas de gerenciamento de defeitos para rastreamento de correções.",
    "Como testador, preciso de suporte à execução de testes de usabilidade remota e teste de usuário beta.",
    "Como testador, quero que a ferramenta forneça feedback em tempo real durante a execução dos testes.",
    "Como testador, desejo integração com ferramentas de automação de infraestrutura para provisionamento e configuração automatizados.",
    "Como testador, preciso de suporte à execução de testes de comparação de desempenho para versões anteriores e atuais do aplicativo."
  ]

# %%
#sem_pontuacao = re.findall(r'\b(^[^A-Za-z])\b', historias_usuario, re.IGNORECASE)

# %%
class ProcessadorHistoriasUsuario:
    def __init__(self):
        nltk.download('punkt')
        nltk.download('stopwords')
        nltk.download('wordnet')
        self.lemmatizer = WordNetLemmatizer()
        self.stop_words = set(stopwords.words('portuguese'))

    def processar_historias_usuario(self, historias_usuario):
        freq_dists = []
        for historia_usuario in historias_usuario:
            tokens = word_tokenize(historia_usuario)
            tokens = [token.lower() for token in tokens if token not in string.punctuation]
            tokens = [token for token in tokens if token not in self.stop_words]
            tokens = [self.lemmatizer.lemmatize(token) for token in tokens]
            freq_dist = FreqDist(tokens)
            freq_dists.append(freq_dist)
        return freq_dists

# %%
processador = ProcessadorHistoriasUsuario()
freq_dists = processador.processar_historias_usuario(historias_usuario)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
unicas = set()

# Iterando sobre as distribuições de frequência para obter as palavras únicas
for freq_dist in freq_dists:
    unicas.update(freq_dist.keys())

print("Total de palavras únicas:", len(unicas))
print("Diversidade Lexica:", len(unicas) / len(freq_dists))
# Out:
# Total de palavras únicas: 186
# Diversidade Lexica: 3.4444444444444446

# %%
for i, freq_dist in enumerate(freq_dists):
    print(f"História de Usuário {i+1}: {freq_dist.most_common(5)}")
# Out:
# História de Usuário 1: [('aplicativo', 2), ('testador', 1), ('quero', 1), ('jeito', 1), ('fácil', 1)]
# História de Usuário 2: [('ferramenta', 2), ('testador', 1), ('quero', 1), ('maneira', 1), ('ensinar', 1)]
# História de Usuário 3: [('casos', 2), ('teste', 2), ('testador', 1), ('quero', 1), ('ferramenta', 1)]
# História de Usuário 4: [('testador', 1), ('quero', 1), ('ferramenta', 1), ('integrada', 1), ('outras', 1)]
# História de Usuário 5: [('sobre', 2), ('testador', 1), ('quero', 1), ('ferramenta', 1), ('forneça', 1)]
# História de Usuário 6: [('testador', 1), ('quero', 1), ('maneira', 1), ('fácil', 1), ('incluir', 1)]
# História de Usuário 7: [('testador', 1), ('desejo', 1), ('ensinar', 1), ('ferramenta', 1), ('entender', 1)]
# História de Usuário 8: [('testador', 1), ('preciso', 1), ('ferramenta', 1), ('gere', 1), ('casos', 1)]
# História de Usuário 9: [('testador', 1), ('quero', 1), ('integração', 1), ('outras', 1), ('ferramentas', 1)]
# História de Usuário 10: [('testador', 1), ('quero', 1), ('relatórios', 1), ('detalhados', 1), ('sobre', 1)]
# História de Usuário 11: [('testador', 1), ('desejo', 1), ('ferramenta', 1), ('identifique', 1), ('automaticamente', 1)]
# História de Usuário 12: [('testador', 1), ('preciso', 1), ('ferramenta', 1), ('sugira', 1), ('casos', 1)]
# História de Usuário 13: [('testador', 1), ('quero', 1), ('sugestões', 1), ('base', 1), ('padrões', 1)]
# História de Usuário 14: [('testador', 1), ('desejo', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 15: [('testador', 1), ('preciso', 1), ('ferramenta', 1), ('detecte', 1), ('automaticamente', 1)]
# História de Usuário 16: [('testador', 1), ('quero', 1), ('integração', 1), ('sistemas', 1), ('controle', 1)]
# História de Usuário 17: [('taxon', 2), ('testador', 1), ('desejo', 1), ('métricas', 1), ('detalhadas', 1)]
# História de Usuário 18: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 19: [('testador', 1), ('quero', 1), ('análise', 1), ('automática', 1), ('resultados', 1)]
# História de Usuário 20: [('testador', 1), ('desejo', 1), ('simular', 1), ('cenários', 1), ('teste', 1)]
# História de Usuário 21: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 22: [('testador', 1), ('quero', 1), ('identificação', 1), ('automática', 1), ('casos', 1)]
# História de Usuário 23: [('testador', 1), ('desejo', 1), ('integração', 1), ('fácil', 1), ('ferramentas', 1)]
# História de Usuário 24: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 25: [('testador', 1), ('quero', 1), ('ferramenta', 1), ('crie', 1), ('automaticamente', 1)]
# História de Usuário 26: [('testador', 1), ('desejo', 1), ('integração', 1), ('ferramentas', 1), ('monitoramento', 1)]
# História de Usuário 27: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 28: [('testador', 1), ('quero', 1), ('geração', 1), ('automática', 1), ('dado', 1)]
# História de Usuário 29: [('testador', 1), ('desejo', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 30: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 31: [('testador', 1), ('quero', 1), ('identificação', 1), ('automática', 1), ('casos', 1)]
# História de Usuário 32: [('testador', 1), ('desejo', 1), ('identificação', 1), ('automática', 1), ('dependências', 1)]
# História de Usuário 33: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 34: [('testador', 1), ('quero', 1), ('ferramenta', 1), ('identifique', 1), ('automaticamente', 1)]
# História de Usuário 35: [('testador', 1), ('desejo', 1), ('simulação', 1), ('cenários', 1), ('teste', 1)]
# História de Usuário 36: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 37: [('testador', 1), ('quero', 1), ('geração', 1), ('automática', 1), ('relatórios', 1)]
# História de Usuário 38: [('testador', 1), ('desejo', 1), ('rastreamento', 1), ('automático', 1), ('resultados', 1)]
# História de Usuário 39: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 40: [('testador', 1), ('quero', 1), ('sugestões', 1), ('automáticas', 1), ('aprimorar', 1)]
# História de Usuário 41: [('testador', 1), ('desejo', 1), ('ferramenta', 1), ('aprenda', 1), ('resultados', 1)]
# História de Usuário 42: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 43: [('testador', 1), ('quero', 1), ('integração', 1), ('ferramentas', 1), ('análise', 1)]
# História de Usuário 44: [('testador', 1), ('desejo', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 45: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 46: [('testador', 1), ('quero', 1), ('ferramenta', 1), ('sugira', 1), ('casos', 1)]
# História de Usuário 47: [('testador', 1), ('desejo', 1), ('integração', 1), ('ferramentas', 1), ('automação', 1)]
# História de Usuário 48: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 49: [('testador', 1), ('quero', 1), ('ferramenta', 1), ('sugira', 1), ('casos', 1)]
# História de Usuário 50: [('testador', 1), ('desejo', 1), ('integração', 1), ('ferramentas', 1), ('gerenciamento', 1)]
# História de Usuário 51: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 52: [('testador', 1), ('quero', 1), ('ferramenta', 1), ('forneça', 1), ('feedback', 1)]
# História de Usuário 53: [('testador', 1), ('desejo', 1), ('integração', 1), ('ferramentas', 1), ('automação', 1)]
# História de Usuário 54: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]

# %%
nome, valor = zip(*freq_dists[0].most_common(5))
fig, ax = plt.subplots(figsize=(6,5))
sns.barplot(x=np.array(nome), y=np.array(valor), ax=ax)
plt.show()

# %%
nome,valor = zip(*freq_dist.most_common(5))
fig, ax = plt.subplots(figsize=(6,5))
sns.barplot(x=np.array(nome), y=np.array(valor), ax=ax)
# Out:
# <Axes: >

# %%
for i, freq_dist in enumerate(freq_dists):
    historia_usuario = " ".join(freq_dist.keys())
    result = classifier(historia_usuario, candidate_labels=candidate_labels)
    top_label = result['labels'][0]
    confidence = result['scores'][0]
    print(f"História de Usuário {i+1}: Rótulo Previsto: {top_label}, Confiança: {confidence:.2f}")
# Out:
# História de Usuário 1: Rótulo Previsto: testador, Confiança: 0.51
# História de Usuário 2: Rótulo Previsto: testador, Confiança: 0.68
# História de Usuário 3: Rótulo Previsto: testador, Confiança: 0.58
# História de Usuário 4: Rótulo Previsto: testador, Confiança: 0.62
# História de Usuário 5: Rótulo Previsto: testador, Confiança: 0.63
# História de Usuário 6: Rótulo Previsto: testador, Confiança: 0.92
# História de Usuário 7: Rótulo Previsto: testador, Confiança: 0.79
# História de Usuário 8: Rótulo Previsto: testador, Confiança: 0.70
# História de Usuário 9: Rótulo Previsto: testador, Confiança: 0.83
# História de Usuário 10: Rótulo Previsto: testador, Confiança: 0.81
# História de Usuário 11: Rótulo Previsto: testador, Confiança: 0.57
# História de Usuário 12: Rótulo Previsto: testador, Confiança: 0.67
# História de Usuário 13: Rótulo Previsto: testador, Confiança: 0.80
# História de Usuário 14: Rótulo Previsto: testador, Confiança: 0.70
# História de Usuário 15: Rótulo Previsto: testador, Confiança: 0.79
# História de Usuário 16: Rótulo Previsto: testador, Confiança: 0.95
# História de Usuário 17: Rótulo Previsto: testador, Confiança: 0.88
# História de Usuário 18: Rótulo Previsto: testador, Confiança: 0.75
# História de Usuário 19: Rótulo Previsto: testador, Confiança: 0.86
# História de Usuário 20: Rótulo Previsto: testador, Confiança: 0.84
# História de Usuário 21: Rótulo Previsto: testador, Confiança: 0.76
# História de Usuário 22: Rótulo Previsto: testador, Confiança: 0.91
# História de Usuário 23: Rótulo Previsto: testador, Confiança: 0.87
# História de Usuário 24: Rótulo Previsto: testador, Confiança: 0.79
# História de Usuário 25: Rótulo Previsto: testador, Confiança: 0.73
# História de Usuário 26: Rótulo Previsto: testador, Confiança: 0.81
# História de Usuário 27: Rótulo Previsto: testador, Confiança: 0.63
# História de Usuário 28: Rótulo Previsto: testador, Confiança: 0.88
# História de Usuário 29: Rótulo Previsto: testador, Confiança: 0.74
# História de Usuário 30: Rótulo Previsto: testador, Confiança: 0.72
# História de Usuário 31: Rótulo Previsto: testador, Confiança: 0.90
# História de Usuário 32: Rótulo Previsto: testador, Confiança: 0.76
# História de Usuário 33: Rótulo Previsto: testador, Confiança: 0.81
# História de Usuário 34: Rótulo Previsto: testador, Confiança: 0.56
# História de Usuário 35: Rótulo Previsto: testador, Confiança: 0.83
# História de Usuário 36: Rótulo Previsto: testador, Confiança: 0.74
# História de Usuário 37: Rótulo Previsto: testador, Confiança: 0.91
# História de Usuário 38: Rótulo Previsto: testador, Confiança: 0.92
# História de Usuário 39: Rótulo Previsto: testador, Confiança: 0.68
# História de Usuário 40: Rótulo Previsto: testador, Confiança: 0.70
# História de Usuário 41: Rótulo Previsto: testador, Confiança: 0.74
# História de Usuário 42: Rótulo Previsto: testador, Confiança: 0.79
# História de Usuário 43: Rótulo Previsto: testador, Confiança: 0.80
# História de Usuário 44: Rótulo Previsto: testador, Confiança: 0.71
# História de Usuário 45: Rótulo Previsto: testador, Confiança: 0.74
# História de Usuário 46: Rótulo Previsto: testador, Confiança: 0.65
# História de Usuário 47: Rótulo Previsto: testador, Confiança: 0.80
# História de Usuário 48: Rótulo Previsto: testador, Confiança: 0.73
# História de Usuário 49: Rótulo Previsto: testador, Confiança: 0.63
# História de Usuário 50: Rótulo Previsto: testador, Confiança: 0.83
# História de Usuário 51: Rótulo Previsto: testador, Confiança: 0.79
# História de Usuário 52: Rótulo Previsto: testador, Confiança: 0.73
# História de Usuário 53: Rótulo Previsto: testador, Confiança: 0.80
# História de Usuário 54: Rótulo Previsto: testador, Confiança: 0.68

# %%
roberta(f"Resultado: {freq_dists}")
# Out:
# [{'entity_group': 'LABEL_1',
#   'score': 0.56435573,
#   'word': ' resultado :',
#   'start': 0,
#   'end': 10},
#  {'entity_group': 'LABEL_0',
#   'score': 0.59582937,
#   'word': ' [',
#   'start': 12,
#   'end': 12},
#  {'entity_group': 'LABEL_1',
#   'score': 0.54507595,
#   'word': ' freqdis',
#   'start': 13,
#   'end': 19},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5812671,
#   'word': 't',
#   'start': 19,
#   'end': 20},
#  {'entity_group': 'LABEL_1',
#   'score': 0.60263604,
#   'word': ' (',
#   'start': 21,
#   'end': 21},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5339283,
#   'word': " { '",
#   'start': 22,
#   'end': 23},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6378029,
#   'word': ' aplica',
#   'start': 24,
#   'end': 29},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5723716,
#   'word': "tivo '",
#   'start': 29,
#   'end': 34},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6084046,
#   'word': ' : 2 ,',
#   'start': 35,
#   'end': 38},
#  {'entity_group': 'LABEL_0',
#   'score': 0.57676196,
#   'word': " ' testador '",
#   'start': 40,
#   'end': 49},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5915764,
#   'word': ' : 1 ,',
#   'start': 50,
#   'end': 53},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6374132,
#   'word': " '",
#   'start': 55,
#   'end': 55},
#  {'entity_group': 'LABEL_1',
#   'score': 0.57367444,
#   'word': ' que',
#   'start': 56,
#   'end': 58},
#  {'entity_group': 'LABEL_0',
#   'score': 0.63928545,
#   'word': "ro '",
#   'start': 58,
#   'end': 61},
#  {'entity_group': 'LABEL_1',
#   'score': 0.57455575,
#   'word': ' : 1',
#   'start': 62,
#   'end': 64},
#  {'entity_group': 'LABEL_0',
#   'score': 0.639268,
#   'word': " , ' jeito '",
#   'start': 65,
#   'end': 73},
#  {'entity_group': 'LABEL_1',
#   'score': 0.53139174,
#   'word': ' : 1',
#   'start': 74,
#   'end': 76},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5828352,
#   'word': " , ' facil '",
#   'start': 77,
#   'end': 85},
#  {'entity_group': 'LABEL_1',
#   'score': 0.54054284,
#   'word': ' : 1',
#   'start': 86,
#   'end': 88},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5809846,
#   'word': " , '",
#   'start': 89,
#   'end': 91},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5711625,
#   'word': ' incluir',
#   'start': 92,
#   'end': 98},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6847067,
#   'word': " '",
#   'start': 99,
#   'end': 99},
#  {'entity_group': 'LABEL_1',
#   'score': 0.560828,
#   'word': ' : 1',
#   'start': 100,
#   'end': 102},
#  {'entity_group': 'LABEL_0',
#   'score': 0.59026396,
#   'word': " , '",
#   'start': 103,
#   'end': 105},
#  {'entity_group': 'LABEL_1',
#   'score': 0.52507967,
#   'word': ' requisitos',
#   'start': 106,
#   'end': 115},
#  {'entity_group': 'LABEL_0',
#   'score': 0.70167047,
#   'word': " '",
#   'start': 116,
#   'end': 116},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5319164,
#   'word': ' : 1',
#   'start': 117,
#   'end': 119},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5969102,
#   'word': " , ' ferramenta '",
#   'start': 120,
#   'end': 133},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5258685,
#   'word': ' : 1 ,',
#   'start': 134,
#   'end': 137},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5160611,
#   'word': " '",
#   'start': 139,
#   'end': 139},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6206145,
#   'word': ' drl - mob',
#   'start': 140,
#   'end': 146},
#  {'entity_group': 'LABEL_0',
#   'score': 0.67203665,
#   'word': "test '",
#   'start': 146,
#   'end': 151},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5974522,
#   'word': ' : 1 ,',
#   'start': 152,
#   'end': 155},
#  {'entity_group': 'LABEL_0',
#   'score': 0.50536853,
#   'word': " '",
#   'start': 157,
#   'end': 157},
#  {'entity_group': 'LABEL_1',
#   'score': 0.53037506,
#   'word': ' criar',
#   'start': 158,
#   'end': 162},
#  {'entity_group': 'LABEL_0',
#   'score': 0.58647627,
#   'word': " '",
#   'start': 163,
#   'end': 163},
#  {'entity_group': 'LABEL_1',
#   'score': 0.603359,
#   'word': ' : 1 , . . .',
#   'start': 164,
#   'end': 171},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5889939,
#   'word': ' }',
#   'start': 172,
#   'end': 172},
#  {'entity_group': 'LABEL_1',
#   'score': 0.575245,
#   'word': ' ) ,',
#   'start': 173,
#   'end': 174},
#  {'entity_group': 'LABEL_0',
#   'score': 0.52328163,
#   'word': ' fre',
#   'start': 176,
#   'end': 178},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5096414,
#   'word': 'qdis',
#   'start': 178,
#   'end': 182},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6339979,
#   'word': 't',
#   'start': 182,
#   'end': 183},
#  {'entity_group': 'LABEL_1',
#   'score': 0.55524,
#   'word': ' (',
#   'start': 184,
#   'end': 184},
#  {'entity_group': 'LABEL_0',
#   'score': 0.59092754,
#   'word': " { '",
#   'start': 185,
#   'end': 186},
#  {'entity_group': 'LABEL_1',
#   'score': 0.52453655,
#   'word': ' ferramenta',
#   'start': 187,
#   'end': 196},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6349369,
#   'word': " '",
#   'start': 197,
#   'end': 197},
#  {'entity_group': 'LABEL_1',
#   'score': 0.57508874,
#   'word': ' : 2 ,',
#   'start': 198,
#   'end': 201},
#  {'entity_group': 'LABEL_0',
#   'score': 0.61269474,
#   'word': " ' testador '",
#   'start': 203,
#   'end': 212},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6083005,
#   'word': ' : 1',
#   'start': 213,
#   'end': 215},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5878096,
#   'word': " , '",
#   'start': 216,
#   'end': 218},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5648408,
#   'word': ' que',
#   'start': 219,
#   'end': 221},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6197402,
#   'word': "ro ' :",
#   'start': 221,
#   'end': 225},
#  {'entity_group': 'LABEL_1',
#   'score': 0.52132434,
#   'word': ' 1',
#   'start': 227,
#   'end': 227},
#  {'entity_group': 'LABEL_0',
#   'score': 0.63594234,
#   'word': " , ' maneira ' :",
#   'start': 228,
#   'end': 239},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5074977,
#   'word': ' 1',
#   'start': 241,
#   'end': 241},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6262703,
#   'word': " , '",
#   'start': 242,
#   'end': 244},
#  {'entity_group': 'LABEL_1',
#   'score': 0.514364,
#   'word': ' ens',
#   'start': 245,
#   'end': 247},
#  {'entity_group': 'LABEL_0',
#   'score': 0.7325647,
#   'word': "inar '",
#   'start': 247,
#   'end': 252},
#  {'entity_group': 'LABEL_1',
#   'score': 0.52513975,
#   'word': ' : 1',
#   'start': 253,
#   'end': 255},
#  {'entity_group': 'LABEL_0',
#   'score': 0.54337144,
#   'word': " , '",
#   'start': 256,
#   'end': 258},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5747988,
#   'word': ' drl - mob',
#   'start': 259,
#   'end': 265},
#  {'entity_group': 'LABEL_0',
#   'score': 0.71899354,
#   'word': "test '",
#   'start': 265,
#   'end': 270},
#  {'entity_group': 'LABEL_1',
#   'score': 0.53653824,
#   'word': ' : 1',
#   'start': 271,
#   'end': 273},
#  {'entity_group': 'LABEL_0',
#   'score': 0.60287106,
#   'word': " , ' entender '",
#   'start': 274,
#   'end': 285},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5330133,
#   'word': ' : 1',
#   'start': 286,
#   'end': 288},
#  {'entity_group': 'LABEL_0',
#   'score': 0.60591984,
#   'word': " , '",
#   'start': 289,
#   'end': 291},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5330788,
#   'word': ' requisitos',
#   'start': 292,
#   'end': 301},
#  {'entity_group': 'LABEL_0',
#   'score': 0.70084924,
#   'word': " '",
#   'start': 302,
#   'end': 302},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5262158,
#   'word': ' : 1',
#   'start': 303,
#   'end': 305},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5737428,
#   'word': " , '",
#   'start': 306,
#   'end': 308},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6267599,
#   'word': ' aplica',
#   'start': 309,
#   'end': 314},
#  {'entity_group': 'LABEL_0',
#   'score': 0.61189646,
#   'word': "tivo '",
#   'start': 314,
#   'end': 319},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5765578,
#   'word': ' : 1 ,',
#   'start': 320,
#   'end': 323},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5998202,
#   'word': " ' usando '",
#   'start': 325,
#   'end': 332},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6088354,
#   'word': ' : 1',
#   'start': 333,
#   'end': 335},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5070981,
#   'word': ' ,',
#   'start': 336,
#   'end': 336},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5973933,
#   'word': ' . . .',
#   'start': 338,
#   'end': 340},
#  {'entity_group': 'LABEL_0',
#   'score': 0.582642,
#   'word': ' }',
#   'start': 341,
#   'end': 341},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5505792,
#   'word': ' ) ,',
#   'start': 342,
#   'end': 343},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5238868,
#   'word': ' freq',
#   'start': 345,
#   'end': 348},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5210341,
#   'word': 'dis',
#   'start': 348,
#   'end': 351},
#  {'entity_group': 'LABEL_0',
#   'score': 0.63416225,
#   'word': 't',
#   'start': 351,
#   'end': 352},
#  {'entity_group': 'LABEL_1',
#   'score': 0.58543825,
#   'word': ' (',
#   'start': 353,
#   'end': 353},
#  {'entity_group': 'LABEL_0',
#   'score': 0.61041546,
#   'word': " { '",
#   'start': 354,
#   'end': 355},
#  {'entity_group': 'LABEL_1',
#   'score': 0.504215,
#   'word': ' casos',
#   'start': 356,
#   'end': 360},
#  {'entity_group': 'LABEL_0',
#   'score': 0.72179824,
#   'word': " '",
#   'start': 361,
#   'end': 361},
#  {'entity_group': 'LABEL_1',
#   'score': 0.54622346,
#   'word': ' : 2 ,',
#   'start': 362,
#   'end': 365},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6607562,
#   'word': " ' teste '",
#   'start': 367,
#   'end': 373},
#  {'entity_group': 'LABEL_1',
#   'score': 0.58024013,
#   'word': ' : 2',
#   'start': 374,
#   'end': 376},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6145952,
#   'word': " , ' testador '",
#   'start': 377,
#   'end': 388},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5943635,
#   'word': ' : 1',
#   'start': 389,
#   'end': 391},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6017746,
#   'word': " , '",
#   'start': 392,
#   'end': 394},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5342084,
#   'word': ' que',
#   'start': 395,
#   'end': 397},
#  {'entity_group': 'LABEL_0',
#   'score': 0.64257973,
#   'word': "ro ' :",
#   'start': 397,
#   'end': 401},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5129294,
#   'word': ' 1',
#   'start': 403,
#   'end': 403},
#  {'entity_group': 'LABEL_0',
#   'score': 0.64621276,
#   'word': " , ' ferramenta '",
#   'start': 404,
#   'end': 417},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5285692,
#   'word': ' : 1',
#   'start': 418,
#   'end': 420},
#  {'entity_group': 'LABEL_0',
#   'score': 0.61980844,
#   'word': " , ' gere '",
#   'start': 421,
#   'end': 428},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5596516,
#   'word': ' : 1 ,',
#   'start': 429,
#   'end': 432},
#  {'entity_group': 'LABEL_0',
#   'score': 0.58118266,
#   'word': " '",
#   'start': 434,
#   'end': 434},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5899299,
#   'word': ' abrangentes',
#   'start': 435,
#   'end': 445},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6900713,
#   'word': " '",
#   'start': 446,
#   'end': 446},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6005363,
#   'word': ' : 1',
#   'start': 447,
#   'end': 449},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5638041,
#   'word': " , '",
#   'start': 450,
#   'end': 452},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5615028,
#   'word': ' cub',
#   'start': 453,
#   'end': 455},
#  {'entity_group': 'LABEL_0',
#   'score': 0.67822284,
#   'word': "ram '",
#   'start': 455,
#   'end': 459},
#  {'entity_group': 'LABEL_1',
#   'score': 0.57572824,
#   'word': ' : 1 ,',
#   'start': 460,
#   'end': 463},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5359396,
#   'word': " '",
#   'start': 465,
#   'end': 465},
#  {'entity_group': 'LABEL_1',
#   'score': 0.594643,
#   'word': ' integralmente',
#   'start': 466,
#   'end': 478},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6590391,
#   'word': " '",
#   'start': 479,
#   'end': 479},
#  {'entity_group': 'LABEL_1',
#   'score': 0.59373623,
#   'word': " : 1 , ' todos",
#   'start': 480,
#   'end': 490},
#  {'entity_group': 'LABEL_0',
#   'score': 0.61467856,
#   'word': " '",
#   'start': 491,
#   'end': 491},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6145887,
#   'word': ' : 1 , . . .',
#   'start': 492,
#   'end': 499},
#  {'entity_group': 'LABEL_0',
#   'score': 0.56178206,
#   'word': ' }',
#   'start': 500,
#   'end': 500},
#  {'entity_group': 'LABEL_1',
#   'score': 0.55961406,
#   'word': ' ) ,',
#   'start': 501,
#   'end': 502},
#  {'entity_group': 'LABEL_0',
#   'score': 0.51390326,
#   'word': ' fre',
#   'start': 504,
#   'end': 506},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5286108,
#   'word': 'qdis',
#   'start': 506,
#   'end': 510},
#  {'entity_group': 'LABEL_0',
#   'score': 0.59360015,
#   'word': 't',
#   'start': 510,
#   'end': 511},
#  {'entity_group': 'LABEL_1',
#   'score': 0.56359303,
#   'word': ' ( {',
#   'start': 512,
#   'end': 513},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5768108,
#   'word': " ' testador '",
#   'start': 514,
#   'end': 523},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6149817,
#   'word': ' : 1 ,',
#   'start': 524,
#   'end': 527},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6149958,
#   'word': " '",
#   'start': 529,
#   'end': 529},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5793871,
#   'word': ' que',
#   'start': 530,
#   'end': 532},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6318549,
#   'word': "ro '",
#   'start': 532,
#   'end': 535},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6165004,
#   'word': ' : 1',
#   'start': 536,
#   'end': 538},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6049935,
#   'word': " , ' ferramenta '",
#   'start': 539,
#   'end': 552},
#  {'entity_group': 'LABEL_1',
#   'score': 0.58864415,
#   'word': ' : 1',
#   'start': 553,
#   'end': 555},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5414648,
#   'word': " , '",
#   'start': 556,
#   'end': 558},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5626594,
#   'word': ' integrada',
#   'start': 559,
#   'end': 567},
#  {'entity_group': 'LABEL_0',
#   'score': 0.66697663,
#   'word': " '",
#   'start': 568,
#   'end': 568},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5774281,
#   'word': ' : 1',
#   'start': 569,
#   'end': 571},
#  {'entity_group': 'LABEL_0',
#   'score': 0.533307,
#   'word': " , '",
#   'start': 572,
#   'end': 574},
#  {'entity_group': 'LABEL_1',
#   'score': 0.57473296,
#   'word': ' outras',
#   'start': 575,
#   'end': 580},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6464031,
#   'word': " '",
#   'start': 581,
#   'end': 581},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5893313,
#   'word': ' : 1 ,',
#   'start': 582,
#   'end': 585},
#  {'entity_group': 'LABEL_0',
#   'score': 0.51056916,
#   'word': " '",
#   'start': 587,
#   'end': 587},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5958577,
#   'word': ' ferramentas',
#   'start': 588,
#   'end': 598},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6036302,
#   'word': " '",
#   'start': 599,
#   'end': 599},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6192291,
#   'word': ' : 1 ,',
#   'start': 600,
#   'end': 603},
#  {'entity_group': 'LABEL_0',
#   'score': 0.52360654,
#   'word': " '",
#   'start': 605,
#   'end': 605},
#  {'entity_group': 'LABEL_1',
#   'score': 0.584044,
#   'word': ' gerenciamento',
#   'start': 606,
#   'end': 618},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5687646,
#   'word': " '",
#   'start': 619,
#   'end': 619},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5908047,
#   'word': " : 1 , ' permitindo",
#   'start': 620,
#   'end': 635},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6212937,
#   'word': " '",
#   'start': 636,
#   'end': 636},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6011449,
#   'word': ' : 1 ,',
#   'start': 637,
#   'end': 640},
#  {'entity_group': 'LABEL_0',
#   'score': 0.537045,
#   'word': " ' sincro",
#   'start': 642,
#   'end': 648},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5239074,
#   'word': 'nizacao',
#   'start': 648,
#   'end': 655},
#  {'entity_group': 'LABEL_0',
#   'score': 0.61175656,
#   'word': " '",
#   'start': 656,
#   'end': 656},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6407958,
#   'word': " : 1 , ' automatica",
#   'start': 657,
#   'end': 672},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5439462,
#   'word': " '",
#   'start': 673,
#   'end': 673},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6281737,
#   'word': ' : 1 , . . .',
#   'start': 674,
#   'end': 681},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5508909,
#   'word': ' }',
#   'start': 682,
#   'end': 682},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5534483,
#   'word': ' ) , freqdis',
#   'start': 683,
#   'end': 692},
#  {'entity_group': 'LABEL_0',
#   'score': 0.57379293,
#   'word': 't',
#   'start': 692,
#   'end': 693},
#  {'entity_group': 'LABEL_1',
#   'score': 0.57373285,
#   'word': ' ( {',
#   'start': 694,
#   'end': 695},
#  {'entity_group': 'LABEL_0',
#   'score': 0.50491965,
#   'word': " '",
#   'start': 696,
#   'end': 696},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5513321,
#   'word': ' sobre',
#   'start': 697,
#   'end': 701},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6391336,
#   'word': " '",
#   'start': 702,
#   'end': 702},
#  {'entity_group': 'LABEL_1',
#   'score': 0.576754,
#   'word': " : 2 , ' tes",
#   'start': 703,
#   'end': 711},
#  {'entity_group': 'LABEL_0',
#   'score': 0.57690483,
#   'word': "tador '",
#   'start': 711,
#   'end': 717},
#  {'entity_group': 'LABEL_1',
#   'score': 0.64134187,
#   'word': ' : 1 ,',
#   'start': 718,
#   'end': 721},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5677526,
#   'word': " '",
#   'start': 723,
#   'end': 723},
#  {'entity_group': 'LABEL_1',
#   'score': 0.637813,
#   'word': ' que',
#   'start': 724,
#   'end': 726},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5959908,
#   'word': "ro '",
#   'start': 726,
#   'end': 729},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5791665,
#   'word': ' : 1 ,',
#   'start': 730,
#   'end': 733},
#  {'entity_group': 'LABEL_0',
#   'score': 0.57927287,
#   'word': " '",
#   'start': 735,
#   'end': 735},
#  {'entity_group': 'LABEL_1',
#   'score': 0.53049946,
#   'word': ' ferramenta',
#   'start': 736,
#   'end': 745},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6533666,
#   'word': " '",
#   'start': 746,
#   'end': 746},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5667045,
#   'word': ' : 1 ,',
#   'start': 747,
#   'end': 750},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5951209,
#   'word': " ' forneca '",
#   'start': 752,
#   'end': 760},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5987885,
#   'word': ' : 1 ,',
#   'start': 761,
#   'end': 764},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5670294,
#   'word': " '",
#   'start': 766,
#   'end': 766},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6687873,
#   'word': ' recurso',
#   'start': 767,
#   'end': 773},
#  {'entity_group': 'LABEL_0',
#   'score': 0.62513506,
#   'word': " '",
#   'start': 774,
#   'end': 774},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5850897,
#   'word': ' : 1 ,',
#   'start': 775,
#   'end': 778},
#  {'entity_group': 'LABEL_0',
#   'score': 0.57181144,
#   'word': " '",
#   'start': 780,
#   'end': 780},
#  {'entity_group': 'LABEL_1',
#   'score': 0.52728003,
#   'word': ' criacao',
#   'start': 781,
#   'end': 787},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6453915,
#   'word': " '",
#   'start': 788,
#   'end': 788},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5523998,
#   'word': ' : 1 ,',
#   'start': 789,
#   'end': 792},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5880475,
#   'word': " '",
#   'start': 794,
#   'end': 794},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6504858,
#   'word': ' relatorios',
#   'start': 795,
#   'end': 804},
#  {'entity_group': 'LABEL_0',
#   'score': 0.67242396,
#   'word': " '",
#   'start': 805,
#   'end': 805},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5820326,
#   'word': ' : 1 ,',
#   'start': 806,
#   'end': 809},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5517047,
#   'word': " '",
#   'start': 811,
#   'end': 811},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5487408,
#   'word': ' detalhados',
#   'start': 812,
#   'end': 821},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6500475,
#   'word': " '",
#   'start': 822,
#   'end': 822},
#  {'entity_group': 'LABEL_1',
#   'score': 0.605391,
#   'word': ' : 1 ,',
#   'start': 823,
#   'end': 826},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5523898,
#   'word': " '",
#   'start': 828,
#   'end': 828},
#  {'entity_group': 'LABEL_1',
#   'score': 0.663855,
#   'word': ' cobertura',
#   'start': 829,
#   'end': 837},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5967016,
#   'word': " '",
#   'start': 838,
#   'end': 838},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6247326,
#   'word': ' : 1',
#   'start': 839,
#   'end': 841},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5010237,
#   'word': ' ,',
#   'start': 842,
#   'end': 842},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6216008,
#   'word': ' . . .',
#   'start': 844,
#   'end': 846},
#  {'entity_group': 'LABEL_0',
#   'score': 0.544137,
#   'word': ' }',
#   'start': 847,
#   'end': 847},
#  {'entity_group': 'LABEL_1',
#   'score': 0.54821765,
#   'word': ' ) , freqdis',
#   'start': 848,
#   'end': 857},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5873489,
#   'word': 't',
#   'start': 857,
#   'end': 858},
#  {'entity_group': 'LABEL_1',
#   'score': 0.55439013,
#   'word': " ( { '",
#   'start': 859,
#   'end': 861},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5694199,
#   'word': " testador '",
#   'start': 862,
#   'end': 870},
#  {'entity_group': 'LABEL_1',
#   'score': 0.64998674,
#   'word': ' : 1 ,',
#   'start': 871,
#   'end': 874},
#  {'entity_group': 'LABEL_0',
#   'score': 0.57218874,
#   'word': " '",
#   'start': 876,
#   'end': 876},
#  {'entity_group': 'LABEL_1',
#   'score': 0.59007096,
#   'word': ' que',
#   'start': 877,
#   'end': 879},
#  {'entity_group': 'LABEL_0',
#   'score': 0.60760534,
#   'word': "ro '",
#   'start': 879,
#   'end': 882},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5957225,
#   'word': ' : 1 ,',
#   'start': 883,
#   'end': 886},
#  {'entity_group': 'LABEL_0',
#   'score': 0.61278516,
#   'word': " ' maneira '",
#   'start': 888,
#   'end': 896},
#  {'entity_group': 'LABEL_1',
#   'score': 0.56325644,
#   'word': ' : 1 ,',
#   'start': 897,
#   'end': 900},
#  {'entity_group': 'LABEL_0',
#   'score': 0.59669393,
#   'word': " ' facil '",
#   'start': 902,
#   'end': 908},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5830238,
#   'word': ' : 1',
#   'start': 909,
#   'end': 911},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5497888,
#   'word': " , '",
#   'start': 912,
#   'end': 914},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6107118,
#   'word': ' incluir',
#   'start': 915,
#   'end': 921},
#  {'entity_group': 'LABEL_0',
#   'score': 0.670436,
#   'word': " '",
#   'start': 922,
#   'end': 922},
#  {'entity_group': 'LABEL_1',
#   'score': 0.60756207,
#   'word': ' : 1',
#   'start': 923,
#   'end': 925},
#  {'entity_group': 'LABEL_0',
#   'score': 0.55727094,
#   'word': " , '",
#   'start': 926,
#   'end': 928},
#  {'entity_group': 'LABEL_1',
#   'score': 0.57958907,
#   'word': ' requisitos',
#   'start': 929,
#   'end': 938},
#  {'entity_group': 'LABEL_0',
#   'score': 0.68542653,
#   'word': " '",
#   'start': 939,
#   'end': 939},
#  {'entity_group': 'LABEL_1',
#   'score': 0.56359833,
#   'word': ' : 1',
#   'start': 940,
#   'end': 942},
#  {'entity_group': 'LABEL_0',
#   'score': 0.59802246,
#   'word': " , '",
#   'start': 943,
#   'end': 945},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5900678,
#   'word': ' aplica',
#   'start': 946,
#   'end': 951},
#  {'entity_group': 'LABEL_0',
#   'score': 0.66414165,
#   'word': "tivo '",
#   'start': 951,
#   'end': 956},
#  {'entity_group': 'LABEL_1',
#   'score': 0.54086566,
#   'word': ' : 1',
#   'start': 957,
#   'end': 959},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6017598,
#   'word': " , ' criar '",
#   'start': 960,
#   'end': 968},
#  {'entity_group': 'LABEL_1',
#   'score': 0.53605795,
#   'word': ' : 1',
#   'start': 969,
#   'end': 971},
#  {'entity_group': 'LABEL_0',
#   'score': 0.60083294,
#   'word': " , '",
#   'start': 972,
#   'end': 974},
#  {'entity_group': 'LABEL_1',
#   'score': 0.58148426,
#   'word': ' casos',
#   'start': 975,
#   'end': 979},
#  {'entity_group': 'LABEL_0',
#   'score': 0.70244694,
#   'word': " '",
#   'start': 980,
#   'end': 980},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5590081,
#   'word': ' : 1',
#   'start': 981,
#   'end': 983},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5949029,
#   'word': " , ' teste '",
#   'start': 984,
#   'end': 992},
#  {'entity_group': 'LABEL_1',
#   'score': 0.58802986,
#   'word': ' : 1',
#   'start': 993,
#   'end': 995},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5148793,
#   'word': ' ,',
#   'start': 996,
#   'end': 996},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5799493,
#   'word': ' . . .',
#   'start': 998,
#   'end': 1000},
#  {'entity_group': 'LABEL_0',
#   'score': 0.54781514,
#   'word': ' }',
#   'start': 1001,
#   'end': 1001},
#  {'entity_group': 'LABEL_1',
#   'score': 0.55348814,
#   'word': ' ) , freqdis',
#   'start': 1002,
#   'end': 1011},
#  {'entity_group': 'LABEL_0',
#   'score': 0.57734084,
#   'word': 't',
#   'start': 1011,
#   'end': 1012},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5682893,
#   'word': " ( { '",
#   'start': 1013,
#   'end': 1015},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5621634,
#   'word': " testador '",
#   'start': 1016,
#   'end': 1024},
#  {'entity_group': 'LABEL_1',
#   'score': 0.65309143,
#   'word': ' : 1 ,',
#   'start': 1025,
#   'end': 1028},
#  {'entity_group': 'LABEL_0',
#   'score': 0.57201666,
#   'word': " '",
#   'start': 1030,
#   'end': 1030},
#  {'entity_group': 'LABEL_1',
#   'score': 0.58105236,
#   'word': ' desejo',
#   'start': 1031,
#   'end': 1036},
#  {'entity_group': 'LABEL_0',
#   'score': 0.65361035,
#   'word': " '",
#   'start': 1037,
#   'end': 1037},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6046945,
#   'word': ' : 1',
#   'start': 1038,
#   'end': 1040},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5708772,
#   'word': " , '",
#   'start': 1041,
#   'end': 1043},
#  {'entity_group': 'LABEL_1',
#   'score': 0.573262,
#   'word': ' ens',
#   'start': 1044,
#   'end': 1046},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6934603,
#   'word': "inar '",
#   'start': 1046,
#   'end': 1051},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5787599,
#   'word': ' : 1',
#   'start': 1052,
#   'end': 1054},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5901003,
#   'word': " , ' ferramenta '",
#   'start': 1055,
#   'end': 1068},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5773501,
#   'word': ' : 1',
#   'start': 1069,
#   'end': 1071},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5654472,
#   'word': " , ' entender '",
#   'start': 1072,
#   'end': 1083},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5977938,
#   'word': ' : 1',
#   'start': 1084,
#   'end': 1086},
#  {'entity_group': 'LABEL_0',
#   'score': 0.56591326,
#   'word': " , '",
#   'start': 1087,
#   'end': 1089},
#  {'entity_group': 'LABEL_1',
#   'score': 0.55598766,
#   'word': ' requisitos',
#   'start': 1090,
#   'end': 1099},
#  {'entity_group': 'LABEL_0',
#   'score': 0.68304396,
#   'word': " '",
#   'start': 1100,
#   'end': 1100},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5690496,
#   'word': ' : 1',
#   'start': 1101,
#   'end': 1103},
#  {'entity_group': 'LABEL_0',
#   'score': 0.56583047,
#   'word': " , '",
#   'start': 1104,
#   'end': 1106},
#  {'entity_group': 'LABEL_1',
#   'score': 0.554033,
#   'word': ' aplica',
#   'start': 1107,
#   'end': 1112},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6369105,
#   'word': 'tivo',
#   'start': 1112,
#   'end': 1116}]

# %%
for i, freq_dist in enumerate(freq_dists):
    historia_usuario = " ".join(freq_dist.keys())
    result = roberta(f"História de Usuário {i+1}: {historia_usuario}")
    print(f"Resultado para História de Usuário {i+1}: {result}")
# Out:
# Resultado para História de Usuário 1: [{'entity_group': 'LABEL_1', 'score': 0.59787536, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.53177094, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.6019137, 'word': ' 1 : tes', 'start': 21, 'end': 26}, {'entity_group': 'LABEL_0', 'score': 0.51160455, 'word': 'tador', 'start': 26, 'end': 31}, {'entity_group': 'LABEL_1', 'score': 0.63626343, 'word': ' quero jeito facil incluir requisitos aplica', 'start': 33, 'end': 75}, {'entity_group': 'LABEL_0', 'score': 0.50638914, 'word': 'tivo', 'start': 75, 'end': 79}, {'entity_group': 'LABEL_1', 'score': 0.6182089, 'word': ' ferramenta drl - mobtest criar casos', 'start': 81, 'end': 114}, {'entity_group': 'LABEL_0', 'score': 0.57804704, 'word': ' teste', 'start': 116, 'end': 120}, {'entity_group': 'LABEL_1', 'score': 0.53773546, 'word': ' cub', 'start': 122, 'end': 124}, {'entity_group': 'LABEL_0', 'score': 0.5825704, 'word': 'ram', 'start': 124, 'end': 127}, {'entity_group': 'LABEL_1', 'score': 0.61502016, 'word': ' tudo', 'start': 129, 'end': 132}, {'entity_group': 'LABEL_0', 'score': 0.5076856, 'word': ' precisa', 'start': 134, 'end': 140}, {'entity_group': 'LABEL_1', 'score': 0.56930995, 'word': ' fazer ter', 'start': 142, 'end': 150}, {'entity_group': 'LABEL_0', 'score': 0.5765195, 'word': ' gastar tempo', 'start': 152, 'end': 163}, {'entity_group': 'LABEL_1', 'score': 0.5687564, 'word': ' escrevendo manualmente', 'start': 165, 'end': 186}]
# Resultado para História de Usuário 2: [{'entity_group': 'LABEL_1', 'score': 0.5783975, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.51196283, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.619781, 'word': ' 2 : testador quero maneira ensinar ferramenta drl - mob', 'start': 21, 'end': 72}, {'entity_group': 'LABEL_0', 'score': 0.5093486, 'word': 'test', 'start': 72, 'end': 76}, {'entity_group': 'LABEL_1', 'score': 0.6046256, 'word': ' entender requisitos aplicativo', 'start': 78, 'end': 107}, {'entity_group': 'LABEL_0', 'score': 0.5578592, 'word': ' usando', 'start': 109, 'end': 114}, {'entity_group': 'LABEL_1', 'score': 0.5391201, 'word': ' nlp fazer gere tes', 'start': 116, 'end': 133}, {'entity_group': 'LABEL_0', 'score': 0.52245796, 'word': 'tis', 'start': 133, 'end': 136}, {'entity_group': 'LABEL_1', 'score': 0.68893254, 'word': ' automaticamente', 'start': 138, 'end': 152}]
# Resultado para História de Usuário 3: [{'entity_group': 'LABEL_1', 'score': 0.5803589, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5242371, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.686412, 'word': ' 3 :', 'start': 21, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.5310307, 'word': ' testador', 'start': 24, 'end': 31}, {'entity_group': 'LABEL_1', 'score': 0.549532, 'word': ' que', 'start': 33, 'end': 35}, {'entity_group': 'LABEL_0', 'score': 0.5077894, 'word': 'ro', 'start': 35, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.61336076, 'word': ' ferramenta gere casos teste abrangentes cubram integralmente todos requisitos aplicativo assegurando software completo funcional depender exclusivamente criacao manual', 'start': 39, 'end': 205}]
# Resultado para História de Usuário 4: [{'entity_group': 'LABEL_1', 'score': 0.58894134, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5495794, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.6172142, 'word': ' 4 :', 'start': 21, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.5263741, 'word': ' testador', 'start': 24, 'end': 31}, {'entity_group': 'LABEL_1', 'score': 0.642611, 'word': ' quero ferramenta integrada outras ferramentas gerenciamento permitindo sincronizacao automatica requisitos facilitando processo criacao casos', 'start': 33, 'end': 173}, {'entity_group': 'LABEL_0', 'score': 0.580585, 'word': ' testis', 'start': 175, 'end': 180}]
# Resultado para História de Usuário 5: [{'entity_group': 'LABEL_1', 'score': 0.59057546, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5541805, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.6505337, 'word': ' 5 :', 'start': 21, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.5411074, 'word': ' testador', 'start': 24, 'end': 31}, {'entity_group': 'LABEL_1', 'score': 0.62094444, 'word': ' quero ferramenta', 'start': 33, 'end': 48}, {'entity_group': 'LABEL_0', 'score': 0.53487366, 'word': ' forneca', 'start': 50, 'end': 56}, {'entity_group': 'LABEL_1', 'score': 0.67011, 'word': ' recurso criacao relatorios detalhados', 'start': 58, 'end': 94}, {'entity_group': 'LABEL_0', 'score': 0.60281235, 'word': ' sobre', 'start': 96, 'end': 100}, {'entity_group': 'LABEL_1', 'score': 0.7110294, 'word': ' cobertura', 'start': 102, 'end': 110}, {'entity_group': 'LABEL_0', 'score': 0.51133245, 'word': ' testis', 'start': 112, 'end': 117}, {'entity_group': 'LABEL_1', 'score': 0.6069737, 'word': ' permitindo analise precisa progressao identificacao lacuna', 'start': 119, 'end': 176}, {'entity_group': 'LABEL_0', 'score': 0.5491053, 'word': ' durante execucao', 'start': 178, 'end': 193}]
# Resultado para História de Usuário 6: [{'entity_group': 'LABEL_1', 'score': 0.62044305, 'word': ' historia de usuario 6 : testador quero maneira facil incluir requisitos aplicativo criar casos teste abrangentes economizando tempo escrita manual', 'start': 0, 'end': 145}]
# Resultado para História de Usuário 7: [{'entity_group': 'LABEL_1', 'score': 0.56124026, 'word': ' historia de usuario', 'start': 0, 'end': 19}, {'entity_group': 'LABEL_0', 'score': 0.52804816, 'word': ' 7', 'start': 21, 'end': 21}, {'entity_group': 'LABEL_1', 'score': 0.6420382, 'word': ' : testador desejo ensinar ferramenta entender requisitos aplicativo usando nlp gerar testis automaticamente', 'start': 22, 'end': 128}]
# Resultado para História de Usuário 8: [{'entity_group': 'LABEL_1', 'score': 0.6295103, 'word': ' historia de usuario 8 : testador preciso ferramenta gere casos teste completos funcionais cubram todos requisitos aplicativo', 'start': 0, 'end': 123}]
# Resultado para História de Usuário 9: [{'entity_group': 'LABEL_1', 'score': 0.5591657, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5514449, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.7240018, 'word': ' 9 :', 'start': 21, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.51049894, 'word': ' tes', 'start': 24, 'end': 26}, {'entity_group': 'LABEL_1', 'score': 0.6779154, 'word': 'tador quero integracao outras ferramentas gerenciamento sincronizar automaticamente requisitos facilitar criacao casos', 'start': 26, 'end': 144}, {'entity_group': 'LABEL_0', 'score': 0.6248737, 'word': ' teste', 'start': 146, 'end': 150}]
# Resultado para História de Usuário 10: [{'entity_group': 'LABEL_1', 'score': 0.5760713, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5190201, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.60918653, 'word': ' 10 : testador quero relatorios detalhados', 'start': 21, 'end': 60}, {'entity_group': 'LABEL_0', 'score': 0.56796557, 'word': ' sobre', 'start': 62, 'end': 66}, {'entity_group': 'LABEL_1', 'score': 0.6210456, 'word': ' cobertura testis analise precisa durante execucao', 'start': 68, 'end': 116}]
# Resultado para História de Usuário 11: [{'entity_group': 'LABEL_1', 'score': 0.5868707, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.50372714, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.61919415, 'word': ' 11 : testador desejo ferramenta', 'start': 21, 'end': 50}, {'entity_group': 'LABEL_0', 'score': 0.54241455, 'word': ' identifique', 'start': 52, 'end': 62}, {'entity_group': 'LABEL_1', 'score': 0.6839576, 'word': ' automaticamente casos teste criticos priorizar analise', 'start': 64, 'end': 117}]
# Resultado para História de Usuário 12: [{'entity_group': 'LABEL_1', 'score': 0.589305, 'word': ' historia de usuario 12 : testador', 'start': 0, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.5034429, 'word': ' preciso', 'start': 34, 'end': 40}, {'entity_group': 'LABEL_1', 'score': 0.63165575, 'word': ' ferramenta sugira casos teste base padroes uso real aplicativo', 'start': 42, 'end': 103}]
# Resultado para História de Usuário 13: [{'entity_group': 'LABEL_1', 'score': 0.6117815, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5081377, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.66422546, 'word': ' 13 : testador quero sugestoes base padroes falha historicos evitar problemas recorrentes software', 'start': 21, 'end': 116}]
# Resultado para História de Usuário 14: [{'entity_group': 'LABEL_1', 'score': 0.57307994, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5073267, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.63994884, 'word': ' 14 :', 'start': 21, 'end': 23}, {'entity_group': 'LABEL_0', 'score': 0.53496605, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.6957749, 'word': 'tador desejo suporte execucao', 'start': 27, 'end': 56}, {'entity_group': 'LABEL_0', 'score': 0.5292616, 'word': ' tes', 'start': 58, 'end': 60}, {'entity_group': 'LABEL_1', 'score': 0.60930824, 'word': 'tis automatizados diferentes dispositivos ambientes', 'start': 60, 'end': 111}]
# Resultado para História de Usuário 15: [{'entity_group': 'LABEL_1', 'score': 0.5806215, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.507182, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.62741756, 'word': ' 15 : testador preciso ferramenta dete', 'start': 21, 'end': 56}, {'entity_group': 'LABEL_0', 'score': 0.5913781, 'word': 'cte', 'start': 56, 'end': 59}, {'entity_group': 'LABEL_1', 'score': 0.7233273, 'word': ' automaticamente mudancas requisitos ajuste casos', 'start': 61, 'end': 108}, {'entity_group': 'LABEL_0', 'score': 0.553828, 'word': ' teste', 'start': 110, 'end': 114}, {'entity_group': 'LABEL_1', 'score': 0.623646, 'word': ' correspondentes', 'start': 116, 'end': 130}]
# Resultado para História de Usuário 16: [{'entity_group': 'LABEL_1', 'score': 0.6661824, 'word': ' historia de usuario 16 : testador quero integracao sistemas controle versao rastrear mudancas requisitos codigo - fonte', 'start': 0, 'end': 116}]
# Resultado para História de Usuário 17: [{'entity_group': 'LABEL_1', 'score': 0.55384064, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5378066, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.63017887, 'word': ' 17 :', 'start': 21, 'end': 23}, {'entity_group': 'LABEL_0', 'score': 0.5432853, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.60087574, 'word': 'tador desejo metricas detalhadas sobre eficacia testis incluindo taxon cobertura falha', 'start': 27, 'end': 113}]
# Resultado para História de Usuário 18: [{'entity_group': 'LABEL_1', 'score': 0.58383715, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5648484, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.66923773, 'word': ' 18 :', 'start': 21, 'end': 23}, {'entity_group': 'LABEL_0', 'score': 0.52635103, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.64609236, 'word': 'tador preciso suporte execucao testis desempenho escalabilidade', 'start': 27, 'end': 90}]
# Resultado para História de Usuário 19: [{'entity_group': 'LABEL_1', 'score': 0.5740557, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5627983, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.630711, 'word': ' 19 : testador quero analise automatica resultados testis relatorios detalhados', 'start': 21, 'end': 97}, {'entity_group': 'LABEL_0', 'score': 0.579109, 'word': ' sobre', 'start': 99, 'end': 103}, {'entity_group': 'LABEL_1', 'score': 0.564216, 'word': ' problemas encontrados', 'start': 105, 'end': 125}]
# Resultado para História de Usuário 20: [{'entity_group': 'LABEL_1', 'score': 0.56485254, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5404721, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.57238674, 'word': ' 20 :', 'start': 21, 'end': 23}, {'entity_group': 'LABEL_0', 'score': 0.55371016, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.65463024, 'word': 'tador desejo simular cenarios teste complexos realistas garantir testis proximos realidade', 'start': 27, 'end': 117}]
# Resultado para História de Usuário 21: [{'entity_group': 'LABEL_1', 'score': 0.59239864, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.524067, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.625314, 'word': ' 21 : testador preciso suporte execucao testis regressao automatizados', 'start': 21, 'end': 88}]
# Resultado para História de Usuário 22: [{'entity_group': 'LABEL_1', 'score': 0.5179012, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5708154, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.60699356, 'word': ' 22 :', 'start': 21, 'end': 23}, {'entity_group': 'LABEL_0', 'score': 0.56022495, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.58205754, 'word': 'tador quero identificacao automatica casos', 'start': 27, 'end': 69}, {'entity_group': 'LABEL_0', 'score': 0.5498209, 'word': ' teste', 'start': 71, 'end': 75}, {'entity_group': 'LABEL_1', 'score': 0.6258612, 'word': ' redundantes desnecessarios', 'start': 77, 'end': 102}]
# Resultado para História de Usuário 23: [{'entity_group': 'LABEL_1', 'score': 0.59959704, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.50463355, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.6766781, 'word': ' 23 : testador desejo integracao facil ferramentas gerenciamento projetos', 'start': 21, 'end': 91}]
# Resultado para História de Usuário 24: [{'entity_group': 'LABEL_1', 'score': 0.5677078, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.53104764, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.6478667, 'word': ' 24 :', 'start': 21, 'end': 23}, {'entity_group': 'LABEL_0', 'score': 0.5095455, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.63698006, 'word': 'tador preciso suporte execucao', 'start': 27, 'end': 57}, {'entity_group': 'LABEL_0', 'score': 0.5186073, 'word': ' tes', 'start': 59, 'end': 61}, {'entity_group': 'LABEL_1', 'score': 0.5896175, 'word': 'tis usabilidade', 'start': 61, 'end': 76}]
# Resultado para História de Usuário 25: [{'entity_group': 'LABEL_1', 'score': 0.5692381, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.54250735, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.66331637, 'word': ' 25 :', 'start': 21, 'end': 23}, {'entity_group': 'LABEL_0', 'score': 0.54967046, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.6091405, 'word': 'tador quero ferramenta crie automaticamente conjuntos dado', 'start': 27, 'end': 85}, {'entity_group': 'LABEL_0', 'score': 0.50356066, 'word': ' teste', 'start': 87, 'end': 91}, {'entity_group': 'LABEL_1', 'score': 0.6671512, 'word': ' realistas', 'start': 93, 'end': 101}]
# Resultado para História de Usuário 26: [{'entity_group': 'LABEL_1', 'score': 0.59386873, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5000813, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.6516781, 'word': ' 26 :', 'start': 21, 'end': 23}, {'entity_group': 'LABEL_0', 'score': 0.5435282, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.64668876, 'word': 'tador desejo integracao ferramentas monitoramento desempenho tempo real', 'start': 27, 'end': 98}]
# Resultado para História de Usuário 27: [{'entity_group': 'LABEL_1', 'score': 0.58325076, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.58366024, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.55971354, 'word': ' 27 :', 'start': 21, 'end': 23}, {'entity_group': 'LABEL_0', 'score': 0.50240725, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.6640925, 'word': 'tador preciso suporte execucao testis localizacao internacionalizacao', 'start': 27, 'end': 96}]
# Resultado para História de Usuário 28: [{'entity_group': 'LABEL_1', 'score': 0.5270797, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.57314, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.6090963, 'word': ' 28 :', 'start': 21, 'end': 23}, {'entity_group': 'LABEL_0', 'score': 0.5421947, 'word': ' testador', 'start': 25, 'end': 32}, {'entity_group': 'LABEL_1', 'score': 0.5636037, 'word': ' quero geracao automatica dado teste sinteticos', 'start': 34, 'end': 79}]
# Resultado para História de Usuário 29: [{'entity_group': 'LABEL_1', 'score': 0.62924916, 'word': ' historia de usuario 29 : testador desejo suporte execucao testis acessibilidade', 'start': 0, 'end': 78}]
# Resultado para História de Usuário 30: [{'entity_group': 'LABEL_1', 'score': 0.56969583, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5298578, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.6209617, 'word': ' 30 : testador preciso suporte execucao testis integracao continua', 'start': 21, 'end': 84}]
# Resultado para História de Usuário 31: [{'entity_group': 'LABEL_1', 'score': 0.5358447, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5641003, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.68118626, 'word': ' 31 :', 'start': 21, 'end': 23}, {'entity_group': 'LABEL_0', 'score': 0.5210387, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.5878161, 'word': 'tador quero identificacao automatica casos teste incompletos mal definidos', 'start': 27, 'end': 101}]
# Resultado para História de Usuário 32: [{'entity_group': 'LABEL_1', 'score': 0.5747374, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5132982, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.64816856, 'word': ' 32 :', 'start': 21, 'end': 23}, {'entity_group': 'LABEL_0', 'score': 0.5262468, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.6162991, 'word': 'tador desejo identificacao automatica dependencias casos teste', 'start': 27, 'end': 89}]
# Resultado para História de Usuário 33: [{'entity_group': 'LABEL_1', 'score': 0.6181048, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.514108, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.64810157, 'word': ' 33 : testador preciso suporte execucao testis recuperacao des', 'start': 21, 'end': 80}, {'entity_group': 'LABEL_0', 'score': 0.510448, 'word': 'astres', 'start': 80, 'end': 86}]
# Resultado para História de Usuário 34: [{'entity_group': 'LABEL_1', 'score': 0.5800377, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5080284, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.66482115, 'word': ' 34 :', 'start': 21, 'end': 23}, {'entity_group': 'LABEL_0', 'score': 0.5614542, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.5655616, 'word': 'tador quero ferramenta', 'start': 27, 'end': 49}, {'entity_group': 'LABEL_0', 'score': 0.5497288, 'word': ' identifique', 'start': 51, 'end': 61}, {'entity_group': 'LABEL_1', 'score': 0.6636382, 'word': ' automaticamente casos teste', 'start': 63, 'end': 89}, {'entity_group': 'LABEL_0', 'score': 0.50495, 'word': ' parale', 'start': 91, 'end': 96}, {'entity_group': 'LABEL_1', 'score': 0.6907912, 'word': 'lizaveis', 'start': 96, 'end': 104}]
# Resultado para História de Usuário 35: [{'entity_group': 'LABEL_1', 'score': 0.58690643, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.50203913, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.7060776, 'word': ' 35 :', 'start': 21, 'end': 23}, {'entity_group': 'LABEL_0', 'score': 0.51141053, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.67356753, 'word': 'tador desejo simulacao cenarios teste carga extremamente alta', 'start': 27, 'end': 88}]
# Resultado para História de Usuário 36: [{'entity_group': 'LABEL_1', 'score': 0.60766685, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5248869, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.6226023, 'word': ' 36 : testador preciso suporte execucao testis compatibilidade diferentes navegadores dispositivos', 'start': 21, 'end': 116}]
# Resultado para História de Usuário 37: [{'entity_group': 'LABEL_1', 'score': 0.57522285, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.53042704, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.59444267, 'word': ' 37 : tes', 'start': 21, 'end': 27}, {'entity_group': 'LABEL_0', 'score': 0.53014, 'word': 'tador', 'start': 27, 'end': 32}, {'entity_group': 'LABEL_1', 'score': 0.6272549, 'word': ' quero geracao automatica relatorios teste personalizados', 'start': 34, 'end': 89}]
# Resultado para História de Usuário 38: [{'entity_group': 'LABEL_1', 'score': 0.55942464, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.56225896, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.6910695, 'word': ' 38 :', 'start': 21, 'end': 23}, {'entity_group': 'LABEL_0', 'score': 0.51658255, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.65529144, 'word': 'tador desejo', 'start': 27, 'end': 39}, {'entity_group': 'LABEL_0', 'score': 0.5086458, 'word': ' rastre', 'start': 41, 'end': 46}, {'entity_group': 'LABEL_1', 'score': 0.60498214, 'word': 'amento automatico resultados', 'start': 46, 'end': 74}, {'entity_group': 'LABEL_0', 'score': 0.53463066, 'word': ' teste longo', 'start': 76, 'end': 86}, {'entity_group': 'LABEL_1', 'score': 0.5952068, 'word': ' tempo', 'start': 88, 'end': 92}]
# Resultado para História de Usuário 39: [{'entity_group': 'LABEL_1', 'score': 0.5411258, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.54611003, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.6259253, 'word': ' 39 : testador preciso suporte execucao testis regressao progressiva', 'start': 21, 'end': 86}]
# Resultado para História de Usuário 40: [{'entity_group': 'LABEL_1', 'score': 0.6329768, 'word': ' historia de usuario 40 : testador quero sugestoes automaticas aprimorar casos teste existentes', 'start': 0, 'end': 93}]
# Resultado para História de Usuário 41: [{'entity_group': 'LABEL_1', 'score': 0.5785663, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5189516, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.64966595, 'word': ' 41 :', 'start': 21, 'end': 23}, {'entity_group': 'LABEL_0', 'score': 0.51759255, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.6689478, 'word': 'tador desejo ferramenta apre', 'start': 27, 'end': 55}, {'entity_group': 'LABEL_0', 'score': 0.515673, 'word': 'nda', 'start': 55, 'end': 58}, {'entity_group': 'LABEL_1', 'score': 0.66681856, 'word': ' resultados testis melhore sugestoes futuras', 'start': 60, 'end': 102}]
# Resultado para História de Usuário 42: [{'entity_group': 'LABEL_1', 'score': 0.5972661, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.56496125, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.6577032, 'word': ' 42 :', 'start': 21, 'end': 23}, {'entity_group': 'LABEL_0', 'score': 0.50084007, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.6441324, 'word': 'tador preciso suporte execucao testis seguranca automatizados', 'start': 27, 'end': 88}]
# Resultado para História de Usuário 43: [{'entity_group': 'LABEL_1', 'score': 0.5873846, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5380234, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.5953419, 'word': ' 43 : tes', 'start': 21, 'end': 27}, {'entity_group': 'LABEL_0', 'score': 0.5137969, 'word': 'tador', 'start': 27, 'end': 32}, {'entity_group': 'LABEL_1', 'score': 0.6588707, 'word': ' quero integracao ferramentas analise codigo estatico identificar areas risco', 'start': 34, 'end': 109}]
# Resultado para História de Usuário 44: [{'entity_group': 'LABEL_1', 'score': 0.60645026, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5087872, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.66214913, 'word': ' 44 : testador desejo suporte execucao testis integracao sistema teste aceitacao usuario', 'start': 21, 'end': 106}]
# Resultado para História de Usuário 45: [{'entity_group': 'LABEL_1', 'score': 0.5875362, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5183624, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.6946064, 'word': ' 45 :', 'start': 21, 'end': 23}, {'entity_group': 'LABEL_0', 'score': 0.52085096, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.64969164, 'word': 'tador preciso suporte execucao testis confiabilidade disponibilidade', 'start': 27, 'end': 95}]
# Resultado para História de Usuário 46: [{'entity_group': 'LABEL_1', 'score': 0.56132096, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5205081, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.6217524, 'word': ' 46 :', 'start': 21, 'end': 23}, {'entity_group': 'LABEL_0', 'score': 0.53032345, 'word': ' testador', 'start': 25, 'end': 32}, {'entity_group': 'LABEL_1', 'score': 0.6023995, 'word': ' quero ferramenta sugira casos', 'start': 34, 'end': 62}, {'entity_group': 'LABEL_0', 'score': 0.5040573, 'word': ' teste', 'start': 64, 'end': 68}, {'entity_group': 'LABEL_1', 'score': 0.71193975, 'word': ' base modelos qualidade software reconhecidos', 'start': 70, 'end': 113}]
# Resultado para História de Usuário 47: [{'entity_group': 'LABEL_1', 'score': 0.55750245, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5468189, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.6075389, 'word': ' 47 :', 'start': 21, 'end': 23}, {'entity_group': 'LABEL_0', 'score': 0.5212579, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.64069515, 'word': 'tador desejo integracao ferramentas automacao teste interface usuario', 'start': 27, 'end': 96}]
# Resultado para História de Usuário 48: [{'entity_group': 'LABEL_1', 'score': 0.5600339, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5378991, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.62396157, 'word': ' 48 : testador preciso suporte execucao testis estresse robustez', 'start': 21, 'end': 82}]
# Resultado para História de Usuário 49: [{'entity_group': 'LABEL_1', 'score': 0.5530864, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5277531, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.6699016, 'word': ' 49 :', 'start': 21, 'end': 23}, {'entity_group': 'LABEL_0', 'score': 0.5452802, 'word': ' testador', 'start': 25, 'end': 32}, {'entity_group': 'LABEL_1', 'score': 0.5501819, 'word': ' que', 'start': 34, 'end': 36}, {'entity_group': 'LABEL_0', 'score': 0.53331846, 'word': 'ro', 'start': 36, 'end': 38}, {'entity_group': 'LABEL_1', 'score': 0.6473337, 'word': ' ferramenta sugira casos', 'start': 40, 'end': 62}, {'entity_group': 'LABEL_0', 'score': 0.51316017, 'word': ' teste', 'start': 64, 'end': 68}, {'entity_group': 'LABEL_1', 'score': 0.71391034, 'word': ' areas alto risco complexidade', 'start': 70, 'end': 98}]
# Resultado para História de Usuário 50: [{'entity_group': 'LABEL_1', 'score': 0.659707, 'word': ' historia de usuario 50 : testador desejo integracao ferramentas gerenciamento defeitos rastreamento correcoes', 'start': 0, 'end': 108}]
# Resultado para História de Usuário 51: [{'entity_group': 'LABEL_1', 'score': 0.6031461, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.51601124, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.70065755, 'word': ' 51 :', 'start': 21, 'end': 23}, {'entity_group': 'LABEL_0', 'score': 0.5343435, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.5993971, 'word': 'tador preciso suporte execucao testis usabilidade remota teste usuario beta', 'start': 27, 'end': 102}]
# Resultado para História de Usuário 52: [{'entity_group': 'LABEL_1', 'score': 0.5917518, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.53900844, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.6972742, 'word': ' 52 :', 'start': 21, 'end': 23}, {'entity_group': 'LABEL_0', 'score': 0.54502887, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.57913834, 'word': 'tador quero ferramenta', 'start': 27, 'end': 49}, {'entity_group': 'LABEL_0', 'score': 0.6169529, 'word': ' forneca', 'start': 51, 'end': 57}, {'entity_group': 'LABEL_1', 'score': 0.539343, 'word': ' feed', 'start': 59, 'end': 62}, {'entity_group': 'LABEL_0', 'score': 0.54998595, 'word': 'back', 'start': 62, 'end': 66}, {'entity_group': 'LABEL_1', 'score': 0.5942106, 'word': ' tempo real durante execucao', 'start': 68, 'end': 94}, {'entity_group': 'LABEL_0', 'score': 0.5299339, 'word': ' testis', 'start': 96, 'end': 101}]
# Resultado para História de Usuário 53: [{'entity_group': 'LABEL_1', 'score': 0.72019416, 'word': ' historia de usuario 53 : testador desejo integracao ferramentas automacao infraestrutura provisionamento configuracao automatizados', 'start': 0, 'end': 130}]
# Resultado para História de Usuário 54: [{'entity_group': 'LABEL_1', 'score': 0.6243645, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.55279124, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.7157165, 'word': ' 54 :', 'start': 21, 'end': 23}, {'entity_group': 'LABEL_0', 'score': 0.51212496, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.64994645, 'word': 'tador preciso suporte execucao testis comparacao desempenho versoes anteriores atuais aplicativo', 'start': 27, 'end': 123}]

# %%
def extract_info(freq_dist):
    freq_dist_text = " ".join(freq_dist.keys())

    autor = None
    if "testador" in freq_dist_text.lower():
        autor = "Testador"

    necessidade = None
    for word in ["quero", "preciso", "desejo"]:
        if word in freq_dist_text.lower():
            pos_inicial = freq_dist_text.lower().find(word) + len(word)
            necessidade = freq_dist_text[pos_inicial:].strip()
            break

    objetivo = None
    if "para" in freq_dist_text.lower():
        pos_inicial = freq_dist_text.lower().find("para") + len("para")
        objetivo = freq_dist_text[pos_inicial:].strip()

    return autor, necessidade, objetivo


for i, freq_dist in enumerate(freq_dists):
    autor, necessidade, objetivo = extract_info(freq_dist)
    print("História do Usuário:", historias_usuario[i])
    print("Autor:", autor)
    print("Necessidade:", necessidade)
    print("Objetivo:", objetivo)
    print()
# Out:
# História do Usuário: Como Testador eu quero um jeito mais fácil de incluir os requisitos do aplicativo na ferramenta DRL-Mobtest para criar casos de teste que cubram tudo que o aplicativo precisa fazer, sem ter que gastar muito tempo escrevendo manualmente.
# Autor: Testador
# Necessidade: jeito fácil incluir requisitos aplicativo ferramenta drl-mobtest criar casos teste cubram tudo precisa fazer ter gastar tempo escrevendo manualmente
# Objetivo: None
#
# História do Usuário: Como Testador eu quero uma maneira de ensinar a ferramenta DRL-Mobtest a entender os requisitos do aplicativo usando NLP para fazer com que a ferramenta gere testes automaticamente.
# Autor: Testador
# Necessidade: maneira ensinar ferramenta drl-mobtest entender requisitos aplicativo usando nlp fazer gere testis automaticamente
# Objetivo: None
#
# História do Usuário: Como Testador eu quero que a ferramenta gere casos de teste abrangentes que cubram integralmente todos os requisitos do aplicativo, assegurando que o software seja completo e funcional, sem depender exclusivamente da criação manual de casos de teste.
# Autor: Testador
# Necessidade: ferramenta gere casos teste abrangentes cubram integralmente todos requisitos aplicativo assegurando software completo funcional depender exclusivamente criação manual
# Objetivo: None
#
# História do Usuário: Como Testador eu quero que a ferramenta seja integrada com outras ferramentas de gerenciamento, permitindo sincronização automática dos requisitos e facilitando o processo de criação de casos de testes.
# Autor: Testador
# Necessidade: ferramenta integrada outras ferramentas gerenciamento permitindo sincronização automática requisitos facilitando processo criação casos testis
# Objetivo: None
#
# História do Usuário: Como Testador eu quero que a ferramenta  forneça o recurso de criação de relatórios detalhados sobre a cobertura dos testes, permitindo uma análise precisa sobre sua progressão e identificação das lacunas durante sua execução.
# Autor: Testador
# Necessidade: ferramenta forneça recurso criação relatórios detalhados sobre cobertura testis permitindo análise precisa progressão identificação lacuna durante execução
# Objetivo: None
#
# História do Usuário: Como testador, quero uma maneira mais fácil de incluir requisitos do aplicativo para criar casos de teste abrangentes, economizando tempo na escrita manual.
# Autor: Testador
# Necessidade: maneira fácil incluir requisitos aplicativo criar casos teste abrangentes economizando tempo escrita manual
# Objetivo: None
#
# História do Usuário: Como testador, desejo ensinar a ferramenta a entender os requisitos do aplicativo usando NLP para gerar testes automaticamente.
# Autor: Testador
# Necessidade: ensinar ferramenta entender requisitos aplicativo usando nlp gerar testis automaticamente
# Objetivo: None
#
# História do Usuário: Como testador, preciso que a ferramenta gere casos de teste completos e funcionais que cubram todos os requisitos do aplicativo.
# Autor: Testador
# Necessidade: ferramenta gere casos teste completos funcionais cubram todos requisitos aplicativo
# Objetivo: None
#
# História do Usuário: Como testador, quero integração com outras ferramentas de gerenciamento para sincronizar automaticamente requisitos e facilitar a criação de casos de teste.
# Autor: Testador
# Necessidade: integração outras ferramentas gerenciamento sincronizar automaticamente requisitos facilitar criação casos teste
# Objetivo: None
#
# História do Usuário: Como testador, quero relatórios detalhados sobre a cobertura dos testes para análise precisa durante a execução.
# Autor: Testador
# Necessidade: relatórios detalhados sobre cobertura testis análise precisa durante execução
# Objetivo: None
#
# História do Usuário: Como testador, desejo que a ferramenta identifique automaticamente os casos de teste mais críticos para priorizar a análise.
# Autor: Testador
# Necessidade: ferramenta identifique automaticamente casos teste críticos priorizar análise
# Objetivo: None
#
# História do Usuário: Como testador, preciso que a ferramenta sugira casos de teste com base em padrões de uso real do aplicativo.
# Autor: Testador
# Necessidade: ferramenta sugira casos teste base padrões uso real aplicativo
# Objetivo: None
#
# História do Usuário: Como testador, quero sugestões com base em padrões de falha históricos para evitar problemas recorrentes no software.
# Autor: Testador
# Necessidade: sugestões base padrões falha históricos evitar problemas recorrentes software
# Objetivo: None
#
# História do Usuário: Como testador, desejo suporte à execução de testes automatizados em diferentes dispositivos e ambientes.
# Autor: Testador
# Necessidade: suporte execução testis automatizados diferentes dispositivos ambientes
# Objetivo: None
#
# História do Usuário: Como testador, preciso que a ferramenta detecte automaticamente mudanças nos requisitos e ajuste os casos de teste correspondentes.
# Autor: Testador
# Necessidade: ferramenta detecte automaticamente mudanças requisitos ajuste casos teste correspondentes
# Objetivo: None
#
# História do Usuário: Como testador, quero integração com sistemas de controle de versão para rastrear mudanças nos requisitos e no código-fonte.
# Autor: Testador
# Necessidade: integração sistemas controle versão rastrear mudanças requisitos código-fonte
# Objetivo: None
#
# História do Usuário: Como testador, desejo métricas detalhadas sobre a eficácia dos testes, incluindo taxa de cobertura e taxa de falha.
# Autor: Testador
# Necessidade: métricas detalhadas sobre eficácia testis incluindo taxon cobertura falha
# Objetivo: None
#
# História do Usuário: Como testador, preciso de suporte à execução de testes de desempenho e escalabilidade.
# Autor: Testador
# Necessidade: suporte execução testis desempenho escalabilidade
# Objetivo: None
#
# História do Usuário: Como testador, quero análise automática dos resultados dos testes para relatórios detalhados sobre problemas encontrados.
# Autor: Testador
# Necessidade: análise automática resultados testis relatórios detalhados sobre problemas encontrados
# Objetivo: None
#
# História do Usuário: Como testador, desejo simular cenários de teste complexos e realistas para garantir testes próximos à realidade.
# Autor: Testador
# Necessidade: simular cenários teste complexos realistas garantir testis próximos realidade
# Objetivo: None
#
# História do Usuário: Como testador, preciso de suporte à execução de testes de regressão automatizados.
# Autor: Testador
# Necessidade: suporte execução testis regressão automatizados
# Objetivo: None
#
# História do Usuário: Como testador, quero identificação automática de casos de teste redundantes ou desnecessários.
# Autor: Testador
# Necessidade: identificação automática casos teste redundantes desnecessários
# Objetivo: None
#
# História do Usuário: Como testador, desejo integração fácil com ferramentas de gerenciamento de projetos.
# Autor: Testador
# Necessidade: integração fácil ferramentas gerenciamento projetos
# Objetivo: None
#
# História do Usuário: Como testador, preciso de suporte à execução de testes de usabilidade.
# Autor: Testador
# Necessidade: suporte execução testis usabilidade
# Objetivo: None
#
# História do Usuário: Como testador, quero que a ferramenta crie automaticamente conjuntos de dados de teste realistas.
# Autor: Testador
# Necessidade: ferramenta crie automaticamente conjuntos dado teste realistas
# Objetivo: None
#
# História do Usuário: Como testador, desejo integração com ferramentas de monitoramento de desempenho em tempo real.
# Autor: Testador
# Necessidade: integração ferramentas monitoramento desempenho tempo real
# Objetivo: None
#
# História do Usuário: Como testador, preciso de suporte à execução de testes de localização e internacionalização.
# Autor: Testador
# Necessidade: suporte execução testis localização internacionalização
# Objetivo: None
#
# História do Usuário: Como testador, quero geração automática de dados de teste sintéticos.
# Autor: Testador
# Necessidade: geração automática dado teste sintéticos
# Objetivo: None
#
# História do Usuário: Como testador, desejo suporte à execução de testes de acessibilidade.
# Autor: Testador
# Necessidade: suporte execução testis acessibilidade
# Objetivo: None
#
# História do Usuário: Como testador, preciso de suporte à execução de testes de integração contínua.
# Autor: Testador
# Necessidade: suporte execução testis integração contínua
# Objetivo: None
#
# História do Usuário: Como testador, quero identificação automática de casos de teste incompletos ou mal definidos.
# Autor: Testador
# Necessidade: identificação automática casos teste incompletos mal definidos
# Objetivo: None
#
# História do Usuário: Como testador, desejo identificação automática de dependências entre casos de teste.
# Autor: Testador
# Necessidade: identificação automática dependências casos teste
# Objetivo: None
#
# História do Usuário: Como testador, preciso de suporte à execução de testes de recuperação de desastres.
# Autor: Testador
# Necessidade: suporte execução testis recuperação desastres
# Objetivo: None
#
# História do Usuário: Como testador, quero que a ferramenta identifique automaticamente casos de teste paralelizáveis.
# Autor: Testador
# Necessidade: ferramenta identifique automaticamente casos teste paralelizáveis
# Objetivo: lelizáveis
#
# História do Usuário: Como testador, desejo simulação de cenários de teste de carga extremamente alta.
# Autor: Testador
# Necessidade: simulação cenários teste carga extremamente alta
# Objetivo: None
#
# História do Usuário: Como testador, preciso de suporte à execução de testes de compatibilidade com diferentes navegadores e dispositivos.
# Autor: Testador
# Necessidade: suporte execução testis compatibilidade diferentes navegadores dispositivos
# Objetivo: None
#
# História do Usuário: Como testador, quero geração automática de relatórios de teste personalizados.
# Autor: Testador
# Necessidade: geração automática relatórios teste personalizados
# Objetivo: None
#
# História do Usuário: Como testador, desejo rastreamento automático de resultados de teste ao longo do tempo.
# Autor: Testador
# Necessidade: rastreamento automático resultados teste longo tempo
# Objetivo: None
#
# História do Usuário: Como testador, preciso de suporte à execução de testes de regressão progressiva.
# Autor: Testador
# Necessidade: suporte execução testis regressão progressiva
# Objetivo: None
#
# História do Usuário: Como testador, quero sugestões automáticas para aprimorar os casos de teste existentes.
# Autor: Testador
# Necessidade: sugestões automáticas aprimorar casos teste existentes
# Objetivo: None
#
# História do Usuário: Como testador, desejo que a ferramenta aprenda com os resultados dos testes e melhore suas sugestões futuras.
# Autor: Testador
# Necessidade: ferramenta aprenda resultados testis melhore sugestões futuras
# Objetivo: None
#
# História do Usuário: Como testador, preciso de suporte à execução de testes de segurança automatizados.
# Autor: Testador
# Necessidade: suporte execução testis segurança automatizados
# Objetivo: None
#
# História do Usuário: Como testador, quero integração com ferramentas de análise de código estático para identificar áreas de risco.
# Autor: Testador
# Necessidade: integração ferramentas análise código estático identificar áreas risco
# Objetivo: None
#
# História do Usuário: Como testador, desejo suporte à execução de testes de integração de sistema e teste de aceitação do usuário.
# Autor: Testador
# Necessidade: suporte execução testis integração sistema teste aceitação usuário
# Objetivo: None
#
# História do Usuário: Como testador, preciso de suporte à execução de testes de confiabilidade e disponibilidade.
# Autor: Testador
# Necessidade: suporte execução testis confiabilidade disponibilidade
# Objetivo: None
#
# História do Usuário: Como testador, quero que a ferramenta sugira casos de teste com base em modelos de qualidade de software reconhecidos.
# Autor: Testador
# Necessidade: ferramenta sugira casos teste base modelos qualidade software reconhecidos
# Objetivo: None
#
# História do Usuário: Como testador, desejo integração com ferramentas de automação de teste de interface do usuário.
# Autor: Testador
# Necessidade: integração ferramentas automação teste interface usuário
# Objetivo: None
#
# História do Usuário: Como testador, preciso de suporte à execução de testes de estresse e robustez.
# Autor: Testador
# Necessidade: suporte execução testis estresse robustez
# Objetivo: None
#
# História do Usuário: Como testador, quero que a ferramenta sugira casos de teste para áreas de alto risco e complexidade.
# Autor: Testador
# Necessidade: ferramenta sugira casos teste áreas alto risco complexidade
# Objetivo: None
#
# História do Usuário: Como testador, desejo integração com ferramentas de gerenciamento de defeitos para rastreamento de correções.
# Autor: Testador
# Necessidade: integração ferramentas gerenciamento defeitos rastreamento correções
# Objetivo: None
#
# História do Usuário: Como testador, preciso de suporte à execução de testes de usabilidade remota e teste de usuário beta.
# Autor: Testador
# Necessidade: suporte execução testis usabilidade remota teste usuário beta
# Objetivo: None
#
# História do Usuário: Como testador, quero que a ferramenta forneça feedback em tempo real durante a execução dos testes.
# Autor: Testador
# Necessidade: ferramenta forneça feedback tempo real durante execução testis
# Objetivo: None
#
# História do Usuário: Como testador, desejo integração com ferramentas de automação de infraestrutura para provisionamento e configuração automatizados.
# Autor: Testador
# Necessidade: integração ferramentas automação infraestrutura provisionamento configuração automatizados
# Objetivo: None
#
# História do Usuário: Como testador, preciso de suporte à execução de testes de comparação de desempenho para versões anteriores e atuais do aplicativo.
# Autor: Testador
# Necessidade: suporte execução testis comparação desempenho versões anteriores atuais aplicativo
# Objetivo: ção desempenho versões anteriores atuais aplicativo

# %%
from sklearn.metrics import recall_score, f1_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.25.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.4.0)

# %%
X = freq_dists
rotulos_possiveis = ["testador", "aplicativo", "execução", "suporte"]
y = [choice(rotulos_possiveis) for _ in range(len(freq_dists))]
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform([" ".join(freq_dist.keys()) for freq_dist in X])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.4, random_state=42,stratify=y)

# %%
clf_tf = DecisionTreeClassifier(criterion='gini',max_depth=15)
clf_tf.fit(X_train, y_train)
pred_arvore_entropy_tf = clf_tf.predict(X_test)
accuracy_decision = accuracy_score(y_test,pred_arvore_entropy_tf)
recall = recall_score(y_test, pred_arvore_entropy_tf, average='weighted')
f1 = f1_score(y_test, pred_arvore_entropy_tf, average='weighted')
print(pred_arvore_entropy_tf)
print(accuracy_decision)
print(recall)
print(f1)
# Out:
# ['testador' 'aplicativo' 'testador' 'testador' 'suporte' 'execução'
#  'execução' 'aplicativo' 'execução' 'testador' 'suporte' 'aplicativo'
#  'suporte' 'aplicativo' 'testador' 'suporte' 'suporte' 'testador'
#  'suporte' 'execução' 'execução' 'suporte']
# 0.2727272727272727
# 0.2727272727272727
# 0.27933884297520656

# %%
clf = DecisionTreeClassifier(criterion='entropy',max_depth=7)
clf.fit(X_train, y_train)
pred_arvore_entropy = clf.predict(X_test)
accuracy_decision = accuracy_score(y_test,pred_arvore_entropy)
recall_entropy = recall_score(y_test, pred_arvore_entropy, average='weighted')
f1_entropy = f1_score(y_test, pred_arvore_entropy, average='weighted')
print(pred_arvore_entropy_tf)
print(accuracy_decision)
print(recall_entropy)
print(f1_entropy)
# Out:
# ['testador' 'aplicativo' 'testador' 'testador' 'suporte' 'execução'
#  'execução' 'aplicativo' 'execução' 'testador' 'suporte' 'aplicativo'
#  'suporte' 'aplicativo' 'testador' 'suporte' 'suporte' 'testador'
#  'suporte' 'execução' 'execução' 'suporte']
# 0.22727272727272727
# 0.22727272727272727
# 0.2529137529137529

# %%
clf_tf3 = KNeighborsClassifier(metric='manhattan',n_neighbors=3)
clf_tf3.fit(X_train, y_train)
pred_knn_tf = clf_tf3.predict(X_test)
acuracy_KNN = accuracy_score(y_test,pred_knn_tf)
recall_knn = recall_score(y_test, pred_knn_tf, average='weighted')
f1_knn = f1_score(y_test, pred_knn_tf, average='weighted')
print(pred_knn_tf)
print(acuracy_KNN)
print(recall_knn)
print(f1_knn)
# Out:
# ['aplicativo' 'suporte' 'suporte' 'aplicativo' 'suporte' 'aplicativo'
#  'aplicativo' 'testador' 'aplicativo' 'suporte' 'suporte' 'aplicativo'
#  'execução' 'aplicativo' 'testador' 'aplicativo' 'aplicativo' 'testador'
#  'suporte' 'aplicativo' 'execução' 'suporte']
# 0.18181818181818182
# 0.18181818181818182
# 0.15775401069518716

# %%
clf_tf4 = KNeighborsClassifier(n_neighbors=5,weights='distance', algorithm='brute')
clf_tf4.fit(X_train, y_train)
pred_knn_tf2 = clf_tf4.predict(X_test)
acuracy_KNN2 = accuracy_score(y_test,pred_knn_tf2)
recall_knn2 = recall_score(y_test, pred_knn_tf2, average='weighted')
f1_knn2 = f1_score(y_test, pred_knn_tf2, average='weighted')
print(pred_knn_tf)
print(acuracy_KNN)
print(recall_knn2)
print(f1_knn2)
# Out:
# ['aplicativo' 'suporte' 'suporte' 'aplicativo' 'suporte' 'aplicativo'
#  'aplicativo' 'testador' 'aplicativo' 'suporte' 'suporte' 'aplicativo'
#  'execução' 'aplicativo' 'testador' 'aplicativo' 'aplicativo' 'testador'
#  'suporte' 'aplicativo' 'execução' 'suporte']
# 0.18181818181818182
# 0.22727272727272727
# 0.21515151515151515

# %%
svc = SVC(kernel='linear', C=0.05)
svc.fit(X_train, y_train)
pred_svc = svc.predict(X_test)
accuracy_svc = accuracy_score(y_test, pred_svc)
recall_svc = recall_score(y_test, pred_svc, average='weighted')
f1_svc = f1_score(y_test, pred_svc, average='weighted')
print(pred_svc)
print(accuracy_svc)
print(recall_svc)
print(f1_svc)
# Out:
# ['aplicativo' 'aplicativo' 'aplicativo' 'aplicativo' 'suporte'
#  'aplicativo' 'aplicativo' 'aplicativo' 'aplicativo' 'suporte' 'suporte'
#  'aplicativo' 'suporte' 'aplicativo' 'aplicativo' 'aplicativo'
#  'aplicativo' 'aplicativo' 'suporte' 'aplicativo' 'aplicativo' 'suporte']
# 0.2727272727272727
# 0.2727272727272727
# 0.20857403466099117

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow import keras
import tensorflow_hub as hub
from tensorflow.keras import layers
import os
import shutil

# %%
le_rn = LabelEncoder()
ytrain = le_rn.fit_transform(y_train)
ytest = le_rn.transform(y_test)

# %%
Xtrain = np.expand_dims(X_train.toarray(), axis=1)
Xtest = np.expand_dims(X_test.toarray(), axis=1)

# %%
num_classes = 4
model = tf.keras.Sequential([
    layers.LSTM(128, input_shape=(Xtrain.shape[1], Xtrain.shape[2])),
    layers.Dense(64, activation='relu'),
    layers.Dense(num_classes, activation='softmax')
])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
EPOCHS = 20
history = model.fit(Xtrain, ytrain, epochs=EPOCHS, batch_size=32, validation_data=(Xtest, ytest))
# Out:
# Epoch 1/20
# 1/1 [==============================] - 3s 3s/step - loss: 1.3907 - accuracy: 0.1875 - val_loss: 1.3838 - val_accuracy: 0.2727
# Epoch 2/20
# 1/1 [==============================] - 0s 75ms/step - loss: 1.3833 - accuracy: 0.3750 - val_loss: 1.3834 - val_accuracy: 0.3182
# Epoch 3/20
# 1/1 [==============================] - 0s 59ms/step - loss: 1.3766 - accuracy: 0.6250 - val_loss: 1.3831 - val_accuracy: 0.4091
# Epoch 4/20
# 1/1 [==============================] - 0s 70ms/step - loss: 1.3704 - accuracy: 0.7188 - val_loss: 1.3828 - val_accuracy: 0.4091
# Epoch 5/20
# 1/1 [==============================] - 0s 71ms/step - loss: 1.3642 - accuracy: 0.7500 - val_loss: 1.3826 - val_accuracy: 0.4091
# Epoch 6/20
# 1/1 [==============================] - 0s 66ms/step - loss: 1.3582 - accuracy: 0.7812 - val_loss: 1.3824 - val_accuracy: 0.4091
# Epoch 7/20
# 1/1 [==============================] - 0s 71ms/step - loss: 1.3521 - accuracy: 0.7812 - val_loss: 1.3823 - val_accuracy: 0.4091
# Epoch 8/20
# 1/1 [==============================] - 0s 77ms/step - loss: 1.3459 - accuracy: 0.7812 - val_loss: 1.3824 - val_accuracy: 0.3636
# Epoch 9/20
# 1/1 [==============================] - 0s 55ms/step - loss: 1.3395 - accuracy: 0.7812 - val_loss: 1.3825 - val_accuracy: 0.3636
# Epoch 10/20
# 1/1 [==============================] - 0s 78ms/step - loss: 1.3330 - accuracy: 0.7500 - val_loss: 1.3826 - val_accuracy: 0.3182
# Epoch 11/20
# 1/1 [==============================] - 0s 71ms/step - loss: 1.3263 - accuracy: 0.7500 - val_loss: 1.3827 - val_accuracy: 0.2727
# Epoch 12/20
# 1/1 [==============================] - 0s 60ms/step - loss: 1.3192 - accuracy: 0.7812 - val_loss: 1.3829 - val_accuracy: 0.2727
# Epoch 13/20
# 1/1 [==============================] - 0s 78ms/step - loss: 1.3119 - accuracy: 0.7812 - val_loss: 1.3830 - val_accuracy: 0.2727
# Epoch 14/20
# 1/1 [==============================] - 0s 94ms/step - loss: 1.3043 - accuracy: 0.8125 - val_loss: 1.3832 - val_accuracy: 0.2727
# Epoch 15/20
# 1/1 [==============================] - 0s 118ms/step - loss: 1.2964 - accuracy: 0.8125 - val_loss: 1.3834 - val_accuracy: 0.2727
# Epoch 16/20
# 1/1 [==============================] - 0s 97ms/step - loss: 1.2881 - accuracy: 0.8438 - val_loss: 1.3836 - val_accuracy: 0.2727
# Epoch 17/20
# 1/1 [==============================] - 0s 131ms/step - loss: 1.2793 - accuracy: 0.8438 - val_loss: 1.3839 - val_accuracy: 0.2727
# Epoch 18/20
# 1/1 [==============================] - 0s 115ms/step - loss: 1.2701 - accuracy: 0.8438 - val_loss: 1.3843 - val_accuracy: 0.2273
# Epoch 19/20
# 1/1 [==============================] - 0s 98ms/step - loss: 1.2604 - accuracy: 0.8750 - val_loss: 1.3848 - val_accuracy: 0.2273
# Epoch 20/20
# 1/1 [==============================] - 0s 42ms/step - loss: 1.2501 - accuracy: 0.8750 - val_loss: 1.3854 - val_accuracy: 0.2273

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(len(acc))

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Acuracia no treino')
plt.plot(epochs_range, val_acc, label='Acuracia na validacao')
plt.legend(loc='lower right')
plt.title('Acuracia no treino na validacao')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Perda no treino')
plt.plot(epochs_range, val_loss, label='Perda na validacao')
plt.legend(loc='upper right')
plt.title('Perda no treino e na validacao')
plt.show()

# %%
model_drop = tf.keras.Sequential([
    layers.LSTM(128, input_shape=(Xtrain.shape[1], Xtrain.shape[2])),
    layers.Dense(64, activation='relu'),
    keras.layers.Dropout(rate=0.5),
    layers.Dense(num_classes, activation='softmax')
])

# %%
model_drop.compile(optimizer='adam',
                   loss='sparse_categorical_crossentropy',
                   metrics=['accuracy'])

# %%
EPOCHS = 20
history_drop = model_drop.fit(Xtrain, ytrain, epochs=EPOCHS, batch_size=32, validation_data=(Xtest, ytest))
# Out:
# Epoch 1/20
# 1/1 [==============================] - 4s 4s/step - loss: 1.3875 - accuracy: 0.3125 - val_loss: 1.3871 - val_accuracy: 0.3182
# Epoch 2/20
# 1/1 [==============================] - 0s 52ms/step - loss: 1.3790 - accuracy: 0.3438 - val_loss: 1.3871 - val_accuracy: 0.3636
# Epoch 3/20
# 1/1 [==============================] - 0s 63ms/step - loss: 1.3733 - accuracy: 0.4688 - val_loss: 1.3871 - val_accuracy: 0.2727
# Epoch 4/20
# 1/1 [==============================] - 0s 47ms/step - loss: 1.3670 - accuracy: 0.5938 - val_loss: 1.3871 - val_accuracy: 0.2727
# Epoch 5/20
# 1/1 [==============================] - 0s 63ms/step - loss: 1.3684 - accuracy: 0.5625 - val_loss: 1.3872 - val_accuracy: 0.2273
# Epoch 6/20
# 1/1 [==============================] - 0s 61ms/step - loss: 1.3609 - accuracy: 0.6562 - val_loss: 1.3873 - val_accuracy: 0.2273
# Epoch 7/20
# 1/1 [==============================] - 0s 72ms/step - loss: 1.3565 - accuracy: 0.6875 - val_loss: 1.3873 - val_accuracy: 0.2727
# Epoch 8/20
# 1/1 [==============================] - 0s 123ms/step - loss: 1.3473 - accuracy: 0.7188 - val_loss: 1.3874 - val_accuracy: 0.2727
# Epoch 9/20
# 1/1 [==============================] - 0s 82ms/step - loss: 1.3466 - accuracy: 0.7188 - val_loss: 1.3875 - val_accuracy: 0.2727
# Epoch 10/20
# 1/1 [==============================] - 0s 87ms/step - loss: 1.3394 - accuracy: 0.7188 - val_loss: 1.3875 - val_accuracy: 0.2727
# Epoch 11/20
# 1/1 [==============================] - 0s 88ms/step - loss: 1.3401 - accuracy: 0.7500 - val_loss: 1.3876 - val_accuracy: 0.2727
# Epoch 12/20
# 1/1 [==============================] - 0s 120ms/step - loss: 1.3371 - accuracy: 0.7500 - val_loss: 1.3876 - val_accuracy: 0.2727
# Epoch 13/20
# 1/1 [==============================] - 0s 89ms/step - loss: 1.3307 - accuracy: 0.6562 - val_loss: 1.3878 - val_accuracy: 0.3182
# Epoch 14/20
# 1/1 [==============================] - 0s 113ms/step - loss: 1.3166 - accuracy: 0.7812 - val_loss: 1.3880 - val_accuracy: 0.3182
# Epoch 15/20
# 1/1 [==============================] - 0s 63ms/step - loss: 1.3116 - accuracy: 0.7188 - val_loss: 1.3883 - val_accuracy: 0.2727
# Epoch 16/20
# 1/1 [==============================] - 0s 134ms/step - loss: 1.3077 - accuracy: 0.7188 - val_loss: 1.3888 - val_accuracy: 0.2727
# Epoch 17/20
# 1/1 [==============================] - 0s 114ms/step - loss: 1.2960 - accuracy: 0.7500 - val_loss: 1.3894 - val_accuracy: 0.2727
# Epoch 18/20
# 1/1 [==============================] - 0s 78ms/step - loss: 1.3005 - accuracy: 0.7188 - val_loss: 1.3900 - val_accuracy: 0.2727
# Epoch 19/20
# 1/1 [==============================] - 0s 89ms/step - loss: 1.2919 - accuracy: 0.7500 - val_loss: 1.3907 - val_accuracy: 0.2727
# Epoch 20/20
# 1/1 [==============================] - 0s 80ms/step - loss: 1.2818 - accuracy: 0.7500 - val_loss: 1.3914 - val_accuracy: 0.2727

# %%
acc2 = history_drop.history['accuracy']
val_acc2 = history_drop.history['val_accuracy']
loss2 = history_drop.history['loss']
val_loss2 = history_drop.history['val_loss']

epochs_range = range(len(acc2))

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc2, label='Acuracia no treino')
plt.plot(epochs_range, val_acc2, label='Acuracia na validacao')
plt.legend(loc='lower right')
plt.title('Acuracia no treino na validacao')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss2, label='Perda no treino')
plt.plot(epochs_range, val_loss2, label='Perda na validacao')
plt.legend(loc='upper right')
plt.title('Perda no treino e na validacao')
plt.show()

# %%
model_early = tf.keras.Sequential([
    layers.LSTM(128, input_shape=(Xtrain.shape[1], Xtrain.shape[2])),
    layers.Dense(64, activation='relu'),
    layers.Dense(num_classes, activation='softmax')
])

# %%
model_early.compile(optimizer='adam',
                   loss='sparse_categorical_crossentropy',
                   metrics=['accuracy'])

# %%
callbacks = [
    keras.callbacks.EarlyStopping(
        monitor="val_loss",
        min_delta=1e-2,
        patience=5,
        restore_best_weights=True,
        verbose=1,
    )
]

# %%
EPOCHS = 100
history_early = model_early.fit(Xtrain, ytrain,callbacks = callbacks, epochs=EPOCHS, batch_size=32, validation_data=(Xtest, ytest))
# Out:
# Epoch 1/100
# 1/1 [==============================] - 5s 5s/step - loss: 1.3891 - accuracy: 0.1250 - val_loss: 1.3846 - val_accuracy: 0.3182
# Epoch 2/100
# 1/1 [==============================] - 0s 131ms/step - loss: 1.3828 - accuracy: 0.3750 - val_loss: 1.3843 - val_accuracy: 0.3182
# Epoch 3/100
# 1/1 [==============================] - 0s 119ms/step - loss: 1.3772 - accuracy: 0.5000 - val_loss: 1.3841 - val_accuracy: 0.3182
# Epoch 4/100
# 1/1 [==============================] - 0s 130ms/step - loss: 1.3720 - accuracy: 0.5312 - val_loss: 1.3840 - val_accuracy: 0.3182
# Epoch 5/100
# 1/1 [==============================] - 0s 129ms/step - loss: 1.3669 - accuracy: 0.6562 - val_loss: 1.3839 - val_accuracy: 0.3182
# Epoch 6/100
# 1/1 [==============================] - ETA: 0s - loss: 1.3617 - accuracy: 0.7188Restoring model weights from the end of the best epoch: 1.
# 1/1 [==============================] - 0s 111ms/step - loss: 1.3617 - accuracy: 0.7188 - val_loss: 1.3837 - val_accuracy: 0.2727
# Epoch 6: early stopping

# %%
acc3 = history_early.history['accuracy']
val_acc3 = history_early.history['val_accuracy']
loss3 = history_early.history['loss']
val_loss3 = history_early.history['val_loss']

epochs_range = range(len(acc3))

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc3, label='Acuracia no treino')
plt.plot(epochs_range, val_acc3, label='Acuracia na validacao')
plt.legend(loc='lower right')
plt.title('Acuracia no treino na validacao')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss3, label='Perda no treino')
plt.plot(epochs_range, val_loss3, label='Perda na validacao')
plt.legend(loc='upper right')
plt.title('Perda no treino e na validacao')
plt.show()

# %%
model_few = tf.keras.Sequential([
    layers.LSTM(128, input_shape=(Xtrain.shape[1], Xtrain.shape[2])),
    layers.Dense(64, activation='relu'),
    layers.Dense(num_classes, activation='softmax')
])
learning_rate = 0.001
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)

model_few.compile(optimizer=optimizer,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
EPOCHS = 20
history_few = model_few.fit(Xtrain, ytrain, epochs=EPOCHS, batch_size=32, validation_data=(Xtest, ytest))
# Out:
# Epoch 1/20
# 1/1 [==============================] - 5s 5s/step - loss: 1.3865 - accuracy: 0.1562 - val_loss: 1.3898 - val_accuracy: 0.0909
# Epoch 2/20
# 1/1 [==============================] - 0s 71ms/step - loss: 1.3794 - accuracy: 0.3750 - val_loss: 1.3898 - val_accuracy: 0.1364
# Epoch 3/20
# 1/1 [==============================] - 0s 77ms/step - loss: 1.3724 - accuracy: 0.7188 - val_loss: 1.3899 - val_accuracy: 0.1364
# Epoch 4/20
# 1/1 [==============================] - 0s 84ms/step - loss: 1.3657 - accuracy: 0.7500 - val_loss: 1.3900 - val_accuracy: 0.1818
# Epoch 5/20
# 1/1 [==============================] - 0s 88ms/step - loss: 1.3591 - accuracy: 0.7812 - val_loss: 1.3900 - val_accuracy: 0.1818
# Epoch 6/20
# 1/1 [==============================] - 0s 78ms/step - loss: 1.3525 - accuracy: 0.8125 - val_loss: 1.3902 - val_accuracy: 0.1818
# Epoch 7/20
# 1/1 [==============================] - 0s 123ms/step - loss: 1.3457 - accuracy: 0.8438 - val_loss: 1.3904 - val_accuracy: 0.1818
# Epoch 8/20
# 1/1 [==============================] - 0s 73ms/step - loss: 1.3387 - accuracy: 0.8438 - val_loss: 1.3906 - val_accuracy: 0.1818
# Epoch 9/20
# 1/1 [==============================] - 0s 74ms/step - loss: 1.3315 - accuracy: 0.8438 - val_loss: 1.3909 - val_accuracy: 0.1818
# Epoch 10/20
# 1/1 [==============================] - 0s 89ms/step - loss: 1.3239 - accuracy: 0.8125 - val_loss: 1.3911 - val_accuracy: 0.1818
# Epoch 11/20
# 1/1 [==============================] - 0s 100ms/step - loss: 1.3159 - accuracy: 0.8125 - val_loss: 1.3915 - val_accuracy: 0.1818
# Epoch 12/20
# 1/1 [==============================] - 0s 92ms/step - loss: 1.3074 - accuracy: 0.8125 - val_loss: 1.3920 - val_accuracy: 0.1818
# Epoch 13/20
# 1/1 [==============================] - 0s 85ms/step - loss: 1.2984 - accuracy: 0.8125 - val_loss: 1.3926 - val_accuracy: 0.1818
# Epoch 14/20
# 1/1 [==============================] - 0s 97ms/step - loss: 1.2890 - accuracy: 0.8125 - val_loss: 1.3932 - val_accuracy: 0.1818
# Epoch 15/20
# 1/1 [==============================] - 0s 75ms/step - loss: 1.2792 - accuracy: 0.8125 - val_loss: 1.3939 - val_accuracy: 0.2273
# Epoch 16/20
# 1/1 [==============================] - 0s 98ms/step - loss: 1.2690 - accuracy: 0.8125 - val_loss: 1.3946 - val_accuracy: 0.2273
# Epoch 17/20
# 1/1 [==============================] - 0s 154ms/step - loss: 1.2581 - accuracy: 0.8125 - val_loss: 1.3954 - val_accuracy: 0.2273
# Epoch 18/20
# 1/1 [==============================] - 0s 137ms/step - loss: 1.2466 - accuracy: 0.8125 - val_loss: 1.3963 - val_accuracy: 0.2273
# Epoch 19/20
# 1/1 [==============================] - 0s 142ms/step - loss: 1.2345 - accuracy: 0.8125 - val_loss: 1.3973 - val_accuracy: 0.2273
# Epoch 20/20
# 1/1 [==============================] - 0s 106ms/step - loss: 1.2217 - accuracy: 0.8125 - val_loss: 1.3983 - val_accuracy: 0.2273

# %%
X = freq_dists
rotulos_possiveis = ["testador", "aplicativo", "execução", "suporte"]
y = [choice(rotulos_possiveis) for _ in range(len(freq_dists))]
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform([" ".join(freq_dist.keys()) for freq_dist in X])


X_novos = csr_matrix(X)
X_novos.sort_indices()


X_novos = np.expand_dims(X_novos.toarray(), axis=1)

y_novos = le_rn.transform([choice(rotulos_possiveis) for _ in range(len(y))])

EPOCHS = 20
history_few = model_few.fit(X_novos, y_novos, epochs=EPOCHS, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/20
# 2/2 [==============================] - 3s 142ms/step - loss: 1.3827 - accuracy: 0.2558 - val_loss: 1.3712 - val_accuracy: 0.3636
# Epoch 2/20
# 2/2 [==============================] - 0s 148ms/step - loss: 1.3770 - accuracy: 0.2558 - val_loss: 1.3690 - val_accuracy: 0.3636
# Epoch 3/20
# 2/2 [==============================] - 0s 194ms/step - loss: 1.3645 - accuracy: 0.2558 - val_loss: 1.3668 - val_accuracy: 0.3636
# Epoch 4/20
# 2/2 [==============================] - 0s 217ms/step - loss: 1.3504 - accuracy: 0.2326 - val_loss: 1.3651 - val_accuracy: 0.3636
# Epoch 5/20
# 2/2 [==============================] - 0s 168ms/step - loss: 1.3346 - accuracy: 0.2558 - val_loss: 1.3626 - val_accuracy: 0.3636
# Epoch 6/20
# 2/2 [==============================] - 0s 169ms/step - loss: 1.3186 - accuracy: 0.2558 - val_loss: 1.3607 - val_accuracy: 0.3636
# Epoch 7/20
# 2/2 [==============================] - 0s 56ms/step - loss: 1.3004 - accuracy: 0.3256 - val_loss: 1.3590 - val_accuracy: 0.3636
# Epoch 8/20
# 2/2 [==============================] - 0s 54ms/step - loss: 1.2825 - accuracy: 0.3953 - val_loss: 1.3575 - val_accuracy: 0.2727
# Epoch 9/20
# 2/2 [==============================] - 0s 54ms/step - loss: 1.2637 - accuracy: 0.4186 - val_loss: 1.3560 - val_accuracy: 0.2727
# Epoch 10/20
# 2/2 [==============================] - 0s 51ms/step - loss: 1.2444 - accuracy: 0.4884 - val_loss: 1.3551 - val_accuracy: 0.2727
# Epoch 11/20
# 2/2 [==============================] - 0s 51ms/step - loss: 1.2252 - accuracy: 0.4884 - val_loss: 1.3533 - val_accuracy: 0.2727
# Epoch 12/20
# 2/2 [==============================] - 0s 69ms/step - loss: 1.2036 - accuracy: 0.5116 - val_loss: 1.3494 - val_accuracy: 0.2727
# Epoch 13/20
# 2/2 [==============================] - 0s 70ms/step - loss: 1.1812 - accuracy: 0.5349 - val_loss: 1.3458 - val_accuracy: 0.2727
# Epoch 14/20
# 2/2 [==============================] - 0s 73ms/step - loss: 1.1579 - accuracy: 0.6047 - val_loss: 1.3424 - val_accuracy: 0.2727
# Epoch 15/20
# 2/2 [==============================] - 0s 53ms/step - loss: 1.1345 - accuracy: 0.6279 - val_loss: 1.3400 - val_accuracy: 0.2727
# Epoch 16/20
# 2/2 [==============================] - 0s 110ms/step - loss: 1.1077 - accuracy: 0.6512 - val_loss: 1.3382 - val_accuracy: 0.2727
# Epoch 17/20
# 2/2 [==============================] - 0s 90ms/step - loss: 1.0810 - accuracy: 0.6512 - val_loss: 1.3366 - val_accuracy: 0.2727
# Epoch 18/20
# 2/2 [==============================] - 0s 71ms/step - loss: 1.0524 - accuracy: 0.6744 - val_loss: 1.3363 - val_accuracy: 0.2727
# Epoch 19/20
# 2/2 [==============================] - 0s 54ms/step - loss: 1.0213 - accuracy: 0.6977 - val_loss: 1.3372 - val_accuracy: 0.2727
# Epoch 20/20
# 2/2 [==============================] - 0s 61ms/step - loss: 0.9889 - accuracy: 0.6977 - val_loss: 1.3368 - val_accuracy: 0.2727
