# %%
import nltk
from sklearn.feature_extraction.text import TfidfVectorizer
# !python3 -m spacy download pt_core_news_lg
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.probability import FreqDist
from transformers import pipeline
from nltk.corpus import stopwords
import matplotlib.pyplot as plt
from random import choice
import seaborn as sns
import numpy as np
import pandas as pd
# %matplotlib inline
import torch
import string
import re
# Out:
# Collecting pt-core-news-lg==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/pt_core_news_lg-3.7.0/pt_core_news_lg-3.7.0-py3-none-any.whl (568.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 568.2/568.2 MB 742.7 kB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from pt-core-news-lg==3.7.0) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (4.66.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.6.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (24.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (1.25.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.16.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.1.5)
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
# !pip install scikit-learn

from sklearn.tree import plot_tree
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow import keras
import tensorflow_hub as hub
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import shutil
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.25.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.4.0)

# %%
classifier = pipeline("zero-shot-classification")
candidate_labels = ["testador", "suporte", "ferramenta"]
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli and revision c626438 (https://huggingface.co/facebook/bart-large-mnli).
# Using a pipeline without specifying a model name and revision in production is not recommended.

# %%
roberta = pipeline("ner", grouped_entities=True, model="joelniklaus/legal-portuguese-roberta-base")
# Out:
# Some weights of RobertaForTokenClassification were not initialized from the model checkpoint at joelniklaus/legal-portuguese-roberta-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/token_classification.py:168: UserWarning: `grouped_entities` is deprecated and will be removed in version v5.0.0, defaulted to `aggregation_strategy="simple"` instead.
#   warnings.warn(

# %%
historias_usuario = [
    "Como Testador eu quero um jeito mais fácil de incluir os requisitos do aplicativo na ferramenta DRL-Mobtest para criar casos de teste que cubram tudo que o aplicativo precisa fazer, sem ter que gastar muito tempo escrevendo manualmente.",
    "Como Testador eu quero uma maneira de ensinar a ferramenta DRL-Mobtest a entender os requisitos do aplicativo usando NLP para fazer com que a ferramenta gere testes automaticamente.",
    "Como Testador eu quero que a ferramenta gere casos de teste abrangentes que cubram integralmente todos os requisitos do aplicativo, assegurando que o software seja completo e funcional, sem depender exclusivamente da criação manual de casos de teste.",
    "Como Testador eu quero que a ferramenta seja integrada com outras ferramentas de gerenciamento, permitindo sincronização automática dos requisitos e facilitando o processo de criação de casos de testes.",
    "Como Testador eu quero que a ferramenta  forneça o recurso de criação de relatórios detalhados sobre a cobertura dos testes, permitindo uma análise precisa sobre sua progressão e identificação das lacunas durante sua execução.",
    "Como testador, quero uma maneira mais fácil de incluir requisitos do aplicativo para criar casos de teste abrangentes, economizando tempo na escrita manual.",
    "Como testador, desejo ensinar a ferramenta a entender os requisitos do aplicativo usando NLP para gerar testes automaticamente.",
    "Como testador, preciso que a ferramenta gere casos de teste completos e funcionais que cubram todos os requisitos do aplicativo.",
    "Como testador, quero integração com outras ferramentas de gerenciamento para sincronizar automaticamente requisitos e facilitar a criação de casos de teste.",
    "Como testador, quero relatórios detalhados sobre a cobertura dos testes para análise precisa durante a execução.",
    "Como testador, desejo que a ferramenta identifique automaticamente os casos de teste mais críticos para priorizar a análise.",
    "Como testador, preciso que a ferramenta sugira casos de teste com base em padrões de uso real do aplicativo.",
    "Como testador, quero sugestões com base em padrões de falha históricos para evitar problemas recorrentes no software.",
    "Como testador, desejo suporte à execução de testes automatizados em diferentes dispositivos e ambientes.",
    "Como testador, preciso que a ferramenta detecte automaticamente mudanças nos requisitos e ajuste os casos de teste correspondentes.",
    "Como testador, quero integração com sistemas de controle de versão para rastrear mudanças nos requisitos e no código-fonte.",
    "Como testador, desejo métricas detalhadas sobre a eficácia dos testes, incluindo taxa de cobertura e taxa de falha.",
    "Como testador, preciso de suporte à execução de testes de desempenho e escalabilidade.",
    "Como testador, quero análise automática dos resultados dos testes para relatórios detalhados sobre problemas encontrados.",
    "Como testador, desejo simular cenários de teste complexos e realistas para garantir testes próximos à realidade.",
    "Como testador, preciso de suporte à execução de testes de regressão automatizados.",
    "Como testador, quero identificação automática de casos de teste redundantes ou desnecessários.",
    "Como testador, desejo integração fácil com ferramentas de gerenciamento de projetos.",
    "Como testador, preciso de suporte à execução de testes de usabilidade.",
    "Como testador, quero que a ferramenta crie automaticamente conjuntos de dados de teste realistas.",
    "Como testador, desejo integração com ferramentas de monitoramento de desempenho em tempo real.",
    "Como testador, preciso de suporte à execução de testes de localização e internacionalização.",
    "Como testador, quero geração automática de dados de teste sintéticos.",
    "Como testador, desejo suporte à execução de testes de acessibilidade.",
    "Como testador, preciso de suporte à execução de testes de integração contínua.",
    "Como testador, quero identificação automática de casos de teste incompletos ou mal definidos.",
    "Como testador, desejo identificação automática de dependências entre casos de teste.",
    "Como testador, preciso de suporte à execução de testes de recuperação de desastres.",
    "Como testador, quero que a ferramenta identifique automaticamente casos de teste paralelizáveis.",
    "Como testador, desejo simulação de cenários de teste de carga extremamente alta.",
    "Como testador, preciso de suporte à execução de testes de compatibilidade com diferentes navegadores e dispositivos.",
    "Como testador, quero geração automática de relatórios de teste personalizados.",
    "Como testador, desejo rastreamento automático de resultados de teste ao longo do tempo.",
    "Como testador, preciso de suporte à execução de testes de regressão progressiva.",
    "Como testador, quero sugestões automáticas para aprimorar os casos de teste existentes.",
    "Como testador, desejo que a ferramenta aprenda com os resultados dos testes e melhore suas sugestões futuras.",
    "Como testador, preciso de suporte à execução de testes de segurança automatizados.",
    "Como testador, quero integração com ferramentas de análise de código estático para identificar áreas de risco.",
    "Como testador, desejo suporte à execução de testes de integração de sistema e teste de aceitação do usuário.",
    "Como testador, preciso de suporte à execução de testes de confiabilidade e disponibilidade.",
    "Como testador, quero que a ferramenta sugira casos de teste com base em modelos de qualidade de software reconhecidos.",
    "Como testador, desejo integração com ferramentas de automação de teste de interface do usuário.",
    "Como testador, preciso de suporte à execução de testes de estresse e robustez.",
    "Como testador, quero que a ferramenta sugira casos de teste para áreas de alto risco e complexidade.",
    "Como testador, desejo integração com ferramentas de gerenciamento de defeitos para rastreamento de correções.",
    "Como testador, preciso de suporte à execução de testes de usabilidade remota e teste de usuário beta.",
    "Como testador, quero que a ferramenta forneça feedback em tempo real durante a execução dos testes.",
    "Como testador, desejo integração com ferramentas de automação de infraestrutura para provisionamento e configuração automatizados.",
    "Como testador, preciso de suporte à execução de testes de comparação de desempenho para versões anteriores e atuais do aplicativo."
  ]

# %%
unicas = set(historias_usuario)

print("Total de palavras unicas:",len(unicas))

print("Diversidade Lexica:",len(unicas)/len(historias_usuario))
# Out:
# Total de palavras unicas: 54
# Diversidade Lexica: 1.0

# %%
#sem_pontuacao = re.findall(r'\b(^[^A-Za-z])\b', historias_usuario, re.IGNORECASE)

# %%
class ProcessadorHistoriasUsuario:
    def __init__(self):
        nltk.download('punkt')
        nltk.download('stopwords')
        nltk.download('wordnet')
        self.lemmatizer = WordNetLemmatizer()
        self.stop_words = set(stopwords.words('portuguese'))

    def processar_historias_usuario(self, historias_usuario):
        freq_dists = []
        for historia_usuario in historias_usuario:
            tokens = word_tokenize(historia_usuario)
            tokens = [token.lower() for token in tokens if token not in string.punctuation]
            tokens = [token for token in tokens if token not in self.stop_words]
            tokens = [self.lemmatizer.lemmatize(token) for token in tokens]
            freq_dist = FreqDist(tokens)
            freq_dists.append(freq_dist)
        return freq_dists

# %%
processador = ProcessadorHistoriasUsuario()
freq_dists = processador.processar_historias_usuario(historias_usuario)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
for i, freq_dist in enumerate(freq_dists):
    print(f"História de Usuário {i+1}: {freq_dist.most_common(5)}")
# Out:
# História de Usuário 1: [('aplicativo', 2), ('testador', 1), ('quero', 1), ('jeito', 1), ('fácil', 1)]
# História de Usuário 2: [('ferramenta', 2), ('testador', 1), ('quero', 1), ('maneira', 1), ('ensinar', 1)]
# História de Usuário 3: [('casos', 2), ('teste', 2), ('testador', 1), ('quero', 1), ('ferramenta', 1)]
# História de Usuário 4: [('testador', 1), ('quero', 1), ('ferramenta', 1), ('integrada', 1), ('outras', 1)]
# História de Usuário 5: [('sobre', 2), ('testador', 1), ('quero', 1), ('ferramenta', 1), ('forneça', 1)]
# História de Usuário 6: [('testador', 1), ('quero', 1), ('maneira', 1), ('fácil', 1), ('incluir', 1)]
# História de Usuário 7: [('testador', 1), ('desejo', 1), ('ensinar', 1), ('ferramenta', 1), ('entender', 1)]
# História de Usuário 8: [('testador', 1), ('preciso', 1), ('ferramenta', 1), ('gere', 1), ('casos', 1)]
# História de Usuário 9: [('testador', 1), ('quero', 1), ('integração', 1), ('outras', 1), ('ferramentas', 1)]
# História de Usuário 10: [('testador', 1), ('quero', 1), ('relatórios', 1), ('detalhados', 1), ('sobre', 1)]
# História de Usuário 11: [('testador', 1), ('desejo', 1), ('ferramenta', 1), ('identifique', 1), ('automaticamente', 1)]
# História de Usuário 12: [('testador', 1), ('preciso', 1), ('ferramenta', 1), ('sugira', 1), ('casos', 1)]
# História de Usuário 13: [('testador', 1), ('quero', 1), ('sugestões', 1), ('base', 1), ('padrões', 1)]
# História de Usuário 14: [('testador', 1), ('desejo', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 15: [('testador', 1), ('preciso', 1), ('ferramenta', 1), ('detecte', 1), ('automaticamente', 1)]
# História de Usuário 16: [('testador', 1), ('quero', 1), ('integração', 1), ('sistemas', 1), ('controle', 1)]
# História de Usuário 17: [('taxon', 2), ('testador', 1), ('desejo', 1), ('métricas', 1), ('detalhadas', 1)]
# História de Usuário 18: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 19: [('testador', 1), ('quero', 1), ('análise', 1), ('automática', 1), ('resultados', 1)]
# História de Usuário 20: [('testador', 1), ('desejo', 1), ('simular', 1), ('cenários', 1), ('teste', 1)]
# História de Usuário 21: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 22: [('testador', 1), ('quero', 1), ('identificação', 1), ('automática', 1), ('casos', 1)]
# História de Usuário 23: [('testador', 1), ('desejo', 1), ('integração', 1), ('fácil', 1), ('ferramentas', 1)]
# História de Usuário 24: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 25: [('testador', 1), ('quero', 1), ('ferramenta', 1), ('crie', 1), ('automaticamente', 1)]
# História de Usuário 26: [('testador', 1), ('desejo', 1), ('integração', 1), ('ferramentas', 1), ('monitoramento', 1)]
# História de Usuário 27: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 28: [('testador', 1), ('quero', 1), ('geração', 1), ('automática', 1), ('dado', 1)]
# História de Usuário 29: [('testador', 1), ('desejo', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 30: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 31: [('testador', 1), ('quero', 1), ('identificação', 1), ('automática', 1), ('casos', 1)]
# História de Usuário 32: [('testador', 1), ('desejo', 1), ('identificação', 1), ('automática', 1), ('dependências', 1)]
# História de Usuário 33: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 34: [('testador', 1), ('quero', 1), ('ferramenta', 1), ('identifique', 1), ('automaticamente', 1)]
# História de Usuário 35: [('testador', 1), ('desejo', 1), ('simulação', 1), ('cenários', 1), ('teste', 1)]
# História de Usuário 36: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 37: [('testador', 1), ('quero', 1), ('geração', 1), ('automática', 1), ('relatórios', 1)]
# História de Usuário 38: [('testador', 1), ('desejo', 1), ('rastreamento', 1), ('automático', 1), ('resultados', 1)]
# História de Usuário 39: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 40: [('testador', 1), ('quero', 1), ('sugestões', 1), ('automáticas', 1), ('aprimorar', 1)]
# História de Usuário 41: [('testador', 1), ('desejo', 1), ('ferramenta', 1), ('aprenda', 1), ('resultados', 1)]
# História de Usuário 42: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 43: [('testador', 1), ('quero', 1), ('integração', 1), ('ferramentas', 1), ('análise', 1)]
# História de Usuário 44: [('testador', 1), ('desejo', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 45: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 46: [('testador', 1), ('quero', 1), ('ferramenta', 1), ('sugira', 1), ('casos', 1)]
# História de Usuário 47: [('testador', 1), ('desejo', 1), ('integração', 1), ('ferramentas', 1), ('automação', 1)]
# História de Usuário 48: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 49: [('testador', 1), ('quero', 1), ('ferramenta', 1), ('sugira', 1), ('casos', 1)]
# História de Usuário 50: [('testador', 1), ('desejo', 1), ('integração', 1), ('ferramentas', 1), ('gerenciamento', 1)]
# História de Usuário 51: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 52: [('testador', 1), ('quero', 1), ('ferramenta', 1), ('forneça', 1), ('feedback', 1)]
# História de Usuário 53: [('testador', 1), ('desejo', 1), ('integração', 1), ('ferramentas', 1), ('automação', 1)]
# História de Usuário 54: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]

# %%
nome, valor = zip(*freq_dists[0].most_common(5))
fig, ax = plt.subplots(figsize=(6,5))
sns.barplot(x=np.array(nome), y=np.array(valor), ax=ax)
plt.show()

# %%
nome,valor = zip(*freq_dist.most_common(5))
fig, ax = plt.subplots(figsize=(6,5))
sns.barplot(x=np.array(nome), y=np.array(valor), ax=ax)
# Out:
# <Axes: >

# %%
for i, historia_usuario in enumerate(historias_usuario):
    result = classifier(historia_usuario, candidate_labels=candidate_labels)
    top_label = result['labels'][0]
    confidence = result['scores'][0]
    print(f"História de Usuário {i+1}: Rótulo Previsto: {top_label}, Confiança: {confidence:.2f}")
# Out:
# História de Usuário 1: Rótulo Previsto: ferramenta, Confiança: 0.70
# História de Usuário 2: Rótulo Previsto: testador, Confiança: 0.64
# História de Usuário 3: Rótulo Previsto: testador, Confiança: 0.64
# História de Usuário 4: Rótulo Previsto: testador, Confiança: 0.73
# História de Usuário 5: Rótulo Previsto: testador, Confiança: 0.70
# História de Usuário 6: Rótulo Previsto: testador, Confiança: 0.95
# História de Usuário 7: Rótulo Previsto: testador, Confiança: 0.68
# História de Usuário 8: Rótulo Previsto: testador, Confiança: 0.69
# História de Usuário 9: Rótulo Previsto: testador, Confiança: 0.87
# História de Usuário 10: Rótulo Previsto: testador, Confiança: 0.95
# História de Usuário 11: Rótulo Previsto: testador, Confiança: 0.66
# História de Usuário 12: Rótulo Previsto: testador, Confiança: 0.68
# História de Usuário 13: Rótulo Previsto: testador, Confiança: 0.94
# História de Usuário 14: Rótulo Previsto: testador, Confiança: 0.76
# História de Usuário 15: Rótulo Previsto: testador, Confiança: 0.72
# História de Usuário 16: Rótulo Previsto: testador, Confiança: 0.91
# História de Usuário 17: Rótulo Previsto: testador, Confiança: 0.95
# História de Usuário 18: Rótulo Previsto: testador, Confiança: 0.72
# História de Usuário 19: Rótulo Previsto: testador, Confiança: 0.92
# História de Usuário 20: Rótulo Previsto: testador, Confiança: 0.91
# História de Usuário 21: Rótulo Previsto: testador, Confiança: 0.82
# História de Usuário 22: Rótulo Previsto: testador, Confiança: 0.98
# História de Usuário 23: Rótulo Previsto: testador, Confiança: 0.80
# História de Usuário 24: Rótulo Previsto: testador, Confiança: 0.81
# História de Usuário 25: Rótulo Previsto: ferramenta, Confiança: 0.53
# História de Usuário 26: Rótulo Previsto: testador, Confiança: 0.80
# História de Usuário 27: Rótulo Previsto: testador, Confiança: 0.75
# História de Usuário 28: Rótulo Previsto: testador, Confiança: 0.95
# História de Usuário 29: Rótulo Previsto: testador, Confiança: 0.82
# História de Usuário 30: Rótulo Previsto: testador, Confiança: 0.80
# História de Usuário 31: Rótulo Previsto: testador, Confiança: 0.95
# História de Usuário 32: Rótulo Previsto: testador, Confiança: 0.92
# História de Usuário 33: Rótulo Previsto: testador, Confiança: 0.77
# História de Usuário 34: Rótulo Previsto: testador, Confiança: 0.61
# História de Usuário 35: Rótulo Previsto: testador, Confiança: 0.90
# História de Usuário 36: Rótulo Previsto: testador, Confiança: 0.75
# História de Usuário 37: Rótulo Previsto: testador, Confiança: 0.95
# História de Usuário 38: Rótulo Previsto: testador, Confiança: 0.94
# História de Usuário 39: Rótulo Previsto: testador, Confiança: 0.78
# História de Usuário 40: Rótulo Previsto: testador, Confiança: 0.94
# História de Usuário 41: Rótulo Previsto: testador, Confiança: 0.61
# História de Usuário 42: Rótulo Previsto: testador, Confiança: 0.82
# História de Usuário 43: Rótulo Previsto: testador, Confiança: 0.76
# História de Usuário 44: Rótulo Previsto: testador, Confiança: 0.73
# História de Usuário 45: Rótulo Previsto: testador, Confiança: 0.75
# História de Usuário 46: Rótulo Previsto: testador, Confiança: 0.80
# História de Usuário 47: Rótulo Previsto: testador, Confiança: 0.74
# História de Usuário 48: Rótulo Previsto: testador, Confiança: 0.77
# História de Usuário 49: Rótulo Previsto: testador, Confiança: 0.66
# História de Usuário 50: Rótulo Previsto: testador, Confiança: 0.77
# História de Usuário 51: Rótulo Previsto: testador, Confiança: 0.77
# História de Usuário 52: Rótulo Previsto: testador, Confiança: 0.54
# História de Usuário 53: Rótulo Previsto: testador, Confiança: 0.87
# História de Usuário 54: Rótulo Previsto: testador, Confiança: 0.70

# %%
roberta(f"Resultado: {historias_usuario}")
# Out:
# [{'entity_group': 'LABEL_0',
#   'score': 0.598269,
#   'word': " resultado : [ ' como testador eu",
#   'start': 0,
#   'end': 29},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5567869,
#   'word': ' quero um je',
#   'start': 31,
#   'end': 41},
#  {'entity_group': 'LABEL_0',
#   'score': 0.51594794,
#   'word': 'ito mais',
#   'start': 41,
#   'end': 49},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6479623,
#   'word': ' facil de incluir os requisitos do aplicativo na ferramenta',
#   'start': 51,
#   'end': 108},
#  {'entity_group': 'LABEL_0',
#   'score': 0.55172646,
#   'word': ' dr',
#   'start': 110,
#   'end': 111},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5091224,
#   'word': 'l',
#   'start': 111,
#   'end': 112},
#  {'entity_group': 'LABEL_0',
#   'score': 0.58183074,
#   'word': ' - mob',
#   'start': 113,
#   'end': 116},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6462538,
#   'word': 'test para criar casos de teste que cubram tudo que o aplicativo precisa fazer , sem ter que gastar muito tempo escrevendo manualmente',
#   'start': 116,
#   'end': 248},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5339443,
#   'word': ' .',
#   'start': 249,
#   'end': 249},
#  {'entity_group': 'LABEL_1',
#   'score': 0.61971855,
#   'word': " ' ,",
#   'start': 250,
#   'end': 251},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6102932,
#   'word': " ' como testador eu",
#   'start': 253,
#   'end': 269},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5779356,
#   'word': ' que',
#   'start': 271,
#   'end': 273},
#  {'entity_group': 'LABEL_0',
#   'score': 0.52634543,
#   'word': 'ro uma maneira',
#   'start': 273,
#   'end': 287},
#  {'entity_group': 'LABEL_1',
#   'score': 0.62347203,
#   'word': ' de ensinar a',
#   'start': 289,
#   'end': 300},
#  {'entity_group': 'LABEL_0',
#   'score': 0.58945143,
#   'word': ' ferramenta drl - mob',
#   'start': 302,
#   'end': 319},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6132735,
#   'word': 'test a entender os requisitos do aplicativo usando nl',
#   'start': 319,
#   'end': 372},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5011672,
#   'word': 'p',
#   'start': 372,
#   'end': 373},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6525109,
#   'word': ' para fazer com que a ferramenta gere testes automaticamente',
#   'start': 375,
#   'end': 433},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5483742,
#   'word': ' .',
#   'start': 434,
#   'end': 434},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6087234,
#   'word': " ' ,",
#   'start': 435,
#   'end': 436},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5810465,
#   'word': " ' como testador eu",
#   'start': 438,
#   'end': 454},
#  {'entity_group': 'LABEL_1',
#   'score': 0.64151245,
#   'word': ' quero que a ferramenta gere casos de teste abrangentes que cubram integralmente todos os requisitos do aplicativo ,',
#   'start': 456,
#   'end': 569},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5034368,
#   'word': ' assegurando',
#   'start': 571,
#   'end': 581},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6279058,
#   'word': ' que o software seja completo',
#   'start': 583,
#   'end': 610},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5369674,
#   'word': ' e',
#   'start': 612,
#   'end': 612},
#  {'entity_group': 'LABEL_1',
#   'score': 0.66836196,
#   'word': ' funcional , sem depender exclusivamente da criacao manual de casos de teste',
#   'start': 614,
#   'end': 687},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5329672,
#   'word': ' .',
#   'start': 688,
#   'end': 688},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5777929,
#   'word': " ' ,",
#   'start': 689,
#   'end': 690},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6133832,
#   'word': " ' como testador eu",
#   'start': 692,
#   'end': 708},
#  {'entity_group': 'LABEL_1',
#   'score': 0.58874476,
#   'word': ' quero que a',
#   'start': 710,
#   'end': 720},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5447387,
#   'word': ' ferramenta',
#   'start': 722,
#   'end': 731},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6120505,
#   'word': ' seja integrada com outras ferramentas de gerenciamento ,',
#   'start': 733,
#   'end': 787},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5261016,
#   'word': ' permitindo',
#   'start': 789,
#   'end': 798},
#  {'entity_group': 'LABEL_1',
#   'score': 0.67606235,
#   'word': ' sincronizacao automatica dos requisitos e facilitando o processo de criacao de casos de testes',
#   'start': 800,
#   'end': 893},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5466527,
#   'word': ' .',
#   'start': 894,
#   'end': 894},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5900172,
#   'word': " ' ,",
#   'start': 895,
#   'end': 896},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6139061,
#   'word': " ' como testador eu",
#   'start': 898,
#   'end': 914},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5962794,
#   'word': ' quero que a',
#   'start': 916,
#   'end': 926},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5611237,
#   'word': ' ferramenta',
#   'start': 928,
#   'end': 937},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6230691,
#   'word': ' forneca o recurso de criacao de relatorios detalhados sobre a cobertura dos testes ,',
#   'start': 940,
#   'end': 1022},
#  {'entity_group': 'LABEL_0',
#   'score': 0.54663754,
#   'word': ' permitindo',
#   'start': 1024,
#   'end': 1033},
#  {'entity_group': 'LABEL_1',
#   'score': 0.65723646,
#   'word': ' uma analise',
#   'start': 1035,
#   'end': 1045},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5164312,
#   'word': ' precisa',
#   'start': 1047,
#   'end': 1053},
#  {'entity_group': 'LABEL_1',
#   'score': 0.56536365,
#   'word': ' sobre',
#   'start': 1055,
#   'end': 1059},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5424628,
#   'word': ' sua',
#   'start': 1061,
#   'end': 1063},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5780259,
#   'word': ' progressao e identificacao das',
#   'start': 1065,
#   'end': 1094},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5684276,
#   'word': ' lacunas',
#   'start': 1096,
#   'end': 1102},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6152835,
#   'word': ' durante',
#   'start': 1104,
#   'end': 1110},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5224946,
#   'word': ' sua',
#   'start': 1112,
#   'end': 1114},
#  {'entity_group': 'LABEL_1',
#   'score': 0.60174364,
#   'word': ' execucao',
#   'start': 1116,
#   'end': 1123},
#  {'entity_group': 'LABEL_0',
#   'score': 0.57812923,
#   'word': ' .',
#   'start': 1124,
#   'end': 1124},
#  {'entity_group': 'LABEL_1',
#   'score': 0.57599723,
#   'word': " ' ,",
#   'start': 1125,
#   'end': 1126},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5915632,
#   'word': " '",
#   'start': 1128,
#   'end': 1128},
#  {'entity_group': 'LABEL_1',
#   'score': 0.51914334,
#   'word': ' como',
#   'start': 1129,
#   'end': 1132},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5861501,
#   'word': ' testador',
#   'start': 1134,
#   'end': 1141},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6327213,
#   'word': ' , quero uma maneira mais facil de incluir requisitos do aplicativo para criar casos de teste abrangentes , economizando tempo na escrita manual',
#   'start': 1142,
#   'end': 1283},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5765925,
#   'word': ' .',
#   'start': 1284,
#   'end': 1284},
#  {'entity_group': 'LABEL_1',
#   'score': 0.60063255,
#   'word': " ' ,",
#   'start': 1285,
#   'end': 1286},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6063977,
#   'word': " ' como testador , desejo",
#   'start': 1288,
#   'end': 1309},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5973466,
#   'word': ' ensinar a',
#   'start': 1311,
#   'end': 1319},
#  {'entity_group': 'LABEL_0',
#   'score': 0.55649585,
#   'word': ' ferramenta',
#   'start': 1321,
#   'end': 1330},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6161994,
#   'word': ' a entender os requisitos do aplicativo usando',
#   'start': 1332,
#   'end': 1376},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5547335,
#   'word': ' nlp',
#   'start': 1378,
#   'end': 1380},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5877934,
#   'word': ' para gerar testes automaticamente',
#   'start': 1382,
#   'end': 1414},
#  {'entity_group': 'LABEL_0',
#   'score': 0.59803236,
#   'word': ' .',
#   'start': 1415,
#   'end': 1415},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5766378,
#   'word': " ' ,",
#   'start': 1416,
#   'end': 1417},
#  {'entity_group': 'LABEL_0',
#   'score': 0.58653826,
#   'word': " ' como testador ,",
#   'start': 1419,
#   'end': 1433},
#  {'entity_group': 'LABEL_1',
#   'score': 0.62205833,
#   'word': ' preciso que a ferramenta gere casos de teste completos e funcionais que cubram todos os requisitos do aplicativo',
#   'start': 1435,
#   'end': 1546},
#  {'entity_group': 'LABEL_0',
#   'score': 0.55471903,
#   'word': ' .',
#   'start': 1547,
#   'end': 1547},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6002463,
#   'word': " ' ,",
#   'start': 1548,
#   'end': 1549},
#  {'entity_group': 'LABEL_0',
#   'score': 0.573719,
#   'word': " ' como testador ,",
#   'start': 1551,
#   'end': 1565},
#  {'entity_group': 'LABEL_1',
#   'score': 0.57025415,
#   'word': ' quero integracao com outras',
#   'start': 1567,
#   'end': 1593},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5282447,
#   'word': ' ferramentas',
#   'start': 1595,
#   'end': 1605},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5775478,
#   'word': ' de gerenciamento',
#   'start': 1607,
#   'end': 1622},
#  {'entity_group': 'LABEL_0',
#   'score': 0.539971,
#   'word': ' para sincro',
#   'start': 1624,
#   'end': 1634},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6312875,
#   'word': 'nizar automaticamente requisitos e facilitar a criacao de casos de teste',
#   'start': 1634,
#   'end': 1706},
#  {'entity_group': 'LABEL_0',
#   'score': 0.59686524,
#   'word': ' .',
#   'start': 1707,
#   'end': 1707},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5753689,
#   'word': " ' ,",
#   'start': 1708,
#   'end': 1709},
#  {'entity_group': 'LABEL_0',
#   'score': 0.59218705,
#   'word': " ' como testador",
#   'start': 1711,
#   'end': 1724},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6132861,
#   'word': ' , quero relatorios detalhados sobre a cobertura dos testes para analise precisa durante a execucao',
#   'start': 1725,
#   'end': 1822},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5733834,
#   'word': ' .',
#   'start': 1823,
#   'end': 1823},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5859186,
#   'word': " ' ,",
#   'start': 1824,
#   'end': 1825},
#  {'entity_group': 'LABEL_0',
#   'score': 0.57836336,
#   'word': " '",
#   'start': 1827,
#   'end': 1827},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5294353,
#   'word': ' como',
#   'start': 1828,
#   'end': 1831},
#  {'entity_group': 'LABEL_0',
#   'score': 0.55466384,
#   'word': ' testador',
#   'start': 1833,
#   'end': 1840},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6357234,
#   'word': ' , desejo que a ferramenta identifique automaticamente os casos de teste mais criticos para',
#   'start': 1841,
#   'end': 1930},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5032374,
#   'word': ' priori',
#   'start': 1932,
#   'end': 1937},
#  {'entity_group': 'LABEL_1',
#   'score': 0.76048255,
#   'word': 'zar a analise',
#   'start': 1937,
#   'end': 1950},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5631227,
#   'word': ' .',
#   'start': 1951,
#   'end': 1951},
#  {'entity_group': 'LABEL_1',
#   'score': 0.59964937,
#   'word': " ' ,",
#   'start': 1952,
#   'end': 1953},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5592218,
#   'word': " ' como testador",
#   'start': 1955,
#   'end': 1968},
#  {'entity_group': 'LABEL_1',
#   'score': 0.58805895,
#   'word': ' , preciso que a',
#   'start': 1969,
#   'end': 1983},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5362515,
#   'word': ' ferramenta',
#   'start': 1985,
#   'end': 1994},
#  {'entity_group': 'LABEL_1',
#   'score': 0.65354335,
#   'word': ' sugira casos de teste com base em padroes de uso real do aplicativo',
#   'start': 1996,
#   'end': 2062},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5490642,
#   'word': ' .',
#   'start': 2063,
#   'end': 2063},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5969892,
#   'word': " ' ,",
#   'start': 2064,
#   'end': 2065},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5745347,
#   'word': " '",
#   'start': 2067,
#   'end': 2067},
#  {'entity_group': 'LABEL_1',
#   'score': 0.55367655,
#   'word': ' como',
#   'start': 2068,
#   'end': 2071},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5436218,
#   'word': ' testador',
#   'start': 2073,
#   'end': 2080},
#  {'entity_group': 'LABEL_1',
#   'score': 0.60057706,
#   'word': ' , quero',
#   'start': 2081,
#   'end': 2087},
#  {'entity_group': 'LABEL_0',
#   'score': 0.52434385,
#   'word': ' sugestoes',
#   'start': 2089,
#   'end': 2097},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6315394,
#   'word': ' com base em padroes de falha',
#   'start': 2099,
#   'end': 2126},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5048266,
#   'word': ' historicos',
#   'start': 2128,
#   'end': 2137},
#  {'entity_group': 'LABEL_1',
#   'score': 0.56732523,
#   'word': ' para evitar',
#   'start': 2139,
#   'end': 2149},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5035557,
#   'word': ' problemas',
#   'start': 2151,
#   'end': 2159},
#  {'entity_group': 'LABEL_1',
#   'score': 0.66620684,
#   'word': ' recorrentes no software',
#   'start': 2161,
#   'end': 2183},
#  {'entity_group': 'LABEL_0',
#   'score': 0.530952,
#   'word': ' .',
#   'start': 2184,
#   'end': 2184},
#  {'entity_group': 'LABEL_1',
#   'score': 0.62320966,
#   'word': " ' ,",
#   'start': 2185,
#   'end': 2186},
#  {'entity_group': 'LABEL_0',
#   'score': 0.56720716,
#   'word': " ' como testador",
#   'start': 2188,
#   'end': 2201},
#  {'entity_group': 'LABEL_1',
#   'score': 0.51135826,
#   'word': ' ,',
#   'start': 2202,
#   'end': 2202},
#  {'entity_group': 'LABEL_0',
#   'score': 0.51958644,
#   'word': ' desejo',
#   'start': 2204,
#   'end': 2209},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6683582,
#   'word': ' suporte a execucao de testes automatizados em diferentes dispositivos e ambientes',
#   'start': 2211,
#   'end': 2291},
#  {'entity_group': 'LABEL_0',
#   'score': 0.56255436,
#   'word': ' .',
#   'start': 2292,
#   'end': 2292},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5986289,
#   'word': " ' ,",
#   'start': 2293,
#   'end': 2294},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5733284,
#   'word': " ' como testador",
#   'start': 2296,
#   'end': 2309},
#  {'entity_group': 'LABEL_1',
#   'score': 0.59394383,
#   'word': ' , preciso que a',
#   'start': 2310,
#   'end': 2324},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5196161,
#   'word': ' ferramenta dete',
#   'start': 2326,
#   'end': 2340},
#  {'entity_group': 'LABEL_1',
#   'score': 0.649535,
#   'word': 'cte automaticamente mudancas nos requisitos e ajuste os casos de teste correspondentes',
#   'start': 2340,
#   'end': 2426},
#  {'entity_group': 'LABEL_0',
#   'score': 0.53494245,
#   'word': ' .',
#   'start': 2427,
#   'end': 2427},
#  {'entity_group': 'LABEL_1',
#   'score': 0.609288,
#   'word': " ' ,",
#   'start': 2428,
#   'end': 2429},
#  {'entity_group': 'LABEL_0',
#   'score': 0.563247,
#   'word': " '",
#   'start': 2431,
#   'end': 2431},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5407963,
#   'word': ' como',
#   'start': 2432,
#   'end': 2435},
#  {'entity_group': 'LABEL_0',
#   'score': 0.56250703,
#   'word': ' testador',
#   'start': 2437,
#   'end': 2444},
#  {'entity_group': 'LABEL_1',
#   'score': 0.57889414,
#   'word': ' , quero integracao com',
#   'start': 2445,
#   'end': 2466},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5204687,
#   'word': ' sistemas',
#   'start': 2468,
#   'end': 2475},
#  {'entity_group': 'LABEL_1',
#   'score': 0.60466945,
#   'word': ' de controle de versao',
#   'start': 2477,
#   'end': 2497},
#  {'entity_group': 'LABEL_0',
#   'score': 0.54107857,
#   'word': ' para',
#   'start': 2499,
#   'end': 2502},
#  {'entity_group': 'LABEL_1',
#   'score': 0.63473976,
#   'word': ' rastrear mudancas nos requisitos e no',
#   'start': 2504,
#   'end': 2540}]

# %%
for i, historia_usuario in enumerate(historias_usuario):
    result = roberta(f"História de Usuário {i+1}: {historia_usuario}")
    print(f"Resultado para História de Usuário {i+1}: {result}")
# Out:
# Resultado para História de Usuário 1: [{'entity_group': 'LABEL_1', 'score': 0.51904917, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5335228, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.5448691, 'word': ' 1', 'start': 21, 'end': 21}, {'entity_group': 'LABEL_0', 'score': 0.6084487, 'word': ' :', 'start': 22, 'end': 22}, {'entity_group': 'LABEL_1', 'score': 0.5842597, 'word': ' como', 'start': 24, 'end': 27}, {'entity_group': 'LABEL_0', 'score': 0.55522317, 'word': ' testador', 'start': 29, 'end': 36}, {'entity_group': 'LABEL_1', 'score': 0.545236, 'word': ' eu quero um je', 'start': 38, 'end': 51}, {'entity_group': 'LABEL_0', 'score': 0.50281066, 'word': 'ito', 'start': 51, 'end': 54}, {'entity_group': 'LABEL_1', 'score': 0.58767265, 'word': ' mais facil de incluir os requisitos do aplicativo na ferramenta dr', 'start': 56, 'end': 121}, {'entity_group': 'LABEL_0', 'score': 0.544364, 'word': 'l - mob', 'start': 121, 'end': 126}, {'entity_group': 'LABEL_1', 'score': 0.61483777, 'word': 'test para criar casos de teste que cubram tudo que o aplicativo precisa fazer , sem ter que gastar', 'start': 126, 'end': 223}, {'entity_group': 'LABEL_0', 'score': 0.5005178, 'word': ' muito', 'start': 225, 'end': 229}, {'entity_group': 'LABEL_1', 'score': 0.605641, 'word': ' tempo escrevendo manualmente', 'start': 231, 'end': 258}, {'entity_group': 'LABEL_0', 'score': 0.62636817, 'word': ' .', 'start': 259, 'end': 259}]
# Resultado para História de Usuário 2: [{'entity_group': 'LABEL_1', 'score': 0.5093765, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.57855034, 'word': ' usuario 2 :', 'start': 13, 'end': 22}, {'entity_group': 'LABEL_1', 'score': 0.57974106, 'word': ' como', 'start': 24, 'end': 27}, {'entity_group': 'LABEL_0', 'score': 0.57685626, 'word': ' testador', 'start': 29, 'end': 36}, {'entity_group': 'LABEL_1', 'score': 0.55002224, 'word': ' eu quero uma', 'start': 38, 'end': 49}, {'entity_group': 'LABEL_0', 'score': 0.5258891, 'word': ' maneira', 'start': 51, 'end': 57}, {'entity_group': 'LABEL_1', 'score': 0.6003704, 'word': ' de ensinar a', 'start': 59, 'end': 70}, {'entity_group': 'LABEL_0', 'score': 0.5592702, 'word': ' ferramenta drl - mob', 'start': 72, 'end': 89}, {'entity_group': 'LABEL_1', 'score': 0.61108834, 'word': 'test a entender os requisitos do aplicativo usando nl', 'start': 89, 'end': 142}, {'entity_group': 'LABEL_0', 'score': 0.5431476, 'word': 'p', 'start': 142, 'end': 143}, {'entity_group': 'LABEL_1', 'score': 0.6309599, 'word': ' para fazer com que a ferramenta gere testes automaticamente', 'start': 145, 'end': 203}, {'entity_group': 'LABEL_0', 'score': 0.6379266, 'word': ' .', 'start': 204, 'end': 204}]
# Resultado para História de Usuário 3: [{'entity_group': 'LABEL_0', 'score': 0.56928307, 'word': ' historia de usuario 3 :', 'start': 0, 'end': 22}, {'entity_group': 'LABEL_1', 'score': 0.5844857, 'word': ' como', 'start': 24, 'end': 27}, {'entity_group': 'LABEL_0', 'score': 0.54051, 'word': ' testador eu', 'start': 29, 'end': 39}, {'entity_group': 'LABEL_1', 'score': 0.5548798, 'word': ' quero que a', 'start': 41, 'end': 51}, {'entity_group': 'LABEL_0', 'score': 0.5290622, 'word': ' ferramenta', 'start': 53, 'end': 62}, {'entity_group': 'LABEL_1', 'score': 0.6206833, 'word': ' gere casos de teste abrangentes', 'start': 64, 'end': 94}, {'entity_group': 'LABEL_0', 'score': 0.50466895, 'word': ' que', 'start': 96, 'end': 98}, {'entity_group': 'LABEL_1', 'score': 0.6294323, 'word': ' cubram integralmente todos os requisitos do aplica', 'start': 100, 'end': 149}, {'entity_group': 'LABEL_0', 'score': 0.52264863, 'word': 'tivo', 'start': 149, 'end': 153}, {'entity_group': 'LABEL_1', 'score': 0.63843596, 'word': ' , assegurando que o software seja completo', 'start': 154, 'end': 195}, {'entity_group': 'LABEL_0', 'score': 0.53950715, 'word': ' e', 'start': 197, 'end': 197}, {'entity_group': 'LABEL_1', 'score': 0.65305316, 'word': ' funcional , sem depender exclusivamente da criacao manual de casos de teste', 'start': 199, 'end': 272}, {'entity_group': 'LABEL_0', 'score': 0.5857382, 'word': ' .', 'start': 273, 'end': 273}]
# Resultado para História de Usuário 4: [{'entity_group': 'LABEL_0', 'score': 0.5057995, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_1', 'score': 0.5308536, 'word': ' de usuario', 'start': 10, 'end': 19}, {'entity_group': 'LABEL_0', 'score': 0.57292527, 'word': ' 4 :', 'start': 21, 'end': 22}, {'entity_group': 'LABEL_1', 'score': 0.55707103, 'word': ' como tes', 'start': 24, 'end': 31}, {'entity_group': 'LABEL_0', 'score': 0.5306409, 'word': 'tador', 'start': 31, 'end': 36}, {'entity_group': 'LABEL_1', 'score': 0.57390374, 'word': ' eu quero que a ferramenta seja integrada com', 'start': 38, 'end': 81}, {'entity_group': 'LABEL_0', 'score': 0.51058304, 'word': ' outras ferramentas', 'start': 83, 'end': 100}, {'entity_group': 'LABEL_1', 'score': 0.6363373, 'word': ' de gerenciamento , permitindo sincronizacao automatica dos requisitos e facilitando o processo de criacao de casos de testes', 'start': 102, 'end': 224}, {'entity_group': 'LABEL_0', 'score': 0.63000417, 'word': ' .', 'start': 225, 'end': 225}]
# Resultado para História de Usuário 5: [{'entity_group': 'LABEL_1', 'score': 0.53100586, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5754157, 'word': ' usuario 5 :', 'start': 13, 'end': 22}, {'entity_group': 'LABEL_1', 'score': 0.55547655, 'word': ' como tes', 'start': 24, 'end': 31}, {'entity_group': 'LABEL_0', 'score': 0.524323, 'word': 'tador eu', 'start': 31, 'end': 39}, {'entity_group': 'LABEL_1', 'score': 0.61340284, 'word': ' quero que a ferramenta forneca o recurso de criacao de relatorios detalhados sobre a cobertura dos', 'start': 41, 'end': 139}, {'entity_group': 'LABEL_0', 'score': 0.5199107, 'word': ' testes', 'start': 141, 'end': 146}, {'entity_group': 'LABEL_1', 'score': 0.64739966, 'word': ' , permitindo uma analise precisa sobre sua progressao e identificacao das', 'start': 147, 'end': 219}, {'entity_group': 'LABEL_0', 'score': 0.5507474, 'word': ' lacunas', 'start': 221, 'end': 227}, {'entity_group': 'LABEL_1', 'score': 0.5785915, 'word': ' durante sua execucao .', 'start': 229, 'end': 249}]
# Resultado para História de Usuário 6: [{'entity_group': 'LABEL_0', 'score': 0.55542797, 'word': ' historia de usuario 6 :', 'start': 0, 'end': 22}, {'entity_group': 'LABEL_1', 'score': 0.5119121, 'word': ' como tes', 'start': 24, 'end': 31}, {'entity_group': 'LABEL_0', 'score': 0.5505011, 'word': 'tador ,', 'start': 31, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.5723332, 'word': ' quero uma maneira mais facil de incluir requisitos do', 'start': 39, 'end': 91}, {'entity_group': 'LABEL_0', 'score': 0.52794635, 'word': ' aplicativo', 'start': 93, 'end': 102}, {'entity_group': 'LABEL_1', 'score': 0.6279744, 'word': ' para criar casos de', 'start': 104, 'end': 122}, {'entity_group': 'LABEL_0', 'score': 0.52053535, 'word': ' teste', 'start': 124, 'end': 128}, {'entity_group': 'LABEL_1', 'score': 0.6334901, 'word': ' abrangentes , economizando tempo na escrita manual', 'start': 130, 'end': 178}, {'entity_group': 'LABEL_0', 'score': 0.5923316, 'word': ' .', 'start': 179, 'end': 179}]
# Resultado para História de Usuário 7: [{'entity_group': 'LABEL_1', 'score': 0.5302811, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5383612, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.54891723, 'word': ' 7', 'start': 21, 'end': 21}, {'entity_group': 'LABEL_0', 'score': 0.6138931, 'word': ' :', 'start': 22, 'end': 22}, {'entity_group': 'LABEL_1', 'score': 0.5310265, 'word': ' como tes', 'start': 24, 'end': 31}, {'entity_group': 'LABEL_0', 'score': 0.5379196, 'word': 'tador ,', 'start': 31, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.59743863, 'word': ' desejo ensinar a ferramenta a entender os requisitos do aplica', 'start': 39, 'end': 100}, {'entity_group': 'LABEL_0', 'score': 0.5294247, 'word': 'tivo', 'start': 100, 'end': 104}, {'entity_group': 'LABEL_1', 'score': 0.5946543, 'word': ' usando nl', 'start': 106, 'end': 114}, {'entity_group': 'LABEL_0', 'score': 0.59407383, 'word': 'p', 'start': 114, 'end': 115}, {'entity_group': 'LABEL_1', 'score': 0.65661615, 'word': ' para gerar testes automaticamente', 'start': 117, 'end': 149}, {'entity_group': 'LABEL_0', 'score': 0.6426786, 'word': ' .', 'start': 150, 'end': 150}]
# Resultado para História de Usuário 8: [{'entity_group': 'LABEL_0', 'score': 0.5036706, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_1', 'score': 0.5131888, 'word': ' de', 'start': 10, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.54312164, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.5303482, 'word': ' 8', 'start': 21, 'end': 21}, {'entity_group': 'LABEL_0', 'score': 0.6451339, 'word': ' :', 'start': 22, 'end': 22}, {'entity_group': 'LABEL_1', 'score': 0.5416988, 'word': ' como tes', 'start': 24, 'end': 31}, {'entity_group': 'LABEL_0', 'score': 0.5282619, 'word': 'tador , preciso', 'start': 31, 'end': 45}, {'entity_group': 'LABEL_1', 'score': 0.621879, 'word': ' que a ferramenta gere casos de teste completos', 'start': 47, 'end': 92}, {'entity_group': 'LABEL_0', 'score': 0.54061955, 'word': ' e', 'start': 94, 'end': 94}, {'entity_group': 'LABEL_1', 'score': 0.6209488, 'word': ' funcionais que cubram todos os requisitos do aplica', 'start': 96, 'end': 146}, {'entity_group': 'LABEL_0', 'score': 0.54083604, 'word': 'tivo .', 'start': 146, 'end': 151}]
# Resultado para História de Usuário 9: [{'entity_group': 'LABEL_0', 'score': 0.50344586, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_1', 'score': 0.5467515, 'word': ' de usuario 9', 'start': 10, 'end': 21}, {'entity_group': 'LABEL_0', 'score': 0.56816506, 'word': ' : como', 'start': 22, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.53307873, 'word': ' tes', 'start': 29, 'end': 31}, {'entity_group': 'LABEL_0', 'score': 0.5588669, 'word': 'tador', 'start': 31, 'end': 36}, {'entity_group': 'LABEL_1', 'score': 0.5268872, 'word': ' , quero integracao', 'start': 37, 'end': 54}, {'entity_group': 'LABEL_0', 'score': 0.5060462, 'word': ' com outras ferramentas', 'start': 56, 'end': 77}, {'entity_group': 'LABEL_1', 'score': 0.5367407, 'word': ' de gerenciamento', 'start': 79, 'end': 94}, {'entity_group': 'LABEL_0', 'score': 0.5694963, 'word': ' para', 'start': 96, 'end': 99}, {'entity_group': 'LABEL_1', 'score': 0.6323845, 'word': ' sincronizar automaticamente requisitos e facilitar a criacao de casos de teste', 'start': 101, 'end': 178}, {'entity_group': 'LABEL_0', 'score': 0.51322246, 'word': ' .', 'start': 179, 'end': 179}]
# Resultado para História de Usuário 10: [{'entity_group': 'LABEL_1', 'score': 0.5706612, 'word': ' historia de usuario 10', 'start': 0, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.6226908, 'word': ' :', 'start': 23, 'end': 23}, {'entity_group': 'LABEL_1', 'score': 0.54377186, 'word': ' como tes', 'start': 25, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.5576907, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.6318027, 'word': ' , quero relatorios detalhados sobre a cobertura dos', 'start': 38, 'end': 88}, {'entity_group': 'LABEL_0', 'score': 0.5147033, 'word': ' testes', 'start': 90, 'end': 95}, {'entity_group': 'LABEL_1', 'score': 0.5884984, 'word': ' para analise precisa durante a execucao .', 'start': 97, 'end': 136}]
# Resultado para História de Usuário 11: [{'entity_group': 'LABEL_1', 'score': 0.55272937, 'word': ' historia de usuario 11', 'start': 0, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.6344656, 'word': ' :', 'start': 23, 'end': 23}, {'entity_group': 'LABEL_1', 'score': 0.5394635, 'word': ' como tes', 'start': 25, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.50843865, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.62419856, 'word': ' , desejo que a ferramenta identifique automaticamente os casos de', 'start': 38, 'end': 102}, {'entity_group': 'LABEL_0', 'score': 0.5117843, 'word': ' teste', 'start': 104, 'end': 108}, {'entity_group': 'LABEL_1', 'score': 0.5304744, 'word': ' mais criticos', 'start': 110, 'end': 122}, {'entity_group': 'LABEL_0', 'score': 0.51614964, 'word': ' para priori', 'start': 124, 'end': 134}, {'entity_group': 'LABEL_1', 'score': 0.7034321, 'word': 'zar a analise', 'start': 134, 'end': 147}, {'entity_group': 'LABEL_0', 'score': 0.5638571, 'word': ' .', 'start': 148, 'end': 148}]
# Resultado para História de Usuário 12: [{'entity_group': 'LABEL_1', 'score': 0.5447738, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5705868, 'word': ' usuario 12 :', 'start': 13, 'end': 23}, {'entity_group': 'LABEL_1', 'score': 0.54173744, 'word': ' como tes', 'start': 25, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.5033195, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.51872486, 'word': ' ,', 'start': 38, 'end': 38}, {'entity_group': 'LABEL_0', 'score': 0.5098438, 'word': ' preciso', 'start': 40, 'end': 46}, {'entity_group': 'LABEL_1', 'score': 0.6515061, 'word': ' que a ferramenta sugira casos de teste com base em padroes de uso real do aplica', 'start': 48, 'end': 127}, {'entity_group': 'LABEL_0', 'score': 0.5575065, 'word': 'tivo .', 'start': 127, 'end': 132}]
# Resultado para História de Usuário 13: [{'entity_group': 'LABEL_0', 'score': 0.5656154, 'word': ' historia de usuario 13 : como', 'start': 0, 'end': 28}, {'entity_group': 'LABEL_1', 'score': 0.5141586, 'word': ' tes', 'start': 30, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.5383156, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.54688615, 'word': ' , quero', 'start': 38, 'end': 44}, {'entity_group': 'LABEL_0', 'score': 0.5288302, 'word': ' sugestoes', 'start': 46, 'end': 54}, {'entity_group': 'LABEL_1', 'score': 0.61410904, 'word': ' com base em', 'start': 56, 'end': 66}, {'entity_group': 'LABEL_0', 'score': 0.51693904, 'word': ' padroes', 'start': 68, 'end': 74}, {'entity_group': 'LABEL_1', 'score': 0.5141762, 'word': ' de', 'start': 76, 'end': 77}, {'entity_group': 'LABEL_0', 'score': 0.5538191, 'word': ' falha historicos para', 'start': 79, 'end': 99}, {'entity_group': 'LABEL_1', 'score': 0.5873989, 'word': ' evitar problemas recorrentes no software', 'start': 101, 'end': 140}, {'entity_group': 'LABEL_0', 'score': 0.53769743, 'word': ' .', 'start': 141, 'end': 141}]
# Resultado para História de Usuário 14: [{'entity_group': 'LABEL_1', 'score': 0.5274246, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.63083816, 'word': ' usuario 14 :', 'start': 13, 'end': 23}, {'entity_group': 'LABEL_1', 'score': 0.5415804, 'word': ' como tes', 'start': 25, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.52787673, 'word': 'tador ,', 'start': 32, 'end': 38}, {'entity_group': 'LABEL_1', 'score': 0.61941093, 'word': ' desejo suporte a execucao de testes automatizados em diferentes', 'start': 40, 'end': 102}, {'entity_group': 'LABEL_0', 'score': 0.51066804, 'word': ' dispositivos', 'start': 104, 'end': 115}, {'entity_group': 'LABEL_1', 'score': 0.6296479, 'word': ' e ambientes', 'start': 117, 'end': 127}, {'entity_group': 'LABEL_0', 'score': 0.5930812, 'word': ' .', 'start': 128, 'end': 128}]
# Resultado para História de Usuário 15: [{'entity_group': 'LABEL_0', 'score': 0.5012943, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_1', 'score': 0.52408713, 'word': ' de', 'start': 10, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5776067, 'word': ' usuario 15 :', 'start': 13, 'end': 23}, {'entity_group': 'LABEL_1', 'score': 0.5755209, 'word': ' como tes', 'start': 25, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.51261127, 'word': 'tador , preciso', 'start': 32, 'end': 46}, {'entity_group': 'LABEL_1', 'score': 0.654052, 'word': ' que a ferramenta detecte automaticamente mudancas nos requisitos e ajuste os casos de teste correspondentes', 'start': 48, 'end': 154}, {'entity_group': 'LABEL_0', 'score': 0.57844836, 'word': ' .', 'start': 155, 'end': 155}]
# Resultado para História de Usuário 16: [{'entity_group': 'LABEL_1', 'score': 0.5495475, 'word': ' historia de usuario 16', 'start': 0, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.5709566, 'word': ' : como', 'start': 23, 'end': 28}, {'entity_group': 'LABEL_1', 'score': 0.54990244, 'word': ' tes', 'start': 30, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.5327755, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.55494606, 'word': ' , quero integracao com', 'start': 38, 'end': 59}, {'entity_group': 'LABEL_0', 'score': 0.52072895, 'word': ' sistemas', 'start': 61, 'end': 68}, {'entity_group': 'LABEL_1', 'score': 0.5474357, 'word': ' de controle de versao', 'start': 70, 'end': 90}, {'entity_group': 'LABEL_0', 'score': 0.52286255, 'word': ' para rastre', 'start': 92, 'end': 102}, {'entity_group': 'LABEL_1', 'score': 0.60223144, 'word': 'ar mudancas nos requisitos e no codigo - fonte', 'start': 102, 'end': 146}, {'entity_group': 'LABEL_0', 'score': 0.63703424, 'word': ' .', 'start': 147, 'end': 147}]
# Resultado para História de Usuário 17: [{'entity_group': 'LABEL_1', 'score': 0.53179264, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5640405, 'word': ' usuario 17 :', 'start': 13, 'end': 23}, {'entity_group': 'LABEL_1', 'score': 0.53183734, 'word': ' como tes', 'start': 25, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.540857, 'word': 'tador , desejo', 'start': 32, 'end': 45}, {'entity_group': 'LABEL_1', 'score': 0.5848775, 'word': ' metricas detalhadas sobre a eficacia dos', 'start': 47, 'end': 86}, {'entity_group': 'LABEL_0', 'score': 0.5132979, 'word': ' testes', 'start': 88, 'end': 93}, {'entity_group': 'LABEL_1', 'score': 0.62478703, 'word': ' ,', 'start': 94, 'end': 94}, {'entity_group': 'LABEL_0', 'score': 0.5095931, 'word': ' incluindo', 'start': 96, 'end': 104}, {'entity_group': 'LABEL_1', 'score': 0.57690394, 'word': ' taxa de cobertura e taxa de falha', 'start': 106, 'end': 138}, {'entity_group': 'LABEL_0', 'score': 0.52175, 'word': ' .', 'start': 139, 'end': 139}]
# Resultado para História de Usuário 18: [{'entity_group': 'LABEL_1', 'score': 0.5111202, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5381937, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.52659655, 'word': ' 18', 'start': 21, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.5917946, 'word': ' :', 'start': 23, 'end': 23}, {'entity_group': 'LABEL_1', 'score': 0.53662777, 'word': ' como tes', 'start': 25, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.5656156, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.54163694, 'word': ' ,', 'start': 38, 'end': 38}, {'entity_group': 'LABEL_0', 'score': 0.5237402, 'word': ' preciso', 'start': 40, 'end': 46}, {'entity_group': 'LABEL_1', 'score': 0.59891737, 'word': ' de suporte a execucao de', 'start': 48, 'end': 71}, {'entity_group': 'LABEL_0', 'score': 0.5233364, 'word': ' testes', 'start': 73, 'end': 78}, {'entity_group': 'LABEL_1', 'score': 0.61286163, 'word': ' de desempenho e escalabilidade', 'start': 80, 'end': 109}, {'entity_group': 'LABEL_0', 'score': 0.55028176, 'word': ' .', 'start': 110, 'end': 110}]
# Resultado para História de Usuário 19: [{'entity_group': 'LABEL_1', 'score': 0.5584976, 'word': ' historia de usuario 19', 'start': 0, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.5905307, 'word': ' :', 'start': 23, 'end': 23}, {'entity_group': 'LABEL_1', 'score': 0.53708243, 'word': ' como tes', 'start': 25, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.5480414, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.62641186, 'word': ' , quero analise automatica dos resultados dos testes para relatorios detalhados sobre', 'start': 38, 'end': 122}, {'entity_group': 'LABEL_0', 'score': 0.5079771, 'word': ' problemas', 'start': 124, 'end': 132}, {'entity_group': 'LABEL_1', 'score': 0.5373341, 'word': ' encontrados .', 'start': 134, 'end': 145}]
# Resultado para História de Usuário 20: [{'entity_group': 'LABEL_1', 'score': 0.5675316, 'word': ' historia de usuario 20', 'start': 0, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.6419315, 'word': ' :', 'start': 23, 'end': 23}, {'entity_group': 'LABEL_1', 'score': 0.5663077, 'word': ' como testador', 'start': 25, 'end': 37}, {'entity_group': 'LABEL_0', 'score': 0.5061321, 'word': ' ,', 'start': 38, 'end': 38}, {'entity_group': 'LABEL_1', 'score': 0.61728233, 'word': ' desejo simular cenarios de teste complexos', 'start': 40, 'end': 81}, {'entity_group': 'LABEL_0', 'score': 0.5701692, 'word': ' e', 'start': 83, 'end': 83}, {'entity_group': 'LABEL_1', 'score': 0.55997074, 'word': ' realistas', 'start': 85, 'end': 93}, {'entity_group': 'LABEL_0', 'score': 0.50039846, 'word': ' para', 'start': 95, 'end': 98}, {'entity_group': 'LABEL_1', 'score': 0.6587671, 'word': ' garantir testes proximos a realidade', 'start': 100, 'end': 135}, {'entity_group': 'LABEL_0', 'score': 0.5550468, 'word': ' .', 'start': 136, 'end': 136}]
# Resultado para História de Usuário 21: [{'entity_group': 'LABEL_1', 'score': 0.5785555, 'word': ' historia de usuario 21', 'start': 0, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.578916, 'word': ' :', 'start': 23, 'end': 23}, {'entity_group': 'LABEL_1', 'score': 0.5346135, 'word': ' como testador ,', 'start': 25, 'end': 38}, {'entity_group': 'LABEL_0', 'score': 0.52667534, 'word': ' preciso', 'start': 40, 'end': 46}, {'entity_group': 'LABEL_1', 'score': 0.57406074, 'word': ' de suporte a execucao de testes de regressao automatizados', 'start': 48, 'end': 105}, {'entity_group': 'LABEL_0', 'score': 0.6573393, 'word': ' .', 'start': 106, 'end': 106}]
# Resultado para História de Usuário 22: [{'entity_group': 'LABEL_1', 'score': 0.54910356, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5152233, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.5392832, 'word': ' 22', 'start': 21, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.62177646, 'word': ' :', 'start': 23, 'end': 23}, {'entity_group': 'LABEL_1', 'score': 0.5350834, 'word': ' como tes', 'start': 25, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.54891944, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.64279455, 'word': ' , quero identificacao automatica de casos de', 'start': 38, 'end': 81}, {'entity_group': 'LABEL_0', 'score': 0.5155198, 'word': ' teste', 'start': 83, 'end': 87}, {'entity_group': 'LABEL_1', 'score': 0.51971775, 'word': ' redunda', 'start': 89, 'end': 95}, {'entity_group': 'LABEL_0', 'score': 0.535564, 'word': 'ntes', 'start': 95, 'end': 99}, {'entity_group': 'LABEL_1', 'score': 0.5976802, 'word': ' ou', 'start': 101, 'end': 102}, {'entity_group': 'LABEL_0', 'score': 0.54387164, 'word': ' desnecessarios .', 'start': 104, 'end': 118}]
# Resultado para História de Usuário 23: [{'entity_group': 'LABEL_0', 'score': 0.56187314, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_1', 'score': 0.5317177, 'word': ' de', 'start': 10, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5011867, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.63208526, 'word': ' 23', 'start': 21, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.61039037, 'word': ' :', 'start': 23, 'end': 23}, {'entity_group': 'LABEL_1', 'score': 0.5278454, 'word': ' como', 'start': 25, 'end': 28}, {'entity_group': 'LABEL_0', 'score': 0.5288613, 'word': ' testador ,', 'start': 30, 'end': 38}, {'entity_group': 'LABEL_1', 'score': 0.54709256, 'word': ' desejo integracao facil com ferramentas', 'start': 40, 'end': 78}, {'entity_group': 'LABEL_0', 'score': 0.5245663, 'word': ' de', 'start': 80, 'end': 81}, {'entity_group': 'LABEL_1', 'score': 0.6188116, 'word': ' gerenciamento de', 'start': 83, 'end': 98}, {'entity_group': 'LABEL_0', 'score': 0.6213833, 'word': ' projetos .', 'start': 100, 'end': 108}]
# Resultado para História de Usuário 24: [{'entity_group': 'LABEL_1', 'score': 0.5387628, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.50066036, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.524171, 'word': ' 24', 'start': 21, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.61785686, 'word': ' :', 'start': 23, 'end': 23}, {'entity_group': 'LABEL_1', 'score': 0.5518682, 'word': ' como tes', 'start': 25, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.5443497, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.53511286, 'word': ' ,', 'start': 38, 'end': 38}, {'entity_group': 'LABEL_0', 'score': 0.5192793, 'word': ' preciso de', 'start': 40, 'end': 49}, {'entity_group': 'LABEL_1', 'score': 0.60311437, 'word': ' suporte a execucao de', 'start': 51, 'end': 71}, {'entity_group': 'LABEL_0', 'score': 0.52778727, 'word': ' testes', 'start': 73, 'end': 78}, {'entity_group': 'LABEL_1', 'score': 0.5590928, 'word': ' de usabilidade', 'start': 80, 'end': 93}, {'entity_group': 'LABEL_0', 'score': 0.609756, 'word': ' .', 'start': 94, 'end': 94}]
# Resultado para História de Usuário 25: [{'entity_group': 'LABEL_1', 'score': 0.5422801, 'word': ' historia de usuario 25', 'start': 0, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.6131498, 'word': ' :', 'start': 23, 'end': 23}, {'entity_group': 'LABEL_1', 'score': 0.5487795, 'word': ' como tes', 'start': 25, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.52162546, 'word': 'tador ,', 'start': 32, 'end': 38}, {'entity_group': 'LABEL_1', 'score': 0.6394982, 'word': ' quero que a ferramenta crie automaticamente conjuntos de dados de', 'start': 40, 'end': 104}, {'entity_group': 'LABEL_0', 'score': 0.5064807, 'word': ' teste', 'start': 106, 'end': 110}, {'entity_group': 'LABEL_1', 'score': 0.5865553, 'word': ' realistas', 'start': 112, 'end': 120}, {'entity_group': 'LABEL_0', 'score': 0.51184475, 'word': ' .', 'start': 121, 'end': 121}]
# Resultado para História de Usuário 26: [{'entity_group': 'LABEL_1', 'score': 0.5669135, 'word': ' historia de usuario 26', 'start': 0, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.5990939, 'word': ' :', 'start': 23, 'end': 23}, {'entity_group': 'LABEL_1', 'score': 0.5446154, 'word': ' como tes', 'start': 25, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.5267559, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.54477596, 'word': ' , desejo integracao com ferramentas', 'start': 38, 'end': 72}, {'entity_group': 'LABEL_0', 'score': 0.51481736, 'word': ' de', 'start': 74, 'end': 75}, {'entity_group': 'LABEL_1', 'score': 0.60225904, 'word': ' monitoramento de desempenho em tempo real', 'start': 77, 'end': 117}, {'entity_group': 'LABEL_0', 'score': 0.5782407, 'word': ' .', 'start': 118, 'end': 118}]
# Resultado para História de Usuário 27: [{'entity_group': 'LABEL_1', 'score': 0.532277, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5489477, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.5829125, 'word': ' 27', 'start': 21, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.58894503, 'word': ' :', 'start': 23, 'end': 23}, {'entity_group': 'LABEL_1', 'score': 0.55228776, 'word': ' como', 'start': 25, 'end': 28}, {'entity_group': 'LABEL_0', 'score': 0.5388624, 'word': ' testador', 'start': 30, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.5193306, 'word': ' ,', 'start': 38, 'end': 38}, {'entity_group': 'LABEL_0', 'score': 0.539169, 'word': ' preciso', 'start': 40, 'end': 46}, {'entity_group': 'LABEL_1', 'score': 0.56791425, 'word': ' de suporte a execucao de', 'start': 48, 'end': 71}, {'entity_group': 'LABEL_0', 'score': 0.55011576, 'word': ' testes de localizacao', 'start': 73, 'end': 93}, {'entity_group': 'LABEL_1', 'score': 0.559294, 'word': ' e internacionalizacao', 'start': 95, 'end': 115}, {'entity_group': 'LABEL_0', 'score': 0.548094, 'word': ' .', 'start': 116, 'end': 116}]
# Resultado para História de Usuário 28: [{'entity_group': 'LABEL_1', 'score': 0.5872482, 'word': ' historia de usuario 28', 'start': 0, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.5947578, 'word': ' :', 'start': 23, 'end': 23}, {'entity_group': 'LABEL_1', 'score': 0.53824925, 'word': ' como tes', 'start': 25, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.52320415, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.6040226, 'word': ' , quero geracao automatica de dados de teste sinteticos .', 'start': 38, 'end': 93}]
# Resultado para História de Usuário 29: [{'entity_group': 'LABEL_0', 'score': 0.51178193, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_1', 'score': 0.54881, 'word': ' de', 'start': 10, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.51115537, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.6149746, 'word': ' 29', 'start': 21, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.61681193, 'word': ' :', 'start': 23, 'end': 23}, {'entity_group': 'LABEL_1', 'score': 0.5008517, 'word': ' como', 'start': 25, 'end': 28}, {'entity_group': 'LABEL_0', 'score': 0.5365984, 'word': ' testador ,', 'start': 30, 'end': 38}, {'entity_group': 'LABEL_1', 'score': 0.53990644, 'word': ' desejo suporte a execucao de', 'start': 40, 'end': 67}, {'entity_group': 'LABEL_0', 'score': 0.55424905, 'word': ' testes', 'start': 69, 'end': 74}, {'entity_group': 'LABEL_1', 'score': 0.517989, 'word': ' de acessibilidade', 'start': 76, 'end': 92}, {'entity_group': 'LABEL_0', 'score': 0.64895344, 'word': ' .', 'start': 93, 'end': 93}]
# Resultado para História de Usuário 30: [{'entity_group': 'LABEL_0', 'score': 0.51669276, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_1', 'score': 0.50545853, 'word': ' de', 'start': 10, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.59461737, 'word': ' usuario 30 :', 'start': 13, 'end': 23}, {'entity_group': 'LABEL_1', 'score': 0.5408634, 'word': ' como tes', 'start': 25, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.56267965, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.5128556, 'word': ' ,', 'start': 38, 'end': 38}, {'entity_group': 'LABEL_0', 'score': 0.5348966, 'word': ' preciso', 'start': 40, 'end': 46}, {'entity_group': 'LABEL_1', 'score': 0.55562943, 'word': ' de suporte a execucao de', 'start': 48, 'end': 71}, {'entity_group': 'LABEL_0', 'score': 0.5451309, 'word': ' testes de', 'start': 73, 'end': 81}, {'entity_group': 'LABEL_1', 'score': 0.5943719, 'word': ' integracao continua', 'start': 83, 'end': 101}, {'entity_group': 'LABEL_0', 'score': 0.6477594, 'word': ' .', 'start': 102, 'end': 102}]
# Resultado para História de Usuário 31: [{'entity_group': 'LABEL_1', 'score': 0.5638258, 'word': ' historia de usuario', 'start': 0, 'end': 19}, {'entity_group': 'LABEL_0', 'score': 0.57544184, 'word': ' 31 :', 'start': 21, 'end': 23}, {'entity_group': 'LABEL_1', 'score': 0.523545, 'word': ' como tes', 'start': 25, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.5600368, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.6686282, 'word': ' , quero identificacao automatica de casos de', 'start': 38, 'end': 81}, {'entity_group': 'LABEL_0', 'score': 0.5136949, 'word': ' teste incompletos', 'start': 83, 'end': 99}, {'entity_group': 'LABEL_1', 'score': 0.62156487, 'word': ' ou', 'start': 101, 'end': 102}, {'entity_group': 'LABEL_0', 'score': 0.6126899, 'word': ' mal', 'start': 104, 'end': 106}, {'entity_group': 'LABEL_1', 'score': 0.5992293, 'word': ' definidos', 'start': 108, 'end': 116}, {'entity_group': 'LABEL_0', 'score': 0.5311817, 'word': ' .', 'start': 117, 'end': 117}]
# Resultado para História de Usuário 32: [{'entity_group': 'LABEL_0', 'score': 0.5279253, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_1', 'score': 0.53540945, 'word': ' de usuario', 'start': 10, 'end': 19}, {'entity_group': 'LABEL_0', 'score': 0.5841675, 'word': ' 32 :', 'start': 21, 'end': 23}, {'entity_group': 'LABEL_1', 'score': 0.5469128, 'word': ' como tes', 'start': 25, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.5265976, 'word': 'tador ,', 'start': 32, 'end': 38}, {'entity_group': 'LABEL_1', 'score': 0.5946716, 'word': ' desejo identificacao automatica de dependencias entre casos de', 'start': 40, 'end': 101}, {'entity_group': 'LABEL_0', 'score': 0.62521446, 'word': ' teste .', 'start': 103, 'end': 108}]
# Resultado para História de Usuário 33: [{'entity_group': 'LABEL_1', 'score': 0.52761424, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.59163576, 'word': ' usuario 33 :', 'start': 13, 'end': 23}, {'entity_group': 'LABEL_1', 'score': 0.5269476, 'word': ' como tes', 'start': 25, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.54706556, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.5270326, 'word': ' ,', 'start': 38, 'end': 38}, {'entity_group': 'LABEL_0', 'score': 0.52640337, 'word': ' preciso', 'start': 40, 'end': 46}, {'entity_group': 'LABEL_1', 'score': 0.5832463, 'word': ' de suporte a execucao de', 'start': 48, 'end': 71}, {'entity_group': 'LABEL_0', 'score': 0.52510434, 'word': ' testes de', 'start': 73, 'end': 81}, {'entity_group': 'LABEL_1', 'score': 0.5899716, 'word': ' recuperacao de desastres', 'start': 83, 'end': 106}, {'entity_group': 'LABEL_0', 'score': 0.62558573, 'word': ' .', 'start': 107, 'end': 107}]
# Resultado para História de Usuário 34: [{'entity_group': 'LABEL_0', 'score': 0.5005843, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_1', 'score': 0.54344416, 'word': ' de usuario', 'start': 10, 'end': 19}, {'entity_group': 'LABEL_0', 'score': 0.6754068, 'word': ' 34 :', 'start': 21, 'end': 23}, {'entity_group': 'LABEL_1', 'score': 0.5498817, 'word': ' como tes', 'start': 25, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.54758906, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.6406171, 'word': ' , quero que a ferramenta identifique automaticamente casos de teste paralelizaveis', 'start': 38, 'end': 119}, {'entity_group': 'LABEL_0', 'score': 0.54093945, 'word': ' .', 'start': 120, 'end': 120}]
# Resultado para História de Usuário 35: [{'entity_group': 'LABEL_1', 'score': 0.5451626, 'word': ' historia de usuario', 'start': 0, 'end': 19}, {'entity_group': 'LABEL_0', 'score': 0.6341189, 'word': ' 35 :', 'start': 21, 'end': 23}, {'entity_group': 'LABEL_1', 'score': 0.56834227, 'word': ' como testador', 'start': 25, 'end': 37}, {'entity_group': 'LABEL_0', 'score': 0.5029399, 'word': ' ,', 'start': 38, 'end': 38}, {'entity_group': 'LABEL_1', 'score': 0.54877824, 'word': ' desejo simulacao de cenarios de teste de', 'start': 40, 'end': 79}, {'entity_group': 'LABEL_0', 'score': 0.51456624, 'word': ' carga', 'start': 81, 'end': 85}, {'entity_group': 'LABEL_1', 'score': 0.541133, 'word': ' extremamente', 'start': 87, 'end': 98}, {'entity_group': 'LABEL_0', 'score': 0.57978237, 'word': ' alta .', 'start': 100, 'end': 104}]
# Resultado para História de Usuário 36: [{'entity_group': 'LABEL_0', 'score': 0.57492834, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_1', 'score': 0.5106143, 'word': ' de', 'start': 10, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.6105364, 'word': ' usuario 36 :', 'start': 13, 'end': 23}, {'entity_group': 'LABEL_1', 'score': 0.5435516, 'word': ' como tes', 'start': 25, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.54921997, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.55821586, 'word': ' ,', 'start': 38, 'end': 38}, {'entity_group': 'LABEL_0', 'score': 0.50623304, 'word': ' preciso', 'start': 40, 'end': 46}, {'entity_group': 'LABEL_1', 'score': 0.5956596, 'word': ' de suporte a execucao de', 'start': 48, 'end': 71}, {'entity_group': 'LABEL_0', 'score': 0.55062634, 'word': ' testes', 'start': 73, 'end': 78}, {'entity_group': 'LABEL_1', 'score': 0.5842124, 'word': ' de compatibilidade com diferentes navegadores e', 'start': 80, 'end': 126}, {'entity_group': 'LABEL_0', 'score': 0.5700903, 'word': ' dispositivos .', 'start': 128, 'end': 140}]
# Resultado para História de Usuário 37: [{'entity_group': 'LABEL_0', 'score': 0.54062146, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_1', 'score': 0.5292193, 'word': ' de', 'start': 10, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.58434963, 'word': ' usuario 37 :', 'start': 13, 'end': 23}, {'entity_group': 'LABEL_1', 'score': 0.53728235, 'word': ' como tes', 'start': 25, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.56905776, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.60981274, 'word': ' , quero geracao automatica de relatorios de', 'start': 38, 'end': 80}, {'entity_group': 'LABEL_0', 'score': 0.5438322, 'word': ' teste', 'start': 82, 'end': 86}, {'entity_group': 'LABEL_1', 'score': 0.6624997, 'word': ' personalizados', 'start': 88, 'end': 101}, {'entity_group': 'LABEL_0', 'score': 0.53514975, 'word': ' .', 'start': 102, 'end': 102}]
# Resultado para História de Usuário 38: [{'entity_group': 'LABEL_0', 'score': 0.50233203, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_1', 'score': 0.5709728, 'word': ' de usuario', 'start': 10, 'end': 19}, {'entity_group': 'LABEL_0', 'score': 0.5659534, 'word': ' 38 :', 'start': 21, 'end': 23}, {'entity_group': 'LABEL_1', 'score': 0.62729645, 'word': ' como testador , desejo rastreamento automatico de resultados de teste ao longo do tempo', 'start': 25, 'end': 110}, {'entity_group': 'LABEL_0', 'score': 0.5643804, 'word': ' .', 'start': 111, 'end': 111}]
# Resultado para História de Usuário 39: [{'entity_group': 'LABEL_1', 'score': 0.5344327, 'word': ' historia de usuario', 'start': 0, 'end': 19}, {'entity_group': 'LABEL_0', 'score': 0.64027333, 'word': ' 39 :', 'start': 21, 'end': 23}, {'entity_group': 'LABEL_1', 'score': 0.5223192, 'word': ' como tes', 'start': 25, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.5225668, 'word': 'tador , preciso de', 'start': 32, 'end': 49}, {'entity_group': 'LABEL_1', 'score': 0.5807501, 'word': ' suporte a execucao de', 'start': 51, 'end': 71}, {'entity_group': 'LABEL_0', 'score': 0.5123744, 'word': ' testes', 'start': 73, 'end': 78}, {'entity_group': 'LABEL_1', 'score': 0.55159247, 'word': ' de regressao progressiva', 'start': 80, 'end': 103}, {'entity_group': 'LABEL_0', 'score': 0.6646963, 'word': ' .', 'start': 104, 'end': 104}]
# Resultado para História de Usuário 40: [{'entity_group': 'LABEL_0', 'score': 0.58587736, 'word': ' historia de usuario 40 :', 'start': 0, 'end': 23}, {'entity_group': 'LABEL_1', 'score': 0.5282266, 'word': ' como tes', 'start': 25, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.54453, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.5568408, 'word': ' , quero sugestoes', 'start': 38, 'end': 54}, {'entity_group': 'LABEL_0', 'score': 0.5304364, 'word': ' automaticas para', 'start': 56, 'end': 71}, {'entity_group': 'LABEL_1', 'score': 0.65592694, 'word': ' aprimorar os casos de', 'start': 73, 'end': 93}, {'entity_group': 'LABEL_0', 'score': 0.5488848, 'word': ' teste', 'start': 95, 'end': 99}, {'entity_group': 'LABEL_1', 'score': 0.51314557, 'word': ' existentes', 'start': 101, 'end': 110}, {'entity_group': 'LABEL_0', 'score': 0.5392235, 'word': ' .', 'start': 111, 'end': 111}]
# Resultado para História de Usuário 41: [{'entity_group': 'LABEL_1', 'score': 0.5229728, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5299953, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.5109299, 'word': ' 41', 'start': 21, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.6346968, 'word': ' :', 'start': 23, 'end': 23}, {'entity_group': 'LABEL_1', 'score': 0.54541194, 'word': ' como tes', 'start': 25, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.5550213, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.61012614, 'word': ' , desejo que a ferramenta aprenda com os resultados dos', 'start': 38, 'end': 92}, {'entity_group': 'LABEL_0', 'score': 0.5422346, 'word': ' testes', 'start': 94, 'end': 99}, {'entity_group': 'LABEL_1', 'score': 0.6425782, 'word': ' e melhore suas sugestoes futuras', 'start': 101, 'end': 132}, {'entity_group': 'LABEL_0', 'score': 0.5156323, 'word': ' .', 'start': 133, 'end': 133}]
# Resultado para História de Usuário 42: [{'entity_group': 'LABEL_1', 'score': 0.5454009, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.58396935, 'word': ' usuario 42 :', 'start': 13, 'end': 23}, {'entity_group': 'LABEL_1', 'score': 0.54478776, 'word': ' como tes', 'start': 25, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.52560514, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.53094167, 'word': ' ,', 'start': 38, 'end': 38}, {'entity_group': 'LABEL_0', 'score': 0.51128197, 'word': ' preciso', 'start': 40, 'end': 46}, {'entity_group': 'LABEL_1', 'score': 0.5562213, 'word': ' de suporte a execucao de', 'start': 48, 'end': 71}, {'entity_group': 'LABEL_0', 'score': 0.507625, 'word': ' testes de', 'start': 73, 'end': 81}, {'entity_group': 'LABEL_1', 'score': 0.63071203, 'word': ' seguranca automatizados', 'start': 83, 'end': 105}, {'entity_group': 'LABEL_0', 'score': 0.6709341, 'word': ' .', 'start': 106, 'end': 106}]
# Resultado para História de Usuário 43: [{'entity_group': 'LABEL_1', 'score': 0.5649782, 'word': ' historia de usuario', 'start': 0, 'end': 19}, {'entity_group': 'LABEL_0', 'score': 0.60034204, 'word': ' 43 : como', 'start': 21, 'end': 28}, {'entity_group': 'LABEL_1', 'score': 0.5362321, 'word': ' tes', 'start': 30, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.51844597, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.60330796, 'word': ' , quero integracao com ferramentas de analise de codigo estatico para identificar areas de risco', 'start': 38, 'end': 133}, {'entity_group': 'LABEL_0', 'score': 0.5814559, 'word': ' .', 'start': 134, 'end': 134}]
# Resultado para História de Usuário 44: [{'entity_group': 'LABEL_0', 'score': 0.53774804, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_1', 'score': 0.5370718, 'word': ' de usuario', 'start': 10, 'end': 19}, {'entity_group': 'LABEL_0', 'score': 0.6370237, 'word': ' 44 : como', 'start': 21, 'end': 28}, {'entity_group': 'LABEL_1', 'score': 0.5643208, 'word': ' tes', 'start': 30, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.56521326, 'word': 'tador , desejo', 'start': 32, 'end': 45}, {'entity_group': 'LABEL_1', 'score': 0.6086776, 'word': ' suporte a execucao de', 'start': 47, 'end': 67}, {'entity_group': 'LABEL_0', 'score': 0.54596984, 'word': ' testes', 'start': 69, 'end': 74}, {'entity_group': 'LABEL_1', 'score': 0.618708, 'word': ' de integracao de', 'start': 76, 'end': 91}, {'entity_group': 'LABEL_0', 'score': 0.50927895, 'word': ' sistema', 'start': 93, 'end': 99}, {'entity_group': 'LABEL_1', 'score': 0.5187634, 'word': ' e', 'start': 101, 'end': 101}, {'entity_group': 'LABEL_0', 'score': 0.5058743, 'word': ' teste', 'start': 103, 'end': 107}, {'entity_group': 'LABEL_1', 'score': 0.6413928, 'word': ' de aceitacao do usuario', 'start': 109, 'end': 131}, {'entity_group': 'LABEL_0', 'score': 0.5255978, 'word': ' .', 'start': 132, 'end': 132}]
# Resultado para História de Usuário 45: [{'entity_group': 'LABEL_1', 'score': 0.526059, 'word': ' historia de usuario', 'start': 0, 'end': 19}, {'entity_group': 'LABEL_0', 'score': 0.63412637, 'word': ' 45 :', 'start': 21, 'end': 23}, {'entity_group': 'LABEL_1', 'score': 0.538224, 'word': ' como tes', 'start': 25, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.5362448, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.5261134, 'word': ' ,', 'start': 38, 'end': 38}, {'entity_group': 'LABEL_0', 'score': 0.5178153, 'word': ' preciso', 'start': 40, 'end': 46}, {'entity_group': 'LABEL_1', 'score': 0.57490253, 'word': ' de suporte a execucao de', 'start': 48, 'end': 71}, {'entity_group': 'LABEL_0', 'score': 0.5553723, 'word': ' testes de confi', 'start': 73, 'end': 87}, {'entity_group': 'LABEL_1', 'score': 0.5159985, 'word': 'abilidade', 'start': 87, 'end': 96}, {'entity_group': 'LABEL_0', 'score': 0.5465338, 'word': ' e', 'start': 98, 'end': 98}, {'entity_group': 'LABEL_1', 'score': 0.5056907, 'word': ' disponibilidade', 'start': 100, 'end': 114}, {'entity_group': 'LABEL_0', 'score': 0.5641201, 'word': ' .', 'start': 115, 'end': 115}]
# Resultado para História de Usuário 46: [{'entity_group': 'LABEL_0', 'score': 0.5034896, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_1', 'score': 0.5665263, 'word': ' de usuario', 'start': 10, 'end': 19}, {'entity_group': 'LABEL_0', 'score': 0.63009876, 'word': ' 46 :', 'start': 21, 'end': 23}, {'entity_group': 'LABEL_1', 'score': 0.51398563, 'word': ' como tes', 'start': 25, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.5371789, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.5970602, 'word': ' , quero que a ferramenta sugira casos de teste com base em modelos de qualidade de software reconhecidos', 'start': 38, 'end': 141}, {'entity_group': 'LABEL_0', 'score': 0.56585944, 'word': ' .', 'start': 142, 'end': 142}]
# Resultado para História de Usuário 47: [{'entity_group': 'LABEL_0', 'score': 0.53281695, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_1', 'score': 0.53770703, 'word': ' de usuario 47', 'start': 10, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.6203946, 'word': ' :', 'start': 23, 'end': 23}, {'entity_group': 'LABEL_1', 'score': 0.5431529, 'word': ' como tes', 'start': 25, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.53206, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.54164225, 'word': ' , desejo integracao com ferramentas de automacao de', 'start': 38, 'end': 88}, {'entity_group': 'LABEL_0', 'score': 0.6054111, 'word': ' teste', 'start': 90, 'end': 94}, {'entity_group': 'LABEL_1', 'score': 0.6181798, 'word': ' de interface do usuario', 'start': 96, 'end': 118}, {'entity_group': 'LABEL_0', 'score': 0.5303726, 'word': ' .', 'start': 119, 'end': 119}]
# Resultado para História de Usuário 48: [{'entity_group': 'LABEL_1', 'score': 0.5718665, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5007124, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.58359885, 'word': ' 48', 'start': 21, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.59314525, 'word': ' :', 'start': 23, 'end': 23}, {'entity_group': 'LABEL_1', 'score': 0.5529481, 'word': ' como tes', 'start': 25, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.5520482, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.5461353, 'word': ' ,', 'start': 38, 'end': 38}, {'entity_group': 'LABEL_0', 'score': 0.50140613, 'word': ' preciso', 'start': 40, 'end': 46}, {'entity_group': 'LABEL_1', 'score': 0.59091777, 'word': ' de suporte a execucao de', 'start': 48, 'end': 71}, {'entity_group': 'LABEL_0', 'score': 0.5146583, 'word': ' testes', 'start': 73, 'end': 78}, {'entity_group': 'LABEL_1', 'score': 0.56158364, 'word': ' de est', 'start': 80, 'end': 85}, {'entity_group': 'LABEL_0', 'score': 0.55671227, 'word': 'resse e', 'start': 85, 'end': 92}, {'entity_group': 'LABEL_1', 'score': 0.62006634, 'word': ' robustez', 'start': 94, 'end': 101}, {'entity_group': 'LABEL_0', 'score': 0.6709881, 'word': ' .', 'start': 102, 'end': 102}]
# Resultado para História de Usuário 49: [{'entity_group': 'LABEL_1', 'score': 0.5454072, 'word': ' historia de usuario 49', 'start': 0, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.6426019, 'word': ' :', 'start': 23, 'end': 23}, {'entity_group': 'LABEL_1', 'score': 0.51392365, 'word': ' como tes', 'start': 25, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.5243362, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.59849954, 'word': ' , quero que a ferramenta sugira casos de', 'start': 38, 'end': 77}, {'entity_group': 'LABEL_0', 'score': 0.52074945, 'word': ' teste', 'start': 79, 'end': 83}, {'entity_group': 'LABEL_1', 'score': 0.5784449, 'word': ' para areas de alto risco e complexidade', 'start': 85, 'end': 123}, {'entity_group': 'LABEL_0', 'score': 0.5940351, 'word': ' .', 'start': 124, 'end': 124}]
# Resultado para História de Usuário 50: [{'entity_group': 'LABEL_1', 'score': 0.53179216, 'word': ' historia de usuario 50', 'start': 0, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.585064, 'word': ' :', 'start': 23, 'end': 23}, {'entity_group': 'LABEL_1', 'score': 0.5342337, 'word': ' como tes', 'start': 25, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.5191643, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.5557229, 'word': ' , desejo integracao com ferramentas de gerenciamento de', 'start': 38, 'end': 92}, {'entity_group': 'LABEL_0', 'score': 0.5584897, 'word': ' defeitos para', 'start': 94, 'end': 106}, {'entity_group': 'LABEL_1', 'score': 0.55210775, 'word': ' rastreamento de correcoes', 'start': 108, 'end': 132}, {'entity_group': 'LABEL_0', 'score': 0.60669637, 'word': ' .', 'start': 133, 'end': 133}]
# Resultado para História de Usuário 51: [{'entity_group': 'LABEL_1', 'score': 0.55725807, 'word': ' historia de usuario', 'start': 0, 'end': 19}, {'entity_group': 'LABEL_0', 'score': 0.5588751, 'word': ' 51 :', 'start': 21, 'end': 23}, {'entity_group': 'LABEL_1', 'score': 0.5697354, 'word': ' como tes', 'start': 25, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.500517, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.55015653, 'word': ' ,', 'start': 38, 'end': 38}, {'entity_group': 'LABEL_0', 'score': 0.52612793, 'word': ' preciso', 'start': 40, 'end': 46}, {'entity_group': 'LABEL_1', 'score': 0.6065785, 'word': ' de suporte a execucao de testes de usabilidade remota e teste de usuario beta', 'start': 48, 'end': 124}, {'entity_group': 'LABEL_0', 'score': 0.6698484, 'word': ' .', 'start': 125, 'end': 125}]
# Resultado para História de Usuário 52: [{'entity_group': 'LABEL_0', 'score': 0.52052516, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_1', 'score': 0.51564956, 'word': ' de usuario', 'start': 10, 'end': 19}, {'entity_group': 'LABEL_0', 'score': 0.62737775, 'word': ' 52 :', 'start': 21, 'end': 23}, {'entity_group': 'LABEL_1', 'score': 0.5333046, 'word': ' como tes', 'start': 25, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.5598904, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.61006325, 'word': ' , quero que a ferramenta forneca feedback em tempo real durante a execucao dos testes', 'start': 38, 'end': 122}, {'entity_group': 'LABEL_0', 'score': 0.53350174, 'word': ' .', 'start': 123, 'end': 123}]
# Resultado para História de Usuário 53: [{'entity_group': 'LABEL_1', 'score': 0.52555054, 'word': ' historia de usuario', 'start': 0, 'end': 19}, {'entity_group': 'LABEL_0', 'score': 0.5497112, 'word': ' 53 :', 'start': 21, 'end': 23}, {'entity_group': 'LABEL_1', 'score': 0.55543715, 'word': ' como testador , desejo integracao com ferramentas de automacao de infraestrutura', 'start': 25, 'end': 103}, {'entity_group': 'LABEL_0', 'score': 0.51544124, 'word': ' para', 'start': 105, 'end': 108}, {'entity_group': 'LABEL_1', 'score': 0.61758196, 'word': ' provisionamento e configuracao automatizados', 'start': 110, 'end': 153}, {'entity_group': 'LABEL_0', 'score': 0.65099525, 'word': ' .', 'start': 154, 'end': 154}]
# Resultado para História de Usuário 54: [{'entity_group': 'LABEL_0', 'score': 0.5769874, 'word': ' historia de usuario 54 :', 'start': 0, 'end': 23}, {'entity_group': 'LABEL_1', 'score': 0.5384613, 'word': ' como tes', 'start': 25, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.56298345, 'word': 'tador', 'start': 32, 'end': 37}, {'entity_group': 'LABEL_1', 'score': 0.51235086, 'word': ' ,', 'start': 38, 'end': 38}, {'entity_group': 'LABEL_0', 'score': 0.52598363, 'word': ' preciso', 'start': 40, 'end': 46}, {'entity_group': 'LABEL_1', 'score': 0.5843888, 'word': ' de suporte a execucao de testes de comparacao de desempenho para versoes', 'start': 48, 'end': 119}, {'entity_group': 'LABEL_0', 'score': 0.6151862, 'word': ' anteriores', 'start': 121, 'end': 130}, {'entity_group': 'LABEL_1', 'score': 0.5745588, 'word': ' e atuais do aplica', 'start': 132, 'end': 149}, {'entity_group': 'LABEL_0', 'score': 0.5693909, 'word': 'tivo .', 'start': 149, 'end': 154}]

# %%
def extract_info(historia):
    autor = None
    if "Testador" in historia:
        autor = "Testador"
    elif "testador" in historia:
        autor = "testador"

    necessidade = None
    for word in ["quero", "preciso", "desejo"]:
        if word in historia:
            pos_inicial = historia.find(word) + len(word)
            necessidade = historia[pos_inicial:].strip()
            break

    objetivo = None
    if "para" in historia:
        pos_inicial = historia.find("para") + len("para")
        objetivo = historia[pos_inicial:].strip()

    return autor, necessidade, objetivo


for historia in historias_usuario:
    autor, necessidade, objetivo = extract_info(historia)
    print("História do Usuário:", historia)
    print("Autor:", autor)
    print("Necessidade:", necessidade)
    print("Objetivo:", objetivo)
    print()
# Out:
# História do Usuário: Como Testador eu quero um jeito mais fácil de incluir os requisitos do aplicativo na ferramenta DRL-Mobtest para criar casos de teste que cubram tudo que o aplicativo precisa fazer, sem ter que gastar muito tempo escrevendo manualmente.
# Autor: Testador
# Necessidade: um jeito mais fácil de incluir os requisitos do aplicativo na ferramenta DRL-Mobtest para criar casos de teste que cubram tudo que o aplicativo precisa fazer, sem ter que gastar muito tempo escrevendo manualmente.
# Objetivo: criar casos de teste que cubram tudo que o aplicativo precisa fazer, sem ter que gastar muito tempo escrevendo manualmente.
#
# História do Usuário: Como Testador eu quero uma maneira de ensinar a ferramenta DRL-Mobtest a entender os requisitos do aplicativo usando NLP para fazer com que a ferramenta gere testes automaticamente.
# Autor: Testador
# Necessidade: uma maneira de ensinar a ferramenta DRL-Mobtest a entender os requisitos do aplicativo usando NLP para fazer com que a ferramenta gere testes automaticamente.
# Objetivo: fazer com que a ferramenta gere testes automaticamente.
#
# História do Usuário: Como Testador eu quero que a ferramenta gere casos de teste abrangentes que cubram integralmente todos os requisitos do aplicativo, assegurando que o software seja completo e funcional, sem depender exclusivamente da criação manual de casos de teste.
# Autor: Testador
# Necessidade: que a ferramenta gere casos de teste abrangentes que cubram integralmente todos os requisitos do aplicativo, assegurando que o software seja completo e funcional, sem depender exclusivamente da criação manual de casos de teste.
# Objetivo: None
#
# História do Usuário: Como Testador eu quero que a ferramenta seja integrada com outras ferramentas de gerenciamento, permitindo sincronização automática dos requisitos e facilitando o processo de criação de casos de testes.
# Autor: Testador
# Necessidade: que a ferramenta seja integrada com outras ferramentas de gerenciamento, permitindo sincronização automática dos requisitos e facilitando o processo de criação de casos de testes.
# Objetivo: None
#
# História do Usuário: Como Testador eu quero que a ferramenta  forneça o recurso de criação de relatórios detalhados sobre a cobertura dos testes, permitindo uma análise precisa sobre sua progressão e identificação das lacunas durante sua execução.
# Autor: Testador
# Necessidade: que a ferramenta  forneça o recurso de criação de relatórios detalhados sobre a cobertura dos testes, permitindo uma análise precisa sobre sua progressão e identificação das lacunas durante sua execução.
# Objetivo: None
#
# História do Usuário: Como testador, quero uma maneira mais fácil de incluir requisitos do aplicativo para criar casos de teste abrangentes, economizando tempo na escrita manual.
# Autor: testador
# Necessidade: uma maneira mais fácil de incluir requisitos do aplicativo para criar casos de teste abrangentes, economizando tempo na escrita manual.
# Objetivo: criar casos de teste abrangentes, economizando tempo na escrita manual.
#
# História do Usuário: Como testador, desejo ensinar a ferramenta a entender os requisitos do aplicativo usando NLP para gerar testes automaticamente.
# Autor: testador
# Necessidade: ensinar a ferramenta a entender os requisitos do aplicativo usando NLP para gerar testes automaticamente.
# Objetivo: gerar testes automaticamente.
#
# História do Usuário: Como testador, preciso que a ferramenta gere casos de teste completos e funcionais que cubram todos os requisitos do aplicativo.
# Autor: testador
# Necessidade: que a ferramenta gere casos de teste completos e funcionais que cubram todos os requisitos do aplicativo.
# Objetivo: None
#
# História do Usuário: Como testador, quero integração com outras ferramentas de gerenciamento para sincronizar automaticamente requisitos e facilitar a criação de casos de teste.
# Autor: testador
# Necessidade: integração com outras ferramentas de gerenciamento para sincronizar automaticamente requisitos e facilitar a criação de casos de teste.
# Objetivo: sincronizar automaticamente requisitos e facilitar a criação de casos de teste.
#
# História do Usuário: Como testador, quero relatórios detalhados sobre a cobertura dos testes para análise precisa durante a execução.
# Autor: testador
# Necessidade: relatórios detalhados sobre a cobertura dos testes para análise precisa durante a execução.
# Objetivo: análise precisa durante a execução.
#
# História do Usuário: Como testador, desejo que a ferramenta identifique automaticamente os casos de teste mais críticos para priorizar a análise.
# Autor: testador
# Necessidade: que a ferramenta identifique automaticamente os casos de teste mais críticos para priorizar a análise.
# Objetivo: priorizar a análise.
#
# História do Usuário: Como testador, preciso que a ferramenta sugira casos de teste com base em padrões de uso real do aplicativo.
# Autor: testador
# Necessidade: que a ferramenta sugira casos de teste com base em padrões de uso real do aplicativo.
# Objetivo: None
#
# História do Usuário: Como testador, quero sugestões com base em padrões de falha históricos para evitar problemas recorrentes no software.
# Autor: testador
# Necessidade: sugestões com base em padrões de falha históricos para evitar problemas recorrentes no software.
# Objetivo: evitar problemas recorrentes no software.
#
# História do Usuário: Como testador, desejo suporte à execução de testes automatizados em diferentes dispositivos e ambientes.
# Autor: testador
# Necessidade: suporte à execução de testes automatizados em diferentes dispositivos e ambientes.
# Objetivo: None
#
# História do Usuário: Como testador, preciso que a ferramenta detecte automaticamente mudanças nos requisitos e ajuste os casos de teste correspondentes.
# Autor: testador
# Necessidade: que a ferramenta detecte automaticamente mudanças nos requisitos e ajuste os casos de teste correspondentes.
# Objetivo: None
#
# História do Usuário: Como testador, quero integração com sistemas de controle de versão para rastrear mudanças nos requisitos e no código-fonte.
# Autor: testador
# Necessidade: integração com sistemas de controle de versão para rastrear mudanças nos requisitos e no código-fonte.
# Objetivo: rastrear mudanças nos requisitos e no código-fonte.
#
# História do Usuário: Como testador, desejo métricas detalhadas sobre a eficácia dos testes, incluindo taxa de cobertura e taxa de falha.
# Autor: testador
# Necessidade: métricas detalhadas sobre a eficácia dos testes, incluindo taxa de cobertura e taxa de falha.
# Objetivo: None
#
# História do Usuário: Como testador, preciso de suporte à execução de testes de desempenho e escalabilidade.
# Autor: testador
# Necessidade: de suporte à execução de testes de desempenho e escalabilidade.
# Objetivo: None
#
# História do Usuário: Como testador, quero análise automática dos resultados dos testes para relatórios detalhados sobre problemas encontrados.
# Autor: testador
# Necessidade: análise automática dos resultados dos testes para relatórios detalhados sobre problemas encontrados.
# Objetivo: relatórios detalhados sobre problemas encontrados.
#
# História do Usuário: Como testador, desejo simular cenários de teste complexos e realistas para garantir testes próximos à realidade.
# Autor: testador
# Necessidade: simular cenários de teste complexos e realistas para garantir testes próximos à realidade.
# Objetivo: garantir testes próximos à realidade.
#
# História do Usuário: Como testador, preciso de suporte à execução de testes de regressão automatizados.
# Autor: testador
# Necessidade: de suporte à execução de testes de regressão automatizados.
# Objetivo: None
#
# História do Usuário: Como testador, quero identificação automática de casos de teste redundantes ou desnecessários.
# Autor: testador
# Necessidade: identificação automática de casos de teste redundantes ou desnecessários.
# Objetivo: None
#
# História do Usuário: Como testador, desejo integração fácil com ferramentas de gerenciamento de projetos.
# Autor: testador
# Necessidade: integração fácil com ferramentas de gerenciamento de projetos.
# Objetivo: None
#
# História do Usuário: Como testador, preciso de suporte à execução de testes de usabilidade.
# Autor: testador
# Necessidade: de suporte à execução de testes de usabilidade.
# Objetivo: None
#
# História do Usuário: Como testador, quero que a ferramenta crie automaticamente conjuntos de dados de teste realistas.
# Autor: testador
# Necessidade: que a ferramenta crie automaticamente conjuntos de dados de teste realistas.
# Objetivo: None
#
# História do Usuário: Como testador, desejo integração com ferramentas de monitoramento de desempenho em tempo real.
# Autor: testador
# Necessidade: integração com ferramentas de monitoramento de desempenho em tempo real.
# Objetivo: None
#
# História do Usuário: Como testador, preciso de suporte à execução de testes de localização e internacionalização.
# Autor: testador
# Necessidade: de suporte à execução de testes de localização e internacionalização.
# Objetivo: None
#
# História do Usuário: Como testador, quero geração automática de dados de teste sintéticos.
# Autor: testador
# Necessidade: geração automática de dados de teste sintéticos.
# Objetivo: None
#
# História do Usuário: Como testador, desejo suporte à execução de testes de acessibilidade.
# Autor: testador
# Necessidade: suporte à execução de testes de acessibilidade.
# Objetivo: None
#
# História do Usuário: Como testador, preciso de suporte à execução de testes de integração contínua.
# Autor: testador
# Necessidade: de suporte à execução de testes de integração contínua.
# Objetivo: None
#
# História do Usuário: Como testador, quero identificação automática de casos de teste incompletos ou mal definidos.
# Autor: testador
# Necessidade: identificação automática de casos de teste incompletos ou mal definidos.
# Objetivo: None
#
# História do Usuário: Como testador, desejo identificação automática de dependências entre casos de teste.
# Autor: testador
# Necessidade: identificação automática de dependências entre casos de teste.
# Objetivo: None
#
# História do Usuário: Como testador, preciso de suporte à execução de testes de recuperação de desastres.
# Autor: testador
# Necessidade: de suporte à execução de testes de recuperação de desastres.
# Objetivo: None
#
# História do Usuário: Como testador, quero que a ferramenta identifique automaticamente casos de teste paralelizáveis.
# Autor: testador
# Necessidade: que a ferramenta identifique automaticamente casos de teste paralelizáveis.
# Objetivo: lelizáveis.
#
# História do Usuário: Como testador, desejo simulação de cenários de teste de carga extremamente alta.
# Autor: testador
# Necessidade: simulação de cenários de teste de carga extremamente alta.
# Objetivo: None
#
# História do Usuário: Como testador, preciso de suporte à execução de testes de compatibilidade com diferentes navegadores e dispositivos.
# Autor: testador
# Necessidade: de suporte à execução de testes de compatibilidade com diferentes navegadores e dispositivos.
# Objetivo: None
#
# História do Usuário: Como testador, quero geração automática de relatórios de teste personalizados.
# Autor: testador
# Necessidade: geração automática de relatórios de teste personalizados.
# Objetivo: None
#
# História do Usuário: Como testador, desejo rastreamento automático de resultados de teste ao longo do tempo.
# Autor: testador
# Necessidade: rastreamento automático de resultados de teste ao longo do tempo.
# Objetivo: None
#
# História do Usuário: Como testador, preciso de suporte à execução de testes de regressão progressiva.
# Autor: testador
# Necessidade: de suporte à execução de testes de regressão progressiva.
# Objetivo: None
#
# História do Usuário: Como testador, quero sugestões automáticas para aprimorar os casos de teste existentes.
# Autor: testador
# Necessidade: sugestões automáticas para aprimorar os casos de teste existentes.
# Objetivo: aprimorar os casos de teste existentes.
#
# História do Usuário: Como testador, desejo que a ferramenta aprenda com os resultados dos testes e melhore suas sugestões futuras.
# Autor: testador
# Necessidade: que a ferramenta aprenda com os resultados dos testes e melhore suas sugestões futuras.
# Objetivo: None
#
# História do Usuário: Como testador, preciso de suporte à execução de testes de segurança automatizados.
# Autor: testador
# Necessidade: de suporte à execução de testes de segurança automatizados.
# Objetivo: None
#
# História do Usuário: Como testador, quero integração com ferramentas de análise de código estático para identificar áreas de risco.
# Autor: testador
# Necessidade: integração com ferramentas de análise de código estático para identificar áreas de risco.
# Objetivo: identificar áreas de risco.
#
# História do Usuário: Como testador, desejo suporte à execução de testes de integração de sistema e teste de aceitação do usuário.
# Autor: testador
# Necessidade: suporte à execução de testes de integração de sistema e teste de aceitação do usuário.
# Objetivo: None
#
# História do Usuário: Como testador, preciso de suporte à execução de testes de confiabilidade e disponibilidade.
# Autor: testador
# Necessidade: de suporte à execução de testes de confiabilidade e disponibilidade.
# Objetivo: None
#
# História do Usuário: Como testador, quero que a ferramenta sugira casos de teste com base em modelos de qualidade de software reconhecidos.
# Autor: testador
# Necessidade: que a ferramenta sugira casos de teste com base em modelos de qualidade de software reconhecidos.
# Objetivo: None
#
# História do Usuário: Como testador, desejo integração com ferramentas de automação de teste de interface do usuário.
# Autor: testador
# Necessidade: integração com ferramentas de automação de teste de interface do usuário.
# Objetivo: None
#
# História do Usuário: Como testador, preciso de suporte à execução de testes de estresse e robustez.
# Autor: testador
# Necessidade: de suporte à execução de testes de estresse e robustez.
# Objetivo: None
#
# História do Usuário: Como testador, quero que a ferramenta sugira casos de teste para áreas de alto risco e complexidade.
# Autor: testador
# Necessidade: que a ferramenta sugira casos de teste para áreas de alto risco e complexidade.
# Objetivo: áreas de alto risco e complexidade.
#
# História do Usuário: Como testador, desejo integração com ferramentas de gerenciamento de defeitos para rastreamento de correções.
# Autor: testador
# Necessidade: integração com ferramentas de gerenciamento de defeitos para rastreamento de correções.
# Objetivo: rastreamento de correções.
#
# História do Usuário: Como testador, preciso de suporte à execução de testes de usabilidade remota e teste de usuário beta.
# Autor: testador
# Necessidade: de suporte à execução de testes de usabilidade remota e teste de usuário beta.
# Objetivo: None
#
# História do Usuário: Como testador, quero que a ferramenta forneça feedback em tempo real durante a execução dos testes.
# Autor: testador
# Necessidade: que a ferramenta forneça feedback em tempo real durante a execução dos testes.
# Objetivo: None
#
# História do Usuário: Como testador, desejo integração com ferramentas de automação de infraestrutura para provisionamento e configuração automatizados.
# Autor: testador
# Necessidade: integração com ferramentas de automação de infraestrutura para provisionamento e configuração automatizados.
# Objetivo: provisionamento e configuração automatizados.
#
# História do Usuário: Como testador, preciso de suporte à execução de testes de comparação de desempenho para versões anteriores e atuais do aplicativo.
# Autor: testador
# Necessidade: de suporte à execução de testes de comparação de desempenho para versões anteriores e atuais do aplicativo.
# Objetivo: ção de desempenho para versões anteriores e atuais do aplicativo.

# %%
X = historias_usuario
rotulos_possiveis = ["testador", "aplicativo", "ferramenta", "suporte"]
y = [choice(rotulos_possiveis) for _ in range(len(historias_usuario))]
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=42)

# %%
clf_tf = DecisionTreeClassifier(criterion='gini',max_depth=3)
clf_tf.fit(X_train, y_train)
pred_arvore_entropy_tf = clf_tf.predict(X_test)
accuracy_decision = accuracy_score(y_test,pred_arvore_entropy_tf)
print(pred_arvore_entropy_tf)
print(accuracy_decision)
# Out:
# ['suporte' 'suporte' 'suporte' 'suporte' 'suporte' 'aplicativo' 'suporte'
#  'suporte' 'aplicativo']
# 0.1111111111111111

# %%
clf_tf = DecisionTreeClassifier(criterion='entropy',max_depth=7)
clf_tf.fit(X_train, y_train)
pred_arvore_entropy_tf = clf_tf.predict(X_test)
accuracy_decision = accuracy_score(y_test,pred_arvore_entropy_tf)
print(pred_arvore_entropy_tf)
print(accuracy_decision)
# Out:
# ['ferramenta' 'aplicativo' 'suporte' 'aplicativo' 'aplicativo'
#  'aplicativo' 'ferramenta' 'aplicativo' 'suporte']
# 0.2222222222222222

# %%
clf_tf3 = KNeighborsClassifier(metric='manhattan')
clf_tf3.fit(X_train, y_train)
pred_knn_tf = clf_tf3.predict(X_test)
acuracy_KNN = accuracy_score(y_test,pred_knn_tf)
print(pred_knn_tf)
print(acuracy_KNN)
# Out:
# ['suporte' 'suporte' 'aplicativo' 'suporte' 'aplicativo' 'suporte'
#  'aplicativo' 'suporte' 'suporte']
# 0.3333333333333333

# %%
clf_tf3 = KNeighborsClassifier(metric='euclidean')
clf_tf3.fit(X_train, y_train)
pred_knn_tf = clf_tf3.predict(X_test)
acuracy_KNN = accuracy_score(y_test,pred_knn_tf)
print(pred_knn_tf)
print(acuracy_KNN)
# Out:
# ['testador' 'ferramenta' 'aplicativo' 'ferramenta' 'suporte' 'aplicativo'
#  'testador' 'ferramenta' 'aplicativo']
# 0.1111111111111111
