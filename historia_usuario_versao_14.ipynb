# %%
from sklearn.feature_extraction.text import TfidfVectorizer
# !python3 -m spacy download pt_core_news_lg
from tensorflow.keras import optimizers
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.probability import FreqDist
from scipy.sparse import csr_matrix
from nltk.corpus import stopwords
from transformers import pipeline
import matplotlib.pyplot as plt
from random import choice
import seaborn as sns
import pandas as pd
import numpy as np
# %matplotlib inline
import torch
import string
import nltk
import re
# Out:
# Collecting pt-core-news-lg==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/pt_core_news_lg-3.7.0/pt_core_news_lg-3.7.0-py3-none-any.whl (568.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 568.2/568.2 MB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from pt-core-news-lg==3.7.0) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (4.66.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.7.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (24.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (1.25.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.18.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.1.5)
# Installing collected packages: pt-core-news-lg
# Successfully installed pt-core-news-lg-3.7.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
classificador = pipeline("zero-shot-classification")
rotulos = ["testador", "aplicativo", "desempenho", "teste"]
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli and revision c626438 (https://huggingface.co/facebook/bart-large-mnli).
# Using a pipeline without specifying a model name and revision in production is not recommended.

# %%
roberta = pipeline("ner", grouped_entities=True, model="joelniklaus/legal-portuguese-roberta-base")
# Out:
# config.json:   0%|          | 0.00/699 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/443M [00:00<?, ?B/s]
# Some weights of RobertaForTokenClassification were not initialized from the model checkpoint at joelniklaus/legal-portuguese-roberta-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# tokenizer_config.json:   0%|          | 0.00/403 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.41M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/167 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/token_classification.py:168: UserWarning: `grouped_entities` is deprecated and will be removed in version v5.0.0, defaulted to `aggregation_strategy="simple"` instead.
#   warnings.warn(

# %%
historias_usuario = [
    "Como Testador eu quero um jeito mais fácil de incluir os requisitos do aplicativo na ferramenta DRL-Mobtest para criar casos de teste que cubram tudo que o aplicativo precisa fazer, sem ter que gastar muito tempo escrevendo manualmente.",
    "Como Testador eu quero uma maneira de ensinar a ferramenta DRL-Mobtest a entender os requisitos do aplicativo usando NLP para fazer com que a ferramenta gere testes automaticamente.",
    "Como Testador eu quero que a ferramenta gere casos de teste abrangentes que cubram integralmente todos os requisitos do aplicativo, assegurando que o software seja completo e funcional, sem depender exclusivamente da criação manual de casos de teste.",
    "Como Testador eu quero que a ferramenta seja integrada com outras ferramentas de gerenciamento, permitindo sincronização automática dos requisitos e facilitando o processo de criação de casos de testes.",
    "Como testador, eu quero que a ferramenta gere casos de teste completos e funcionais que cubram todos os requisitos do aplicativo, para garantir uma cobertura abrangente durante os testes.",
    "Como testador, eu quero integração com outras ferramentas de gerenciamento para sincronizar automaticamente requisitos e facilitar a criação de casos de teste, visando melhorar a eficiência e precisão do processo de teste.",
    "Como testador, eu quero relatórios detalhados sobre a cobertura dos testes para análise precisa durante a execução, a fim de avaliar a qualidade e a extensão dos testes realizados.",
    "Como testador, eu desejo que a ferramenta identifique automaticamente os casos de teste mais críticos para priorizar a análise, visando direcionar os esforços de teste para áreas de maior risco.",
    "Como testador, eu preciso que a ferramenta sugira casos de teste com base em padrões de uso real do aplicativo, para garantir que os testes reflitam cenários típicos de uso.",
    "Como testador, eu quero sugestões com base em padrões de falha históricos para evitar problemas recorrentes no software, visando melhorar a qualidade e a robustez do produto.",
    "Como testador, eu desejo suporte à execução de testes automatizados em diferentes dispositivos e ambientes, para garantir a consistência e a confiabilidade dos testes em diferentes cenários.",
    "Como testador, eu preciso que a ferramenta detecte automaticamente mudanças nos requisitos e ajuste os casos de teste correspondentes, para manter os testes alinhados com a evolução do aplicativo.",
    "Como testador, eu quero integração com sistemas de controle de versão para rastrear mudanças nos requisitos e no código-fonte, visando uma gestão eficaz de mudanças durante o ciclo de desenvolvimento.",
    "Como testador, eu desejo métricas detalhadas sobre a eficácia dos testes, incluindo taxa de cobertura e taxa de falha, para avaliar a qualidade do processo de teste.",
    "Como testador, eu preciso de suporte à execução de testes de desempenho e escalabilidade, para garantir que o aplicativo atenda aos requisitos de desempenho sob carga.",
    "Como testador, eu quero análise automática dos resultados dos testes para relatórios detalhados sobre problemas encontrados, a fim de facilitar a identificação e correção de defeitos.",
    "Como testador, eu desejo simular cenários de teste complexos e realistas para garantir testes próximos à realidade, visando uma validação mais precisa do software.",
    "Como testador, eu preciso de suporte à execução de testes de regressão automatizados, para garantir que as alterações no código não introduzam regressões.",
    "Como testador, eu quero identificação automática de casos de teste redundantes ou desnecessários, para otimizar os esforços de teste.",
    "Como testador, eu desejo integração fácil com ferramentas de gerenciamento de projetos, para uma colaboração eficiente com outros membros da equipe de desenvolvimento.",
    "Como testador, eu preciso de suporte à execução de testes de usabilidade, para garantir que o aplicativo seja fácil e intuitivo de usar.",
    "Como testador, eu quero que a ferramenta crie automaticamente conjuntos de dados de teste realistas, para simular condições reais de uso.",
    "Como testador, eu desejo integração com ferramentas de monitoramento de desempenho em tempo real, para avaliar o desempenho do aplicativo durante os testes.",
    "Como testador, eu preciso de suporte à execução de testes de localização e internacionalização, para garantir que o aplicativo seja compatível com diferentes idiomas e regiões.",
    "Como testador, eu quero geração automática de dados de teste sintéticos, para complementar os casos de teste manuais.",
    "Como testador, eu desejo suporte à execução de testes de acessibilidade, para garantir que o aplicativo seja acessível a todos os usuários.",
    "Como testador, eu preciso de suporte à execução de testes de integração contínua, para garantir que as alterações no código não quebrem a integração com outras partes do sistema.",
    "Como testador, eu quero identificação automática de casos de teste incompletos ou mal definidos, para garantir a qualidade dos testes.",
    "Como testador, eu desejo identificação automática de dependências entre casos de teste, para garantir uma sequência lógica na execução dos testes.",
    "Como testador, eu preciso de suporte à execução de testes de recuperação de desastres, para avaliar a capacidade do sistema de se recuperar de falhas.",
    "Como testador, eu quero que a ferramenta identifique automaticamente casos de teste paralelizáveis, para otimizar a execução dos testes.",
    "Como testador, eu desejo simulação de cenários de teste de carga extremamente alta, para avaliar a capacidade de escalabilidade do sistema.",
    "Como testador, eu preciso de suporte à execução de testes de compatibilidade com diferentes navegadores e dispositivos, para garantir uma experiência consistente para todos os usuários.",
    "Como testador, eu quero geração automática de relatórios de teste personalizados, para comunicar eficazmente os resultados dos testes.",
    "Como testador, eu desejo rastreamento automático de resultados de teste ao longo do tempo, para identificar tendências e padrões de qualidade.",
    "Como testador, eu preciso de suporte à execução de testes de regressão progressiva, para garantir que as novas alterações não quebrem funcionalidades existentes.",
    "Como testador, eu quero sugestões automáticas para aprimorar os casos de teste existentes, para aumentar a eficiência e a eficácia dos testes.",
    "Como testador, eu desejo que a ferramenta aprenda com os resultados dos testes e melhore suas sugestões futuras, para uma otimização contínua do processo de teste.",
    "Como testador, eu preciso de suporte à execução de testes de segurança automatizados, para identificar vulnerabilidades no aplicativo.",
    "Como testador, eu quero integração com ferramentas de análise de código estático para identificar áreas de risco, para uma avaliação abrangente da qualidade do código.",
    "Como testador, eu desejo suporte à execução de testes de integração de sistema e teste de aceitação do usuário, para validar a integração entre diferentes partes do sistema e a conformidade com os requisitos do usuário.",
    "Como testador, eu preciso de suporte à execução de testes de confiabilidade e disponibilidade, para garantir que o aplicativo esteja sempre disponível e funcione corretamente.",
    "Como testador, eu quero que a ferramenta sugira casos de teste com base em modelos de qualidade de software reconhecidos, para garantir uma abordagem abrangente e padronizada para os testes.",
    "Como testador, eu desejo integração com ferramentas de automação de teste de interface do usuário, para automatizar testes de interação com o usuário.",
    "Como testador, eu preciso de suporte à execução de testes de estresse e robustez, para avaliar a estabilidade e a confiabilidade do aplicativo sob condições adversas.",
    "Como testador, eu quero que a ferramenta sugira casos de teste para áreas de alto risco e complexidade, para priorizar os esforços de teste.",
    "Como testador, eu desejo integração com ferramentas de gerenciamento de defeitos para rastreamento de correções, para uma gestão eficaz de problemas encontrados durante os testes.",
    "Como testador, eu preciso de suporte à execução de testes de usabilidade remota e teste de usuário beta, para coletar feedback de usuários reais.",
    "Como testador, eu quero que a ferramenta forneça feedback em tempo real durante a execução dos testes, para facilitar a identificação imediata de problemas.",
    "Como testador, eu desejo integração com ferramentas de automação de infraestrutura para provisionamento e configuração automatizados, para facilitar a preparação do ambiente de teste.",
    "Como testador, eu preciso de suporte à execução de testes de comparação de desempenho para versões anteriores e atuais do aplicativo, para avaliar o impacto de mudanças no desempenho."
]

# %%
#sem_pontuacao = re.findall(r'\b(^[^A-Za-z])\b', historias_usuario, re.IGNORECASE)

# %%
class ProcessadorHistoriasUsuario:
    def __init__(self):
        nltk.download('punkt')
        nltk.download('stopwords')
        nltk.download('wordnet')
        self.lemmatizer = WordNetLemmatizer()
        self.stop_words = set(stopwords.words('portuguese'))

    def processar_historias_usuario(self, historias_usuario):
        freq_dists = []
        for historia_usuario in historias_usuario:
            tokens = word_tokenize(historia_usuario)
            tokens = [token.lower() for token in tokens if token not in string.punctuation]
            tokens = [token for token in tokens if token not in self.stop_words]
            tokens = [self.lemmatizer.lemmatize(token) for token in tokens]
            freq_dist = FreqDist(tokens)
            freq_dists.append(freq_dist)
        return freq_dists

# %%
processador = ProcessadorHistoriasUsuario()
freq_dists = processador.processar_historias_usuario(historias_usuario)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
unicas = set()
for freq_dist in freq_dists:
    unicas.update(freq_dist.keys())

print("Total de palavras únicas:", len(unicas))
print("Diversidade Lexica:", len(unicas) / len(freq_dists))
# Out:
# Total de palavras únicas: 262
# Diversidade Lexica: 5.137254901960785

# %%
for palavra, freq_dist in enumerate(freq_dists):
    print(f"História de Usuário {palavra+1}: {freq_dist.most_common(5)}")
# Out:
# História de Usuário 1: [('aplicativo', 2), ('testador', 1), ('quero', 1), ('jeito', 1), ('fácil', 1)]
# História de Usuário 2: [('ferramenta', 2), ('testador', 1), ('quero', 1), ('maneira', 1), ('ensinar', 1)]
# História de Usuário 3: [('casos', 2), ('teste', 2), ('testador', 1), ('quero', 1), ('ferramenta', 1)]
# História de Usuário 4: [('testador', 1), ('quero', 1), ('ferramenta', 1), ('integrada', 1), ('outras', 1)]
# História de Usuário 5: [('testador', 1), ('quero', 1), ('ferramenta', 1), ('gere', 1), ('casos', 1)]
# História de Usuário 6: [('teste', 2), ('testador', 1), ('quero', 1), ('integração', 1), ('outras', 1)]
# História de Usuário 7: [('testis', 2), ('testador', 1), ('quero', 1), ('relatórios', 1), ('detalhados', 1)]
# História de Usuário 8: [('teste', 2), ('testador', 1), ('desejo', 1), ('ferramenta', 1), ('identifique', 1)]
# História de Usuário 9: [('uso', 2), ('testador', 1), ('preciso', 1), ('ferramenta', 1), ('sugira', 1)]
# História de Usuário 10: [('testador', 1), ('quero', 1), ('sugestões', 1), ('base', 1), ('padrões', 1)]
# História de Usuário 11: [('testis', 2), ('diferentes', 2), ('testador', 1), ('desejo', 1), ('suporte', 1)]
# História de Usuário 12: [('testador', 1), ('preciso', 1), ('ferramenta', 1), ('detecte', 1), ('automaticamente', 1)]
# História de Usuário 13: [('mudanças', 2), ('testador', 1), ('quero', 1), ('integração', 1), ('sistemas', 1)]
# História de Usuário 14: [('taxon', 2), ('testador', 1), ('desejo', 1), ('métricas', 1), ('detalhadas', 1)]
# História de Usuário 15: [('desempenho', 2), ('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1)]
# História de Usuário 16: [('testador', 1), ('quero', 1), ('análise', 1), ('automática', 1), ('resultados', 1)]
# História de Usuário 17: [('testador', 1), ('desejo', 1), ('simular', 1), ('cenários', 1), ('teste', 1)]
# História de Usuário 18: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 19: [('teste', 2), ('testador', 1), ('quero', 1), ('identificação', 1), ('automática', 1)]
# História de Usuário 20: [('testador', 1), ('desejo', 1), ('integração', 1), ('fácil', 1), ('ferramentas', 1)]
# História de Usuário 21: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 22: [('testador', 1), ('quero', 1), ('ferramenta', 1), ('crie', 1), ('automaticamente', 1)]
# História de Usuário 23: [('desempenho', 2), ('testador', 1), ('desejo', 1), ('integração', 1), ('ferramentas', 1)]
# História de Usuário 24: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 25: [('teste', 2), ('testador', 1), ('quero', 1), ('geração', 1), ('automática', 1)]
# História de Usuário 26: [('testador', 1), ('desejo', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 27: [('integração', 2), ('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1)]
# História de Usuário 28: [('testador', 1), ('quero', 1), ('identificação', 1), ('automática', 1), ('casos', 1)]
# História de Usuário 29: [('testador', 1), ('desejo', 1), ('identificação', 1), ('automática', 1), ('dependências', 1)]
# História de Usuário 30: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 31: [('testador', 1), ('quero', 1), ('ferramenta', 1), ('identifique', 1), ('automaticamente', 1)]
# História de Usuário 32: [('testador', 1), ('desejo', 1), ('simulação', 1), ('cenários', 1), ('teste', 1)]
# História de Usuário 33: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 34: [('testador', 1), ('quero', 1), ('geração', 1), ('automática', 1), ('relatórios', 1)]
# História de Usuário 35: [('testador', 1), ('desejo', 1), ('rastreamento', 1), ('automático', 1), ('resultados', 1)]
# História de Usuário 36: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 37: [('testador', 1), ('quero', 1), ('sugestões', 1), ('automáticas', 1), ('aprimorar', 1)]
# História de Usuário 38: [('testador', 1), ('desejo', 1), ('ferramenta', 1), ('aprenda', 1), ('resultados', 1)]
# História de Usuário 39: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 40: [('código', 2), ('testador', 1), ('quero', 1), ('integração', 1), ('ferramentas', 1)]
# História de Usuário 41: [('integração', 2), ('sistema', 2), ('usuário', 2), ('testador', 1), ('desejo', 1)]
# História de Usuário 42: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 43: [('testador', 1), ('quero', 1), ('ferramenta', 1), ('sugira', 1), ('casos', 1)]
# História de Usuário 44: [('usuário', 2), ('testador', 1), ('desejo', 1), ('integração', 1), ('ferramentas', 1)]
# História de Usuário 45: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 46: [('teste', 2), ('testador', 1), ('quero', 1), ('ferramenta', 1), ('sugira', 1)]
# História de Usuário 47: [('testador', 1), ('desejo', 1), ('integração', 1), ('ferramentas', 1), ('gerenciamento', 1)]
# História de Usuário 48: [('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1), ('testis', 1)]
# História de Usuário 49: [('testador', 1), ('quero', 1), ('ferramenta', 1), ('forneça', 1), ('feedback', 1)]
# História de Usuário 50: [('testador', 1), ('desejo', 1), ('integração', 1), ('ferramentas', 1), ('automação', 1)]
# História de Usuário 51: [('desempenho', 2), ('testador', 1), ('preciso', 1), ('suporte', 1), ('execução', 1)]

# %%
nome, valor = zip(*freq_dists[0].most_common(5))
fig, ax = plt.subplots(figsize=(6,5))
sns.barplot(x=np.array(nome), y=np.array(valor), ax=ax)
plt.show()

# %%
nome,valor = zip(*freq_dist.most_common(5))
fig, ax = plt.subplots(figsize=(6,5))
sns.barplot(x=np.array(nome), y=np.array(valor), ax=ax)
# Out:
# <Axes: >

# %%
for i, freq_dist in enumerate(freq_dists):
    historia_usuario = " ".join(freq_dist.keys())
    resultado = classificador(historia_usuario, candidate_labels=rotulos)
    top_label = resultado['labels'][0]
    confianca = resultado['scores'][0]
    print(f"História de Usuário {i+1}: Rótulo Previsto: {top_label}, Confiança: {confianca:.2f}")
# Out:
# História de Usuário 1: Rótulo Previsto: testador, Confiança: 0.56
# História de Usuário 2: Rótulo Previsto: testador, Confiança: 0.69
# História de Usuário 3: Rótulo Previsto: testador, Confiança: 0.60
# História de Usuário 4: Rótulo Previsto: testador, Confiança: 0.70
# História de Usuário 5: Rótulo Previsto: testador, Confiança: 0.63
# História de Usuário 6: Rótulo Previsto: testador, Confiança: 0.73
# História de Usuário 7: Rótulo Previsto: testador, Confiança: 0.68
# História de Usuário 8: Rótulo Previsto: testador, Confiança: 0.53
# História de Usuário 9: Rótulo Previsto: testador, Confiança: 0.44
# História de Usuário 10: Rótulo Previsto: testador, Confiança: 0.79
# História de Usuário 11: Rótulo Previsto: testador, Confiança: 0.56
# História de Usuário 12: Rótulo Previsto: testador, Confiança: 0.64
# História de Usuário 13: Rótulo Previsto: testador, Confiança: 0.78
# História de Usuário 14: Rótulo Previsto: testador, Confiança: 0.72
# História de Usuário 15: Rótulo Previsto: testador, Confiança: 0.58
# História de Usuário 16: Rótulo Previsto: testador, Confiança: 0.64

# %%
roberta(f"Resultado: {freq_dists}")
# Out:
# [{'entity_group': 'LABEL_1',
#   'score': 0.54755,
#   'word': ' resultado',
#   'start': 0,
#   'end': 9},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5525551,
#   'word': ' : [ fre',
#   'start': 10,
#   'end': 15},
#  {'entity_group': 'LABEL_1',
#   'score': 0.691658,
#   'word': 'q',
#   'start': 15,
#   'end': 16},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6181933,
#   'word': "dist ( { '",
#   'start': 16,
#   'end': 23},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5746949,
#   'word': ' aplica',
#   'start': 24,
#   'end': 29},
#  {'entity_group': 'LABEL_0',
#   'score': 0.56658643,
#   'word': "tivo '",
#   'start': 29,
#   'end': 34},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5648897,
#   'word': ' :',
#   'start': 35,
#   'end': 35},
#  {'entity_group': 'LABEL_0',
#   'score': 0.63246936,
#   'word': " 2 , ' testador '",
#   'start': 37,
#   'end': 49},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5783365,
#   'word': ' :',
#   'start': 50,
#   'end': 50},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6034041,
#   'word': " 1 , ' quero '",
#   'start': 52,
#   'end': 61},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5858954,
#   'word': ' :',
#   'start': 62,
#   'end': 62},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6048569,
#   'word': " 1 , '",
#   'start': 64,
#   'end': 67},
#  {'entity_group': 'LABEL_1',
#   'score': 0.50370955,
#   'word': ' je',
#   'start': 68,
#   'end': 69},
#  {'entity_group': 'LABEL_0',
#   'score': 0.61897457,
#   'word': "ito '",
#   'start': 69,
#   'end': 73},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6155837,
#   'word': ' :',
#   'start': 74,
#   'end': 74},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6016197,
#   'word': " 1 , ' facil",
#   'start': 76,
#   'end': 84},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5905101,
#   'word': " ' :",
#   'start': 85,
#   'end': 86},
#  {'entity_group': 'LABEL_0',
#   'score': 0.54948086,
#   'word': " 1 , '",
#   'start': 88,
#   'end': 91},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5621493,
#   'word': " incluir ' :",
#   'start': 92,
#   'end': 100},
#  {'entity_group': 'LABEL_0',
#   'score': 0.54931027,
#   'word': " 1 , '",
#   'start': 102,
#   'end': 105},
#  {'entity_group': 'LABEL_1',
#   'score': 0.59702283,
#   'word': " requisitos ' :",
#   'start': 106,
#   'end': 117},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5270018,
#   'word': " 1 , '",
#   'start': 119,
#   'end': 122},
#  {'entity_group': 'LABEL_1',
#   'score': 0.57094425,
#   'word': " ferramenta ' :",
#   'start': 123,
#   'end': 134},
#  {'entity_group': 'LABEL_0',
#   'score': 0.54877377,
#   'word': " 1 , '",
#   'start': 136,
#   'end': 139},
#  {'entity_group': 'LABEL_1',
#   'score': 0.51121783,
#   'word': ' dr',
#   'start': 140,
#   'end': 141},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6092962,
#   'word': 'l - mob',
#   'start': 141,
#   'end': 146},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5391919,
#   'word': "test ' :",
#   'start': 146,
#   'end': 152},
#  {'entity_group': 'LABEL_0',
#   'score': 0.57714754,
#   'word': " 1 , '",
#   'start': 154,
#   'end': 157},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5791111,
#   'word': " criar ' :",
#   'start': 158,
#   'end': 164},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5921061,
#   'word': ' 1 , . . . } ) ,',
#   'start': 166,
#   'end': 174},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6242213,
#   'word': ' freq',
#   'start': 176,
#   'end': 179},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6237778,
#   'word': 'dist (',
#   'start': 179,
#   'end': 184},
#  {'entity_group': 'LABEL_1',
#   'score': 0.54787195,
#   'word': ' {',
#   'start': 185,
#   'end': 185},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5343311,
#   'word': " ' ferramenta",
#   'start': 186,
#   'end': 196},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5561221,
#   'word': " ' :",
#   'start': 197,
#   'end': 198},
#  {'entity_group': 'LABEL_0',
#   'score': 0.60618037,
#   'word': " 2 , ' testador",
#   'start': 200,
#   'end': 211},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5658685,
#   'word': " ' :",
#   'start': 212,
#   'end': 213},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5887991,
#   'word': " 1 , ' quero",
#   'start': 215,
#   'end': 223},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5816535,
#   'word': " ' :",
#   'start': 224,
#   'end': 225},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5485413,
#   'word': " 1 , ' maneira",
#   'start': 227,
#   'end': 237},
#  {'entity_group': 'LABEL_1',
#   'score': 0.61436296,
#   'word': " ' :",
#   'start': 238,
#   'end': 239},
#  {'entity_group': 'LABEL_0',
#   'score': 0.53993005,
#   'word': ' 1 ,',
#   'start': 241,
#   'end': 242},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5195106,
#   'word': " ' ens",
#   'start': 244,
#   'end': 247},
#  {'entity_group': 'LABEL_0',
#   'score': 0.51815283,
#   'word': 'inar',
#   'start': 247,
#   'end': 251},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5974876,
#   'word': " ' :",
#   'start': 252,
#   'end': 253},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5478265,
#   'word': ' 1 ,',
#   'start': 255,
#   'end': 256},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5086734,
#   'word': " ' dr",
#   'start': 258,
#   'end': 260},
#  {'entity_group': 'LABEL_0',
#   'score': 0.57293606,
#   'word': 'l - mob',
#   'start': 260,
#   'end': 265},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5639439,
#   'word': "test ' :",
#   'start': 265,
#   'end': 271},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5534557,
#   'word': ' 1 ,',
#   'start': 273,
#   'end': 274},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5027186,
#   'word': " '",
#   'start': 276,
#   'end': 276},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6370915,
#   'word': ' entender',
#   'start': 277,
#   'end': 284},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6015228,
#   'word': " ' :",
#   'start': 285,
#   'end': 286},
#  {'entity_group': 'LABEL_0',
#   'score': 0.56445956,
#   'word': " 1 , '",
#   'start': 288,
#   'end': 291},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5541545,
#   'word': " requisitos ' :",
#   'start': 292,
#   'end': 303},
#  {'entity_group': 'LABEL_0',
#   'score': 0.59306645,
#   'word': " 1 , '",
#   'start': 305,
#   'end': 308},
#  {'entity_group': 'LABEL_1',
#   'score': 0.59290993,
#   'word': ' aplica',
#   'start': 309,
#   'end': 314},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5428115,
#   'word': "tivo '",
#   'start': 314,
#   'end': 319},
#  {'entity_group': 'LABEL_1',
#   'score': 0.60298157,
#   'word': ' :',
#   'start': 320,
#   'end': 320},
#  {'entity_group': 'LABEL_0',
#   'score': 0.64455855,
#   'word': " 1 , ' usando",
#   'start': 322,
#   'end': 331},
#  {'entity_group': 'LABEL_1',
#   'score': 0.55531585,
#   'word': " ' :",
#   'start': 332,
#   'end': 333},
#  {'entity_group': 'LABEL_0',
#   'score': 0.61323255,
#   'word': ' 1 , . . . } ) ,',
#   'start': 335,
#   'end': 343},
#  {'entity_group': 'LABEL_1',
#   'score': 0.63334084,
#   'word': ' freq',
#   'start': 345,
#   'end': 348},
#  {'entity_group': 'LABEL_0',
#   'score': 0.63289386,
#   'word': 'dist (',
#   'start': 348,
#   'end': 353},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5245611,
#   'word': ' {',
#   'start': 354,
#   'end': 354},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5897486,
#   'word': " ' casos",
#   'start': 355,
#   'end': 360},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5737934,
#   'word': " ' :",
#   'start': 361,
#   'end': 362},
#  {'entity_group': 'LABEL_0',
#   'score': 0.62036073,
#   'word': " 2 , ' teste",
#   'start': 364,
#   'end': 372},
#  {'entity_group': 'LABEL_1',
#   'score': 0.58781797,
#   'word': " ' :",
#   'start': 373,
#   'end': 374},
#  {'entity_group': 'LABEL_0',
#   'score': 0.60807025,
#   'word': " 2 , ' testador",
#   'start': 376,
#   'end': 387},
#  {'entity_group': 'LABEL_1',
#   'score': 0.55649024,
#   'word': " ' :",
#   'start': 388,
#   'end': 389},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5861243,
#   'word': " 1 , ' quero",
#   'start': 391,
#   'end': 399},
#  {'entity_group': 'LABEL_1',
#   'score': 0.57989323,
#   'word': " ' :",
#   'start': 400,
#   'end': 401},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5409436,
#   'word': " 1 , ' ferramenta",
#   'start': 403,
#   'end': 416},
#  {'entity_group': 'LABEL_1',
#   'score': 0.58246267,
#   'word': " ' :",
#   'start': 417,
#   'end': 418},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5692083,
#   'word': " 1 , ' gere",
#   'start': 420,
#   'end': 427},
#  {'entity_group': 'LABEL_1',
#   'score': 0.56377643,
#   'word': " ' :",
#   'start': 428,
#   'end': 429},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5729794,
#   'word': " 1 , '",
#   'start': 431,
#   'end': 434},
#  {'entity_group': 'LABEL_1',
#   'score': 0.57379246,
#   'word': " abrangentes ' :",
#   'start': 435,
#   'end': 447},
#  {'entity_group': 'LABEL_0',
#   'score': 0.56284493,
#   'word': " 1 , '",
#   'start': 449,
#   'end': 452},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5697282,
#   'word': ' cub',
#   'start': 453,
#   'end': 455},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6072889,
#   'word': "ram '",
#   'start': 455,
#   'end': 459},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5956715,
#   'word': ' :',
#   'start': 460,
#   'end': 460},
#  {'entity_group': 'LABEL_0',
#   'score': 0.58804584,
#   'word': " 1 , '",
#   'start': 462,
#   'end': 465},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5207234,
#   'word': ' integralmente',
#   'start': 466,
#   'end': 478},
#  {'entity_group': 'LABEL_0',
#   'score': 0.51671994,
#   'word': " '",
#   'start': 479,
#   'end': 479},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5876872,
#   'word': ' :',
#   'start': 480,
#   'end': 480},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6061525,
#   'word': " 1 , ' todos '",
#   'start': 482,
#   'end': 491},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6123364,
#   'word': ' :',
#   'start': 492,
#   'end': 492},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6160042,
#   'word': ' 1 , . . . } ) ,',
#   'start': 494,
#   'end': 502},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6397724,
#   'word': ' freq',
#   'start': 504,
#   'end': 507},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6276696,
#   'word': 'dist (',
#   'start': 507,
#   'end': 512},
#  {'entity_group': 'LABEL_1',
#   'score': 0.50440633,
#   'word': ' {',
#   'start': 513,
#   'end': 513},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6369001,
#   'word': " ' testador",
#   'start': 514,
#   'end': 522},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5763036,
#   'word': " ' :",
#   'start': 523,
#   'end': 524},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6139245,
#   'word': " 1 , ' quero",
#   'start': 526,
#   'end': 534},
#  {'entity_group': 'LABEL_1',
#   'score': 0.55142313,
#   'word': " ' :",
#   'start': 535,
#   'end': 536},
#  {'entity_group': 'LABEL_0',
#   'score': 0.54692817,
#   'word': " 1 , ' ferramenta",
#   'start': 538,
#   'end': 551},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5798282,
#   'word': " ' :",
#   'start': 552,
#   'end': 553},
#  {'entity_group': 'LABEL_0',
#   'score': 0.58822113,
#   'word': " 1 , '",
#   'start': 555,
#   'end': 558},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5808397,
#   'word': " integrada ' : 1",
#   'start': 559,
#   'end': 571},
#  {'entity_group': 'LABEL_0',
#   'score': 0.55793935,
#   'word': " , ' outras '",
#   'start': 572,
#   'end': 581},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6004869,
#   'word': ' :',
#   'start': 582,
#   'end': 582},
#  {'entity_group': 'LABEL_0',
#   'score': 0.55398893,
#   'word': " 1 , '",
#   'start': 584,
#   'end': 587},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5303086,
#   'word': ' ferramentas',
#   'start': 588,
#   'end': 598},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5234742,
#   'word': " '",
#   'start': 599,
#   'end': 599},
#  {'entity_group': 'LABEL_1',
#   'score': 0.59017235,
#   'word': ' :',
#   'start': 600,
#   'end': 600},
#  {'entity_group': 'LABEL_0',
#   'score': 0.62864995,
#   'word': " 1 , '",
#   'start': 602,
#   'end': 605},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6857679,
#   'word': ' gerencia',
#   'start': 606,
#   'end': 613},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5934148,
#   'word': "mento '",
#   'start': 613,
#   'end': 619},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6494486,
#   'word': ' :',
#   'start': 620,
#   'end': 620},
#  {'entity_group': 'LABEL_0',
#   'score': 0.59671324,
#   'word': " 1 , ' permitindo",
#   'start': 622,
#   'end': 635},
#  {'entity_group': 'LABEL_1',
#   'score': 0.57495606,
#   'word': " ' :",
#   'start': 636,
#   'end': 637},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5794692,
#   'word': " 1 , ' sincronizacao",
#   'start': 639,
#   'end': 655},
#  {'entity_group': 'LABEL_1',
#   'score': 0.55418485,
#   'word': " ' :",
#   'start': 656,
#   'end': 657},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6368037,
#   'word': " 1 , ' automatica",
#   'start': 659,
#   'end': 672},
#  {'entity_group': 'LABEL_1',
#   'score': 0.57204425,
#   'word': " ' :",
#   'start': 673,
#   'end': 674},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6027329,
#   'word': ' 1 , . . . } ) ,',
#   'start': 676,
#   'end': 684},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6474293,
#   'word': ' freq',
#   'start': 686,
#   'end': 689},
#  {'entity_group': 'LABEL_0',
#   'score': 0.61887926,
#   'word': 'dist (',
#   'start': 689,
#   'end': 694},
#  {'entity_group': 'LABEL_1',
#   'score': 0.52610725,
#   'word': ' {',
#   'start': 695,
#   'end': 695},
#  {'entity_group': 'LABEL_0',
#   'score': 0.60465294,
#   'word': " ' testador",
#   'start': 696,
#   'end': 704},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5912865,
#   'word': " ' :",
#   'start': 705,
#   'end': 706},
#  {'entity_group': 'LABEL_0',
#   'score': 0.59484786,
#   'word': " 1 , ' quero",
#   'start': 708,
#   'end': 716},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5867704,
#   'word': " ' :",
#   'start': 717,
#   'end': 718},
#  {'entity_group': 'LABEL_0',
#   'score': 0.544502,
#   'word': " 1 , ' ferramenta",
#   'start': 720,
#   'end': 733},
#  {'entity_group': 'LABEL_1',
#   'score': 0.58797365,
#   'word': " ' :",
#   'start': 734,
#   'end': 735},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5774319,
#   'word': " 1 , ' gere",
#   'start': 737,
#   'end': 744},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5642267,
#   'word': " ' :",
#   'start': 745,
#   'end': 746},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5780965,
#   'word': " 1 , ' casos '",
#   'start': 748,
#   'end': 757},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6446873,
#   'word': ' :',
#   'start': 758,
#   'end': 758},
#  {'entity_group': 'LABEL_0',
#   'score': 0.58866525,
#   'word': " 1 , ' teste",
#   'start': 760,
#   'end': 768},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5912184,
#   'word': " ' :",
#   'start': 769,
#   'end': 770},
#  {'entity_group': 'LABEL_0',
#   'score': 0.58024406,
#   'word': " 1 , ' completos",
#   'start': 772,
#   'end': 784},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5936978,
#   'word': " ' :",
#   'start': 785,
#   'end': 786},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5758241,
#   'word': " 1 , '",
#   'start': 788,
#   'end': 791},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5875532,
#   'word': " funcionais ' :",
#   'start': 792,
#   'end': 803},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5508178,
#   'word': " 1 , '",
#   'start': 805,
#   'end': 808},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5798676,
#   'word': ' cub',
#   'start': 809,
#   'end': 811},
#  {'entity_group': 'LABEL_0',
#   'score': 0.605985,
#   'word': "ram '",
#   'start': 811,
#   'end': 815},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6077504,
#   'word': ' :',
#   'start': 816,
#   'end': 816},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5794819,
#   'word': " 1 , ' todos",
#   'start': 818,
#   'end': 826},
#  {'entity_group': 'LABEL_1',
#   'score': 0.58516014,
#   'word': " ' :",
#   'start': 827,
#   'end': 828},
#  {'entity_group': 'LABEL_0',
#   'score': 0.612413,
#   'word': ' 1 ,',
#   'start': 830,
#   'end': 831},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5033672,
#   'word': ' .',
#   'start': 833,
#   'end': 833},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5959081,
#   'word': ' . . } ) ,',
#   'start': 834,
#   'end': 838},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6362916,
#   'word': ' freq',
#   'start': 840,
#   'end': 843},
#  {'entity_group': 'LABEL_0',
#   'score': 0.61476153,
#   'word': 'dist (',
#   'start': 843,
#   'end': 848},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5290135,
#   'word': " { '",
#   'start': 849,
#   'end': 850},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5502473,
#   'word': ' teste',
#   'start': 851,
#   'end': 855},
#  {'entity_group': 'LABEL_1',
#   'score': 0.60649586,
#   'word': " ' :",
#   'start': 856,
#   'end': 857},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5953649,
#   'word': " 2 , ' testador",
#   'start': 859,
#   'end': 870},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5968075,
#   'word': " ' :",
#   'start': 871,
#   'end': 872},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5831925,
#   'word': " 1 , ' quero",
#   'start': 874,
#   'end': 882},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5854554,
#   'word': " ' :",
#   'start': 883,
#   'end': 884},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5483485,
#   'word': " 1 , '",
#   'start': 886,
#   'end': 889},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5736723,
#   'word': " integracao ' :",
#   'start': 890,
#   'end': 901},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5496919,
#   'word': " 1 , ' outras '",
#   'start': 903,
#   'end': 913},
#  {'entity_group': 'LABEL_1',
#   'score': 0.58993936,
#   'word': ' :',
#   'start': 914,
#   'end': 914},
#  {'entity_group': 'LABEL_0',
#   'score': 0.54172903,
#   'word': " 1 , '",
#   'start': 916,
#   'end': 919},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5707576,
#   'word': " ferramentas ' :",
#   'start': 920,
#   'end': 932},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5609898,
#   'word': " 1 , '",
#   'start': 934,
#   'end': 937},
#  {'entity_group': 'LABEL_1',
#   'score': 0.695808,
#   'word': ' gerencia',
#   'start': 938,
#   'end': 945},
#  {'entity_group': 'LABEL_0',
#   'score': 0.64184123,
#   'word': 'mento',
#   'start': 945,
#   'end': 950},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6109531,
#   'word': " ' :",
#   'start': 951,
#   'end': 952},
#  {'entity_group': 'LABEL_0',
#   'score': 0.550359,
#   'word': " 1 , ' sincronizar",
#   'start': 954,
#   'end': 968},
#  {'entity_group': 'LABEL_1',
#   'score': 0.61607915,
#   'word': " ' :",
#   'start': 969,
#   'end': 970},
#  {'entity_group': 'LABEL_0',
#   'score': 0.55467016,
#   'word': " 1 , ' automaticamente",
#   'start': 972,
#   'end': 990},
#  {'entity_group': 'LABEL_1',
#   'score': 0.58723444,
#   'word': " ' : 1",
#   'start': 991,
#   'end': 994},
#  {'entity_group': 'LABEL_0',
#   'score': 0.588553,
#   'word': " , '",
#   'start': 995,
#   'end': 997},
#  {'entity_group': 'LABEL_1',
#   'score': 0.587155,
#   'word': " requisitos ' : 1",
#   'start': 998,
#   'end': 1011},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6798766,
#   'word': ' ,',
#   'start': 1012,
#   'end': 1012},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5158407,
#   'word': ' .',
#   'start': 1014,
#   'end': 1014},
#  {'entity_group': 'LABEL_0',
#   'score': 0.5994344,
#   'word': ' . . } ) ,',
#   'start': 1015,
#   'end': 1019},
#  {'entity_group': 'LABEL_1',
#   'score': 0.6207925,
#   'word': ' freq',
#   'start': 1021,
#   'end': 1024},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6080195,
#   'word': "dist ( { ' testis '",
#   'start': 1024,
#   'end': 1038},
#  {'entity_group': 'LABEL_1',
#   'score': 0.562795,
#   'word': ' :',
#   'start': 1039,
#   'end': 1039},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6166359,
#   'word': " 2 , ' testador '",
#   'start': 1041,
#   'end': 1053},
#  {'entity_group': 'LABEL_1',
#   'score': 0.56662107,
#   'word': ' :',
#   'start': 1054,
#   'end': 1054},
#  {'entity_group': 'LABEL_0',
#   'score': 0.62436974,
#   'word': " 1 , ' quero '",
#   'start': 1056,
#   'end': 1065},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5933338,
#   'word': ' :',
#   'start': 1066,
#   'end': 1066},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6221597,
#   'word': " 1 , ' relatorios",
#   'start': 1068,
#   'end': 1081},
#  {'entity_group': 'LABEL_1',
#   'score': 0.5969238,
#   'word': " ' :",
#   'start': 1082,
#   'end': 1083},
#  {'entity_group': 'LABEL_0',
#   'score': 0.59240496,
#   'word': " 1 , ' detalhados",
#   'start': 1085,
#   'end': 1098},
#  {'entity_group': 'LABEL_1',
#   'score': 0.60878384,
#   'word': " ' :",
#   'start': 1099,
#   'end': 1100},
#  {'entity_group': 'LABEL_0',
#   'score': 0.6022284,
#   'word': " 1 , ' sobre",
#   'start': 1102,
#   'end': 1110},
#  {'entity_group': 'LABEL_1',
#   'score': 0.60029674,
#   'word': " ' :",
#   'start': 1111,
#   'end': 1112},
#  {'entity_group': 'LABEL_0',
#   'score': 0.66091526,
#   'word': ' 1 ,',
#   'start': 1114,
#   'end': 1115}]

# %%
for i, freq_dist in enumerate(freq_dists):
    historia_usuario = " ".join(freq_dist.keys())
    resultado = roberta(f"História de Usuário {i+1}: {historia_usuario}")
    print(f"Resultado para História de Usuário {i+1}: {resultado}")
# Out:
# Resultado para História de Usuário 1: [{'entity_group': 'LABEL_0', 'score': 0.7062716, 'word': ' historia de usuario 1 : testador quero jeito facil incluir requisitos', 'start': 0, 'end': 68}, {'entity_group': 'LABEL_1', 'score': 0.5115314, 'word': ' aplica', 'start': 70, 'end': 75}, {'entity_group': 'LABEL_0', 'score': 0.57602555, 'word': 'tivo ferramenta', 'start': 75, 'end': 90}, {'entity_group': 'LABEL_1', 'score': 0.500364, 'word': ' dr', 'start': 92, 'end': 93}, {'entity_group': 'LABEL_0', 'score': 0.5926132, 'word': 'l - mobtest', 'start': 93, 'end': 102}, {'entity_group': 'LABEL_1', 'score': 0.51542115, 'word': ' criar', 'start': 104, 'end': 108}, {'entity_group': 'LABEL_0', 'score': 0.6812933, 'word': ' casos teste cubram tudo precisa fazer ter gastar tempo', 'start': 110, 'end': 163}, {'entity_group': 'LABEL_1', 'score': 0.59035856, 'word': ' escreve', 'start': 165, 'end': 171}, {'entity_group': 'LABEL_0', 'score': 0.6606543, 'word': 'ndo manualmente', 'start': 171, 'end': 186}]
# Resultado para História de Usuário 2: [{'entity_group': 'LABEL_0', 'score': 0.6659288, 'word': ' historia de usuario 2 : testador quero maneira ensinar ferramenta drl - mobtest entender requisitos aplicativo usando nlp fazer gere testis automaticamente', 'start': 0, 'end': 152}]
# Resultado para História de Usuário 3: [{'entity_group': 'LABEL_0', 'score': 0.67341214, 'word': ' historia de usuario 3 : testador quero ferramenta gere casos teste abrangentes cubram integralmente todos requisitos aplicativo assegurando software completo funcional depender exclusivamente criacao manual', 'start': 0, 'end': 205}]
# Resultado para História de Usuário 4: [{'entity_group': 'LABEL_0', 'score': 0.6619262, 'word': ' historia de usuario 4 : testador quero ferramenta integrada outras ferramentas', 'start': 0, 'end': 77}, {'entity_group': 'LABEL_1', 'score': 0.6194042, 'word': ' gerenciamento', 'start': 79, 'end': 91}, {'entity_group': 'LABEL_0', 'score': 0.6300618, 'word': ' permitindo sincronizacao automatica requisitos facilitando processo criacao casos testis', 'start': 93, 'end': 180}]
# Resultado para História de Usuário 5: [{'entity_group': 'LABEL_0', 'score': 0.67415035, 'word': ' historia de usuario 5 : testador quero ferramenta gere casos teste completos funcionais cubram todos requisitos aplicativo garantir cobertura abrangente durante testis', 'start': 0, 'end': 166}]
# Resultado para História de Usuário 6: [{'entity_group': 'LABEL_0', 'score': 0.66695994, 'word': ' historia de usuario 6 : testador quero integracao outras ferramentas', 'start': 0, 'end': 67}, {'entity_group': 'LABEL_1', 'score': 0.73294234, 'word': ' gerencia', 'start': 69, 'end': 76}, {'entity_group': 'LABEL_0', 'score': 0.5799966, 'word': 'mento sincronizar automaticamente requisitos facilitar criacao casos teste visando melhorar eficiencia precisao processo', 'start': 76, 'end': 196}]
# Resultado para História de Usuário 7: [{'entity_group': 'LABEL_0', 'score': 0.6552578, 'word': ' historia de usuario 7 : testador quero relatorios detalhados sobre cobertura testis analise precisa durante execucao fim avaliar qualidade extensao realizados', 'start': 0, 'end': 157}]
# Resultado para História de Usuário 8: [{'entity_group': 'LABEL_0', 'score': 0.67637265, 'word': ' historia de usuario 8 : testador desejo ferramenta identifique automaticamente casos teste criticos priorizar analise visando', 'start': 0, 'end': 124}, {'entity_group': 'LABEL_1', 'score': 0.5508721, 'word': ' direcionar', 'start': 126, 'end': 135}, {'entity_group': 'LABEL_0', 'score': 0.67452025, 'word': ' esforcos areas maior risco', 'start': 137, 'end': 162}]
# Resultado para História de Usuário 9: [{'entity_group': 'LABEL_0', 'score': 0.7130583, 'word': ' historia de usuario 9 : testador preciso ferramenta su', 'start': 0, 'end': 53}, {'entity_group': 'LABEL_1', 'score': 0.5162597, 'word': 'gira', 'start': 53, 'end': 57}, {'entity_group': 'LABEL_0', 'score': 0.6349088, 'word': ' casos teste base padroes uso real aplicativo garantir testis reflitam cenarios tipicos', 'start': 59, 'end': 144}]
# Resultado para História de Usuário 10: [{'entity_group': 'LABEL_0', 'score': 0.7210133, 'word': ' historia de usuario 10 : testador quero sugestoes base padroes falha historicos evitar problemas recorrentes software visando melhorar qualidade robus', 'start': 0, 'end': 149}, {'entity_group': 'LABEL_1', 'score': 0.5410863, 'word': 'te', 'start': 149, 'end': 151}, {'entity_group': 'LABEL_0', 'score': 0.73390806, 'word': 'z produto', 'start': 151, 'end': 160}]
# Resultado para História de Usuário 11: [{'entity_group': 'LABEL_0', 'score': 0.7034967, 'word': ' historia de usuario 11 : testador desejo suporte execucao testis automatizados diferentes dispositivos ambientes garantir consistencia confiabilidade cenarios', 'start': 0, 'end': 157}]
# Resultado para História de Usuário 12: [{'entity_group': 'LABEL_0', 'score': 0.65607953, 'word': ' historia de usuario 12 : testador preciso ferramenta detecte automaticamente mudancas requisitos ajuste casos teste correspondentes manter testis alinhados evolucao aplicativo', 'start': 0, 'end': 174}]
# Resultado para História de Usuário 13: [{'entity_group': 'LABEL_0', 'score': 0.6349181, 'word': ' historia de usuario 13 : testador quero integracao sistemas controle versao rastrear mudancas requisitos codigo - fonte visando gestao eficaz durante ciclo desenvolvimento', 'start': 0, 'end': 168}]
# Resultado para História de Usuário 14: [{'entity_group': 'LABEL_0', 'score': 0.7161103, 'word': ' historia de usuario 14 : testador desejo metricas detalhadas sobre eficacia testis incluindo taxon cobertura falha avaliar qualidade processo teste', 'start': 0, 'end': 146}]
# Resultado para História de Usuário 15: [{'entity_group': 'LABEL_0', 'score': 0.67953926, 'word': ' historia de usuario 15 : testador preciso suporte execucao testis desempenho', 'start': 0, 'end': 75}, {'entity_group': 'LABEL_1', 'score': 0.57829225, 'word': ' escalabilidade', 'start': 77, 'end': 90}, {'entity_group': 'LABEL_0', 'score': 0.6032153, 'word': ' garantir aplicativo', 'start': 92, 'end': 110}, {'entity_group': 'LABEL_1', 'score': 0.5472871, 'word': ' ate', 'start': 112, 'end': 114}, {'entity_group': 'LABEL_0', 'score': 0.6262539, 'word': 'nda requisitos sob carga', 'start': 114, 'end': 138}]
# Resultado para História de Usuário 16: [{'entity_group': 'LABEL_0', 'score': 0.69777316, 'word': ' historia de usuario 16 : testador quero analise automatica resultados testis relatorios detalhados sobre problemas encontrados fim facilitar identificacao correcao defeitos', 'start': 0, 'end': 171}]
# Resultado para História de Usuário 17: [{'entity_group': 'LABEL_0', 'score': 0.7406899, 'word': ' historia de usuario 17 : testador desejo simular cenarios teste complexos realistas garantir testis proximos realidade visando validacao precisa software', 'start': 0, 'end': 152}]
# Resultado para História de Usuário 18: [{'entity_group': 'LABEL_0', 'score': 0.7108884, 'word': ' historia de usuario 18 : testador preciso suporte execucao testis regressao automatizados garantir alteracoes codigo', 'start': 0, 'end': 115}, {'entity_group': 'LABEL_1', 'score': 0.5093202, 'word': ' introdu', 'start': 117, 'end': 123}, {'entity_group': 'LABEL_0', 'score': 0.6303143, 'word': 'zam regressoes', 'start': 123, 'end': 137}]
# Resultado para História de Usuário 19: [{'entity_group': 'LABEL_0', 'score': 0.6960822, 'word': ' historia de usuario 19 : testador quero identificacao automatica casos teste', 'start': 0, 'end': 75}, {'entity_group': 'LABEL_1', 'score': 0.5232781, 'word': ' redunda', 'start': 77, 'end': 83}, {'entity_group': 'LABEL_0', 'score': 0.6580069, 'word': 'ntes desnecessarios otimizar esforcos', 'start': 83, 'end': 120}]
# Resultado para História de Usuário 20: [{'entity_group': 'LABEL_0', 'score': 0.6672008, 'word': ' historia de usuario 20 : testador desejo integracao facil ferramentas', 'start': 0, 'end': 68}, {'entity_group': 'LABEL_1', 'score': 0.7010494, 'word': ' gerencia', 'start': 70, 'end': 77}, {'entity_group': 'LABEL_0', 'score': 0.6168527, 'word': 'mento projetos', 'start': 77, 'end': 91}, {'entity_group': 'LABEL_1', 'score': 0.5175391, 'word': ' colaboracao', 'start': 93, 'end': 103}, {'entity_group': 'LABEL_0', 'score': 0.6211562, 'word': ' eficiente outros membros equipe desenvolvimento', 'start': 105, 'end': 151}]
# Resultado para História de Usuário 21: [{'entity_group': 'LABEL_0', 'score': 0.6866172, 'word': ' historia de usuario 21 : testador preciso suporte execucao testis', 'start': 0, 'end': 64}, {'entity_group': 'LABEL_1', 'score': 0.5439906, 'word': ' usabilidade', 'start': 66, 'end': 76}, {'entity_group': 'LABEL_0', 'score': 0.60575014, 'word': ' garantir aplicativo facil', 'start': 78, 'end': 102}, {'entity_group': 'LABEL_1', 'score': 0.62850666, 'word': ' intui', 'start': 104, 'end': 108}, {'entity_group': 'LABEL_0', 'score': 0.6054601, 'word': 'tivo usar', 'start': 108, 'end': 117}]
# Resultado para História de Usuário 22: [{'entity_group': 'LABEL_0', 'score': 0.71522343, 'word': ' historia de usuario 22 : testador quero ferramenta crie automaticamente conjuntos dado teste realistas simular condicoes reais uso', 'start': 0, 'end': 129}]
# Resultado para História de Usuário 23: [{'entity_group': 'LABEL_0', 'score': 0.699766, 'word': ' historia de usuario 23 : testador desejo integracao ferramentas', 'start': 0, 'end': 62}, {'entity_group': 'LABEL_1', 'score': 0.5206189, 'word': ' monito', 'start': 64, 'end': 69}, {'entity_group': 'LABEL_0', 'score': 0.6640217, 'word': 'ramento desempenho tempo real avaliar aplicativo durante testis', 'start': 69, 'end': 132}]
# Resultado para História de Usuário 24: [{'entity_group': 'LABEL_0', 'score': 0.63340616, 'word': ' historia de usuario 24 : testador preciso suporte execucao testis localizacao internacionalizacao garantir aplicativo', 'start': 0, 'end': 116}, {'entity_group': 'LABEL_1', 'score': 0.52749175, 'word': ' compativel', 'start': 118, 'end': 127}, {'entity_group': 'LABEL_0', 'score': 0.6255745, 'word': ' diferentes idiomas regioes', 'start': 129, 'end': 154}]
# Resultado para História de Usuário 25: [{'entity_group': 'LABEL_0', 'score': 0.742898, 'word': ' historia de usuario 25 : testador quero geracao automatica dado teste sinteticos complementar casos manuais', 'start': 0, 'end': 106}]
# Resultado para História de Usuário 26: [{'entity_group': 'LABEL_0', 'score': 0.6951749, 'word': ' historia de usuario 26 : testador desejo suporte execucao testis acessibilidade garantir aplicativo acessivel todos usuarios', 'start': 0, 'end': 123}]
# Resultado para História de Usuário 27: [{'entity_group': 'LABEL_0', 'score': 0.6870684, 'word': ' historia de usuario 27 : testador preciso suporte execucao testis integracao continua garantir alteracoes codigo que', 'start': 0, 'end': 115}, {'entity_group': 'LABEL_1', 'score': 0.5395266, 'word': 'bre', 'start': 115, 'end': 118}, {'entity_group': 'LABEL_0', 'score': 0.7548195, 'word': 'm outras partes sistema', 'start': 118, 'end': 141}]
# Resultado para História de Usuário 28: [{'entity_group': 'LABEL_0', 'score': 0.71310717, 'word': ' historia de usuario 28 : testador quero identificacao automatica casos teste incompletos mal definidos garantir qualidade testis', 'start': 0, 'end': 127}]
# Resultado para História de Usuário 29: [{'entity_group': 'LABEL_0', 'score': 0.684737, 'word': ' historia de usuario 29 : testador desejo identificacao automatica dependencias casos teste garantir sequencia logica execucao testis', 'start': 0, 'end': 131}]
# Resultado para História de Usuário 30: [{'entity_group': 'LABEL_0', 'score': 0.71191865, 'word': ' historia de usuario 30 : testador preciso suporte execucao testis recuperacao desastres avaliar capacidade sistema recuperar falhas', 'start': 0, 'end': 130}]
# Resultado para História de Usuário 31: [{'entity_group': 'LABEL_0', 'score': 0.6912686, 'word': ' historia de usuario 31 : testador quero ferramenta identifique automaticamente casos teste paralelizaveis otimizar execucao testis', 'start': 0, 'end': 129}]
# Resultado para História de Usuário 32: [{'entity_group': 'LABEL_0', 'score': 0.70188695, 'word': ' historia de usuario 32 : testador desejo simulacao cenarios teste carga extremamente alta avaliar capacidade escalabilidade sistema', 'start': 0, 'end': 130}]
# Resultado para História de Usuário 33: [{'entity_group': 'LABEL_0', 'score': 0.71165746, 'word': ' historia de usuario 33 : testador preciso suporte execucao testis', 'start': 0, 'end': 64}, {'entity_group': 'LABEL_1', 'score': 0.5082709, 'word': ' compatibilidade', 'start': 66, 'end': 80}, {'entity_group': 'LABEL_0', 'score': 0.6540277, 'word': ' diferentes navegadores dispositivos garantir experiencia consistente todos usuarios', 'start': 82, 'end': 164}]
# Resultado para História de Usuário 34: [{'entity_group': 'LABEL_0', 'score': 0.70488054, 'word': ' historia de usuario 34 : testador quero geracao automatica relatorios teste personalizados comunicar eficazmente resultados testis', 'start': 0, 'end': 129}]
# Resultado para História de Usuário 35: [{'entity_group': 'LABEL_0', 'score': 0.662829, 'word': ' historia de usuario 35 : testador desejo rastreamento automatico resultados teste longo tempo identificar tendencias padroes qualidade', 'start': 0, 'end': 133}]
# Resultado para História de Usuário 36: [{'entity_group': 'LABEL_0', 'score': 0.7073932, 'word': ' historia de usuario 36 : testador preciso suporte execucao testis regressao progressiva garantir nova alteracoes quebrem funcionalidades existentes', 'start': 0, 'end': 146}]
# Resultado para História de Usuário 37: [{'entity_group': 'LABEL_0', 'score': 0.67030805, 'word': ' historia de usuario 37 : testador quero sugestoes automaticas aprimorar casos teste existentes aumentar eficiencia eficacia testis', 'start': 0, 'end': 129}]
# Resultado para História de Usuário 38: [{'entity_group': 'LABEL_0', 'score': 0.715495, 'word': ' historia de usuario 38 : testador desejo ferramenta apre', 'start': 0, 'end': 55}, {'entity_group': 'LABEL_1', 'score': 0.54134077, 'word': 'nda', 'start': 55, 'end': 58}, {'entity_group': 'LABEL_0', 'score': 0.6680217, 'word': ' resultados testis melhore sugestoes futuras otimizacao continua processo teste', 'start': 60, 'end': 137}]
# Resultado para História de Usuário 39: [{'entity_group': 'LABEL_0', 'score': 0.6829955, 'word': ' historia de usuario 39 : testador preciso suporte execucao testis seguranca automatizados identificar vulnerabilidades aplicativo', 'start': 0, 'end': 128}]
# Resultado para História de Usuário 40: [{'entity_group': 'LABEL_0', 'score': 0.67625725, 'word': ' historia de usuario 40 : testador quero integracao ferramentas analise codigo estatico identificar areas risco avaliacao abrangente qualidade', 'start': 0, 'end': 140}]
# Resultado para História de Usuário 41: [{'entity_group': 'LABEL_0', 'score': 0.68388677, 'word': ' historia de usuario 41 : testador desejo suporte execucao testis integracao sistema teste aceitacao usuario validar diferentes partes conformidade', 'start': 0, 'end': 145}, {'entity_group': 'LABEL_1', 'score': 0.5193986, 'word': ' requisitos', 'start': 147, 'end': 156}]
# Resultado para História de Usuário 42: [{'entity_group': 'LABEL_0', 'score': 0.67478204, 'word': ' historia de usuario 42 : testador preciso suporte execucao testis confiabilidade disponibilidade garantir aplicativo sempre disponivel funcione corretamente', 'start': 0, 'end': 155}]
# Resultado para História de Usuário 43: [{'entity_group': 'LABEL_0', 'score': 0.70891005, 'word': ' historia de usuario 43 : testador quero ferramenta su', 'start': 0, 'end': 52}, {'entity_group': 'LABEL_1', 'score': 0.5019328, 'word': 'gira', 'start': 52, 'end': 56}, {'entity_group': 'LABEL_0', 'score': 0.63964856, 'word': ' casos teste base modelos qualidade software reconhecidos garantir abordagem abrangente', 'start': 58, 'end': 143}, {'entity_group': 'LABEL_1', 'score': 0.5425782, 'word': ' padro', 'start': 145, 'end': 149}, {'entity_group': 'LABEL_0', 'score': 0.6091818, 'word': 'nizada testis', 'start': 149, 'end': 162}]
# Resultado para História de Usuário 44: [{'entity_group': 'LABEL_0', 'score': 0.6611115, 'word': ' historia de usuario 44 : testador desejo integracao ferramentas automacao teste interface usuario automatizar testis interacao', 'start': 0, 'end': 125}]
# Resultado para História de Usuário 45: [{'entity_group': 'LABEL_0', 'score': 0.6781574, 'word': ' historia de usuario 45 : testador preciso suporte execucao testis estresse robus', 'start': 0, 'end': 79}, {'entity_group': 'LABEL_1', 'score': 0.5238763, 'word': 'te', 'start': 79, 'end': 81}, {'entity_group': 'LABEL_0', 'score': 0.61810666, 'word': 'z avaliar estabilidade confiabilidade aplicativo sob condicoes adversas', 'start': 81, 'end': 152}]
# Resultado para História de Usuário 46: [{'entity_group': 'LABEL_0', 'score': 0.71816844, 'word': ' historia de usuario 46 : testador quero ferramenta', 'start': 0, 'end': 49}, {'entity_group': 'LABEL_1', 'score': 0.5088096, 'word': ' su', 'start': 51, 'end': 52}, {'entity_group': 'LABEL_0', 'score': 0.6203849, 'word': 'gira casos teste areas alto risco complexidade', 'start': 52, 'end': 98}, {'entity_group': 'LABEL_1', 'score': 0.5487927, 'word': ' priorizar', 'start': 100, 'end': 108}, {'entity_group': 'LABEL_0', 'score': 0.6216647, 'word': ' esforcos', 'start': 110, 'end': 117}]
# Resultado para História de Usuário 47: [{'entity_group': 'LABEL_0', 'score': 0.69418347, 'word': ' historia de usuario 47 : testador desejo integracao ferramentas', 'start': 0, 'end': 62}, {'entity_group': 'LABEL_1', 'score': 0.71527684, 'word': ' gerencia', 'start': 64, 'end': 71}, {'entity_group': 'LABEL_0', 'score': 0.65218526, 'word': 'mento defeitos rastreamento correcoes gestao eficaz problemas encontrados durante testis', 'start': 71, 'end': 159}]
# Resultado para História de Usuário 48: [{'entity_group': 'LABEL_0', 'score': 0.6870008, 'word': ' historia de usuario 48 : testador preciso suporte execucao testis', 'start': 0, 'end': 64}, {'entity_group': 'LABEL_1', 'score': 0.56869406, 'word': ' usabilidade remo', 'start': 66, 'end': 81}, {'entity_group': 'LABEL_0', 'score': 0.62113947, 'word': 'ta teste usuario beta coletar feedback usuarios reais', 'start': 81, 'end': 134}]
# Resultado para História de Usuário 49: [{'entity_group': 'LABEL_0', 'score': 0.65991586, 'word': ' historia de usuario 49 : testador quero ferramenta forneca feedback tempo real durante execucao testis facilitar identificacao imediata problemas', 'start': 0, 'end': 144}]
# Resultado para História de Usuário 50: [{'entity_group': 'LABEL_0', 'score': 0.6780158, 'word': ' historia de usuario 50 : testador desejo integracao ferramentas automacao infraestrutura provisionamento configuracao automatizados facilitar preparacao ambiente teste', 'start': 0, 'end': 166}]
# Resultado para História de Usuário 51: [{'entity_group': 'LABEL_0', 'score': 0.6817782, 'word': ' historia de usuario 51 : testador preciso suporte execucao testis comparacao desempenho versoes anteriores atuais aplicativo avaliar impacto mudancas', 'start': 0, 'end': 148}]

# %%
def extracao(freq_dist):
    frequencia = " ".join(freq_dist.keys())

    autor = None
    if "testador" in frequencia.lower():
        autor = "Testador"

    finalidade = None
    for word in ["quero", "preciso", "desejo"]:
        if word in frequencia.lower():
            pos_inicial = frequencia.lower().find(word) + len(word)
            finalidade = frequencia[pos_inicial:].strip().split(",")[0]
            break

    if "para" in frequencia.lower():
        pos_inicial = frequencia.lower().find("para") + len("para")
        objetivo = frequencia[pos_inicial:].strip()

    return autor, finalidade


for i, freq_dist in enumerate(freq_dists):
    autor, finalidade = extracao(freq_dist)
    print("História do Usuário:", historias_usuario[i])
    print("Autor:", autor)
    print("Finalidade:", finalidade)
    print()
# Out:
# História do Usuário: Como Testador eu quero um jeito mais fácil de incluir os requisitos do aplicativo na ferramenta DRL-Mobtest para criar casos de teste que cubram tudo que o aplicativo precisa fazer, sem ter que gastar muito tempo escrevendo manualmente.
# Autor: Testador
# Finalidade: jeito fácil incluir requisitos aplicativo ferramenta drl-mobtest criar casos teste cubram tudo precisa fazer ter gastar tempo escrevendo manualmente
#
# História do Usuário: Como Testador eu quero uma maneira de ensinar a ferramenta DRL-Mobtest a entender os requisitos do aplicativo usando NLP para fazer com que a ferramenta gere testes automaticamente.
# Autor: Testador
# Finalidade: maneira ensinar ferramenta drl-mobtest entender requisitos aplicativo usando nlp fazer gere testis automaticamente
#
# História do Usuário: Como Testador eu quero que a ferramenta gere casos de teste abrangentes que cubram integralmente todos os requisitos do aplicativo, assegurando que o software seja completo e funcional, sem depender exclusivamente da criação manual de casos de teste.
# Autor: Testador
# Finalidade: ferramenta gere casos teste abrangentes cubram integralmente todos requisitos aplicativo assegurando software completo funcional depender exclusivamente criação manual
#
# História do Usuário: Como Testador eu quero que a ferramenta seja integrada com outras ferramentas de gerenciamento, permitindo sincronização automática dos requisitos e facilitando o processo de criação de casos de testes.
# Autor: Testador
# Finalidade: ferramenta integrada outras ferramentas gerenciamento permitindo sincronização automática requisitos facilitando processo criação casos testis
#
# História do Usuário: Como testador, eu quero que a ferramenta gere casos de teste completos e funcionais que cubram todos os requisitos do aplicativo, para garantir uma cobertura abrangente durante os testes.
# Autor: Testador
# Finalidade: ferramenta gere casos teste completos funcionais cubram todos requisitos aplicativo garantir cobertura abrangente durante testis
#
# História do Usuário: Como testador, eu quero integração com outras ferramentas de gerenciamento para sincronizar automaticamente requisitos e facilitar a criação de casos de teste, visando melhorar a eficiência e precisão do processo de teste.
# Autor: Testador
# Finalidade: integração outras ferramentas gerenciamento sincronizar automaticamente requisitos facilitar criação casos teste visando melhorar eficiência precisão processo
#
# História do Usuário: Como testador, eu quero relatórios detalhados sobre a cobertura dos testes para análise precisa durante a execução, a fim de avaliar a qualidade e a extensão dos testes realizados.
# Autor: Testador
# Finalidade: relatórios detalhados sobre cobertura testis análise precisa durante execução fim avaliar qualidade extensão realizados
#
# História do Usuário: Como testador, eu desejo que a ferramenta identifique automaticamente os casos de teste mais críticos para priorizar a análise, visando direcionar os esforços de teste para áreas de maior risco.
# Autor: Testador
# Finalidade: ferramenta identifique automaticamente casos teste críticos priorizar análise visando direcionar esforços áreas maior risco
#
# História do Usuário: Como testador, eu preciso que a ferramenta sugira casos de teste com base em padrões de uso real do aplicativo, para garantir que os testes reflitam cenários típicos de uso.
# Autor: Testador
# Finalidade: ferramenta sugira casos teste base padrões uso real aplicativo garantir testis reflitam cenários típicos
#
# História do Usuário: Como testador, eu quero sugestões com base em padrões de falha históricos para evitar problemas recorrentes no software, visando melhorar a qualidade e a robustez do produto.
# Autor: Testador
# Finalidade: sugestões base padrões falha históricos evitar problemas recorrentes software visando melhorar qualidade robustez produto
#
# História do Usuário: Como testador, eu desejo suporte à execução de testes automatizados em diferentes dispositivos e ambientes, para garantir a consistência e a confiabilidade dos testes em diferentes cenários.
# Autor: Testador
# Finalidade: suporte execução testis automatizados diferentes dispositivos ambientes garantir consistência confiabilidade cenários
#
# História do Usuário: Como testador, eu preciso que a ferramenta detecte automaticamente mudanças nos requisitos e ajuste os casos de teste correspondentes, para manter os testes alinhados com a evolução do aplicativo.
# Autor: Testador
# Finalidade: ferramenta detecte automaticamente mudanças requisitos ajuste casos teste correspondentes manter testis alinhados evolução aplicativo
#
# História do Usuário: Como testador, eu quero integração com sistemas de controle de versão para rastrear mudanças nos requisitos e no código-fonte, visando uma gestão eficaz de mudanças durante o ciclo de desenvolvimento.
# Autor: Testador
# Finalidade: integração sistemas controle versão rastrear mudanças requisitos código-fonte visando gestão eficaz durante ciclo desenvolvimento
#
# História do Usuário: Como testador, eu desejo métricas detalhadas sobre a eficácia dos testes, incluindo taxa de cobertura e taxa de falha, para avaliar a qualidade do processo de teste.
# Autor: Testador
# Finalidade: métricas detalhadas sobre eficácia testis incluindo taxon cobertura falha avaliar qualidade processo teste
#
# História do Usuário: Como testador, eu preciso de suporte à execução de testes de desempenho e escalabilidade, para garantir que o aplicativo atenda aos requisitos de desempenho sob carga.
# Autor: Testador
# Finalidade: suporte execução testis desempenho escalabilidade garantir aplicativo atenda requisitos sob carga
#
# História do Usuário: Como testador, eu quero análise automática dos resultados dos testes para relatórios detalhados sobre problemas encontrados, a fim de facilitar a identificação e correção de defeitos.
# Autor: Testador
# Finalidade: análise automática resultados testis relatórios detalhados sobre problemas encontrados fim facilitar identificação correção defeitos
#
# História do Usuário: Como testador, eu desejo simular cenários de teste complexos e realistas para garantir testes próximos à realidade, visando uma validação mais precisa do software.
# Autor: Testador
# Finalidade: simular cenários teste complexos realistas garantir testis próximos realidade visando validação precisa software
#
# História do Usuário: Como testador, eu preciso de suporte à execução de testes de regressão automatizados, para garantir que as alterações no código não introduzam regressões.
# Autor: Testador
# Finalidade: suporte execução testis regressão automatizados garantir alterações código introduzam regressões
#
# História do Usuário: Como testador, eu quero identificação automática de casos de teste redundantes ou desnecessários, para otimizar os esforços de teste.
# Autor: Testador
# Finalidade: identificação automática casos teste redundantes desnecessários otimizar esforços
#
# História do Usuário: Como testador, eu desejo integração fácil com ferramentas de gerenciamento de projetos, para uma colaboração eficiente com outros membros da equipe de desenvolvimento.
# Autor: Testador
# Finalidade: integração fácil ferramentas gerenciamento projetos colaboração eficiente outros membros equipe desenvolvimento
#
# História do Usuário: Como testador, eu preciso de suporte à execução de testes de usabilidade, para garantir que o aplicativo seja fácil e intuitivo de usar.
# Autor: Testador
# Finalidade: suporte execução testis usabilidade garantir aplicativo fácil intuitivo usar
#
# História do Usuário: Como testador, eu quero que a ferramenta crie automaticamente conjuntos de dados de teste realistas, para simular condições reais de uso.
# Autor: Testador
# Finalidade: ferramenta crie automaticamente conjuntos dado teste realistas simular condições reais uso
#
# História do Usuário: Como testador, eu desejo integração com ferramentas de monitoramento de desempenho em tempo real, para avaliar o desempenho do aplicativo durante os testes.
# Autor: Testador
# Finalidade: integração ferramentas monitoramento desempenho tempo real avaliar aplicativo durante testis
#
# História do Usuário: Como testador, eu preciso de suporte à execução de testes de localização e internacionalização, para garantir que o aplicativo seja compatível com diferentes idiomas e regiões.
# Autor: Testador
# Finalidade: suporte execução testis localização internacionalização garantir aplicativo compatível diferentes idiomas regiões
#
# História do Usuário: Como testador, eu quero geração automática de dados de teste sintéticos, para complementar os casos de teste manuais.
# Autor: Testador
# Finalidade: geração automática dado teste sintéticos complementar casos manuais
#
# História do Usuário: Como testador, eu desejo suporte à execução de testes de acessibilidade, para garantir que o aplicativo seja acessível a todos os usuários.
# Autor: Testador
# Finalidade: suporte execução testis acessibilidade garantir aplicativo acessível todos usuários
#
# História do Usuário: Como testador, eu preciso de suporte à execução de testes de integração contínua, para garantir que as alterações no código não quebrem a integração com outras partes do sistema.
# Autor: Testador
# Finalidade: suporte execução testis integração contínua garantir alterações código quebrem outras partes sistema
#
# História do Usuário: Como testador, eu quero identificação automática de casos de teste incompletos ou mal definidos, para garantir a qualidade dos testes.
# Autor: Testador
# Finalidade: identificação automática casos teste incompletos mal definidos garantir qualidade testis
#
# História do Usuário: Como testador, eu desejo identificação automática de dependências entre casos de teste, para garantir uma sequência lógica na execução dos testes.
# Autor: Testador
# Finalidade: identificação automática dependências casos teste garantir sequência lógica execução testis
#
# História do Usuário: Como testador, eu preciso de suporte à execução de testes de recuperação de desastres, para avaliar a capacidade do sistema de se recuperar de falhas.
# Autor: Testador
# Finalidade: suporte execução testis recuperação desastres avaliar capacidade sistema recuperar falhas
#
# História do Usuário: Como testador, eu quero que a ferramenta identifique automaticamente casos de teste paralelizáveis, para otimizar a execução dos testes.
# Autor: Testador
# Finalidade: ferramenta identifique automaticamente casos teste paralelizáveis otimizar execução testis
#
# História do Usuário: Como testador, eu desejo simulação de cenários de teste de carga extremamente alta, para avaliar a capacidade de escalabilidade do sistema.
# Autor: Testador
# Finalidade: simulação cenários teste carga extremamente alta avaliar capacidade escalabilidade sistema
#
# História do Usuário: Como testador, eu preciso de suporte à execução de testes de compatibilidade com diferentes navegadores e dispositivos, para garantir uma experiência consistente para todos os usuários.
# Autor: Testador
# Finalidade: suporte execução testis compatibilidade diferentes navegadores dispositivos garantir experiência consistente todos usuários
#
# História do Usuário: Como testador, eu quero geração automática de relatórios de teste personalizados, para comunicar eficazmente os resultados dos testes.
# Autor: Testador
# Finalidade: geração automática relatórios teste personalizados comunicar eficazmente resultados testis
#
# História do Usuário: Como testador, eu desejo rastreamento automático de resultados de teste ao longo do tempo, para identificar tendências e padrões de qualidade.
# Autor: Testador
# Finalidade: rastreamento automático resultados teste longo tempo identificar tendências padrões qualidade
#
# História do Usuário: Como testador, eu preciso de suporte à execução de testes de regressão progressiva, para garantir que as novas alterações não quebrem funcionalidades existentes.
# Autor: Testador
# Finalidade: suporte execução testis regressão progressiva garantir nova alterações quebrem funcionalidades existentes
#
# História do Usuário: Como testador, eu quero sugestões automáticas para aprimorar os casos de teste existentes, para aumentar a eficiência e a eficácia dos testes.
# Autor: Testador
# Finalidade: sugestões automáticas aprimorar casos teste existentes aumentar eficiência eficácia testis
#
# História do Usuário: Como testador, eu desejo que a ferramenta aprenda com os resultados dos testes e melhore suas sugestões futuras, para uma otimização contínua do processo de teste.
# Autor: Testador
# Finalidade: ferramenta aprenda resultados testis melhore sugestões futuras otimização contínua processo teste
#
# História do Usuário: Como testador, eu preciso de suporte à execução de testes de segurança automatizados, para identificar vulnerabilidades no aplicativo.
# Autor: Testador
# Finalidade: suporte execução testis segurança automatizados identificar vulnerabilidades aplicativo
#
# História do Usuário: Como testador, eu quero integração com ferramentas de análise de código estático para identificar áreas de risco, para uma avaliação abrangente da qualidade do código.
# Autor: Testador
# Finalidade: integração ferramentas análise código estático identificar áreas risco avaliação abrangente qualidade
#
# História do Usuário: Como testador, eu desejo suporte à execução de testes de integração de sistema e teste de aceitação do usuário, para validar a integração entre diferentes partes do sistema e a conformidade com os requisitos do usuário.
# Autor: Testador
# Finalidade: suporte execução testis integração sistema teste aceitação usuário validar diferentes partes conformidade requisitos
#
# História do Usuário: Como testador, eu preciso de suporte à execução de testes de confiabilidade e disponibilidade, para garantir que o aplicativo esteja sempre disponível e funcione corretamente.
# Autor: Testador
# Finalidade: suporte execução testis confiabilidade disponibilidade garantir aplicativo sempre disponível funcione corretamente
#
# História do Usuário: Como testador, eu quero que a ferramenta sugira casos de teste com base em modelos de qualidade de software reconhecidos, para garantir uma abordagem abrangente e padronizada para os testes.
# Autor: Testador
# Finalidade: ferramenta sugira casos teste base modelos qualidade software reconhecidos garantir abordagem abrangente padronizada testis
#
# História do Usuário: Como testador, eu desejo integração com ferramentas de automação de teste de interface do usuário, para automatizar testes de interação com o usuário.
# Autor: Testador
# Finalidade: integração ferramentas automação teste interface usuário automatizar testis interação
#
# História do Usuário: Como testador, eu preciso de suporte à execução de testes de estresse e robustez, para avaliar a estabilidade e a confiabilidade do aplicativo sob condições adversas.
# Autor: Testador
# Finalidade: suporte execução testis estresse robustez avaliar estabilidade confiabilidade aplicativo sob condições adversas
#
# História do Usuário: Como testador, eu quero que a ferramenta sugira casos de teste para áreas de alto risco e complexidade, para priorizar os esforços de teste.
# Autor: Testador
# Finalidade: ferramenta sugira casos teste áreas alto risco complexidade priorizar esforços
#
# História do Usuário: Como testador, eu desejo integração com ferramentas de gerenciamento de defeitos para rastreamento de correções, para uma gestão eficaz de problemas encontrados durante os testes.
# Autor: Testador
# Finalidade: integração ferramentas gerenciamento defeitos rastreamento correções gestão eficaz problemas encontrados durante testis
#
# História do Usuário: Como testador, eu preciso de suporte à execução de testes de usabilidade remota e teste de usuário beta, para coletar feedback de usuários reais.
# Autor: Testador
# Finalidade: suporte execução testis usabilidade remota teste usuário beta coletar feedback usuários reais
#
# História do Usuário: Como testador, eu quero que a ferramenta forneça feedback em tempo real durante a execução dos testes, para facilitar a identificação imediata de problemas.
# Autor: Testador
# Finalidade: ferramenta forneça feedback tempo real durante execução testis facilitar identificação imediata problemas
#
# História do Usuário: Como testador, eu desejo integração com ferramentas de automação de infraestrutura para provisionamento e configuração automatizados, para facilitar a preparação do ambiente de teste.
# Autor: Testador
# Finalidade: integração ferramentas automação infraestrutura provisionamento configuração automatizados facilitar preparação ambiente teste
#
# História do Usuário: Como testador, eu preciso de suporte à execução de testes de comparação de desempenho para versões anteriores e atuais do aplicativo, para avaliar o impacto de mudanças no desempenho.
# Autor: Testador
# Finalidade: suporte execução testis comparação desempenho versões anteriores atuais aplicativo avaliar impacto mudanças

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import recall_score, f1_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.25.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.4.0)

# %%
X = freq_dists
rotulos_possiveis = ["testador", "aplicativo", "desempenho", "teste"]
y = [choice(rotulos_possiveis) for _ in range(len(freq_dists))]
vetorizacao = TfidfVectorizer()
X = vetorizacao.fit_transform([" ".join(freq_dist.keys()) for freq_dist in X])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.4, random_state=42,stratify=y)

# %%
from sklearn.linear_model import LogisticRegression
modelo_regressao = LogisticRegression()
modelo_regressao.fit(X_train, y_train)
y_predicted = modelo_regressao.predict(X_test)
acuracia = accuracy_score(y_test, y_predicted)
print("Acurácia:", acuracia)
# Out:
# Acurácia: 0.3333333333333333

# %%
clf_tf = DecisionTreeClassifier(criterion='gini',max_depth=15)
clf_tf.fit(X_train, y_train)
pred_arvore_entropy_tf = clf_tf.predict(X_test)
accuracy_decision = accuracy_score(y_test,pred_arvore_entropy_tf)
recall = recall_score(y_test, pred_arvore_entropy_tf, average='weighted')
f1 = f1_score(y_test, pred_arvore_entropy_tf, average='weighted')
print(f"Resultado: ",accuracy_decision)
print(f"Resultado: ",recall)
print(f"Resultado: ",f1)
# Out:
# Resultado:  0.23809523809523808
# Resultado:  0.23809523809523808
# Resultado:  0.2159090909090909

# %%
clf = DecisionTreeClassifier(criterion='entropy',max_depth=7)
clf.fit(X_train, y_train)
pred_arvore_entropy = clf.predict(X_test)
accuracy_decision = accuracy_score(y_test,pred_arvore_entropy)
recall_entropy = recall_score(y_test, pred_arvore_entropy, average='weighted')
f1_entropy = f1_score(y_test, pred_arvore_entropy, average='weighted')
print(f"Resultado: ",accuracy_decision)
print(f"Resultado: ",recall_entropy)
print(f"Resultado: ",f1_entropy)
# Out:
# Resultado:  0.14285714285714285
# Resultado:  0.14285714285714285
# Resultado:  0.11996336996336995

# %%
clf_tf3 = KNeighborsClassifier(metric='manhattan',n_neighbors=3)
clf_tf3.fit(X_train, y_train)
pred_knn_tf = clf_tf3.predict(X_test)
acuracy_KNN = accuracy_score(y_test,pred_knn_tf)
recall_knn = recall_score(y_test, pred_knn_tf, average='weighted')
f1_knn = f1_score(y_test, pred_knn_tf, average='weighted')
print(f"Resultado: ",acuracy_KNN)
print(f"Resultado: ",recall_knn)
print(f"Resultado: ",f1_knn)
# Out:
# Resultado:  0.42857142857142855
# Resultado:  0.42857142857142855
# Resultado:  0.3131868131868132

# %%
clf_tf4 = KNeighborsClassifier(n_neighbors=5,weights='distance', algorithm='brute')
clf_tf4.fit(X_train, y_train)
pred_knn_tf2 = clf_tf4.predict(X_test)
acuracy_KNN2 = accuracy_score(y_test,pred_knn_tf2)
recall_knn2 = recall_score(y_test, pred_knn_tf2, average='weighted')
f1_knn2 = f1_score(y_test, pred_knn_tf2, average='weighted')
print(f"Resultado: ",acuracy_KNN)
print(f"Resultado: ",recall_knn2)
print(f"Resultado: ",f1_knn2)
# Out:
# Resultado:  0.42857142857142855
# Resultado:  0.19047619047619047
# Resultado:  0.18557422969187676

# %%
svc = SVC(kernel='linear', C=0.05)
svc.fit(X_train, y_train)
pred_svc = svc.predict(X_test)
accuracy_svc = accuracy_score(y_test, pred_svc)
recall_svc = recall_score(y_test, pred_svc, average='weighted')
f1_svc = f1_score(y_test, pred_svc, average='weighted')
print(f"Resultado: ",accuracy_svc)
print(f"Resultado: ",recall_svc)
print(f"Resultado: ",f1_svc)
# Out:
# Resultado:  0.3333333333333333
# Resultado:  0.3333333333333333
# Resultado:  0.16666666666666666

# %%
from tensorflow.keras import layers
import tensorflow_datasets as tfds
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt
from tensorflow import keras
import tensorflow_hub as hub
import tensorflow as tf

# %%
le_rn = LabelEncoder()
ytrain = le_rn.fit_transform(y_train)
ytest = le_rn.transform(y_test)

# %%
Xtrain = np.expand_dims(X_train.toarray(), axis=1)
Xtest = np.expand_dims(X_test.toarray(), axis=1)

# %%
num_classes = 4
model = tf.keras.Sequential([
    layers.LSTM(128, input_shape=(Xtrain.shape[1], Xtrain.shape[2])),
    layers.Dense(64, activation='relu'),
    layers.Dense(num_classes, activation='softmax')
])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
EPOCHS = 20
history = model.fit(Xtrain, ytrain, epochs=EPOCHS, batch_size=32, validation_data=(Xtest, ytest))
# Out:
# Epoch 1/20
# 1/1 [==============================] - 1s 1s/step - loss: 1.3855 - accuracy: 0.3667 - val_loss: 1.3842 - val_accuracy: 0.2381
# Epoch 2/20
# 1/1 [==============================] - 0s 36ms/step - loss: 1.3773 - accuracy: 0.4333 - val_loss: 1.3834 - val_accuracy: 0.3333
# Epoch 3/20
# 1/1 [==============================] - 0s 35ms/step - loss: 1.3694 - accuracy: 0.5333 - val_loss: 1.3826 - val_accuracy: 0.3333
# Epoch 4/20
# 1/1 [==============================] - 0s 40ms/step - loss: 1.3617 - accuracy: 0.6000 - val_loss: 1.3821 - val_accuracy: 0.3333
# Epoch 5/20
# 1/1 [==============================] - 0s 31ms/step - loss: 1.3541 - accuracy: 0.6000 - val_loss: 1.3815 - val_accuracy: 0.3333
# Epoch 6/20
# 1/1 [==============================] - 0s 32ms/step - loss: 1.3464 - accuracy: 0.5667 - val_loss: 1.3810 - val_accuracy: 0.3333
# Epoch 7/20
# 1/1 [==============================] - 0s 32ms/step - loss: 1.3385 - accuracy: 0.5667 - val_loss: 1.3805 - val_accuracy: 0.3333
# Epoch 8/20
# 1/1 [==============================] - 0s 32ms/step - loss: 1.3302 - accuracy: 0.6000 - val_loss: 1.3800 - val_accuracy: 0.3333
# Epoch 9/20
# 1/1 [==============================] - 0s 35ms/step - loss: 1.3216 - accuracy: 0.6333 - val_loss: 1.3795 - val_accuracy: 0.3333
# Epoch 10/20
# 1/1 [==============================] - 0s 32ms/step - loss: 1.3126 - accuracy: 0.6333 - val_loss: 1.3791 - val_accuracy: 0.3333
# Epoch 11/20
# 1/1 [==============================] - 0s 31ms/step - loss: 1.3031 - accuracy: 0.6333 - val_loss: 1.3786 - val_accuracy: 0.2857
# Epoch 12/20
# 1/1 [==============================] - 0s 30ms/step - loss: 1.2931 - accuracy: 0.6333 - val_loss: 1.3783 - val_accuracy: 0.2857
# Epoch 13/20
# 1/1 [==============================] - 0s 33ms/step - loss: 1.2827 - accuracy: 0.6333 - val_loss: 1.3780 - val_accuracy: 0.2857
# Epoch 14/20
# 1/1 [==============================] - 0s 35ms/step - loss: 1.2717 - accuracy: 0.6333 - val_loss: 1.3778 - val_accuracy: 0.2857
# Epoch 15/20
# 1/1 [==============================] - 0s 32ms/step - loss: 1.2601 - accuracy: 0.7000 - val_loss: 1.3778 - val_accuracy: 0.2857
# Epoch 16/20
# 1/1 [==============================] - 0s 36ms/step - loss: 1.2479 - accuracy: 0.7333 - val_loss: 1.3779 - val_accuracy: 0.2857
# Epoch 17/20
# 1/1 [==============================] - 0s 32ms/step - loss: 1.2350 - accuracy: 0.7333 - val_loss: 1.3780 - val_accuracy: 0.2857
# Epoch 18/20
# 1/1 [==============================] - 0s 33ms/step - loss: 1.2214 - accuracy: 0.7333 - val_loss: 1.3783 - val_accuracy: 0.2857
# Epoch 19/20
# 1/1 [==============================] - 0s 32ms/step - loss: 1.2072 - accuracy: 0.7667 - val_loss: 1.3788 - val_accuracy: 0.2857
# Epoch 20/20
# 1/1 [==============================] - 0s 31ms/step - loss: 1.1923 - accuracy: 0.7667 - val_loss: 1.3795 - val_accuracy: 0.2857

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(len(acc))

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Acuracia no treino')
plt.plot(epochs_range, val_acc, label='Acuracia na validacao')
plt.legend(loc='lower right')
plt.title('Acuracia no treino na validacao')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Perda no treino')
plt.plot(epochs_range, val_loss, label='Perda na validacao')
plt.legend(loc='upper right')
plt.title('Perda no treino e na validacao')
plt.show()

# %%
model_drop = tf.keras.Sequential([
    layers.LSTM(128, input_shape=(Xtrain.shape[1], Xtrain.shape[2])),
    layers.Dense(64, activation='relu'),
    keras.layers.Dropout(rate=0.5),
    layers.Dense(num_classes, activation='softmax')
])

# %%
model_drop.compile(optimizer='adam',
                   loss='sparse_categorical_crossentropy',
                   metrics=['accuracy'])

# %%
EPOCHS = 20
history_drop = model_drop.fit(Xtrain, ytrain, epochs=EPOCHS, batch_size=32, validation_data=(Xtest, ytest))
# Out:
# Epoch 1/20
# 1/1 [==============================] - 1s 1s/step - loss: 1.3840 - accuracy: 0.3333 - val_loss: 1.3851 - val_accuracy: 0.3333
# Epoch 2/20
# 1/1 [==============================] - 0s 31ms/step - loss: 1.3831 - accuracy: 0.2667 - val_loss: 1.3848 - val_accuracy: 0.3333
# Epoch 3/20
# 1/1 [==============================] - 0s 33ms/step - loss: 1.3723 - accuracy: 0.4667 - val_loss: 1.3844 - val_accuracy: 0.2857
# Epoch 4/20
# 1/1 [==============================] - 0s 36ms/step - loss: 1.3683 - accuracy: 0.4667 - val_loss: 1.3838 - val_accuracy: 0.2381
# Epoch 5/20
# 1/1 [==============================] - 0s 33ms/step - loss: 1.3585 - accuracy: 0.7667 - val_loss: 1.3833 - val_accuracy: 0.2381
# Epoch 6/20
# 1/1 [==============================] - 0s 34ms/step - loss: 1.3512 - accuracy: 0.5667 - val_loss: 1.3827 - val_accuracy: 0.1905
# Epoch 7/20
# 1/1 [==============================] - 0s 32ms/step - loss: 1.3528 - accuracy: 0.7000 - val_loss: 1.3821 - val_accuracy: 0.1905
# Epoch 8/20
# 1/1 [==============================] - 0s 36ms/step - loss: 1.3423 - accuracy: 0.6667 - val_loss: 1.3815 - val_accuracy: 0.2857
# Epoch 9/20
# 1/1 [==============================] - 0s 34ms/step - loss: 1.3414 - accuracy: 0.6333 - val_loss: 1.3810 - val_accuracy: 0.3333
# Epoch 10/20
# 1/1 [==============================] - 0s 33ms/step - loss: 1.3327 - accuracy: 0.7333 - val_loss: 1.3806 - val_accuracy: 0.3333
# Epoch 11/20
# 1/1 [==============================] - 0s 32ms/step - loss: 1.3289 - accuracy: 0.7333 - val_loss: 1.3802 - val_accuracy: 0.3333
# Epoch 12/20
# 1/1 [==============================] - 0s 35ms/step - loss: 1.3287 - accuracy: 0.6667 - val_loss: 1.3797 - val_accuracy: 0.3333
# Epoch 13/20
# 1/1 [==============================] - 0s 34ms/step - loss: 1.3171 - accuracy: 0.6333 - val_loss: 1.3794 - val_accuracy: 0.3333
# Epoch 14/20
# 1/1 [==============================] - 0s 36ms/step - loss: 1.3067 - accuracy: 0.8000 - val_loss: 1.3792 - val_accuracy: 0.3333
# Epoch 15/20
# 1/1 [==============================] - 0s 35ms/step - loss: 1.2990 - accuracy: 0.7333 - val_loss: 1.3790 - val_accuracy: 0.3333
# Epoch 16/20
# 1/1 [==============================] - 0s 52ms/step - loss: 1.2993 - accuracy: 0.7667 - val_loss: 1.3790 - val_accuracy: 0.3333
# Epoch 17/20
# 1/1 [==============================] - 0s 33ms/step - loss: 1.2891 - accuracy: 0.7000 - val_loss: 1.3790 - val_accuracy: 0.3333
# Epoch 18/20
# 1/1 [==============================] - 0s 33ms/step - loss: 1.2756 - accuracy: 0.7667 - val_loss: 1.3791 - val_accuracy: 0.3333
# Epoch 19/20
# 1/1 [==============================] - 0s 32ms/step - loss: 1.2739 - accuracy: 0.8000 - val_loss: 1.3793 - val_accuracy: 0.3333
# Epoch 20/20
# 1/1 [==============================] - 0s 36ms/step - loss: 1.2511 - accuracy: 0.8000 - val_loss: 1.3795 - val_accuracy: 0.3333

# %%
acc2 = history_drop.history['accuracy']
val_acc2 = history_drop.history['val_accuracy']
loss2 = history_drop.history['loss']
val_loss2 = history_drop.history['val_loss']

epochs_range = range(len(acc2))

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc2, label='Acuracia no treino')
plt.plot(epochs_range, val_acc2, label='Acuracia na validacao')
plt.legend(loc='lower right')
plt.title('Acuracia no treino na validacao')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss2, label='Perda no treino')
plt.plot(epochs_range, val_loss2, label='Perda na validacao')
plt.legend(loc='upper right')
plt.title('Perda no treino e na validacao')
plt.show()

# %%
model_early = tf.keras.Sequential([
    layers.LSTM(128, input_shape=(Xtrain.shape[1], Xtrain.shape[2])),
    layers.Dense(64, activation='relu'),
    layers.Dense(num_classes, activation='softmax')
])

# %%
model_early.compile(optimizer='adam',
                   loss='sparse_categorical_crossentropy',
                   metrics=['accuracy'])

# %%
callbacks = [
    keras.callbacks.EarlyStopping(
        monitor="val_loss",
        min_delta=1e-2,
        patience=5,
        restore_best_weights=True,
        verbose=1,
    )
]

# %%
EPOCHS = 100
history_early = model_early.fit(Xtrain, ytrain,callbacks = callbacks, epochs=EPOCHS, batch_size=32, validation_data=(Xtest, ytest))
# Out:
# Epoch 1/100
# 1/1 [==============================] - 2s 2s/step - loss: 1.3861 - accuracy: 0.2667 - val_loss: 1.3856 - val_accuracy: 0.1905
# Epoch 2/100
# 1/1 [==============================] - 0s 75ms/step - loss: 1.3772 - accuracy: 0.4667 - val_loss: 1.3849 - val_accuracy: 0.1905
# Epoch 3/100
# 1/1 [==============================] - 0s 79ms/step - loss: 1.3690 - accuracy: 0.6333 - val_loss: 1.3843 - val_accuracy: 0.1905
# Epoch 4/100
# 1/1 [==============================] - 0s 46ms/step - loss: 1.3609 - accuracy: 0.7000 - val_loss: 1.3836 - val_accuracy: 0.2381
# Epoch 5/100
# 1/1 [==============================] - 0s 81ms/step - loss: 1.3528 - accuracy: 0.8333 - val_loss: 1.3829 - val_accuracy: 0.2381
# Epoch 6/100
# 1/1 [==============================] - ETA: 0s - loss: 1.3447 - accuracy: 0.9000Restoring model weights from the end of the best epoch: 1.
# 1/1 [==============================] - 0s 67ms/step - loss: 1.3447 - accuracy: 0.9000 - val_loss: 1.3824 - val_accuracy: 0.1905
# Epoch 6: early stopping

# %%
acc3 = history_early.history['accuracy']
val_acc3 = history_early.history['val_accuracy']
loss3 = history_early.history['loss']
val_loss3 = history_early.history['val_loss']

epochs_range = range(len(acc3))

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc3, label='Acuracia no treino')
plt.plot(epochs_range, val_acc3, label='Acuracia na validacao')
plt.legend(loc='lower right')
plt.title('Acuracia no treino na validacao')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss3, label='Perda no treino')
plt.plot(epochs_range, val_loss3, label='Perda na validacao')
plt.legend(loc='upper right')
plt.title('Perda no treino e na validacao')
plt.show()

# %%
model_few = tf.keras.Sequential([
    layers.LSTM(128, input_shape=(Xtrain.shape[1], Xtrain.shape[2])),
    layers.Dense(64, activation='relu'),
    layers.Dense(num_classes, activation='softmax')
])
learning_rate = 0.001
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)

model_few.compile(optimizer=optimizer,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
EPOCHS = 20
history_few = model_few.fit(Xtrain, ytrain, epochs=EPOCHS, batch_size=32, validation_data=(Xtest, ytest))
# Out:
# Epoch 1/20
# 1/1 [==============================] - 2s 2s/step - loss: 1.3891 - accuracy: 0.2667 - val_loss: 1.3865 - val_accuracy: 0.1905
# Epoch 2/20
# 1/1 [==============================] - 0s 44ms/step - loss: 1.3809 - accuracy: 0.4667 - val_loss: 1.3854 - val_accuracy: 0.1905
# Epoch 3/20
# 1/1 [==============================] - 0s 44ms/step - loss: 1.3730 - accuracy: 0.6333 - val_loss: 1.3844 - val_accuracy: 0.1905
# Epoch 4/20
# 1/1 [==============================] - 0s 56ms/step - loss: 1.3656 - accuracy: 0.7000 - val_loss: 1.3832 - val_accuracy: 0.2381
# Epoch 5/20
# 1/1 [==============================] - 0s 41ms/step - loss: 1.3582 - accuracy: 0.7333 - val_loss: 1.3821 - val_accuracy: 0.2381
# Epoch 6/20
# 1/1 [==============================] - 0s 49ms/step - loss: 1.3506 - accuracy: 0.7333 - val_loss: 1.3811 - val_accuracy: 0.2857
# Epoch 7/20
# 1/1 [==============================] - 0s 40ms/step - loss: 1.3427 - accuracy: 0.7667 - val_loss: 1.3802 - val_accuracy: 0.2857
# Epoch 8/20
# 1/1 [==============================] - 0s 44ms/step - loss: 1.3346 - accuracy: 0.7667 - val_loss: 1.3795 - val_accuracy: 0.2857
# Epoch 9/20
# 1/1 [==============================] - 0s 65ms/step - loss: 1.3262 - accuracy: 0.8333 - val_loss: 1.3789 - val_accuracy: 0.2857
# Epoch 10/20
# 1/1 [==============================] - 0s 67ms/step - loss: 1.3173 - accuracy: 0.8333 - val_loss: 1.3784 - val_accuracy: 0.2857
# Epoch 11/20
# 1/1 [==============================] - 0s 48ms/step - loss: 1.3081 - accuracy: 0.8667 - val_loss: 1.3781 - val_accuracy: 0.2857
# Epoch 12/20
# 1/1 [==============================] - 0s 45ms/step - loss: 1.2985 - accuracy: 0.8667 - val_loss: 1.3778 - val_accuracy: 0.2857
# Epoch 13/20
# 1/1 [==============================] - 0s 71ms/step - loss: 1.2883 - accuracy: 0.8667 - val_loss: 1.3776 - val_accuracy: 0.2857
# Epoch 14/20
# 1/1 [==============================] - 0s 43ms/step - loss: 1.2776 - accuracy: 0.8667 - val_loss: 1.3775 - val_accuracy: 0.2857
# Epoch 15/20
# 1/1 [==============================] - 0s 50ms/step - loss: 1.2663 - accuracy: 0.8667 - val_loss: 1.3776 - val_accuracy: 0.2857
# Epoch 16/20
# 1/1 [==============================] - 0s 79ms/step - loss: 1.2544 - accuracy: 0.8667 - val_loss: 1.3777 - val_accuracy: 0.2857
# Epoch 17/20
# 1/1 [==============================] - 0s 62ms/step - loss: 1.2418 - accuracy: 0.8667 - val_loss: 1.3778 - val_accuracy: 0.2857
# Epoch 18/20
# 1/1 [==============================] - 0s 62ms/step - loss: 1.2285 - accuracy: 0.8667 - val_loss: 1.3780 - val_accuracy: 0.2857
# Epoch 19/20
# 1/1 [==============================] - 0s 53ms/step - loss: 1.2145 - accuracy: 0.8667 - val_loss: 1.3783 - val_accuracy: 0.2857
# Epoch 20/20
# 1/1 [==============================] - 0s 41ms/step - loss: 1.1997 - accuracy: 0.8667 - val_loss: 1.3787 - val_accuracy: 0.2857

# %%
X = freq_dists
rotulos_possiveis = ["testador", "aplicativo", "desempenho", "teste"]
y = [choice(rotulos_possiveis) for _ in range(len(freq_dists))]
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform([" ".join(freq_dist.keys()) for freq_dist in X])


X_novos = csr_matrix(X)
X_novos.sort_indices()


X_novos = np.expand_dims(X_novos.toarray(), axis=1)

y_novos = le_rn.transform([choice(rotulos_possiveis) for _ in range(len(y))])

EPOCHS = 20
history_few = model_few.fit(X_novos, y_novos, epochs=EPOCHS, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/20
# 2/2 [==============================] - 0s 70ms/step - loss: 1.5122 - accuracy: 0.2500 - val_loss: 1.5856 - val_accuracy: 0.0909
# Epoch 2/20
# 2/2 [==============================] - 0s 26ms/step - loss: 1.5143 - accuracy: 0.2500 - val_loss: 1.5854 - val_accuracy: 0.0909
# Epoch 3/20
# 2/2 [==============================] - 0s 27ms/step - loss: 1.5009 - accuracy: 0.2500 - val_loss: 1.5814 - val_accuracy: 0.0909
# Epoch 4/20
# 2/2 [==============================] - 0s 29ms/step - loss: 1.4772 - accuracy: 0.2500 - val_loss: 1.5734 - val_accuracy: 0.0909
# Epoch 5/20
# 2/2 [==============================] - 0s 27ms/step - loss: 1.4442 - accuracy: 0.2500 - val_loss: 1.5627 - val_accuracy: 0.0909
# Epoch 6/20
# 2/2 [==============================] - 0s 27ms/step - loss: 1.4073 - accuracy: 0.2750 - val_loss: 1.5518 - val_accuracy: 0.1818
# Epoch 7/20
# 2/2 [==============================] - 0s 27ms/step - loss: 1.3697 - accuracy: 0.2750 - val_loss: 1.5429 - val_accuracy: 0.1818
# Epoch 8/20
# 2/2 [==============================] - 0s 28ms/step - loss: 1.3339 - accuracy: 0.3250 - val_loss: 1.5341 - val_accuracy: 0.1818
# Epoch 9/20
# 2/2 [==============================] - 0s 27ms/step - loss: 1.2970 - accuracy: 0.3750 - val_loss: 1.5254 - val_accuracy: 0.1818
# Epoch 10/20
# 2/2 [==============================] - 0s 27ms/step - loss: 1.2698 - accuracy: 0.4000 - val_loss: 1.5184 - val_accuracy: 0.2727
# Epoch 11/20
# 2/2 [==============================] - 0s 29ms/step - loss: 1.2413 - accuracy: 0.4500 - val_loss: 1.5127 - val_accuracy: 0.2727
# Epoch 12/20
# 2/2 [==============================] - 0s 48ms/step - loss: 1.2142 - accuracy: 0.4750 - val_loss: 1.5060 - val_accuracy: 0.2727
# Epoch 13/20
# 2/2 [==============================] - 0s 29ms/step - loss: 1.1907 - accuracy: 0.4750 - val_loss: 1.5000 - val_accuracy: 0.2727
# Epoch 14/20
# 2/2 [==============================] - 0s 29ms/step - loss: 1.1659 - accuracy: 0.4750 - val_loss: 1.4952 - val_accuracy: 0.2727
# Epoch 15/20
# 2/2 [==============================] - 0s 28ms/step - loss: 1.1435 - accuracy: 0.5000 - val_loss: 1.4923 - val_accuracy: 0.2727
# Epoch 16/20
# 2/2 [==============================] - 0s 28ms/step - loss: 1.1191 - accuracy: 0.5000 - val_loss: 1.4904 - val_accuracy: 0.2727
# Epoch 17/20
# 2/2 [==============================] - 0s 28ms/step - loss: 1.0959 - accuracy: 0.5000 - val_loss: 1.4890 - val_accuracy: 0.2727
# Epoch 18/20
# 2/2 [==============================] - 0s 27ms/step - loss: 1.0709 - accuracy: 0.5250 - val_loss: 1.4860 - val_accuracy: 0.2727
# Epoch 19/20
# 2/2 [==============================] - 0s 27ms/step - loss: 1.0457 - accuracy: 0.5500 - val_loss: 1.4842 - val_accuracy: 0.2727
# Epoch 20/20
# 2/2 [==============================] - 0s 29ms/step - loss: 1.0196 - accuracy: 0.5500 - val_loss: 1.4819 - val_accuracy: 0.2727
