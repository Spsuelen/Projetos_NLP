# %%
# !python3 -m spacy download pt_core_news_lg
from tensorflow.keras import optimizers
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.probability import FreqDist
from scipy.sparse import csr_matrix
from nltk.corpus import stopwords
from transformers import pipeline
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
# %matplotlib inline
import torch
import string
import nltk
import re
# Out:
# Collecting pt-core-news-lg==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/pt_core_news_lg-3.7.0/pt_core_news_lg-3.7.0-py3-none-any.whl (568.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 568.2/568.2 MB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from pt-core-news-lg==3.7.0) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (4.66.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.7.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (24.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (1.25.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.18.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.0->pt-core-news-lg==3.7.0) (2.1.5)
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
classificador = pipeline("zero-shot-classification")
rotulos = ["testador", "aplicativo", "desempenho", "teste"]
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli and revision c626438 (https://huggingface.co/facebook/bart-large-mnli).
# Using a pipeline without specifying a model name and revision in production is not recommended.

# %%
roberta = pipeline("ner", grouped_entities=True, model="joelniklaus/legal-portuguese-roberta-base")
# Out:
# Some weights of RobertaForTokenClassification were not initialized from the model checkpoint at joelniklaus/legal-portuguese-roberta-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/token_classification.py:168: UserWarning: `grouped_entities` is deprecated and will be removed in version v5.0.0, defaulted to `aggregation_strategy="simple"` instead.
#   warnings.warn(

# %%
historias_usuario = [
    "Como Testador eu quero um jeito mais fácil de incluir os requisitos do aplicativo na ferramenta DRL-Mobtest para criar casos de teste que cubram tudo que o aplicativo precisa fazer, sem ter que gastar muito tempo escrevendo manualmente.",
    "Como Testador eu quero uma maneira de ensinar a ferramenta DRL-Mobtest a entender os requisitos do aplicativo usando NLP para fazer com que a ferramenta gere testes automaticamente.",
    "Como Testador eu quero que a ferramenta gere casos de teste abrangentes que cubram integralmente todos os requisitos do aplicativo, assegurando que o software seja completo e funcional, sem depender exclusivamente da criação manual de casos de teste.",
    "Como Testador eu quero que a ferramenta seja integrada com outras ferramentas de gerenciamento, permitindo sincronização automática dos requisitos e facilitando o processo de criação de casos de testes.",
    "Como testador, eu quero que a ferramenta gere casos de teste completos e funcionais que cubram todos os requisitos do aplicativo, para garantir uma cobertura abrangente durante os testes.",
    "Como testador, eu quero integração com outras ferramentas de gerenciamento para sincronizar automaticamente requisitos e facilitar a criação de casos de teste, visando melhorar a eficiência e precisão do processo de teste.",
    "Como testador, eu quero relatórios detalhados sobre a cobertura dos testes para análise precisa durante a execução, a fim de avaliar a qualidade e a extensão dos testes realizados.",
    "Como testador, eu desejo que a ferramenta identifique automaticamente os casos de teste mais críticos para priorizar a análise, visando direcionar os esforços de teste para áreas de maior risco.",
    "Como testador, eu preciso que a ferramenta sugira casos de teste com base em padrões de uso real do aplicativo, para garantir que os testes reflitam cenários típicos de uso.",
    "Como testador, eu quero sugestões com base em padrões de falha históricos para evitar problemas recorrentes no software, visando melhorar a qualidade e a robustez do produto.",
    "Como testador, eu desejo suporte à execução de testes automatizados em diferentes dispositivos e ambientes, para garantir a consistência e a confiabilidade dos testes em diferentes cenários.",
    "Como testador, eu preciso que a ferramenta detecte automaticamente mudanças nos requisitos e ajuste os casos de teste correspondentes, para manter os testes alinhados com a evolução do aplicativo.",
    "Como testador, eu quero integração com sistemas de controle de versão para rastrear mudanças nos requisitos e no código-fonte, visando uma gestão eficaz de mudanças durante o ciclo de desenvolvimento.",
    "Como testador, eu desejo métricas detalhadas sobre a eficácia dos testes, incluindo taxa de cobertura e taxa de falha, para avaliar a qualidade do processo de teste.",
    "Como testador, eu preciso de suporte à execução de testes de desempenho e escalabilidade, para garantir que o aplicativo atenda aos requisitos de desempenho sob carga.",
    "Como testador, eu quero análise automática dos resultados dos testes para relatórios detalhados sobre problemas encontrados, a fim de facilitar a identificação e correção de defeitos.",
    "Como testador, eu desejo simular cenários de teste complexos e realistas para garantir testes próximos à realidade, visando uma validação mais precisa do software.",
    "Como testador, eu preciso de suporte à execução de testes de regressão automatizados, para garantir que as alterações no código não introduzam regressões.",
    "Como testador, eu quero identificação automática de casos de teste redundantes ou desnecessários, para otimizar os esforços de teste.",
    "Como testador, eu desejo integração fácil com ferramentas de gerenciamento de projetos, para uma colaboração eficiente com outros membros da equipe de desenvolvimento.",
    "Como testador, eu preciso de suporte à execução de testes de usabilidade, para garantir que o aplicativo seja fácil e intuitivo de usar.",
    "Como testador, eu quero que a ferramenta crie automaticamente conjuntos de dados de teste realistas, para simular condições reais de uso.",
    "Como testador, eu desejo integração com ferramentas de monitoramento de desempenho em tempo real, para avaliar o desempenho do aplicativo durante os testes.",
    "Como testador, eu preciso de suporte à execução de testes de localização e internacionalização, para garantir que o aplicativo seja compatível com diferentes idiomas e regiões.",
    "Como testador, eu quero geração automática de dados de teste sintéticos, para complementar os casos de teste manuais.",
    "Como testador, eu desejo suporte à execução de testes de acessibilidade, para garantir que o aplicativo seja acessível a todos os usuários.",
    "Como testador, eu preciso de suporte à execução de testes de integração contínua, para garantir que as alterações no código não quebrem a integração com outras partes do sistema.",
    "Como testador, eu quero identificação automática de casos de teste incompletos ou mal definidos, para garantir a qualidade dos testes.",
    "Como testador, eu desejo identificação automática de dependências entre casos de teste, para garantir uma sequência lógica na execução dos testes.",
    "Como testador, eu preciso de suporte à execução de testes de recuperação de desastres, para avaliar a capacidade do sistema de se recuperar de falhas.",
    "Como testador, eu quero que a ferramenta identifique automaticamente casos de teste paralelizáveis, para otimizar a execução dos testes.",
    "Como testador, eu desejo simulação de cenários de teste de carga extremamente alta, para avaliar a capacidade de escalabilidade do sistema.",
    "Como testador, eu preciso de suporte à execução de testes de compatibilidade com diferentes navegadores e dispositivos, para garantir uma experiência consistente para todos os usuários.",
    "Como testador, eu quero geração automática de relatórios de teste personalizados, para comunicar eficazmente os resultados dos testes.",
    "Como testador, eu desejo rastreamento automático de resultados de teste ao longo do tempo, para identificar tendências e padrões de qualidade.",
    "Como testador, eu preciso de suporte à execução de testes de regressão progressiva, para garantir que as novas alterações não quebrem funcionalidades existentes.",
    "Como testador, eu quero sugestões automáticas para aprimorar os casos de teste existentes, para aumentar a eficiência e a eficácia dos testes.",
    "Como testador, eu desejo que a ferramenta aprenda com os resultados dos testes e melhore suas sugestões futuras, para uma otimização contínua do processo de teste.",
    "Como testador, eu preciso de suporte à execução de testes de segurança automatizados, para identificar vulnerabilidades no aplicativo.",
    "Como testador, eu quero integração com ferramentas de análise de código estático para identificar áreas de risco, para uma avaliação abrangente da qualidade do código.",
    "Como testador, eu desejo suporte à execução de testes de integração de sistema e teste de aceitação do usuário, para validar a integração entre diferentes partes do sistema e a conformidade com os requisitos do usuário.",
    "Como testador, eu preciso de suporte à execução de testes de confiabilidade e disponibilidade, para garantir que o aplicativo esteja sempre disponível e funcione corretamente.",
    "Como testador, eu quero que a ferramenta sugira casos de teste com base em modelos de qualidade de software reconhecidos, para garantir uma abordagem abrangente e padronizada para os testes.",
    "Como testador, eu desejo integração com ferramentas de automação de teste de interface do usuário, para automatizar testes de interação com o usuário.",
    "Como testador, eu preciso de suporte à execução de testes de estresse e robustez, para avaliar a estabilidade e a confiabilidade do aplicativo sob condições adversas.",
    "Como testador, eu quero que a ferramenta sugira casos de teste para áreas de alto risco e complexidade, para priorizar os esforços de teste.",
    "Como testador, eu desejo integração com ferramentas de gerenciamento de defeitos para rastreamento de correções, para uma gestão eficaz de problemas encontrados durante os testes.",
    "Como testador, eu preciso de suporte à execução de testes de usabilidade remota e teste de usuário beta, para coletar feedback de usuários reais.",
    "Como testador, eu quero que a ferramenta forneça feedback em tempo real durante a execução dos testes, para facilitar a identificação imediata de problemas.",
    "Como testador, eu desejo integração com ferramentas de automação de infraestrutura para provisionamento e configuração automatizados, para facilitar a preparação do ambiente de teste.",
    "Como testador, eu preciso de suporte à execução de testes de comparação de desempenho para versões anteriores e atuais do aplicativo, para avaliar o impacto de mudanças no desempenho."
]

# %%
#sem_pontuacao = re.findall(r'\b(^[^A-Za-z])\b', historias_usuario, re.IGNORECASE)

# %%
class ProcessadorHistoriasUsuario:
    def __init__(self):
        nltk.download('punkt')
        nltk.download('stopwords')
        nltk.download('wordnet')
        self.lemmatizer = WordNetLemmatizer()
        self.stop_words = set(stopwords.words('portuguese'))

    def processar_historias_usuario(self, historias_usuario):
        freq_dists = []
        for historia_usuario in historias_usuario:
            tokens = word_tokenize(historia_usuario)
            tokens = [token.lower() for token in tokens if token not in string.punctuation]
            tokens = [token for token in tokens if token not in self.stop_words]
            tokens = [self.lemmatizer.lemmatize(token) for token in tokens]
            freq_dist = FreqDist(tokens)
            freq_dists.append(freq_dist)
        return freq_dists

# %%
processador = ProcessadorHistoriasUsuario()
freq_dists = processador.processar_historias_usuario(historias_usuario)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
unicas = set()
for freq_dist in freq_dists:
    unicas.update(freq_dist.keys())

print("Total de palavras únicas:", len(unicas))
print("Diversidade Lexica:", len(unicas) / len(freq_dists))
# Out:
# Total de palavras únicas: 262
# Diversidade Lexica: 5.137254901960785

# %%
historia_index = 0
print("História de usuário original:")
print(historias_usuario[historia_index])
print()
print("Tokens processados e limpos:")
print(freq_dists[historia_index].keys())
# Out:
# História de usuário original:
# Como Testador eu quero um jeito mais fácil de incluir os requisitos do aplicativo na ferramenta DRL-Mobtest para criar casos de teste que cubram tudo que o aplicativo precisa fazer, sem ter que gastar muito tempo escrevendo manualmente.
#
# Tokens processados e limpos:
# dict_keys(['testador', 'quero', 'jeito', 'fácil', 'incluir', 'requisitos', 'aplicativo', 'ferramenta', 'drl-mobtest', 'criar', 'casos', 'teste', 'cubram', 'tudo', 'precisa', 'fazer', 'ter', 'gastar', 'tempo', 'escrevendo', 'manualmente'])

# %%
for i, freq_dist in enumerate(freq_dists):
    print(f"História de Usuário {i+1}:")
    for palavra, frequencia in freq_dist.most_common():
        print(f"- {palavra}:  - QTDE: ({frequencia})")
        print(f"tipo: {type(palavra)},\n Tamanho: {len(palavra)},\n Binário: {palavra.isalpha()},\n Null:{palavra == ''},\n")
# Out:
# História de Usuário 1:
# - aplicativo:  - QTDE: (2)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - quero:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - jeito:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - fácil:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - incluir:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - requisitos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - ferramenta:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - drl-mobtest:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: False,
#  Null:False,
#
# - criar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - casos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - teste:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - cubram:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - tudo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 4,
#  Binário: True,
#  Null:False,
#
# - precisa:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - fazer:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - ter:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 3,
#  Binário: True,
#  Null:False,
#
# - gastar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - tempo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - escrevendo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - manualmente:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# História de Usuário 2:
# - ferramenta:  - QTDE: (2)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - quero:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - maneira:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - ensinar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - drl-mobtest:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: False,
#  Null:False,
#
# - entender:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - requisitos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - aplicativo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - usando:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - nlp:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 3,
#  Binário: True,
#  Null:False,
#
# - fazer:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - gere:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 4,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - automaticamente:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 15,
#  Binário: True,
#  Null:False,
#
# História de Usuário 3:
# - casos:  - QTDE: (2)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - teste:  - QTDE: (2)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - quero:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - ferramenta:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - gere:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 4,
#  Binário: True,
#  Null:False,
#
# - abrangentes:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - cubram:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - integralmente:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 13,
#  Binário: True,
#  Null:False,
#
# - todos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - requisitos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - aplicativo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - assegurando:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - software:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - completo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - funcional:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - depender:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - exclusivamente:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 14,
#  Binário: True,
#  Null:False,
#
# - criação:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - manual:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# História de Usuário 4:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - quero:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - ferramenta:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - integrada:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - outras:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - ferramentas:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - gerenciamento:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 13,
#  Binário: True,
#  Null:False,
#
# - permitindo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - sincronização:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 13,
#  Binário: True,
#  Null:False,
#
# - automática:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - requisitos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - facilitando:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - processo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - criação:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - casos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# História de Usuário 5:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - quero:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - ferramenta:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - gere:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 4,
#  Binário: True,
#  Null:False,
#
# - casos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - teste:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - completos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - funcionais:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - cubram:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - todos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - requisitos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - aplicativo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - garantir:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - cobertura:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - abrangente:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - durante:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# História de Usuário 6:
# - teste:  - QTDE: (2)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - quero:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - integração:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - outras:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - ferramentas:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - gerenciamento:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 13,
#  Binário: True,
#  Null:False,
#
# - sincronizar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - automaticamente:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 15,
#  Binário: True,
#  Null:False,
#
# - requisitos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - facilitar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - criação:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - casos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - visando:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - melhorar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - eficiência:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - precisão:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - processo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# História de Usuário 7:
# - testis:  - QTDE: (2)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - quero:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - relatórios:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - detalhados:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - sobre:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - cobertura:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - análise:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - precisa:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - durante:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - execução:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - fim:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 3,
#  Binário: True,
#  Null:False,
#
# - avaliar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - qualidade:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - extensão:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - realizados:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# História de Usuário 8:
# - teste:  - QTDE: (2)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - desejo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - ferramenta:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - identifique:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - automaticamente:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 15,
#  Binário: True,
#  Null:False,
#
# - casos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - críticos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - priorizar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - análise:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - visando:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - direcionar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - esforços:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - áreas:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - maior:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - risco:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# História de Usuário 9:
# - uso:  - QTDE: (2)
# tipo: <class 'str'>,
#  Tamanho: 3,
#  Binário: True,
#  Null:False,
#
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - preciso:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - ferramenta:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - sugira:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - casos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - teste:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - base:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 4,
#  Binário: True,
#  Null:False,
#
# - padrões:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - real:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 4,
#  Binário: True,
#  Null:False,
#
# - aplicativo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - garantir:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - reflitam:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - cenários:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - típicos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# História de Usuário 10:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - quero:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - sugestões:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - base:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 4,
#  Binário: True,
#  Null:False,
#
# - padrões:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - falha:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - históricos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - evitar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - problemas:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - recorrentes:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - software:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - visando:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - melhorar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - qualidade:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - robustez:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - produto:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# História de Usuário 11:
# - testis:  - QTDE: (2)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - diferentes:  - QTDE: (2)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - desejo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - suporte:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - execução:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - automatizados:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 13,
#  Binário: True,
#  Null:False,
#
# - dispositivos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 12,
#  Binário: True,
#  Null:False,
#
# - ambientes:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - garantir:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - consistência:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 12,
#  Binário: True,
#  Null:False,
#
# - confiabilidade:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 14,
#  Binário: True,
#  Null:False,
#
# - cenários:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# História de Usuário 12:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - preciso:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - ferramenta:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - detecte:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - automaticamente:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 15,
#  Binário: True,
#  Null:False,
#
# - mudanças:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - requisitos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - ajuste:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - casos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - teste:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - correspondentes:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 15,
#  Binário: True,
#  Null:False,
#
# - manter:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - alinhados:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - evolução:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - aplicativo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# História de Usuário 13:
# - mudanças:  - QTDE: (2)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - quero:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - integração:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - sistemas:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - controle:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - versão:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - rastrear:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - requisitos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - código-fonte:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 12,
#  Binário: False,
#  Null:False,
#
# - visando:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - gestão:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - eficaz:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - durante:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - ciclo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - desenvolvimento:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 15,
#  Binário: True,
#  Null:False,
#
# História de Usuário 14:
# - taxon:  - QTDE: (2)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - desejo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - métricas:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - detalhadas:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - sobre:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - eficácia:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - incluindo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - cobertura:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - falha:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - avaliar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - qualidade:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - processo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - teste:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# História de Usuário 15:
# - desempenho:  - QTDE: (2)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - preciso:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - suporte:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - execução:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - escalabilidade:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 14,
#  Binário: True,
#  Null:False,
#
# - garantir:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - aplicativo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - atenda:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - requisitos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - sob:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 3,
#  Binário: True,
#  Null:False,
#
# - carga:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# História de Usuário 16:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - quero:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - análise:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - automática:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - resultados:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - relatórios:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - detalhados:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - sobre:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - problemas:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - encontrados:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - fim:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 3,
#  Binário: True,
#  Null:False,
#
# - facilitar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - identificação:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 13,
#  Binário: True,
#  Null:False,
#
# - correção:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - defeitos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# História de Usuário 17:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - desejo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - simular:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - cenários:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - teste:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - complexos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - realistas:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - garantir:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - próximos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - realidade:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - visando:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - validação:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - precisa:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - software:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# História de Usuário 18:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - preciso:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - suporte:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - execução:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - regressão:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - automatizados:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 13,
#  Binário: True,
#  Null:False,
#
# - garantir:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - alterações:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - código:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - introduzam:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - regressões:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# História de Usuário 19:
# - teste:  - QTDE: (2)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - quero:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - identificação:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 13,
#  Binário: True,
#  Null:False,
#
# - automática:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - casos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - redundantes:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - desnecessários:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 14,
#  Binário: True,
#  Null:False,
#
# - otimizar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - esforços:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# História de Usuário 20:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - desejo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - integração:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - fácil:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - ferramentas:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - gerenciamento:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 13,
#  Binário: True,
#  Null:False,
#
# - projetos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - colaboração:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - eficiente:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - outros:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - membros:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - equipe:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - desenvolvimento:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 15,
#  Binário: True,
#  Null:False,
#
# História de Usuário 21:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - preciso:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - suporte:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - execução:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - usabilidade:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - garantir:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - aplicativo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - fácil:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - intuitivo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - usar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 4,
#  Binário: True,
#  Null:False,
#
# História de Usuário 22:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - quero:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - ferramenta:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - crie:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 4,
#  Binário: True,
#  Null:False,
#
# - automaticamente:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 15,
#  Binário: True,
#  Null:False,
#
# - conjuntos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - dado:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 4,
#  Binário: True,
#  Null:False,
#
# - teste:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - realistas:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - simular:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - condições:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - reais:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - uso:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 3,
#  Binário: True,
#  Null:False,
#
# História de Usuário 23:
# - desempenho:  - QTDE: (2)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - desejo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - integração:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - ferramentas:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - monitoramento:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 13,
#  Binário: True,
#  Null:False,
#
# - tempo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - real:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 4,
#  Binário: True,
#  Null:False,
#
# - avaliar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - aplicativo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - durante:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# História de Usuário 24:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - preciso:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - suporte:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - execução:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - localização:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - internacionalização:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 19,
#  Binário: True,
#  Null:False,
#
# - garantir:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - aplicativo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - compatível:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - diferentes:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - idiomas:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - regiões:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# História de Usuário 25:
# - teste:  - QTDE: (2)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - quero:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - geração:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - automática:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - dado:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 4,
#  Binário: True,
#  Null:False,
#
# - sintéticos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - complementar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 12,
#  Binário: True,
#  Null:False,
#
# - casos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - manuais:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# História de Usuário 26:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - desejo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - suporte:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - execução:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - acessibilidade:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 14,
#  Binário: True,
#  Null:False,
#
# - garantir:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - aplicativo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - acessível:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - todos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - usuários:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# História de Usuário 27:
# - integração:  - QTDE: (2)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - preciso:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - suporte:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - execução:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - contínua:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - garantir:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - alterações:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - código:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - quebrem:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - outras:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - partes:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - sistema:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# História de Usuário 28:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - quero:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - identificação:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 13,
#  Binário: True,
#  Null:False,
#
# - automática:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - casos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - teste:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - incompletos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - mal:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 3,
#  Binário: True,
#  Null:False,
#
# - definidos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - garantir:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - qualidade:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# História de Usuário 29:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - desejo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - identificação:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 13,
#  Binário: True,
#  Null:False,
#
# - automática:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - dependências:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 12,
#  Binário: True,
#  Null:False,
#
# - casos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - teste:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - garantir:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - sequência:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - lógica:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - execução:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# História de Usuário 30:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - preciso:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - suporte:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - execução:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - recuperação:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - desastres:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - avaliar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - capacidade:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - sistema:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - recuperar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - falhas:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# História de Usuário 31:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - quero:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - ferramenta:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - identifique:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - automaticamente:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 15,
#  Binário: True,
#  Null:False,
#
# - casos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - teste:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - paralelizáveis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 14,
#  Binário: True,
#  Null:False,
#
# - otimizar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - execução:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# História de Usuário 32:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - desejo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - simulação:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - cenários:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - teste:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - carga:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - extremamente:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 12,
#  Binário: True,
#  Null:False,
#
# - alta:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 4,
#  Binário: True,
#  Null:False,
#
# - avaliar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - capacidade:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - escalabilidade:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 14,
#  Binário: True,
#  Null:False,
#
# - sistema:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# História de Usuário 33:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - preciso:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - suporte:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - execução:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - compatibilidade:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 15,
#  Binário: True,
#  Null:False,
#
# - diferentes:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - navegadores:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - dispositivos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 12,
#  Binário: True,
#  Null:False,
#
# - garantir:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - experiência:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - consistente:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - todos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - usuários:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# História de Usuário 34:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - quero:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - geração:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - automática:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - relatórios:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - teste:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - personalizados:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 14,
#  Binário: True,
#  Null:False,
#
# - comunicar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - eficazmente:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - resultados:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# História de Usuário 35:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - desejo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - rastreamento:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 12,
#  Binário: True,
#  Null:False,
#
# - automático:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - resultados:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - teste:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - longo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - tempo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - identificar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - tendências:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - padrões:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - qualidade:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# História de Usuário 36:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - preciso:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - suporte:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - execução:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - regressão:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - progressiva:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - garantir:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - nova:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 4,
#  Binário: True,
#  Null:False,
#
# - alterações:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - quebrem:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - funcionalidades:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 15,
#  Binário: True,
#  Null:False,
#
# - existentes:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# História de Usuário 37:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - quero:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - sugestões:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - automáticas:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - aprimorar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - casos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - teste:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - existentes:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - aumentar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - eficiência:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - eficácia:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# História de Usuário 38:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - desejo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - ferramenta:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - aprenda:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - resultados:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - melhore:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - sugestões:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - futuras:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - otimização:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - contínua:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - processo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - teste:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# História de Usuário 39:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - preciso:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - suporte:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - execução:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - segurança:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - automatizados:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 13,
#  Binário: True,
#  Null:False,
#
# - identificar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - vulnerabilidades:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 16,
#  Binário: True,
#  Null:False,
#
# - aplicativo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# História de Usuário 40:
# - código:  - QTDE: (2)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - quero:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - integração:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - ferramentas:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - análise:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - estático:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - identificar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - áreas:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - risco:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - avaliação:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - abrangente:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - qualidade:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# História de Usuário 41:
# - integração:  - QTDE: (2)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - sistema:  - QTDE: (2)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - usuário:  - QTDE: (2)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - desejo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - suporte:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - execução:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - teste:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - aceitação:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - validar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - diferentes:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - partes:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - conformidade:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 12,
#  Binário: True,
#  Null:False,
#
# - requisitos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# História de Usuário 42:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - preciso:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - suporte:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - execução:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - confiabilidade:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 14,
#  Binário: True,
#  Null:False,
#
# - disponibilidade:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 15,
#  Binário: True,
#  Null:False,
#
# - garantir:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - aplicativo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - sempre:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - disponível:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - funcione:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - corretamente:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 12,
#  Binário: True,
#  Null:False,
#
# História de Usuário 43:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - quero:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - ferramenta:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - sugira:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - casos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - teste:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - base:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 4,
#  Binário: True,
#  Null:False,
#
# - modelos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - qualidade:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - software:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - reconhecidos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 12,
#  Binário: True,
#  Null:False,
#
# - garantir:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - abordagem:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - abrangente:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - padronizada:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# História de Usuário 44:
# - usuário:  - QTDE: (2)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - desejo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - integração:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - ferramentas:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - automação:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - teste:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - interface:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - automatizar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - interação:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# História de Usuário 45:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - preciso:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - suporte:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - execução:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - estresse:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - robustez:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - avaliar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - estabilidade:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 12,
#  Binário: True,
#  Null:False,
#
# - confiabilidade:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 14,
#  Binário: True,
#  Null:False,
#
# - aplicativo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - sob:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 3,
#  Binário: True,
#  Null:False,
#
# - condições:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - adversas:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# História de Usuário 46:
# - teste:  - QTDE: (2)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - quero:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - ferramenta:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - sugira:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - casos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - áreas:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - alto:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 4,
#  Binário: True,
#  Null:False,
#
# - risco:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - complexidade:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 12,
#  Binário: True,
#  Null:False,
#
# - priorizar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - esforços:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# História de Usuário 47:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - desejo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - integração:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - ferramentas:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - gerenciamento:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 13,
#  Binário: True,
#  Null:False,
#
# - defeitos:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - rastreamento:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 12,
#  Binário: True,
#  Null:False,
#
# - correções:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - gestão:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - eficaz:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - problemas:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - encontrados:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - durante:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# História de Usuário 48:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - preciso:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - suporte:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - execução:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - usabilidade:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - remota:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - teste:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - usuário:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - beta:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 4,
#  Binário: True,
#  Null:False,
#
# - coletar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - feedback:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - usuários:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - reais:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# História de Usuário 49:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - quero:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - ferramenta:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - forneça:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - feedback:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - tempo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# - real:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 4,
#  Binário: True,
#  Null:False,
#
# - durante:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - execução:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - facilitar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - identificação:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 13,
#  Binário: True,
#  Null:False,
#
# - imediata:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - problemas:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# História de Usuário 50:
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - desejo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - integração:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - ferramentas:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 11,
#  Binário: True,
#  Null:False,
#
# - automação:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - infraestrutura:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 14,
#  Binário: True,
#  Null:False,
#
# - provisionamento:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 15,
#  Binário: True,
#  Null:False,
#
# - configuração:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 12,
#  Binário: True,
#  Null:False,
#
# - automatizados:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 13,
#  Binário: True,
#  Null:False,
#
# - facilitar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 9,
#  Binário: True,
#  Null:False,
#
# - preparação:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - ambiente:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - teste:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 5,
#  Binário: True,
#  Null:False,
#
# História de Usuário 51:
# - desempenho:  - QTDE: (2)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - testador:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - preciso:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - suporte:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - execução:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,
#
# - testis:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - comparação:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - versões:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - anteriores:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - atuais:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 6,
#  Binário: True,
#  Null:False,
#
# - aplicativo:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 10,
#  Binário: True,
#  Null:False,
#
# - avaliar:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - impacto:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 7,
#  Binário: True,
#  Null:False,
#
# - mudanças:  - QTDE: (1)
# tipo: <class 'str'>,
#  Tamanho: 8,
#  Binário: True,
#  Null:False,

# %%
nome, valor = zip(*freq_dists[0].most_common(5))
fig, ax = plt.subplots(figsize=(6,5))
sns.barplot(x=np.array(nome), y=np.array(valor), ax=ax)
plt.show()

# %%
nome,valor = zip(*freq_dists[i].most_common(5))
fig, ax = plt.subplots(figsize=(6,5))
sns.barplot(x=np.array(nome), y=np.array(valor), ax=ax)
# Out:
# <Axes: >

# %%
for i, freq_dist in enumerate(freq_dists):
    historia_usuario = " ".join(freq_dist.keys())
    resultado = classificador(historia_usuario, candidate_labels=rotulos)
    top_label = resultado['labels'][0]
    confianca = resultado['scores'][0]
    print(f"História de Usuário {i+1}: Rótulo Previsto: {top_label}, Confiança: {confianca:.2f}")
# Out:
# História de Usuário 1: Rótulo Previsto: testador, Confiança: 0.56
# História de Usuário 2: Rótulo Previsto: testador, Confiança: 0.69
# História de Usuário 3: Rótulo Previsto: testador, Confiança: 0.60
# História de Usuário 4: Rótulo Previsto: testador, Confiança: 0.70
# História de Usuário 5: Rótulo Previsto: testador, Confiança: 0.63
# História de Usuário 6: Rótulo Previsto: testador, Confiança: 0.73
# História de Usuário 7: Rótulo Previsto: testador, Confiança: 0.68
# História de Usuário 8: Rótulo Previsto: testador, Confiança: 0.53
# História de Usuário 9: Rótulo Previsto: testador, Confiança: 0.44
# História de Usuário 10: Rótulo Previsto: testador, Confiança: 0.79
# História de Usuário 11: Rótulo Previsto: testador, Confiança: 0.56
# História de Usuário 12: Rótulo Previsto: testador, Confiança: 0.64
# História de Usuário 13: Rótulo Previsto: testador, Confiança: 0.78
# História de Usuário 14: Rótulo Previsto: testador, Confiança: 0.72
# História de Usuário 15: Rótulo Previsto: testador, Confiança: 0.58
# História de Usuário 16: Rótulo Previsto: testador, Confiança: 0.64
# História de Usuário 17: Rótulo Previsto: testador, Confiança: 0.70
# História de Usuário 18: Rótulo Previsto: testador, Confiança: 0.66
# História de Usuário 19: Rótulo Previsto: testador, Confiança: 0.43
# História de Usuário 20: Rótulo Previsto: testador, Confiança: 0.78
# História de Usuário 21: Rótulo Previsto: testador, Confiança: 0.68
# História de Usuário 22: Rótulo Previsto: testador, Confiança: 0.55
# História de Usuário 23: Rótulo Previsto: testador, Confiança: 0.47
# História de Usuário 24: Rótulo Previsto: testador, Confiança: 0.63
# História de Usuário 25: Rótulo Previsto: testador, Confiança: 0.49
# História de Usuário 26: Rótulo Previsto: testador, Confiança: 0.52
# História de Usuário 27: Rótulo Previsto: testador, Confiança: 0.66
# História de Usuário 28: Rótulo Previsto: testador, Confiança: 0.53
# História de Usuário 29: Rótulo Previsto: testador, Confiança: 0.55
# História de Usuário 30: Rótulo Previsto: testador, Confiança: 0.66
# História de Usuário 31: Rótulo Previsto: testador, Confiança: 0.48
# História de Usuário 32: Rótulo Previsto: testador, Confiança: 0.63
# História de Usuário 33: Rótulo Previsto: testador, Confiança: 0.60
# História de Usuário 34: Rótulo Previsto: testador, Confiança: 0.56
# História de Usuário 35: Rótulo Previsto: testador, Confiança: 0.60
# História de Usuário 36: Rótulo Previsto: testador, Confiança: 0.74
# História de Usuário 37: Rótulo Previsto: testador, Confiança: 0.49
# História de Usuário 38: Rótulo Previsto: testador, Confiança: 0.63
# História de Usuário 39: Rótulo Previsto: testador, Confiança: 0.63
# História de Usuário 40: Rótulo Previsto: testador, Confiança: 0.69
# História de Usuário 41: Rótulo Previsto: testador, Confiança: 0.58
# História de Usuário 42: Rótulo Previsto: testador, Confiança: 0.66
# História de Usuário 43: Rótulo Previsto: testador, Confiança: 0.65
# História de Usuário 44: Rótulo Previsto: testador, Confiança: 0.71
# História de Usuário 45: Rótulo Previsto: testador, Confiança: 0.66
# História de Usuário 46: Rótulo Previsto: testador, Confiança: 0.61
# História de Usuário 47: Rótulo Previsto: testador, Confiança: 0.77
# História de Usuário 48: Rótulo Previsto: testador, Confiança: 0.56
# História de Usuário 49: Rótulo Previsto: testador, Confiança: 0.72
# História de Usuário 50: Rótulo Previsto: testador, Confiança: 0.63
# História de Usuário 51: Rótulo Previsto: testador, Confiança: 0.33

# %%
for i, freq_dist in enumerate(freq_dists):
    historia_usuario = " ".join(freq_dist.keys())
    resultado = roberta(f"História de Usuário {i+1}: {historia_usuario}")
    print(f"Resultado para História de Usuário {i+1}: {resultado}")
# Out:
# Resultado para História de Usuário 1: [{'entity_group': 'LABEL_1', 'score': 0.5718294, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.54316276, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.6169304, 'word': ' 1 : testador quero jeito facil incluir requisitos aplicativo ferramenta drl - mobtest criar casos teste cubram tudo precisa fazer ter', 'start': 21, 'end': 150}, {'entity_group': 'LABEL_0', 'score': 0.5604832, 'word': ' gas', 'start': 152, 'end': 154}, {'entity_group': 'LABEL_1', 'score': 0.51532245, 'word': 'tar tempo escrevendo manualmente', 'start': 154, 'end': 186}]
# Resultado para História de Usuário 2: [{'entity_group': 'LABEL_1', 'score': 0.57995206, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5443058, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.6083664, 'word': ' 2 : testador quero maneira ensinar ferramenta drl - mobtest entender requisitos aplicativo usando nlp fazer gere testis automaticamente', 'start': 21, 'end': 152}]
# Resultado para História de Usuário 3: [{'entity_group': 'LABEL_1', 'score': 0.55166996, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.57075673, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.5972941, 'word': ' 3 : testador quero ferramenta gere casos teste abrangentes', 'start': 21, 'end': 77}, {'entity_group': 'LABEL_0', 'score': 0.54414666, 'word': ' cubram', 'start': 79, 'end': 84}, {'entity_group': 'LABEL_1', 'score': 0.6087066, 'word': ' integralmente todos requisitos aplicativo assegurando software completo funcional depender exclusivamente criacao manual', 'start': 86, 'end': 205}]
# Resultado para História de Usuário 4: [{'entity_group': 'LABEL_1', 'score': 0.58442724, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5629132, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.6117276, 'word': ' 4 : testador quero ferramenta integrada outras ferramentas gerenciamento permitindo sincronizacao automatica requisitos facilitando processo criacao casos testis', 'start': 21, 'end': 180}]
# Resultado para História de Usuário 5: [{'entity_group': 'LABEL_1', 'score': 0.5810312, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.56161016, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.68329847, 'word': ' 5 :', 'start': 21, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.51877755, 'word': ' tes', 'start': 24, 'end': 26}, {'entity_group': 'LABEL_1', 'score': 0.6243158, 'word': 'tador quero ferramenta gere', 'start': 26, 'end': 53}, {'entity_group': 'LABEL_0', 'score': 0.5112634, 'word': ' casos', 'start': 55, 'end': 59}, {'entity_group': 'LABEL_1', 'score': 0.51869154, 'word': ' teste completos funcionais', 'start': 61, 'end': 86}, {'entity_group': 'LABEL_0', 'score': 0.51413405, 'word': ' cub', 'start': 88, 'end': 90}, {'entity_group': 'LABEL_1', 'score': 0.60589606, 'word': 'ram todos requisitos', 'start': 90, 'end': 110}, {'entity_group': 'LABEL_0', 'score': 0.5153051, 'word': ' aplica', 'start': 112, 'end': 117}, {'entity_group': 'LABEL_1', 'score': 0.60246503, 'word': 'tivo garantir cobertura abrangente durante testis', 'start': 117, 'end': 166}]
# Resultado para História de Usuário 6: [{'entity_group': 'LABEL_1', 'score': 0.58814603, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.54764664, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.65415543, 'word': ' 6 : testador quero', 'start': 21, 'end': 37}, {'entity_group': 'LABEL_0', 'score': 0.58110064, 'word': ' integracao', 'start': 39, 'end': 48}, {'entity_group': 'LABEL_1', 'score': 0.5625034, 'word': ' outras ferramentas gerencia', 'start': 50, 'end': 76}, {'entity_group': 'LABEL_0', 'score': 0.55477536, 'word': 'mento', 'start': 76, 'end': 81}, {'entity_group': 'LABEL_1', 'score': 0.58382434, 'word': ' sincronizar automaticamente requisitos facilitar criacao casos teste visando melhorar eficiencia precisao processo', 'start': 83, 'end': 196}]
# Resultado para História de Usuário 7: [{'entity_group': 'LABEL_1', 'score': 0.5970738, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.51463896, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.63557535, 'word': ' 7 :', 'start': 21, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.506363, 'word': ' tes', 'start': 24, 'end': 26}, {'entity_group': 'LABEL_1', 'score': 0.6310175, 'word': 'tador quero relatorios detalhados sobre cobertura testis analise precisa durante execucao fim avaliar', 'start': 26, 'end': 127}, {'entity_group': 'LABEL_0', 'score': 0.53815335, 'word': ' qualidade', 'start': 129, 'end': 137}, {'entity_group': 'LABEL_1', 'score': 0.60264844, 'word': ' extensao realizados', 'start': 139, 'end': 157}]
# Resultado para História de Usuário 8: [{'entity_group': 'LABEL_1', 'score': 0.5652815, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5401864, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.5582016, 'word': ' 8 : testador desejo ferramenta identifique automaticamente casos teste criticos', 'start': 21, 'end': 98}, {'entity_group': 'LABEL_0', 'score': 0.53411484, 'word': ' priori', 'start': 100, 'end': 105}, {'entity_group': 'LABEL_1', 'score': 0.6233111, 'word': 'zar analise visando direcionar esforcos areas maior', 'start': 105, 'end': 156}, {'entity_group': 'LABEL_0', 'score': 0.5494594, 'word': ' risco', 'start': 158, 'end': 162}]
# Resultado para História de Usuário 9: [{'entity_group': 'LABEL_0', 'score': 0.51335484, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_1', 'score': 0.5857138, 'word': ' de', 'start': 10, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5558537, 'word': ' usuario 9', 'start': 13, 'end': 21}, {'entity_group': 'LABEL_1', 'score': 0.5750891, 'word': ' :', 'start': 22, 'end': 22}, {'entity_group': 'LABEL_0', 'score': 0.57238394, 'word': ' tes', 'start': 24, 'end': 26}, {'entity_group': 'LABEL_1', 'score': 0.6178654, 'word': 'tador preciso ferramenta sugira', 'start': 26, 'end': 57}, {'entity_group': 'LABEL_0', 'score': 0.5113086, 'word': ' casos', 'start': 59, 'end': 63}, {'entity_group': 'LABEL_1', 'score': 0.5340799, 'word': ' teste base', 'start': 65, 'end': 74}, {'entity_group': 'LABEL_0', 'score': 0.608062, 'word': ' padroes', 'start': 76, 'end': 82}, {'entity_group': 'LABEL_1', 'score': 0.52017576, 'word': ' uso real', 'start': 84, 'end': 91}, {'entity_group': 'LABEL_0', 'score': 0.56187606, 'word': ' aplicativo', 'start': 93, 'end': 102}, {'entity_group': 'LABEL_1', 'score': 0.5566999, 'word': ' garantir testis refli', 'start': 104, 'end': 124}, {'entity_group': 'LABEL_0', 'score': 0.5514441, 'word': 'tam', 'start': 124, 'end': 127}, {'entity_group': 'LABEL_1', 'score': 0.5809677, 'word': ' cenarios tipicos', 'start': 129, 'end': 144}]
# Resultado para História de Usuário 10: [{'entity_group': 'LABEL_1', 'score': 0.6104133, 'word': ' historia de usuario 10 : testador quero sugestoes base', 'start': 0, 'end': 53}, {'entity_group': 'LABEL_0', 'score': 0.51083153, 'word': ' padroes', 'start': 55, 'end': 61}, {'entity_group': 'LABEL_1', 'score': 0.62684494, 'word': ' falha historicos evitar problemas recorrentes software visando melhorar qualidade robustez produto', 'start': 63, 'end': 160}]
# Resultado para História de Usuário 11: [{'entity_group': 'LABEL_0', 'score': 0.50592685, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_1', 'score': 0.6044458, 'word': ' de', 'start': 10, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.56578404, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.61343086, 'word': ' 11 :', 'start': 21, 'end': 23}, {'entity_group': 'LABEL_0', 'score': 0.5317646, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.5211847, 'word': 'tador', 'start': 27, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.52502483, 'word': ' desejo', 'start': 34, 'end': 39}, {'entity_group': 'LABEL_1', 'score': 0.55509293, 'word': ' suporte execucao testis', 'start': 41, 'end': 63}, {'entity_group': 'LABEL_0', 'score': 0.53278655, 'word': ' automatizados', 'start': 65, 'end': 77}, {'entity_group': 'LABEL_1', 'score': 0.5818974, 'word': ' diferentes dispositivos', 'start': 79, 'end': 101}, {'entity_group': 'LABEL_0', 'score': 0.50321394, 'word': ' ambientes', 'start': 103, 'end': 111}, {'entity_group': 'LABEL_1', 'score': 0.63402, 'word': ' garantir consistencia', 'start': 113, 'end': 133}, {'entity_group': 'LABEL_0', 'score': 0.5214474, 'word': ' confiabilidade cenarios', 'start': 135, 'end': 157}]
# Resultado para História de Usuário 12: [{'entity_group': 'LABEL_1', 'score': 0.55864334, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5224552, 'word': ' usuario 12', 'start': 13, 'end': 22}, {'entity_group': 'LABEL_1', 'score': 0.62899923, 'word': ' :', 'start': 23, 'end': 23}, {'entity_group': 'LABEL_0', 'score': 0.53776515, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.5934421, 'word': 'tador preciso ferramenta detecte automaticamente mudancas requisitos', 'start': 27, 'end': 95}, {'entity_group': 'LABEL_0', 'score': 0.5058553, 'word': ' ajuste', 'start': 97, 'end': 102}, {'entity_group': 'LABEL_1', 'score': 0.5757134, 'word': ' casos teste correspondentes manter testis alinhados evolucao', 'start': 104, 'end': 163}, {'entity_group': 'LABEL_0', 'score': 0.5211923, 'word': ' aplica', 'start': 165, 'end': 170}, {'entity_group': 'LABEL_1', 'score': 0.52435327, 'word': 'tivo', 'start': 170, 'end': 174}]
# Resultado para História de Usuário 13: [{'entity_group': 'LABEL_1', 'score': 0.55652654, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.52328265, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.5828588, 'word': ' 13 :', 'start': 21, 'end': 23}, {'entity_group': 'LABEL_0', 'score': 0.52997375, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.65254974, 'word': 'tador quero', 'start': 27, 'end': 38}, {'entity_group': 'LABEL_0', 'score': 0.5727834, 'word': ' integracao sistemas', 'start': 40, 'end': 58}, {'entity_group': 'LABEL_1', 'score': 0.6031702, 'word': ' controle versao rastrear mudancas requisitos codigo - fonte visando gestao eficaz durante ciclo', 'start': 60, 'end': 152}, {'entity_group': 'LABEL_0', 'score': 0.5825058, 'word': ' desenvolvimento', 'start': 154, 'end': 168}]
# Resultado para História de Usuário 14: [{'entity_group': 'LABEL_0', 'score': 0.52488375, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_1', 'score': 0.5706907, 'word': ' de', 'start': 10, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.55379224, 'word': ' usuario 14', 'start': 13, 'end': 22}, {'entity_group': 'LABEL_1', 'score': 0.6546954, 'word': ' :', 'start': 23, 'end': 23}, {'entity_group': 'LABEL_0', 'score': 0.53978086, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.52196187, 'word': 'tador', 'start': 27, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.56935966, 'word': ' desejo metricas', 'start': 34, 'end': 48}, {'entity_group': 'LABEL_1', 'score': 0.5750876, 'word': ' detalhadas sobre eficacia testis incluindo', 'start': 50, 'end': 91}, {'entity_group': 'LABEL_0', 'score': 0.6279867, 'word': ' tax', 'start': 93, 'end': 95}, {'entity_group': 'LABEL_1', 'score': 0.62999094, 'word': 'on', 'start': 95, 'end': 97}, {'entity_group': 'LABEL_0', 'score': 0.5023856, 'word': ' cobertura', 'start': 99, 'end': 107}, {'entity_group': 'LABEL_1', 'score': 0.55497754, 'word': ' falha avaliar', 'start': 109, 'end': 121}, {'entity_group': 'LABEL_0', 'score': 0.57215977, 'word': ' qualidade', 'start': 123, 'end': 131}, {'entity_group': 'LABEL_1', 'score': 0.5523881, 'word': ' processo teste', 'start': 133, 'end': 146}]
# Resultado para História de Usuário 15: [{'entity_group': 'LABEL_0', 'score': 0.5524421, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_1', 'score': 0.62993604, 'word': ' de', 'start': 10, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5887423, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.6616345, 'word': ' 15 :', 'start': 21, 'end': 23}, {'entity_group': 'LABEL_0', 'score': 0.5713165, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.5884295, 'word': 'tador preciso suporte execucao testis', 'start': 27, 'end': 64}, {'entity_group': 'LABEL_0', 'score': 0.5699714, 'word': ' desempenho escalabilidade', 'start': 66, 'end': 90}, {'entity_group': 'LABEL_1', 'score': 0.57486874, 'word': ' garantir', 'start': 92, 'end': 99}, {'entity_group': 'LABEL_0', 'score': 0.55631846, 'word': ' aplica', 'start': 101, 'end': 106}, {'entity_group': 'LABEL_1', 'score': 0.5254799, 'word': 'tivo atenda requisitos', 'start': 106, 'end': 128}, {'entity_group': 'LABEL_0', 'score': 0.5613432, 'word': ' sob carga', 'start': 130, 'end': 138}]
# Resultado para História de Usuário 16: [{'entity_group': 'LABEL_1', 'score': 0.6121608, 'word': ' historia de usuario 16 :', 'start': 0, 'end': 23}, {'entity_group': 'LABEL_0', 'score': 0.50746334, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.60858124, 'word': 'tador quero analise automatica', 'start': 27, 'end': 57}, {'entity_group': 'LABEL_0', 'score': 0.5182938, 'word': ' resultados', 'start': 59, 'end': 68}, {'entity_group': 'LABEL_1', 'score': 0.58829784, 'word': ' testis', 'start': 70, 'end': 75}, {'entity_group': 'LABEL_0', 'score': 0.5295484, 'word': ' relatorios', 'start': 77, 'end': 86}, {'entity_group': 'LABEL_1', 'score': 0.58721507, 'word': ' detalhados sobre problemas encontrados fim facilitar identificacao correcao defeitos', 'start': 88, 'end': 171}]
# Resultado para História de Usuário 17: [{'entity_group': 'LABEL_1', 'score': 0.5733597, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.53210706, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.67000127, 'word': ' 17 :', 'start': 21, 'end': 23}, {'entity_group': 'LABEL_0', 'score': 0.50768185, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.53952855, 'word': 'tador desejo si', 'start': 27, 'end': 42}, {'entity_group': 'LABEL_0', 'score': 0.5653875, 'word': 'mular', 'start': 42, 'end': 47}, {'entity_group': 'LABEL_1', 'score': 0.6054768, 'word': ' cenarios teste complexos realistas garantir testis proximos realidade visando validacao precisa software', 'start': 49, 'end': 152}]
# Resultado para História de Usuário 18: [{'entity_group': 'LABEL_0', 'score': 0.539712, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_1', 'score': 0.58621395, 'word': ' de', 'start': 10, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.543938, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.5959103, 'word': ' 18 :', 'start': 21, 'end': 23}, {'entity_group': 'LABEL_0', 'score': 0.5484441, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.5956823, 'word': 'tador preciso suporte execucao testis', 'start': 27, 'end': 64}, {'entity_group': 'LABEL_0', 'score': 0.52689135, 'word': ' regressao automatizados', 'start': 66, 'end': 88}, {'entity_group': 'LABEL_1', 'score': 0.55066884, 'word': ' garantir alteracoes codigo introdu', 'start': 90, 'end': 123}, {'entity_group': 'LABEL_0', 'score': 0.518664, 'word': 'zam regres', 'start': 123, 'end': 133}, {'entity_group': 'LABEL_1', 'score': 0.55332047, 'word': 'soes', 'start': 133, 'end': 137}]
# Resultado para História de Usuário 19: [{'entity_group': 'LABEL_1', 'score': 0.5901954, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5235672, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.59030086, 'word': ' 19 : testador quero identificacao automatica casos teste redundantes desnecessarios otimizar esforcos', 'start': 21, 'end': 120}]
# Resultado para História de Usuário 20: [{'entity_group': 'LABEL_1', 'score': 0.5983454, 'word': ' historia de usuario 20 :', 'start': 0, 'end': 23}, {'entity_group': 'LABEL_0', 'score': 0.50769615, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.59421253, 'word': 'tador desejo', 'start': 27, 'end': 39}, {'entity_group': 'LABEL_0', 'score': 0.51020896, 'word': ' integracao', 'start': 41, 'end': 50}, {'entity_group': 'LABEL_1', 'score': 0.560331, 'word': ' facil ferramentas gerenciamento projetos colaboracao eficiente outros', 'start': 52, 'end': 120}, {'entity_group': 'LABEL_0', 'score': 0.53710586, 'word': ' membros', 'start': 122, 'end': 128}, {'entity_group': 'LABEL_1', 'score': 0.5795698, 'word': ' equipe', 'start': 130, 'end': 135}, {'entity_group': 'LABEL_0', 'score': 0.54008424, 'word': ' desenvolvimento', 'start': 137, 'end': 151}]
# Resultado para História de Usuário 21: [{'entity_group': 'LABEL_1', 'score': 0.5768827, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.55061525, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.63247395, 'word': ' 21 :', 'start': 21, 'end': 23}, {'entity_group': 'LABEL_0', 'score': 0.5493132, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.61757946, 'word': 'tador preciso suporte execucao testis', 'start': 27, 'end': 64}, {'entity_group': 'LABEL_0', 'score': 0.50788707, 'word': ' usa', 'start': 66, 'end': 68}, {'entity_group': 'LABEL_1', 'score': 0.5998163, 'word': 'bilidade garantir', 'start': 68, 'end': 85}, {'entity_group': 'LABEL_0', 'score': 0.5360549, 'word': ' aplica', 'start': 87, 'end': 92}, {'entity_group': 'LABEL_1', 'score': 0.5904358, 'word': 'tivo facil intuitivo usar', 'start': 92, 'end': 117}]
# Resultado para História de Usuário 22: [{'entity_group': 'LABEL_1', 'score': 0.57418454, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5142052, 'word': ' usuario 22', 'start': 13, 'end': 22}, {'entity_group': 'LABEL_1', 'score': 0.6004889, 'word': ' : testador quero ferramenta crie automaticamente conjuntos dado teste realistas', 'start': 23, 'end': 101}, {'entity_group': 'LABEL_0', 'score': 0.57966423, 'word': ' simular', 'start': 103, 'end': 109}, {'entity_group': 'LABEL_1', 'score': 0.5419267, 'word': ' condicoes', 'start': 111, 'end': 119}, {'entity_group': 'LABEL_0', 'score': 0.50244, 'word': ' reais', 'start': 121, 'end': 125}, {'entity_group': 'LABEL_1', 'score': 0.56988245, 'word': ' uso', 'start': 127, 'end': 129}]
# Resultado para História de Usuário 23: [{'entity_group': 'LABEL_1', 'score': 0.53928804, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5586945, 'word': ' usuario 23', 'start': 13, 'end': 22}, {'entity_group': 'LABEL_1', 'score': 0.63872075, 'word': ' :', 'start': 23, 'end': 23}, {'entity_group': 'LABEL_0', 'score': 0.51411253, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.55508614, 'word': 'tador', 'start': 27, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.56187636, 'word': ' desejo integracao', 'start': 34, 'end': 50}, {'entity_group': 'LABEL_1', 'score': 0.5000385, 'word': ' ferramentas', 'start': 52, 'end': 62}, {'entity_group': 'LABEL_0', 'score': 0.53469706, 'word': ' monitoramento desempenho tempo', 'start': 64, 'end': 93}, {'entity_group': 'LABEL_1', 'score': 0.5374782, 'word': ' real avaliar', 'start': 95, 'end': 106}, {'entity_group': 'LABEL_0', 'score': 0.5740233, 'word': ' aplica', 'start': 108, 'end': 113}, {'entity_group': 'LABEL_1', 'score': 0.59864753, 'word': 'tivo durante tes', 'start': 113, 'end': 129}, {'entity_group': 'LABEL_0', 'score': 0.5093134, 'word': 'tis', 'start': 129, 'end': 132}]
# Resultado para História de Usuário 24: [{'entity_group': 'LABEL_1', 'score': 0.6076317, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.51040417, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.637172, 'word': ' 24 :', 'start': 21, 'end': 23}, {'entity_group': 'LABEL_0', 'score': 0.5211866, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.62408626, 'word': 'tador preciso suporte execucao testis localizacao internacionalizacao garantir aplicativo compativel diferentes', 'start': 27, 'end': 138}, {'entity_group': 'LABEL_0', 'score': 0.5841995, 'word': ' idiomas', 'start': 140, 'end': 146}, {'entity_group': 'LABEL_1', 'score': 0.60308313, 'word': ' regioes', 'start': 148, 'end': 154}]
# Resultado para História de Usuário 25: [{'entity_group': 'LABEL_1', 'score': 0.614339, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5249192, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.61549914, 'word': ' 25 : testador quero geracao automatica dado teste sinteticos complementar casos manuais', 'start': 21, 'end': 106}]
# Resultado para História de Usuário 26: [{'entity_group': 'LABEL_1', 'score': 0.5825733, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.56564677, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.62645465, 'word': ' 26 :', 'start': 21, 'end': 23}, {'entity_group': 'LABEL_0', 'score': 0.5575593, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.5549489, 'word': 'tador desejo suporte execucao testis', 'start': 27, 'end': 63}, {'entity_group': 'LABEL_0', 'score': 0.5491903, 'word': ' acessibilidade', 'start': 65, 'end': 78}, {'entity_group': 'LABEL_1', 'score': 0.67675227, 'word': ' garantir', 'start': 80, 'end': 87}, {'entity_group': 'LABEL_0', 'score': 0.5000484, 'word': ' aplica', 'start': 89, 'end': 94}, {'entity_group': 'LABEL_1', 'score': 0.58189803, 'word': 'tivo acessivel todos', 'start': 94, 'end': 114}, {'entity_group': 'LABEL_0', 'score': 0.6295262, 'word': ' usuarios', 'start': 116, 'end': 123}]
# Resultado para História de Usuário 27: [{'entity_group': 'LABEL_1', 'score': 0.60568047, 'word': ' historia de usuario 27 :', 'start': 0, 'end': 23}, {'entity_group': 'LABEL_0', 'score': 0.52635175, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.6320478, 'word': 'tador preciso suporte execucao testis integracao continua garantir alteracoes codigo quebrem outras partes sistema', 'start': 27, 'end': 141}]
# Resultado para História de Usuário 28: [{'entity_group': 'LABEL_1', 'score': 0.60642254, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5254208, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.6070863, 'word': ' 28 :', 'start': 21, 'end': 23}, {'entity_group': 'LABEL_0', 'score': 0.5464794, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.6407652, 'word': 'tador quero', 'start': 27, 'end': 38}, {'entity_group': 'LABEL_0', 'score': 0.5103502, 'word': ' identificacao', 'start': 40, 'end': 52}, {'entity_group': 'LABEL_1', 'score': 0.5679996, 'word': ' automatica casos teste', 'start': 54, 'end': 75}, {'entity_group': 'LABEL_0', 'score': 0.5690451, 'word': ' incompletos mal definidos', 'start': 77, 'end': 101}, {'entity_group': 'LABEL_1', 'score': 0.57320416, 'word': ' garantir', 'start': 103, 'end': 110}, {'entity_group': 'LABEL_0', 'score': 0.5250282, 'word': ' qualidade', 'start': 112, 'end': 120}, {'entity_group': 'LABEL_1', 'score': 0.60601145, 'word': ' testis', 'start': 122, 'end': 127}]
# Resultado para História de Usuário 29: [{'entity_group': 'LABEL_1', 'score': 0.5673332, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5219121, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.5695621, 'word': ' 29 :', 'start': 21, 'end': 23}, {'entity_group': 'LABEL_0', 'score': 0.53672796, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.5392698, 'word': 'tador desejo', 'start': 27, 'end': 39}, {'entity_group': 'LABEL_0', 'score': 0.5135042, 'word': ' identificacao', 'start': 41, 'end': 53}, {'entity_group': 'LABEL_1', 'score': 0.574684, 'word': ' automatica dependencias casos teste garantir sequencia', 'start': 55, 'end': 108}, {'entity_group': 'LABEL_0', 'score': 0.51715815, 'word': ' logica', 'start': 110, 'end': 115}, {'entity_group': 'LABEL_1', 'score': 0.55609775, 'word': ' execucao testis', 'start': 117, 'end': 131}]
# Resultado para História de Usuário 30: [{'entity_group': 'LABEL_0', 'score': 0.5153088, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_1', 'score': 0.5729386, 'word': ' de usuario 30 :', 'start': 10, 'end': 23}, {'entity_group': 'LABEL_0', 'score': 0.5051015, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.5972523, 'word': 'tador preciso suporte execucao testis recuperacao desastres avaliar capacidade sistema recuperar falhas', 'start': 27, 'end': 130}]
# Resultado para História de Usuário 31: [{'entity_group': 'LABEL_1', 'score': 0.56930757, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5283461, 'word': ' usuario 31', 'start': 13, 'end': 22}, {'entity_group': 'LABEL_1', 'score': 0.586941, 'word': ' : testador quero ferramenta identifique automaticamente casos teste parale', 'start': 23, 'end': 96}, {'entity_group': 'LABEL_0', 'score': 0.5633359, 'word': 'lizaveis', 'start': 96, 'end': 104}, {'entity_group': 'LABEL_1', 'score': 0.5542939, 'word': ' otimizar execucao testis', 'start': 106, 'end': 129}]
# Resultado para História de Usuário 32: [{'entity_group': 'LABEL_0', 'score': 0.564966, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_1', 'score': 0.5820763, 'word': ' de', 'start': 10, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5618397, 'word': ' usuario 32', 'start': 13, 'end': 22}, {'entity_group': 'LABEL_1', 'score': 0.6148842, 'word': ' :', 'start': 23, 'end': 23}, {'entity_group': 'LABEL_0', 'score': 0.5514297, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.550861, 'word': 'tador', 'start': 27, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.5268764, 'word': ' desejo simulacao', 'start': 34, 'end': 49}, {'entity_group': 'LABEL_1', 'score': 0.50081533, 'word': ' cenarios', 'start': 51, 'end': 58}, {'entity_group': 'LABEL_0', 'score': 0.55777866, 'word': ' teste', 'start': 60, 'end': 64}, {'entity_group': 'LABEL_1', 'score': 0.6418366, 'word': ' carga extremamente alta', 'start': 66, 'end': 88}, {'entity_group': 'LABEL_0', 'score': 0.5117085, 'word': ' avaliar', 'start': 90, 'end': 96}, {'entity_group': 'LABEL_1', 'score': 0.528726, 'word': ' capacidade', 'start': 98, 'end': 107}, {'entity_group': 'LABEL_0', 'score': 0.5998422, 'word': ' escalabilidade', 'start': 109, 'end': 122}, {'entity_group': 'LABEL_1', 'score': 0.57012266, 'word': ' sistema', 'start': 124, 'end': 130}]
# Resultado para História de Usuário 33: [{'entity_group': 'LABEL_0', 'score': 0.54417497, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_1', 'score': 0.59270054, 'word': ' de', 'start': 10, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5290741, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.59842086, 'word': ' 33 :', 'start': 21, 'end': 23}, {'entity_group': 'LABEL_0', 'score': 0.5479235, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.5975771, 'word': 'tador preciso suporte execucao testis compatibilidade diferentes', 'start': 27, 'end': 91}, {'entity_group': 'LABEL_0', 'score': 0.54209125, 'word': ' navegadores', 'start': 93, 'end': 103}, {'entity_group': 'LABEL_1', 'score': 0.603481, 'word': ' dispositivos garantir experiencia consistente todos', 'start': 105, 'end': 155}, {'entity_group': 'LABEL_0', 'score': 0.5454829, 'word': ' usuarios', 'start': 157, 'end': 164}]
# Resultado para História de Usuário 34: [{'entity_group': 'LABEL_1', 'score': 0.59511304, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.51956105, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.615903, 'word': ' 34 : testador quero geracao automatica', 'start': 21, 'end': 57}, {'entity_group': 'LABEL_0', 'score': 0.5122476, 'word': ' relatorios', 'start': 59, 'end': 68}, {'entity_group': 'LABEL_1', 'score': 0.59240997, 'word': ' teste personalizados comunicar eficazmente resultados testis', 'start': 70, 'end': 129}]
# Resultado para História de Usuário 35: [{'entity_group': 'LABEL_1', 'score': 0.5847911, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5298559, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.5859218, 'word': ' 35 : testador desejo', 'start': 21, 'end': 39}, {'entity_group': 'LABEL_0', 'score': 0.5232369, 'word': ' rastreamento', 'start': 41, 'end': 52}, {'entity_group': 'LABEL_1', 'score': 0.5520129, 'word': ' automatico', 'start': 54, 'end': 63}, {'entity_group': 'LABEL_0', 'score': 0.5360093, 'word': ' resultados teste', 'start': 65, 'end': 80}, {'entity_group': 'LABEL_1', 'score': 0.5655481, 'word': ' longo', 'start': 82, 'end': 86}, {'entity_group': 'LABEL_0', 'score': 0.5109904, 'word': ' tempo identificar', 'start': 88, 'end': 104}, {'entity_group': 'LABEL_1', 'score': 0.5925306, 'word': ' tendencias', 'start': 106, 'end': 115}, {'entity_group': 'LABEL_0', 'score': 0.6643598, 'word': ' padroes qualidade', 'start': 117, 'end': 133}]
# Resultado para História de Usuário 36: [{'entity_group': 'LABEL_0', 'score': 0.5285351, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_1', 'score': 0.5919339, 'word': ' de', 'start': 10, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5204831, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.6139613, 'word': ' 36 :', 'start': 21, 'end': 23}, {'entity_group': 'LABEL_0', 'score': 0.5185636, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.6039945, 'word': 'tador preciso suporte execucao testis regressao progressiva garantir nova alteracoes quebrem funcionalidades existentes', 'start': 27, 'end': 146}]
# Resultado para História de Usuário 37: [{'entity_group': 'LABEL_0', 'score': 0.5030434, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_1', 'score': 0.6117418, 'word': ' de', 'start': 10, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5313457, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.6006477, 'word': ' 37 : testador quero sugestoes automaticas', 'start': 21, 'end': 60}, {'entity_group': 'LABEL_0', 'score': 0.5266059, 'word': ' apri', 'start': 62, 'end': 65}, {'entity_group': 'LABEL_1', 'score': 0.5894197, 'word': 'morar casos teste existentes aumentar eficiencia eficacia testis', 'start': 65, 'end': 129}]
# Resultado para História de Usuário 38: [{'entity_group': 'LABEL_1', 'score': 0.56783426, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.52851784, 'word': ' usuario 38', 'start': 13, 'end': 22}, {'entity_group': 'LABEL_1', 'score': 0.63356817, 'word': ' :', 'start': 23, 'end': 23}, {'entity_group': 'LABEL_0', 'score': 0.54047704, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.53646046, 'word': 'tador desejo ferramenta', 'start': 27, 'end': 50}, {'entity_group': 'LABEL_0', 'score': 0.5622076, 'word': ' apre', 'start': 52, 'end': 55}, {'entity_group': 'LABEL_1', 'score': 0.5556735, 'word': 'nda', 'start': 55, 'end': 58}, {'entity_group': 'LABEL_0', 'score': 0.55819535, 'word': ' resultados', 'start': 60, 'end': 69}, {'entity_group': 'LABEL_1', 'score': 0.51272196, 'word': ' tes', 'start': 71, 'end': 73}, {'entity_group': 'LABEL_0', 'score': 0.5140857, 'word': 'tis', 'start': 73, 'end': 76}, {'entity_group': 'LABEL_1', 'score': 0.5571627, 'word': ' melhore', 'start': 78, 'end': 84}, {'entity_group': 'LABEL_0', 'score': 0.5292143, 'word': ' sugestoes', 'start': 86, 'end': 94}, {'entity_group': 'LABEL_1', 'score': 0.5983736, 'word': ' futuras otimizacao continua processo teste', 'start': 96, 'end': 137}]
# Resultado para História de Usuário 39: [{'entity_group': 'LABEL_1', 'score': 0.5685314, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5587896, 'word': ' usuario 39', 'start': 13, 'end': 22}, {'entity_group': 'LABEL_1', 'score': 0.60929024, 'word': ' :', 'start': 23, 'end': 23}, {'entity_group': 'LABEL_0', 'score': 0.53681064, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.57890755, 'word': 'tador preciso suporte execucao testis', 'start': 27, 'end': 64}, {'entity_group': 'LABEL_0', 'score': 0.58473223, 'word': ' seguranca automatizados identificar vulnerabilidades aplica', 'start': 66, 'end': 124}, {'entity_group': 'LABEL_1', 'score': 0.5163073, 'word': 'tivo', 'start': 124, 'end': 128}]
# Resultado para História de Usuário 40: [{'entity_group': 'LABEL_1', 'score': 0.6107279, 'word': ' historia de usuario 40 : testador quero', 'start': 0, 'end': 38}, {'entity_group': 'LABEL_0', 'score': 0.52810645, 'word': ' integracao', 'start': 40, 'end': 49}, {'entity_group': 'LABEL_1', 'score': 0.6145088, 'word': ' ferramentas analise codigo estatico identificar areas risco avaliacao abrangente', 'start': 51, 'end': 130}, {'entity_group': 'LABEL_0', 'score': 0.5498076, 'word': ' qualidade', 'start': 132, 'end': 140}]
# Resultado para História de Usuário 41: [{'entity_group': 'LABEL_1', 'score': 0.53844595, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.57873356, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.5903119, 'word': ' 41 :', 'start': 21, 'end': 23}, {'entity_group': 'LABEL_0', 'score': 0.5545279, 'word': ' testador desejo suporte execucao', 'start': 25, 'end': 56}, {'entity_group': 'LABEL_1', 'score': 0.5544194, 'word': ' tes', 'start': 58, 'end': 60}, {'entity_group': 'LABEL_0', 'score': 0.60684806, 'word': 'tis integracao sistema teste aceitacao usuario validar', 'start': 60, 'end': 114}, {'entity_group': 'LABEL_1', 'score': 0.54719603, 'word': ' diferentes partes', 'start': 116, 'end': 132}, {'entity_group': 'LABEL_0', 'score': 0.5781245, 'word': ' conformidade', 'start': 134, 'end': 145}, {'entity_group': 'LABEL_1', 'score': 0.5660752, 'word': ' requisitos', 'start': 147, 'end': 156}]
# Resultado para História de Usuário 42: [{'entity_group': 'LABEL_1', 'score': 0.5915224, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.58463955, 'word': ' usuario 42', 'start': 13, 'end': 22}, {'entity_group': 'LABEL_1', 'score': 0.64867723, 'word': ' :', 'start': 23, 'end': 23}, {'entity_group': 'LABEL_0', 'score': 0.54076606, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.62638086, 'word': 'tador preciso suporte execucao testis', 'start': 27, 'end': 64}, {'entity_group': 'LABEL_0', 'score': 0.5168559, 'word': ' confi', 'start': 66, 'end': 70}, {'entity_group': 'LABEL_1', 'score': 0.5771177, 'word': 'abilidade disponibilidade garantir', 'start': 70, 'end': 104}, {'entity_group': 'LABEL_0', 'score': 0.501495, 'word': ' aplica', 'start': 106, 'end': 111}, {'entity_group': 'LABEL_1', 'score': 0.64388144, 'word': 'tivo sempre disponivel funcione corretamente', 'start': 111, 'end': 155}]
# Resultado para História de Usuário 43: [{'entity_group': 'LABEL_0', 'score': 0.5012627, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_1', 'score': 0.6154778, 'word': ' de', 'start': 10, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5402477, 'word': ' usuario 43', 'start': 13, 'end': 22}, {'entity_group': 'LABEL_1', 'score': 0.6463678, 'word': ' :', 'start': 23, 'end': 23}, {'entity_group': 'LABEL_0', 'score': 0.5226206, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.6472495, 'word': 'tador quero ferramenta sugira', 'start': 27, 'end': 56}, {'entity_group': 'LABEL_0', 'score': 0.51513994, 'word': ' casos', 'start': 58, 'end': 62}, {'entity_group': 'LABEL_1', 'score': 0.54913974, 'word': ' teste base modelos', 'start': 64, 'end': 81}, {'entity_group': 'LABEL_0', 'score': 0.6075719, 'word': ' qualidade', 'start': 83, 'end': 91}, {'entity_group': 'LABEL_1', 'score': 0.6173824, 'word': ' software reconhecidos garantir abordagem abrangente', 'start': 93, 'end': 143}, {'entity_group': 'LABEL_0', 'score': 0.5270277, 'word': ' padro', 'start': 145, 'end': 149}, {'entity_group': 'LABEL_1', 'score': 0.5842871, 'word': 'nizada testis', 'start': 149, 'end': 162}]
# Resultado para História de Usuário 44: [{'entity_group': 'LABEL_0', 'score': 0.5136092, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_1', 'score': 0.5346256, 'word': ' de', 'start': 10, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.58012235, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.5808089, 'word': ' 44 :', 'start': 21, 'end': 23}, {'entity_group': 'LABEL_0', 'score': 0.5157597, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.5286657, 'word': 'tador', 'start': 27, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.5696727, 'word': ' desejo integracao ferramentas automacao', 'start': 34, 'end': 72}, {'entity_group': 'LABEL_1', 'score': 0.50494146, 'word': ' teste interface', 'start': 74, 'end': 88}, {'entity_group': 'LABEL_0', 'score': 0.5774205, 'word': ' usuario', 'start': 90, 'end': 96}, {'entity_group': 'LABEL_1', 'score': 0.5462972, 'word': ' automatizar testis interacao', 'start': 98, 'end': 125}]
# Resultado para História de Usuário 45: [{'entity_group': 'LABEL_1', 'score': 0.57171166, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.54700434, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.6893201, 'word': ' 45 :', 'start': 21, 'end': 23}, {'entity_group': 'LABEL_0', 'score': 0.56163204, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.6152837, 'word': 'tador preciso suporte execucao testis estresse robustez avaliar estabilidade', 'start': 27, 'end': 103}, {'entity_group': 'LABEL_0', 'score': 0.5699954, 'word': ' confi', 'start': 105, 'end': 109}, {'entity_group': 'LABEL_1', 'score': 0.54051745, 'word': 'abilidade', 'start': 109, 'end': 118}, {'entity_group': 'LABEL_0', 'score': 0.55541617, 'word': ' aplica', 'start': 120, 'end': 125}, {'entity_group': 'LABEL_1', 'score': 0.54968596, 'word': 'tivo sob condicoes', 'start': 125, 'end': 143}, {'entity_group': 'LABEL_0', 'score': 0.52452445, 'word': ' adversas', 'start': 145, 'end': 152}]
# Resultado para História de Usuário 46: [{'entity_group': 'LABEL_1', 'score': 0.63115263, 'word': ' historia de usuario 46 : testador quero ferramenta sugira casos teste areas alto', 'start': 0, 'end': 79}, {'entity_group': 'LABEL_0', 'score': 0.51356727, 'word': ' risco', 'start': 81, 'end': 85}, {'entity_group': 'LABEL_1', 'score': 0.60122514, 'word': ' complexidade priorizar esforcos', 'start': 87, 'end': 117}]
# Resultado para História de Usuário 47: [{'entity_group': 'LABEL_1', 'score': 0.59315276, 'word': ' historia de usuario 47 : testador desejo', 'start': 0, 'end': 39}, {'entity_group': 'LABEL_0', 'score': 0.54866093, 'word': ' integracao', 'start': 41, 'end': 50}, {'entity_group': 'LABEL_1', 'score': 0.5656419, 'word': ' ferramentas gerenciamento defeitos rastreamento correcoes gestao eficaz problemas encontrados durante testis', 'start': 52, 'end': 159}]
# Resultado para História de Usuário 48: [{'entity_group': 'LABEL_0', 'score': 0.56694037, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_1', 'score': 0.5349223, 'word': ' de', 'start': 10, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.5740702, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.6217452, 'word': ' 48 :', 'start': 21, 'end': 23}, {'entity_group': 'LABEL_0', 'score': 0.59260964, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.56057495, 'word': 'tador preciso suporte execucao testis', 'start': 27, 'end': 64}, {'entity_group': 'LABEL_0', 'score': 0.5365946, 'word': ' usabilidade', 'start': 66, 'end': 76}, {'entity_group': 'LABEL_1', 'score': 0.55141085, 'word': ' remota', 'start': 78, 'end': 83}, {'entity_group': 'LABEL_0', 'score': 0.50966656, 'word': ' teste', 'start': 85, 'end': 89}, {'entity_group': 'LABEL_1', 'score': 0.5013908, 'word': ' usuario', 'start': 91, 'end': 97}, {'entity_group': 'LABEL_0', 'score': 0.6052984, 'word': ' beta cole', 'start': 99, 'end': 107}, {'entity_group': 'LABEL_1', 'score': 0.6363587, 'word': 'tar feedback', 'start': 107, 'end': 119}, {'entity_group': 'LABEL_0', 'score': 0.52854455, 'word': ' usuarios reais', 'start': 121, 'end': 134}]
# Resultado para História de Usuário 49: [{'entity_group': 'LABEL_1', 'score': 0.6525344, 'word': ' historia de usuario 49 : testador quero ferramenta forneca feedback tempo real durante execucao testis facilitar identificacao imediata problemas', 'start': 0, 'end': 144}]
# Resultado para História de Usuário 50: [{'entity_group': 'LABEL_0', 'score': 0.51164716, 'word': ' historia', 'start': 0, 'end': 8}, {'entity_group': 'LABEL_1', 'score': 0.5559032, 'word': ' de', 'start': 10, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.56215554, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.60232735, 'word': ' 50 :', 'start': 21, 'end': 23}, {'entity_group': 'LABEL_0', 'score': 0.5384483, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.52942526, 'word': 'tador', 'start': 27, 'end': 32}, {'entity_group': 'LABEL_0', 'score': 0.5411694, 'word': ' desejo integracao ferramentas automacao infraestrutura', 'start': 34, 'end': 87}, {'entity_group': 'LABEL_1', 'score': 0.5587121, 'word': ' provisionamento', 'start': 89, 'end': 103}, {'entity_group': 'LABEL_0', 'score': 0.5251359, 'word': ' configuracao automatizados', 'start': 105, 'end': 130}, {'entity_group': 'LABEL_1', 'score': 0.53557503, 'word': ' facilitar', 'start': 132, 'end': 140}, {'entity_group': 'LABEL_0', 'score': 0.57749194, 'word': ' preparacao ambiente teste', 'start': 142, 'end': 166}]
# Resultado para História de Usuário 51: [{'entity_group': 'LABEL_1', 'score': 0.5442184, 'word': ' historia de', 'start': 0, 'end': 11}, {'entity_group': 'LABEL_0', 'score': 0.52045786, 'word': ' usuario', 'start': 13, 'end': 19}, {'entity_group': 'LABEL_1', 'score': 0.6882019, 'word': ' 51 :', 'start': 21, 'end': 23}, {'entity_group': 'LABEL_0', 'score': 0.52437514, 'word': ' tes', 'start': 25, 'end': 27}, {'entity_group': 'LABEL_1', 'score': 0.59469134, 'word': 'tador preciso suporte execucao testis', 'start': 27, 'end': 64}, {'entity_group': 'LABEL_0', 'score': 0.5172779, 'word': ' comparacao', 'start': 66, 'end': 75}, {'entity_group': 'LABEL_1', 'score': 0.5758133, 'word': ' desempenho versoes anteriores atuais', 'start': 77, 'end': 112}, {'entity_group': 'LABEL_0', 'score': 0.5203, 'word': ' aplica', 'start': 114, 'end': 119}, {'entity_group': 'LABEL_1', 'score': 0.5705661, 'word': 'tivo avaliar impacto mudancas', 'start': 119, 'end': 148}]

# %%
def extracao(freq_dist):
    frequencia = " ".join(freq_dist.keys()).lower()

    autor = None
    if "testador" in frequencia:
        autor = "Testador"

    finalidade = None
    for word in ["quero", "preciso", "desejo"]:
        if word in frequencia:
            pos_inicial = frequencia.find(word) + len(word)
            finalidade = frequencia[pos_inicial:].strip().split(",")[0]
            break
    if "para" in frequencia:
        pos_inicial_para = frequencia.find("para") + len("para")
        finalidade = "para " + frequencia[pos_inicial_para:].strip().split(",")[0]


    return autor, finalidade


for i, freq_dist in enumerate(freq_dists):
    autor, finalidade = extracao(freq_dist)
    print("História do Usuário:", historias_usuario[i])
    print("Autor:", autor)
    print("Finalidade:", finalidade)
    print()
# Out:
# História do Usuário: Como Testador eu quero um jeito mais fácil de incluir os requisitos do aplicativo na ferramenta DRL-Mobtest para criar casos de teste que cubram tudo que o aplicativo precisa fazer, sem ter que gastar muito tempo escrevendo manualmente.
# Autor: Testador
# Finalidade: jeito fácil incluir requisitos aplicativo ferramenta drl-mobtest criar casos teste cubram tudo precisa fazer ter gastar tempo escrevendo manualmente
#
# História do Usuário: Como Testador eu quero uma maneira de ensinar a ferramenta DRL-Mobtest a entender os requisitos do aplicativo usando NLP para fazer com que a ferramenta gere testes automaticamente.
# Autor: Testador
# Finalidade: maneira ensinar ferramenta drl-mobtest entender requisitos aplicativo usando nlp fazer gere testis automaticamente
#
# História do Usuário: Como Testador eu quero que a ferramenta gere casos de teste abrangentes que cubram integralmente todos os requisitos do aplicativo, assegurando que o software seja completo e funcional, sem depender exclusivamente da criação manual de casos de teste.
# Autor: Testador
# Finalidade: ferramenta gere casos teste abrangentes cubram integralmente todos requisitos aplicativo assegurando software completo funcional depender exclusivamente criação manual
#
# História do Usuário: Como Testador eu quero que a ferramenta seja integrada com outras ferramentas de gerenciamento, permitindo sincronização automática dos requisitos e facilitando o processo de criação de casos de testes.
# Autor: Testador
# Finalidade: ferramenta integrada outras ferramentas gerenciamento permitindo sincronização automática requisitos facilitando processo criação casos testis
#
# História do Usuário: Como testador, eu quero que a ferramenta gere casos de teste completos e funcionais que cubram todos os requisitos do aplicativo, para garantir uma cobertura abrangente durante os testes.
# Autor: Testador
# Finalidade: ferramenta gere casos teste completos funcionais cubram todos requisitos aplicativo garantir cobertura abrangente durante testis
#
# História do Usuário: Como testador, eu quero integração com outras ferramentas de gerenciamento para sincronizar automaticamente requisitos e facilitar a criação de casos de teste, visando melhorar a eficiência e precisão do processo de teste.
# Autor: Testador
# Finalidade: integração outras ferramentas gerenciamento sincronizar automaticamente requisitos facilitar criação casos teste visando melhorar eficiência precisão processo
#
# História do Usuário: Como testador, eu quero relatórios detalhados sobre a cobertura dos testes para análise precisa durante a execução, a fim de avaliar a qualidade e a extensão dos testes realizados.
# Autor: Testador
# Finalidade: relatórios detalhados sobre cobertura testis análise precisa durante execução fim avaliar qualidade extensão realizados
#
# História do Usuário: Como testador, eu desejo que a ferramenta identifique automaticamente os casos de teste mais críticos para priorizar a análise, visando direcionar os esforços de teste para áreas de maior risco.
# Autor: Testador
# Finalidade: ferramenta identifique automaticamente casos teste críticos priorizar análise visando direcionar esforços áreas maior risco
#
# História do Usuário: Como testador, eu preciso que a ferramenta sugira casos de teste com base em padrões de uso real do aplicativo, para garantir que os testes reflitam cenários típicos de uso.
# Autor: Testador
# Finalidade: ferramenta sugira casos teste base padrões uso real aplicativo garantir testis reflitam cenários típicos
#
# História do Usuário: Como testador, eu quero sugestões com base em padrões de falha históricos para evitar problemas recorrentes no software, visando melhorar a qualidade e a robustez do produto.
# Autor: Testador
# Finalidade: sugestões base padrões falha históricos evitar problemas recorrentes software visando melhorar qualidade robustez produto
#
# História do Usuário: Como testador, eu desejo suporte à execução de testes automatizados em diferentes dispositivos e ambientes, para garantir a consistência e a confiabilidade dos testes em diferentes cenários.
# Autor: Testador
# Finalidade: suporte execução testis automatizados diferentes dispositivos ambientes garantir consistência confiabilidade cenários
#
# História do Usuário: Como testador, eu preciso que a ferramenta detecte automaticamente mudanças nos requisitos e ajuste os casos de teste correspondentes, para manter os testes alinhados com a evolução do aplicativo.
# Autor: Testador
# Finalidade: ferramenta detecte automaticamente mudanças requisitos ajuste casos teste correspondentes manter testis alinhados evolução aplicativo
#
# História do Usuário: Como testador, eu quero integração com sistemas de controle de versão para rastrear mudanças nos requisitos e no código-fonte, visando uma gestão eficaz de mudanças durante o ciclo de desenvolvimento.
# Autor: Testador
# Finalidade: integração sistemas controle versão rastrear mudanças requisitos código-fonte visando gestão eficaz durante ciclo desenvolvimento
#
# História do Usuário: Como testador, eu desejo métricas detalhadas sobre a eficácia dos testes, incluindo taxa de cobertura e taxa de falha, para avaliar a qualidade do processo de teste.
# Autor: Testador
# Finalidade: métricas detalhadas sobre eficácia testis incluindo taxon cobertura falha avaliar qualidade processo teste
#
# História do Usuário: Como testador, eu preciso de suporte à execução de testes de desempenho e escalabilidade, para garantir que o aplicativo atenda aos requisitos de desempenho sob carga.
# Autor: Testador
# Finalidade: suporte execução testis desempenho escalabilidade garantir aplicativo atenda requisitos sob carga
#
# História do Usuário: Como testador, eu quero análise automática dos resultados dos testes para relatórios detalhados sobre problemas encontrados, a fim de facilitar a identificação e correção de defeitos.
# Autor: Testador
# Finalidade: análise automática resultados testis relatórios detalhados sobre problemas encontrados fim facilitar identificação correção defeitos
#
# História do Usuário: Como testador, eu desejo simular cenários de teste complexos e realistas para garantir testes próximos à realidade, visando uma validação mais precisa do software.
# Autor: Testador
# Finalidade: simular cenários teste complexos realistas garantir testis próximos realidade visando validação precisa software
#
# História do Usuário: Como testador, eu preciso de suporte à execução de testes de regressão automatizados, para garantir que as alterações no código não introduzam regressões.
# Autor: Testador
# Finalidade: suporte execução testis regressão automatizados garantir alterações código introduzam regressões
#
# História do Usuário: Como testador, eu quero identificação automática de casos de teste redundantes ou desnecessários, para otimizar os esforços de teste.
# Autor: Testador
# Finalidade: identificação automática casos teste redundantes desnecessários otimizar esforços
#
# História do Usuário: Como testador, eu desejo integração fácil com ferramentas de gerenciamento de projetos, para uma colaboração eficiente com outros membros da equipe de desenvolvimento.
# Autor: Testador
# Finalidade: integração fácil ferramentas gerenciamento projetos colaboração eficiente outros membros equipe desenvolvimento
#
# História do Usuário: Como testador, eu preciso de suporte à execução de testes de usabilidade, para garantir que o aplicativo seja fácil e intuitivo de usar.
# Autor: Testador
# Finalidade: suporte execução testis usabilidade garantir aplicativo fácil intuitivo usar
#
# História do Usuário: Como testador, eu quero que a ferramenta crie automaticamente conjuntos de dados de teste realistas, para simular condições reais de uso.
# Autor: Testador
# Finalidade: ferramenta crie automaticamente conjuntos dado teste realistas simular condições reais uso
#
# História do Usuário: Como testador, eu desejo integração com ferramentas de monitoramento de desempenho em tempo real, para avaliar o desempenho do aplicativo durante os testes.
# Autor: Testador
# Finalidade: integração ferramentas monitoramento desempenho tempo real avaliar aplicativo durante testis
#
# História do Usuário: Como testador, eu preciso de suporte à execução de testes de localização e internacionalização, para garantir que o aplicativo seja compatível com diferentes idiomas e regiões.
# Autor: Testador
# Finalidade: suporte execução testis localização internacionalização garantir aplicativo compatível diferentes idiomas regiões
#
# História do Usuário: Como testador, eu quero geração automática de dados de teste sintéticos, para complementar os casos de teste manuais.
# Autor: Testador
# Finalidade: geração automática dado teste sintéticos complementar casos manuais
#
# História do Usuário: Como testador, eu desejo suporte à execução de testes de acessibilidade, para garantir que o aplicativo seja acessível a todos os usuários.
# Autor: Testador
# Finalidade: suporte execução testis acessibilidade garantir aplicativo acessível todos usuários
#
# História do Usuário: Como testador, eu preciso de suporte à execução de testes de integração contínua, para garantir que as alterações no código não quebrem a integração com outras partes do sistema.
# Autor: Testador
# Finalidade: suporte execução testis integração contínua garantir alterações código quebrem outras partes sistema
#
# História do Usuário: Como testador, eu quero identificação automática de casos de teste incompletos ou mal definidos, para garantir a qualidade dos testes.
# Autor: Testador
# Finalidade: identificação automática casos teste incompletos mal definidos garantir qualidade testis
#
# História do Usuário: Como testador, eu desejo identificação automática de dependências entre casos de teste, para garantir uma sequência lógica na execução dos testes.
# Autor: Testador
# Finalidade: identificação automática dependências casos teste garantir sequência lógica execução testis
#
# História do Usuário: Como testador, eu preciso de suporte à execução de testes de recuperação de desastres, para avaliar a capacidade do sistema de se recuperar de falhas.
# Autor: Testador
# Finalidade: suporte execução testis recuperação desastres avaliar capacidade sistema recuperar falhas
#
# História do Usuário: Como testador, eu quero que a ferramenta identifique automaticamente casos de teste paralelizáveis, para otimizar a execução dos testes.
# Autor: Testador
# Finalidade: para lelizáveis otimizar execução testis
#
# História do Usuário: Como testador, eu desejo simulação de cenários de teste de carga extremamente alta, para avaliar a capacidade de escalabilidade do sistema.
# Autor: Testador
# Finalidade: simulação cenários teste carga extremamente alta avaliar capacidade escalabilidade sistema
#
# História do Usuário: Como testador, eu preciso de suporte à execução de testes de compatibilidade com diferentes navegadores e dispositivos, para garantir uma experiência consistente para todos os usuários.
# Autor: Testador
# Finalidade: suporte execução testis compatibilidade diferentes navegadores dispositivos garantir experiência consistente todos usuários
#
# História do Usuário: Como testador, eu quero geração automática de relatórios de teste personalizados, para comunicar eficazmente os resultados dos testes.
# Autor: Testador
# Finalidade: geração automática relatórios teste personalizados comunicar eficazmente resultados testis
#
# História do Usuário: Como testador, eu desejo rastreamento automático de resultados de teste ao longo do tempo, para identificar tendências e padrões de qualidade.
# Autor: Testador
# Finalidade: rastreamento automático resultados teste longo tempo identificar tendências padrões qualidade
#
# História do Usuário: Como testador, eu preciso de suporte à execução de testes de regressão progressiva, para garantir que as novas alterações não quebrem funcionalidades existentes.
# Autor: Testador
# Finalidade: suporte execução testis regressão progressiva garantir nova alterações quebrem funcionalidades existentes
#
# História do Usuário: Como testador, eu quero sugestões automáticas para aprimorar os casos de teste existentes, para aumentar a eficiência e a eficácia dos testes.
# Autor: Testador
# Finalidade: sugestões automáticas aprimorar casos teste existentes aumentar eficiência eficácia testis
#
# História do Usuário: Como testador, eu desejo que a ferramenta aprenda com os resultados dos testes e melhore suas sugestões futuras, para uma otimização contínua do processo de teste.
# Autor: Testador
# Finalidade: ferramenta aprenda resultados testis melhore sugestões futuras otimização contínua processo teste
#
# História do Usuário: Como testador, eu preciso de suporte à execução de testes de segurança automatizados, para identificar vulnerabilidades no aplicativo.
# Autor: Testador
# Finalidade: suporte execução testis segurança automatizados identificar vulnerabilidades aplicativo
#
# História do Usuário: Como testador, eu quero integração com ferramentas de análise de código estático para identificar áreas de risco, para uma avaliação abrangente da qualidade do código.
# Autor: Testador
# Finalidade: integração ferramentas análise código estático identificar áreas risco avaliação abrangente qualidade
#
# História do Usuário: Como testador, eu desejo suporte à execução de testes de integração de sistema e teste de aceitação do usuário, para validar a integração entre diferentes partes do sistema e a conformidade com os requisitos do usuário.
# Autor: Testador
# Finalidade: suporte execução testis integração sistema teste aceitação usuário validar diferentes partes conformidade requisitos
#
# História do Usuário: Como testador, eu preciso de suporte à execução de testes de confiabilidade e disponibilidade, para garantir que o aplicativo esteja sempre disponível e funcione corretamente.
# Autor: Testador
# Finalidade: suporte execução testis confiabilidade disponibilidade garantir aplicativo sempre disponível funcione corretamente
#
# História do Usuário: Como testador, eu quero que a ferramenta sugira casos de teste com base em modelos de qualidade de software reconhecidos, para garantir uma abordagem abrangente e padronizada para os testes.
# Autor: Testador
# Finalidade: ferramenta sugira casos teste base modelos qualidade software reconhecidos garantir abordagem abrangente padronizada testis
#
# História do Usuário: Como testador, eu desejo integração com ferramentas de automação de teste de interface do usuário, para automatizar testes de interação com o usuário.
# Autor: Testador
# Finalidade: integração ferramentas automação teste interface usuário automatizar testis interação
#
# História do Usuário: Como testador, eu preciso de suporte à execução de testes de estresse e robustez, para avaliar a estabilidade e a confiabilidade do aplicativo sob condições adversas.
# Autor: Testador
# Finalidade: suporte execução testis estresse robustez avaliar estabilidade confiabilidade aplicativo sob condições adversas
#
# História do Usuário: Como testador, eu quero que a ferramenta sugira casos de teste para áreas de alto risco e complexidade, para priorizar os esforços de teste.
# Autor: Testador
# Finalidade: ferramenta sugira casos teste áreas alto risco complexidade priorizar esforços
#
# História do Usuário: Como testador, eu desejo integração com ferramentas de gerenciamento de defeitos para rastreamento de correções, para uma gestão eficaz de problemas encontrados durante os testes.
# Autor: Testador
# Finalidade: integração ferramentas gerenciamento defeitos rastreamento correções gestão eficaz problemas encontrados durante testis
#
# História do Usuário: Como testador, eu preciso de suporte à execução de testes de usabilidade remota e teste de usuário beta, para coletar feedback de usuários reais.
# Autor: Testador
# Finalidade: suporte execução testis usabilidade remota teste usuário beta coletar feedback usuários reais
#
# História do Usuário: Como testador, eu quero que a ferramenta forneça feedback em tempo real durante a execução dos testes, para facilitar a identificação imediata de problemas.
# Autor: Testador
# Finalidade: ferramenta forneça feedback tempo real durante execução testis facilitar identificação imediata problemas
#
# História do Usuário: Como testador, eu desejo integração com ferramentas de automação de infraestrutura para provisionamento e configuração automatizados, para facilitar a preparação do ambiente de teste.
# Autor: Testador
# Finalidade: para ção ambiente teste
#
# História do Usuário: Como testador, eu preciso de suporte à execução de testes de comparação de desempenho para versões anteriores e atuais do aplicativo, para avaliar o impacto de mudanças no desempenho.
# Autor: Testador
# Finalidade: para ção desempenho versões anteriores atuais aplicativo avaliar impacto mudanças

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import recall_score, f1_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
# !pip install scikit-learn
from random import choice
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.25.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.4.0)

# %%
X = freq_dists
rotulos_possiveis = ["testador", "aplicativo", "desempenho", "teste"]
y = [choice(rotulos_possiveis) for _ in range(len(freq_dists))]
vetorizacao = TfidfVectorizer()
X = vetorizacao.fit_transform([" ".join(freq_dist.keys()) for freq_dist in X])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.4, random_state=42,stratify=y)

# %%
from sklearn.linear_model import LogisticRegression
modelo_regressao = LogisticRegression()
modelo_regressao.fit(X_train, y_train)
y_predicted = modelo_regressao.predict(X_test)
acuracia = accuracy_score(y_test, y_predicted)
print("Acurácia:", acuracia)
# Out:
# Acurácia: 0.3333333333333333

# %%
clf_tf = DecisionTreeClassifier(criterion='gini',max_depth=15)
clf_tf.fit(X_train, y_train)
pred_arvore_entropy_tf = clf_tf.predict(X_test)
accuracy_decision = accuracy_score(y_test,pred_arvore_entropy_tf)
recall = recall_score(y_test, pred_arvore_entropy_tf, average='weighted')
f1 = f1_score(y_test, pred_arvore_entropy_tf, average='weighted')
print(f"Resultado: ",accuracy_decision)
print(f"Resultado: ",recall)
print(f"Resultado: ",f1)
# Out:
# Resultado:  0.23809523809523808
# Resultado:  0.23809523809523808
# Resultado:  0.21920873612602937

# %%
clf = DecisionTreeClassifier(criterion='entropy',max_depth=7)
clf.fit(X_train, y_train)
pred_arvore_entropy = clf.predict(X_test)
accuracy_decision = accuracy_score(y_test,pred_arvore_entropy)
recall_entropy = recall_score(y_test, pred_arvore_entropy, average='weighted')
f1_entropy = f1_score(y_test, pred_arvore_entropy, average='weighted')
print(f"Resultado: ",accuracy_decision)
print(f"Resultado: ",recall_entropy)
print(f"Resultado: ",f1_entropy)
# Out:
# Resultado:  0.23809523809523808
# Resultado:  0.23809523809523808
# Resultado:  0.183969239869861

# %%
clf_tf3 = KNeighborsClassifier(metric='manhattan',n_neighbors=3)
clf_tf3.fit(X_train, y_train)
pred_knn_tf = clf_tf3.predict(X_test)
acuracy_KNN = accuracy_score(y_test,pred_knn_tf)
recall_knn = recall_score(y_test, pred_knn_tf, average='weighted')
f1_knn = f1_score(y_test, pred_knn_tf, average='weighted')
print(f"Resultado: ",acuracy_KNN)
print(f"Resultado: ",recall_knn)
print(f"Resultado: ",f1_knn)
# Out:
# Resultado:  0.3333333333333333
# Resultado:  0.3333333333333333
# Resultado:  0.22682309638831377

# %%
clf_tf4 = KNeighborsClassifier(n_neighbors=5,weights='distance', algorithm='brute')
clf_tf4.fit(X_train, y_train)
pred_knn_tf2 = clf_tf4.predict(X_test)
acuracy_KNN2 = accuracy_score(y_test,pred_knn_tf2)
recall_knn2 = recall_score(y_test, pred_knn_tf2, average='weighted')
f1_knn2 = f1_score(y_test, pred_knn_tf2, average='weighted')
print(f"Resultado: ",acuracy_KNN)
print(f"Resultado: ",recall_knn2)
print(f"Resultado: ",f1_knn2)
# Out:
# Resultado:  0.3333333333333333
# Resultado:  0.14285714285714285
# Resultado:  0.13445378151260506

# %%
svc = SVC(kernel='linear', C=0.05)
svc.fit(X_train, y_train)
pred_svc = svc.predict(X_test)
accuracy_svc = accuracy_score(y_test, pred_svc)
recall_svc = recall_score(y_test, pred_svc, average='weighted')
f1_svc = f1_score(y_test, pred_svc, average='weighted')
print(f"Resultado: ",accuracy_svc)
print(f"Resultado: ",recall_svc)
print(f"Resultado: ",f1_svc)
# Out:
# Resultado:  0.3333333333333333
# Resultado:  0.3333333333333333
# Resultado:  0.16666666666666666

# %%
from tensorflow.keras import layers
import tensorflow_datasets as tfds
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt
from tensorflow import keras
import tensorflow_hub as hub
import tensorflow as tf

# %%
le_rn = LabelEncoder()
ytrain = le_rn.fit_transform(y_train)
ytest = le_rn.transform(y_test)

# %%
Xtrain = np.expand_dims(X_train.toarray(), axis=1)
Xtest = np.expand_dims(X_test.toarray(), axis=1)

# %%
num_classes = 4
model = tf.keras.Sequential([
    layers.LSTM(128, input_shape=(Xtrain.shape[1], Xtrain.shape[2])),
    layers.Dense(64, activation='relu'),
    layers.Dense(num_classes, activation='softmax')
])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
EPOCHS = 20
history = model.fit(Xtrain, ytrain, epochs=EPOCHS, batch_size=32, validation_data=(Xtest, ytest))
# Out:
# Epoch 1/20
# 1/1 [==============================] - 2s 2s/step - loss: 1.3873 - accuracy: 0.2000 - val_loss: 1.3805 - val_accuracy: 0.3810
# Epoch 2/20
# 1/1 [==============================] - 0s 59ms/step - loss: 1.3796 - accuracy: 0.6000 - val_loss: 1.3800 - val_accuracy: 0.4286
# Epoch 3/20
# 1/1 [==============================] - 0s 59ms/step - loss: 1.3728 - accuracy: 0.7000 - val_loss: 1.3795 - val_accuracy: 0.3810
# Epoch 4/20
# 1/1 [==============================] - 0s 47ms/step - loss: 1.3664 - accuracy: 0.8333 - val_loss: 1.3790 - val_accuracy: 0.2857
# Epoch 5/20
# 1/1 [==============================] - 0s 47ms/step - loss: 1.3601 - accuracy: 0.8667 - val_loss: 1.3785 - val_accuracy: 0.2857
# Epoch 6/20
# 1/1 [==============================] - 0s 60ms/step - loss: 1.3537 - accuracy: 0.8333 - val_loss: 1.3780 - val_accuracy: 0.2857
# Epoch 7/20
# 1/1 [==============================] - 0s 62ms/step - loss: 1.3472 - accuracy: 0.8667 - val_loss: 1.3774 - val_accuracy: 0.3333
# Epoch 8/20
# 1/1 [==============================] - 0s 62ms/step - loss: 1.3406 - accuracy: 0.8667 - val_loss: 1.3768 - val_accuracy: 0.3333
# Epoch 9/20
# 1/1 [==============================] - 0s 60ms/step - loss: 1.3336 - accuracy: 0.8667 - val_loss: 1.3761 - val_accuracy: 0.3333
# Epoch 10/20
# 1/1 [==============================] - 0s 46ms/step - loss: 1.3262 - accuracy: 0.9000 - val_loss: 1.3754 - val_accuracy: 0.2857
# Epoch 11/20
# 1/1 [==============================] - 0s 54ms/step - loss: 1.3185 - accuracy: 0.9000 - val_loss: 1.3749 - val_accuracy: 0.3333
# Epoch 12/20
# 1/1 [==============================] - 0s 62ms/step - loss: 1.3104 - accuracy: 0.9000 - val_loss: 1.3743 - val_accuracy: 0.3810
# Epoch 13/20
# 1/1 [==============================] - 0s 58ms/step - loss: 1.3019 - accuracy: 0.9000 - val_loss: 1.3737 - val_accuracy: 0.3333
# Epoch 14/20
# 1/1 [==============================] - 0s 73ms/step - loss: 1.2930 - accuracy: 0.9000 - val_loss: 1.3731 - val_accuracy: 0.3333
# Epoch 15/20
# 1/1 [==============================] - 0s 60ms/step - loss: 1.2835 - accuracy: 0.9333 - val_loss: 1.3725 - val_accuracy: 0.2857
# Epoch 16/20
# 1/1 [==============================] - 0s 62ms/step - loss: 1.2735 - accuracy: 0.9333 - val_loss: 1.3718 - val_accuracy: 0.2857
# Epoch 17/20
# 1/1 [==============================] - 0s 61ms/step - loss: 1.2630 - accuracy: 0.9333 - val_loss: 1.3711 - val_accuracy: 0.2857
# Epoch 18/20
# 1/1 [==============================] - 0s 51ms/step - loss: 1.2518 - accuracy: 0.9667 - val_loss: 1.3705 - val_accuracy: 0.2857
# Epoch 19/20
# 1/1 [==============================] - 0s 62ms/step - loss: 1.2399 - accuracy: 0.9667 - val_loss: 1.3698 - val_accuracy: 0.2857
# Epoch 20/20
# 1/1 [==============================] - 0s 53ms/step - loss: 1.2272 - accuracy: 0.9667 - val_loss: 1.3692 - val_accuracy: 0.2857

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(len(acc))

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Acuracia no treino')
plt.plot(epochs_range, val_acc, label='Acuracia na validacao')
plt.legend(loc='lower right')
plt.title('Acuracia no treino na validacao')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Perda no treino')
plt.plot(epochs_range, val_loss, label='Perda na validacao')
plt.legend(loc='upper right')
plt.title('Perda no treino e na validacao')
plt.show()

# %%
model_drop = tf.keras.Sequential([
    layers.LSTM(128, input_shape=(Xtrain.shape[1], Xtrain.shape[2])),
    layers.Dense(64, activation='relu'),
    keras.layers.Dropout(rate=0.5),
    layers.Dense(num_classes, activation='softmax')
])

# %%
model_drop.compile(optimizer='adam',
                   loss='sparse_categorical_crossentropy',
                   metrics=['accuracy'])

# %%
EPOCHS = 20
history_drop = model_drop.fit(Xtrain, ytrain, epochs=EPOCHS, batch_size=32, validation_data=(Xtest, ytest))
# Out:
# Epoch 1/20
# 1/1 [==============================] - 5s 5s/step - loss: 1.3872 - accuracy: 0.1667 - val_loss: 1.3865 - val_accuracy: 0.1905
# Epoch 2/20
# 1/1 [==============================] - 0s 101ms/step - loss: 1.3830 - accuracy: 0.2000 - val_loss: 1.3858 - val_accuracy: 0.2381
# Epoch 3/20
# 1/1 [==============================] - 0s 88ms/step - loss: 1.3802 - accuracy: 0.4000 - val_loss: 1.3852 - val_accuracy: 0.2857
# Epoch 4/20
# 1/1 [==============================] - 0s 76ms/step - loss: 1.3704 - accuracy: 0.5333 - val_loss: 1.3847 - val_accuracy: 0.2857
# Epoch 5/20
# 1/1 [==============================] - 0s 87ms/step - loss: 1.3651 - accuracy: 0.6000 - val_loss: 1.3842 - val_accuracy: 0.2857
# Epoch 6/20
# 1/1 [==============================] - 0s 151ms/step - loss: 1.3652 - accuracy: 0.6333 - val_loss: 1.3838 - val_accuracy: 0.3333
# Epoch 7/20
# 1/1 [==============================] - 0s 146ms/step - loss: 1.3555 - accuracy: 0.7333 - val_loss: 1.3834 - val_accuracy: 0.3333
# Epoch 8/20
# 1/1 [==============================] - 0s 93ms/step - loss: 1.3480 - accuracy: 0.8000 - val_loss: 1.3830 - val_accuracy: 0.3810
# Epoch 9/20
# 1/1 [==============================] - 0s 144ms/step - loss: 1.3416 - accuracy: 0.8000 - val_loss: 1.3826 - val_accuracy: 0.3810
# Epoch 10/20
# 1/1 [==============================] - 0s 118ms/step - loss: 1.3356 - accuracy: 0.8333 - val_loss: 1.3823 - val_accuracy: 0.3810
# Epoch 11/20
# 1/1 [==============================] - 0s 66ms/step - loss: 1.3294 - accuracy: 0.9000 - val_loss: 1.3821 - val_accuracy: 0.3810
# Epoch 12/20
# 1/1 [==============================] - 0s 93ms/step - loss: 1.3226 - accuracy: 0.8667 - val_loss: 1.3819 - val_accuracy: 0.3810
# Epoch 13/20
# 1/1 [==============================] - 0s 219ms/step - loss: 1.3302 - accuracy: 0.7667 - val_loss: 1.3818 - val_accuracy: 0.2857
# Epoch 14/20
# 1/1 [==============================] - 0s 127ms/step - loss: 1.3090 - accuracy: 0.8667 - val_loss: 1.3817 - val_accuracy: 0.2857
# Epoch 15/20
# 1/1 [==============================] - 0s 91ms/step - loss: 1.2960 - accuracy: 0.9000 - val_loss: 1.3816 - val_accuracy: 0.2857
# Epoch 16/20
# 1/1 [==============================] - 0s 63ms/step - loss: 1.2965 - accuracy: 0.9333 - val_loss: 1.3815 - val_accuracy: 0.2857
# Epoch 17/20
# 1/1 [==============================] - 0s 67ms/step - loss: 1.2768 - accuracy: 0.9333 - val_loss: 1.3815 - val_accuracy: 0.2857
# Epoch 18/20
# 1/1 [==============================] - 0s 74ms/step - loss: 1.2766 - accuracy: 0.8667 - val_loss: 1.3814 - val_accuracy: 0.2857
# Epoch 19/20
# 1/1 [==============================] - 0s 80ms/step - loss: 1.2700 - accuracy: 0.9667 - val_loss: 1.3813 - val_accuracy: 0.2857
# Epoch 20/20
# 1/1 [==============================] - 0s 79ms/step - loss: 1.2685 - accuracy: 0.8667 - val_loss: 1.3812 - val_accuracy: 0.2857

# %%
acc2 = history_drop.history['accuracy']
val_acc2 = history_drop.history['val_accuracy']
loss2 = history_drop.history['loss']
val_loss2 = history_drop.history['val_loss']

epochs_range = range(len(acc2))

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc2, label='Acuracia no treino')
plt.plot(epochs_range, val_acc2, label='Acuracia na validacao')
plt.legend(loc='lower right')
plt.title('Acuracia no treino na validacao')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss2, label='Perda no treino')
plt.plot(epochs_range, val_loss2, label='Perda na validacao')
plt.legend(loc='upper right')
plt.title('Perda no treino e na validacao')
plt.show()

# %%
model_early = tf.keras.Sequential([
    layers.LSTM(128, input_shape=(Xtrain.shape[1], Xtrain.shape[2])),
    layers.Dense(64, activation='relu'),
    layers.Dense(num_classes, activation='softmax')
])

# %%
model_early.compile(optimizer='adam',
                   loss='sparse_categorical_crossentropy',
                   metrics=['accuracy'])

# %%
callbacks = [
    keras.callbacks.EarlyStopping(
        monitor="val_loss",
        min_delta=1e-2,
        patience=5,
        restore_best_weights=True,
        verbose=1,
    )
]

# %%
EPOCHS = 100
history_early = model_early.fit(Xtrain, ytrain,callbacks = callbacks, epochs=EPOCHS, batch_size=32, validation_data=(Xtest, ytest))
# Out:
# Epoch 1/100
# 1/1 [==============================] - 6s 6s/step - loss: 1.3854 - accuracy: 0.2667 - val_loss: 1.3851 - val_accuracy: 0.2381
# Epoch 2/100
# 1/1 [==============================] - 0s 80ms/step - loss: 1.3771 - accuracy: 0.4333 - val_loss: 1.3845 - val_accuracy: 0.2857
# Epoch 3/100
# 1/1 [==============================] - 0s 106ms/step - loss: 1.3691 - accuracy: 0.5667 - val_loss: 1.3838 - val_accuracy: 0.3333
# Epoch 4/100
# 1/1 [==============================] - 0s 115ms/step - loss: 1.3615 - accuracy: 0.7000 - val_loss: 1.3831 - val_accuracy: 0.3333
# Epoch 5/100
# 1/1 [==============================] - 0s 131ms/step - loss: 1.3540 - accuracy: 0.7333 - val_loss: 1.3824 - val_accuracy: 0.3333
# Epoch 6/100
# 1/1 [==============================] - ETA: 0s - loss: 1.3462 - accuracy: 0.8000Restoring model weights from the end of the best epoch: 1.
# 1/1 [==============================] - 0s 106ms/step - loss: 1.3462 - accuracy: 0.8000 - val_loss: 1.3817 - val_accuracy: 0.3810
# Epoch 6: early stopping

# %%
acc3 = history_early.history['accuracy']
val_acc3 = history_early.history['val_accuracy']
loss3 = history_early.history['loss']
val_loss3 = history_early.history['val_loss']

epochs_range = range(len(acc3))

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc3, label='Acuracia no treino')
plt.plot(epochs_range, val_acc3, label='Acuracia na validacao')
plt.legend(loc='lower right')
plt.title('Acuracia no treino na validacao')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss3, label='Perda no treino')
plt.plot(epochs_range, val_loss3, label='Perda na validacao')
plt.legend(loc='upper right')
plt.title('Perda no treino e na validacao')
plt.show()
